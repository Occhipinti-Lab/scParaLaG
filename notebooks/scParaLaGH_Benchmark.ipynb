# %%
# !pip install torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cu121
# !pip install dgl -f https://data.dgl.ai/wheels/torch-2.2/cu121/repo.html
# !pip install pydance
# !pip install --force-reinstall torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cu121
# !pip install numpy==1.24.0
# Out:
# Looking in indexes: https://download.pytorch.org/whl/cu121
# Requirement already satisfied: torch in /usr/local/lib/python3.12/dist-packages (2.8.0+cu126)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.12/dist-packages (0.23.0+cu126)
# Requirement already satisfied: torchaudio in /usr/local/lib/python3.12/dist-packages (2.8.0+cu126)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch) (3.20.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch) (4.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch) (1.13.3)
# Requirement already satisfied: networkx in /usr/local/lib/python3.12/dist-packages (from torch) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.12/dist-packages (from torch) (2025.3.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /usr/local/lib/python3.12/dist-packages (from torch) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /usr/local/lib/python3.12/dist-packages (from torch) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /usr/local/lib/python3.12/dist-packages (from torch) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /usr/local/lib/python3.12/dist-packages (from torch) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /usr/local/lib/python3.12/dist-packages (from torch) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /usr/local/lib/python3.12/dist-packages (from torch) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.3 in /usr/local/lib/python3.12/dist-packages (from torch) (2.27.3)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /usr/local/lib/python3.12/dist-packages (from torch) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /usr/local/lib/python3.12/dist-packages (from torch) (1.11.1.6)
# Requirement already satisfied: triton==3.4.0 in /usr/local/lib/python3.12/dist-packages (from torch) (3.4.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from torchvision) (2.0.2)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.12/dist-packages (from torchvision) (11.3.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch) (3.0.3)
# Looking in links: https://data.dgl.ai/wheels/torch-2.2/cu121/repo.html
# Collecting dgl
#   Downloading https://data.dgl.ai/wheels/torch-2.2/cu121/dgl-2.4.0%2Bcu121-cp312-cp312-manylinux1_x86_64.whl (483.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 483.9/483.9 MB 3.3 MB/s eta 0:00:00
# Requirement already satisfied: networkx>=2.1 in /usr/local/lib/python3.12/dist-packages (from dgl) (3.5)
# Requirement already satisfied: numpy>=1.14.0 in /usr/local/lib/python3.12/dist-packages (from dgl) (2.0.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from dgl) (25.0)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (from dgl) (2.2.2)
# Requirement already satisfied: psutil>=5.8.0 in /usr/local/lib/python3.12/dist-packages (from dgl) (5.9.5)
# Requirement already satisfied: pydantic>=2.0 in /usr/local/lib/python3.12/dist-packages (from dgl) (2.11.10)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.12/dist-packages (from dgl) (6.0.3)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.12/dist-packages (from dgl) (2.32.4)
# Requirement already satisfied: scipy>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from dgl) (1.16.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from dgl) (4.67.1)
# Collecting torch<=2.4.0 (from dgl)
#   Downloading torch-2.4.0-cp312-cp312-manylinux1_x86_64.whl.metadata (26 kB)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic>=2.0->dgl) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /usr/local/lib/python3.12/dist-packages (from pydantic>=2.0->dgl) (2.33.2)
# Requirement already satisfied: typing-extensions>=4.12.2 in /usr/local/lib/python3.12/dist-packages (from pydantic>=2.0->dgl) (4.15.0)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.12/dist-packages (from pydantic>=2.0->dgl) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.19.0->dgl) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests>=2.19.0->dgl) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.19.0->dgl) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests>=2.19.0->dgl) (2025.10.5)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch<=2.4.0->dgl) (3.20.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.12/dist-packages (from torch<=2.4.0->dgl) (1.13.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch<=2.4.0->dgl) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.12/dist-packages (from torch<=2.4.0->dgl) (2025.3.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch<=2.4.0->dgl) (75.2.0)
# Collecting nvidia-cuda-nvrtc-cu12==12.1.105 (from torch<=2.4.0->dgl)
#   Downloading nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.1.105 (from torch<=2.4.0->dgl)
#   Downloading nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.1.105 (from torch<=2.4.0->dgl)
#   Downloading nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==9.1.0.70 (from torch<=2.4.0->dgl)
#   Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.1.3.1 (from torch<=2.4.0->dgl)
#   Downloading nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.0.2.54 (from torch<=2.4.0->dgl)
#   Downloading nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.2.106 (from torch<=2.4.0->dgl)
#   Downloading nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.4.5.107 (from torch<=2.4.0->dgl)
#   Downloading nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.1.0.106 (from torch<=2.4.0->dgl)
#   Downloading nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-nccl-cu12==2.20.5 (from torch<=2.4.0->dgl)
#   Downloading nvidia_nccl_cu12-2.20.5-py3-none-manylinux2014_x86_64.whl.metadata (1.8 kB)
# Collecting nvidia-nvtx-cu12==12.1.105 (from torch<=2.4.0->dgl)
#   Downloading nvidia_nvtx_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.7 kB)
# Collecting triton==3.0.0 (from torch<=2.4.0->dgl)
#   Downloading triton-3.0.0-1-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.3 kB)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /usr/local/lib/python3.12/dist-packages (from nvidia-cusolver-cu12==11.4.5.107->torch<=2.4.0->dgl) (12.6.85)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas->dgl) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas->dgl) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas->dgl) (2025.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas->dgl) (1.17.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch<=2.4.0->dgl) (3.0.3)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy->torch<=2.4.0->dgl) (1.3.0)
# Downloading torch-2.4.0-cp312-cp312-manylinux1_x86_64.whl (797.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 797.2/797.2 MB 2.3 MB/s eta 0:00:00
# Downloading nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 410.6/410.6 MB 2.4 MB/s eta 0:00:00
# Downloading nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.1/14.1 MB 137.5 MB/s eta 0:00:00
# Downloading nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.7/23.7 MB 111.7 MB/s eta 0:00:00
# Downloading nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 823.6/823.6 kB 55.9 MB/s eta 0:00:00
# Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl (664.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 1.8 MB/s eta 0:00:00
# Downloading nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.6/121.6 MB 18.5 MB/s eta 0:00:00
# Downloading nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.5/56.5 MB 42.9 MB/s eta 0:00:00
# Downloading nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 124.2/124.2 MB 5.0 MB/s eta 0:00:00
# Downloading nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (196.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 196.0/196.0 MB 5.3 MB/s eta 0:00:00
# Downloading nvidia_nccl_cu12-2.20.5-py3-none-manylinux2014_x86_64.whl (176.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 176.2/176.2 MB 6.6 MB/s eta 0:00:00
# Downloading nvidia_nvtx_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (99 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 99.1/99.1 kB 9.8 MB/s eta 0:00:00
# Downloading triton-3.0.0-1-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (209.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 209.5/209.5 MB 3.5 MB/s eta 0:00:00
# Installing collected packages: triton, nvidia-nvtx-cu12, nvidia-nccl-cu12, nvidia-cusparse-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, nvidia-cusolver-cu12, nvidia-cudnn-cu12, torch, dgl
#   Attempting uninstall: triton
#     Found existing installation: triton 3.4.0
#     Uninstalling triton-3.4.0:
#       Successfully uninstalled triton-3.4.0
#   Attempting uninstall: nvidia-nvtx-cu12
#     Found existing installation: nvidia-nvtx-cu12 12.6.77
#     Uninstalling nvidia-nvtx-cu12-12.6.77:
#       Successfully uninstalled nvidia-nvtx-cu12-12.6.77
#   Attempting uninstall: nvidia-nccl-cu12
#     Found existing installation: nvidia-nccl-cu12 2.27.3
#     Uninstalling nvidia-nccl-cu12-2.27.3:
#       Successfully uninstalled nvidia-nccl-cu12-2.27.3
#   Attempting uninstall: nvidia-cusparse-cu12
#     Found existing installation: nvidia-cusparse-cu12 12.5.4.2
#     Uninstalling nvidia-cusparse-cu12-12.5.4.2:
#       Successfully uninstalled nvidia-cusparse-cu12-12.5.4.2
#   Attempting uninstall: nvidia-curand-cu12
#     Found existing installation: nvidia-curand-cu12 10.3.7.77
#     Uninstalling nvidia-curand-cu12-10.3.7.77:
#       Successfully uninstalled nvidia-curand-cu12-10.3.7.77
#   Attempting uninstall: nvidia-cufft-cu12
#     Found existing installation: nvidia-cufft-cu12 11.3.0.4
#     Uninstalling nvidia-cufft-cu12-11.3.0.4:
#       Successfully uninstalled nvidia-cufft-cu12-11.3.0.4
#   Attempting uninstall: nvidia-cuda-runtime-cu12
#     Found existing installation: nvidia-cuda-runtime-cu12 12.6.77
#     Uninstalling nvidia-cuda-runtime-cu12-12.6.77:
#       Successfully uninstalled nvidia-cuda-runtime-cu12-12.6.77
#   Attempting uninstall: nvidia-cuda-nvrtc-cu12
#     Found existing installation: nvidia-cuda-nvrtc-cu12 12.6.77
#     Uninstalling nvidia-cuda-nvrtc-cu12-12.6.77:
#       Successfully uninstalled nvidia-cuda-nvrtc-cu12-12.6.77
#   Attempting uninstall: nvidia-cuda-cupti-cu12
#     Found existing installation: nvidia-cuda-cupti-cu12 12.6.80
#     Uninstalling nvidia-cuda-cupti-cu12-12.6.80:
#       Successfully uninstalled nvidia-cuda-cupti-cu12-12.6.80
#   Attempting uninstall: nvidia-cublas-cu12
#     Found existing installation: nvidia-cublas-cu12 12.6.4.1
#     Uninstalling nvidia-cublas-cu12-12.6.4.1:
#       Successfully uninstalled nvidia-cublas-cu12-12.6.4.1
#   Attempting uninstall: nvidia-cusolver-cu12
#     Found existing installation: nvidia-cusolver-cu12 11.7.1.2
#     Uninstalling nvidia-cusolver-cu12-11.7.1.2:
#       Successfully uninstalled nvidia-cusolver-cu12-11.7.1.2
#   Attempting uninstall: nvidia-cudnn-cu12
#     Found existing installation: nvidia-cudnn-cu12 9.10.2.21
#     Uninstalling nvidia-cudnn-cu12-9.10.2.21:
#       Successfully uninstalled nvidia-cudnn-cu12-9.10.2.21
#   Attempting uninstall: torch
#     Found existing installation: torch 2.8.0+cu126
#     Uninstalling torch-2.8.0+cu126:
#       Successfully uninstalled torch-2.8.0+cu126
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# torchaudio 2.8.0+cu126 requires torch==2.8.0, but you have torch 2.4.0 which is incompatible.
# torchvision 0.23.0+cu126 requires torch==2.8.0, but you have torch 2.4.0 which is incompatible.
# Successfully installed dgl-2.4.0+cu121 nvidia-cublas-cu12-12.1.3.1 nvidia-cuda-cupti-cu12-12.1.105 nvidia-cuda-nvrtc-cu12-12.1.105 nvidia-cuda-runtime-cu12-12.1.105 nvidia-cudnn-cu12-9.1.0.70 nvidia-cufft-cu12-11.0.2.54 nvidia-curand-cu12-10.3.2.106 nvidia-cusolver-cu12-11.4.5.107 nvidia-cusparse-cu12-12.1.0.106 nvidia-nccl-cu12-2.20.5 nvidia-nvtx-cu12-12.1.105 torch-2.4.0 triton-3.0.0
# Collecting pydance
#   Downloading pydance-1.0.1-py3-none-any.whl.metadata (29 kB)
# Requirement already satisfied: h5py in /usr/local/lib/python3.12/dist-packages (from pydance) (3.15.0)
# Collecting igraph (from pydance)
#   Downloading igraph-0.11.9-cp39-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.4 kB)
# Collecting leidenalg (from pydance)
#   Downloading leidenalg-0.10.2-cp38-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (10 kB)
# Collecting louvain (from pydance)
#   Downloading louvain-0.8.2.tar.gz (4.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.2/4.2 MB 7.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting mudata (from pydance)
#   Downloading mudata-0.3.2-py3-none-any.whl.metadata (8.4 kB)
# Requirement already satisfied: networkx in /usr/local/lib/python3.12/dist-packages (from pydance) (3.5)
# Requirement already satisfied: numba in /usr/local/lib/python3.12/dist-packages (from pydance) (0.60.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from pydance) (2.0.2)
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.12/dist-packages (from pydance) (4.12.0.88)
# Requirement already satisfied: openpyxl in /usr/local/lib/python3.12/dist-packages (from pydance) (3.1.5)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (from pydance) (2.2.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from pydance) (2.32.4)
# Collecting scanpy (from pydance)
#   Downloading scanpy-1.11.4-py3-none-any.whl.metadata (9.2 kB)
# Collecting scib (from pydance)
#   Downloading scib-1.1.7-1-py3-none-any.whl.metadata (9.8 kB)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.12/dist-packages (from pydance) (1.6.1)
# Collecting scikit-misc (from pydance)
#   Downloading scikit_misc-0.5.1-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (5.0 kB)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from pydance) (1.16.2)
# Requirement already satisfied: statsmodels in /usr/local/lib/python3.12/dist-packages (from pydance) (0.14.5)
# Requirement already satisfied: tables in /usr/local/lib/python3.12/dist-packages (from pydance) (3.10.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from pydance) (3.6.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from pydance) (4.67.1)
# Collecting texttable>=1.6.2 (from igraph->pydance)
#   Downloading texttable-1.7.0-py2.py3-none-any.whl.metadata (9.8 kB)
# Collecting anndata>=0.10.8 (from mudata->pydance)
#   Downloading anndata-0.12.3-py3-none-any.whl.metadata (9.9 kB)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /usr/local/lib/python3.12/dist-packages (from numba->pydance) (0.43.0)
# Requirement already satisfied: et-xmlfile in /usr/local/lib/python3.12/dist-packages (from openpyxl->pydance) (2.0.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas->pydance) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas->pydance) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas->pydance) (2025.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->pydance) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->pydance) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->pydance) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->pydance) (2025.10.5)
# Requirement already satisfied: joblib in /usr/local/lib/python3.12/dist-packages (from scanpy->pydance) (1.5.2)
# Collecting legacy-api-wrap>=1.4.1 (from scanpy->pydance)
#   Downloading legacy_api_wrap-1.4.1-py3-none-any.whl.metadata (2.1 kB)
# Requirement already satisfied: matplotlib>=3.7.5 in /usr/local/lib/python3.12/dist-packages (from scanpy->pydance) (3.10.0)
# Requirement already satisfied: natsort in /usr/local/lib/python3.12/dist-packages (from scanpy->pydance) (8.4.0)
# Requirement already satisfied: packaging>=21.3 in /usr/local/lib/python3.12/dist-packages (from scanpy->pydance) (25.0)
# Requirement already satisfied: patsy!=1.0.0 in /usr/local/lib/python3.12/dist-packages (from scanpy->pydance) (1.0.1)
# Requirement already satisfied: pynndescent>=0.5.13 in /usr/local/lib/python3.12/dist-packages (from scanpy->pydance) (0.5.13)
# Requirement already satisfied: seaborn>=0.13.2 in /usr/local/lib/python3.12/dist-packages (from scanpy->pydance) (0.13.2)
# Collecting session-info2 (from scanpy->pydance)
#   Downloading session_info2-0.2.3-py3-none-any.whl.metadata (3.4 kB)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.12/dist-packages (from scanpy->pydance) (4.15.0)
# Requirement already satisfied: umap-learn>=0.5.6 in /usr/local/lib/python3.12/dist-packages (from scanpy->pydance) (0.5.9.post2)
# Requirement already satisfied: pydot in /usr/local/lib/python3.12/dist-packages (from scib->pydance) (3.0.4)
# Collecting deprecated (from scib->pydance)
#   Downloading Deprecated-1.2.18-py2.py3-none-any.whl.metadata (5.7 kB)
# Requirement already satisfied: numexpr>=2.6.2 in /usr/local/lib/python3.12/dist-packages (from tables->pydance) (2.14.1)
# Requirement already satisfied: py-cpuinfo in /usr/local/lib/python3.12/dist-packages (from tables->pydance) (9.0.0)
# Requirement already satisfied: blosc2>=2.3.0 in /usr/local/lib/python3.12/dist-packages (from tables->pydance) (3.10.1)
# Collecting array-api-compat>=1.7.1 (from anndata>=0.10.8->mudata->pydance)
#   Downloading array_api_compat-1.12.0-py3-none-any.whl.metadata (2.5 kB)
# Collecting zarr!=3.0.*,>=2.18.7 (from anndata>=0.10.8->mudata->pydance)
#   Downloading zarr-3.1.3-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: ndindex in /usr/local/lib/python3.12/dist-packages (from blosc2>=2.3.0->tables->pydance) (1.10.0)
# Requirement already satisfied: msgpack in /usr/local/lib/python3.12/dist-packages (from blosc2>=2.3.0->tables->pydance) (1.1.2)
# Requirement already satisfied: platformdirs in /usr/local/lib/python3.12/dist-packages (from blosc2>=2.3.0->tables->pydance) (4.5.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.7.5->scanpy->pydance) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.7.5->scanpy->pydance) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.7.5->scanpy->pydance) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.7.5->scanpy->pydance) (1.4.9)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.7.5->scanpy->pydance) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.7.5->scanpy->pydance) (3.2.5)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas->pydance) (1.17.0)
# Requirement already satisfied: wrapt<2,>=1.10 in /usr/local/lib/python3.12/dist-packages (from deprecated->scib->pydance) (1.17.3)
# Collecting donfig>=0.8 (from zarr!=3.0.*,>=2.18.7->anndata>=0.10.8->mudata->pydance)
#   Downloading donfig-0.8.1.post1-py3-none-any.whl.metadata (5.0 kB)
# Collecting numcodecs>=0.14 (from numcodecs[crc32c]>=0.14->zarr!=3.0.*,>=2.18.7->anndata>=0.10.8->mudata->pydance)
#   Downloading numcodecs-0.16.3-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.3 kB)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.12/dist-packages (from donfig>=0.8->zarr!=3.0.*,>=2.18.7->anndata>=0.10.8->mudata->pydance) (6.0.3)
# Collecting crc32c>=2.7 (from numcodecs[crc32c]>=0.14->zarr!=3.0.*,>=2.18.7->anndata>=0.10.8->mudata->pydance)
#   Downloading crc32c-2.8-cp312-cp312-manylinux1_x86_64.manylinux_2_28_x86_64.manylinux_2_5_x86_64.whl.metadata (7.8 kB)
# Downloading pydance-1.0.1-py3-none-any.whl (270 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 270.6/270.6 kB 26.6 MB/s eta 0:00:00
# Downloading igraph-0.11.9-cp39-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.4/4.4 MB 17.1 MB/s eta 0:00:00
# Downloading leidenalg-0.10.2-cp38-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 91.7 MB/s eta 0:00:00
# Downloading mudata-0.3.2-py3-none-any.whl (41 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.9/41.9 kB 4.1 MB/s eta 0:00:00
# Downloading scanpy-1.11.4-py3-none-any.whl (2.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 101.5 MB/s eta 0:00:00
# Downloading scib-1.1.7-1-py3-none-any.whl (84 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.6/84.6 kB 9.5 MB/s eta 0:00:00
# Downloading scikit_misc-0.5.1-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (183 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 183.6/183.6 kB 20.8 MB/s eta 0:00:00
# Downloading anndata-0.12.3-py3-none-any.whl (169 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 169.3/169.3 kB 19.1 MB/s eta 0:00:00
# Downloading legacy_api_wrap-1.4.1-py3-none-any.whl (10.0 kB)
# Downloading texttable-1.7.0-py2.py3-none-any.whl (10 kB)
# Downloading Deprecated-1.2.18-py2.py3-none-any.whl (10.0 kB)
# Downloading session_info2-0.2.3-py3-none-any.whl (16 kB)
# Downloading array_api_compat-1.12.0-py3-none-any.whl (58 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.2/58.2 kB 6.4 MB/s eta 0:00:00
# Downloading zarr-3.1.3-py3-none-any.whl (276 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 276.4/276.4 kB 27.5 MB/s eta 0:00:00
# Downloading donfig-0.8.1.post1-py3-none-any.whl (21 kB)
# Downloading numcodecs-0.16.3-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (8.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.8/8.8 MB 133.4 MB/s eta 0:00:00
# Downloading crc32c-2.8-cp312-cp312-manylinux1_x86_64.manylinux_2_28_x86_64.manylinux_2_5_x86_64.whl (80 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 80.0/80.0 kB 8.5 MB/s eta 0:00:00
# Building wheels for collected packages: louvain

# %% [markdown]
# ## **Template CODE**

# %%
import os
os.environ['DGLBACKEND'] = 'pytorch'
import random
import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
import dgl.nn as dglnn
from dgl.nn.pytorch.conv import GATConv, GraphConv, SAGEConv
from sklearn.cluster import KMeans
import torch.optim as optim
import math
import gc
import pandas as pd
from scipy.stats import pearsonr, spearmanr
from decimal import Decimal
from sklearn.metrics import mean_absolute_error
import dgl
import scipy.stats
from sklearn.neighbors import NearestNeighbors, kneighbors_graph
from sklearn.model_selection import train_test_split
from sklearn.metrics.pairwise import cosine_distances
from sklearn.decomposition import TruncatedSVD
from dance.data.base import Data

import argparse
from argparse import Namespace

from dance.datasets.multimodality import ModalityPredictionDataset
from dance.data import Data

# seed = 1
# random.seed(seed)
# np.random.seed(seed)
# torch.manual_seed(seed)
# torch.cuda.manual_seed(seed)
# torch.backends.cudnn.deterministic = True
# torch.backends.cudnn.benchmark = False

class LayerAttention(nn.Module):
    """
    A layer to compute attention weights over different layers' outputs.

    This layer calculates the attention weights for a set of layer outputs and produces a weighted sum of these outputs.

    Attributes
    ----------
    attention_weights : nn.Parameter
        The learnable attention weights.

    Methods
    -------
    forward(layer_outputs)
        Applies attention mechanism on the given layer outputs.

    Parameters
    ----------
    num_layers : int
        Number of layers for which attention weights are to be learned.
    num_feat : int
        The size of each feature vector.

    Usage
    -----
    - Instantiate this class and pass the outputs of different layers to the forward method to get a weighted sum.
    """
    def __init__(self, num_layers, num_feat):
        super(LayerAttention, self).__init__()
        self.attention_weights = nn.Parameter(torch.empty(num_layers, num_feat))
        nn.init.kaiming_normal_(self.attention_weights, mode='fan_in', nonlinearity='leaky_relu')

    def forward(self, layer_outputs):
        normalized_weights = F.softmax(self.attention_weights, dim=0)
        weighted_sum = sum(w * output for w, output in zip(normalized_weights, layer_outputs))
        return weighted_sum

class scParaLaG(nn.Module):
    """
    A model for graph neural network with parameterized layer aggregation.

    This model includes multiple convolutional, residual, and linear layers with an attention mechanism for aggregating
    the outputs of these layers.

    Attributes
    ----------
    conv_layers : nn.ModuleList
        A list of convolutional layers.
    residual_layers : nn.ModuleList
        A list of residual layers corresponding to the convolutional layers.
    linear_layers : nn.ModuleList
        A list of linear layers for transforming the output of the convolutional and residual layers.
    layer_attention : LayerAttention
        The layer attention mechanism for aggregating layer outputs.
    final_linear : nn.Linear
        The final linear layer for output transformation.
    dropout : nn.Dropout
        The dropout layer for regularization.

    Methods
    -------
    forward(g, features, conv_flow, agg_flow)
        Propagates input through the model layers and returns the final output.

    Parameters
    ----------
    num_heads : int
        Number of attention heads.
    FEATURE_SIZE : int
        Size of input features.
    OUTPUT_SIZE : int
        Size of output features.
    hidden_size : int
        Size of hidden layer features.
    conv_flow : list
        List of convolution layer types.
    agg_flow : list
        List of aggregation types for each convolution layer.
    act : str
        Activation function to use.
    dropout_rate : float
        Dropout rate for regularization.

    Usage
    -----
    - Instantiate this class and call the forward method with a graph, its features, and the convolution and aggregation flows.
    """
    def __init__(self, args):
        super().__init__()
        self.args = args


        num_heads = self.args.num_heads
        self.activation = self.get_activation_function(self.args.act)

        self.conv_layers = nn.ModuleList()
        self.linear_layers = nn.ModuleList()
        self.residual_layers = nn.ModuleList()
        self.layer_attention = LayerAttention(len(self.args.conv_flow) + self.args.layer_dim_ex, self.args.hidden_size)
        self.final_linear = nn.Linear(self.args.hidden_size, self.args.OUTPUT_SIZE)
        self.dropout = nn.Dropout(self.args.dropout_rate)

        in_feats = self.args.FEATURE_SIZE
        out_feats = self.args.hidden_size

        for i, (layer_type, aggregate_type) in enumerate(zip(self.args.conv_flow, self.args.agg_flow)):
            conv_layer = self.layer_factory(layer_type, in_feats, out_feats, aggregate_type, num_heads)
            self.conv_layers.append(conv_layer)

            out_in_dim = out_feats * num_heads if (layer_type == 'gat' and aggregate_type is None) else out_feats
            linear_layer = nn.Linear(in_feats, out_in_dim)
            self.linear_layers.append(linear_layer)

            residual_layer = nn.Linear(out_in_dim, self.args.hidden_size)
            self.residual_layers.append(residual_layer)

    def forward(self, g, features):
        layer_outputs = []

        for i, (conv_layer, residual_layer, linear_layer) in enumerate(
          zip(self.conv_layers, self.residual_layers, self.linear_layers)):
            conv_h = conv_layer(g, features)

            if self.args.conv_flow[i] == 'gat':
                if self.args.agg_flow[i] == 'mean':
                    conv_h = conv_h.mean(1)
                elif self.args.agg_flow[i] is None:
                    conv_h = conv_h.flatten(1)

            linear_h = linear_layer(features)
            conv_linear = conv_h + linear_h

            conv_linear_h = residual_layer(conv_linear)
            conv_linear_h = self.activation(conv_linear_h)
            conv_linear_h = self.dropout(conv_linear_h)
            layer_outputs.append(conv_linear_h)

        h = self.layer_attention(layer_outputs)
        h = self.final_linear(h)
        return h

    @staticmethod
    def layer_factory(layer_type, in_feats, out_feats, aggregate_type=None,
                      num_heads=None):
        """
        Factory method to create a layer based on the specified type.

        This method creates a graph convolutional layer of a specified type. It supports various types of layers like GATConv,
        GraphConv, and SAGEConv.

        Parameters
        ----------
        layer_type : str
            The type of layer to create ('gat', 'gconv', 'sage').
        in_feats : int
            The number of input features.
        out_feats : int
            The number of output features.
        aggregate_type : str, optional
            The type of aggregator for Conv layers.
        num_heads : int, optional
            The number of attention heads for GATConv layers.

        Returns
        -------
        nn.Module
            The created graph convolutional layer.

        Raises
        ------
        ValueError
            If the layer type is unknown.

        Usage
        -----
        - This method is used internally by the scParaLaG class to instantiate layers based on configuration parameters.
        """
        if layer_type == 'gat':
            return GATConv(in_feats=in_feats, out_feats=out_feats,
                           num_heads=num_heads, activation=F.leaky_relu)
        elif layer_type == 'gconv':
            return GraphConv(in_feats=in_feats, out_feats=out_feats)
        elif layer_type == 'sage':
            return SAGEConv(in_feats=in_feats, out_feats=out_feats,
                            aggregator_type=aggregate_type)
        else:
            raise ValueError(f"Unknown layer type: {layer_type}")

    @staticmethod
    def get_activation_function(name):
      """
      Get the specified activation function.

      This method returns an activation function based on the given name. It supports various activation functions like ReLU,
      Sigmoid, Tanh, Leaky ReLU, etc.

      Parameters
      ----------
      name : str
          The name of the activation function.

      Returns
      -------
      callable
          The corresponding activation function.

      Usage
      -----
      - This method is used internally by the scParaLaG class to set the activation function based on configuration parameters.
      """
      activation_functions = {
            'relu': F.relu,
            'relu6': F.relu6,
            'sigmoid': torch.sigmoid,
            'tanh': torch.tanh,
            'leaky_relu': F.leaky_relu,
            'selu': F.selu,
            'gelu': F.gelu,
            'rrelu': F.rrelu
      }
      return activation_functions.get(name)



class scParaLaG_Hierarchical(nn.Module):
    def __init__(self, args, num_clusters=10):
        super(scParaLaG_Hierarchical, self).__init__()
        self.args = args
        self.num_clusters = num_clusters
        num_heads = self.args.num_heads
        self.activation = scParaLaG_Hierarchical.get_activation_function(self.args.act)
        self.conv_layers = nn.ModuleList()
        self.linear_layers = nn.ModuleList()
        self.residual_layers = nn.ModuleList()
        self.layer_attention = LayerAttention(len(self.args.conv_flow) + self.args.layer_dim_ex, self.args.hidden_size)
        self.final_linear = nn.Linear(self.args.hidden_size, self.args.OUTPUT_SIZE)
        self.dropout = nn.Dropout(self.args.dropout_rate)
        # Hierarchical pooling doubles the feature dimension.
        in_feats = self.args.FEATURE_SIZE * 2
        out_feats = self.args.hidden_size
        for i, (layer_type, agg_type) in enumerate(zip(self.args.conv_flow, self.args.agg_flow)):
            conv_layer = scParaLaG_Hierarchical.layer_factory(layer_type, in_feats, out_feats, agg_type, num_heads)
            self.conv_layers.append(conv_layer)
            out_in_dim = out_feats * num_heads if (layer_type == 'gat' and agg_type is None) else out_feats
            linear_layer = nn.Linear(in_feats, out_in_dim)
            self.linear_layers.append(linear_layer)
            residual_layer = nn.Linear(out_in_dim, self.args.hidden_size)
            self.residual_layers.append(residual_layer)
            in_feats = self.args.hidden_size

    def hierarchical_pool(self, features):
        # features: [N, FEATURE_SIZE]
        N, feat_dim = features.shape
        features_np = features.detach().cpu().numpy()
        kmeans = KMeans(n_clusters=self.num_clusters, random_state=0).fit(features_np)
        labels = kmeans.labels_
        centroids = torch.tensor(kmeans.cluster_centers_, dtype=features.dtype, device=features.device)
        centroid_feats = centroids[torch.tensor(labels, device=features.device)]
        new_features = torch.cat([features, centroid_feats], dim=1)
        return new_features

    def forward(self, g, features):
        x = self.hierarchical_pool(features)  # now [N, FEATURE_SIZE*2]
        layer_outputs = []
        for i, (conv, linear, residual) in enumerate(zip(self.conv_layers, self.linear_layers, self.residual_layers)):
            conv_h = conv(g, x)
            if self.args.conv_flow[i] == 'gat':
                if self.args.agg_flow[i] == 'mean':
                    conv_h = conv_h.mean(1)
                elif self.args.agg_flow[i] is None:
                    conv_h = conv_h.flatten(1)
            linear_h = linear(x)
            combined = conv_h + linear_h
            res = residual(combined)
            res = self.activation(res)
            res = self.dropout(res)
            layer_outputs.append(res)
            x = res
        h = self.layer_attention(layer_outputs)
        h = self.final_linear(h)
        return h

    @staticmethod
    def layer_factory(layer_type, in_feats, out_feats, agg_type=None, num_heads=None):
        if layer_type == 'gat':
            return GATConv(in_feats=in_feats, out_feats=out_feats,
                           num_heads=num_heads, activation=F.leaky_relu)
        elif layer_type == 'gconv':
            return GraphConv(in_feats=in_feats, out_feats=out_feats)
        elif layer_type == 'sage':
            return SAGEConv(in_feats=in_feats, out_feats=out_feats,
                            aggregator_type=agg_type)
        else:
            raise ValueError(f"Unknown layer type: {layer_type}")

    @staticmethod
    def get_activation_function(name):
        funcs = {
            'relu': F.relu,
            'relu6': F.relu6,
            'sigmoid': torch.sigmoid,
            'tanh': torch.tanh,
            'leaky_relu': F.leaky_relu,
            'selu': F.selu,
            'gelu': F.gelu,
            'rrelu': F.rrelu
        }
        return funcs.get(name)

# %%
class CustomEarlyStopping:
    def __init__(self, patience=10, min_delta=0.001, rate_threshold=0.001):
        self.patience = patience
        self.min_delta = min_delta
        self.rate_threshold = rate_threshold
        self.best_loss = float('inf')
        self.best_epoch = -1
        self.epochs_since_improvement = 0
        self.prev_loss = float('inf')
    def update(self, current_loss, current_epoch):
        if current_loss < self.best_loss - self.min_delta:
            self.best_loss = current_loss
            self.best_epoch = current_epoch
            self.epochs_since_improvement = 0
        else:
            self.epochs_since_improvement += 1
        rate_of_improvement = (self.prev_loss - current_loss) / self.prev_loss if self.prev_loss != 0 else 0
        if rate_of_improvement < self.rate_threshold:
            self.epochs_since_improvement += 1
        print(f'Patience grace period: {self.patience - self.epochs_since_improvement}')
        self.prev_loss = current_loss
    def should_stop(self):
        return self.epochs_since_improvement >= self.patience

# Unified wrapper that selects a model variant based on args.variant.
class scParaLaGWrapper:
    def __init__(self, args):
        self.args = args
        if hasattr(self.args, 'variant'):
            variant = self.args.variant
        else:
            variant = "original"
        if variant == "original":
            ModelClass = scParaLaG
        elif variant == "hierarchical":
            ModelClass = scParaLaG_Hierarchical
        elif variant == "no_residual":
            ModelClass = scParaLaG_NoResidual
        elif variant == "no_attention":
            ModelClass = scParaLaG_NoAttention
        else:
            raise ValueError(f"Unknown variant: {variant}")
        self.model = ModelClass(self.args).to(self.args.device)

    def predict(self, graph, idx=None):
        self.model.eval()
        with torch.no_grad():
            if idx is not None:
                graph = graph.subgraph(idx).to(self.args.device)
            else:
                graph = graph.to(self.args.device)
            outputs = self.model(graph, graph.ndata['feat'])
        return outputs

    def score(self, graph, labels, idx=None):
        self.model.eval()
        with torch.no_grad():
            preds = self.predict(graph, idx)
            if idx is not None:
                preds = preds[idx]
                labels = labels[idx]
            mse_loss = F.mse_loss(preds, labels.to(self.args.device).float())
            rmse = math.sqrt(mse_loss.item())
            mae = mean_absolute_error(labels.cpu().numpy(), preds.cpu().numpy())
            return rmse, mae

    def fit(self, train_graph, val_graph, test_graph, train_label, val_label,
            test_label, num_epochs=500, batch_size=520, verbose=True,
            es_patience=20, es_min_delta=0.01, es_rate_threshold=0.001,
            learning_rate=0.000028, sample=True, l2_lambda=0.0):
        torch.manual_seed(self.args.seed)
        if self.args.device == "cuda":
            torch.cuda.manual_seed_all(self.args.seed)
        early_stopping = CustomEarlyStopping(patience=es_patience,
                                            min_delta=es_min_delta,
                                            rate_threshold=es_rate_threshold)
        optimizer = optim.Adam(self.model.parameters(), lr=learning_rate, weight_decay=l2_lambda)
        save_dir = "model_checkpoints"
        os.makedirs(save_dir, exist_ok=True)
        best_val_loss = float('inf')
        num_nodes = len(train_graph.ndata['feat'])
        indices = torch.randperm(num_nodes) if sample else torch.arange(num_nodes)
        for epoch in range(num_epochs):
            self.model.train()
            epoch_loss = 0
            for i in range(0, num_nodes, batch_size):
                batch_indices = indices[i:i+batch_size]
                subgraph = train_graph.subgraph(batch_indices).to(self.args.device)
                batch_labels = train_label[batch_indices].to(self.args.device).float()
                optimizer.zero_grad()
                outputs = self.model(subgraph, subgraph.ndata['feat'])
                loss = F.mse_loss(outputs, batch_labels)
                loss.backward()
                optimizer.step()
                epoch_loss += loss.item()
            avg_loss = math.sqrt(epoch_loss / (len(indices)/batch_size))
            val_rmse, val_mae = self.score(val_graph, val_label.float())
            test_rmse, test_mae = self.score(test_graph, test_label.float())
            if verbose:
                print('---------------------------------')
                print(f'Epoch {epoch+1}/{num_epochs}')
                print(f'Train RMSE: {avg_loss:.4f}')
                print(f'Val RMSE: {val_rmse:.4f}, Val MAE: {val_mae:.4f}')
                print(f'Test RMSE: {test_rmse:.4f}, Test MAE: {test_mae:.4f}')
                print('---------------------------------')
            if val_rmse < best_val_loss:
                best_val_loss = val_rmse
                torch.save(self.model.state_dict(), os.path.join(save_dir, 'best_model.pth'))
                print(f'Model saved at epoch {epoch+1} with val RMSE {val_rmse:.4f}')
            early_stopping.update(val_rmse, epoch)
            if early_stopping.should_stop():
                print(f"Early stopping triggered at epoch {epoch+1}")
                break
        self.model.load_state_dict(torch.load(os.path.join(save_dir, 'best_model.pth')))
        self.model.eval()
        final_test_rmse, final_test_mae = self.score(test_graph, test_label.float())
        print(f'Final Test RMSE: {final_test_rmse:.4f}, Final Test MAE: {final_test_mae:.4f}')
        # Compute correlation.
        test_graph = test_graph.to(self.args.device)
        test_feat = test_graph.ndata['feat'].to(self.args.device)
        test_label = test_label.to(self.args.device)
        outputs = self.model(test_graph, test_feat).to(self.args.device)
        rmse = math.sqrt(F.mse_loss(outputs, test_label))
        pred_cpu = outputs.cpu().detach().numpy()
        test_cpu = test_label.cpu().detach().numpy()
        pearson_corr, p_value_pearson = pearsonr(pred_cpu.flatten(), test_cpu.flatten())
        spearman_corr, p_value_spearman = spearmanr(pred_cpu.flatten(), test_cpu.flatten())
        p_value_pearson = Decimal(str(p_value_pearson)).quantize(Decimal('1.0000e+0')) if not math.isnan(p_value_pearson) else "NaN"
        p_value_spearman = Decimal(str(p_value_spearman)).quantize(Decimal('1.0000e+0')) if not math.isnan(p_value_spearman) else "NaN"
        print('Pearson Corr:', pearson_corr)
        print('Spearman Corr:', spearman_corr)
        print('p-rmse:', rmse)
        result = pd.DataFrame({
            'rmse': [rmse],
            'mae': [final_test_mae],
            'seed': [self.args.seed],
            'subtask': [self.args.subtask],
            'method': [self.args.variant if hasattr(self.args, 'variant') else 'original'],
            'pearson': [pearson_corr],
            'p_value_pearson': [p_value_pearson],
            'spearman': [spearman_corr],
            'p_value_spearman': [p_value_spearman]
        })
        print(result)
        # Clean up.
        del train_graph, val_graph, test_graph
        del train_label, val_label, test_label
        del outputs, test_feat, pred_cpu, test_cpu
        if self.args.device == "cuda":
            torch.cuda.empty_cache()
        gc.collect()

# %%
class GraphCreator:
    def __init__(self, preprocess_type, n_neighbors=20, n_components=1200,
                 metric='euclidean', weight_type='gaussian', sigma=1.0):
        self.preprocess_type = preprocess_type
        self.n_neighbors = n_neighbors
        self.n_components = n_components
        self.metric = metric
        self.weight_type = weight_type
        self.sigma = sigma

    def _compute_edge_weights(self, distances):
        if self.weight_type == 'gaussian':
            return np.exp(-distances**2 / (2 * self.sigma**2))
        elif self.weight_type == 'cosine':
            return 1 - distances
        return distances

    def _build_knn_graph(self, features):
        A = kneighbors_graph(features, n_neighbors=self.n_neighbors,
                           metric=self.metric, mode='distance',
                           include_self=True)
        # Convert distances to weights
        weights = self._compute_edge_weights(A.data)
        A.data = weights

        graph = dgl.from_scipy(A)
        graph.edata['weight'] = torch.tensor(weights, dtype=torch.float32)
        return graph

    def _create_graphs(self, train_features, val_features, test_features):
        """
        Create training and testing graphs using the provided feature sets.

        Parameters
        ----------
        train_features : array-like
            The feature set for training data.
        val_features : array-like
            The feature set for validation data.
        test_features : array-like
            The feature set for testing data.

        Returns
        -------
        tuple
            A tuple containing the training, validation and testing graphs (dgl.DGLGraph, dgl.DGLGraph, dgl.DGLGraph).
        """
        train_graph = self._build_knn_graph(train_features)
        val_graph = self._build_knn_graph(val_features)
        test_graph = self._build_knn_graph(test_features)
        return train_graph, val_graph, test_graph

    def __call__(self, data: Data) -> Data:
        """
        Call method to process the data and create graphs.

        Parameters
        ----------
        data : Data
            The data object containing training and testing data.

        Returns
        -------
        Data
            The updated data object with training and testing graphs added.
        train_label : torch.Tensor
            Labels corresponding to the training data.
        val_label : torch.Tensor
            Labels corresponding to the validation data.
        test_label : torch.Tensor
            Labels corresponding to the testing data.
        ftl_shape : tuple
            Feature and Label size of the dataset.
        """
        input, label = data.get_train_data(return_type="numpy")
        test_input, test_label = data.get_test_data(return_type="numpy")
        train_input, val_input, train_label, val_label = train_test_split(
            input, label, test_size=0.05, random_state=42)



        if self.preprocess_type == 'SVD':
            embedder = TruncatedSVD(n_components=self.n_components)
            train_input = embedder.fit_transform(
                scipy.sparse.csr_matrix(train_input))
            val_input = embedder.transform(scipy.sparse.csr_matrix(val_input))
            test_input = embedder.transform(scipy.sparse.csr_matrix(test_input))
            print("Truncated", train_input.shape)

        train_graph, val_graph, test_graph = self._create_graphs(
            train_input, val_input, test_input)
        train_graph.ndata['feat'] = torch.tensor(train_input, dtype=torch.float32)
        val_graph.ndata['feat'] = torch.tensor(val_input, dtype=torch.float32)
        test_graph.ndata['feat'] = torch.tensor(test_input, dtype=torch.float32)

        data.data.uns['gtrain'] = train_graph
        data.data.uns['gval'] = val_graph
        data.data.uns['gtest'] = test_graph
        ftl_shape = (train_input.shape[1], train_label.shape[1])

        return data, train_label, val_label, test_label, ftl_shape

# %%
def pipeline(**kwargs):
    print("\nInitializing pipeline...")
    subtask = kwargs["subtask"]
    dataset = ModalityPredictionDataset(subtask, preprocess='feature_selection')
    data = dataset.load_data()

    # Define a base name for the saved files, specific to the subtask
    base_file_name = f"processed_data_{kwargs['subtask']}"

    # Define paths for all the processed data components
    train_graph_path = f"{base_file_name}_train_graph.pt"
    val_graph_path = f"{base_file_name}_val_graph.pt"
    test_graph_path = f"{base_file_name}_test_graph.pt"
    train_label_path = f"{base_file_name}_train_label.pt"
    val_label_path = f"{base_file_name}_val_label.pt"
    test_label_path = f"{base_file_name}_test_label.pt"
    feature_size_path = f"{base_file_name}_feature_size.pt"
    output_size_path = f"{base_file_name}_output_size.pt"
    processed_flag_path = f"{base_file_name}_processed.flag"

    # Check if the processed data files exist
    if os.path.exists(processed_flag_path) and \
       os.path.exists(train_graph_path) and \
       os.path.exists(val_graph_path) and \
       os.path.exists(test_graph_path) and \
       os.path.exists(train_label_path) and \
       os.path.exists(val_label_path) and \
       os.path.exists(test_label_path) and \
       os.path.exists(feature_size_path) and \
       os.path.exists(output_size_path):
        print("Processed data found. Loading...")
        data.data.uns['gtrain'] = torch.load(train_graph_path)
        data.data.uns['gval'] = torch.load(val_graph_path)
        data.data.uns['gtest'] = torch.load(test_graph_path)
        train_label = torch.load(train_label_path).numpy()
        val_label = torch.load(val_label_path).numpy()
        test_label = torch.load(test_label_path).numpy()
        kwargs["FEATURE_SIZE"] = torch.load(feature_size_path).item()
        kwargs["OUTPUT_SIZE"] = torch.load(output_size_path).item()
        kwargs["processed"] = True
        print("Processed data loaded.")
    else:
        kwargs["processed"] = False

    # If necessary, override preprocessing_type based on subtask.
    if kwargs["subtask"] == "openproblems_bmmc_cite_phase2_mod2":
        kwargs["preprocessing_type"] = "None"

    # Create cell-based graph as before.
    if not kwargs["processed"]:
        print("Performing data processing using GraphCreator...")
        data, train_label, val_label, test_label, ftl_shape = GraphCreator(
            kwargs["preprocessing_type"], kwargs["n_neigbours"],
            kwargs["n_components"], kwargs["metric"])(data)
        if kwargs["preprocessing_type"] == "SVD":
            kwargs["FEATURE_SIZE"] = kwargs["n_components"]
        else:
            kwargs["FEATURE_SIZE"] = ftl_shape[0]
        kwargs["OUTPUT_SIZE"] = ftl_shape[1]
        train_graph = data.data.uns['gtrain']
        val_graph = data.data.uns['gval']
        test_graph = data.data.uns['gtest']

        # Save the processed data
        torch.save(train_graph, train_graph_path)
        torch.save(val_graph, val_graph_path)
        torch.save(test_graph, test_graph_path)
        torch.save(torch.tensor(train_label), train_label_path)
        torch.save(torch.tensor(val_label), val_label_path)
        torch.save(torch.tensor(test_label), test_label_path)
        torch.save(torch.tensor([kwargs["FEATURE_SIZE"]]), feature_size_path)
        torch.save(torch.tensor([kwargs["OUTPUT_SIZE"]]), output_size_path)

        # Create the flag file
        with open(processed_flag_path, 'w') as f:
            f.write('')
        print("Data processing using GraphCreator complete and saved.")
        kwargs["processed"] = True
    else:
        train_graph = data.data.uns['gtrain']
        val_graph = data.data.uns['gval']
        test_graph = data.data.uns['gtest']

    for rand_seed in range(5, 6):
        kwargs["seed"] = rand_seed
        # Instantiate the unified wrapper.
        model = scParaLaGWrapper(Namespace(**kwargs))
        model.fit(train_graph, val_graph, test_graph,
                  torch.tensor(train_label) if 'train_label' in locals() else None,
                  torch.tensor(val_label) if 'val_label' in locals() else None,
                  torch.tensor(test_label) if 'test_label' in locals() else None,
                  num_epochs=kwargs["num_epochs"],
                  batch_size=kwargs["batch_size"],
                  verbose=kwargs["verbose"],
                  es_patience=kwargs["es_patience"],
                  es_min_delta=kwargs["es_min_delta"],
                  es_rate_threshold=kwargs["es_rate_threshold"],
                  learning_rate=kwargs["learning_rate"],
                  sample=kwargs["sample"])


parser = argparse.ArgumentParser()
parser.add_argument("-st", "--subtask", default="openproblems_bmmc_cite_phase2_mod2")
parser.add_argument("-bs", "--batch_size", default=300, type=int) #400
parser.add_argument("-ac", "--act", default="leaky_relu", choices=["relu", "relu6", "gelu", "leaky_relu"])
parser.add_argument("-convf", "--conv_flow", nargs='*', choices=['gat', 'sage', 'gconv'], default=['gat'])
parser.add_argument("-aggf", "--agg_flow", nargs='*', choices=[None, 'mean'], default=[None])
parser.add_argument("-device", "--device", default="cuda")
parser.add_argument("-lr", "--learning_rate", type=float, default=0.000064)
parser.add_argument("-hid", "--hidden_size", type=int, default=520)
parser.add_argument("-nh", "--num_heads", type=int, default=3)
parser.add_argument("-nneig", "--n_neigbours", type=int, default=18) #18
parser.add_argument("-ncomp", "--n_components", type=int, default=1200)
parser.add_argument("-m", "--metric", type=str, default='euclidean')
parser.add_argument("-dr", "--dropout_rate", type=float, default=0.2)
parser.add_argument("-ne", "--num_epochs", type=int, default=500)
parser.add_argument("-sd", "--seed", type=int, default=1)
parser.add_argument("-pat", "--es_patience", type=int, default=40)
parser.add_argument("-esmd", "--es_min_delta", type=float, default=0.01)
parser.add_argument("-esrt", "--es_rate_threshold", type=float, default=0.0008)
parser.add_argument("-lde", "--layer_dim_ex", type=int, default=3)
parser.add_argument("-v", "--verbose", type=bool, default=True)
parser.add_argument("-sam", "--sample", type=bool, default=True)
parser.add_argument("-prep", "--preprocessing_type", default="None", choices=["None", "SVD"])
parser.add_argument("-ispro", "--processed", type=bool, default=False)
# New argument to select the variant.
parser.add_argument("-var", "--variant", type=str, default="original",
                    choices=["original", "no_residual", "no_attention", "hierarchical"])
# If hierarchical variant is used, we may also want to set the number of clusters.
parser.add_argument("-nc", "--num_clusters", type=int, default=10)

args, unk = parser.parse_known_args()
torch.set_num_threads(1)
#pipeline(**vars(args))

# %% [markdown]
# ## **Multiome RNA**

# %%
config_hierachical_MulRNA = {
    "subtask": "openproblems_bmmc_multiome_phase2_rna",
    "batch_size": 520,
    "act": "relu",
    "conv_flow": ["gat"],
    "agg_flow": [None],
    "device": "cuda",
    "learning_rate": 0.00064,
    "hidden_size": 520,
    "num_heads": 5,
    "n_neigbours": 5,
    "n_components": 1500,
    "metric": "euclidean",
    "dropout_rate": 0.2,
    "num_epochs": 500,
    "es_patience": 80,
    "es_min_delta": 0.01,
    "es_rate_threshold": 0.0008,
    "layer_dim_ex": 3,
    "verbose": True,
    "sample": True,
    "preprocessing_type": "SVD",
    "variant": "hierarchical",
    "num_clusters": 10
}

pipeline(**config_hierachical_MulRNA)
# Out:
# Initializing pipeline...
# [INFO][2025-04-05 05:40:39,163][dance][download_file] Downloading: /content/data/openproblems_bmmc_multiome_phase2_rna.zip Bytes: 1,661,364,326
# 100%|██████████| 1.55G/1.55G [01:37<00:00, 17.1MB/s]
# [INFO][2025-04-05 05:42:16,177][dance][unzip_file] Unzipping /content/data/openproblems_bmmc_multiome_phase2_rna.zip
# [INFO][2025-04-05 05:42:27,574][dance][delete_file] Deleting /content/data/openproblems_bmmc_multiome_phase2_rna.zip
# [INFO][2025-04-05 05:42:27,835][dance][_load_raw_data] Loading /content/data/openproblems_bmmc_multiome_phase2_rna/openproblems_bmmc_multiome_phase2_rna.censor_dataset.output_train_mod1.h5ad
# [INFO][2025-04-05 05:42:32,822][dance][_load_raw_data] Loading /content/data/openproblems_bmmc_multiome_phase2_rna/openproblems_bmmc_multiome_phase2_rna.censor_dataset.output_train_mod2.h5ad
# [INFO][2025-04-05 05:42:47,221][dance][_load_raw_data] Loading /content/data/openproblems_bmmc_multiome_phase2_rna/openproblems_bmmc_multiome_phase2_rna.censor_dataset.output_test_mod1.h5ad
# [INFO][2025-04-05 05:42:47,327][dance][_load_raw_data] Loading /content/data/openproblems_bmmc_multiome_phase2_rna/openproblems_bmmc_multiome_phase2_rna.censor_dataset.output_test_mod2.h5ad
# [INFO][2025-04-05 05:42:47,710][dance][_maybe_preprocess] Preprocessing done.
# /usr/local/lib/python3.11/dist-packages/mudata/_core/mudata.py:1531: FutureWarning: From 0.4 .update() will not pull obs/var columns from individual modalities by default anymore. Set mudata.set_options(pull_on_update=False) to adopt the new behaviour, which will become the default. Use new pull_obs/pull_var and push_obs/push_var methods for more flexibility.
#   self._update_attr("var", axis=0, join_common=join_common)
# /usr/local/lib/python3.11/dist-packages/mudata/_core/mudata.py:1429: FutureWarning: From 0.4 .update() will not pull obs/var columns from individual modalities by default anymore. Set mudata.set_options(pull_on_update=False) to adopt the new behaviour, which will become the default. Use new pull_obs/pull_var and push_obs/push_var methods for more flexibility.
#   self._update_attr("obs", axis=1, join_common=join_common)
# [INFO][2025-04-05 05:43:15,410][dance][set_config_from_dict] Setting config 'feature_mod' to 'mod1'
# [INFO][2025-04-05 05:43:15,411][dance][set_config_from_dict] Setting config 'label_mod' to 'mod2'
# [INFO][2025-04-05 05:43:15,412][dance][load_data] Raw data loaded:
# Data object that wraps (.data):
# MuData object with n_obs × n_vars = 43492 × 23431
#   uns:	'dance_config'
#   2 modalities
#     mod1:	43492 x 13431
#       obs:	'batch', 'size_factors'
#       layers:	'counts'
#     mod2:	43492 x 10000
#       obs:	'batch', 'size_factors'
#       obsm:	'gene_activity'
#       layers:	'counts'
# [INFO][2025-04-05 05:43:15,686][dance][wrapped_func] Took 0:02:38.479780 to load and process data.
# Truncated (40367, 1500)
# ---------------------------------
# Epoch 1/500
# Train RMSE: 0.1636
# Val RMSE: 0.1590, Val MAE: 0.0496
# Test RMSE: 0.1831, Test MAE: 0.0519
# ---------------------------------
# Model saved at epoch 1 with val RMSE 0.1590
# Patience grace period: 80
# ---------------------------------
# Epoch 2/500
# Train RMSE: 0.1589
# Val RMSE: 0.1583, Val MAE: 0.0517
# Test RMSE: 0.1822, Test MAE: 0.0506
# ---------------------------------
# Model saved at epoch 2 with val RMSE 0.1583
# Patience grace period: 79
# ---------------------------------
# Epoch 3/500
# Train RMSE: 0.1582
# Val RMSE: 0.1589, Val MAE: 0.0448
# Test RMSE: 0.1841, Test MAE: 0.0467
# ---------------------------------
# Patience grace period: 77
# ---------------------------------
# Epoch 4/500
# Train RMSE: 0.1580
# Val RMSE: 0.1580, Val MAE: 0.0521
# Test RMSE: 0.1803, Test MAE: 0.0521
# ---------------------------------
# Model saved at epoch 4 with val RMSE 0.1580
# Patience grace period: 76
# ---------------------------------
# Epoch 5/500
# Train RMSE: 0.1577
# Val RMSE: 0.1579, Val MAE: 0.0517
# Test RMSE: 0.1809, Test MAE: 0.0510
# ---------------------------------
# Model saved at epoch 5 with val RMSE 0.1579
# Patience grace period: 74
# ---------------------------------
# Epoch 6/500
# Train RMSE: 0.1575
# Val RMSE: 0.1578, Val MAE: 0.0507
# Test RMSE: 0.1817, Test MAE: 0.0497
# ---------------------------------
# Model saved at epoch 6 with val RMSE 0.1578
# Patience grace period: 72
# ---------------------------------
# Epoch 7/500
# Train RMSE: 0.1576
# Val RMSE: 0.1577, Val MAE: 0.0504
# Test RMSE: 0.1811, Test MAE: 0.0511
# ---------------------------------
# Model saved at epoch 7 with val RMSE 0.1577
# Patience grace period: 70
# ---------------------------------
# Epoch 8/500
# Train RMSE: 0.1574
# Val RMSE: 0.1577, Val MAE: 0.0509
# Test RMSE: 0.1800, Test MAE: 0.0528
# ---------------------------------
# Model saved at epoch 8 with val RMSE 0.1577
# Patience grace period: 68
# ---------------------------------
# Epoch 9/500
# Train RMSE: 0.1571
# Val RMSE: 0.1580, Val MAE: 0.0531
# Test RMSE: 0.1794, Test MAE: 0.0545
# ---------------------------------
# Patience grace period: 66
# ---------------------------------
# Epoch 10/500
# Train RMSE: 0.1572
# Val RMSE: 0.1589, Val MAE: 0.0551
# Test RMSE: 0.1797, Test MAE: 0.0543
# ---------------------------------
# Patience grace period: 64
# ---------------------------------
# Epoch 11/500
# Train RMSE: 0.1572
# Val RMSE: 0.1579, Val MAE: 0.0502
# Test RMSE: 0.1811, Test MAE: 0.0512
# ---------------------------------
# Patience grace period: 63
# ---------------------------------
# Epoch 12/500
# Train RMSE: 0.1570
# Val RMSE: 0.1577, Val MAE: 0.0495
# Test RMSE: 0.1800, Test MAE: 0.0526
# ---------------------------------
# Model saved at epoch 12 with val RMSE 0.1577
# Patience grace period: 62
# ---------------------------------
# Epoch 13/500
# Train RMSE: 0.1566
# Val RMSE: 0.1579, Val MAE: 0.0472
# Test RMSE: 0.1798, Test MAE: 0.0527
# ---------------------------------
# Patience grace period: 60
# ---------------------------------
# Epoch 14/500
# Train RMSE: 0.1568
# Val RMSE: 0.1579, Val MAE: 0.0478
# Test RMSE: 0.1798, Test MAE: 0.0527
# ---------------------------------
# Patience grace period: 58
# ---------------------------------
# Epoch 15/500
# Train RMSE: 0.1571
# Val RMSE: 0.1577, Val MAE: 0.0492
# Test RMSE: 0.1803, Test MAE: 0.0514
# ---------------------------------
# Patience grace period: 57
# ---------------------------------
# Epoch 16/500
# Train RMSE: 0.1569
# Val RMSE: 0.1579, Val MAE: 0.0524
# Test RMSE: 0.1797, Test MAE: 0.0530
# ---------------------------------
# Patience grace period: 55
# ---------------------------------
# Epoch 17/500
# Train RMSE: 0.1567
# Val RMSE: 0.1591, Val MAE: 0.0570
# Test RMSE: 0.1790, Test MAE: 0.0548
# ---------------------------------
# Patience grace period: 53
# ---------------------------------
# Epoch 18/500
# Train RMSE: 0.1565
# Val RMSE: 0.1608, Val MAE: 0.0614
# Test RMSE: 0.1786, Test MAE: 0.0568
# ---------------------------------
# Patience grace period: 51
# ---------------------------------
# Epoch 19/500
# Train RMSE: 0.1568
# Val RMSE: 0.1587, Val MAE: 0.0562
# Test RMSE: 0.1798, Test MAE: 0.0530
# ---------------------------------
# Patience grace period: 50
# ---------------------------------
# Epoch 20/500
# Train RMSE: 0.1570
# Val RMSE: 0.1575, Val MAE: 0.0511
# Test RMSE: 0.1803, Test MAE: 0.0518
# ---------------------------------
# Model saved at epoch 20 with val RMSE 0.1575
# Patience grace period: 49
# ---------------------------------
# Epoch 21/500
# Train RMSE: 0.1569
# Val RMSE: 0.1575, Val MAE: 0.0507
# Test RMSE: 0.1801, Test MAE: 0.0524
# ---------------------------------
# Patience grace period: 47
# ---------------------------------
# Epoch 22/500
# Train RMSE: 0.1567
# Val RMSE: 0.1577, Val MAE: 0.0492
# Test RMSE: 0.1803, Test MAE: 0.0519
# ---------------------------------
# Patience grace period: 45
# ---------------------------------
# Epoch 23/500
# Train RMSE: 0.1564
# Val RMSE: 0.1578, Val MAE: 0.0465
# Test RMSE: 0.1807, Test MAE: 0.0505
# ---------------------------------
# Patience grace period: 43
# ---------------------------------
# Epoch 24/500
# Train RMSE: 0.1563
# Val RMSE: 0.1582, Val MAE: 0.0448
# Test RMSE: 0.1808, Test MAE: 0.0501
# ---------------------------------
# Patience grace period: 41
# ---------------------------------
# Epoch 25/500
# Train RMSE: 0.1564
# Val RMSE: 0.1583, Val MAE: 0.0446
# Test RMSE: 0.1807, Test MAE: 0.0502
# ---------------------------------
# Patience grace period: 39
# ---------------------------------
# Epoch 26/500
# Train RMSE: 0.1564
# Val RMSE: 0.1580, Val MAE: 0.0453
# Test RMSE: 0.1802, Test MAE: 0.0508
# ---------------------------------
# Patience grace period: 38
# ---------------------------------
# Epoch 27/500
# Train RMSE: 0.1566
# Val RMSE: 0.1575, Val MAE: 0.0485
# Test RMSE: 0.1793, Test MAE: 0.0534
# ---------------------------------
# Model saved at epoch 27 with val RMSE 0.1575
# Patience grace period: 37
# ---------------------------------
# Epoch 28/500
# Train RMSE: 0.1566
# Val RMSE: 0.1582, Val MAE: 0.0555
# Test RMSE: 0.1785, Test MAE: 0.0583
# ---------------------------------
# Patience grace period: 35
# ---------------------------------
# Epoch 29/500
# Train RMSE: 0.1568
# Val RMSE: 0.1593, Val MAE: 0.0580
# Test RMSE: 0.1787, Test MAE: 0.0580
# ---------------------------------
# Patience grace period: 33
# ---------------------------------
# Epoch 30/500
# Train RMSE: 0.1566
# Val RMSE: 0.1585, Val MAE: 0.0553
# Test RMSE: 0.1794, Test MAE: 0.0544
# ---------------------------------
# Patience grace period: 32
# ---------------------------------
# Epoch 31/500
# Train RMSE: 0.1564
# Val RMSE: 0.1578, Val MAE: 0.0527
# Test RMSE: 0.1799, Test MAE: 0.0525
# ---------------------------------
# Patience grace period: 31
# ---------------------------------
# Epoch 32/500
# Train RMSE: 0.1561
# Val RMSE: 0.1576, Val MAE: 0.0512
# Test RMSE: 0.1803, Test MAE: 0.0514
# ---------------------------------
# Patience grace period: 30
# ---------------------------------
# Epoch 33/500
# Train RMSE: 0.1558
# Val RMSE: 0.1576, Val MAE: 0.0507
# Test RMSE: 0.1806, Test MAE: 0.0505
# ---------------------------------
# Patience grace period: 28
# ---------------------------------
# Epoch 34/500
# Train RMSE: 0.1556
# Val RMSE: 0.1576, Val MAE: 0.0504
# Test RMSE: 0.1806, Test MAE: 0.0505
# ---------------------------------
# Patience grace period: 26
# ---------------------------------
# Epoch 35/500
# Train RMSE: 0.1555
# Val RMSE: 0.1577, Val MAE: 0.0505
# Test RMSE: 0.1805, Test MAE: 0.0509
# ---------------------------------
# Patience grace period: 24
# ---------------------------------
# Epoch 36/500
# Train RMSE: 0.1555
# Val RMSE: 0.1579, Val MAE: 0.0507
# Test RMSE: 0.1804, Test MAE: 0.0512
# ---------------------------------
# Patience grace period: 22
# ---------------------------------
# Epoch 37/500
# Train RMSE: 0.1555
# Val RMSE: 0.1583, Val MAE: 0.0516
# Test RMSE: 0.1798, Test MAE: 0.0525
# ---------------------------------
# Patience grace period: 20
# ---------------------------------
# Epoch 38/500
# Train RMSE: 0.1556
# Val RMSE: 0.1586, Val MAE: 0.0529
# Test RMSE: 0.1794, Test MAE: 0.0534
# ---------------------------------
# Patience grace period: 18
# ---------------------------------
# Epoch 39/500
# Train RMSE: 0.1557
# Val RMSE: 0.1583, Val MAE: 0.0528
# Test RMSE: 0.1794, Test MAE: 0.0531
# ---------------------------------
# Patience grace period: 17
# ---------------------------------
# Epoch 40/500
# Train RMSE: 0.1558
# Val RMSE: 0.1576, Val MAE: 0.0518
# Test RMSE: 0.1791, Test MAE: 0.0548
# ---------------------------------
# Patience grace period: 16
# ---------------------------------
# Epoch 41/500
# Train RMSE: 0.1560
# Val RMSE: 0.1596, Val MAE: 0.0587
# Test RMSE: 0.1782, Test MAE: 0.0587
# ---------------------------------
# Patience grace period: 14
# ---------------------------------
# Epoch 42/500
# Train RMSE: 0.1561
# Val RMSE: 0.1611, Val MAE: 0.0621
# Test RMSE: 0.1784, Test MAE: 0.0594
# ---------------------------------
# Patience grace period: 12
# ---------------------------------
# Epoch 43/500
# Train RMSE: 0.1561
# Val RMSE: 0.1583, Val MAE: 0.0543
# Test RMSE: 0.1792, Test MAE: 0.0553
# ---------------------------------
# Patience grace period: 11
# ---------------------------------
# Epoch 44/500
# Train RMSE: 0.1560
# Val RMSE: 0.1577, Val MAE: 0.0511
# Test RMSE: 0.1801, Test MAE: 0.0522
# ---------------------------------
# Patience grace period: 10
# ---------------------------------
# Epoch 45/500
# Train RMSE: 0.1556
# Val RMSE: 0.1577, Val MAE: 0.0499
# Test RMSE: 0.1803, Test MAE: 0.0513
# ---------------------------------
# Patience grace period: 8
# ---------------------------------
# Epoch 46/500
# Train RMSE: 0.1553
# Val RMSE: 0.1576, Val MAE: 0.0489
# Test RMSE: 0.1802, Test MAE: 0.0511
# ---------------------------------
# Patience grace period: 6
# ---------------------------------
# Epoch 47/500
# Train RMSE: 0.1551
# Val RMSE: 0.1578, Val MAE: 0.0482
# Test RMSE: 0.1803, Test MAE: 0.0508
# ---------------------------------
# Patience grace period: 4
# ---------------------------------
# Epoch 48/500
# Train RMSE: 0.1550
# Val RMSE: 0.1579, Val MAE: 0.0474
# Test RMSE: 0.1802, Test MAE: 0.0510
# ---------------------------------
# Patience grace period: 2
# ---------------------------------
# Epoch 49/500
# Train RMSE: 0.1550
# Val RMSE: 0.1578, Val MAE: 0.0467
# Test RMSE: 0.1805, Test MAE: 0.0499
# ---------------------------------
# Patience grace period: 0
# Early stopping triggered at epoch 49
# <ipython-input-2-d8b64875fc37>:120: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   self.model.load_state_dict(torch.load(os.path.join(save_dir, 'best_model.pth')))
# Final Test RMSE: 0.1793, Final Test MAE: 0.0534
# Pearson Corr: 0.32081304472001443
# Spearman Corr: 0.22048720424031532
# p-rmse: 0.17927039497324848
#       rmse       mae  seed                                subtask  \
# 0  0.17927  0.053426     1  openproblems_bmmc_multiome_phase2_rna
#
#          method   pearson p_value_pearson  spearman p_value_spearman
# 0  hierarchical  0.320813          0.0000  0.220487           0.0000
# ---------------------------------
# Epoch 1/500
# Train RMSE: 0.1640
# Val RMSE: 0.1590, Val MAE: 0.0528
# Test RMSE: 0.1814, Test MAE: 0.0533
# ---------------------------------
# Model saved at epoch 1 with val RMSE 0.1590
# Patience grace period: 80
# ---------------------------------
# Epoch 2/500
# Train RMSE: 0.1589
# Val RMSE: 0.1585, Val MAE: 0.0519
# Test RMSE: 0.1818, Test MAE: 0.0513
# ---------------------------------
# Model saved at epoch 2 with val RMSE 0.1585
# Patience grace period: 79
# ---------------------------------
# Epoch 3/500
# Train RMSE: 0.1584
# Val RMSE: 0.1586, Val MAE: 0.0459
# Test RMSE: 0.1822, Test MAE: 0.0491
# ---------------------------------
# Patience grace period: 77
# ---------------------------------
# Epoch 4/500
# Train RMSE: 0.1581
# Val RMSE: 0.1580, Val MAE: 0.0490
# Test RMSE: 0.1813, Test MAE: 0.0499
# ---------------------------------
# Model saved at epoch 4 with val RMSE 0.1580
# Patience grace period: 76
# ---------------------------------
# Epoch 5/500
# Train RMSE: 0.1578
# Val RMSE: 0.1585, Val MAE: 0.0549
# Test RMSE: 0.1797, Test MAE: 0.0537
# ---------------------------------
# Patience grace period: 74
# ---------------------------------
# Epoch 6/500
# Train RMSE: 0.1578
# Val RMSE: 0.1579, Val MAE: 0.0500
# Test RMSE: 0.1823, Test MAE: 0.0488
# ---------------------------------
# Model saved at epoch 6 with val RMSE 0.1579
# Patience grace period: 73
# ---------------------------------
# Epoch 7/500
# Train RMSE: 0.1576
# Val RMSE: 0.1578, Val MAE: 0.0485
# Test RMSE: 0.1823, Test MAE: 0.0486
# ---------------------------------
# Model saved at epoch 7 with val RMSE 0.1578
# Patience grace period: 72
# ---------------------------------
# Epoch 8/500
# Train RMSE: 0.1572
# Val RMSE: 0.1578, Val MAE: 0.0486
# Test RMSE: 0.1820, Test MAE: 0.0488
# ---------------------------------
# Patience grace period: 70
# ---------------------------------
# Epoch 9/500
# Train RMSE: 0.1573
# Val RMSE: 0.1585, Val MAE: 0.0549
# Test RMSE: 0.1793, Test MAE: 0.0538
# ---------------------------------
# Patience grace period: 68
# ---------------------------------
# Epoch 10/500
# Train RMSE: 0.1576
# Val RMSE: 0.1579, Val MAE: 0.0508
# Test RMSE: 0.1801, Test MAE: 0.0530
# ---------------------------------
# Patience grace period: 67
# ---------------------------------
# Epoch 11/500
# Train RMSE: 0.1571
# Val RMSE: 0.1580, Val MAE: 0.0540
# Test RMSE: 0.1794, Test MAE: 0.0544
# ---------------------------------
# Patience grace period: 65
# ---------------------------------
# Epoch 12/500
# Train RMSE: 0.1570
# Val RMSE: 0.1579, Val MAE: 0.0478
# Test RMSE: 0.1810, Test MAE: 0.0507
# ---------------------------------
# Patience grace period: 63
# ---------------------------------
# Epoch 13/500
# Train RMSE: 0.1573
# Val RMSE: 0.1579, Val MAE: 0.0518
# Test RMSE: 0.1801, Test MAE: 0.0542
# ---------------------------------
# Patience grace period: 61
# ---------------------------------
# Epoch 14/500
# Train RMSE: 0.1573
# Val RMSE: 0.1579, Val MAE: 0.0537
# Test RMSE: 0.1796, Test MAE: 0.0549
# ---------------------------------
# Patience grace period: 59
# ---------------------------------
# Epoch 15/500
# Train RMSE: 0.1570
# Val RMSE: 0.1584, Val MAE: 0.0551
# Test RMSE: 0.1801, Test MAE: 0.0527
# ---------------------------------
# Patience grace period: 57
# ---------------------------------
# Epoch 16/500
# Train RMSE: 0.1568
# Val RMSE: 0.1582, Val MAE: 0.0536
# Test RMSE: 0.1796, Test MAE: 0.0537
# ---------------------------------
# Patience grace period: 56
# ---------------------------------
# Epoch 17/500
# Train RMSE: 0.1568
# Val RMSE: 0.1577, Val MAE: 0.0485
# Test RMSE: 0.1800, Test MAE: 0.0520
# ---------------------------------
# Model saved at epoch 17 with val RMSE 0.1577
# Patience grace period: 55
# ---------------------------------
# Epoch 18/500
# Train RMSE: 0.1567
# Val RMSE: 0.1584, Val MAE: 0.0452
# Test RMSE: 0.1805, Test MAE: 0.0508
# ---------------------------------
# Patience grace period: 53
# ---------------------------------
# Epoch 19/500
# Train RMSE: 0.1568
# Val RMSE: 0.1593, Val MAE: 0.0425
# Test RMSE: 0.1815, Test MAE: 0.0488
# ---------------------------------
# Patience grace period: 51
# ---------------------------------
# Epoch 20/500
# Train RMSE: 0.1570
# Val RMSE: 0.1594, Val MAE: 0.0421
# Test RMSE: 0.1814, Test MAE: 0.0489
# ---------------------------------
# Patience grace period: 49
# ---------------------------------
# Epoch 21/500
# Train RMSE: 0.1570
# Val RMSE: 0.1589, Val MAE: 0.0433
# Test RMSE: 0.1811, Test MAE: 0.0495
# ---------------------------------
# Patience grace period: 48
# ---------------------------------
# Epoch 22/500
# Train RMSE: 0.1570
# Val RMSE: 0.1584, Val MAE: 0.0446
# Test RMSE: 0.1809, Test MAE: 0.0501
# ---------------------------------
# Patience grace period: 47
# ---------------------------------
# Epoch 23/500
# Train RMSE: 0.1570
# Val RMSE: 0.1576, Val MAE: 0.0495
# Test RMSE: 0.1797, Test MAE: 0.0526
# ---------------------------------
# Model saved at epoch 23 with val RMSE 0.1576
# Patience grace period: 46
# ---------------------------------
# Epoch 24/500
# Train RMSE: 0.1568
# Val RMSE: 0.1587, Val MAE: 0.0571
# Test RMSE: 0.1790, Test MAE: 0.0556
# ---------------------------------
# Patience grace period: 44
# ---------------------------------
# Epoch 25/500
# Train RMSE: 0.1565
# Val RMSE: 0.1597, Val MAE: 0.0600
# Test RMSE: 0.1788, Test MAE: 0.0561
# ---------------------------------
# Patience grace period: 42
# ---------------------------------
# Epoch 26/500
# Train RMSE: 0.1563
# Val RMSE: 0.1599, Val MAE: 0.0603
# Test RMSE: 0.1789, Test MAE: 0.0559
# ---------------------------------
# Patience grace period: 40
# ---------------------------------
# Epoch 27/500
# Train RMSE: 0.1560
# Val RMSE: 0.1604, Val MAE: 0.0608
# Test RMSE: 0.1788, Test MAE: 0.0553
# ---------------------------------
# Patience grace period: 38
# ---------------------------------
# Epoch 28/500
# Train RMSE: 0.1559
# Val RMSE: 0.1609, Val MAE: 0.0623
# Test RMSE: 0.1786, Test MAE: 0.0571
# ---------------------------------
# Patience grace period: 36
# ---------------------------------
# Epoch 29/500
# Train RMSE: 0.1558
# Val RMSE: 0.1597, Val MAE: 0.0586
# Test RMSE: 0.1790, Test MAE: 0.0543
# ---------------------------------
# Patience grace period: 35
# ---------------------------------
# Epoch 30/500
# Train RMSE: 0.1559
# Val RMSE: 0.1582, Val MAE: 0.0540
# Test RMSE: 0.1790, Test MAE: 0.0545
# ---------------------------------
# Patience grace period: 34
# ---------------------------------
# Epoch 31/500
# Train RMSE: 0.1560
# Val RMSE: 0.1577, Val MAE: 0.0499
# Test RMSE: 0.1794, Test MAE: 0.0534
# ---------------------------------
# Patience grace period: 33
# ---------------------------------
# Epoch 32/500
# Train RMSE: 0.1562
# Val RMSE: 0.1581, Val MAE: 0.0492
# Test RMSE: 0.1798, Test MAE: 0.0527
# ---------------------------------
# Patience grace period: 31
# ---------------------------------
# Epoch 33/500
# Train RMSE: 0.1564
# Val RMSE: 0.1582, Val MAE: 0.0487
# Test RMSE: 0.1799, Test MAE: 0.0528
# ---------------------------------
# Patience grace period: 29
# ---------------------------------
# Epoch 34/500
# Train RMSE: 0.1566
# Val RMSE: 0.1577, Val MAE: 0.0487
# Test RMSE: 0.1797, Test MAE: 0.0530
# ---------------------------------
# Patience grace period: 28
# ---------------------------------
# Epoch 35/500
# Train RMSE: 0.1566
# Val RMSE: 0.1577, Val MAE: 0.0481
# Test RMSE: 0.1801, Test MAE: 0.0514
# ---------------------------------
# Patience grace period: 26
# ---------------------------------
# Epoch 36/500
# Train RMSE: 0.1565
# Val RMSE: 0.1575, Val MAE: 0.0501
# Test RMSE: 0.1798, Test MAE: 0.0527
# ---------------------------------
# Model saved at epoch 36 with val RMSE 0.1575
# Patience grace period: 25
# ---------------------------------
# Epoch 37/500
# Train RMSE: 0.1561
# Val RMSE: 0.1580, Val MAE: 0.0535
# Test RMSE: 0.1795, Test MAE: 0.0538
# ---------------------------------
# Patience grace period: 23
# ---------------------------------
# Epoch 38/500
# Train RMSE: 0.1557
# Val RMSE: 0.1583, Val MAE: 0.0543
# Test RMSE: 0.1797, Test MAE: 0.0529
# ---------------------------------
# Patience grace period: 21
# ---------------------------------
# Epoch 39/500
# Train RMSE: 0.1554
# Val RMSE: 0.1581, Val MAE: 0.0536
# Test RMSE: 0.1801, Test MAE: 0.0515
# ---------------------------------
# Patience grace period: 20
# ---------------------------------
# Epoch 40/500
# Train RMSE: 0.1551
# Val RMSE: 0.1582, Val MAE: 0.0539
# Test RMSE: 0.1802, Test MAE: 0.0513
# ---------------------------------
# Patience grace period: 18
# ---------------------------------
# Epoch 41/500
# Train RMSE: 0.1549
# Val RMSE: 0.1582, Val MAE: 0.0541
# Test RMSE: 0.1803, Test MAE: 0.0510
# ---------------------------------
# Patience grace period: 16
# ---------------------------------
# Epoch 42/500
# Train RMSE: 0.1549
# Val RMSE: 0.1583, Val MAE: 0.0543
# Test RMSE: 0.1801, Test MAE: 0.0516
# ---------------------------------
# Patience grace period: 14
# ---------------------------------
# Epoch 43/500
# Train RMSE: 0.1549
# Val RMSE: 0.1589, Val MAE: 0.0564
# Test RMSE: 0.1797, Test MAE: 0.0528
# ---------------------------------
# Patience grace period: 12
# ---------------------------------
# Epoch 44/500
# Train RMSE: 0.1549
# Val RMSE: 0.1604, Val MAE: 0.0604
# Test RMSE: 0.1791, Test MAE: 0.0551
# ---------------------------------
# Patience grace period: 10
# ---------------------------------
# Epoch 45/500
# Train RMSE: 0.1553
# Val RMSE: 0.1604, Val MAE: 0.0604
# Test RMSE: 0.1789, Test MAE: 0.0568
# ---------------------------------
# Patience grace period: 8
# ---------------------------------
# Epoch 46/500
# Train RMSE: 0.1555
# Val RMSE: 0.1589, Val MAE: 0.0573
# Test RMSE: 0.1792, Test MAE: 0.0552
# ---------------------------------
# Patience grace period: 7
# ---------------------------------
# Epoch 47/500
# Train RMSE: 0.1554
# Val RMSE: 0.1585, Val MAE: 0.0524
# Test RMSE: 0.1795, Test MAE: 0.0540
# ---------------------------------
# Patience grace period: 6
# ---------------------------------
# Epoch 48/500
# Train RMSE: 0.1553
# Val RMSE: 0.1583, Val MAE: 0.0511
# Test RMSE: 0.1793, Test MAE: 0.0543
# ---------------------------------
# Patience grace period: 5
# ---------------------------------
# Epoch 49/500
# Train RMSE: 0.1553
# Val RMSE: 0.1582, Val MAE: 0.0488
# Test RMSE: 0.1797, Test MAE: 0.0533
# ---------------------------------
# Patience grace period: 4
# ---------------------------------
# Epoch 50/500
# Train RMSE: 0.1553
# Val RMSE: 0.1580, Val MAE: 0.0471
# Test RMSE: 0.1800, Test MAE: 0.0522
# ---------------------------------
# Patience grace period: 3
# ---------------------------------
# Epoch 51/500
# Train RMSE: 0.1553
# Val RMSE: 0.1579, Val MAE: 0.0464
# Test RMSE: 0.1798, Test MAE: 0.0525
# ---------------------------------
# Patience grace period: 1
# ---------------------------------
# Epoch 52/500
# Train RMSE: 0.1553
# Val RMSE: 0.1577, Val MAE: 0.0474
# Test RMSE: 0.1797, Test MAE: 0.0530
# ---------------------------------
# Patience grace period: 0
# Early stopping triggered at epoch 52
# <ipython-input-2-d8b64875fc37>:120: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   self.model.load_state_dict(torch.load(os.path.join(save_dir, 'best_model.pth')))
# Final Test RMSE: 0.1798, Final Test MAE: 0.0527
# Pearson Corr: 0.3190973622717237
# Spearman Corr: 0.21574248885232813
# p-rmse: 0.17983837635022706
#        rmse       mae  seed                                subtask  \
# 0  0.179838  0.052683     2  openproblems_bmmc_multiome_phase2_rna
#
#          method   pearson p_value_pearson  spearman p_value_spearman
# 0  hierarchical  0.319097          0.0000  0.215742           0.0000
# ---------------------------------
# Epoch 1/500
# Train RMSE: 0.1641
# Val RMSE: 0.1591, Val MAE: 0.0497
# Test RMSE: 0.1828, Test MAE: 0.0520
# ---------------------------------
# Model saved at epoch 1 with val RMSE 0.1591
# Patience grace period: 80
# ---------------------------------
# Epoch 2/500
# Train RMSE: 0.1591
# Val RMSE: 0.1585, Val MAE: 0.0487
# Test RMSE: 0.1816, Test MAE: 0.0512
# ---------------------------------
# Model saved at epoch 2 with val RMSE 0.1585
# Patience grace period: 79
# ---------------------------------
# Epoch 3/500
# Train RMSE: 0.1586
# Val RMSE: 0.1582, Val MAE: 0.0505
# Test RMSE: 0.1802, Test MAE: 0.0529
# ---------------------------------
# Model saved at epoch 3 with val RMSE 0.1582
# Patience grace period: 78
# ---------------------------------
# Epoch 4/500
# Train RMSE: 0.1582
# Val RMSE: 0.1583, Val MAE: 0.0477
# Test RMSE: 0.1812, Test MAE: 0.0505
# ---------------------------------
# Patience grace period: 76
# ---------------------------------
# Epoch 5/500
# Train RMSE: 0.1579
# Val RMSE: 0.1580, Val MAE: 0.0488
# Test RMSE: 0.1799, Test MAE: 0.0534
# ---------------------------------
# Model saved at epoch 5 with val RMSE 0.1580
# Patience grace period: 75
# ---------------------------------
# Epoch 6/500
# Train RMSE: 0.1577
# Val RMSE: 0.1581, Val MAE: 0.0491
# Test RMSE: 0.1803, Test MAE: 0.0528
# ---------------------------------
# Patience grace period: 73
# ---------------------------------
# Epoch 7/500
# Train RMSE: 0.1579
# Val RMSE: 0.1581, Val MAE: 0.0533
# Test RMSE: 0.1792, Test MAE: 0.0558
# ---------------------------------
# Patience grace period: 71
# ---------------------------------
# Epoch 8/500
# Train RMSE: 0.1577
# Val RMSE: 0.1579, Val MAE: 0.0532
# Test RMSE: 0.1793, Test MAE: 0.0553
# ---------------------------------
# Model saved at epoch 8 with val RMSE 0.1579
# Patience grace period: 70
# ---------------------------------
# Epoch 9/500
# Train RMSE: 0.1574
# Val RMSE: 0.1578, Val MAE: 0.0533
# Test RMSE: 0.1793, Test MAE: 0.0554
# ---------------------------------
# Model saved at epoch 9 with val RMSE 0.1578
# Patience grace period: 68
# ---------------------------------
# Epoch 10/500
# Train RMSE: 0.1572
# Val RMSE: 0.1578, Val MAE: 0.0495
# Test RMSE: 0.1799, Test MAE: 0.0535
# ---------------------------------
# Model saved at epoch 10 with val RMSE 0.1578
# Patience grace period: 66
# ---------------------------------
# Epoch 11/500
# Train RMSE: 0.1573
# Val RMSE: 0.1586, Val MAE: 0.0457
# Test RMSE: 0.1810, Test MAE: 0.0512
# ---------------------------------
# Patience grace period: 64
# ---------------------------------
# Epoch 12/500
# Train RMSE: 0.1574
# Val RMSE: 0.1577, Val MAE: 0.0486
# Test RMSE: 0.1797, Test MAE: 0.0531
# ---------------------------------
# Model saved at epoch 12 with val RMSE 0.1577
# Patience grace period: 63
# ---------------------------------
# Epoch 13/500
# Train RMSE: 0.1573
# Val RMSE: 0.1581, Val MAE: 0.0547
# Test RMSE: 0.1791, Test MAE: 0.0550
# ---------------------------------
# Patience grace period: 61
# ---------------------------------
# Epoch 14/500
# Train RMSE: 0.1569
# Val RMSE: 0.1582, Val MAE: 0.0553
# Test RMSE: 0.1790, Test MAE: 0.0555
# ---------------------------------
# Patience grace period: 59
# ---------------------------------
# Epoch 15/500
# Train RMSE: 0.1568
# Val RMSE: 0.1581, Val MAE: 0.0532
# Test RMSE: 0.1790, Test MAE: 0.0550
# ---------------------------------
# Patience grace period: 57
# ---------------------------------
# Epoch 16/500
# Train RMSE: 0.1569
# Val RMSE: 0.1580, Val MAE: 0.0485
# Test RMSE: 0.1792, Test MAE: 0.0541
# ---------------------------------
# Patience grace period: 56
# ---------------------------------
# Epoch 17/500
# Train RMSE: 0.1570
# Val RMSE: 0.1582, Val MAE: 0.0477
# Test RMSE: 0.1796, Test MAE: 0.0532
# ---------------------------------
# Patience grace period: 54
# ---------------------------------
# Epoch 18/500
# Train RMSE: 0.1569
# Val RMSE: 0.1579, Val MAE: 0.0491
# Test RMSE: 0.1798, Test MAE: 0.0527
# ---------------------------------
# Patience grace period: 53
# ---------------------------------
# Epoch 19/500
# Train RMSE: 0.1566
# Val RMSE: 0.1577, Val MAE: 0.0501
# Test RMSE: 0.1799, Test MAE: 0.0523
# ---------------------------------
# Model saved at epoch 19 with val RMSE 0.1577
# Patience grace period: 52
# ---------------------------------
# Epoch 20/500
# Train RMSE: 0.1565
# Val RMSE: 0.1577, Val MAE: 0.0494
# Test RMSE: 0.1802, Test MAE: 0.0515
# ---------------------------------
# Model saved at epoch 20 with val RMSE 0.1577
# Patience grace period: 50
# ---------------------------------
# Epoch 21/500
# Train RMSE: 0.1565
# Val RMSE: 0.1578, Val MAE: 0.0473
# Test RMSE: 0.1803, Test MAE: 0.0510
# ---------------------------------
# Patience grace period: 48
# ---------------------------------
# Epoch 22/500
# Train RMSE: 0.1566
# Val RMSE: 0.1581, Val MAE: 0.0462
# Test RMSE: 0.1808, Test MAE: 0.0507
# ---------------------------------
# Patience grace period: 46
# ---------------------------------
# Epoch 23/500
# Train RMSE: 0.1568
# Val RMSE: 0.1584, Val MAE: 0.0462
# Test RMSE: 0.1806, Test MAE: 0.0513
# ---------------------------------
# Patience grace period: 44
# ---------------------------------
# Epoch 24/500
# Train RMSE: 0.1571
# Val RMSE: 0.1576, Val MAE: 0.0501
# Test RMSE: 0.1791, Test MAE: 0.0543
# ---------------------------------
# Model saved at epoch 24 with val RMSE 0.1576
# Patience grace period: 43
# ---------------------------------
# Epoch 25/500
# Train RMSE: 0.1569
# Val RMSE: 0.1578, Val MAE: 0.0531
# Test RMSE: 0.1787, Test MAE: 0.0559
# ---------------------------------
# Patience grace period: 41
# ---------------------------------
# Epoch 26/500
# Train RMSE: 0.1568
# Val RMSE: 0.1588, Val MAE: 0.0575
# Test RMSE: 0.1785, Test MAE: 0.0588
# ---------------------------------
# Patience grace period: 39
# ---------------------------------
# Epoch 27/500
# Train RMSE: 0.1568
# Val RMSE: 0.1582, Val MAE: 0.0545
# Test RMSE: 0.1790, Test MAE: 0.0562
# ---------------------------------
# Patience grace period: 38
# ---------------------------------
# Epoch 28/500
# Train RMSE: 0.1565
# Val RMSE: 0.1577, Val MAE: 0.0513
# Test RMSE: 0.1793, Test MAE: 0.0542
# ---------------------------------
# Patience grace period: 37
# ---------------------------------
# Epoch 29/500
# Train RMSE: 0.1564
# Val RMSE: 0.1577, Val MAE: 0.0490
# Test RMSE: 0.1797, Test MAE: 0.0527
# ---------------------------------
# Patience grace period: 35
# ---------------------------------
# Epoch 30/500
# Train RMSE: 0.1562
# Val RMSE: 0.1579, Val MAE: 0.0471
# Test RMSE: 0.1801, Test MAE: 0.0515
# ---------------------------------
# Patience grace period: 33
# ---------------------------------
# Epoch 31/500
# Train RMSE: 0.1561
# Val RMSE: 0.1581, Val MAE: 0.0449
# Test RMSE: 0.1804, Test MAE: 0.0506
# ---------------------------------
# Patience grace period: 31
# ---------------------------------
# Epoch 32/500
# Train RMSE: 0.1562
# Val RMSE: 0.1582, Val MAE: 0.0450
# Test RMSE: 0.1805, Test MAE: 0.0505
# ---------------------------------
# Patience grace period: 29
# ---------------------------------
# Epoch 33/500
# Train RMSE: 0.1563
# Val RMSE: 0.1580, Val MAE: 0.0465
# Test RMSE: 0.1804, Test MAE: 0.0507
# ---------------------------------
# Patience grace period: 28
# ---------------------------------
# Epoch 34/500
# Train RMSE: 0.1564
# Val RMSE: 0.1578, Val MAE: 0.0476
# Test RMSE: 0.1802, Test MAE: 0.0513
# ---------------------------------
# Patience grace period: 27
# ---------------------------------
# Epoch 35/500
# Train RMSE: 0.1565
# Val RMSE: 0.1576, Val MAE: 0.0506
# Test RMSE: 0.1794, Test MAE: 0.0528
# ---------------------------------
# Model saved at epoch 35 with val RMSE 0.1576
# Patience grace period: 26
# ---------------------------------
# Epoch 36/500
# Train RMSE: 0.1565
# Val RMSE: 0.1591, Val MAE: 0.0585
# Test RMSE: 0.1785, Test MAE: 0.0575
# ---------------------------------
# Patience grace period: 24
# ---------------------------------
# Epoch 37/500
# Train RMSE: 0.1563
# Val RMSE: 0.1585, Val MAE: 0.0564
# Test RMSE: 0.1785, Test MAE: 0.0575
# ---------------------------------
# Patience grace period: 23
# ---------------------------------
# Epoch 38/500
# Train RMSE: 0.1561
# Val RMSE: 0.1581, Val MAE: 0.0538
# Test RMSE: 0.1788, Test MAE: 0.0554
# ---------------------------------
# Patience grace period: 22
# ---------------------------------
# Epoch 39/500
# Train RMSE: 0.1558
# Val RMSE: 0.1579, Val MAE: 0.0528
# Test RMSE: 0.1788, Test MAE: 0.0551
# ---------------------------------
# Patience grace period: 21
# ---------------------------------
# Epoch 40/500
# Train RMSE: 0.1556
# Val RMSE: 0.1577, Val MAE: 0.0508
# Test RMSE: 0.1790, Test MAE: 0.0542
# ---------------------------------
# Patience grace period: 20
# ---------------------------------
# Epoch 41/500
# Train RMSE: 0.1555
# Val RMSE: 0.1577, Val MAE: 0.0491
# Test RMSE: 0.1793, Test MAE: 0.0531
# ---------------------------------
# Patience grace period: 18
# ---------------------------------
# Epoch 42/500
# Train RMSE: 0.1554
# Val RMSE: 0.1577, Val MAE: 0.0475
# Test RMSE: 0.1796, Test MAE: 0.0520
# ---------------------------------
# Patience grace period: 16
# ---------------------------------
# Epoch 43/500
# Train RMSE: 0.1555
# Val RMSE: 0.1579, Val MAE: 0.0477
# Test RMSE: 0.1800, Test MAE: 0.0515
# ---------------------------------
# Patience grace period: 14
# ---------------------------------
# Epoch 44/500
# Train RMSE: 0.1557
# Val RMSE: 0.1582, Val MAE: 0.0490
# Test RMSE: 0.1803, Test MAE: 0.0517
# ---------------------------------
# Patience grace period: 12
# ---------------------------------
# Epoch 45/500
# Train RMSE: 0.1557
# Val RMSE: 0.1579, Val MAE: 0.0498
# Test RMSE: 0.1797, Test MAE: 0.0526
# ---------------------------------
# Patience grace period: 11
# ---------------------------------
# Epoch 46/500
# Train RMSE: 0.1558
# Val RMSE: 0.1577, Val MAE: 0.0495
# Test RMSE: 0.1796, Test MAE: 0.0524
# ---------------------------------
# Patience grace period: 10
# ---------------------------------
# Epoch 47/500
# Train RMSE: 0.1559
# Val RMSE: 0.1587, Val MAE: 0.0565
# Test RMSE: 0.1785, Test MAE: 0.0577
# ---------------------------------
# Patience grace period: 8
# ---------------------------------
# Epoch 48/500
# Train RMSE: 0.1558
# Val RMSE: 0.1608, Val MAE: 0.0626
# Test RMSE: 0.1784, Test MAE: 0.0615
# ---------------------------------
# Patience grace period: 6
# ---------------------------------
# Epoch 49/500
# Train RMSE: 0.1557
# Val RMSE: 0.1600, Val MAE: 0.0612
# Test RMSE: 0.1784, Test MAE: 0.0600
# ---------------------------------
# Patience grace period: 5
# ---------------------------------
# Epoch 50/500
# Train RMSE: 0.1557
# Val RMSE: 0.1587, Val MAE: 0.0565
# Test RMSE: 0.1788, Test MAE: 0.0563
# ---------------------------------
# Patience grace period: 4
# ---------------------------------
# Epoch 51/500
# Train RMSE: 0.1553
# Val RMSE: 0.1587, Val MAE: 0.0554
# Test RMSE: 0.1787, Test MAE: 0.0559
# ---------------------------------
# Patience grace period: 2
# ---------------------------------
# Epoch 52/500
# Train RMSE: 0.1552
# Val RMSE: 0.1590, Val MAE: 0.0547
# Test RMSE: 0.1791, Test MAE: 0.0545
# ---------------------------------
# Patience grace period: 0
# Early stopping triggered at epoch 52
# <ipython-input-2-d8b64875fc37>:120: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   self.model.load_state_dict(torch.load(os.path.join(save_dir, 'best_model.pth')))
# Final Test RMSE: 0.1794, Final Test MAE: 0.0528
# Pearson Corr: 0.3213582336295567
# Spearman Corr: 0.22062842545217026
# p-rmse: 0.1793721064058374
#        rmse       mae  seed                                subtask  \
# 0  0.179372  0.052755     3  openproblems_bmmc_multiome_phase2_rna
#
#          method   pearson p_value_pearson  spearman p_value_spearman
# 0  hierarchical  0.321358          0.0000  0.220628           0.0000
# ---------------------------------
# Epoch 1/500
# Train RMSE: 0.1642
# Val RMSE: 0.1590, Val MAE: 0.0500
# Test RMSE: 0.1826, Test MAE: 0.0518
# ---------------------------------
# Model saved at epoch 1 with val RMSE 0.1590
# Patience grace period: 80
# ---------------------------------
# Epoch 2/500
# Train RMSE: 0.1590
# Val RMSE: 0.1584, Val MAE: 0.0496
# Test RMSE: 0.1817, Test MAE: 0.0508
# ---------------------------------
# Model saved at epoch 2 with val RMSE 0.1584
# Patience grace period: 79
# ---------------------------------
# Epoch 3/500
# Train RMSE: 0.1585
# Val RMSE: 0.1582, Val MAE: 0.0527
# Test RMSE: 0.1799, Test MAE: 0.0535
# ---------------------------------
# Model saved at epoch 3 with val RMSE 0.1582
# Patience grace period: 78
# ---------------------------------
# Epoch 4/500
# Train RMSE: 0.1582
# Val RMSE: 0.1581, Val MAE: 0.0484
# Test RMSE: 0.1814, Test MAE: 0.0500
# ---------------------------------
# Model saved at epoch 4 with val RMSE 0.1581
# Patience grace period: 76
# ---------------------------------
# Epoch 5/500
# Train RMSE: 0.1579
# Val RMSE: 0.1579, Val MAE: 0.0508
# Test RMSE: 0.1805, Test MAE: 0.0517
# ---------------------------------
# Model saved at epoch 5 with val RMSE 0.1579
# Patience grace period: 75
# ---------------------------------
# Epoch 6/500
# Train RMSE: 0.1577
# Val RMSE: 0.1582, Val MAE: 0.0472
# Test RMSE: 0.1815, Test MAE: 0.0501
# ---------------------------------
# Patience grace period: 73
# ---------------------------------
# Epoch 7/500
# Train RMSE: 0.1578
# Val RMSE: 0.1579, Val MAE: 0.0498
# Test RMSE: 0.1802, Test MAE: 0.0524
# ---------------------------------
# Model saved at epoch 7 with val RMSE 0.1579
# Patience grace period: 72
# ---------------------------------
# Epoch 8/500
# Train RMSE: 0.1576
# Val RMSE: 0.1582, Val MAE: 0.0524
# Test RMSE: 0.1802, Test MAE: 0.0524
# ---------------------------------
# Patience grace period: 70
# ---------------------------------
# Epoch 9/500
# Train RMSE: 0.1572
# Val RMSE: 0.1593, Val MAE: 0.0566
# Test RMSE: 0.1797, Test MAE: 0.0533
# ---------------------------------
# Patience grace period: 68
# ---------------------------------
# Epoch 10/500
# Train RMSE: 0.1574
# Val RMSE: 0.1580, Val MAE: 0.0506
# Test RMSE: 0.1800, Test MAE: 0.0523
# ---------------------------------
# Patience grace period: 67
# ---------------------------------
# Epoch 11/500
# Train RMSE: 0.1574
# Val RMSE: 0.1583, Val MAE: 0.0473
# Test RMSE: 0.1807, Test MAE: 0.0511
# ---------------------------------
# Patience grace period: 65
# ---------------------------------
# Epoch 12/500
# Train RMSE: 0.1571
# Val RMSE: 0.1582, Val MAE: 0.0466
# Test RMSE: 0.1806, Test MAE: 0.0509
# ---------------------------------
# Patience grace period: 63
# ---------------------------------
# Epoch 13/500
# Train RMSE: 0.1569
# Val RMSE: 0.1583, Val MAE: 0.0459
# Test RMSE: 0.1802, Test MAE: 0.0513
# ---------------------------------
# Patience grace period: 61
# ---------------------------------
# Epoch 14/500
# Train RMSE: 0.1571
# Val RMSE: 0.1579, Val MAE: 0.0519
# Test RMSE: 0.1797, Test MAE: 0.0533
# ---------------------------------
# Patience grace period: 60
# ---------------------------------
# Epoch 15/500
# Train RMSE: 0.1572
# Val RMSE: 0.1594, Val MAE: 0.0593
# Test RMSE: 0.1795, Test MAE: 0.0542
# ---------------------------------
# Patience grace period: 58
# ---------------------------------
# Epoch 16/500
# Train RMSE: 0.1571
# Val RMSE: 0.1579, Val MAE: 0.0549
# Test RMSE: 0.1794, Test MAE: 0.0545
# ---------------------------------
# Patience grace period: 57
# ---------------------------------
# Epoch 17/500
# Train RMSE: 0.1568
# Val RMSE: 0.1585, Val MAE: 0.0558
# Test RMSE: 0.1792, Test MAE: 0.0544
# ---------------------------------
# Patience grace period: 55
# ---------------------------------
# Epoch 18/500
# Train RMSE: 0.1565
# Val RMSE: 0.1585, Val MAE: 0.0546
# Test RMSE: 0.1791, Test MAE: 0.0544
# ---------------------------------
# Patience grace period: 53
# ---------------------------------
# Epoch 19/500
# Train RMSE: 0.1563
# Val RMSE: 0.1589, Val MAE: 0.0551
# Test RMSE: 0.1792, Test MAE: 0.0543
# ---------------------------------
# Patience grace period: 51
# ---------------------------------
# Epoch 20/500
# Train RMSE: 0.1564
# Val RMSE: 0.1581, Val MAE: 0.0506
# Test RMSE: 0.1797, Test MAE: 0.0522
# ---------------------------------
# Patience grace period: 50
# ---------------------------------
# Epoch 21/500
# Train RMSE: 0.1567
# Val RMSE: 0.1580, Val MAE: 0.0484
# Test RMSE: 0.1802, Test MAE: 0.0513
# ---------------------------------
# Patience grace period: 48
# ---------------------------------
# Epoch 22/500
# Train RMSE: 0.1571
# Val RMSE: 0.1577, Val MAE: 0.0506
# Test RMSE: 0.1798, Test MAE: 0.0527
# ---------------------------------
# Model saved at epoch 22 with val RMSE 0.1577
# Patience grace period: 47
# ---------------------------------
# Epoch 23/500
# Train RMSE: 0.1572
# Val RMSE: 0.1580, Val MAE: 0.0511
# Test RMSE: 0.1796, Test MAE: 0.0533
# ---------------------------------
# Patience grace period: 45
# ---------------------------------
# Epoch 24/500
# Train RMSE: 0.1570
# Val RMSE: 0.1583, Val MAE: 0.0500
# Test RMSE: 0.1798, Test MAE: 0.0527
# ---------------------------------
# Patience grace period: 43
# ---------------------------------
# Epoch 25/500
# Train RMSE: 0.1567
# Val RMSE: 0.1583, Val MAE: 0.0475
# Test RMSE: 0.1802, Test MAE: 0.0513
# ---------------------------------
# Patience grace period: 41
# ---------------------------------
# Epoch 26/500
# Train RMSE: 0.1565
# Val RMSE: 0.1582, Val MAE: 0.0464
# Test RMSE: 0.1803, Test MAE: 0.0508
# ---------------------------------
# Patience grace period: 39
# ---------------------------------
# Epoch 27/500
# Train RMSE: 0.1564
# Val RMSE: 0.1581, Val MAE: 0.0465
# Test RMSE: 0.1801, Test MAE: 0.0512
# ---------------------------------
# Patience grace period: 38
# ---------------------------------
# Epoch 28/500
# Train RMSE: 0.1565
# Val RMSE: 0.1578, Val MAE: 0.0486
# Test RMSE: 0.1796, Test MAE: 0.0525
# ---------------------------------
# Patience grace period: 37
# ---------------------------------
# Epoch 29/500
# Train RMSE: 0.1565
# Val RMSE: 0.1579, Val MAE: 0.0525
# Test RMSE: 0.1791, Test MAE: 0.0549
# ---------------------------------
# Patience grace period: 35
# ---------------------------------
# Epoch 30/500
# Train RMSE: 0.1564
# Val RMSE: 0.1590, Val MAE: 0.0570
# Test RMSE: 0.1787, Test MAE: 0.0563
# ---------------------------------
# Patience grace period: 33
# ---------------------------------
# Epoch 31/500
# Train RMSE: 0.1563
# Val RMSE: 0.1606, Val MAE: 0.0598
# Test RMSE: 0.1786, Test MAE: 0.0566
# ---------------------------------
# Patience grace period: 31
# ---------------------------------
# Epoch 32/500
# Train RMSE: 0.1564
# Val RMSE: 0.1602, Val MAE: 0.0587
# Test RMSE: 0.1787, Test MAE: 0.0559
# ---------------------------------
# Patience grace period: 30
# ---------------------------------
# Epoch 33/500
# Train RMSE: 0.1566
# Val RMSE: 0.1585, Val MAE: 0.0540
# Test RMSE: 0.1792, Test MAE: 0.0538
# ---------------------------------
# Patience grace period: 29
# ---------------------------------
# Epoch 34/500
# Train RMSE: 0.1567
# Val RMSE: 0.1579, Val MAE: 0.0516
# Test RMSE: 0.1796, Test MAE: 0.0538
# ---------------------------------
# Patience grace period: 28
# ---------------------------------
# Epoch 35/500
# Train RMSE: 0.1565
# Val RMSE: 0.1578, Val MAE: 0.0495
# Test RMSE: 0.1798, Test MAE: 0.0527
# ---------------------------------
# Patience grace period: 26
# ---------------------------------
# Epoch 36/500
# Train RMSE: 0.1563
# Val RMSE: 0.1578, Val MAE: 0.0479
# Test RMSE: 0.1799, Test MAE: 0.0518
# ---------------------------------
# Patience grace period: 24
# ---------------------------------
# Epoch 37/500
# Train RMSE: 0.1561
# Val RMSE: 0.1578, Val MAE: 0.0478
# Test RMSE: 0.1798, Test MAE: 0.0516
# ---------------------------------
# Patience grace period: 22
# ---------------------------------
# Epoch 38/500
# Train RMSE: 0.1558
# Val RMSE: 0.1577, Val MAE: 0.0482
# Test RMSE: 0.1795, Test MAE: 0.0520
# ---------------------------------
# Patience grace period: 20
# ---------------------------------
# Epoch 39/500
# Train RMSE: 0.1557
# Val RMSE: 0.1578, Val MAE: 0.0496
# Test RMSE: 0.1794, Test MAE: 0.0526
# ---------------------------------
# Patience grace period: 18
# ---------------------------------
# Epoch 40/500
# Train RMSE: 0.1558
# Val RMSE: 0.1584, Val MAE: 0.0538
# Test RMSE: 0.1790, Test MAE: 0.0540
# ---------------------------------
# Patience grace period: 16
# ---------------------------------
# Epoch 41/500
# Train RMSE: 0.1557
# Val RMSE: 0.1605, Val MAE: 0.0606
# Test RMSE: 0.1785, Test MAE: 0.0565
# ---------------------------------
# Patience grace period: 14
# ---------------------------------
# Epoch 42/500
# Train RMSE: 0.1557
# Val RMSE: 0.1621, Val MAE: 0.0638
# Test RMSE: 0.1783, Test MAE: 0.0577
# ---------------------------------
# Patience grace period: 12
# ---------------------------------
# Epoch 43/500
# Train RMSE: 0.1558
# Val RMSE: 0.1602, Val MAE: 0.0610
# Test RMSE: 0.1783, Test MAE: 0.0577
# ---------------------------------
# Patience grace period: 11
# ---------------------------------
# Epoch 44/500
# Train RMSE: 0.1560
# Val RMSE: 0.1584, Val MAE: 0.0540
# Test RMSE: 0.1790, Test MAE: 0.0547
# ---------------------------------
# Patience grace period: 10
# ---------------------------------
# Epoch 45/500
# Train RMSE: 0.1561
# Val RMSE: 0.1579, Val MAE: 0.0474
# Test RMSE: 0.1802, Test MAE: 0.0515
# ---------------------------------
# Patience grace period: 9
# ---------------------------------
# Epoch 46/500
# Train RMSE: 0.1562
# Val RMSE: 0.1579, Val MAE: 0.0465
# Test RMSE: 0.1805, Test MAE: 0.0507
# ---------------------------------
# Patience grace period: 7
# ---------------------------------
# Epoch 47/500
# Train RMSE: 0.1558
# Val RMSE: 0.1578, Val MAE: 0.0464
# Test RMSE: 0.1800, Test MAE: 0.0509
# ---------------------------------
# Patience grace period: 5
# ---------------------------------
# Epoch 48/500
# Train RMSE: 0.1555
# Val RMSE: 0.1577, Val MAE: 0.0472
# Test RMSE: 0.1799, Test MAE: 0.0510
# ---------------------------------
# Patience grace period: 3
# ---------------------------------
# Epoch 49/500
# Train RMSE: 0.1553
# Val RMSE: 0.1578, Val MAE: 0.0488
# Test RMSE: 0.1797, Test MAE: 0.0516
# ---------------------------------
# Patience grace period: 1
# ---------------------------------
# Epoch 50/500
# Train RMSE: 0.1552
# Val RMSE: 0.1580, Val MAE: 0.0515
# Test RMSE: 0.1795, Test MAE: 0.0524
# ---------------------------------
# Patience grace period: -1
# Early stopping triggered at epoch 50
# <ipython-input-2-d8b64875fc37>:120: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   self.model.load_state_dict(torch.load(os.path.join(save_dir, 'best_model.pth')))
# Final Test RMSE: 0.1798, Final Test MAE: 0.0527
# Pearson Corr: 0.3213248478711165
# Spearman Corr: 0.22076942422132614
# p-rmse: 0.1797831322319316
#        rmse      mae  seed                                subtask  \
# 0  0.179783  0.05266     4  openproblems_bmmc_multiome_phase2_rna
#
#          method   pearson p_value_pearson  spearman p_value_spearman
# 0  hierarchical  0.321325          0.0000  0.220769           0.0000
# ---------------------------------
# Epoch 1/500
# Train RMSE: 0.1635
# Val RMSE: 0.1589, Val MAE: 0.0505
# Test RMSE: 0.1830, Test MAE: 0.0517
# ---------------------------------
# Model saved at epoch 1 with val RMSE 0.1589
# Patience grace period: 80
# ---------------------------------
# Epoch 2/500
# Train RMSE: 0.1588
# Val RMSE: 0.1584, Val MAE: 0.0481
# Test RMSE: 0.1829, Test MAE: 0.0496
# ---------------------------------
# Model saved at epoch 2 with val RMSE 0.1584
# Patience grace period: 79
# ---------------------------------
# Epoch 3/500
# Train RMSE: 0.1582
# Val RMSE: 0.1579, Val MAE: 0.0500
# Test RMSE: 0.1815, Test MAE: 0.0498
# ---------------------------------
# Model saved at epoch 3 with val RMSE 0.1579
# Patience grace period: 78
# ---------------------------------
# Epoch 4/500
# Train RMSE: 0.1578
# Val RMSE: 0.1580, Val MAE: 0.0509
# Test RMSE: 0.1813, Test MAE: 0.0501
# ---------------------------------
# Patience grace period: 76
# ---------------------------------
# Epoch 5/500
# Train RMSE: 0.1577
# Val RMSE: 0.1579, Val MAE: 0.0488
# Test RMSE: 0.1816, Test MAE: 0.0499
# ---------------------------------
# Patience grace period: 74
# ---------------------------------
# Epoch 6/500
# Train RMSE: 0.1575
# Val RMSE: 0.1578, Val MAE: 0.0479
# Test RMSE: 0.1811, Test MAE: 0.0506
# ---------------------------------
# Model saved at epoch 6 with val RMSE 0.1578
# Patience grace period: 72
# ---------------------------------
# Epoch 7/500
# Train RMSE: 0.1573
# Val RMSE: 0.1577, Val MAE: 0.0496
# Test RMSE: 0.1807, Test MAE: 0.0514
# ---------------------------------
# Model saved at epoch 7 with val RMSE 0.1577
# Patience grace period: 71
# ---------------------------------
# Epoch 8/500
# Train RMSE: 0.1573
# Val RMSE: 0.1580, Val MAE: 0.0492
# Test RMSE: 0.1810, Test MAE: 0.0511
# ---------------------------------
# Patience grace period: 69
# ---------------------------------
# Epoch 9/500
# Train RMSE: 0.1576
# Val RMSE: 0.1581, Val MAE: 0.0557
# Test RMSE: 0.1792, Test MAE: 0.0553
# ---------------------------------
# Patience grace period: 67
# ---------------------------------
# Epoch 10/500
# Train RMSE: 0.1573
# Val RMSE: 0.1578, Val MAE: 0.0546
# Test RMSE: 0.1794, Test MAE: 0.0547
# ---------------------------------
# Patience grace period: 66
# ---------------------------------
# Epoch 11/500
# Train RMSE: 0.1570
# Val RMSE: 0.1581, Val MAE: 0.0549
# Test RMSE: 0.1794, Test MAE: 0.0542
# ---------------------------------
# Patience grace period: 64
# ---------------------------------
# Epoch 12/500
# Train RMSE: 0.1567
# Val RMSE: 0.1594, Val MAE: 0.0590
# Test RMSE: 0.1788, Test MAE: 0.0559
# ---------------------------------
# Patience grace period: 62
# ---------------------------------
# Epoch 13/500
# Train RMSE: 0.1572
# Val RMSE: 0.1586, Val MAE: 0.0473
# Test RMSE: 0.1810, Test MAE: 0.0517
# ---------------------------------
# Patience grace period: 61
# ---------------------------------
# Epoch 14/500
# Train RMSE: 0.1573
# Val RMSE: 0.1581, Val MAE: 0.0472
# Test RMSE: 0.1803, Test MAE: 0.0522
# ---------------------------------
# Patience grace period: 60
# ---------------------------------
# Epoch 15/500
# Train RMSE: 0.1568
# Val RMSE: 0.1578, Val MAE: 0.0476
# Test RMSE: 0.1799, Test MAE: 0.0524
# ---------------------------------
# Patience grace period: 59
# ---------------------------------
# Epoch 16/500
# Train RMSE: 0.1564
# Val RMSE: 0.1578, Val MAE: 0.0484
# Test RMSE: 0.1797, Test MAE: 0.0528
# ---------------------------------
# Patience grace period: 57
# ---------------------------------
# Epoch 17/500
# Train RMSE: 0.1563
# Val RMSE: 0.1580, Val MAE: 0.0508
# Test RMSE: 0.1792, Test MAE: 0.0547
# ---------------------------------
# Patience grace period: 55
# ---------------------------------
# Epoch 18/500
# Train RMSE: 0.1563
# Val RMSE: 0.1589, Val MAE: 0.0549
# Test RMSE: 0.1786, Test MAE: 0.0582
# ---------------------------------
# Patience grace period: 53
# ---------------------------------
# Epoch 19/500
# Train RMSE: 0.1567
# Val RMSE: 0.1610, Val MAE: 0.0594
# Test RMSE: 0.1786, Test MAE: 0.0595
# ---------------------------------
# Patience grace period: 51
# ---------------------------------
# Epoch 20/500
# Train RMSE: 0.1570
# Val RMSE: 0.1586, Val MAE: 0.0528
# Test RMSE: 0.1791, Test MAE: 0.0560
# ---------------------------------
# Patience grace period: 50
# ---------------------------------
# Epoch 21/500
# Train RMSE: 0.1569
# Val RMSE: 0.1578, Val MAE: 0.0511
# Test RMSE: 0.1794, Test MAE: 0.0542
# ---------------------------------
# Patience grace period: 49
# ---------------------------------
# Epoch 22/500
# Train RMSE: 0.1565
# Val RMSE: 0.1579, Val MAE: 0.0505
# Test RMSE: 0.1795, Test MAE: 0.0535
# ---------------------------------
# Patience grace period: 47
# ---------------------------------
# Epoch 23/500
# Train RMSE: 0.1562
# Val RMSE: 0.1581, Val MAE: 0.0501
# Test RMSE: 0.1799, Test MAE: 0.0520
# ---------------------------------
# Patience grace period: 45
# ---------------------------------
# Epoch 24/500
# Train RMSE: 0.1559
# Val RMSE: 0.1582, Val MAE: 0.0502
# Test RMSE: 0.1803, Test MAE: 0.0511
# ---------------------------------
# Patience grace period: 43
# ---------------------------------
# Epoch 25/500
# Train RMSE: 0.1558
# Val RMSE: 0.1587, Val MAE: 0.0542
# Test RMSE: 0.1800, Test MAE: 0.0519
# ---------------------------------
# Patience grace period: 41
# ---------------------------------
# Epoch 26/500
# Train RMSE: 0.1558
# Val RMSE: 0.1590, Val MAE: 0.0565
# Test RMSE: 0.1797, Test MAE: 0.0528
# ---------------------------------
# Patience grace period: 39
# ---------------------------------
# Epoch 27/500
# Train RMSE: 0.1562
# Val RMSE: 0.1579, Val MAE: 0.0489
# Test RMSE: 0.1806, Test MAE: 0.0511
# ---------------------------------
# Patience grace period: 38
# ---------------------------------
# Epoch 28/500
# Train RMSE: 0.1565
# Val RMSE: 0.1580, Val MAE: 0.0465
# Test RMSE: 0.1805, Test MAE: 0.0515
# ---------------------------------
# Patience grace period: 36
# ---------------------------------
# Epoch 29/500
# Train RMSE: 0.1562
# Val RMSE: 0.1578, Val MAE: 0.0466
# Test RMSE: 0.1804, Test MAE: 0.0512
# ---------------------------------
# Patience grace period: 35
# ---------------------------------
# Epoch 30/500
# Train RMSE: 0.1558
# Val RMSE: 0.1576, Val MAE: 0.0474
# Test RMSE: 0.1800, Test MAE: 0.0517
# ---------------------------------
# Model saved at epoch 30 with val RMSE 0.1576
# Patience grace period: 34
# ---------------------------------
# Epoch 31/500
# Train RMSE: 0.1556
# Val RMSE: 0.1576, Val MAE: 0.0489
# Test RMSE: 0.1797, Test MAE: 0.0521
# ---------------------------------
# Model saved at epoch 31 with val RMSE 0.1576
# Patience grace period: 32
# ---------------------------------
# Epoch 32/500
# Train RMSE: 0.1556
# Val RMSE: 0.1581, Val MAE: 0.0535
# Test RMSE: 0.1791, Test MAE: 0.0542
# ---------------------------------
# Patience grace period: 30
# ---------------------------------
# Epoch 33/500
# Train RMSE: 0.1558
# Val RMSE: 0.1610, Val MAE: 0.0619
# Test RMSE: 0.1788, Test MAE: 0.0589
# ---------------------------------
# Patience grace period: 28
# ---------------------------------
# Epoch 34/500
# Train RMSE: 0.1559
# Val RMSE: 0.1611, Val MAE: 0.0628
# Test RMSE: 0.1791, Test MAE: 0.0614
# ---------------------------------
# Patience grace period: 26
# ---------------------------------
# Epoch 35/500
# Train RMSE: 0.1562
# Val RMSE: 0.1588, Val MAE: 0.0584
# Test RMSE: 0.1786, Test MAE: 0.0586
# ---------------------------------
# Patience grace period: 25
# ---------------------------------
# Epoch 36/500
# Train RMSE: 0.1564
# Val RMSE: 0.1579, Val MAE: 0.0536
# Test RMSE: 0.1792, Test MAE: 0.0551
# ---------------------------------
# Patience grace period: 24
# ---------------------------------
# Epoch 37/500
# Train RMSE: 0.1561
# Val RMSE: 0.1578, Val MAE: 0.0498
# Test RMSE: 0.1797, Test MAE: 0.0541
# ---------------------------------
# Patience grace period: 22
# ---------------------------------
# Epoch 38/500
# Train RMSE: 0.1559
# Val RMSE: 0.1578, Val MAE: 0.0485
# Test RMSE: 0.1799, Test MAE: 0.0530
# ---------------------------------
# Patience grace period: 20
# ---------------------------------
# Epoch 39/500
# Train RMSE: 0.1556
# Val RMSE: 0.1579, Val MAE: 0.0476
# Test RMSE: 0.1803, Test MAE: 0.0522
# ---------------------------------
# Patience grace period: 18
# ---------------------------------
# Epoch 40/500
# Train RMSE: 0.1554
# Val RMSE: 0.1583, Val MAE: 0.0448
# Test RMSE: 0.1815, Test MAE: 0.0494
# ---------------------------------
# Patience grace period: 16
# ---------------------------------
# Epoch 41/500
# Train RMSE: 0.1553
# Val RMSE: 0.1589, Val MAE: 0.0424
# Test RMSE: 0.1825, Test MAE: 0.0470
# ---------------------------------
# Patience grace period: 14
# ---------------------------------
# Epoch 42/500
# Train RMSE: 0.1552
# Val RMSE: 0.1591, Val MAE: 0.0414
# Test RMSE: 0.1830, Test MAE: 0.0458
# ---------------------------------
# Patience grace period: 12
# ---------------------------------
# Epoch 43/500
# Train RMSE: 0.1552
# Val RMSE: 0.1584, Val MAE: 0.0434
# Test RMSE: 0.1820, Test MAE: 0.0472
# ---------------------------------
# Patience grace period: 11
# ---------------------------------
# Epoch 44/500
# Train RMSE: 0.1552
# Val RMSE: 0.1577, Val MAE: 0.0471
# Test RMSE: 0.1806, Test MAE: 0.0501
# ---------------------------------
# Patience grace period: 10
# ---------------------------------
# Epoch 45/500
# Train RMSE: 0.1553
# Val RMSE: 0.1580, Val MAE: 0.0524
# Test RMSE: 0.1796, Test MAE: 0.0528
# ---------------------------------
# Patience grace period: 8
# ---------------------------------
# Epoch 46/500
# Train RMSE: 0.1554
# Val RMSE: 0.1585, Val MAE: 0.0557
# Test RMSE: 0.1791, Test MAE: 0.0546
# ---------------------------------
# Patience grace period: 6
# ---------------------------------
# Epoch 47/500
# Train RMSE: 0.1556
# Val RMSE: 0.1587, Val MAE: 0.0570
# Test RMSE: 0.1790, Test MAE: 0.0556
# ---------------------------------
# Patience grace period: 4
# ---------------------------------
# Epoch 48/500
# Train RMSE: 0.1556
# Val RMSE: 0.1581, Val MAE: 0.0541
# Test RMSE: 0.1792, Test MAE: 0.0548
# ---------------------------------
# Patience grace period: 3
# ---------------------------------
# Epoch 49/500
# Train RMSE: 0.1554
# Val RMSE: 0.1576, Val MAE: 0.0487
# Test RMSE: 0.1802, Test MAE: 0.0516
# ---------------------------------
# Patience grace period: 2
# ---------------------------------
# Epoch 50/500
# Train RMSE: 0.1552
# Val RMSE: 0.1578, Val MAE: 0.0471
# Test RMSE: 0.1803, Test MAE: 0.0510
# ---------------------------------
# Patience grace period: 0
# Early stopping triggered at epoch 50
# <ipython-input-2-d8b64875fc37>:120: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   self.model.load_state_dict(torch.load(os.path.join(save_dir, 'best_model.pth')))
# Final Test RMSE: 0.1797, Final Test MAE: 0.0521
# Pearson Corr: 0.3212856032950594
# Spearman Corr: 0.22053778147866096
# p-rmse: 0.17972505218527918
#        rmse      mae  seed                                subtask  \
# 0  0.179725  0.05206     5  openproblems_bmmc_multiome_phase2_rna
#
#          method   pearson p_value_pearson  spearman p_value_spearman
# 0  hierarchical  0.321286          0.0000  0.220538           0.0000

# %%
config_hierachical_MulRNA = {
    "subtask": "openproblems_bmmc_multiome_phase2_rna",
    "batch_size": 520,
    "act": "relu",
    "conv_flow": ["gat"],
    "agg_flow": [None],
    "device": "cuda",
    "learning_rate": 0.00064,
    "hidden_size": 520,
    "num_heads": 5,
    "n_neigbours": 5,
    "n_components": 1500,
    "metric": "euclidean",
    "dropout_rate": 0.2,
    "num_epochs": 500,
    "es_patience": 80,
    "es_min_delta": 0.01,
    "es_rate_threshold": 0.0008,
    "layer_dim_ex": 3,
    "verbose": True,
    "sample": True,
    "preprocessing_type": "SVD",
    "variant": "original",
    "num_clusters": 10
}

pipeline(**config_hierachical_MulRNA)
# Out:
# [INFO][2025-04-05 06:28:07,039][dance][_load_raw_data] Loading /content/data/openproblems_bmmc_multiome_phase2_rna/openproblems_bmmc_multiome_phase2_rna.censor_dataset.output_train_mod1.h5ad
# Initializing pipeline...
# [INFO][2025-04-05 06:28:11,888][dance][_load_raw_data] Loading /content/data/openproblems_bmmc_multiome_phase2_rna/openproblems_bmmc_multiome_phase2_rna.censor_dataset.output_train_mod2.h5ad
# [INFO][2025-04-05 06:28:26,227][dance][_load_raw_data] Loading /content/data/openproblems_bmmc_multiome_phase2_rna/openproblems_bmmc_multiome_phase2_rna.censor_dataset.output_test_mod1.h5ad
# [INFO][2025-04-05 06:28:26,324][dance][_load_raw_data] Loading /content/data/openproblems_bmmc_multiome_phase2_rna/openproblems_bmmc_multiome_phase2_rna.censor_dataset.output_test_mod2.h5ad
# [INFO][2025-04-05 06:28:26,690][dance][_maybe_preprocess] Preprocessing done.
# /usr/local/lib/python3.11/dist-packages/mudata/_core/mudata.py:1531: FutureWarning: From 0.4 .update() will not pull obs/var columns from individual modalities by default anymore. Set mudata.set_options(pull_on_update=False) to adopt the new behaviour, which will become the default. Use new pull_obs/pull_var and push_obs/push_var methods for more flexibility.
#   self._update_attr("var", axis=0, join_common=join_common)
# /usr/local/lib/python3.11/dist-packages/mudata/_core/mudata.py:1429: FutureWarning: From 0.4 .update() will not pull obs/var columns from individual modalities by default anymore. Set mudata.set_options(pull_on_update=False) to adopt the new behaviour, which will become the default. Use new pull_obs/pull_var and push_obs/push_var methods for more flexibility.
#   self._update_attr("obs", axis=1, join_common=join_common)
# [INFO][2025-04-05 06:28:47,055][dance][set_config_from_dict] Setting config 'feature_mod' to 'mod1'
# [INFO][2025-04-05 06:28:47,056][dance][set_config_from_dict] Setting config 'label_mod' to 'mod2'
# [INFO][2025-04-05 06:28:47,058][dance][load_data] Raw data loaded:
# Data object that wraps (.data):
# MuData object with n_obs × n_vars = 43492 × 23431
#   uns:	'dance_config'
#   2 modalities
#     mod1:	43492 x 13431
#       obs:	'batch', 'size_factors'
#       layers:	'counts'
#     mod2:	43492 x 10000
#       obs:	'batch', 'size_factors'
#       obsm:	'gene_activity'
#       layers:	'counts'
# [INFO][2025-04-05 06:28:47,321][dance][wrapped_func] Took 0:00:40.282417 to load and process data.
# Truncated (40367, 1500)
# ---------------------------------
# Epoch 1/500
# Train RMSE: 0.1635
# Val RMSE: 0.1589, Val MAE: 0.0505
# Test RMSE: 0.1829, Test MAE: 0.0521
# ---------------------------------
# Model saved at epoch 1 with val RMSE 0.1589
# Patience grace period: 80
# ---------------------------------
# Epoch 2/500
# Train RMSE: 0.1588
# Val RMSE: 0.1583, Val MAE: 0.0508
# Test RMSE: 0.1822, Test MAE: 0.0507
# ---------------------------------
# Model saved at epoch 2 with val RMSE 0.1583
# Patience grace period: 79
# ---------------------------------
# Epoch 3/500
# Train RMSE: 0.1580
# Val RMSE: 0.1580, Val MAE: 0.0505
# Test RMSE: 0.1816, Test MAE: 0.0499
# ---------------------------------
# Model saved at epoch 3 with val RMSE 0.1580
# Patience grace period: 78
# ---------------------------------
# Epoch 4/500
# Train RMSE: 0.1575
# Val RMSE: 0.1580, Val MAE: 0.0483
# Test RMSE: 0.1819, Test MAE: 0.0489
# ---------------------------------
# Patience grace period: 76
# ---------------------------------
# Epoch 5/500
# Train RMSE: 0.1572
# Val RMSE: 0.1578, Val MAE: 0.0490
# Test RMSE: 0.1814, Test MAE: 0.0498
# ---------------------------------
# Model saved at epoch 5 with val RMSE 0.1578
# Patience grace period: 75
# ---------------------------------
# Epoch 6/500
# Train RMSE: 0.1569
# Val RMSE: 0.1578, Val MAE: 0.0507
# Test RMSE: 0.1807, Test MAE: 0.0511
# ---------------------------------
# Patience grace period: 73
# ---------------------------------
# Epoch 7/500
# Train RMSE: 0.1566
# Val RMSE: 0.1585, Val MAE: 0.0542
# Test RMSE: 0.1799, Test MAE: 0.0532
# ---------------------------------
# Patience grace period: 71
# ---------------------------------
# Epoch 8/500
# Train RMSE: 0.1564
# Val RMSE: 0.1585, Val MAE: 0.0538
# Test RMSE: 0.1801, Test MAE: 0.0530
# ---------------------------------
# Patience grace period: 69
# ---------------------------------
# Epoch 9/500
# Train RMSE: 0.1562
# Val RMSE: 0.1584, Val MAE: 0.0532
# Test RMSE: 0.1801, Test MAE: 0.0527
# ---------------------------------
# Patience grace period: 67
# ---------------------------------
# Epoch 10/500
# Train RMSE: 0.1561
# Val RMSE: 0.1584, Val MAE: 0.0534
# Test RMSE: 0.1799, Test MAE: 0.0540
# ---------------------------------
# Patience grace period: 65
# ---------------------------------
# Epoch 11/500
# Train RMSE: 0.1560
# Val RMSE: 0.1586, Val MAE: 0.0543
# Test RMSE: 0.1798, Test MAE: 0.0535
# ---------------------------------
# Patience grace period: 63
# ---------------------------------
# Epoch 12/500
# Train RMSE: 0.1560
# Val RMSE: 0.1582, Val MAE: 0.0521
# Test RMSE: 0.1802, Test MAE: 0.0526
# ---------------------------------
# Patience grace period: 62
# ---------------------------------
# Epoch 13/500
# Train RMSE: 0.1560
# Val RMSE: 0.1584, Val MAE: 0.0536
# Test RMSE: 0.1800, Test MAE: 0.0532
# ---------------------------------
# Patience grace period: 60
# ---------------------------------
# Epoch 14/500
# Train RMSE: 0.1559
# Val RMSE: 0.1579, Val MAE: 0.0508
# Test RMSE: 0.1798, Test MAE: 0.0532
# ---------------------------------
# Patience grace period: 59
# ---------------------------------
# Epoch 15/500
# Train RMSE: 0.1559
# Val RMSE: 0.1578, Val MAE: 0.0495
# Test RMSE: 0.1799, Test MAE: 0.0525
# ---------------------------------
# Model saved at epoch 15 with val RMSE 0.1578
# Patience grace period: 57
# ---------------------------------
# Epoch 16/500
# Train RMSE: 0.1557
# Val RMSE: 0.1578, Val MAE: 0.0500
# Test RMSE: 0.1798, Test MAE: 0.0532
# ---------------------------------
# Patience grace period: 55
# ---------------------------------
# Epoch 17/500
# Train RMSE: 0.1556
# Val RMSE: 0.1581, Val MAE: 0.0508
# Test RMSE: 0.1798, Test MAE: 0.0535
# ---------------------------------
# Patience grace period: 53
# ---------------------------------
# Epoch 18/500
# Train RMSE: 0.1555
# Val RMSE: 0.1582, Val MAE: 0.0520
# Test RMSE: 0.1796, Test MAE: 0.0542
# ---------------------------------
# Patience grace period: 51
# ---------------------------------
# Epoch 19/500
# Train RMSE: 0.1554
# Val RMSE: 0.1586, Val MAE: 0.0537
# Test RMSE: 0.1797, Test MAE: 0.0545
# ---------------------------------
# Patience grace period: 49
# ---------------------------------
# Epoch 20/500
# Train RMSE: 0.1554
# Val RMSE: 0.1593, Val MAE: 0.0565
# Test RMSE: 0.1792, Test MAE: 0.0565
# ---------------------------------
# Patience grace period: 47
# ---------------------------------
# Epoch 21/500
# Train RMSE: 0.1555
# Val RMSE: 0.1593, Val MAE: 0.0558
# Test RMSE: 0.1793, Test MAE: 0.0560
# ---------------------------------
# Patience grace period: 45
# ---------------------------------
# Epoch 22/500
# Train RMSE: 0.1554
# Val RMSE: 0.1590, Val MAE: 0.0549
# Test RMSE: 0.1792, Test MAE: 0.0553
# ---------------------------------
# Patience grace period: 44
# ---------------------------------
# Epoch 23/500
# Train RMSE: 0.1554
# Val RMSE: 0.1583, Val MAE: 0.0528
# Test RMSE: 0.1792, Test MAE: 0.0546
# ---------------------------------
# Patience grace period: 43
# ---------------------------------
# Epoch 24/500
# Train RMSE: 0.1553
# Val RMSE: 0.1576, Val MAE: 0.0487
# Test RMSE: 0.1798, Test MAE: 0.0516
# ---------------------------------
# Model saved at epoch 24 with val RMSE 0.1576
# Patience grace period: 42
# ---------------------------------
# Epoch 25/500
# Train RMSE: 0.1552
# Val RMSE: 0.1576, Val MAE: 0.0483
# Test RMSE: 0.1799, Test MAE: 0.0513
# ---------------------------------
# Patience grace period: 40
# ---------------------------------
# Epoch 26/500
# Train RMSE: 0.1550
# Val RMSE: 0.1576, Val MAE: 0.0487
# Test RMSE: 0.1800, Test MAE: 0.0514
# ---------------------------------
# Patience grace period: 38
# ---------------------------------
# Epoch 27/500
# Train RMSE: 0.1548
# Val RMSE: 0.1576, Val MAE: 0.0481
# Test RMSE: 0.1799, Test MAE: 0.0514
# ---------------------------------
# Patience grace period: 36
# ---------------------------------
# Epoch 28/500
# Train RMSE: 0.1547
# Val RMSE: 0.1578, Val MAE: 0.0491
# Test RMSE: 0.1799, Test MAE: 0.0519
# ---------------------------------
# Patience grace period: 34
# ---------------------------------
# Epoch 29/500
# Train RMSE: 0.1546
# Val RMSE: 0.1579, Val MAE: 0.0496
# Test RMSE: 0.1798, Test MAE: 0.0521
# ---------------------------------
# Patience grace period: 32
# ---------------------------------
# Epoch 30/500
# Train RMSE: 0.1545
# Val RMSE: 0.1580, Val MAE: 0.0516
# Test RMSE: 0.1793, Test MAE: 0.0538
# ---------------------------------
# Patience grace period: 30
# ---------------------------------
# Epoch 31/500
# Train RMSE: 0.1545
# Val RMSE: 0.1584, Val MAE: 0.0542
# Test RMSE: 0.1791, Test MAE: 0.0545
# ---------------------------------
# Patience grace period: 28
# ---------------------------------
# Epoch 32/500
# Train RMSE: 0.1545
# Val RMSE: 0.1585, Val MAE: 0.0546
# Test RMSE: 0.1790, Test MAE: 0.0552
# ---------------------------------
# Patience grace period: 26
# ---------------------------------
# Epoch 33/500
# Train RMSE: 0.1544
# Val RMSE: 0.1583, Val MAE: 0.0534
# Test RMSE: 0.1792, Test MAE: 0.0542
# ---------------------------------
# Patience grace period: 25
# ---------------------------------
# Epoch 34/500
# Train RMSE: 0.1544
# Val RMSE: 0.1583, Val MAE: 0.0526
# Test RMSE: 0.1791, Test MAE: 0.0543
# ---------------------------------
# Patience grace period: 23
# ---------------------------------
# Epoch 35/500
# Train RMSE: 0.1542
# Val RMSE: 0.1587, Val MAE: 0.0542
# Test RMSE: 0.1790, Test MAE: 0.0552
# ---------------------------------
# Patience grace period: 21
# ---------------------------------
# Epoch 36/500
# Train RMSE: 0.1542
# Val RMSE: 0.1592, Val MAE: 0.0560
# Test RMSE: 0.1788, Test MAE: 0.0556
# ---------------------------------
# Patience grace period: 19
# ---------------------------------
# Epoch 37/500
# Train RMSE: 0.1541
# Val RMSE: 0.1599, Val MAE: 0.0581
# Test RMSE: 0.1787, Test MAE: 0.0570
# ---------------------------------
# Patience grace period: 17
# ---------------------------------
# Epoch 38/500
# Train RMSE: 0.1542
# Val RMSE: 0.1597, Val MAE: 0.0584
# Test RMSE: 0.1787, Test MAE: 0.0571
# ---------------------------------
# Patience grace period: 16
# ---------------------------------
# Epoch 39/500
# Train RMSE: 0.1542
# Val RMSE: 0.1598, Val MAE: 0.0585
# Test RMSE: 0.1786, Test MAE: 0.0571
# ---------------------------------
# Patience grace period: 14
# ---------------------------------
# Epoch 40/500
# Train RMSE: 0.1542
# Val RMSE: 0.1599, Val MAE: 0.0586
# Test RMSE: 0.1789, Test MAE: 0.0561
# ---------------------------------
# Patience grace period: 12
# ---------------------------------
# Epoch 41/500
# Train RMSE: 0.1542
# Val RMSE: 0.1594, Val MAE: 0.0569
# Test RMSE: 0.1789, Test MAE: 0.0560
# ---------------------------------
# Patience grace period: 11
# ---------------------------------
# Epoch 42/500
# Train RMSE: 0.1542
# Val RMSE: 0.1582, Val MAE: 0.0530
# Test RMSE: 0.1792, Test MAE: 0.0541
# ---------------------------------
# Patience grace period: 10
# ---------------------------------
# Epoch 43/500
# Train RMSE: 0.1542
# Val RMSE: 0.1577, Val MAE: 0.0508
# Test RMSE: 0.1794, Test MAE: 0.0532
# ---------------------------------
# Patience grace period: 9
# ---------------------------------
# Epoch 44/500
# Train RMSE: 0.1541
# Val RMSE: 0.1576, Val MAE: 0.0497
# Test RMSE: 0.1796, Test MAE: 0.0522
# ---------------------------------
# Patience grace period: 7
# ---------------------------------
# Epoch 45/500
# Train RMSE: 0.1540
# Val RMSE: 0.1575, Val MAE: 0.0496
# Test RMSE: 0.1795, Test MAE: 0.0525
# ---------------------------------
# Model saved at epoch 45 with val RMSE 0.1575
# Patience grace period: 5
# ---------------------------------
# Epoch 46/500
# Train RMSE: 0.1538
# Val RMSE: 0.1575, Val MAE: 0.0500
# Test RMSE: 0.1794, Test MAE: 0.0526
# ---------------------------------
# Patience grace period: 3
# ---------------------------------
# Epoch 47/500
# Train RMSE: 0.1538
# Val RMSE: 0.1577, Val MAE: 0.0510
# Test RMSE: 0.1791, Test MAE: 0.0540
# ---------------------------------
# Patience grace period: 1
# ---------------------------------
# Epoch 48/500
# Train RMSE: 0.1537
# Val RMSE: 0.1577, Val MAE: 0.0510
# Test RMSE: 0.1791, Test MAE: 0.0535
# ---------------------------------
# Patience grace period: -1
# Early stopping triggered at epoch 48
# Final Test RMSE: 0.1795, Final Test MAE: 0.0525
# <ipython-input-2-d8b64875fc37>:120: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   self.model.load_state_dict(torch.load(os.path.join(save_dir, 'best_model.pth')))
# Pearson Corr: 0.3189881733486485
# Spearman Corr: 0.2232206018674403
# p-rmse: 0.17948635909587093
#        rmse       mae  seed                                subtask    method  \
# 0  0.179486  0.052504     1  openproblems_bmmc_multiome_phase2_rna  original
#
#     pearson p_value_pearson  spearman p_value_spearman
# 0  0.318988          0.0000  0.223221           0.0000
# ---------------------------------
# Epoch 1/500
# Train RMSE: 0.1636
# Val RMSE: 0.1590, Val MAE: 0.0523
# Test RMSE: 0.1818, Test MAE: 0.0528
# ---------------------------------
# Model saved at epoch 1 with val RMSE 0.1590
# Patience grace period: 80
# ---------------------------------
# Epoch 2/500
# Train RMSE: 0.1589
# Val RMSE: 0.1584, Val MAE: 0.0528
# Test RMSE: 0.1810, Test MAE: 0.0520
# ---------------------------------
# Model saved at epoch 2 with val RMSE 0.1584
# Patience grace period: 79
# ---------------------------------
# Epoch 3/500
# Train RMSE: 0.1581
# Val RMSE: 0.1581, Val MAE: 0.0528
# Test RMSE: 0.1804, Test MAE: 0.0520
# ---------------------------------
# Model saved at epoch 3 with val RMSE 0.1581
# Patience grace period: 78
# ---------------------------------
# Epoch 4/500
# Train RMSE: 0.1576
# Val RMSE: 0.1581, Val MAE: 0.0538
# Test RMSE: 0.1799, Test MAE: 0.0532
# ---------------------------------
# Patience grace period: 76
# ---------------------------------
# Epoch 5/500
# Train RMSE: 0.1573
# Val RMSE: 0.1585, Val MAE: 0.0551
# Test RMSE: 0.1799, Test MAE: 0.0534
# ---------------------------------
# Patience grace period: 74
# ---------------------------------
# Epoch 6/500
# Train RMSE: 0.1571
# Val RMSE: 0.1580, Val MAE: 0.0515
# Test RMSE: 0.1805, Test MAE: 0.0521
# ---------------------------------
# Model saved at epoch 6 with val RMSE 0.1580
# Patience grace period: 73
# ---------------------------------
# Epoch 7/500
# Train RMSE: 0.1568
# Val RMSE: 0.1578, Val MAE: 0.0505
# Test RMSE: 0.1804, Test MAE: 0.0517
# ---------------------------------
# Model saved at epoch 7 with val RMSE 0.1578
# Patience grace period: 72
# ---------------------------------
# Epoch 8/500
# Train RMSE: 0.1565
# Val RMSE: 0.1579, Val MAE: 0.0499
# Test RMSE: 0.1803, Test MAE: 0.0520
# ---------------------------------
# Patience grace period: 70
# ---------------------------------
# Epoch 9/500
# Train RMSE: 0.1563
# Val RMSE: 0.1579, Val MAE: 0.0501
# Test RMSE: 0.1801, Test MAE: 0.0526
# ---------------------------------
# Patience grace period: 68
# ---------------------------------
# Epoch 10/500
# Train RMSE: 0.1562
# Val RMSE: 0.1580, Val MAE: 0.0510
# Test RMSE: 0.1797, Test MAE: 0.0535
# ---------------------------------
# Patience grace period: 66
# ---------------------------------
# Epoch 11/500
# Train RMSE: 0.1561
# Val RMSE: 0.1582, Val MAE: 0.0520
# Test RMSE: 0.1796, Test MAE: 0.0536
# ---------------------------------
# Patience grace period: 64
# ---------------------------------
# Epoch 12/500
# Train RMSE: 0.1561
# Val RMSE: 0.1581, Val MAE: 0.0513
# Test RMSE: 0.1795, Test MAE: 0.0539
# ---------------------------------
# Patience grace period: 62
# ---------------------------------
# Epoch 13/500
# Train RMSE: 0.1560
# Val RMSE: 0.1580, Val MAE: 0.0509
# Test RMSE: 0.1794, Test MAE: 0.0544
# ---------------------------------
# Patience grace period: 60
# ---------------------------------
# Epoch 14/500
# Train RMSE: 0.1560
# Val RMSE: 0.1581, Val MAE: 0.0519
# Test RMSE: 0.1792, Test MAE: 0.0550
# ---------------------------------
# Patience grace period: 58
# ---------------------------------
# Epoch 15/500
# Train RMSE: 0.1560
# Val RMSE: 0.1589, Val MAE: 0.0551
# Test RMSE: 0.1789, Test MAE: 0.0566
# ---------------------------------
# Patience grace period: 56
# ---------------------------------
# Epoch 16/500
# Train RMSE: 0.1559
# Val RMSE: 0.1592, Val MAE: 0.0553
# Test RMSE: 0.1791, Test MAE: 0.0567
# ---------------------------------
# Patience grace period: 54
# ---------------------------------
# Epoch 17/500
# Train RMSE: 0.1558
# Val RMSE: 0.1591, Val MAE: 0.0549
# Test RMSE: 0.1791, Test MAE: 0.0562
# ---------------------------------
# Patience grace period: 53
# ---------------------------------
# Epoch 18/500
# Train RMSE: 0.1557
# Val RMSE: 0.1585, Val MAE: 0.0531
# Test RMSE: 0.1791, Test MAE: 0.0554
# ---------------------------------
# Patience grace period: 52
# ---------------------------------
# Epoch 19/500
# Train RMSE: 0.1556
# Val RMSE: 0.1587, Val MAE: 0.0534
# Test RMSE: 0.1791, Test MAE: 0.0552
# ---------------------------------
# Patience grace period: 50
# ---------------------------------
# Epoch 20/500
# Train RMSE: 0.1555
# Val RMSE: 0.1588, Val MAE: 0.0541
# Test RMSE: 0.1789, Test MAE: 0.0556
# ---------------------------------
# Patience grace period: 48
# ---------------------------------
# Epoch 21/500
# Train RMSE: 0.1555
# Val RMSE: 0.1586, Val MAE: 0.0540
# Test RMSE: 0.1789, Test MAE: 0.0556
# ---------------------------------
# Patience grace period: 47
# ---------------------------------
# Epoch 22/500
# Train RMSE: 0.1555
# Val RMSE: 0.1587, Val MAE: 0.0538
# Test RMSE: 0.1793, Test MAE: 0.0547
# ---------------------------------
# Patience grace period: 45
# ---------------------------------
# Epoch 23/500
# Train RMSE: 0.1555
# Val RMSE: 0.1582, Val MAE: 0.0511
# Test RMSE: 0.1799, Test MAE: 0.0526
# ---------------------------------
# Patience grace period: 44
# ---------------------------------
# Epoch 24/500
# Train RMSE: 0.1554
# Val RMSE: 0.1578, Val MAE: 0.0488
# Test RMSE: 0.1800, Test MAE: 0.0513
# ---------------------------------
# Patience grace period: 43
# ---------------------------------
# Epoch 25/500
# Train RMSE: 0.1553
# Val RMSE: 0.1578, Val MAE: 0.0494
# Test RMSE: 0.1797, Test MAE: 0.0517
# ---------------------------------
# Patience grace period: 41
# ---------------------------------
# Epoch 26/500
# Train RMSE: 0.1551
# Val RMSE: 0.1578, Val MAE: 0.0505
# Test RMSE: 0.1794, Test MAE: 0.0526
# ---------------------------------
# Model saved at epoch 26 with val RMSE 0.1578
# Patience grace period: 39
# ---------------------------------
# Epoch 27/500
# Train RMSE: 0.1549
# Val RMSE: 0.1579, Val MAE: 0.0508
# Test RMSE: 0.1795, Test MAE: 0.0522
# ---------------------------------
# Patience grace period: 37
# ---------------------------------
# Epoch 28/500
# Train RMSE: 0.1548
# Val RMSE: 0.1579, Val MAE: 0.0511
# Test RMSE: 0.1794, Test MAE: 0.0525
# ---------------------------------
# Patience grace period: 35
# ---------------------------------
# Epoch 29/500
# Train RMSE: 0.1547
# Val RMSE: 0.1584, Val MAE: 0.0533
# Test RMSE: 0.1790, Test MAE: 0.0542
# ---------------------------------
# Patience grace period: 33
# ---------------------------------
# Epoch 30/500
# Train RMSE: 0.1546
# Val RMSE: 0.1589, Val MAE: 0.0545
# Test RMSE: 0.1788, Test MAE: 0.0545
# ---------------------------------
# Patience grace period: 31
# ---------------------------------
# Epoch 31/500
# Train RMSE: 0.1546
# Val RMSE: 0.1594, Val MAE: 0.0558
# Test RMSE: 0.1787, Test MAE: 0.0558
# ---------------------------------
# Patience grace period: 29
# ---------------------------------
# Epoch 32/500
# Train RMSE: 0.1545
# Val RMSE: 0.1596, Val MAE: 0.0560
# Test RMSE: 0.1787, Test MAE: 0.0554
# ---------------------------------
# Patience grace period: 27
# ---------------------------------
# Epoch 33/500
# Train RMSE: 0.1545
# Val RMSE: 0.1589, Val MAE: 0.0540
# Test RMSE: 0.1788, Test MAE: 0.0555
# ---------------------------------
# Patience grace period: 26
# ---------------------------------
# Epoch 34/500
# Train RMSE: 0.1544
# Val RMSE: 0.1587, Val MAE: 0.0539
# Test RMSE: 0.1788, Test MAE: 0.0551
# ---------------------------------
# Patience grace period: 25
# ---------------------------------
# Epoch 35/500
# Train RMSE: 0.1543
# Val RMSE: 0.1588, Val MAE: 0.0552
# Test RMSE: 0.1786, Test MAE: 0.0561
# ---------------------------------
# Patience grace period: 23
# ---------------------------------
# Epoch 36/500
# Train RMSE: 0.1543
# Val RMSE: 0.1595, Val MAE: 0.0564
# Test RMSE: 0.1786, Test MAE: 0.0566
# ---------------------------------
# Patience grace period: 21
# ---------------------------------
# Epoch 37/500
# Train RMSE: 0.1543
# Val RMSE: 0.1590, Val MAE: 0.0555
# Test RMSE: 0.1787, Test MAE: 0.0557
# ---------------------------------
# Patience grace period: 20
# ---------------------------------
# Epoch 38/500
# Train RMSE: 0.1544
# Val RMSE: 0.1582, Val MAE: 0.0529
# Test RMSE: 0.1788, Test MAE: 0.0548
# ---------------------------------
# Patience grace period: 19
# ---------------------------------
# Epoch 39/500
# Train RMSE: 0.1543
# Val RMSE: 0.1577, Val MAE: 0.0498
# Test RMSE: 0.1794, Test MAE: 0.0526
# ---------------------------------
# Model saved at epoch 39 with val RMSE 0.1577
# Patience grace period: 18
# ---------------------------------
# Epoch 40/500
# Train RMSE: 0.1544
# Val RMSE: 0.1577, Val MAE: 0.0473
# Test RMSE: 0.1800, Test MAE: 0.0511
# ---------------------------------
# Model saved at epoch 40 with val RMSE 0.1577
# Patience grace period: 16
# ---------------------------------
# Epoch 41/500
# Train RMSE: 0.1544
# Val RMSE: 0.1576, Val MAE: 0.0476
# Test RMSE: 0.1802, Test MAE: 0.0509
# ---------------------------------
# Model saved at epoch 41 with val RMSE 0.1576
# Patience grace period: 14
# ---------------------------------
# Epoch 42/500
# Train RMSE: 0.1542
# Val RMSE: 0.1576, Val MAE: 0.0488
# Test RMSE: 0.1799, Test MAE: 0.0518
# ---------------------------------
# Model saved at epoch 42 with val RMSE 0.1576
# Patience grace period: 12
# ---------------------------------
# Epoch 43/500
# Train RMSE: 0.1540
# Val RMSE: 0.1578, Val MAE: 0.0510
# Test RMSE: 0.1794, Test MAE: 0.0532
# ---------------------------------
# Patience grace period: 10
# ---------------------------------
# Epoch 44/500
# Train RMSE: 0.1539
# Val RMSE: 0.1580, Val MAE: 0.0522
# Test RMSE: 0.1794, Test MAE: 0.0533
# ---------------------------------
# Patience grace period: 8
# ---------------------------------
# Epoch 45/500
# Train RMSE: 0.1538
# Val RMSE: 0.1580, Val MAE: 0.0523
# Test RMSE: 0.1794, Test MAE: 0.0533
# ---------------------------------
# Patience grace period: 6
# ---------------------------------
# Epoch 46/500
# Train RMSE: 0.1537
# Val RMSE: 0.1580, Val MAE: 0.0525
# Test RMSE: 0.1793, Test MAE: 0.0535
# ---------------------------------
# Patience grace period: 4
# ---------------------------------
# Epoch 47/500
# Train RMSE: 0.1537
# Val RMSE: 0.1580, Val MAE: 0.0526
# Test RMSE: 0.1793, Test MAE: 0.0535
# ---------------------------------
# Patience grace period: 2
# ---------------------------------
# Epoch 48/500
# Train RMSE: 0.1537
# Val RMSE: 0.1581, Val MAE: 0.0531
# Test RMSE: 0.1793, Test MAE: 0.0539
# ---------------------------------
# Patience grace period: 0
# Early stopping triggered at epoch 48
# Final Test RMSE: 0.1799, Final Test MAE: 0.0518
# <ipython-input-2-d8b64875fc37>:120: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   self.model.load_state_dict(torch.load(os.path.join(save_dir, 'best_model.pth')))
# Pearson Corr: 0.31720624815957793
# Spearman Corr: 0.22365199819289044
# p-rmse: 0.17987267655137176
#        rmse      mae  seed                                subtask    method  \
# 0  0.179873  0.05183     2  openproblems_bmmc_multiome_phase2_rna  original
#
#     pearson p_value_pearson  spearman p_value_spearman
# 0  0.317206          0.0000  0.223652           0.0000
# ---------------------------------
# Epoch 1/500
# Train RMSE: 0.1633
# Val RMSE: 0.1588, Val MAE: 0.0498
# Test RMSE: 0.1822, Test MAE: 0.0520
# ---------------------------------
# Model saved at epoch 1 with val RMSE 0.1588
# Patience grace period: 80
# ---------------------------------
# Epoch 2/500
# Train RMSE: 0.1586
# Val RMSE: 0.1582, Val MAE: 0.0516
# Test RMSE: 0.1811, Test MAE: 0.0519
# ---------------------------------
# Model saved at epoch 2 with val RMSE 0.1582
# Patience grace period: 79
# ---------------------------------
# Epoch 3/500
# Train RMSE: 0.1579
# Val RMSE: 0.1579, Val MAE: 0.0504
# Test RMSE: 0.1805, Test MAE: 0.0516
# ---------------------------------
# Model saved at epoch 3 with val RMSE 0.1579
# Patience grace period: 78
# ---------------------------------
# Epoch 4/500
# Train RMSE: 0.1575
# Val RMSE: 0.1578, Val MAE: 0.0495
# Test RMSE: 0.1804, Test MAE: 0.0517
# ---------------------------------
# Model saved at epoch 4 with val RMSE 0.1578
# Patience grace period: 76
# ---------------------------------
# Epoch 5/500
# Train RMSE: 0.1571
# Val RMSE: 0.1581, Val MAE: 0.0524
# Test RMSE: 0.1794, Test MAE: 0.0543
# ---------------------------------
# Patience grace period: 74
# ---------------------------------
# Epoch 6/500
# Train RMSE: 0.1568
# Val RMSE: 0.1583, Val MAE: 0.0528
# Test RMSE: 0.1793, Test MAE: 0.0543
# ---------------------------------
# Patience grace period: 72
# ---------------------------------
# Epoch 7/500
# Train RMSE: 0.1566
# Val RMSE: 0.1582, Val MAE: 0.0525
# Test RMSE: 0.1793, Test MAE: 0.0548
# ---------------------------------
# Patience grace period: 70
# ---------------------------------
# Epoch 8/500
# Train RMSE: 0.1563
# Val RMSE: 0.1584, Val MAE: 0.0528
# Test RMSE: 0.1791, Test MAE: 0.0554
# ---------------------------------
# Patience grace period: 68
# ---------------------------------
# Epoch 9/500
# Train RMSE: 0.1561
# Val RMSE: 0.1583, Val MAE: 0.0520
# Test RMSE: 0.1792, Test MAE: 0.0552
# ---------------------------------
# Patience grace period: 67
# ---------------------------------
# Epoch 10/500
# Train RMSE: 0.1560
# Val RMSE: 0.1583, Val MAE: 0.0517
# Test RMSE: 0.1793, Test MAE: 0.0552
# ---------------------------------
# Patience grace period: 65
# ---------------------------------
# Epoch 11/500
# Train RMSE: 0.1560
# Val RMSE: 0.1580, Val MAE: 0.0505
# Test RMSE: 0.1795, Test MAE: 0.0538
# ---------------------------------
# Patience grace period: 64
# ---------------------------------
# Epoch 12/500
# Train RMSE: 0.1560
# Val RMSE: 0.1582, Val MAE: 0.0526
# Test RMSE: 0.1795, Test MAE: 0.0546
# ---------------------------------
# Patience grace period: 62
# ---------------------------------
# Epoch 13/500
# Train RMSE: 0.1560
# Val RMSE: 0.1580, Val MAE: 0.0509
# Test RMSE: 0.1796, Test MAE: 0.0536
# ---------------------------------
# Patience grace period: 61
# ---------------------------------
# Epoch 14/500
# Train RMSE: 0.1558
# Val RMSE: 0.1580, Val MAE: 0.0494
# Test RMSE: 0.1798, Test MAE: 0.0530
# ---------------------------------
# Patience grace period: 59
# ---------------------------------
# Epoch 15/500
# Train RMSE: 0.1557
# Val RMSE: 0.1580, Val MAE: 0.0486
# Test RMSE: 0.1800, Test MAE: 0.0525
# ---------------------------------
# Patience grace period: 57
# ---------------------------------
# Epoch 16/500
# Train RMSE: 0.1556
# Val RMSE: 0.1581, Val MAE: 0.0497
# Test RMSE: 0.1798, Test MAE: 0.0532
# ---------------------------------
# Patience grace period: 55
# ---------------------------------
# Epoch 17/500
# Train RMSE: 0.1555
# Val RMSE: 0.1582, Val MAE: 0.0507
# Test RMSE: 0.1795, Test MAE: 0.0537
# ---------------------------------
# Patience grace period: 53
# ---------------------------------
# Epoch 18/500
# Train RMSE: 0.1555
# Val RMSE: 0.1582, Val MAE: 0.0519
# Test RMSE: 0.1794, Test MAE: 0.0538
# ---------------------------------
# Patience grace period: 51
# ---------------------------------
# Epoch 19/500
# Train RMSE: 0.1555
# Val RMSE: 0.1588, Val MAE: 0.0547
# Test RMSE: 0.1791, Test MAE: 0.0552
# ---------------------------------
# Patience grace period: 49
# ---------------------------------
# Epoch 20/500
# Train RMSE: 0.1557
# Val RMSE: 0.1598, Val MAE: 0.0580
# Test RMSE: 0.1790, Test MAE: 0.0562
# ---------------------------------
# Patience grace period: 47
# ---------------------------------
# Epoch 21/500
# Train RMSE: 0.1556
# Val RMSE: 0.1590, Val MAE: 0.0561
# Test RMSE: 0.1788, Test MAE: 0.0560
# ---------------------------------
# Patience grace period: 46
# ---------------------------------
# Epoch 22/500
# Train RMSE: 0.1554
# Val RMSE: 0.1582, Val MAE: 0.0536
# Test RMSE: 0.1790, Test MAE: 0.0543
# ---------------------------------
# Patience grace period: 45
# ---------------------------------
# Epoch 23/500
# Train RMSE: 0.1551
# Val RMSE: 0.1580, Val MAE: 0.0522
# Test RMSE: 0.1790, Test MAE: 0.0541
# ---------------------------------
# Patience grace period: 44
# ---------------------------------
# Epoch 24/500
# Train RMSE: 0.1549
# Val RMSE: 0.1580, Val MAE: 0.0521
# Test RMSE: 0.1793, Test MAE: 0.0534
# ---------------------------------
# Patience grace period: 42
# ---------------------------------
# Epoch 25/500
# Train RMSE: 0.1548
# Val RMSE: 0.1580, Val MAE: 0.0519
# Test RMSE: 0.1796, Test MAE: 0.0521
# ---------------------------------
# Patience grace period: 40
# ---------------------------------
# Epoch 26/500
# Train RMSE: 0.1547
# Val RMSE: 0.1581, Val MAE: 0.0521
# Test RMSE: 0.1793, Test MAE: 0.0533
# ---------------------------------
# Patience grace period: 38
# ---------------------------------
# Epoch 27/500
# Train RMSE: 0.1545
# Val RMSE: 0.1580, Val MAE: 0.0515
# Test RMSE: 0.1796, Test MAE: 0.0524
# ---------------------------------
# Patience grace period: 36
# ---------------------------------
# Epoch 28/500
# Train RMSE: 0.1545
# Val RMSE: 0.1579, Val MAE: 0.0519
# Test RMSE: 0.1794, Test MAE: 0.0528
# ---------------------------------
# Patience grace period: 34
# ---------------------------------
# Epoch 29/500
# Train RMSE: 0.1544
# Val RMSE: 0.1580, Val MAE: 0.0514
# Test RMSE: 0.1796, Test MAE: 0.0521
# ---------------------------------
# Patience grace period: 32
# ---------------------------------
# Epoch 30/500
# Train RMSE: 0.1543
# Val RMSE: 0.1581, Val MAE: 0.0519
# Test RMSE: 0.1795, Test MAE: 0.0525
# ---------------------------------
# Patience grace period: 30
# ---------------------------------
# Epoch 31/500
# Train RMSE: 0.1543
# Val RMSE: 0.1585, Val MAE: 0.0538
# Test RMSE: 0.1793, Test MAE: 0.0538
# ---------------------------------
# Patience grace period: 28
# ---------------------------------
# Epoch 32/500
# Train RMSE: 0.1542
# Val RMSE: 0.1584, Val MAE: 0.0534
# Test RMSE: 0.1793, Test MAE: 0.0536
# ---------------------------------
# Patience grace period: 26
# ---------------------------------
# Epoch 33/500
# Train RMSE: 0.1542
# Val RMSE: 0.1582, Val MAE: 0.0527
# Test RMSE: 0.1794, Test MAE: 0.0537
# ---------------------------------
# Patience grace period: 25
# ---------------------------------
# Epoch 34/500
# Train RMSE: 0.1542
# Val RMSE: 0.1583, Val MAE: 0.0524
# Test RMSE: 0.1795, Test MAE: 0.0528
# ---------------------------------
# Patience grace period: 23
# ---------------------------------
# Epoch 35/500
# Train RMSE: 0.1541
# Val RMSE: 0.1585, Val MAE: 0.0540
# Test RMSE: 0.1791, Test MAE: 0.0542
# ---------------------------------
# Patience grace period: 21
# ---------------------------------
# Epoch 36/500
# Train RMSE: 0.1540
# Val RMSE: 0.1590, Val MAE: 0.0560
# Test RMSE: 0.1788, Test MAE: 0.0550
# ---------------------------------
# Patience grace period: 19
# ---------------------------------
# Epoch 37/500
# Train RMSE: 0.1540
# Val RMSE: 0.1595, Val MAE: 0.0575
# Test RMSE: 0.1786, Test MAE: 0.0559
# ---------------------------------
# Patience grace period: 17
# ---------------------------------
# Epoch 38/500
# Train RMSE: 0.1540
# Val RMSE: 0.1593, Val MAE: 0.0569
# Test RMSE: 0.1788, Test MAE: 0.0551
# ---------------------------------
# Patience grace period: 16
# ---------------------------------
# Epoch 39/500
# Train RMSE: 0.1540
# Val RMSE: 0.1584, Val MAE: 0.0541
# Test RMSE: 0.1791, Test MAE: 0.0538
# ---------------------------------
# Patience grace period: 15
# ---------------------------------
# Epoch 40/500
# Train RMSE: 0.1539
# Val RMSE: 0.1580, Val MAE: 0.0519
# Test RMSE: 0.1794, Test MAE: 0.0529
# ---------------------------------
# Patience grace period: 14
# ---------------------------------
# Epoch 41/500
# Train RMSE: 0.1539
# Val RMSE: 0.1579, Val MAE: 0.0510
# Test RMSE: 0.1797, Test MAE: 0.0520
# ---------------------------------
# Patience grace period: 12
# ---------------------------------
# Epoch 42/500
# Train RMSE: 0.1539
# Val RMSE: 0.1580, Val MAE: 0.0507
# Test RMSE: 0.1797, Test MAE: 0.0521
# ---------------------------------
# Patience grace period: 10
# ---------------------------------
# Epoch 43/500
# Train RMSE: 0.1539
# Val RMSE: 0.1578, Val MAE: 0.0484
# Test RMSE: 0.1801, Test MAE: 0.0511
# ---------------------------------
# Model saved at epoch 43 with val RMSE 0.1578
# Patience grace period: 9
# ---------------------------------
# Epoch 44/500
# Train RMSE: 0.1539
# Val RMSE: 0.1579, Val MAE: 0.0459
# Test RMSE: 0.1805, Test MAE: 0.0498
# ---------------------------------
# Patience grace period: 7
# ---------------------------------
# Epoch 45/500
# Train RMSE: 0.1540
# Val RMSE: 0.1579, Val MAE: 0.0460
# Test RMSE: 0.1806, Test MAE: 0.0498
# ---------------------------------
# Patience grace period: 5
# ---------------------------------
# Epoch 46/500
# Train RMSE: 0.1540
# Val RMSE: 0.1577, Val MAE: 0.0477
# Test RMSE: 0.1799, Test MAE: 0.0512
# ---------------------------------
# Model saved at epoch 46 with val RMSE 0.1577
# Patience grace period: 4
# ---------------------------------
# Epoch 47/500
# Train RMSE: 0.1538
# Val RMSE: 0.1576, Val MAE: 0.0495
# Test RMSE: 0.1799, Test MAE: 0.0515
# ---------------------------------
# Model saved at epoch 47 with val RMSE 0.1576
# Patience grace period: 2
# ---------------------------------
# Epoch 48/500
# Train RMSE: 0.1536
# Val RMSE: 0.1577, Val MAE: 0.0511
# Test RMSE: 0.1796, Test MAE: 0.0521
# ---------------------------------
# Patience grace period: 0
# Early stopping triggered at epoch 48
# Final Test RMSE: 0.1799, Final Test MAE: 0.0515
# <ipython-input-2-d8b64875fc37>:120: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   self.model.load_state_dict(torch.load(os.path.join(save_dir, 'best_model.pth')))
# Pearson Corr: 0.31914139829189103
# Spearman Corr: 0.22405764177344534
# p-rmse: 0.17987477867584714
#        rmse       mae  seed                                subtask    method  \
# 0  0.179875  0.051461     3  openproblems_bmmc_multiome_phase2_rna  original
#
#     pearson p_value_pearson  spearman p_value_spearman
# 0  0.319141          0.0000  0.224058           0.0000
# ---------------------------------
# Epoch 1/500
# Train RMSE: 0.1644
# Val RMSE: 0.1592, Val MAE: 0.0496
# Test RMSE: 0.1826, Test MAE: 0.0519
# ---------------------------------
# Model saved at epoch 1 with val RMSE 0.1592
# Patience grace period: 80
# ---------------------------------
# Epoch 2/500
# Train RMSE: 0.1593
# Val RMSE: 0.1586, Val MAE: 0.0509
# Test RMSE: 0.1816, Test MAE: 0.0517
# ---------------------------------
# Model saved at epoch 2 with val RMSE 0.1586
# Patience grace period: 79
# ---------------------------------
# Epoch 3/500
# Train RMSE: 0.1588
# Val RMSE: 0.1583, Val MAE: 0.0501
# Test RMSE: 0.1812, Test MAE: 0.0512
# ---------------------------------
# Model saved at epoch 3 with val RMSE 0.1583
# Patience grace period: 78
# ---------------------------------
# Epoch 4/500
# Train RMSE: 0.1584
# Val RMSE: 0.1581, Val MAE: 0.0511
# Test RMSE: 0.1807, Test MAE: 0.0520
# ---------------------------------
# Model saved at epoch 4 with val RMSE 0.1581
# Patience grace period: 77
# ---------------------------------
# Epoch 5/500
# Train RMSE: 0.1580
# Val RMSE: 0.1580, Val MAE: 0.0517
# Test RMSE: 0.1800, Test MAE: 0.0536
# ---------------------------------
# Model saved at epoch 5 with val RMSE 0.1580
# Patience grace period: 75
# ---------------------------------
# Epoch 6/500
# Train RMSE: 0.1577
# Val RMSE: 0.1580, Val MAE: 0.0515
# Test RMSE: 0.1799, Test MAE: 0.0537
# ---------------------------------
# Model saved at epoch 6 with val RMSE 0.1580
# Patience grace period: 73
# ---------------------------------
# Epoch 7/500
# Train RMSE: 0.1573
# Val RMSE: 0.1581, Val MAE: 0.0513
# Test RMSE: 0.1798, Test MAE: 0.0538
# ---------------------------------
# Patience grace period: 71
# ---------------------------------
# Epoch 8/500
# Train RMSE: 0.1571
# Val RMSE: 0.1584, Val MAE: 0.0539
# Test RMSE: 0.1794, Test MAE: 0.0561
# ---------------------------------
# Patience grace period: 69
# ---------------------------------
# Epoch 9/500
# Train RMSE: 0.1569
# Val RMSE: 0.1588, Val MAE: 0.0553
# Test RMSE: 0.1791, Test MAE: 0.0571
# ---------------------------------
# Patience grace period: 67
# ---------------------------------
# Epoch 10/500
# Train RMSE: 0.1567
# Val RMSE: 0.1585, Val MAE: 0.0541
# Test RMSE: 0.1792, Test MAE: 0.0561
# ---------------------------------
# Patience grace period: 66
# ---------------------------------
# Epoch 11/500
# Train RMSE: 0.1566
# Val RMSE: 0.1585, Val MAE: 0.0537
# Test RMSE: 0.1791, Test MAE: 0.0567
# ---------------------------------
# Patience grace period: 64
# ---------------------------------
# Epoch 12/500
# Train RMSE: 0.1566
# Val RMSE: 0.1584, Val MAE: 0.0539
# Test RMSE: 0.1793, Test MAE: 0.0555
# ---------------------------------
# Patience grace period: 62
# ---------------------------------
# Epoch 13/500
# Train RMSE: 0.1566
# Val RMSE: 0.1581, Val MAE: 0.0520
# Test RMSE: 0.1794, Test MAE: 0.0550
# ---------------------------------
# Patience grace period: 61
# ---------------------------------
# Epoch 14/500
# Train RMSE: 0.1565
# Val RMSE: 0.1582, Val MAE: 0.0519
# Test RMSE: 0.1793, Test MAE: 0.0558
# ---------------------------------
# Patience grace period: 59
# ---------------------------------
# Epoch 15/500
# Train RMSE: 0.1564
# Val RMSE: 0.1582, Val MAE: 0.0510
# Test RMSE: 0.1795, Test MAE: 0.0551
# ---------------------------------
# Patience grace period: 57
# ---------------------------------
# Epoch 16/500
# Train RMSE: 0.1563
# Val RMSE: 0.1581, Val MAE: 0.0514
# Test RMSE: 0.1793, Test MAE: 0.0558
# ---------------------------------
# Patience grace period: 55
# ---------------------------------
# Epoch 17/500
# Train RMSE: 0.1561
# Val RMSE: 0.1582, Val MAE: 0.0514
# Test RMSE: 0.1794, Test MAE: 0.0559
# ---------------------------------
# Patience grace period: 53
# ---------------------------------
# Epoch 18/500
# Train RMSE: 0.1561
# Val RMSE: 0.1583, Val MAE: 0.0517
# Test RMSE: 0.1794, Test MAE: 0.0547
# ---------------------------------
# Patience grace period: 51
# ---------------------------------
# Epoch 19/500
# Train RMSE: 0.1560
# Val RMSE: 0.1583, Val MAE: 0.0523
# Test RMSE: 0.1793, Test MAE: 0.0551
# ---------------------------------
# Patience grace period: 49
# ---------------------------------
# Epoch 20/500
# Train RMSE: 0.1558
# Val RMSE: 0.1583, Val MAE: 0.0518
# Test RMSE: 0.1794, Test MAE: 0.0546
# ---------------------------------
# Patience grace period: 47
# ---------------------------------
# Epoch 21/500
# Train RMSE: 0.1558
# Val RMSE: 0.1582, Val MAE: 0.0504
# Test RMSE: 0.1795, Test MAE: 0.0535
# ---------------------------------
# Patience grace period: 46
# ---------------------------------
# Epoch 22/500
# Train RMSE: 0.1558
# Val RMSE: 0.1584, Val MAE: 0.0522
# Test RMSE: 0.1792, Test MAE: 0.0549
# ---------------------------------
# Patience grace period: 44
# ---------------------------------
# Epoch 23/500
# Train RMSE: 0.1559
# Val RMSE: 0.1588, Val MAE: 0.0551
# Test RMSE: 0.1789, Test MAE: 0.0567
# ---------------------------------
# Patience grace period: 42
# ---------------------------------
# Epoch 24/500
# Train RMSE: 0.1559
# Val RMSE: 0.1581, Val MAE: 0.0517
# Test RMSE: 0.1793, Test MAE: 0.0540
# ---------------------------------
# Patience grace period: 41
# ---------------------------------
# Epoch 25/500
# Train RMSE: 0.1556
# Val RMSE: 0.1580, Val MAE: 0.0502
# Test RMSE: 0.1794, Test MAE: 0.0535
# ---------------------------------
# Patience grace period: 39
# ---------------------------------
# Epoch 26/500
# Train RMSE: 0.1555
# Val RMSE: 0.1581, Val MAE: 0.0506
# Test RMSE: 0.1793, Test MAE: 0.0535
# ---------------------------------
# Patience grace period: 37
# ---------------------------------
# Epoch 27/500
# Train RMSE: 0.1553
# Val RMSE: 0.1582, Val MAE: 0.0519
# Test RMSE: 0.1791, Test MAE: 0.0546
# ---------------------------------
# Patience grace period: 35
# ---------------------------------
# Epoch 28/500
# Train RMSE: 0.1552
# Val RMSE: 0.1584, Val MAE: 0.0527
# Test RMSE: 0.1793, Test MAE: 0.0540
# ---------------------------------
# Patience grace period: 33
# ---------------------------------
# Epoch 29/500
# Train RMSE: 0.1552
# Val RMSE: 0.1593, Val MAE: 0.0561
# Test RMSE: 0.1790, Test MAE: 0.0554
# ---------------------------------
# Patience grace period: 31
# ---------------------------------
# Epoch 30/500
# Train RMSE: 0.1551
# Val RMSE: 0.1600, Val MAE: 0.0580
# Test RMSE: 0.1788, Test MAE: 0.0571
# ---------------------------------
# Patience grace period: 29
# ---------------------------------
# Epoch 31/500
# Train RMSE: 0.1551
# Val RMSE: 0.1592, Val MAE: 0.0567
# Test RMSE: 0.1789, Test MAE: 0.0558
# ---------------------------------
# Patience grace period: 28
# ---------------------------------
# Epoch 32/500
# Train RMSE: 0.1550
# Val RMSE: 0.1584, Val MAE: 0.0537
# Test RMSE: 0.1790, Test MAE: 0.0551
# ---------------------------------
# Patience grace period: 27
# ---------------------------------
# Epoch 33/500
# Train RMSE: 0.1549
# Val RMSE: 0.1581, Val MAE: 0.0516
# Test RMSE: 0.1794, Test MAE: 0.0532
# ---------------------------------
# Patience grace period: 26
# ---------------------------------
# Epoch 34/500
# Train RMSE: 0.1547
# Val RMSE: 0.1579, Val MAE: 0.0502
# Test RMSE: 0.1796, Test MAE: 0.0526
# ---------------------------------
# Model saved at epoch 34 with val RMSE 0.1579
# Patience grace period: 25
# ---------------------------------
# Epoch 35/500
# Train RMSE: 0.1546
# Val RMSE: 0.1579, Val MAE: 0.0505
# Test RMSE: 0.1795, Test MAE: 0.0529
# ---------------------------------
# Patience grace period: 23
# ---------------------------------
# Epoch 36/500
# Train RMSE: 0.1545
# Val RMSE: 0.1580, Val MAE: 0.0511
# Test RMSE: 0.1796, Test MAE: 0.0527
# ---------------------------------
# Patience grace period: 21
# ---------------------------------
# Epoch 37/500
# Train RMSE: 0.1545
# Val RMSE: 0.1581, Val MAE: 0.0517
# Test RMSE: 0.1795, Test MAE: 0.0529
# ---------------------------------
# Patience grace period: 19
# ---------------------------------
# Epoch 38/500
# Train RMSE: 0.1543
# Val RMSE: 0.1581, Val MAE: 0.0518
# Test RMSE: 0.1795, Test MAE: 0.0527
# ---------------------------------
# Patience grace period: 17
# ---------------------------------
# Epoch 39/500
# Train RMSE: 0.1543
# Val RMSE: 0.1583, Val MAE: 0.0526
# Test RMSE: 0.1793, Test MAE: 0.0537
# ---------------------------------
# Patience grace period: 15
# ---------------------------------
# Epoch 40/500
# Train RMSE: 0.1543
# Val RMSE: 0.1585, Val MAE: 0.0539
# Test RMSE: 0.1791, Test MAE: 0.0547
# ---------------------------------
# Patience grace period: 13
# ---------------------------------
# Epoch 41/500
# Train RMSE: 0.1543
# Val RMSE: 0.1586, Val MAE: 0.0544
# Test RMSE: 0.1790, Test MAE: 0.0548
# ---------------------------------
# Patience grace period: 11
# ---------------------------------
# Epoch 42/500
# Train RMSE: 0.1542
# Val RMSE: 0.1584, Val MAE: 0.0539
# Test RMSE: 0.1791, Test MAE: 0.0544
# ---------------------------------
# Patience grace period: 10
# ---------------------------------
# Epoch 43/500
# Train RMSE: 0.1543
# Val RMSE: 0.1579, Val MAE: 0.0512
# Test RMSE: 0.1795, Test MAE: 0.0531
# ---------------------------------
# Patience grace period: 9
# ---------------------------------
# Epoch 44/500
# Train RMSE: 0.1543
# Val RMSE: 0.1578, Val MAE: 0.0482
# Test RMSE: 0.1803, Test MAE: 0.0511
# ---------------------------------
# Model saved at epoch 44 with val RMSE 0.1578
# Patience grace period: 7
# ---------------------------------
# Epoch 45/500
# Train RMSE: 0.1542
# Val RMSE: 0.1578, Val MAE: 0.0471
# Test RMSE: 0.1802, Test MAE: 0.0510
# ---------------------------------
# Patience grace period: 5
# ---------------------------------
# Epoch 46/500
# Train RMSE: 0.1542
# Val RMSE: 0.1579, Val MAE: 0.0478
# Test RMSE: 0.1803, Test MAE: 0.0511
# ---------------------------------
# Patience grace period: 3
# ---------------------------------
# Epoch 47/500
# Train RMSE: 0.1541
# Val RMSE: 0.1579, Val MAE: 0.0485
# Test RMSE: 0.1802, Test MAE: 0.0513
# ---------------------------------
# Patience grace period: 1
# ---------------------------------
# Epoch 48/500
# Train RMSE: 0.1542
# Val RMSE: 0.1577, Val MAE: 0.0495
# Test RMSE: 0.1798, Test MAE: 0.0522
# ---------------------------------
# Model saved at epoch 48 with val RMSE 0.1577
# Patience grace period: 0
# Early stopping triggered at epoch 48
# <ipython-input-2-d8b64875fc37>:120: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   self.model.load_state_dict(torch.load(os.path.join(save_dir, 'best_model.pth')))
# Final Test RMSE: 0.1798, Final Test MAE: 0.0522
# Pearson Corr: 0.31552464377848766
# Spearman Corr: 0.22411306203745868
# p-rmse: 0.17981249152333675
#        rmse      mae  seed                                subtask    method  \
# 0  0.179812  0.05223     4  openproblems_bmmc_multiome_phase2_rna  original
#
#     pearson p_value_pearson  spearman p_value_spearman
# 0  0.315525          0.0000  0.224113           0.0000
# ---------------------------------
# Epoch 1/500
# Train RMSE: 0.1639
# Val RMSE: 0.1591, Val MAE: 0.0494
# Test RMSE: 0.1828, Test MAE: 0.0519
# ---------------------------------
# Model saved at epoch 1 with val RMSE 0.1591
# Patience grace period: 80
# ---------------------------------
# Epoch 2/500
# Train RMSE: 0.1590
# Val RMSE: 0.1584, Val MAE: 0.0491
# Test RMSE: 0.1820, Test MAE: 0.0506
# ---------------------------------
# Model saved at epoch 2 with val RMSE 0.1584
# Patience grace period: 79
# ---------------------------------
# Epoch 3/500
# Train RMSE: 0.1583
# Val RMSE: 0.1580, Val MAE: 0.0501
# Test RMSE: 0.1811, Test MAE: 0.0511
# ---------------------------------
# Model saved at epoch 3 with val RMSE 0.1580
# Patience grace period: 78
# ---------------------------------
# Epoch 4/500
# Train RMSE: 0.1579
# Val RMSE: 0.1579, Val MAE: 0.0503
# Test RMSE: 0.1806, Test MAE: 0.0519
# ---------------------------------
# Model saved at epoch 4 with val RMSE 0.1579
# Patience grace period: 77
# ---------------------------------
# Epoch 5/500
# Train RMSE: 0.1576
# Val RMSE: 0.1577, Val MAE: 0.0500
# Test RMSE: 0.1804, Test MAE: 0.0519
# ---------------------------------
# Model saved at epoch 5 with val RMSE 0.1577
# Patience grace period: 76
# ---------------------------------
# Epoch 6/500
# Train RMSE: 0.1572
# Val RMSE: 0.1578, Val MAE: 0.0505
# Test RMSE: 0.1800, Test MAE: 0.0533
# ---------------------------------
# Patience grace period: 74
# ---------------------------------
# Epoch 7/500
# Train RMSE: 0.1569
# Val RMSE: 0.1578, Val MAE: 0.0499
# Test RMSE: 0.1799, Test MAE: 0.0530
# ---------------------------------
# Patience grace period: 72
# ---------------------------------
# Epoch 8/500
# Train RMSE: 0.1568
# Val RMSE: 0.1579, Val MAE: 0.0514
# Test RMSE: 0.1796, Test MAE: 0.0541
# ---------------------------------
# Patience grace period: 70
# ---------------------------------
# Epoch 9/500
# Train RMSE: 0.1567
# Val RMSE: 0.1585, Val MAE: 0.0546
# Test RMSE: 0.1792, Test MAE: 0.0558
# ---------------------------------
# Patience grace period: 68
# ---------------------------------
# Epoch 10/500
# Train RMSE: 0.1565
# Val RMSE: 0.1584, Val MAE: 0.0535
# Test RMSE: 0.1793, Test MAE: 0.0557
# ---------------------------------
# Patience grace period: 66
# ---------------------------------
# Epoch 11/500
# Train RMSE: 0.1563
# Val RMSE: 0.1583, Val MAE: 0.0523
# Test RMSE: 0.1794, Test MAE: 0.0550
# ---------------------------------
# Patience grace period: 64
# ---------------------------------
# Epoch 12/500
# Train RMSE: 0.1562
# Val RMSE: 0.1582, Val MAE: 0.0522
# Test RMSE: 0.1793, Test MAE: 0.0548
# ---------------------------------
# Patience grace period: 62
# ---------------------------------
# Epoch 13/500
# Train RMSE: 0.1561
# Val RMSE: 0.1585, Val MAE: 0.0540
# Test RMSE: 0.1790, Test MAE: 0.0567
# ---------------------------------
# Patience grace period: 60
# ---------------------------------
# Epoch 14/500
# Train RMSE: 0.1560
# Val RMSE: 0.1588, Val MAE: 0.0548
# Test RMSE: 0.1790, Test MAE: 0.0564
# ---------------------------------
# Patience grace period: 58
# ---------------------------------
# Epoch 15/500
# Train RMSE: 0.1559
# Val RMSE: 0.1593, Val MAE: 0.0563
# Test RMSE: 0.1790, Test MAE: 0.0576
# ---------------------------------
# Patience grace period: 56
# ---------------------------------
# Epoch 16/500
# Train RMSE: 0.1560
# Val RMSE: 0.1584, Val MAE: 0.0524
# Test RMSE: 0.1791, Test MAE: 0.0552
# ---------------------------------
# Patience grace period: 55
# ---------------------------------
# Epoch 17/500
# Train RMSE: 0.1560
# Val RMSE: 0.1580, Val MAE: 0.0487
# Test RMSE: 0.1795, Test MAE: 0.0531
# ---------------------------------
# Patience grace period: 54
# ---------------------------------
# Epoch 18/500
# Train RMSE: 0.1558
# Val RMSE: 0.1580, Val MAE: 0.0486
# Test RMSE: 0.1792, Test MAE: 0.0540
# ---------------------------------
# Patience grace period: 52
# ---------------------------------
# Epoch 19/500
# Train RMSE: 0.1557
# Val RMSE: 0.1581, Val MAE: 0.0490
# Test RMSE: 0.1791, Test MAE: 0.0548
# ---------------------------------
# Patience grace period: 50
# ---------------------------------
# Epoch 20/500
# Train RMSE: 0.1556
# Val RMSE: 0.1582, Val MAE: 0.0498
# Test RMSE: 0.1789, Test MAE: 0.0556
# ---------------------------------
# Patience grace period: 48
# ---------------------------------
# Epoch 21/500
# Train RMSE: 0.1555
# Val RMSE: 0.1583, Val MAE: 0.0509
# Test RMSE: 0.1791, Test MAE: 0.0553
# ---------------------------------
# Patience grace period: 46
# ---------------------------------
# Epoch 22/500
# Train RMSE: 0.1555
# Val RMSE: 0.1581, Val MAE: 0.0502
# Test RMSE: 0.1793, Test MAE: 0.0541
# ---------------------------------
# Patience grace period: 45
# ---------------------------------
# Epoch 23/500
# Train RMSE: 0.1554
# Val RMSE: 0.1582, Val MAE: 0.0501
# Test RMSE: 0.1793, Test MAE: 0.0541
# ---------------------------------
# Patience grace period: 43
# ---------------------------------
# Epoch 24/500
# Train RMSE: 0.1554
# Val RMSE: 0.1583, Val MAE: 0.0501
# Test RMSE: 0.1793, Test MAE: 0.0539
# ---------------------------------
# Patience grace period: 41
# ---------------------------------
# Epoch 25/500
# Train RMSE: 0.1555
# Val RMSE: 0.1588, Val MAE: 0.0528
# Test RMSE: 0.1790, Test MAE: 0.0553
# ---------------------------------
# Patience grace period: 39
# ---------------------------------
# Epoch 26/500
# Train RMSE: 0.1556
# Val RMSE: 0.1590, Val MAE: 0.0556
# Test RMSE: 0.1788, Test MAE: 0.0568
# ---------------------------------
# Patience grace period: 37
# ---------------------------------
# Epoch 27/500
# Train RMSE: 0.1554
# Val RMSE: 0.1585, Val MAE: 0.0547
# Test RMSE: 0.1787, Test MAE: 0.0557
# ---------------------------------
# Patience grace period: 36
# ---------------------------------
# Epoch 28/500
# Train RMSE: 0.1552
# Val RMSE: 0.1581, Val MAE: 0.0529
# Test RMSE: 0.1788, Test MAE: 0.0551
# ---------------------------------
# Patience grace period: 35
# ---------------------------------
# Epoch 29/500
# Train RMSE: 0.1549
# Val RMSE: 0.1579, Val MAE: 0.0523
# Test RMSE: 0.1790, Test MAE: 0.0547
# ---------------------------------
# Patience grace period: 34
# ---------------------------------
# Epoch 30/500
# Train RMSE: 0.1548
# Val RMSE: 0.1580, Val MAE: 0.0517
# Test RMSE: 0.1791, Test MAE: 0.0541
# ---------------------------------
# Patience grace period: 32
# ---------------------------------
# Epoch 31/500
# Train RMSE: 0.1547
# Val RMSE: 0.1579, Val MAE: 0.0509
# Test RMSE: 0.1792, Test MAE: 0.0535
# ---------------------------------
# Patience grace period: 31
# ---------------------------------
# Epoch 32/500
# Train RMSE: 0.1546
# Val RMSE: 0.1579, Val MAE: 0.0509
# Test RMSE: 0.1792, Test MAE: 0.0537
# ---------------------------------
# Patience grace period: 29
# ---------------------------------
# Epoch 33/500
# Train RMSE: 0.1545
# Val RMSE: 0.1578, Val MAE: 0.0504
# Test RMSE: 0.1793, Test MAE: 0.0535
# ---------------------------------
# Patience grace period: 27
# ---------------------------------
# Epoch 34/500
# Train RMSE: 0.1545
# Val RMSE: 0.1578, Val MAE: 0.0497
# Test RMSE: 0.1793, Test MAE: 0.0531
# ---------------------------------
# Patience grace period: 25
# ---------------------------------
# Epoch 35/500
# Train RMSE: 0.1544
# Val RMSE: 0.1578, Val MAE: 0.0494
# Test RMSE: 0.1795, Test MAE: 0.0526
# ---------------------------------
# Patience grace period: 23
# ---------------------------------
# Epoch 36/500
# Train RMSE: 0.1544
# Val RMSE: 0.1578, Val MAE: 0.0505
# Test RMSE: 0.1794, Test MAE: 0.0525
# ---------------------------------
# Patience grace period: 21
# ---------------------------------
# Epoch 37/500
# Train RMSE: 0.1543
# Val RMSE: 0.1579, Val MAE: 0.0510
# Test RMSE: 0.1796, Test MAE: 0.0524
# ---------------------------------
# Patience grace period: 19
# ---------------------------------
# Epoch 38/500
# Train RMSE: 0.1544
# Val RMSE: 0.1589, Val MAE: 0.0556
# Test RMSE: 0.1787, Test MAE: 0.0561
# ---------------------------------
# Patience grace period: 17
# ---------------------------------
# Epoch 39/500
# Train RMSE: 0.1545
# Val RMSE: 0.1606, Val MAE: 0.0593
# Test RMSE: 0.1785, Test MAE: 0.0585
# ---------------------------------
# Patience grace period: 15
# ---------------------------------
# Epoch 40/500
# Train RMSE: 0.1545
# Val RMSE: 0.1601, Val MAE: 0.0588
# Test RMSE: 0.1784, Test MAE: 0.0582
# ---------------------------------
# Patience grace period: 14
# ---------------------------------
# Epoch 41/500
# Train RMSE: 0.1544
# Val RMSE: 0.1591, Val MAE: 0.0563
# Test RMSE: 0.1786, Test MAE: 0.0566
# ---------------------------------
# Patience grace period: 13
# ---------------------------------
# Epoch 42/500
# Train RMSE: 0.1543
# Val RMSE: 0.1587, Val MAE: 0.0549
# Test RMSE: 0.1789, Test MAE: 0.0551
# ---------------------------------
# Patience grace period: 12
# ---------------------------------
# Epoch 43/500
# Train RMSE: 0.1543
# Val RMSE: 0.1581, Val MAE: 0.0525
# Test RMSE: 0.1792, Test MAE: 0.0539
# ---------------------------------
# Patience grace period: 11
# ---------------------------------
# Epoch 44/500
# Train RMSE: 0.1542
# Val RMSE: 0.1577, Val MAE: 0.0498
# Test RMSE: 0.1795, Test MAE: 0.0523
# ---------------------------------
# Patience grace period: 10
# ---------------------------------
# Epoch 45/500
# Train RMSE: 0.1542
# Val RMSE: 0.1576, Val MAE: 0.0483
# Test RMSE: 0.1799, Test MAE: 0.0513
# ---------------------------------
# Model saved at epoch 45 with val RMSE 0.1576
# Patience grace period: 9
# ---------------------------------
# Epoch 46/500
# Train RMSE: 0.1541
# Val RMSE: 0.1576, Val MAE: 0.0477
# Test RMSE: 0.1798, Test MAE: 0.0515
# ---------------------------------
# Patience grace period: 7
# ---------------------------------
# Epoch 47/500
# Train RMSE: 0.1541
# Val RMSE: 0.1576, Val MAE: 0.0485
# Test RMSE: 0.1796, Test MAE: 0.0518
# ---------------------------------
# Patience grace period: 5
# ---------------------------------
# Epoch 48/500
# Train RMSE: 0.1540
# Val RMSE: 0.1576, Val MAE: 0.0492
# Test RMSE: 0.1794, Test MAE: 0.0523
# ---------------------------------
# Model saved at epoch 48 with val RMSE 0.1576
# Patience grace period: 3
# ---------------------------------
# Epoch 49/500
# Train RMSE: 0.1539
# Val RMSE: 0.1576, Val MAE: 0.0500
# Test RMSE: 0.1794, Test MAE: 0.0526
# ---------------------------------
# Patience grace period: 1
# ---------------------------------
# Epoch 50/500
# Train RMSE: 0.1538
# Val RMSE: 0.1577, Val MAE: 0.0508
# Test RMSE: 0.1793, Test MAE: 0.0531
# ---------------------------------
# Patience grace period: -1
# Early stopping triggered at epoch 50
# Final Test RMSE: 0.1794, Final Test MAE: 0.0523
# <ipython-input-2-d8b64875fc37>:120: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   self.model.load_state_dict(torch.load(os.path.join(save_dir, 'best_model.pth')))
# Pearson Corr: 0.32206363346497563
# Spearman Corr: 0.2264475241266822
# p-rmse: 0.1793967257777151
#        rmse       mae  seed                                subtask    method  \
# 0  0.179397  0.052332     5  openproblems_bmmc_multiome_phase2_rna  original
#
#     pearson p_value_pearson  spearman p_value_spearman
# 0  0.322064          0.0000  0.226448           0.0000

# %% [markdown]
# ## **Protein**

# %%
config_PROTEIN = {
    "subtask": "openproblems_bmmc_cite_phase2_mod2",
    "batch_size": 520,
    "act": "relu",
    "conv_flow": ["gat"],
    "agg_flow": [None],
    "device": "cuda",
    "learning_rate": 0.000064,
    "hidden_size": 280,
    "num_heads": 6,
    "n_neigbours": 3,
    "metric": "euclidean",
    "n_components": 1200,
    "dropout_rate": 0.2,
    "num_epochs": 500,
    "seed": 1,
    "es_patience": 150,
    "es_min_delta": 0.01,
    "es_rate_threshold": 0.00002,
    "layer_dim_ex": 3,
    "verbose": True,
    "sample": True,
    "preprocessing_type": "None",
    "variant": "original"
}

pipeline(**config_PROTEIN)
# Out:
# [INFO][2025-04-06 13:16:20,716][dance][_load_raw_data] Loading /content/data/openproblems_bmmc_cite_phase2_mod2/openproblems_bmmc_cite_phase2_mod2.censor_dataset.output_train_mod1.h5ad
# Initializing pipeline...
# [INFO][2025-04-06 13:16:21,331][dance][_load_raw_data] Loading /content/data/openproblems_bmmc_cite_phase2_mod2/openproblems_bmmc_cite_phase2_mod2.censor_dataset.output_train_mod2.h5ad
# [INFO][2025-04-06 13:16:28,665][dance][_load_raw_data] Loading /content/data/openproblems_bmmc_cite_phase2_mod2/openproblems_bmmc_cite_phase2_mod2.censor_dataset.output_test_mod1.h5ad
# [INFO][2025-04-06 13:16:28,689][dance][_load_raw_data] Loading /content/data/openproblems_bmmc_cite_phase2_mod2/openproblems_bmmc_cite_phase2_mod2.censor_dataset.output_test_mod2.h5ad
# [INFO][2025-04-06 13:16:28,882][dance][_maybe_preprocess] Preprocessing done.
# /usr/local/lib/python3.11/dist-packages/mudata/_core/mudata.py:1531: FutureWarning: From 0.4 .update() will not pull obs/var columns from individual modalities by default anymore. Set mudata.set_options(pull_on_update=False) to adopt the new behaviour, which will become the default. Use new pull_obs/pull_var and push_obs/push_var methods for more flexibility.
#   self._update_attr("var", axis=0, join_common=join_common)
# /usr/local/lib/python3.11/dist-packages/mudata/_core/mudata.py:931: UserWarning: Cannot join columns with the same name because var_names are intersecting.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/mudata/_core/mudata.py:1429: FutureWarning: From 0.4 .update() will not pull obs/var columns from individual modalities by default anymore. Set mudata.set_options(pull_on_update=False) to adopt the new behaviour, which will become the default. Use new pull_obs/pull_var and push_obs/push_var methods for more flexibility.
#   self._update_attr("obs", axis=1, join_common=join_common)
# /usr/local/lib/python3.11/dist-packages/mudata/_core/mudata.py:1558: UserWarning: Modality names will be prepended to var_names since there are identical var_names in different modalities.
#   warnings.warn(
# [INFO][2025-04-06 13:16:35,889][dance][set_config_from_dict] Setting config 'feature_mod' to 'mod1'
# [INFO][2025-04-06 13:16:35,890][dance][set_config_from_dict] Setting config 'label_mod' to 'mod2'
# [INFO][2025-04-06 13:16:35,891][dance][load_data] Raw data loaded:
# Data object that wraps (.data):
# MuData object with n_obs × n_vars = 67175 × 14087
#   uns:	'dance_config'
#   2 modalities
#     mod1:	67175 x 134
#       obs:	'batch'
#       layers:	'counts'
#     mod2:	67175 x 13953
#       obs:	'batch'
#       layers:	'counts'
# [INFO][2025-04-06 13:16:36,030][dance][wrapped_func] Took 0:00:15.313714 to load and process data.
# <ipython-input-4-15ebac2ab37f>:42: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   data.data.uns['gtrain'] = torch.load(train_graph_path)
# <ipython-input-4-15ebac2ab37f>:43: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   data.data.uns['gval'] = torch.load(val_graph_path)
# <ipython-input-4-15ebac2ab37f>:44: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   data.data.uns['gtest'] = torch.load(test_graph_path)
# <ipython-input-4-15ebac2ab37f>:45: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   train_label = torch.load(train_label_path).numpy()
# Processed data found. Loading...
# <ipython-input-4-15ebac2ab37f>:46: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   val_label = torch.load(val_label_path).numpy()
# <ipython-input-4-15ebac2ab37f>:47: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   test_label = torch.load(test_label_path).numpy()
# <ipython-input-4-15ebac2ab37f>:48: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   kwargs["FEATURE_SIZE"] = torch.load(feature_size_path).item()
# <ipython-input-4-15ebac2ab37f>:49: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   kwargs["OUTPUT_SIZE"] = torch.load(output_size_path).item()
# Processed data loaded.
# ---------------------------------
# Epoch 1/500
# Train RMSE: 0.3737
# Val RMSE: 0.3212, Val MAE: 0.1327
# Test RMSE: 0.3978, Test MAE: 0.1766
# ---------------------------------
# Model saved at epoch 1 with val RMSE 0.3212
# Patience grace period: 150
# ---------------------------------
# Epoch 2/500
# Train RMSE: 0.3260
# Val RMSE: 0.2939, Val MAE: 0.1262
# Test RMSE: 0.3693, Test MAE: 0.1671
# ---------------------------------
# Model saved at epoch 2 with val RMSE 0.2939
# Patience grace period: 150
# ---------------------------------
# Epoch 3/500
# Train RMSE: 0.3044
# Val RMSE: 0.2792, Val MAE: 0.1206
# Test RMSE: 0.3554, Test MAE: 0.1602
# ---------------------------------
# Model saved at epoch 3 with val RMSE 0.2792
# Patience grace period: 150
# ---------------------------------
# Epoch 4/500
# Train RMSE: 0.2916
# Val RMSE: 0.2720, Val MAE: 0.1181
# Test RMSE: 0.3489, Test MAE: 0.1575
# ---------------------------------
# Model saved at epoch 4 with val RMSE 0.2720
# Patience grace period: 149
# ---------------------------------
# Epoch 5/500
# Train RMSE: 0.2836
# Val RMSE: 0.2681, Val MAE: 0.1168
# Test RMSE: 0.3454, Test MAE: 0.1561
# ---------------------------------
# Model saved at epoch 5 with val RMSE 0.2681
# Patience grace period: 150
# ---------------------------------
# Epoch 6/500
# Train RMSE: 0.2779
# Val RMSE: 0.2650, Val MAE: 0.1154
# Test RMSE: 0.3426, Test MAE: 0.1543
# ---------------------------------
# Model saved at epoch 6 with val RMSE 0.2650
# Patience grace period: 149
# ---------------------------------
# Epoch 7/500
# Train RMSE: 0.2732
# Val RMSE: 0.2624, Val MAE: 0.1141
# Test RMSE: 0.3400, Test MAE: 0.1527
# ---------------------------------
# Model saved at epoch 7 with val RMSE 0.2624
# Patience grace period: 148
# ---------------------------------
# Epoch 8/500
# Train RMSE: 0.2695
# Val RMSE: 0.2603, Val MAE: 0.1128
# Test RMSE: 0.3384, Test MAE: 0.1513
# ---------------------------------
# Model saved at epoch 8 with val RMSE 0.2603
# Patience grace period: 147
# ---------------------------------
# Epoch 9/500
# Train RMSE: 0.2665
# Val RMSE: 0.2588, Val MAE: 0.1116
# Test RMSE: 0.3377, Test MAE: 0.1500
# ---------------------------------
# Model saved at epoch 9 with val RMSE 0.2588
# Patience grace period: 146
# ---------------------------------
# Epoch 10/500
# Train RMSE: 0.2643
# Val RMSE: 0.2577, Val MAE: 0.1106
# Test RMSE: 0.3369, Test MAE: 0.1492
# ---------------------------------
# Model saved at epoch 10 with val RMSE 0.2577
# Patience grace period: 150
# ---------------------------------
# Epoch 11/500
# Train RMSE: 0.2625
# Val RMSE: 0.2567, Val MAE: 0.1103
# Test RMSE: 0.3358, Test MAE: 0.1489
# ---------------------------------
# Model saved at epoch 11 with val RMSE 0.2567
# Patience grace period: 149
# ---------------------------------
# Epoch 12/500
# Train RMSE: 0.2613
# Val RMSE: 0.2558, Val MAE: 0.1106
# Test RMSE: 0.3337, Test MAE: 0.1490
# ---------------------------------
# Model saved at epoch 12 with val RMSE 0.2558
# Patience grace period: 148
# ---------------------------------
# Epoch 13/500
# Train RMSE: 0.2602
# Val RMSE: 0.2554, Val MAE: 0.1095
# Test RMSE: 0.3348, Test MAE: 0.1481
# ---------------------------------
# Model saved at epoch 13 with val RMSE 0.2554
# Patience grace period: 147
# ---------------------------------
# Epoch 14/500
# Train RMSE: 0.2594
# Val RMSE: 0.2549, Val MAE: 0.1087
# Test RMSE: 0.3346, Test MAE: 0.1475
# ---------------------------------
# Model saved at epoch 14 with val RMSE 0.2549
# Patience grace period: 146
# ---------------------------------
# Epoch 15/500
# Train RMSE: 0.2586
# Val RMSE: 0.2543, Val MAE: 0.1092
# Test RMSE: 0.3329, Test MAE: 0.1477
# ---------------------------------
# Model saved at epoch 15 with val RMSE 0.2543
# Patience grace period: 145
# ---------------------------------
# Epoch 16/500
# Train RMSE: 0.2580
# Val RMSE: 0.2539, Val MAE: 0.1090
# Test RMSE: 0.3322, Test MAE: 0.1475
# ---------------------------------
# Model saved at epoch 16 with val RMSE 0.2539
# Patience grace period: 144
# ---------------------------------
# Epoch 17/500
# Train RMSE: 0.2575
# Val RMSE: 0.2535, Val MAE: 0.1096
# Test RMSE: 0.3306, Test MAE: 0.1478
# ---------------------------------
# Model saved at epoch 17 with val RMSE 0.2535
# Patience grace period: 143
# ---------------------------------
# Epoch 18/500
# Train RMSE: 0.2571
# Val RMSE: 0.2533, Val MAE: 0.1089
# Test RMSE: 0.3310, Test MAE: 0.1476
# ---------------------------------
# Model saved at epoch 18 with val RMSE 0.2533
# Patience grace period: 142
# ---------------------------------
# Epoch 19/500
# Train RMSE: 0.2566
# Val RMSE: 0.2531, Val MAE: 0.1085
# Test RMSE: 0.3316, Test MAE: 0.1473
# ---------------------------------
# Model saved at epoch 19 with val RMSE 0.2531
# Patience grace period: 141
# ---------------------------------
# Epoch 20/500
# Train RMSE: 0.2563
# Val RMSE: 0.2529, Val MAE: 0.1082
# Test RMSE: 0.3311, Test MAE: 0.1473
# ---------------------------------
# Model saved at epoch 20 with val RMSE 0.2529
# Patience grace period: 140
# ---------------------------------
# Epoch 21/500
# Train RMSE: 0.2559
# Val RMSE: 0.2527, Val MAE: 0.1077
# Test RMSE: 0.3318, Test MAE: 0.1468
# ---------------------------------
# Model saved at epoch 21 with val RMSE 0.2527
# Patience grace period: 139
# ---------------------------------
# Epoch 22/500
# Train RMSE: 0.2556
# Val RMSE: 0.2524, Val MAE: 0.1080
# Test RMSE: 0.3307, Test MAE: 0.1472
# ---------------------------------
# Model saved at epoch 22 with val RMSE 0.2524
# Patience grace period: 138
# ---------------------------------
# Epoch 23/500
# Train RMSE: 0.2553
# Val RMSE: 0.2523, Val MAE: 0.1076
# Test RMSE: 0.3311, Test MAE: 0.1470
# ---------------------------------
# Model saved at epoch 23 with val RMSE 0.2523
# Patience grace period: 137
# ---------------------------------
# Epoch 24/500
# Train RMSE: 0.2550
# Val RMSE: 0.2520, Val MAE: 0.1077
# Test RMSE: 0.3303, Test MAE: 0.1470
# ---------------------------------
# Model saved at epoch 24 with val RMSE 0.2520
# Patience grace period: 136
# ---------------------------------
# Epoch 25/500
# Train RMSE: 0.2548
# Val RMSE: 0.2519, Val MAE: 0.1076
# Test RMSE: 0.3299, Test MAE: 0.1473
# ---------------------------------
# Model saved at epoch 25 with val RMSE 0.2519
# Patience grace period: 135
# ---------------------------------
# Epoch 26/500
# Train RMSE: 0.2546
# Val RMSE: 0.2518, Val MAE: 0.1080
# Test RMSE: 0.3297, Test MAE: 0.1475
# ---------------------------------
# Model saved at epoch 26 with val RMSE 0.2518
# Patience grace period: 134
# ---------------------------------
# Epoch 27/500
# Train RMSE: 0.2544
# Val RMSE: 0.2517, Val MAE: 0.1073
# Test RMSE: 0.3298, Test MAE: 0.1472
# ---------------------------------
# Model saved at epoch 27 with val RMSE 0.2517
# Patience grace period: 133
# ---------------------------------
# Epoch 28/500
# Train RMSE: 0.2541
# Val RMSE: 0.2516, Val MAE: 0.1069
# Test RMSE: 0.3303, Test MAE: 0.1470
# ---------------------------------
# Model saved at epoch 28 with val RMSE 0.2516
# Patience grace period: 132
# ---------------------------------
# Epoch 29/500
# Train RMSE: 0.2540
# Val RMSE: 0.2514, Val MAE: 0.1072
# Test RMSE: 0.3298, Test MAE: 0.1472
# ---------------------------------
# Model saved at epoch 29 with val RMSE 0.2514
# Patience grace period: 131
# ---------------------------------
# Epoch 30/500
# Train RMSE: 0.2538
# Val RMSE: 0.2513, Val MAE: 0.1075
# Test RMSE: 0.3292, Test MAE: 0.1476
# ---------------------------------
# Model saved at epoch 30 with val RMSE 0.2513
# Patience grace period: 130
# ---------------------------------
# Epoch 31/500
# Train RMSE: 0.2536
# Val RMSE: 0.2513, Val MAE: 0.1068
# Test RMSE: 0.3299, Test MAE: 0.1470
# ---------------------------------
# Model saved at epoch 31 with val RMSE 0.2513
# Patience grace period: 129
# ---------------------------------
# Epoch 32/500
# Train RMSE: 0.2535
# Val RMSE: 0.2511, Val MAE: 0.1073
# Test RMSE: 0.3287, Test MAE: 0.1476
# ---------------------------------
# Model saved at epoch 32 with val RMSE 0.2511
# Patience grace period: 128
# ---------------------------------
# Epoch 33/500
# Train RMSE: 0.2533
# Val RMSE: 0.2510, Val MAE: 0.1072
# Test RMSE: 0.3287, Test MAE: 0.1476
# ---------------------------------
# Model saved at epoch 33 with val RMSE 0.2510
# Patience grace period: 127
# ---------------------------------
# Epoch 34/500
# Train RMSE: 0.2531
# Val RMSE: 0.2509, Val MAE: 0.1072
# Test RMSE: 0.3288, Test MAE: 0.1477
# ---------------------------------
# Model saved at epoch 34 with val RMSE 0.2509
# Patience grace period: 126
# ---------------------------------
# Epoch 35/500
# Train RMSE: 0.2530
# Val RMSE: 0.2508, Val MAE: 0.1076
# Test RMSE: 0.3276, Test MAE: 0.1479
# ---------------------------------
# Model saved at epoch 35 with val RMSE 0.2508
# Patience grace period: 125
# ---------------------------------
# Epoch 36/500
# Train RMSE: 0.2529
# Val RMSE: 0.2507, Val MAE: 0.1074
# Test RMSE: 0.3279, Test MAE: 0.1479
# ---------------------------------
# Model saved at epoch 36 with val RMSE 0.2507
# Patience grace period: 124
# ---------------------------------
# Epoch 37/500
# Train RMSE: 0.2528
# Val RMSE: 0.2507, Val MAE: 0.1069
# Test RMSE: 0.3286, Test MAE: 0.1476
# ---------------------------------
# Model saved at epoch 37 with val RMSE 0.2507
# Patience grace period: 123
# ---------------------------------
# Epoch 38/500
# Train RMSE: 0.2527
# Val RMSE: 0.2506, Val MAE: 0.1071
# Test RMSE: 0.3284, Test MAE: 0.1477
# ---------------------------------
# Model saved at epoch 38 with val RMSE 0.2506
# Patience grace period: 122
# ---------------------------------
# Epoch 39/500
# Train RMSE: 0.2525
# Val RMSE: 0.2506, Val MAE: 0.1064
# Test RMSE: 0.3292, Test MAE: 0.1474
# ---------------------------------
# Patience grace period: 120
# ---------------------------------
# Epoch 40/500
# Train RMSE: 0.2524
# Val RMSE: 0.2504, Val MAE: 0.1072
# Test RMSE: 0.3276, Test MAE: 0.1479
# ---------------------------------
# Model saved at epoch 40 with val RMSE 0.2504
# Patience grace period: 119
# ---------------------------------
# Epoch 41/500
# Train RMSE: 0.2523
# Val RMSE: 0.2504, Val MAE: 0.1077
# Test RMSE: 0.3267, Test MAE: 0.1483
# ---------------------------------
# Model saved at epoch 41 with val RMSE 0.2504
# Patience grace period: 118
# ---------------------------------
# Epoch 42/500
# Train RMSE: 0.2522
# Val RMSE: 0.2504, Val MAE: 0.1070
# Test RMSE: 0.3279, Test MAE: 0.1479
# ---------------------------------
# Model saved at epoch 42 with val RMSE 0.2504
# Patience grace period: 117
# ---------------------------------
# Epoch 43/500
# Train RMSE: 0.2521
# Val RMSE: 0.2503, Val MAE: 0.1069
# Test RMSE: 0.3274, Test MAE: 0.1480
# ---------------------------------
# Model saved at epoch 43 with val RMSE 0.2503
# Patience grace period: 116
# ---------------------------------
# Epoch 44/500
# Train RMSE: 0.2520
# Val RMSE: 0.2502, Val MAE: 0.1071
# Test RMSE: 0.3271, Test MAE: 0.1480
# ---------------------------------
# Model saved at epoch 44 with val RMSE 0.2502
# Patience grace period: 115
# ---------------------------------
# Epoch 45/500
# Train RMSE: 0.2519
# Val RMSE: 0.2502, Val MAE: 0.1073
# Test RMSE: 0.3268, Test MAE: 0.1483
# ---------------------------------
# Model saved at epoch 45 with val RMSE 0.2502
# Patience grace period: 114
# ---------------------------------
# Epoch 46/500
# Train RMSE: 0.2518
# Val RMSE: 0.2501, Val MAE: 0.1073
# Test RMSE: 0.3266, Test MAE: 0.1483
# ---------------------------------
# Model saved at epoch 46 with val RMSE 0.2501
# Patience grace period: 113
# ---------------------------------
# Epoch 47/500
# Train RMSE: 0.2518
# Val RMSE: 0.2501, Val MAE: 0.1067
# Test RMSE: 0.3276, Test MAE: 0.1478
# ---------------------------------
# Model saved at epoch 47 with val RMSE 0.2501
# Patience grace period: 112
# ---------------------------------
# Epoch 48/500
# Train RMSE: 0.2516
# Val RMSE: 0.2500, Val MAE: 0.1074
# Test RMSE: 0.3262, Test MAE: 0.1485
# ---------------------------------
# Model saved at epoch 48 with val RMSE 0.2500
# Patience grace period: 111
# ---------------------------------
# Epoch 49/500
# Train RMSE: 0.2516
# Val RMSE: 0.2500, Val MAE: 0.1066
# Test RMSE: 0.3278, Test MAE: 0.1479
# ---------------------------------
# Patience grace period: 109
# ---------------------------------
# Epoch 50/500
# Train RMSE: 0.2515
# Val RMSE: 0.2499, Val MAE: 0.1068
# Test RMSE: 0.3273, Test MAE: 0.1481
# ---------------------------------
# Model saved at epoch 50 with val RMSE 0.2499
# Patience grace period: 108
# ---------------------------------
# Epoch 51/500
# Train RMSE: 0.2514
# Val RMSE: 0.2499, Val MAE: 0.1074
# Test RMSE: 0.3260, Test MAE: 0.1485
# ---------------------------------
# Model saved at epoch 51 with val RMSE 0.2499
# Patience grace period: 107
# ---------------------------------
# Epoch 52/500
# Train RMSE: 0.2514
# Val RMSE: 0.2499, Val MAE: 0.1067
# Test RMSE: 0.3270, Test MAE: 0.1481
# ---------------------------------
# Patience grace period: 105
# ---------------------------------
# Epoch 53/500
# Train RMSE: 0.2513
# Val RMSE: 0.2498, Val MAE: 0.1070
# Test RMSE: 0.3263, Test MAE: 0.1484
# ---------------------------------
# Model saved at epoch 53 with val RMSE 0.2498
# Patience grace period: 104
# ---------------------------------
# Epoch 54/500
# Train RMSE: 0.2512
# Val RMSE: 0.2497, Val MAE: 0.1072
# Test RMSE: 0.3257, Test MAE: 0.1484
# ---------------------------------
# Model saved at epoch 54 with val RMSE 0.2497
# Patience grace period: 103
# ---------------------------------
# Epoch 55/500
# Train RMSE: 0.2511
# Val RMSE: 0.2497, Val MAE: 0.1070
# Test RMSE: 0.3262, Test MAE: 0.1486
# ---------------------------------
# Model saved at epoch 55 with val RMSE 0.2497
# Patience grace period: 102
# ---------------------------------
# Epoch 56/500
# Train RMSE: 0.2511
# Val RMSE: 0.2497, Val MAE: 0.1073
# Test RMSE: 0.3257, Test MAE: 0.1488
# ---------------------------------
# Model saved at epoch 56 with val RMSE 0.2497
# Patience grace period: 101
# ---------------------------------
# Epoch 57/500
# Train RMSE: 0.2510
# Val RMSE: 0.2497, Val MAE: 0.1066
# Test RMSE: 0.3264, Test MAE: 0.1481
# ---------------------------------
# Model saved at epoch 57 with val RMSE 0.2497
# Patience grace period: 100
# ---------------------------------
# Epoch 58/500
# Train RMSE: 0.2509
# Val RMSE: 0.2496, Val MAE: 0.1074
# Test RMSE: 0.3252, Test MAE: 0.1488
# ---------------------------------
# Model saved at epoch 58 with val RMSE 0.2496
# Patience grace period: 99
# ---------------------------------
# Epoch 59/500
# Train RMSE: 0.2509
# Val RMSE: 0.2496, Val MAE: 0.1070
# Test RMSE: 0.3259, Test MAE: 0.1487
# ---------------------------------
# Model saved at epoch 59 with val RMSE 0.2496
# Patience grace period: 98
# ---------------------------------
# Epoch 60/500
# Train RMSE: 0.2508
# Val RMSE: 0.2496, Val MAE: 0.1075
# Test RMSE: 0.3246, Test MAE: 0.1491
# ---------------------------------
# Model saved at epoch 60 with val RMSE 0.2496
# Patience grace period: 97
# ---------------------------------
# Epoch 61/500
# Train RMSE: 0.2508
# Val RMSE: 0.2495, Val MAE: 0.1072
# Test RMSE: 0.3255, Test MAE: 0.1489
# ---------------------------------
# Model saved at epoch 61 with val RMSE 0.2495
# Patience grace period: 96
# ---------------------------------
# Epoch 62/500
# Train RMSE: 0.2507
# Val RMSE: 0.2495, Val MAE: 0.1070
# Test RMSE: 0.3259, Test MAE: 0.1487
# ---------------------------------
# Patience grace period: 94
# ---------------------------------
# Epoch 63/500
# Train RMSE: 0.2506
# Val RMSE: 0.2494, Val MAE: 0.1070
# Test RMSE: 0.3256, Test MAE: 0.1487
# ---------------------------------
# Model saved at epoch 63 with val RMSE 0.2494
# Patience grace period: 93
# ---------------------------------
# Epoch 64/500
# Train RMSE: 0.2506
# Val RMSE: 0.2494, Val MAE: 0.1063
# Test RMSE: 0.3268, Test MAE: 0.1482
# ---------------------------------
# Patience grace period: 91
# ---------------------------------
# Epoch 65/500
# Train RMSE: 0.2506
# Val RMSE: 0.2495, Val MAE: 0.1060
# Test RMSE: 0.3271, Test MAE: 0.1482
# ---------------------------------
# Patience grace period: 89
# ---------------------------------
# Epoch 66/500
# Train RMSE: 0.2505
# Val RMSE: 0.2493, Val MAE: 0.1069
# Test RMSE: 0.3258, Test MAE: 0.1488
# ---------------------------------
# Model saved at epoch 66 with val RMSE 0.2493
# Patience grace period: 88
# ---------------------------------
# Epoch 67/500
# Train RMSE: 0.2505
# Val RMSE: 0.2493, Val MAE: 0.1068
# Test RMSE: 0.3257, Test MAE: 0.1488
# ---------------------------------
# Model saved at epoch 67 with val RMSE 0.2493
# Patience grace period: 87
# ---------------------------------
# Epoch 68/500
# Train RMSE: 0.2504
# Val RMSE: 0.2493, Val MAE: 0.1064
# Test RMSE: 0.3266, Test MAE: 0.1487
# ---------------------------------
# Patience grace period: 85
# ---------------------------------
# Epoch 69/500
# Train RMSE: 0.2503
# Val RMSE: 0.2493, Val MAE: 0.1071
# Test RMSE: 0.3251, Test MAE: 0.1491
# ---------------------------------
# Model saved at epoch 69 with val RMSE 0.2493
# Patience grace period: 84
# ---------------------------------
# Epoch 70/500
# Train RMSE: 0.2503
# Val RMSE: 0.2493, Val MAE: 0.1073
# Test RMSE: 0.3248, Test MAE: 0.1493
# ---------------------------------
# Model saved at epoch 70 with val RMSE 0.2493
# Patience grace period: 83
# ---------------------------------
# Epoch 71/500
# Train RMSE: 0.2503
# Val RMSE: 0.2493, Val MAE: 0.1067
# Test RMSE: 0.3256, Test MAE: 0.1488
# ---------------------------------
# Patience grace period: 81
# ---------------------------------
# Epoch 72/500
# Train RMSE: 0.2502
# Val RMSE: 0.2492, Val MAE: 0.1069
# Test RMSE: 0.3254, Test MAE: 0.1490
# ---------------------------------
# Model saved at epoch 72 with val RMSE 0.2492
# Patience grace period: 80
# ---------------------------------
# Epoch 73/500
# Train RMSE: 0.2502
# Val RMSE: 0.2492, Val MAE: 0.1063
# Test RMSE: 0.3262, Test MAE: 0.1487
# ---------------------------------
# Patience grace period: 78
# ---------------------------------
# Epoch 74/500
# Train RMSE: 0.2501
# Val RMSE: 0.2492, Val MAE: 0.1070
# Test RMSE: 0.3248, Test MAE: 0.1490
# ---------------------------------
# Model saved at epoch 74 with val RMSE 0.2492
# Patience grace period: 77
# ---------------------------------
# Epoch 75/500
# Train RMSE: 0.2501
# Val RMSE: 0.2491, Val MAE: 0.1067
# Test RMSE: 0.3255, Test MAE: 0.1489
# ---------------------------------
# Model saved at epoch 75 with val RMSE 0.2491
# Patience grace period: 76
# ---------------------------------
# Epoch 76/500
# Train RMSE: 0.2500
# Val RMSE: 0.2491, Val MAE: 0.1070
# Test RMSE: 0.3249, Test MAE: 0.1492
# ---------------------------------
# Model saved at epoch 76 with val RMSE 0.2491
# Patience grace period: 75
# ---------------------------------
# Epoch 77/500
# Train RMSE: 0.2500
# Val RMSE: 0.2491, Val MAE: 0.1073
# Test RMSE: 0.3243, Test MAE: 0.1494
# ---------------------------------
# Patience grace period: 73
# ---------------------------------
# Epoch 78/500
# Train RMSE: 0.2499
# Val RMSE: 0.2491, Val MAE: 0.1064
# Test RMSE: 0.3261, Test MAE: 0.1488
# ---------------------------------
# Model saved at epoch 78 with val RMSE 0.2491
# Patience grace period: 72
# ---------------------------------
# Epoch 79/500
# Train RMSE: 0.2499
# Val RMSE: 0.2490, Val MAE: 0.1071
# Test RMSE: 0.3248, Test MAE: 0.1492
# ---------------------------------
# Model saved at epoch 79 with val RMSE 0.2490
# Patience grace period: 71
# ---------------------------------
# Epoch 80/500
# Train RMSE: 0.2499
# Val RMSE: 0.2491, Val MAE: 0.1066
# Test RMSE: 0.3253, Test MAE: 0.1490
# ---------------------------------
# Patience grace period: 69
# ---------------------------------
# Epoch 81/500
# Train RMSE: 0.2498
# Val RMSE: 0.2490, Val MAE: 0.1066
# Test RMSE: 0.3250, Test MAE: 0.1490
# ---------------------------------
# Model saved at epoch 81 with val RMSE 0.2490
# Patience grace period: 68
# ---------------------------------
# Epoch 82/500
# Train RMSE: 0.2498
# Val RMSE: 0.2490, Val MAE: 0.1066
# Test RMSE: 0.3252, Test MAE: 0.1490
# ---------------------------------
# Model saved at epoch 82 with val RMSE 0.2490
# Patience grace period: 67
# ---------------------------------
# Epoch 83/500
# Train RMSE: 0.2498
# Val RMSE: 0.2490, Val MAE: 0.1070
# Test RMSE: 0.3246, Test MAE: 0.1495
# ---------------------------------
# Patience grace period: 65
# ---------------------------------
# Epoch 84/500
# Train RMSE: 0.2497
# Val RMSE: 0.2489, Val MAE: 0.1069
# Test RMSE: 0.3247, Test MAE: 0.1494
# ---------------------------------
# Model saved at epoch 84 with val RMSE 0.2489
# Patience grace period: 64
# ---------------------------------
# Epoch 85/500
# Train RMSE: 0.2497
# Val RMSE: 0.2489, Val MAE: 0.1066
# Test RMSE: 0.3251, Test MAE: 0.1491
# ---------------------------------
# Model saved at epoch 85 with val RMSE 0.2489
# Patience grace period: 63
# ---------------------------------
# Epoch 86/500
# Train RMSE: 0.2496
# Val RMSE: 0.2489, Val MAE: 0.1065
# Test RMSE: 0.3252, Test MAE: 0.1490
# ---------------------------------
# Patience grace period: 61
# ---------------------------------
# Epoch 87/500
# Train RMSE: 0.2496
# Val RMSE: 0.2488, Val MAE: 0.1069
# Test RMSE: 0.3247, Test MAE: 0.1494
# ---------------------------------
# Model saved at epoch 87 with val RMSE 0.2488
# Patience grace period: 60
# ---------------------------------
# Epoch 88/500
# Train RMSE: 0.2496
# Val RMSE: 0.2489, Val MAE: 0.1068
# Test RMSE: 0.3249, Test MAE: 0.1494
# ---------------------------------
# Patience grace period: 58
# ---------------------------------
# Epoch 89/500
# Train RMSE: 0.2496
# Val RMSE: 0.2488, Val MAE: 0.1065
# Test RMSE: 0.3249, Test MAE: 0.1492
# ---------------------------------
# Patience grace period: 57
# ---------------------------------
# Epoch 90/500
# Train RMSE: 0.2495
# Val RMSE: 0.2488, Val MAE: 0.1065
# Test RMSE: 0.3252, Test MAE: 0.1494
# ---------------------------------
# Patience grace period: 55
# ---------------------------------
# Epoch 91/500
# Train RMSE: 0.2495
# Val RMSE: 0.2488, Val MAE: 0.1064
# Test RMSE: 0.3249, Test MAE: 0.1492
# ---------------------------------
# Model saved at epoch 91 with val RMSE 0.2488
# Patience grace period: 54
# ---------------------------------
# Epoch 92/500
# Train RMSE: 0.2495
# Val RMSE: 0.2488, Val MAE: 0.1071
# Test RMSE: 0.3240, Test MAE: 0.1498
# ---------------------------------
# Patience grace period: 52
# ---------------------------------
# Epoch 93/500
# Train RMSE: 0.2494
# Val RMSE: 0.2488, Val MAE: 0.1066
# Test RMSE: 0.3247, Test MAE: 0.1495
# ---------------------------------
# Model saved at epoch 93 with val RMSE 0.2488
# Patience grace period: 51
# ---------------------------------
# Epoch 94/500
# Train RMSE: 0.2494
# Val RMSE: 0.2488, Val MAE: 0.1066
# Test RMSE: 0.3248, Test MAE: 0.1494
# ---------------------------------
# Patience grace period: 49
# ---------------------------------
# Epoch 95/500
# Train RMSE: 0.2494
# Val RMSE: 0.2488, Val MAE: 0.1069
# Test RMSE: 0.3245, Test MAE: 0.1496
# ---------------------------------
# Patience grace period: 47
# ---------------------------------
# Epoch 96/500
# Train RMSE: 0.2494
# Val RMSE: 0.2488, Val MAE: 0.1069
# Test RMSE: 0.3241, Test MAE: 0.1497
# ---------------------------------
# Patience grace period: 46
# ---------------------------------
# Epoch 97/500
# Train RMSE: 0.2493
# Val RMSE: 0.2488, Val MAE: 0.1069
# Test RMSE: 0.3243, Test MAE: 0.1495
# ---------------------------------
# Patience grace period: 45
# ---------------------------------
# Epoch 98/500
# Train RMSE: 0.2493
# Val RMSE: 0.2487, Val MAE: 0.1064
# Test RMSE: 0.3252, Test MAE: 0.1492
# ---------------------------------
# Model saved at epoch 98 with val RMSE 0.2487
# Patience grace period: 44
# ---------------------------------
# Epoch 99/500
# Train RMSE: 0.2493
# Val RMSE: 0.2487, Val MAE: 0.1069
# Test RMSE: 0.3239, Test MAE: 0.1497
# ---------------------------------
# Patience grace period: 42
# ---------------------------------
# Epoch 100/500
# Train RMSE: 0.2492
# Val RMSE: 0.2487, Val MAE: 0.1062
# Test RMSE: 0.3256, Test MAE: 0.1491
# ---------------------------------
# Patience grace period: 41
# ---------------------------------
# Epoch 101/500
# Train RMSE: 0.2492
# Val RMSE: 0.2487, Val MAE: 0.1067
# Test RMSE: 0.3246, Test MAE: 0.1495
# ---------------------------------
# Patience grace period: 39
# ---------------------------------
# Epoch 102/500
# Train RMSE: 0.2492
# Val RMSE: 0.2487, Val MAE: 0.1065
# Test RMSE: 0.3248, Test MAE: 0.1493
# ---------------------------------
# Model saved at epoch 102 with val RMSE 0.2487
# Patience grace period: 38
# ---------------------------------
# Epoch 103/500
# Train RMSE: 0.2492
# Val RMSE: 0.2487, Val MAE: 0.1064
# Test RMSE: 0.3248, Test MAE: 0.1494
# ---------------------------------
# Model saved at epoch 103 with val RMSE 0.2487
# Patience grace period: 37
# ---------------------------------
# Epoch 104/500
# Train RMSE: 0.2491
# Val RMSE: 0.2487, Val MAE: 0.1068
# Test RMSE: 0.3241, Test MAE: 0.1498
# ---------------------------------
# Patience grace period: 35
# ---------------------------------
# Epoch 105/500
# Train RMSE: 0.2491
# Val RMSE: 0.2486, Val MAE: 0.1059
# Test RMSE: 0.3257, Test MAE: 0.1489
# ---------------------------------
# Model saved at epoch 105 with val RMSE 0.2486
# Patience grace period: 34
# ---------------------------------
# Epoch 106/500
# Train RMSE: 0.2491
# Val RMSE: 0.2487, Val MAE: 0.1067
# Test RMSE: 0.3241, Test MAE: 0.1497
# ---------------------------------
# Patience grace period: 32
# ---------------------------------
# Epoch 107/500
# Train RMSE: 0.2491
# Val RMSE: 0.2486, Val MAE: 0.1065
# Test RMSE: 0.3247, Test MAE: 0.1495
# ---------------------------------
# Model saved at epoch 107 with val RMSE 0.2486
# Patience grace period: 31
# ---------------------------------
# Epoch 108/500
# Train RMSE: 0.2490
# Val RMSE: 0.2486, Val MAE: 0.1066
# Test RMSE: 0.3244, Test MAE: 0.1496
# ---------------------------------
# Model saved at epoch 108 with val RMSE 0.2486
# Patience grace period: 30
# ---------------------------------
# Epoch 109/500
# Train RMSE: 0.2490
# Val RMSE: 0.2487, Val MAE: 0.1063
# Test RMSE: 0.3246, Test MAE: 0.1494
# ---------------------------------
# Patience grace period: 28
# ---------------------------------
# Epoch 110/500
# Train RMSE: 0.2490
# Val RMSE: 0.2486, Val MAE: 0.1061
# Test RMSE: 0.3254, Test MAE: 0.1493
# ---------------------------------
# Patience grace period: 27
# ---------------------------------
# Epoch 111/500
# Train RMSE: 0.2490
# Val RMSE: 0.2486, Val MAE: 0.1065
# Test RMSE: 0.3251, Test MAE: 0.1495
# ---------------------------------
# Patience grace period: 26
# ---------------------------------
# Epoch 112/500
# Train RMSE: 0.2489
# Val RMSE: 0.2486, Val MAE: 0.1070
# Test RMSE: 0.3239, Test MAE: 0.1501
# ---------------------------------
# Patience grace period: 25
# ---------------------------------
# Epoch 113/500
# Train RMSE: 0.2489
# Val RMSE: 0.2486, Val MAE: 0.1062
# Test RMSE: 0.3252, Test MAE: 0.1496
# ---------------------------------
# Patience grace period: 23
# ---------------------------------
# Epoch 114/500
# Train RMSE: 0.2489
# Val RMSE: 0.2486, Val MAE: 0.1065
# Test RMSE: 0.3243, Test MAE: 0.1495
# ---------------------------------
# Patience grace period: 22
# ---------------------------------
# Epoch 115/500
# Train RMSE: 0.2489
# Val RMSE: 0.2485, Val MAE: 0.1064
# Test RMSE: 0.3243, Test MAE: 0.1495
# ---------------------------------
# Model saved at epoch 115 with val RMSE 0.2485
# Patience grace period: 21
# ---------------------------------
# Epoch 116/500
# Train RMSE: 0.2488
# Val RMSE: 0.2486, Val MAE: 0.1059
# Test RMSE: 0.3258, Test MAE: 0.1492
# ---------------------------------
# Patience grace period: 19
# ---------------------------------
# Epoch 117/500
# Train RMSE: 0.2488
# Val RMSE: 0.2486, Val MAE: 0.1064
# Test RMSE: 0.3249, Test MAE: 0.1496
# ---------------------------------
# Patience grace period: 17
# ---------------------------------
# Epoch 118/500
# Train RMSE: 0.2488
# Val RMSE: 0.2486, Val MAE: 0.1070
# Test RMSE: 0.3236, Test MAE: 0.1502
# ---------------------------------
# Patience grace period: 16
# ---------------------------------
# Epoch 119/500
# Train RMSE: 0.2488
# Val RMSE: 0.2486, Val MAE: 0.1069
# Test RMSE: 0.3239, Test MAE: 0.1501
# ---------------------------------
# Patience grace period: 14
# ---------------------------------
# Epoch 120/500
# Train RMSE: 0.2488
# Val RMSE: 0.2485, Val MAE: 0.1066
# Test RMSE: 0.3243, Test MAE: 0.1498
# ---------------------------------
# Patience grace period: 13
# ---------------------------------
# Epoch 121/500
# Train RMSE: 0.2488
# Val RMSE: 0.2485, Val MAE: 0.1062
# Test RMSE: 0.3249, Test MAE: 0.1495
# ---------------------------------
# Model saved at epoch 121 with val RMSE 0.2485
# Patience grace period: 12
# ---------------------------------
# Epoch 122/500
# Train RMSE: 0.2488
# Val RMSE: 0.2486, Val MAE: 0.1072
# Test RMSE: 0.3233, Test MAE: 0.1504
# ---------------------------------
# Patience grace period: 10
# ---------------------------------
# Epoch 123/500
# Train RMSE: 0.2488
# Val RMSE: 0.2485, Val MAE: 0.1065
# Test RMSE: 0.3242, Test MAE: 0.1497
# ---------------------------------
# Model saved at epoch 123 with val RMSE 0.2485
# Patience grace period: 9
# ---------------------------------
# Epoch 124/500
# Train RMSE: 0.2487
# Val RMSE: 0.2485, Val MAE: 0.1069
# Test RMSE: 0.3237, Test MAE: 0.1500
# ---------------------------------
# Patience grace period: 7
# ---------------------------------
# Epoch 125/500
# Train RMSE: 0.2487
# Val RMSE: 0.2485, Val MAE: 0.1064
# Test RMSE: 0.3245, Test MAE: 0.1496
# ---------------------------------
# Patience grace period: 5
# ---------------------------------
# Epoch 126/500
# Train RMSE: 0.2487
# Val RMSE: 0.2485, Val MAE: 0.1070
# Test RMSE: 0.3235, Test MAE: 0.1502
# ---------------------------------
# Patience grace period: 3
# ---------------------------------
# Epoch 127/500
# Train RMSE: 0.2487
# Val RMSE: 0.2486, Val MAE: 0.1070
# Test RMSE: 0.3235, Test MAE: 0.1501
# ---------------------------------
# Patience grace period: 1
# ---------------------------------
# Epoch 128/500
# Train RMSE: 0.2486
# Val RMSE: 0.2485, Val MAE: 0.1060
# Test RMSE: 0.3253, Test MAE: 0.1496
# ---------------------------------
# Model saved at epoch 128 with val RMSE 0.2485
# Patience grace period: 0
# Early stopping triggered at epoch 128
# Final Test RMSE: 0.3253, Final Test MAE: 0.1496
# <ipython-input-2-d8b64875fc37>:120: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   self.model.load_state_dict(torch.load(os.path.join(save_dir, 'best_model.pth')))
# Pearson Corr: 0.749115263248846
# Spearman Corr: 0.43082221855730685
# p-rmse: 0.3253058626522033
#        rmse       mae  seed                             subtask    method  \
# 0  0.325306  0.149565     1  openproblems_bmmc_cite_phase2_mod2  original
#
#     pearson p_value_pearson  spearman p_value_spearman
# 0  0.749115          0.0000  0.430822           0.0000
# ---------------------------------
# Epoch 1/500
# Train RMSE: 0.3746
# Val RMSE: 0.3227, Val MAE: 0.1329
# Test RMSE: 0.3993, Test MAE: 0.1770
# ---------------------------------
# Model saved at epoch 1 with val RMSE 0.3227
# Patience grace period: 150
# ---------------------------------
# Epoch 2/500
# Train RMSE: 0.3272
# Val RMSE: 0.2941, Val MAE: 0.1276
# Test RMSE: 0.3683, Test MAE: 0.1683
# ---------------------------------
# Model saved at epoch 2 with val RMSE 0.2941
# Patience grace period: 150
# ---------------------------------
# Epoch 3/500
# Train RMSE: 0.3051
# Val RMSE: 0.2794, Val MAE: 0.1207
# Test RMSE: 0.3553, Test MAE: 0.1606
# ---------------------------------
# Model saved at epoch 3 with val RMSE 0.2794
# Patience grace period: 150
# ---------------------------------
# Epoch 4/500
# Train RMSE: 0.2921
# Val RMSE: 0.2727, Val MAE: 0.1180
# Test RMSE: 0.3496, Test MAE: 0.1577
# ---------------------------------
# Model saved at epoch 4 with val RMSE 0.2727
# Patience grace period: 149
# ---------------------------------
# Epoch 5/500
# Train RMSE: 0.2841
# Val RMSE: 0.2685, Val MAE: 0.1168
# Test RMSE: 0.3457, Test MAE: 0.1561
# ---------------------------------
# Model saved at epoch 5 with val RMSE 0.2685
# Patience grace period: 150
# ---------------------------------
# Epoch 6/500
# Train RMSE: 0.2782
# Val RMSE: 0.2653, Val MAE: 0.1156
# Test RMSE: 0.3419, Test MAE: 0.1541
# ---------------------------------
# Model saved at epoch 6 with val RMSE 0.2653
# Patience grace period: 149
# ---------------------------------
# Epoch 7/500
# Train RMSE: 0.2736
# Val RMSE: 0.2627, Val MAE: 0.1145
# Test RMSE: 0.3391, Test MAE: 0.1525
# ---------------------------------
# Model saved at epoch 7 with val RMSE 0.2627
# Patience grace period: 148
# ---------------------------------
# Epoch 8/500
# Train RMSE: 0.2698
# Val RMSE: 0.2606, Val MAE: 0.1136
# Test RMSE: 0.3369, Test MAE: 0.1512
# ---------------------------------
# Model saved at epoch 8 with val RMSE 0.2606
# Patience grace period: 147
# ---------------------------------
# Epoch 9/500
# Train RMSE: 0.2667
# Val RMSE: 0.2589, Val MAE: 0.1118
# Test RMSE: 0.3366, Test MAE: 0.1496
# ---------------------------------
# Model saved at epoch 9 with val RMSE 0.2589
# Patience grace period: 146
# ---------------------------------
# Epoch 10/500
# Train RMSE: 0.2644
# Val RMSE: 0.2577, Val MAE: 0.1108
# Test RMSE: 0.3366, Test MAE: 0.1488
# ---------------------------------
# Model saved at epoch 10 with val RMSE 0.2577
# Patience grace period: 150
# ---------------------------------
# Epoch 11/500
# Train RMSE: 0.2625
# Val RMSE: 0.2565, Val MAE: 0.1110
# Test RMSE: 0.3343, Test MAE: 0.1488
# ---------------------------------
# Model saved at epoch 11 with val RMSE 0.2565
# Patience grace period: 149
# ---------------------------------
# Epoch 12/500
# Train RMSE: 0.2612
# Val RMSE: 0.2557, Val MAE: 0.1104
# Test RMSE: 0.3338, Test MAE: 0.1484
# ---------------------------------
# Model saved at epoch 12 with val RMSE 0.2557
# Patience grace period: 148
# ---------------------------------
# Epoch 13/500
# Train RMSE: 0.2601
# Val RMSE: 0.2551, Val MAE: 0.1095
# Test RMSE: 0.3337, Test MAE: 0.1475
# ---------------------------------
# Model saved at epoch 13 with val RMSE 0.2551
# Patience grace period: 147
# ---------------------------------
# Epoch 14/500
# Train RMSE: 0.2593
# Val RMSE: 0.2546, Val MAE: 0.1091
# Test RMSE: 0.3336, Test MAE: 0.1473
# ---------------------------------
# Model saved at epoch 14 with val RMSE 0.2546
# Patience grace period: 146
# ---------------------------------
# Epoch 15/500
# Train RMSE: 0.2586
# Val RMSE: 0.2542, Val MAE: 0.1092
# Test RMSE: 0.3326, Test MAE: 0.1474
# ---------------------------------
# Model saved at epoch 15 with val RMSE 0.2542
# Patience grace period: 145
# ---------------------------------
# Epoch 16/500
# Train RMSE: 0.2580
# Val RMSE: 0.2539, Val MAE: 0.1086
# Test RMSE: 0.3327, Test MAE: 0.1470
# ---------------------------------
# Model saved at epoch 16 with val RMSE 0.2539
# Patience grace period: 144
# ---------------------------------
# Epoch 17/500
# Train RMSE: 0.2575
# Val RMSE: 0.2537, Val MAE: 0.1082
# Test RMSE: 0.3326, Test MAE: 0.1468
# ---------------------------------
# Model saved at epoch 17 with val RMSE 0.2537
# Patience grace period: 143
# ---------------------------------
# Epoch 18/500
# Train RMSE: 0.2571
# Val RMSE: 0.2533, Val MAE: 0.1085
# Test RMSE: 0.3316, Test MAE: 0.1471
# ---------------------------------
# Model saved at epoch 18 with val RMSE 0.2533
# Patience grace period: 142
# ---------------------------------
# Epoch 19/500
# Train RMSE: 0.2567
# Val RMSE: 0.2530, Val MAE: 0.1089
# Test RMSE: 0.3305, Test MAE: 0.1473
# ---------------------------------
# Model saved at epoch 19 with val RMSE 0.2530
# Patience grace period: 141
# ---------------------------------
# Epoch 20/500
# Train RMSE: 0.2563
# Val RMSE: 0.2528, Val MAE: 0.1084
# Test RMSE: 0.3312, Test MAE: 0.1471
# ---------------------------------
# Model saved at epoch 20 with val RMSE 0.2528
# Patience grace period: 140
# ---------------------------------
# Epoch 21/500
# Train RMSE: 0.2560
# Val RMSE: 0.2527, Val MAE: 0.1080
# Test RMSE: 0.3313, Test MAE: 0.1469
# ---------------------------------
# Model saved at epoch 21 with val RMSE 0.2527
# Patience grace period: 139
# ---------------------------------
# Epoch 22/500
# Train RMSE: 0.2557
# Val RMSE: 0.2524, Val MAE: 0.1082
# Test RMSE: 0.3302, Test MAE: 0.1473
# ---------------------------------
# Model saved at epoch 22 with val RMSE 0.2524
# Patience grace period: 138
# ---------------------------------
# Epoch 23/500
# Train RMSE: 0.2554
# Val RMSE: 0.2523, Val MAE: 0.1081
# Test RMSE: 0.3304, Test MAE: 0.1472
# ---------------------------------
# Model saved at epoch 23 with val RMSE 0.2523
# Patience grace period: 137
# ---------------------------------
# Epoch 24/500
# Train RMSE: 0.2552
# Val RMSE: 0.2520, Val MAE: 0.1080
# Test RMSE: 0.3297, Test MAE: 0.1471
# ---------------------------------
# Model saved at epoch 24 with val RMSE 0.2520
# Patience grace period: 136
# ---------------------------------
# Epoch 25/500
# Train RMSE: 0.2549
# Val RMSE: 0.2519, Val MAE: 0.1074
# Test RMSE: 0.3301, Test MAE: 0.1469
# ---------------------------------
# Model saved at epoch 25 with val RMSE 0.2519
# Patience grace period: 135
# ---------------------------------
# Epoch 26/500
# Train RMSE: 0.2547
# Val RMSE: 0.2517, Val MAE: 0.1079
# Test RMSE: 0.3292, Test MAE: 0.1472
# ---------------------------------
# Model saved at epoch 26 with val RMSE 0.2517
# Patience grace period: 134
# ---------------------------------
# Epoch 27/500
# Train RMSE: 0.2545
# Val RMSE: 0.2517, Val MAE: 0.1074
# Test RMSE: 0.3301, Test MAE: 0.1469
# ---------------------------------
# Model saved at epoch 27 with val RMSE 0.2517
# Patience grace period: 133
# ---------------------------------
# Epoch 28/500
# Train RMSE: 0.2543
# Val RMSE: 0.2516, Val MAE: 0.1071
# Test RMSE: 0.3299, Test MAE: 0.1469
# ---------------------------------
# Model saved at epoch 28 with val RMSE 0.2516
# Patience grace period: 132
# ---------------------------------
# Epoch 29/500
# Train RMSE: 0.2541
# Val RMSE: 0.2515, Val MAE: 0.1071
# Test RMSE: 0.3296, Test MAE: 0.1470
# ---------------------------------
# Model saved at epoch 29 with val RMSE 0.2515
# Patience grace period: 131
# ---------------------------------
# Epoch 30/500
# Train RMSE: 0.2539
# Val RMSE: 0.2514, Val MAE: 0.1070
# ...
# Model saved at epoch 117 with val RMSE 0.2485
# Patience grace period: 20
# ---------------------------------
# Epoch 118/500
# Train RMSE: 0.2489
# Val RMSE: 0.2485, Val MAE: 0.1058
# Test RMSE: 0.3256, Test MAE: 0.1489
# ---------------------------------
# Model saved at epoch 118 with val RMSE 0.2485
# Patience grace period: 19
# ---------------------------------
# Epoch 119/500
# Train RMSE: 0.2489
# Val RMSE: 0.2485, Val MAE: 0.1057
# Test RMSE: 0.3258, Test MAE: 0.1490
# ---------------------------------
# Model saved at epoch 119 with val RMSE 0.2485
# Patience grace period: 18
# ---------------------------------
# Epoch 120/500
# Train RMSE: 0.2489
# Val RMSE: 0.2485, Val MAE: 0.1058
# Test RMSE: 0.3255, Test MAE: 0.1489
# ---------------------------------
# Patience grace period: 16
# ---------------------------------
# Epoch 121/500
# Train RMSE: 0.2489
# Val RMSE: 0.2485, Val MAE: 0.1058
# Test RMSE: 0.3256, Test MAE: 0.1490
# ---------------------------------
# Model saved at epoch 121 with val RMSE 0.2485
# Patience grace period: 15
# ---------------------------------
# Epoch 122/500
# Train RMSE: 0.2489
# Val RMSE: 0.2485, Val MAE: 0.1056
# Test RMSE: 0.3257, Test MAE: 0.1489
# ---------------------------------
# Patience grace period: 13
# ---------------------------------
# Epoch 123/500
# Train RMSE: 0.2489
# Val RMSE: 0.2485, Val MAE: 0.1055
# Test RMSE: 0.3255, Test MAE: 0.1490
# ---------------------------------
# Patience grace period: 12
# ---------------------------------
# Epoch 124/500
# Train RMSE: 0.2488
# Val RMSE: 0.2485, Val MAE: 0.1055
# Test RMSE: 0.3255, Test MAE: 0.1488
# ---------------------------------
# Patience grace period: 10
# ---------------------------------
# Epoch 125/500
# Train RMSE: 0.2488
# Val RMSE: 0.2485, Val MAE: 0.1054
# Test RMSE: 0.3260, Test MAE: 0.1489
# ---------------------------------
# Patience grace period: 8
# ---------------------------------
# Epoch 126/500
# Train RMSE: 0.2488
# Val RMSE: 0.2484, Val MAE: 0.1055
# Test RMSE: 0.3257, Test MAE: 0.1489
# ---------------------------------
# Model saved at epoch 126 with val RMSE 0.2484
# Patience grace period: 7
# ---------------------------------
# Epoch 127/500
# Train RMSE: 0.2488
# Val RMSE: 0.2485, Val MAE: 0.1057
# Test RMSE: 0.3257, Test MAE: 0.1489
# ---------------------------------
# Patience grace period: 5
# ---------------------------------
# Epoch 128/500
# Train RMSE: 0.2488
# Val RMSE: 0.2484, Val MAE: 0.1055
# Test RMSE: 0.3260, Test MAE: 0.1490
# ---------------------------------
# Patience grace period: 4
# ---------------------------------
# Epoch 129/500
# Train RMSE: 0.2487
# Val RMSE: 0.2484, Val MAE: 0.1060
# Test RMSE: 0.3254, Test MAE: 0.1493
# ---------------------------------
# Model saved at epoch 129 with val RMSE 0.2484
# Patience grace period: 3
# ---------------------------------
# Epoch 130/500
# Train RMSE: 0.2487
# Val RMSE: 0.2484, Val MAE: 0.1060
# Test RMSE: 0.3247, Test MAE: 0.1493
# ---------------------------------
# Model saved at epoch 130 with val RMSE 0.2484
# Patience grace period: 2
# ---------------------------------
# Epoch 131/500
# Train RMSE: 0.2487
# Val RMSE: 0.2484, Val MAE: 0.1060
# Test RMSE: 0.3251, Test MAE: 0.1495
# ---------------------------------
# Patience grace period: 0
# Early stopping triggered at epoch 131
# Final Test RMSE: 0.3247, Final Test MAE: 0.1493
# <ipython-input-2-d8b64875fc37>:120: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   self.model.load_state_dict(torch.load(os.path.join(save_dir, 'best_model.pth')))
# Pearson Corr: 0.7489358838553101
# Spearman Corr: 0.42999095796629894
# p-rmse: 0.3247325686401
#        rmse       mae  seed                             subtask    method  \
# 0  0.324733  0.149262     4  openproblems_bmmc_cite_phase2_mod2  original
#
#     pearson p_value_pearson  spearman p_value_spearman
# 0  0.748936          0.0000  0.429991           0.0000
# ---------------------------------
# Epoch 1/500
# Train RMSE: 0.3728
# Val RMSE: 0.3195, Val MAE: 0.1334
# Test RMSE: 0.3945, Test MAE: 0.1774
# ---------------------------------
# Model saved at epoch 1 with val RMSE 0.3195
# Patience grace period: 150
# ---------------------------------
# Epoch 2/500
# Train RMSE: 0.3247
# Val RMSE: 0.2920, Val MAE: 0.1263
# Test RMSE: 0.3665, Test MAE: 0.1672
# ---------------------------------
# Model saved at epoch 2 with val RMSE 0.2920
# Patience grace period: 150
# ---------------------------------
# Epoch 3/500
# Train RMSE: 0.3035
# Val RMSE: 0.2789, Val MAE: 0.1205
# Test RMSE: 0.3548, Test MAE: 0.1606
# ---------------------------------
# Model saved at epoch 3 with val RMSE 0.2789
# Patience grace period: 150
# ---------------------------------
# Epoch 4/500
# Train RMSE: 0.2914
# Val RMSE: 0.2723, Val MAE: 0.1182
# Test RMSE: 0.3489, Test MAE: 0.1580
# ---------------------------------
# Model saved at epoch 4 with val RMSE 0.2723
# Patience grace period: 149
# ---------------------------------
# Epoch 5/500
# Train RMSE: 0.2838
# Val RMSE: 0.2686, Val MAE: 0.1167
# Test RMSE: 0.3461, Test MAE: 0.1562
# ---------------------------------
# Model saved at epoch 5 with val RMSE 0.2686
# Patience grace period: 150
# ---------------------------------
# Epoch 6/500
# Train RMSE: 0.2782
# Val RMSE: 0.2655, Val MAE: 0.1156
# Test RMSE: 0.3430, Test MAE: 0.1544
# ---------------------------------
# Model saved at epoch 6 with val RMSE 0.2655
# Patience grace period: 149
# ---------------------------------
# Epoch 7/500
# Train RMSE: 0.2736
# Val RMSE: 0.2626, Val MAE: 0.1152
# Test RMSE: 0.3390, Test MAE: 0.1532
# ---------------------------------
# Model saved at epoch 7 with val RMSE 0.2626
# Patience grace period: 148
# ---------------------------------
# Epoch 8/500
# Train RMSE: 0.2699
# Val RMSE: 0.2605, Val MAE: 0.1144
# Test RMSE: 0.3364, Test MAE: 0.1518
# ---------------------------------
# Model saved at epoch 8 with val RMSE 0.2605
# Patience grace period: 147
# ---------------------------------
# Epoch 9/500
# Train RMSE: 0.2670
# Val RMSE: 0.2590, Val MAE: 0.1130
# Test RMSE: 0.3362, Test MAE: 0.1504
# ---------------------------------
# Model saved at epoch 9 with val RMSE 0.2590
# Patience grace period: 146
# ---------------------------------
# Epoch 10/500
# Train RMSE: 0.2647
# Val RMSE: 0.2577, Val MAE: 0.1121
# Test RMSE: 0.3350, Test MAE: 0.1496
# ---------------------------------
# Model saved at epoch 10 with val RMSE 0.2577
# Patience grace period: 150
# ---------------------------------
# Epoch 11/500
# Train RMSE: 0.2629
# Val RMSE: 0.2568, Val MAE: 0.1113
# Test RMSE: 0.3354, Test MAE: 0.1487
# ---------------------------------
# Model saved at epoch 11 with val RMSE 0.2568
# Patience grace period: 149
# ---------------------------------
# Epoch 12/500
# Train RMSE: 0.2616
# Val RMSE: 0.2560, Val MAE: 0.1113
# Test RMSE: 0.3340, Test MAE: 0.1489
# ---------------------------------
# Model saved at epoch 12 with val RMSE 0.2560
# Patience grace period: 148
# ---------------------------------
# Epoch 13/500
# Train RMSE: 0.2605
# Val RMSE: 0.2554, Val MAE: 0.1104
# Test RMSE: 0.3339, Test MAE: 0.1485
# ---------------------------------
# Model saved at epoch 13 with val RMSE 0.2554
# Patience grace period: 147
# ---------------------------------
# Epoch 14/500
# Train RMSE: 0.2596
# Val RMSE: 0.2547, Val MAE: 0.1109
# Test RMSE: 0.3321, Test MAE: 0.1487
# ---------------------------------
# Model saved at epoch 14 with val RMSE 0.2547
# Patience grace period: 146
# ---------------------------------
# Epoch 15/500
# Train RMSE: 0.2588
# Val RMSE: 0.2542, Val MAE: 0.1109
# Test RMSE: 0.3313, Test MAE: 0.1486
# ---------------------------------
# Model saved at epoch 15 with val RMSE 0.2542
# Patience grace period: 145
# ---------------------------------
# Epoch 16/500
# Train RMSE: 0.2581
# Val RMSE: 0.2538, Val MAE: 0.1101
# Test RMSE: 0.3315, Test MAE: 0.1481
# ---------------------------------
# Model saved at epoch 16 with val RMSE 0.2538
# Patience grace period: 144
# ---------------------------------
# Epoch 17/500
# Train RMSE: 0.2575
# Val RMSE: 0.2535, Val MAE: 0.1096
# Test RMSE: 0.3314, Test MAE: 0.1477
# ---------------------------------
# Model saved at epoch 17 with val RMSE 0.2535
# Patience grace period: 143
# ---------------------------------
# Epoch 18/500
# Train RMSE: 0.2570
# Val RMSE: 0.2532, Val MAE: 0.1095
# Test RMSE: 0.3309, Test MAE: 0.1477
# ---------------------------------
# Model saved at epoch 18 with val RMSE 0.2532
# Patience grace period: 142
# ---------------------------------
# Epoch 19/500
# Train RMSE: 0.2566
# Val RMSE: 0.2529, Val MAE: 0.1094
# Test RMSE: 0.3304, Test MAE: 0.1477
# ---------------------------------
# Model saved at epoch 19 with val RMSE 0.2529
# Patience grace period: 141
# ---------------------------------
# Epoch 20/500
# Train RMSE: 0.2562
# Val RMSE: 0.2527, Val MAE: 0.1088
# Test RMSE: 0.3306, Test MAE: 0.1474
# ---------------------------------
# Model saved at epoch 20 with val RMSE 0.2527
# Patience grace period: 140
# ---------------------------------
# Epoch 21/500
# Train RMSE: 0.2559
# Val RMSE: 0.2524, Val MAE: 0.1092
# Test RMSE: 0.3297, Test MAE: 0.1479
# ---------------------------------
# Model saved at epoch 21 with val RMSE 0.2524
# Patience grace period: 139
# ---------------------------------
# Epoch 22/500
# Train RMSE: 0.2556
# Val RMSE: 0.2522, Val MAE: 0.1089
# Test RMSE: 0.3298, Test MAE: 0.1477
# ---------------------------------
# Model saved at epoch 22 with val RMSE 0.2522
# Patience grace period: 138
# ---------------------------------
# Epoch 23/500
# Train RMSE: 0.2553
# Val RMSE: 0.2521, Val MAE: 0.1090
# Test RMSE: 0.3294, Test MAE: 0.1480
# ---------------------------------
# Model saved at epoch 23 with val RMSE 0.2521
# Patience grace period: 137
# ---------------------------------
# Epoch 24/500
# Train RMSE: 0.2550
# Val RMSE: 0.2519, Val MAE: 0.1087
# Test RMSE: 0.3295, Test MAE: 0.1480
# ---------------------------------
# Model saved at epoch 24 with val RMSE 0.2519
# Patience grace period: 136
# ---------------------------------
# Epoch 25/500
# Train RMSE: 0.2548
# Val RMSE: 0.2518, Val MAE: 0.1090
# Test RMSE: 0.3285, Test MAE: 0.1484
# ---------------------------------
# Model saved at epoch 25 with val RMSE 0.2518
# Patience grace period: 135
# ---------------------------------
# Epoch 26/500
# Train RMSE: 0.2546
# Val RMSE: 0.2516, Val MAE: 0.1091
# Test RMSE: 0.3284, Test MAE: 0.1484
# ---------------------------------
# Model saved at epoch 26 with val RMSE 0.2516
# Patience grace period: 134
# ---------------------------------
# Epoch 27/500
# Train RMSE: 0.2544
# Val RMSE: 0.2515, Val MAE: 0.1090
# Test RMSE: 0.3284, Test MAE: 0.1484
# ---------------------------------
# Model saved at epoch 27 with val RMSE 0.2515
# Patience grace period: 133
# ---------------------------------
# Epoch 28/500
# Train RMSE: 0.2541
# Val RMSE: 0.2515, Val MAE: 0.1076
# Test RMSE: 0.3304, Test MAE: 0.1476
# ---------------------------------
# Model saved at epoch 28 with val RMSE 0.2515
# Patience grace period: 132
# ---------------------------------
# Epoch 29/500
# Train RMSE: 0.2540
# Val RMSE: 0.2513, Val MAE: 0.1090
# Test RMSE: 0.3279, Test MAE: 0.1486
# ---------------------------------
# Model saved at epoch 29 with val RMSE 0.2513
# Patience grace period: 131
# ---------------------------------
# Epoch 30/500
# Train RMSE: 0.2538
# Val RMSE: 0.2512, Val MAE: 0.1088
# Test RMSE: 0.3278, Test MAE: 0.1484
# ---------------------------------
# Model saved at epoch 30 with val RMSE 0.2512
# Patience grace period: 130
# ---------------------------------
# Epoch 31/500
# Train RMSE: 0.2537
# Val RMSE: 0.2512, Val MAE: 0.1090
# Test RMSE: 0.3270, Test MAE: 0.1487
# ---------------------------------
# Model saved at epoch 31 with val RMSE 0.2512
# Patience grace period: 129
# ---------------------------------
# Epoch 32/500
# Train RMSE: 0.2535
# Val RMSE: 0.2510, Val MAE: 0.1088
# Test RMSE: 0.3273, Test MAE: 0.1487
# ---------------------------------
# Model saved at epoch 32 with val RMSE 0.2510
# Patience grace period: 128
# ---------------------------------
# Epoch 33/500
# Train RMSE: 0.2534
# Val RMSE: 0.2510, Val MAE: 0.1083
# Test RMSE: 0.3278, Test MAE: 0.1485
# ---------------------------------
# Model saved at epoch 33 with val RMSE 0.2510
# Patience grace period: 127
# ---------------------------------
# Epoch 34/500
# Train RMSE: 0.2533
# Val RMSE: 0.2509, Val MAE: 0.1085
# Test RMSE: 0.3274, Test MAE: 0.1486
# ---------------------------------
# Model saved at epoch 34 with val RMSE 0.2509
# Patience grace period: 126
# ---------------------------------
# Epoch 35/500
# Train RMSE: 0.2531
# Val RMSE: 0.2508, Val MAE: 0.1087
# Test RMSE: 0.3268, Test MAE: 0.1487
# ---------------------------------
# Model saved at epoch 35 with val RMSE 0.2508
# Patience grace period: 125
# ---------------------------------
# Epoch 36/500
# Train RMSE: 0.2530
# Val RMSE: 0.2507, Val MAE: 0.1086
# Test RMSE: 0.3269, Test MAE: 0.1489
# ---------------------------------
# Model saved at epoch 36 with val RMSE 0.2507
# Patience grace period: 124
# ---------------------------------
# Epoch 37/500
# Train RMSE: 0.2529
# Val RMSE: 0.2507, Val MAE: 0.1079
# Test RMSE: 0.3277, Test MAE: 0.1486
# ---------------------------------
# Model saved at epoch 37 with val RMSE 0.2507
# Patience grace period: 123
# ---------------------------------
# Epoch 38/500
# Train RMSE: 0.2527
# Val RMSE: 0.2506, Val MAE: 0.1087
# Test RMSE: 0.3262, Test MAE: 0.1491
# ---------------------------------
# Model saved at epoch 38 with val RMSE 0.2506
# Patience grace period: 122
# ---------------------------------
# Epoch 39/500
# Train RMSE: 0.2526
# Val RMSE: 0.2505, Val MAE: 0.1082
# Test RMSE: 0.3270, Test MAE: 0.1489
# ---------------------------------
# Model saved at epoch 39 with val RMSE 0.2505
# Patience grace period: 121
# ---------------------------------
# Epoch 40/500
# Train RMSE: 0.2525
# Val RMSE: 0.2505, Val MAE: 0.1082
# Test RMSE: 0.3267, Test MAE: 0.1492
# ---------------------------------
# Model saved at epoch 40 with val RMSE 0.2505
# Patience grace period: 120
# ---------------------------------
# Epoch 41/500
# Train RMSE: 0.2524
# Val RMSE: 0.2504, Val MAE: 0.1080
# Test RMSE: 0.3271, Test MAE: 0.1489
# ---------------------------------
# Model saved at epoch 41 with val RMSE 0.2504
# Patience grace period: 119
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-18-a285d73a92df> in <cell line: 0>()
#      25 }
#      26
# ---> 27 pipeline(**config_PROTEIN)
#
# <ipython-input-4-15ebac2ab37f> in pipeline(**kwargs)
#      96         # Instantiate the unified wrapper.
#      97         model = scParaLaGWrapper(Namespace(**kwargs))
# ---> 98         model.fit(train_graph, val_graph, test_graph,
#      99                   torch.tensor(train_label) if 'train_label' in locals() else None,
#     100                   torch.tensor(val_label) if 'val_label' in locals() else None,
#
# <ipython-input-2-d8b64875fc37> in fit(self, train_graph, val_graph, test_graph, train_label, val_label, test_label, num_epochs, batch_size, verbose, es_patience, es_min_delta, es_rate_threshold, learning_rate, sample, l2_lambda)
#      97                 outputs = self.model(subgraph, subgraph.ndata['feat'])
#      98                 loss = F.mse_loss(outputs, batch_labels)
# ---> 99                 loss.backward()
#     100                 optimizer.step()
#     101                 epoch_loss += loss.item()
#
# /usr/local/lib/python3.11/dist-packages/torch/_tensor.py in backward(self, gradient, retain_graph, create_graph, inputs)
#     523         return torch._tensor_str._str(self, tensor_contents=tensor_contents)
#     524
# --> 525     def backward(
#     526         self, gradient=None, retain_graph=None, create_graph=False, inputs=None
#     527     ):
#
# KeyboardInterrupt:

# %%
config_PROTEIN = {
    "subtask": "openproblems_bmmc_cite_phase2_mod2",
    "batch_size": 520,
    "act": "relu",
    "conv_flow": ["gat"],
    "agg_flow": [None],
    "device": "cuda",
    "learning_rate": 0.000064,
    "hidden_size": 280,
    "num_heads": 6,
    "n_neigbours": 3,
    "metric": "euclidean",
    "n_components": 1200,
    "dropout_rate": 0.2,
    "num_epochs": 500,
    "seed": 5,
    "es_patience": 150,
    "es_min_delta": 0.01,
    "es_rate_threshold": 0.00002,
    "layer_dim_ex": 3,
    "verbose": True,
    "sample": True,
    "preprocessing_type": "None",
    "variant": "original"
}

pipeline(**config_PROTEIN)
# Out:
# Initializing pipeline...
# [INFO][2025-04-16 06:46:54,349][dance][download_file] Downloading: /content/data/openproblems_bmmc_cite_phase2_mod2.zip Bytes: 625,243,451
# 100%|██████████| 596M/596M [00:36<00:00, 17.4MB/s]
# [INFO][2025-04-16 06:47:30,369][dance][unzip_file] Unzipping /content/data/openproblems_bmmc_cite_phase2_mod2.zip
# [INFO][2025-04-16 06:47:33,777][dance][delete_file] Deleting /content/data/openproblems_bmmc_cite_phase2_mod2.zip
# [INFO][2025-04-16 06:47:33,882][dance][_load_raw_data] Loading /content/data/openproblems_bmmc_cite_phase2_mod2/openproblems_bmmc_cite_phase2_mod2.censor_dataset.output_train_mod1.h5ad
# [INFO][2025-04-16 06:47:34,600][dance][_load_raw_data] Loading /content/data/openproblems_bmmc_cite_phase2_mod2/openproblems_bmmc_cite_phase2_mod2.censor_dataset.output_train_mod2.h5ad
# [INFO][2025-04-16 06:47:42,308][dance][_load_raw_data] Loading /content/data/openproblems_bmmc_cite_phase2_mod2/openproblems_bmmc_cite_phase2_mod2.censor_dataset.output_test_mod1.h5ad
# [INFO][2025-04-16 06:47:42,335][dance][_load_raw_data] Loading /content/data/openproblems_bmmc_cite_phase2_mod2/openproblems_bmmc_cite_phase2_mod2.censor_dataset.output_test_mod2.h5ad
# [INFO][2025-04-16 06:47:42,559][dance][_maybe_preprocess] Preprocessing done.
# /usr/local/lib/python3.11/dist-packages/mudata/_core/mudata.py:1531: FutureWarning: From 0.4 .update() will not pull obs/var columns from individual modalities by default anymore. Set mudata.set_options(pull_on_update=False) to adopt the new behaviour, which will become the default. Use new pull_obs/pull_var and push_obs/push_var methods for more flexibility.
#   self._update_attr("var", axis=0, join_common=join_common)
# /usr/local/lib/python3.11/dist-packages/mudata/_core/mudata.py:931: UserWarning: Cannot join columns with the same name because var_names are intersecting.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/mudata/_core/mudata.py:1429: FutureWarning: From 0.4 .update() will not pull obs/var columns from individual modalities by default anymore. Set mudata.set_options(pull_on_update=False) to adopt the new behaviour, which will become the default. Use new pull_obs/pull_var and push_obs/push_var methods for more flexibility.
#   self._update_attr("obs", axis=1, join_common=join_common)
# /usr/local/lib/python3.11/dist-packages/mudata/_core/mudata.py:1558: UserWarning: Modality names will be prepended to var_names since there are identical var_names in different modalities.
#   warnings.warn(
# [INFO][2025-04-16 06:47:52,473][dance][set_config_from_dict] Setting config 'feature_mod' to 'mod1'
# [INFO][2025-04-16 06:47:52,474][dance][set_config_from_dict] Setting config 'label_mod' to 'mod2'
# [INFO][2025-04-16 06:47:52,474][dance][load_data] Raw data loaded:
# Data object that wraps (.data):
# MuData object with n_obs × n_vars = 67175 × 14087
#   uns:	'dance_config'
#   2 modalities
#     mod1:	67175 x 134
#       obs:	'batch'
#       layers:	'counts'
#     mod2:	67175 x 13953
#       obs:	'batch'
#       layers:	'counts'
# [INFO][2025-04-16 06:47:52,591][dance][wrapped_func] Took 0:00:59.524811 to load and process data.
# Performing data processing using GraphCreator...
# Data processing using GraphCreator complete and saved.
# ---------------------------------
# Epoch 1/500
# Train RMSE: 0.3752
# Val RMSE: 0.3231, Val MAE: 0.1338
# Test RMSE: 0.3991, Test MAE: 0.1782
# ---------------------------------
# Model saved at epoch 1 with val RMSE 0.3231
# Patience grace period: 150
# ---------------------------------
# Epoch 2/500
# Train RMSE: 0.3279
# Val RMSE: 0.2953, Val MAE: 0.1278
# Test RMSE: 0.3698, Test MAE: 0.1684
# ---------------------------------
# Model saved at epoch 2 with val RMSE 0.2953
# Patience grace period: 150
# ---------------------------------
# Epoch 3/500
# Train RMSE: 0.3057
# Val RMSE: 0.2799, Val MAE: 0.1205
# Test RMSE: 0.3560, Test MAE: 0.1602
# ---------------------------------
# Model saved at epoch 3 with val RMSE 0.2799
# Patience grace period: 150
# ---------------------------------
# Epoch 4/500
# Train RMSE: 0.2923
# Val RMSE: 0.2725, Val MAE: 0.1181
# Test RMSE: 0.3492, Test MAE: 0.1577
# ---------------------------------
# Model saved at epoch 4 with val RMSE 0.2725
# Patience grace period: 149
# ---------------------------------
# Epoch 5/500
# Train RMSE: 0.2841
# Val RMSE: 0.2685, Val MAE: 0.1166
# Test RMSE: 0.3456, Test MAE: 0.1560
# ---------------------------------
# Model saved at epoch 5 with val RMSE 0.2685
# Patience grace period: 150
# ---------------------------------
# Epoch 6/500
# Train RMSE: 0.2781
# Val RMSE: 0.2654, Val MAE: 0.1152
# Test RMSE: 0.3429, Test MAE: 0.1540
# ---------------------------------
# Model saved at epoch 6 with val RMSE 0.2654
# Patience grace period: 149
# ---------------------------------
# Epoch 7/500
# Train RMSE: 0.2734
# Val RMSE: 0.2625, Val MAE: 0.1149
# Test RMSE: 0.3389, Test MAE: 0.1531
# ---------------------------------
# Model saved at epoch 7 with val RMSE 0.2625
# Patience grace period: 148
# ---------------------------------
# Epoch 8/500
# Train RMSE: 0.2696
# Val RMSE: 0.2605, Val MAE: 0.1138
# Test RMSE: 0.3369, Test MAE: 0.1516
# ---------------------------------
# Model saved at epoch 8 with val RMSE 0.2605
# Patience grace period: 147
# ---------------------------------
# Epoch 9/500
# Train RMSE: 0.2667
# Val RMSE: 0.2589, Val MAE: 0.1129
# Test RMSE: 0.3359, Test MAE: 0.1507
# ---------------------------------
# Model saved at epoch 9 with val RMSE 0.2589
# Patience grace period: 146
# ---------------------------------
# Epoch 10/500
# Train RMSE: 0.2645
# Val RMSE: 0.2577, Val MAE: 0.1122
# Test RMSE: 0.3352, Test MAE: 0.1500
# ---------------------------------
# Model saved at epoch 10 with val RMSE 0.2577
# Patience grace period: 150
# ---------------------------------
# Epoch 11/500
# Train RMSE: 0.2629
# Val RMSE: 0.2568, Val MAE: 0.1117
# Test RMSE: 0.3342, Test MAE: 0.1497
# ---------------------------------
# Model saved at epoch 11 with val RMSE 0.2568
# Patience grace period: 149
# ---------------------------------
# Epoch 12/500
# Train RMSE: 0.2616
# Val RMSE: 0.2561, Val MAE: 0.1114
# Test RMSE: 0.3337, Test MAE: 0.1494
# ---------------------------------
# Model saved at epoch 12 with val RMSE 0.2561
# Patience grace period: 148
# ---------------------------------
# Epoch 13/500
# Train RMSE: 0.2606
# Val RMSE: 0.2554, Val MAE: 0.1111
# Test RMSE: 0.3329, Test MAE: 0.1493
# ---------------------------------
# Model saved at epoch 13 with val RMSE 0.2554
# Patience grace period: 147
# ---------------------------------
# Epoch 14/500
# Train RMSE: 0.2597
# Val RMSE: 0.2549, Val MAE: 0.1108
# Test RMSE: 0.3322, Test MAE: 0.1490
# ---------------------------------
# Model saved at epoch 14 with val RMSE 0.2549
# Patience grace period: 146
# ---------------------------------
# Epoch 15/500
# Train RMSE: 0.2590
# Val RMSE: 0.2544, Val MAE: 0.1108
# Test RMSE: 0.3316, Test MAE: 0.1490
# ---------------------------------
# Model saved at epoch 15 with val RMSE 0.2544
# Patience grace period: 145
# ---------------------------------
# Epoch 16/500
# Train RMSE: 0.2583
# Val RMSE: 0.2540, Val MAE: 0.1107
# Test RMSE: 0.3307, Test MAE: 0.1491
# ---------------------------------
# Model saved at epoch 16 with val RMSE 0.2540
# Patience grace period: 144
# ---------------------------------
# Epoch 17/500
# Train RMSE: 0.2578
# Val RMSE: 0.2536, Val MAE: 0.1098
# Test RMSE: 0.3311, Test MAE: 0.1483
# ---------------------------------
# Model saved at epoch 17 with val RMSE 0.2536
# Patience grace period: 143
# ---------------------------------
# Epoch 18/500
# Train RMSE: 0.2573
# Val RMSE: 0.2533, Val MAE: 0.1092
# Test RMSE: 0.3312, Test MAE: 0.1479
# ---------------------------------
# Model saved at epoch 18 with val RMSE 0.2533
# Patience grace period: 142
# ---------------------------------
# Epoch 19/500
# Train RMSE: 0.2568
# Val RMSE: 0.2530, Val MAE: 0.1096
# Test RMSE: 0.3305, Test MAE: 0.1480
# ---------------------------------
# Model saved at epoch 19 with val RMSE 0.2530
# Patience grace period: 141
# ---------------------------------
# Epoch 20/500
# Train RMSE: 0.2564
# Val RMSE: 0.2528, Val MAE: 0.1089
# Test RMSE: 0.3308, Test MAE: 0.1476
# ---------------------------------
# Model saved at epoch 20 with val RMSE 0.2528
# Patience grace period: 140
# ---------------------------------
# Epoch 21/500
# Train RMSE: 0.2560
# Val RMSE: 0.2525, Val MAE: 0.1093
# Test RMSE: 0.3295, Test MAE: 0.1479
# ---------------------------------
# Model saved at epoch 21 with val RMSE 0.2525
# Patience grace period: 139
# ---------------------------------
# Epoch 22/500
# Train RMSE: 0.2557
# Val RMSE: 0.2523, Val MAE: 0.1086
# Test RMSE: 0.3299, Test MAE: 0.1475
# ---------------------------------
# Model saved at epoch 22 with val RMSE 0.2523
# Patience grace period: 138
# ---------------------------------
# Epoch 23/500
# Train RMSE: 0.2554
# Val RMSE: 0.2521, Val MAE: 0.1094
# Test RMSE: 0.3284, Test MAE: 0.1480
# ---------------------------------
# Model saved at epoch 23 with val RMSE 0.2521
# Patience grace period: 137
# ---------------------------------
# Epoch 24/500
# Train RMSE: 0.2551
# Val RMSE: 0.2519, Val MAE: 0.1088
# Test RMSE: 0.3292, Test MAE: 0.1477
# ---------------------------------
# Model saved at epoch 24 with val RMSE 0.2519
# Patience grace period: 136
# ---------------------------------
# Epoch 25/500
# Train RMSE: 0.2549
# Val RMSE: 0.2517, Val MAE: 0.1088
# Test RMSE: 0.3284, Test MAE: 0.1478
# ---------------------------------
# Model saved at epoch 25 with val RMSE 0.2517
# Patience grace period: 135
# ---------------------------------
# Epoch 26/500
# Train RMSE: 0.2547
# Val RMSE: 0.2516, Val MAE: 0.1088
# Test RMSE: 0.3287, Test MAE: 0.1477
# ---------------------------------
# Model saved at epoch 26 with val RMSE 0.2516
# Patience grace period: 134
# ---------------------------------
# Epoch 27/500
# Train RMSE: 0.2545
# Val RMSE: 0.2515, Val MAE: 0.1087
# Test RMSE: 0.3283, Test MAE: 0.1478
# ---------------------------------
# Model saved at epoch 27 with val RMSE 0.2515
# Patience grace period: 133
# ---------------------------------
# Epoch 28/500
# Train RMSE: 0.2542
# Val RMSE: 0.2514, Val MAE: 0.1081
# Test RMSE: 0.3293, Test MAE: 0.1476
# ---------------------------------
# Model saved at epoch 28 with val RMSE 0.2514
# Patience grace period: 132
# ---------------------------------
# Epoch 29/500
# Train RMSE: 0.2540
# Val RMSE: 0.2512, Val MAE: 0.1084
# Test RMSE: 0.3283, Test MAE: 0.1479
# ---------------------------------
# Model saved at epoch 29 with val RMSE 0.2512
# Patience grace period: 131
# ---------------------------------
# Epoch 30/500
# Train RMSE: 0.2538
# Val RMSE: 0.2511, Val MAE: 0.1081
# Test RMSE: 0.3282, Test MAE: 0.1478
# ---------------------------------
# Model saved at epoch 30 with val RMSE 0.2511
# Patience grace period: 130
# ---------------------------------
# Epoch 31/500
# Train RMSE: 0.2537
# Val RMSE: 0.2510, Val MAE: 0.1084
# Test RMSE: 0.3277, Test MAE: 0.1479
# ---------------------------------
# Model saved at epoch 31 with val RMSE 0.2510
# Patience grace period: 129
# ---------------------------------
# Epoch 32/500
# Train RMSE: 0.2535
# Val RMSE: 0.2509, Val MAE: 0.1084
# Test RMSE: 0.3277, Test MAE: 0.1480
# ---------------------------------
# Model saved at epoch 32 with val RMSE 0.2509
# Patience grace period: 128
# ---------------------------------
# Epoch 33/500
# Train RMSE: 0.2534
# Val RMSE: 0.2508, Val MAE: 0.1084
# Test RMSE: 0.3276, Test MAE: 0.1480
# ---------------------------------
# Model saved at epoch 33 with val RMSE 0.2508
# Patience grace period: 127
# ---------------------------------
# Epoch 34/500
# Train RMSE: 0.2532
# Val RMSE: 0.2507, Val MAE: 0.1077
# Test RMSE: 0.3279, Test MAE: 0.1477
# ---------------------------------
# Model saved at epoch 34 with val RMSE 0.2507
# Patience grace period: 126
# ---------------------------------
# Epoch 35/500
# Train RMSE: 0.2531
# Val RMSE: 0.2506, Val MAE: 0.1084
# Test RMSE: 0.3268, Test MAE: 0.1480
# ---------------------------------
# Model saved at epoch 35 with val RMSE 0.2506
# Patience grace period: 125
# ---------------------------------
# Epoch 36/500
# Train RMSE: 0.2529
# Val RMSE: 0.2506, Val MAE: 0.1084
# Test RMSE: 0.3269, Test MAE: 0.1483
# ---------------------------------
# Model saved at epoch 36 with val RMSE 0.2506
# Patience grace period: 124
# ---------------------------------
# Epoch 37/500
# Train RMSE: 0.2528
# Val RMSE: 0.2505, Val MAE: 0.1080
# Test RMSE: 0.3272, Test MAE: 0.1480
# ---------------------------------
# Model saved at epoch 37 with val RMSE 0.2505
# Patience grace period: 123
# ---------------------------------
# Epoch 38/500
# Train RMSE: 0.2527
# Val RMSE: 0.2504, Val MAE: 0.1082
# Test RMSE: 0.3267, Test MAE: 0.1482
# ---------------------------------
# Model saved at epoch 38 with val RMSE 0.2504
# Patience grace period: 122
# ---------------------------------
# Epoch 39/500
# Train RMSE: 0.2526
# Val RMSE: 0.2504, Val MAE: 0.1081
# Test RMSE: 0.3264, Test MAE: 0.1484
# ---------------------------------
# Model saved at epoch 39 with val RMSE 0.2504
# Patience grace period: 121
# ---------------------------------
# Epoch 40/500
# Train RMSE: 0.2525
# Val RMSE: 0.2503, Val MAE: 0.1078
# Test RMSE: 0.3269, Test MAE: 0.1482
# ---------------------------------
# Model saved at epoch 40 with val RMSE 0.2503
# Patience grace period: 120
# ---------------------------------
# Epoch 41/500
# Train RMSE: 0.2523
# Val RMSE: 0.2502, Val MAE: 0.1079
# Test RMSE: 0.3266, Test MAE: 0.1482
# ---------------------------------
# Model saved at epoch 41 with val RMSE 0.2502
# Patience grace period: 119
# ---------------------------------
# Epoch 42/500
# Train RMSE: 0.2523
# Val RMSE: 0.2502, Val MAE: 0.1080
# Test RMSE: 0.3264, Test MAE: 0.1483
# ---------------------------------
# Model saved at epoch 42 with val RMSE 0.2502
# Patience grace period: 118
# ---------------------------------
# Epoch 43/500
# Train RMSE: 0.2522
# Val RMSE: 0.2501, Val MAE: 0.1081
# Test RMSE: 0.3262, Test MAE: 0.1485
# ---------------------------------
# Model saved at epoch 43 with val RMSE 0.2501
# Patience grace period: 117
# ---------------------------------
# Epoch 44/500
# Train RMSE: 0.2521
# Val RMSE: 0.2501, Val MAE: 0.1082
# Test RMSE: 0.3256, Test MAE: 0.1488
# ---------------------------------
# Model saved at epoch 44 with val RMSE 0.2501
# Patience grace period: 116
# ---------------------------------
# Epoch 45/500
# Train RMSE: 0.2520
# Val RMSE: 0.2500, Val MAE: 0.1077
# Test RMSE: 0.3264, Test MAE: 0.1483
# ---------------------------------
# Model saved at epoch 45 with val RMSE 0.2500
# Patience grace period: 115
# ---------------------------------
# Epoch 46/500
# Train RMSE: 0.2519
# Val RMSE: 0.2500, Val MAE: 0.1080
# Test RMSE: 0.3260, Test MAE: 0.1486
# ---------------------------------
# Model saved at epoch 46 with val RMSE 0.2500
# Patience grace period: 114
# ---------------------------------
# Epoch 47/500
# Train RMSE: 0.2518
# Val RMSE: 0.2499, Val MAE: 0.1082
# Test RMSE: 0.3257, Test MAE: 0.1487
# ---------------------------------
# Model saved at epoch 47 with val RMSE 0.2499
# Patience grace period: 113
# ---------------------------------
# Epoch 48/500
# Train RMSE: 0.2517
# Val RMSE: 0.2499, Val MAE: 0.1080
# Test RMSE: 0.3256, Test MAE: 0.1486
# ---------------------------------
# Model saved at epoch 48 with val RMSE 0.2499
# Patience grace period: 112
# ---------------------------------
# Epoch 49/500
# Train RMSE: 0.2516
# Val RMSE: 0.2498, Val MAE: 0.1078
# Test RMSE: 0.3263, Test MAE: 0.1484
# ---------------------------------
# Model saved at epoch 49 with val RMSE 0.2498
# Patience grace period: 111
# ---------------------------------
# Epoch 50/500
# Train RMSE: 0.2516
# Val RMSE: 0.2498, Val MAE: 0.1080
# Test RMSE: 0.3259, Test MAE: 0.1486
# ---------------------------------
# Model saved at epoch 50 with val RMSE 0.2498
# Patience grace period: 110
# ---------------------------------
# Epoch 51/500
# Train RMSE: 0.2515
# Val RMSE: 0.2497, Val MAE: 0.1079
# Test RMSE: 0.3255, Test MAE: 0.1488
# ---------------------------------
# Model saved at epoch 51 with val RMSE 0.2497
# Patience grace period: 109
# ---------------------------------
# Epoch 52/500
# Train RMSE: 0.2514
# Val RMSE: 0.2497, Val MAE: 0.1076
# Test RMSE: 0.3258, Test MAE: 0.1487
# ---------------------------------
# Model saved at epoch 52 with val RMSE 0.2497
# Patience grace period: 108
# ---------------------------------
# Epoch 53/500
# Train RMSE: 0.2513
# Val RMSE: 0.2497, Val MAE: 0.1080
# Test RMSE: 0.3252, Test MAE: 0.1487
# ---------------------------------
# Model saved at epoch 53 with val RMSE 0.2497
# Patience grace period: 107
# ---------------------------------
# Epoch 54/500
# Train RMSE: 0.2513
# Val RMSE: 0.2496, Val MAE: 0.1079
# Test RMSE: 0.3249, Test MAE: 0.1487
# ---------------------------------
# Model saved at epoch 54 with val RMSE 0.2496
# Patience grace period: 106
# ---------------------------------
# Epoch 55/500
# Train RMSE: 0.2512
# Val RMSE: 0.2495, Val MAE: 0.1076
# Test RMSE: 0.3255, Test MAE: 0.1487
# ---------------------------------
# Model saved at epoch 55 with val RMSE 0.2495
# Patience grace period: 105
# ---------------------------------
# Epoch 56/500
# Train RMSE: 0.2511
# Val RMSE: 0.2495, Val MAE: 0.1070
# Test RMSE: 0.3258, Test MAE: 0.1484
# ---------------------------------
# Model saved at epoch 56 with val RMSE 0.2495
# Patience grace period: 104
# ---------------------------------
# Epoch 57/500
# Train RMSE: 0.2511
# Val RMSE: 0.2495, Val MAE: 0.1076
# Test RMSE: 0.3256, Test MAE: 0.1488
# ---------------------------------
# Patience grace period: 102
# ---------------------------------
# Epoch 58/500
# Train RMSE: 0.2510
# Val RMSE: 0.2494, Val MAE: 0.1074
# Test RMSE: 0.3255, Test MAE: 0.1487
# ---------------------------------
# Model saved at epoch 58 with val RMSE 0.2494
# Patience grace period: 101
# ---------------------------------
# Epoch 59/500
# Train RMSE: 0.2509
# Val RMSE: 0.2495, Val MAE: 0.1083
# Test RMSE: 0.3240, Test MAE: 0.1492
# ---------------------------------
# Patience grace period: 99
# ---------------------------------
# Epoch 60/500
# Train RMSE: 0.2509
# Val RMSE: 0.2494, Val MAE: 0.1076
# Test RMSE: 0.3252, Test MAE: 0.1488
# ---------------------------------
# Model saved at epoch 60 with val RMSE 0.2494
# Patience grace period: 98
# ---------------------------------
# Epoch 61/500
# Train RMSE: 0.2508
# Val RMSE: 0.2493, Val MAE: 0.1073
# Test RMSE: 0.3254, Test MAE: 0.1487
# ---------------------------------
# Model saved at epoch 61 with val RMSE 0.2493
# Patience grace period: 97
# ---------------------------------
# Epoch 62/500
# Train RMSE: 0.2507
# Val RMSE: 0.2493, Val MAE: 0.1074
# Test RMSE: 0.3249, Test MAE: 0.1486
# ---------------------------------
# Model saved at epoch 62 with val RMSE 0.2493
# Patience grace period: 96
# ---------------------------------
# Epoch 63/500
# Train RMSE: 0.2507
# Val RMSE: 0.2492, Val MAE: 0.1070
# Test RMSE: 0.3260, Test MAE: 0.1483
# ---------------------------------
# Model saved at epoch 63 with val RMSE 0.2492
# Patience grace period: 95
# ---------------------------------
# Epoch 64/500
# Train RMSE: 0.2506
# Val RMSE: 0.2492, Val MAE: 0.1072
# Test RMSE: 0.3256, Test MAE: 0.1486
# ---------------------------------
# Model saved at epoch 64 with val RMSE 0.2492
# Patience grace period: 94
# ---------------------------------
# Epoch 65/500
# Train RMSE: 0.2506
# Val RMSE: 0.2492, Val MAE: 0.1068
# Test RMSE: 0.3257, Test MAE: 0.1485
# ---------------------------------
# Model saved at epoch 65 with val RMSE 0.2492
# Patience grace period: 93
# ---------------------------------
# Epoch 66/500
# Train RMSE: 0.2505
# Val RMSE: 0.2491, Val MAE: 0.1071
# Test RMSE: 0.3252, Test MAE: 0.1485
# ---------------------------------
# Model saved at epoch 66 with val RMSE 0.2491
# Patience grace period: 92
# ---------------------------------
# Epoch 67/500
# Train RMSE: 0.2504
# Val RMSE: 0.2491, Val MAE: 0.1067
# Test RMSE: 0.3257, Test MAE: 0.1484
# ---------------------------------
# Model saved at epoch 67 with val RMSE 0.2491
# Patience grace period: 91
# ---------------------------------
# Epoch 68/500
# Train RMSE: 0.2504
# Val RMSE: 0.2491, Val MAE: 0.1064
# Test RMSE: 0.3266, Test MAE: 0.1483
# ---------------------------------
# Patience grace period: 89
# ---------------------------------
# Epoch 69/500
# Train RMSE: 0.2503
# Val RMSE: 0.2491, Val MAE: 0.1075
# Test RMSE: 0.3247, Test MAE: 0.1488
# ---------------------------------
# Model saved at epoch 69 with val RMSE 0.2491
# Patience grace period: 88
# ---------------------------------
# Epoch 70/500
# Train RMSE: 0.2503
# Val RMSE: 0.2490, Val MAE: 0.1069
# Test RMSE: 0.3255, Test MAE: 0.1485
# ---------------------------------
# Model saved at epoch 70 with val RMSE 0.2490
# Patience grace period: 87
# ---------------------------------
# Epoch 71/500
# Train RMSE: 0.2502
# Val RMSE: 0.2490, Val MAE: 0.1075
# Test RMSE: 0.3246, Test MAE: 0.1488
# ---------------------------------
# Patience grace period: 85
# ---------------------------------
# Epoch 72/500
# Train RMSE: 0.2502
# Val RMSE: 0.2490, Val MAE: 0.1070
# Test RMSE: 0.3250, Test MAE: 0.1486
# ---------------------------------
# Model saved at epoch 72 with val RMSE 0.2490
# Patience grace period: 84
# ---------------------------------
# Epoch 73/500
# Train RMSE: 0.2501
# Val RMSE: 0.2489, Val MAE: 0.1071
# Test RMSE: 0.3247, Test MAE: 0.1489
# ---------------------------------
# Model saved at epoch 73 with val RMSE 0.2489
# Patience grace period: 83
# ---------------------------------
# Epoch 74/500
# Train RMSE: 0.2501
# Val RMSE: 0.2489, Val MAE: 0.1063
# Test RMSE: 0.3263, Test MAE: 0.1482
# ---------------------------------
# Patience grace period: 81
# ---------------------------------
# Epoch 75/500
# Train RMSE: 0.2501
# Val RMSE: 0.2489, Val MAE: 0.1070
# Test RMSE: 0.3245, Test MAE: 0.1486
# ---------------------------------
# Model saved at epoch 75 with val RMSE 0.2489
# Patience grace period: 80
# ---------------------------------
# Epoch 76/500
# Train RMSE: 0.2500
# Val RMSE: 0.2489, Val MAE: 0.1068
# Test RMSE: 0.3252, Test MAE: 0.1486
# ---------------------------------
# Model saved at epoch 76 with val RMSE 0.2489
# Patience grace period: 79
# ---------------------------------
# Epoch 77/500
# Train RMSE: 0.2500
# Val RMSE: 0.2488, Val MAE: 0.1069
# Test RMSE: 0.3250, Test MAE: 0.1485
# ---------------------------------
# Model saved at epoch 77 with val RMSE 0.2488
# Patience grace period: 78
# ---------------------------------
# Epoch 78/500
# Train RMSE: 0.2499
# Val RMSE: 0.2488, Val MAE: 0.1068
# Test RMSE: 0.3252, Test MAE: 0.1487
# ---------------------------------
# Model saved at epoch 78 with val RMSE 0.2488
# Patience grace period: 76
# ---------------------------------
# Epoch 79/500
# Train RMSE: 0.2499
# Val RMSE: 0.2488, Val MAE: 0.1064
# Test RMSE: 0.3261, Test MAE: 0.1483
# ---------------------------------
# Model saved at epoch 79 with val RMSE 0.2488
# Patience grace period: 75
# ---------------------------------
# Epoch 80/500
# Train RMSE: 0.2499
# Val RMSE: 0.2488, Val MAE: 0.1071
# Test RMSE: 0.3247, Test MAE: 0.1488
# ---------------------------------
# Model saved at epoch 80 with val RMSE 0.2488
# Patience grace period: 74
# ---------------------------------
# Epoch 81/500
# Train RMSE: 0.2498
# Val RMSE: 0.2488, Val MAE: 0.1068
# Test RMSE: 0.3250, Test MAE: 0.1486
# ---------------------------------
# Model saved at epoch 81 with val RMSE 0.2488
# Patience grace period: 73
# ---------------------------------
# Epoch 82/500
# Train RMSE: 0.2498
# Val RMSE: 0.2487, Val MAE: 0.1064
# Test RMSE: 0.3256, Test MAE: 0.1484
# ---------------------------------
# Model saved at epoch 82 with val RMSE 0.2487
# Patience grace period: 72
# ---------------------------------
# Epoch 83/500
# Train RMSE: 0.2497
# Val RMSE: 0.2487, Val MAE: 0.1070
# Test RMSE: 0.3246, Test MAE: 0.1488
# ---------------------------------
# Model saved at epoch 83 with val RMSE 0.2487
# Patience grace period: 70
# ---------------------------------
# Epoch 84/500
# Train RMSE: 0.2497
# Val RMSE: 0.2487, Val MAE: 0.1068
# Test RMSE: 0.3249, Test MAE: 0.1487
# ---------------------------------
# Model saved at epoch 84 with val RMSE 0.2487
# Patience grace period: 69
# ---------------------------------
# Epoch 85/500
# Train RMSE: 0.2497
# Val RMSE: 0.2487, Val MAE: 0.1066
# Test RMSE: 0.3257, Test MAE: 0.1485
# ---------------------------------
# Model saved at epoch 85 with val RMSE 0.2487
# Patience grace period: 68
# ---------------------------------
# Epoch 86/500
# Train RMSE: 0.2497
# Val RMSE: 0.2487, Val MAE: 0.1076
# Test RMSE: 0.3237, Test MAE: 0.1493
# ---------------------------------
# Patience grace period: 66
# ---------------------------------
# Epoch 87/500
# Train RMSE: 0.2496
# Val RMSE: 0.2486, Val MAE: 0.1063
# Test RMSE: 0.3250, Test MAE: 0.1486
# ---------------------------------
# Model saved at epoch 87 with val RMSE 0.2486
# Patience grace period: 65
# ---------------------------------
# Epoch 88/500
# Train RMSE: 0.2496
# Val RMSE: 0.2486, Val MAE: 0.1068
# Test RMSE: 0.3245, Test MAE: 0.1489
# ---------------------------------
# Model saved at epoch 88 with val RMSE 0.2486
# Patience grace period: 64
# ---------------------------------
# Epoch 89/500
# Train RMSE: 0.2495
# Val RMSE: 0.2486, Val MAE: 0.1070
# Test RMSE: 0.3244, Test MAE: 0.1488
# ---------------------------------
# Patience grace period: 62
# ---------------------------------
# Epoch 90/500
# Train RMSE: 0.2495
# Val RMSE: 0.2486, Val MAE: 0.1069
# Test RMSE: 0.3244, Test MAE: 0.1488
# ---------------------------------
# Model saved at epoch 90 with val RMSE 0.2486
# Patience grace period: 61
# ---------------------------------
# Epoch 91/500
# Train RMSE: 0.2495
# Val RMSE: 0.2486, Val MAE: 0.1070
# Test RMSE: 0.3242, Test MAE: 0.1490
# ---------------------------------
# Patience grace period: 59
# ---------------------------------
# Epoch 92/500
# Train RMSE: 0.2494
# Val RMSE: 0.2486, Val MAE: 0.1067
# Test RMSE: 0.3247, Test MAE: 0.1491
# ---------------------------------
# Model saved at epoch 92 with val RMSE 0.2486
# Patience grace period: 58
# ---------------------------------
# Epoch 93/500
# Train RMSE: 0.2494
# Val RMSE: 0.2485, Val MAE: 0.1067
# Test RMSE: 0.3248, Test MAE: 0.1489
# ---------------------------------
# Model saved at epoch 93 with val RMSE 0.2485
# Patience grace period: 57
# ---------------------------------
# Epoch 94/500
# Train RMSE: 0.2494
# Val RMSE: 0.2485, Val MAE: 0.1063
# Test RMSE: 0.3254, Test MAE: 0.1487
# ---------------------------------
# Patience grace period: 55
# ---------------------------------
# Epoch 95/500
# Train RMSE: 0.2494
# Val RMSE: 0.2485, Val MAE: 0.1067
# Test RMSE: 0.3248, Test MAE: 0.1490
# ---------------------------------
# Model saved at epoch 95 with val RMSE 0.2485
# Patience grace period: 54
# ---------------------------------
# Epoch 96/500
# Train RMSE: 0.2493
# Val RMSE: 0.2485, Val MAE: 0.1064
# Test RMSE: 0.3255, Test MAE: 0.1487
# ---------------------------------
# Patience grace period: 52
# ---------------------------------
# Epoch 97/500
# Train RMSE: 0.2493
# Val RMSE: 0.2485, Val MAE: 0.1061
# Test RMSE: 0.3263, Test MAE: 0.1485
# ---------------------------------
# Model saved at epoch 97 with val RMSE 0.2485
# Patience grace period: 51
# ---------------------------------
# Epoch 98/500
# Train RMSE: 0.2493
# Val RMSE: 0.2485, Val MAE: 0.1063
# Test RMSE: 0.3250, Test MAE: 0.1488
# ---------------------------------
# Model saved at epoch 98 with val RMSE 0.2485
# Patience grace period: 50
# ---------------------------------
# Epoch 99/500
# Train RMSE: 0.2492
# Val RMSE: 0.2484, Val MAE: 0.1060
# Test RMSE: 0.3254, Test MAE: 0.1487
# ---------------------------------
# Model saved at epoch 99 with val RMSE 0.2484
# Patience grace period: 49
# ---------------------------------
# Epoch 100/500
# Train RMSE: 0.2492
# Val RMSE: 0.2484, Val MAE: 0.1063
# Test RMSE: 0.3250, Test MAE: 0.1490
# ---------------------------------
# Model saved at epoch 100 with val RMSE 0.2484
# Patience grace period: 48
# ---------------------------------
# Epoch 101/500
# Train RMSE: 0.2492
# Val RMSE: 0.2485, Val MAE: 0.1063
# Test RMSE: 0.3256, Test MAE: 0.1489
# ---------------------------------
# Patience grace period: 46
# ---------------------------------
# Epoch 102/500
# Train RMSE: 0.2492
# Val RMSE: 0.2485, Val MAE: 0.1070
# Test RMSE: 0.3236, Test MAE: 0.1494
# ---------------------------------
# Patience grace period: 44
# ---------------------------------
# Epoch 103/500
# Train RMSE: 0.2492
# Val RMSE: 0.2484, Val MAE: 0.1064
# Test RMSE: 0.3247, Test MAE: 0.1488
# ---------------------------------
# Model saved at epoch 103 with val RMSE 0.2484
# Patience grace period: 43
# ---------------------------------
# Epoch 104/500
# Train RMSE: 0.2491
# Val RMSE: 0.2484, Val MAE: 0.1064
# Test RMSE: 0.3247, Test MAE: 0.1492
# ---------------------------------
# Patience grace period: 41
# ---------------------------------
# Epoch 105/500
# Train RMSE: 0.2491
# Val RMSE: 0.2484, Val MAE: 0.1068
# Test RMSE: 0.3244, Test MAE: 0.1494
# ---------------------------------
# Patience grace period: 39
# ---------------------------------
# Epoch 106/500
# Train RMSE: 0.2491
# Val RMSE: 0.2484, Val MAE: 0.1065
# Test RMSE: 0.3245, Test MAE: 0.1492
# ---------------------------------
# Model saved at epoch 106 with val RMSE 0.2484
# Patience grace period: 38
# ---------------------------------
# Epoch 107/500
# Train RMSE: 0.2490
# Val RMSE: 0.2484, Val MAE: 0.1069
# Test RMSE: 0.3237, Test MAE: 0.1493
# ---------------------------------
# Patience grace period: 36
# ---------------------------------
# Epoch 108/500
# Train RMSE: 0.2490
# Val RMSE: 0.2484, Val MAE: 0.1065
# Test RMSE: 0.3246, Test MAE: 0.1489
# ---------------------------------
# Model saved at epoch 108 with val RMSE 0.2484
# Patience grace period: 35
# ---------------------------------
# Epoch 109/500
# Train RMSE: 0.2490
# Val RMSE: 0.2484, Val MAE: 0.1071
# Test RMSE: 0.3237, Test MAE: 0.1494
# ---------------------------------
# Patience grace period: 33
# ---------------------------------
# Epoch 110/500
# Train RMSE: 0.2490
# Val RMSE: 0.2483, Val MAE: 0.1062
# Test RMSE: 0.3248, Test MAE: 0.1489
# ---------------------------------
# Model saved at epoch 110 with val RMSE 0.2483
# Patience grace period: 32
# ---------------------------------
# Epoch 111/500
# Train RMSE: 0.2489
# Val RMSE: 0.2483, Val MAE: 0.1064
# Test RMSE: 0.3244, Test MAE: 0.1489
# ---------------------------------
# Patience grace period: 30
# ---------------------------------
# Epoch 112/500
# Train RMSE: 0.2489
# Val RMSE: 0.2483, Val MAE: 0.1068
# Test RMSE: 0.3238, Test MAE: 0.1493
# ---------------------------------
# Patience grace period: 28
# ---------------------------------
# Epoch 113/500
# Train RMSE: 0.2489
# Val RMSE: 0.2483, Val MAE: 0.1067
# Test RMSE: 0.3244, Test MAE: 0.1492
# ---------------------------------
# Patience grace period: 27
# ---------------------------------
# Epoch 114/500
# Train RMSE: 0.2489
# Val RMSE: 0.2484, Val MAE: 0.1071
# Test RMSE: 0.3235, Test MAE: 0.1494
# ---------------------------------
# Patience grace period: 25
# ---------------------------------
# Epoch 115/500
# Train RMSE: 0.2489
# Val RMSE: 0.2483, Val MAE: 0.1066
# Test RMSE: 0.3245, Test MAE: 0.1494
# ---------------------------------
# Patience grace period: 24
# ---------------------------------
# Epoch 116/500
# Train RMSE: 0.2488
# Val RMSE: 0.2483, Val MAE: 0.1067
# Test RMSE: 0.3237, Test MAE: 0.1495
# ---------------------------------
# Model saved at epoch 116 with val RMSE 0.2483
# Patience grace period: 23
# ---------------------------------
# Epoch 117/500
# Train RMSE: 0.2488
# Val RMSE: 0.2483, Val MAE: 0.1067
# Test RMSE: 0.3237, Test MAE: 0.1492
# ---------------------------------
# Model saved at epoch 117 with val RMSE 0.2483
# Patience grace period: 22
# ---------------------------------
# Epoch 118/500
# Train RMSE: 0.2488
# Val RMSE: 0.2483, Val MAE: 0.1071
# Test RMSE: 0.3231, Test MAE: 0.1498
# ---------------------------------
# Patience grace period: 20
# ---------------------------------
# Epoch 119/500
# Train RMSE: 0.2488
# Val RMSE: 0.2484, Val MAE: 0.1074
# Test RMSE: 0.3229, Test MAE: 0.1500
# ---------------------------------
# Patience grace period: 18
# ---------------------------------
# Epoch 120/500
# Train RMSE: 0.2488
# Val RMSE: 0.2482, Val MAE: 0.1066
# Test RMSE: 0.3243, Test MAE: 0.1492
# ---------------------------------
# Model saved at epoch 120 with val RMSE 0.2482
# Patience grace period: 17
# ---------------------------------
# Epoch 121/500
# Train RMSE: 0.2488
# Val RMSE: 0.2483, Val MAE: 0.1067
# Test RMSE: 0.3241, Test MAE: 0.1494
# ---------------------------------
# Patience grace period: 15
# ---------------------------------
# Epoch 122/500
# Train RMSE: 0.2487
# Val RMSE: 0.2482, Val MAE: 0.1066
# Test RMSE: 0.3241, Test MAE: 0.1493
# ---------------------------------
# Model saved at epoch 122 with val RMSE 0.2482
# Patience grace period: 14
# ---------------------------------
# Epoch 123/500
# Train RMSE: 0.2487
# Val RMSE: 0.2482, Val MAE: 0.1065
# Test RMSE: 0.3245, Test MAE: 0.1490
# ---------------------------------
# Patience grace period: 12
# ---------------------------------
# Epoch 124/500
# Train RMSE: 0.2487
# Val RMSE: 0.2482, Val MAE: 0.1068
# Test RMSE: 0.3241, Test MAE: 0.1497
# ---------------------------------
# Patience grace period: 10
# ---------------------------------
# Epoch 125/500
# Train RMSE: 0.2487
# Val RMSE: 0.2483, Val MAE: 0.1071
# Test RMSE: 0.3235, Test MAE: 0.1500
# ---------------------------------
# Patience grace period: 8
# ---------------------------------
# Epoch 126/500
# Train RMSE: 0.2486
# Val RMSE: 0.2483, Val MAE: 0.1072
# Test RMSE: 0.3230, Test MAE: 0.1499
# ---------------------------------
# Patience grace period: 6
# ---------------------------------
# Epoch 127/500
# Train RMSE: 0.2486
# Val RMSE: 0.2482, Val MAE: 0.1068
# Test RMSE: 0.3235, Test MAE: 0.1497
# ---------------------------------
# Model saved at epoch 127 with val RMSE 0.2482
# Patience grace period: 5
# ---------------------------------
# Epoch 128/500
# Train RMSE: 0.2486
# Val RMSE: 0.2482, Val MAE: 0.1068
# Test RMSE: 0.3234, Test MAE: 0.1498
# ---------------------------------
# Patience grace period: 3
# ---------------------------------
# Epoch 129/500
# Train RMSE: 0.2486
# Val RMSE: 0.2482, Val MAE: 0.1064
# Test RMSE: 0.3243, Test MAE: 0.1496
# ---------------------------------
# Model saved at epoch 129 with val RMSE 0.2482
# Patience grace period: 2
# ---------------------------------
# Epoch 130/500
# Train RMSE: 0.2486
# Val RMSE: 0.2482, Val MAE: 0.1063
# Test RMSE: 0.3242, Test MAE: 0.1493
# ---------------------------------
# Model saved at epoch 130 with val RMSE 0.2482
# Patience grace period: 1
# ---------------------------------
# Epoch 131/500
# Train RMSE: 0.2486
# Val RMSE: 0.2482, Val MAE: 0.1061
# Test RMSE: 0.3248, Test MAE: 0.1493
# ---------------------------------
# Patience grace period: -1
# Early stopping triggered at epoch 131
# Final Test RMSE: 0.3242, Final Test MAE: 0.1493
# <ipython-input-2-2a228d64b832>:126: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   self.model.load_state_dict(torch.load(os.path.join(save_dir, 'best_model.pth')))
# Pearson Corr: 0.7497833680875586
# Spearman Corr: 0.4308989993846295
# p-rmse: 0.32421559022030133
#        rmse       mae  seed                             subtask    method  \
# 0  0.324216  0.149305     5  openproblems_bmmc_cite_phase2_mod2  original
#
#     pearson p_value_pearson  spearman p_value_spearman
# 0  0.749783          0.0000  0.430899           0.0000

# %%
config_hierachical_PROTEIN = {
    "subtask": "openproblems_bmmc_cite_phase2_mod2",
    "batch_size": 520,
    "act": "relu",
    "conv_flow": ["gat"],
    "agg_flow": [None],
    "device": "cuda",
    "learning_rate": 0.000064,
    "hidden_size": 280,
    "num_heads": 6,
    "n_neigbours": 3,
    "metric": "euclidean",
    "n_components": 1200,
    "dropout_rate": 0.2,
    "num_epochs": 500,
    "seed": 1,
    "es_patience": 40,
    "es_min_delta": 0.0001,
    "es_rate_threshold": 0.00002,
    "layer_dim_ex": 3,
    "verbose": True,
    "sample": True,
    "preprocessing_type": "None",
    "variant": "hierarchical",
    "num_clusters": 10
}

pipeline(**config_hierachical_PROTEIN)
# Out:
# [INFO][2025-04-06 13:50:21,896][dance][_load_raw_data] Loading /content/data/openproblems_bmmc_cite_phase2_mod2/openproblems_bmmc_cite_phase2_mod2.censor_dataset.output_train_mod1.h5ad
# Initializing pipeline...
# [INFO][2025-04-06 13:50:22,516][dance][_load_raw_data] Loading /content/data/openproblems_bmmc_cite_phase2_mod2/openproblems_bmmc_cite_phase2_mod2.censor_dataset.output_train_mod2.h5ad
# [INFO][2025-04-06 13:50:29,757][dance][_load_raw_data] Loading /content/data/openproblems_bmmc_cite_phase2_mod2/openproblems_bmmc_cite_phase2_mod2.censor_dataset.output_test_mod1.h5ad
# [INFO][2025-04-06 13:50:29,779][dance][_load_raw_data] Loading /content/data/openproblems_bmmc_cite_phase2_mod2/openproblems_bmmc_cite_phase2_mod2.censor_dataset.output_test_mod2.h5ad
# [INFO][2025-04-06 13:50:29,978][dance][_maybe_preprocess] Preprocessing done.
# /usr/local/lib/python3.11/dist-packages/mudata/_core/mudata.py:1531: FutureWarning: From 0.4 .update() will not pull obs/var columns from individual modalities by default anymore. Set mudata.set_options(pull_on_update=False) to adopt the new behaviour, which will become the default. Use new pull_obs/pull_var and push_obs/push_var methods for more flexibility.
#   self._update_attr("var", axis=0, join_common=join_common)
# /usr/local/lib/python3.11/dist-packages/mudata/_core/mudata.py:931: UserWarning: Cannot join columns with the same name because var_names are intersecting.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/mudata/_core/mudata.py:1429: FutureWarning: From 0.4 .update() will not pull obs/var columns from individual modalities by default anymore. Set mudata.set_options(pull_on_update=False) to adopt the new behaviour, which will become the default. Use new pull_obs/pull_var and push_obs/push_var methods for more flexibility.
#   self._update_attr("obs", axis=1, join_common=join_common)
# /usr/local/lib/python3.11/dist-packages/mudata/_core/mudata.py:1558: UserWarning: Modality names will be prepended to var_names since there are identical var_names in different modalities.
#   warnings.warn(
# [INFO][2025-04-06 13:50:36,893][dance][set_config_from_dict] Setting config 'feature_mod' to 'mod1'
# [INFO][2025-04-06 13:50:36,894][dance][set_config_from_dict] Setting config 'label_mod' to 'mod2'
# [INFO][2025-04-06 13:50:36,895][dance][load_data] Raw data loaded:
# Data object that wraps (.data):
# MuData object with n_obs × n_vars = 67175 × 14087
#   uns:	'dance_config'
#   2 modalities
#     mod1:	67175 x 134
#       obs:	'batch'
#       layers:	'counts'
#     mod2:	67175 x 13953
#       obs:	'batch'
#       layers:	'counts'
# [INFO][2025-04-06 13:50:36,993][dance][wrapped_func] Took 0:00:15.097118 to load and process data.
# <ipython-input-4-15ebac2ab37f>:42: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   data.data.uns['gtrain'] = torch.load(train_graph_path)
# <ipython-input-4-15ebac2ab37f>:43: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   data.data.uns['gval'] = torch.load(val_graph_path)
# <ipython-input-4-15ebac2ab37f>:44: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   data.data.uns['gtest'] = torch.load(test_graph_path)
# <ipython-input-4-15ebac2ab37f>:45: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   train_label = torch.load(train_label_path).numpy()
# Processed data found. Loading...
# <ipython-input-4-15ebac2ab37f>:46: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   val_label = torch.load(val_label_path).numpy()
# <ipython-input-4-15ebac2ab37f>:47: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   test_label = torch.load(test_label_path).numpy()
# <ipython-input-4-15ebac2ab37f>:48: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   kwargs["FEATURE_SIZE"] = torch.load(feature_size_path).item()
# <ipython-input-4-15ebac2ab37f>:49: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   kwargs["OUTPUT_SIZE"] = torch.load(output_size_path).item()
# Processed data loaded.
# ---------------------------------
# Epoch 1/500
# Train RMSE: 0.3746
# Val RMSE: 0.3226, Val MAE: 0.1327
# Test RMSE: 0.3987, Test MAE: 0.1774
# ---------------------------------
# Model saved at epoch 1 with val RMSE 0.3226
# Patience grace period: 150
# ---------------------------------
# Epoch 2/500
# Train RMSE: 0.3272
# Val RMSE: 0.2947, Val MAE: 0.1279
# Test RMSE: 0.3672, Test MAE: 0.1693
# ---------------------------------
# Model saved at epoch 2 with val RMSE 0.2947
# Patience grace period: 150
# ---------------------------------
# Epoch 3/500
# Train RMSE: 0.3056
# Val RMSE: 0.2792, Val MAE: 0.1212
# Test RMSE: 0.3519, Test MAE: 0.1619
# ---------------------------------
# Model saved at epoch 3 with val RMSE 0.2792
# Patience grace period: 150
# ---------------------------------
# Epoch 4/500
# Train RMSE: 0.2922
# Val RMSE: 0.2719, Val MAE: 0.1182
# Test RMSE: 0.3454, Test MAE: 0.1591
# ---------------------------------
# Model saved at epoch 4 with val RMSE 0.2719
# Patience grace period: 149
# ---------------------------------
# Epoch 5/500
# Train RMSE: 0.2838
# Val RMSE: 0.2676, Val MAE: 0.1168
# Test RMSE: 0.3412, Test MAE: 0.1574
# ---------------------------------
# Model saved at epoch 5 with val RMSE 0.2676
# Patience grace period: 150
# ---------------------------------
# Epoch 6/500
# Train RMSE: 0.2777
# Val RMSE: 0.2645, Val MAE: 0.1154
# Test RMSE: 0.3378, Test MAE: 0.1554
# ---------------------------------
# Model saved at epoch 6 with val RMSE 0.2645
# Patience grace period: 149
# ---------------------------------
# Epoch 7/500
# Train RMSE: 0.2730
# Val RMSE: 0.2620, Val MAE: 0.1147
# Test RMSE: 0.3349, Test MAE: 0.1546
# ---------------------------------
# Model saved at epoch 7 with val RMSE 0.2620
# Patience grace period: 148
# ---------------------------------
# Epoch 8/500
# Train RMSE: 0.2694
# Val RMSE: 0.2602, Val MAE: 0.1132
# Test RMSE: 0.3335, Test MAE: 0.1530
# ---------------------------------
# Model saved at epoch 8 with val RMSE 0.2602
# Patience grace period: 147
# ---------------------------------
# Epoch 9/500
# Train RMSE: 0.2665
# Val RMSE: 0.2588, Val MAE: 0.1122
# Test RMSE: 0.3323, Test MAE: 0.1520
# ---------------------------------
# Model saved at epoch 9 with val RMSE 0.2588
# Patience grace period: 146
# ---------------------------------
# Epoch 10/500
# Train RMSE: 0.2644
# Val RMSE: 0.2577, Val MAE: 0.1113
# Test RMSE: 0.3315, Test MAE: 0.1513
# ---------------------------------
# Model saved at epoch 10 with val RMSE 0.2577
# Patience grace period: 145
# ---------------------------------
# Epoch 11/500
# Train RMSE: 0.2627
# Val RMSE: 0.2569, Val MAE: 0.1105
# Test RMSE: 0.3310, Test MAE: 0.1508
# ---------------------------------
# Model saved at epoch 11 with val RMSE 0.2569
# Patience grace period: 150
# ---------------------------------
# Epoch 12/500
# Train RMSE: 0.2615
# Val RMSE: 0.2561, Val MAE: 0.1107
# Test RMSE: 0.3300, Test MAE: 0.1509
# ---------------------------------
# Model saved at epoch 12 with val RMSE 0.2561
# Patience grace period: 149
# ---------------------------------
# Epoch 13/500
# Train RMSE: 0.2605
# Val RMSE: 0.2555, Val MAE: 0.1108
# Test RMSE: 0.3290, Test MAE: 0.1513
# ---------------------------------
# Model saved at epoch 13 with val RMSE 0.2555
# Patience grace period: 148
# ---------------------------------
# Epoch 14/500
# Train RMSE: 0.2597
# Val RMSE: 0.2550, Val MAE: 0.1096
# Test RMSE: 0.3290, Test MAE: 0.1502
# ---------------------------------
# Model saved at epoch 14 with val RMSE 0.2550
# Patience grace period: 147
# ---------------------------------
# Epoch 15/500
# Train RMSE: 0.2590
# Val RMSE: 0.2546, Val MAE: 0.1092
# Test RMSE: 0.3286, Test MAE: 0.1498
# ---------------------------------
# Model saved at epoch 15 with val RMSE 0.2546
# Patience grace period: 146
# ---------------------------------
# Epoch 16/500
# Train RMSE: 0.2584
# Val RMSE: 0.2541, Val MAE: 0.1096
# Test RMSE: 0.3275, Test MAE: 0.1503
# ---------------------------------
# Model saved at epoch 16 with val RMSE 0.2541
# Patience grace period: 145
# ---------------------------------
# Epoch 17/500
# Train RMSE: 0.2579
# Val RMSE: 0.2537, Val MAE: 0.1099
# Test RMSE: 0.3265, Test MAE: 0.1506
# ---------------------------------
# Model saved at epoch 17 with val RMSE 0.2537
# Patience grace period: 144
# ---------------------------------
# Epoch 18/500
# Train RMSE: 0.2574
# Val RMSE: 0.2535, Val MAE: 0.1090
# Test RMSE: 0.3268, Test MAE: 0.1499
# ---------------------------------
# Model saved at epoch 18 with val RMSE 0.2535
# Patience grace period: 143
# ---------------------------------
# Epoch 19/500
# Train RMSE: 0.2570
# Val RMSE: 0.2533, Val MAE: 0.1092
# Test RMSE: 0.3266, Test MAE: 0.1498
# ---------------------------------
# Model saved at epoch 19 with val RMSE 0.2533
# Patience grace period: 142
# ---------------------------------
# Epoch 20/500
# Train RMSE: 0.2566
# Val RMSE: 0.2530, Val MAE: 0.1092
# Test RMSE: 0.3261, Test MAE: 0.1499
# ---------------------------------
# Model saved at epoch 20 with val RMSE 0.2530
# Patience grace period: 141
# ---------------------------------
# Epoch 21/500
# Train RMSE: 0.2563
# Val RMSE: 0.2528, Val MAE: 0.1087
# Test RMSE: 0.3260, Test MAE: 0.1495
# ---------------------------------
# Model saved at epoch 21 with val RMSE 0.2528
# Patience grace period: 140
# ---------------------------------
# Epoch 22/500
# Train RMSE: 0.2560
# Val RMSE: 0.2526, Val MAE: 0.1092
# Test RMSE: 0.3254, Test MAE: 0.1501
# ---------------------------------
# Model saved at epoch 22 with val RMSE 0.2526
# Patience grace period: 139
# ---------------------------------
# Epoch 23/500
# Train RMSE: 0.2557
# Val RMSE: 0.2524, Val MAE: 0.1090
# Test RMSE: 0.3252, Test MAE: 0.1499
# ---------------------------------
# Model saved at epoch 23 with val RMSE 0.2524
# Patience grace period: 138
# ---------------------------------
# Epoch 24/500
# Train RMSE: 0.2554
# Val RMSE: 0.2522, Val MAE: 0.1083
# Test RMSE: 0.3254, Test MAE: 0.1493
# ---------------------------------
# Model saved at epoch 24 with val RMSE 0.2522
# Patience grace period: 137
# ---------------------------------
# Epoch 25/500
# Train RMSE: 0.2552
# Val RMSE: 0.2521, Val MAE: 0.1087
# Test RMSE: 0.3249, Test MAE: 0.1498
# ---------------------------------
# Model saved at epoch 25 with val RMSE 0.2521
# Patience grace period: 136
# ---------------------------------
# Epoch 26/500
# Train RMSE: 0.2549
# Val RMSE: 0.2519, Val MAE: 0.1085
# Test RMSE: 0.3250, Test MAE: 0.1493
# ---------------------------------
# Model saved at epoch 26 with val RMSE 0.2519
# Patience grace period: 135
# ---------------------------------
# Epoch 27/500
# Train RMSE: 0.2547
# Val RMSE: 0.2518, Val MAE: 0.1083
# Test RMSE: 0.3248, Test MAE: 0.1495
# ---------------------------------
# Model saved at epoch 27 with val RMSE 0.2518
# Patience grace period: 134
# ---------------------------------
# Epoch 28/500
# Train RMSE: 0.2545
# Val RMSE: 0.2517, Val MAE: 0.1077
# Test RMSE: 0.3251, Test MAE: 0.1489
# ---------------------------------
# Model saved at epoch 28 with val RMSE 0.2517
# Patience grace period: 133
# ---------------------------------
# Epoch 29/500
# Train RMSE: 0.2543
# Val RMSE: 0.2515, Val MAE: 0.1076
# Test RMSE: 0.3248, Test MAE: 0.1489
# ---------------------------------
# Model saved at epoch 29 with val RMSE 0.2515
# Patience grace period: 132
# ---------------------------------
# Epoch 30/500
# Train RMSE: 0.2541
# Val RMSE: 0.2514, Val MAE: 0.1082
# Test RMSE: 0.3239, Test MAE: 0.1494
# ---------------------------------
# Model saved at epoch 30 with val RMSE 0.2514
# Patience grace period: 131
# ---------------------------------
# Epoch 31/500
# Train RMSE: 0.2540
# Val RMSE: 0.2514, Val MAE: 0.1079
# Test RMSE: 0.3243, Test MAE: 0.1493
# ---------------------------------
# Patience grace period: 129
# ---------------------------------
# Epoch 32/500
# Train RMSE: 0.2539
# Val RMSE: 0.2512, Val MAE: 0.1078
# Test RMSE: 0.3239, Test MAE: 0.1492
# ---------------------------------
# Model saved at epoch 32 with val RMSE 0.2512
# Patience grace period: 128
# ---------------------------------
# Epoch 33/500
# Train RMSE: 0.2537
# Val RMSE: 0.2511, Val MAE: 0.1078
# Test RMSE: 0.3238, Test MAE: 0.1493
# ---------------------------------
# Model saved at epoch 33 with val RMSE 0.2511
# Patience grace period: 127
# ---------------------------------
# Epoch 34/500
# Train RMSE: 0.2535
# Val RMSE: 0.2511, Val MAE: 0.1074
# Test RMSE: 0.3246, Test MAE: 0.1489
# ---------------------------------
# Model saved at epoch 34 with val RMSE 0.2511
# Patience grace period: 125
# ---------------------------------
# Epoch 35/500
# Train RMSE: 0.2533
# Val RMSE: 0.2509, Val MAE: 0.1075
# Test RMSE: 0.3240, Test MAE: 0.1488
# ---------------------------------
# Model saved at epoch 35 with val RMSE 0.2509
# Patience grace period: 124
# ---------------------------------
# Epoch 36/500
# Train RMSE: 0.2532
# Val RMSE: 0.2509, Val MAE: 0.1074
# Test RMSE: 0.3238, Test MAE: 0.1490
# ---------------------------------
# Model saved at epoch 36 with val RMSE 0.2509
# Patience grace period: 123
# ---------------------------------
# Epoch 37/500
# Train RMSE: 0.2530
# Val RMSE: 0.2508, Val MAE: 0.1073
# Test RMSE: 0.3242, Test MAE: 0.1487
# ---------------------------------
# Model saved at epoch 37 with val RMSE 0.2508
# Patience grace period: 122
# ---------------------------------
# Epoch 38/500
# Train RMSE: 0.2529
# Val RMSE: 0.2507, Val MAE: 0.1072
# Test RMSE: 0.3241, Test MAE: 0.1486
# ---------------------------------
# Model saved at epoch 38 with val RMSE 0.2507
# Patience grace period: 121
# ---------------------------------
# Epoch 39/500
# Train RMSE: 0.2528
# Val RMSE: 0.2507, Val MAE: 0.1070
# Test RMSE: 0.3240, Test MAE: 0.1485
# ---------------------------------
# Model saved at epoch 39 with val RMSE 0.2507
# Patience grace period: 120
# ---------------------------------
# Epoch 40/500
# Train RMSE: 0.2527
# Val RMSE: 0.2506, Val MAE: 0.1072
# Test RMSE: 0.3237, Test MAE: 0.1487
# ---------------------------------
# Model saved at epoch 40 with val RMSE 0.2506
# Patience grace period: 119
# ---------------------------------
# Epoch 41/500
# Train RMSE: 0.2526
# Val RMSE: 0.2504, Val MAE: 0.1078
# Test RMSE: 0.3232, Test MAE: 0.1495
# ---------------------------------
# Model saved at epoch 41 with val RMSE 0.2504
# Patience grace period: 118
# ---------------------------------
# Epoch 42/500
# Train RMSE: 0.2525
# Val RMSE: 0.2505, Val MAE: 0.1067
# Test RMSE: 0.3240, Test MAE: 0.1483
# ---------------------------------
# Patience grace period: 116
# ---------------------------------
# Epoch 43/500
# Train RMSE: 0.2524
# Val RMSE: 0.2503, Val MAE: 0.1073
# Test RMSE: 0.3234, Test MAE: 0.1491
# ---------------------------------
# Model saved at epoch 43 with val RMSE 0.2503
# Patience grace period: 115
# ---------------------------------
# Epoch 44/500
# Train RMSE: 0.2523
# Val RMSE: 0.2503, Val MAE: 0.1071
# Test RMSE: 0.3233, Test MAE: 0.1490
# ---------------------------------
# Model saved at epoch 44 with val RMSE 0.2503
# Patience grace period: 114
# ---------------------------------
# Epoch 45/500
# Train RMSE: 0.2522
# Val RMSE: 0.2502, Val MAE: 0.1068
# Test RMSE: 0.3235, Test MAE: 0.1485
# ---------------------------------
# Model saved at epoch 45 with val RMSE 0.2502
# Patience grace period: 113
# ---------------------------------
# Epoch 46/500
# Train RMSE: 0.2521
# Val RMSE: 0.2502, Val MAE: 0.1072
# Test RMSE: 0.3230, Test MAE: 0.1490
# ---------------------------------
# Model saved at epoch 46 with val RMSE 0.2502
# Patience grace period: 112
# ---------------------------------
# Epoch 47/500
# Train RMSE: 0.2520
# Val RMSE: 0.2501, Val MAE: 0.1066
# Test RMSE: 0.3235, Test MAE: 0.1483
# ---------------------------------
# Model saved at epoch 47 with val RMSE 0.2501
# Patience grace period: 111
# ---------------------------------
# Epoch 48/500
# Train RMSE: 0.2519
# Val RMSE: 0.2500, Val MAE: 0.1073
# Test RMSE: 0.3227, Test MAE: 0.1490
# ---------------------------------
# Model saved at epoch 48 with val RMSE 0.2500
# Patience grace period: 110
# ---------------------------------
# Epoch 49/500
# Train RMSE: 0.2518
# Val RMSE: 0.2500, Val MAE: 0.1070
# Test RMSE: 0.3231, Test MAE: 0.1487
# ---------------------------------
# Model saved at epoch 49 with val RMSE 0.2500
# Patience grace period: 109
# ---------------------------------
# Epoch 50/500
# Train RMSE: 0.2518
# Val RMSE: 0.2501, Val MAE: 0.1062
# Test RMSE: 0.3240, Test MAE: 0.1480
# ---------------------------------
# Patience grace period: 107
# ---------------------------------
# Epoch 51/500
# Train RMSE: 0.2516
# Val RMSE: 0.2499, Val MAE: 0.1074
# Test RMSE: 0.3225, Test MAE: 0.1490
# ---------------------------------
# Model saved at epoch 51 with val RMSE 0.2499
# Patience grace period: 106
# ---------------------------------
# Epoch 52/500
# Train RMSE: 0.2516
# Val RMSE: 0.2499, Val MAE: 0.1063
# Test RMSE: 0.3235, Test MAE: 0.1480
# ---------------------------------
# Patience grace period: 104
# ---------------------------------
# Epoch 53/500
# Train RMSE: 0.2515
# Val RMSE: 0.2499, Val MAE: 0.1065
# Test RMSE: 0.3232, Test MAE: 0.1482
# ---------------------------------
# Patience grace period: 103
# ---------------------------------
# Epoch 54/500
# Train RMSE: 0.2514
# Val RMSE: 0.2497, Val MAE: 0.1072
# Test RMSE: 0.3223, Test MAE: 0.1489
# ---------------------------------
# Model saved at epoch 54 with val RMSE 0.2497
# Patience grace period: 102
# ---------------------------------
# Epoch 55/500
# Train RMSE: 0.2513
# Val RMSE: 0.2497, Val MAE: 0.1065
# Test RMSE: 0.3231, Test MAE: 0.1483
# ---------------------------------
# Model saved at epoch 55 with val RMSE 0.2497
# Patience grace period: 101
# ---------------------------------
# Epoch 56/500
# Train RMSE: 0.2513
# Val RMSE: 0.2497, Val MAE: 0.1066
# Test RMSE: 0.3229, Test MAE: 0.1483
# ---------------------------------
# Model saved at epoch 56 with val RMSE 0.2497
# Patience grace period: 100
# ---------------------------------
# Epoch 57/500
# Train RMSE: 0.2512
# Val RMSE: 0.2496, Val MAE: 0.1069
# Test RMSE: 0.3224, Test MAE: 0.1484
# ---------------------------------
# Model saved at epoch 57 with val RMSE 0.2496
# Patience grace period: 99
# ---------------------------------
# Epoch 58/500
# Train RMSE: 0.2511
# Val RMSE: 0.2496, Val MAE: 0.1068
# Test RMSE: 0.3226, Test MAE: 0.1485
# ---------------------------------
# Patience grace period: 97
# ---------------------------------
# Epoch 59/500
# Train RMSE: 0.2510
# Val RMSE: 0.2495, Val MAE: 0.1065
# Test RMSE: 0.3229, Test MAE: 0.1481
# ---------------------------------
# Model saved at epoch 59 with val RMSE 0.2495
# Patience grace period: 96
# ---------------------------------
# Epoch 60/500
# Train RMSE: 0.2510
# Val RMSE: 0.2495, Val MAE: 0.1072
# Test RMSE: 0.3219, Test MAE: 0.1490
# ---------------------------------
# Model saved at epoch 60 with val RMSE 0.2495
# Patience grace period: 95
# ---------------------------------
# Epoch 61/500
# Train RMSE: 0.2509
# Val RMSE: 0.2495, Val MAE: 0.1068
# Test RMSE: 0.3222, Test MAE: 0.1487
# ---------------------------------
# Model saved at epoch 61 with val RMSE 0.2495
# Patience grace period: 94
# ---------------------------------
# Epoch 62/500
# Train RMSE: 0.2509
# Val RMSE: 0.2494, Val MAE: 0.1067
# Test RMSE: 0.3225, Test MAE: 0.1486
# ---------------------------------
# Model saved at epoch 62 with val RMSE 0.2494
# Patience grace period: 93
# ---------------------------------
# Epoch 63/500
# Train RMSE: 0.2508
# Val RMSE: 0.2494, Val MAE: 0.1066
# Test RMSE: 0.3226, Test MAE: 0.1481
# ---------------------------------
# Model saved at epoch 63 with val RMSE 0.2494
# Patience grace period: 92
# ---------------------------------
# Epoch 64/500
# Train RMSE: 0.2507
# Val RMSE: 0.2494, Val MAE: 0.1064
# Test RMSE: 0.3229, Test MAE: 0.1480
# ---------------------------------
# Patience grace period: 90
# ---------------------------------
# Epoch 65/500
# Train RMSE: 0.2507
# Val RMSE: 0.2494, Val MAE: 0.1058
# Test RMSE: 0.3232, Test MAE: 0.1477
# ---------------------------------
# Patience grace period: 89
# ---------------------------------
# Epoch 66/500
# Train RMSE: 0.2507
# Val RMSE: 0.2493, Val MAE: 0.1065
# Test RMSE: 0.3225, Test MAE: 0.1481
# ---------------------------------
# Model saved at epoch 66 with val RMSE 0.2493
# Patience grace period: 88
# ---------------------------------
# Epoch 67/500
# Train RMSE: 0.2506
# Val RMSE: 0.2492, Val MAE: 0.1064
# Test RMSE: 0.3225, Test MAE: 0.1480
# ---------------------------------
# Model saved at epoch 67 with val RMSE 0.2492
# Patience grace period: 87
# ---------------------------------
# Epoch 68/500
# Train RMSE: 0.2505
# Val RMSE: 0.2493, Val MAE: 0.1062
# Test RMSE: 0.3229, Test MAE: 0.1479
# ---------------------------------
# Patience grace period: 85
# ---------------------------------
# Epoch 69/500
# Train RMSE: 0.2505
# Val RMSE: 0.2492, Val MAE: 0.1070
# Test RMSE: 0.3218, Test MAE: 0.1486
# ---------------------------------
# Model saved at epoch 69 with val RMSE 0.2492
# Patience grace period: 84
# ---------------------------------
# Epoch 70/500
# Train RMSE: 0.2504
# Val RMSE: 0.2492, Val MAE: 0.1065
# Test RMSE: 0.3224, Test MAE: 0.1483
# ---------------------------------
# Patience grace period: 82
# ---------------------------------
# Epoch 71/500
# Train RMSE: 0.2504
# Val RMSE: 0.2492, Val MAE: 0.1064
# Test RMSE: 0.3224, Test MAE: 0.1481
# ---------------------------------
# Model saved at epoch 71 with val RMSE 0.2492
# Patience grace period: 81
# ---------------------------------
# Epoch 72/500
# Train RMSE: 0.2504
# Val RMSE: 0.2491, Val MAE: 0.1066
# Test RMSE: 0.3223, Test MAE: 0.1482
# ---------------------------------
# Model saved at epoch 72 with val RMSE 0.2491
# Patience grace period: 80
# ---------------------------------
# Epoch 73/500
# Train RMSE: 0.2503
# Val RMSE: 0.2492, Val MAE: 0.1059
# Test RMSE: 0.3229, Test MAE: 0.1477
# ---------------------------------
# Patience grace period: 78
# ---------------------------------
# Epoch 74/500
# Train RMSE: 0.2502
# Val RMSE: 0.2491, Val MAE: 0.1069
# Test RMSE: 0.3215, Test MAE: 0.1485
# ---------------------------------
# Patience grace period: 77
# ---------------------------------
# Epoch 75/500
# Train RMSE: 0.2502
# Val RMSE: 0.2490, Val MAE: 0.1061
# Test RMSE: 0.3225, Test MAE: 0.1478
# ---------------------------------
# Model saved at epoch 75 with val RMSE 0.2490
# Patience grace period: 76
# ---------------------------------
# Epoch 76/500
# Train RMSE: 0.2502
# Val RMSE: 0.2489, Val MAE: 0.1071
# Test RMSE: 0.3214, Test MAE: 0.1488
# ---------------------------------
# Model saved at epoch 76 with val RMSE 0.2489
# Patience grace period: 75
# ---------------------------------
# Epoch 77/500
# Train RMSE: 0.2501
# Val RMSE: 0.2490, Val MAE: 0.1070
# Test RMSE: 0.3215, Test MAE: 0.1487
# ---------------------------------
# Patience grace period: 73
# ---------------------------------
# Epoch 78/500
# Train RMSE: 0.2501
# Val RMSE: 0.2490, Val MAE: 0.1061
# Test RMSE: 0.3224, Test MAE: 0.1479
# ---------------------------------
# Patience grace period: 71
# ---------------------------------
# Epoch 79/500
# Train RMSE: 0.2501
# Val RMSE: 0.2489, Val MAE: 0.1065
# Test RMSE: 0.3220, Test MAE: 0.1481
# ---------------------------------
# Model saved at epoch 79 with val RMSE 0.2489
# Patience grace period: 70
# ---------------------------------
# Epoch 80/500
# Train RMSE: 0.2500
# Val RMSE: 0.2490, Val MAE: 0.1061
# Test RMSE: 0.3222, Test MAE: 0.1480
# ---------------------------------
# Patience grace period: 68
# ---------------------------------
# Epoch 81/500
# Train RMSE: 0.2500
# Val RMSE: 0.2489, Val MAE: 0.1062
# Test RMSE: 0.3223, Test MAE: 0.1481
# ---------------------------------
# Patience grace period: 67
# ---------------------------------
# Epoch 82/500
# Train RMSE: 0.2499
# Val RMSE: 0.2488, Val MAE: 0.1064
# Test RMSE: 0.3219, Test MAE: 0.1482
# ---------------------------------
# Model saved at epoch 82 with val RMSE 0.2488
# Patience grace period: 66
# ---------------------------------
# Epoch 83/500
# Train RMSE: 0.2499
# Val RMSE: 0.2489, Val MAE: 0.1064
# Test RMSE: 0.3218, Test MAE: 0.1484
# ---------------------------------
# Patience grace period: 64
# ---------------------------------
# Epoch 84/500
# Train RMSE: 0.2499
# Val RMSE: 0.2488, Val MAE: 0.1071
# Test RMSE: 0.3209, Test MAE: 0.1488
# ---------------------------------
# Model saved at epoch 84 with val RMSE 0.2488
# Patience grace period: 63
# ---------------------------------
# Epoch 85/500
# Train RMSE: 0.2498
# Val RMSE: 0.2488, Val MAE: 0.1062
# Test RMSE: 0.3220, Test MAE: 0.1478
# ---------------------------------
# Model saved at epoch 85 with val RMSE 0.2488
# Patience grace period: 62
# ---------------------------------
# Epoch 86/500
# Train RMSE: 0.2498
# Val RMSE: 0.2487, Val MAE: 0.1064
# Test RMSE: 0.3215, Test MAE: 0.1482
# ---------------------------------
# Model saved at epoch 86 with val RMSE 0.2487
# Patience grace period: 61
# ---------------------------------
# Epoch 87/500
# Train RMSE: 0.2498
# Val RMSE: 0.2488, Val MAE: 0.1062
# Test RMSE: 0.3221, Test MAE: 0.1479
# ---------------------------------
# Patience grace period: 59
# ---------------------------------
# Epoch 88/500
# Train RMSE: 0.2497
# Val RMSE: 0.2487, Val MAE: 0.1066
# Test RMSE: 0.3215, Test MAE: 0.1482
# ---------------------------------
# Model saved at epoch 88 with val RMSE 0.2487
# Patience grace period: 58
# ---------------------------------
# Epoch 89/500
# Train RMSE: 0.2497
# Val RMSE: 0.2487, Val MAE: 0.1063
# Test RMSE: 0.3218, Test MAE: 0.1482
# ---------------------------------
# Patience grace period: 56
# ---------------------------------
# Epoch 90/500
# Train RMSE: 0.2497
# Val RMSE: 0.2487, Val MAE: 0.1062
# Test RMSE: 0.3220, Test MAE: 0.1481
# ---------------------------------
# Patience grace period: 55
# ---------------------------------
# Epoch 91/500
# Train RMSE: 0.2496
# Val RMSE: 0.2487, Val MAE: 0.1065
# Test RMSE: 0.3214, Test MAE: 0.1484
# ---------------------------------
# Model saved at epoch 91 with val RMSE 0.2487
# Patience grace period: 54
# ---------------------------------
# Epoch 92/500
# Train RMSE: 0.2496
# Val RMSE: 0.2486, Val MAE: 0.1061
# Test RMSE: 0.3217, Test MAE: 0.1479
# ---------------------------------
# Model saved at epoch 92 with val RMSE 0.2486
# Patience grace period: 53
# ---------------------------------
# Epoch 93/500
# Train RMSE: 0.2496
# Val RMSE: 0.2486, Val MAE: 0.1060
# Test RMSE: 0.3220, Test MAE: 0.1479
# ---------------------------------
# Patience grace period: 51
# ---------------------------------
# Epoch 94/500
# Train RMSE: 0.2495
# Val RMSE: 0.2487, Val MAE: 0.1063
# Test RMSE: 0.3217, Test MAE: 0.1483
# ---------------------------------
# Patience grace period: 49
# ---------------------------------
# Epoch 95/500
# Train RMSE: 0.2495
# Val RMSE: 0.2486, Val MAE: 0.1071
# Test RMSE: 0.3206, Test MAE: 0.1491
# ---------------------------------
# Patience grace period: 48
# ---------------------------------
# Epoch 96/500
# Train RMSE: 0.2495
# Val RMSE: 0.2486, Val MAE: 0.1070
# Test RMSE: 0.3206, Test MAE: 0.1491
# ---------------------------------
# Model saved at epoch 96 with val RMSE 0.2486
# Patience grace period: 47
# ---------------------------------
# Epoch 97/500
# Train RMSE: 0.2495
# Val RMSE: 0.2485, Val MAE: 0.1066
# Test RMSE: 0.3212, Test MAE: 0.1486
# ---------------------------------
# Model saved at epoch 97 with val RMSE 0.2485
# Patience grace period: 46
# ---------------------------------
# Epoch 98/500
# Train RMSE: 0.2495
# Val RMSE: 0.2485, Val MAE: 0.1065
# Test RMSE: 0.3213, Test MAE: 0.1484
# ---------------------------------
# Patience grace period: 44
# ---------------------------------
# Epoch 99/500
# Train RMSE: 0.2494
# Val RMSE: 0.2486, Val MAE: 0.1071
# Test RMSE: 0.3205, Test MAE: 0.1493
# ---------------------------------
# Patience grace period: 42
# ---------------------------------
# Epoch 100/500
# Train RMSE: 0.2494
# Val RMSE: 0.2486, Val MAE: 0.1060
# Test RMSE: 0.3220, Test MAE: 0.1479
# ---------------------------------
# Patience grace period: 40
# ---------------------------------
# Epoch 101/500
# Train RMSE: 0.2494
# Val RMSE: 0.2486, Val MAE: 0.1061
# Test RMSE: 0.3219, Test MAE: 0.1480
# ---------------------------------
# Patience grace period: 38
# ---------------------------------
# Epoch 102/500
# Train RMSE: 0.2494
# Val RMSE: 0.2485, Val MAE: 0.1063
# Test RMSE: 0.3214, Test MAE: 0.1484
# ---------------------------------
# Model saved at epoch 102 with val RMSE 0.2485
# Patience grace period: 37
# ---------------------------------
# Epoch 103/500
# Train RMSE: 0.2493
# Val RMSE: 0.2485, Val MAE: 0.1064
# Test RMSE: 0.3211, Test MAE: 0.1484
# ---------------------------------
# Model saved at epoch 103 with val RMSE 0.2485
# Patience grace period: 36
# ---------------------------------
# Epoch 104/500
# Train RMSE: 0.2493
# Val RMSE: 0.2485, Val MAE: 0.1065
# Test RMSE: 0.3211, Test MAE: 0.1486
# ---------------------------------
# Patience grace period: 34
# ---------------------------------
# Epoch 105/500
# Train RMSE: 0.2493
# Val RMSE: 0.2485, Val MAE: 0.1057
# Test RMSE: 0.3217, Test MAE: 0.1478
# ---------------------------------
# Model saved at epoch 105 with val RMSE 0.2485
# Patience grace period: 33
# ---------------------------------
# Epoch 106/500
# Train RMSE: 0.2492
# Val RMSE: 0.2484, Val MAE: 0.1069
# Test RMSE: 0.3203, Test MAE: 0.1492
# ---------------------------------
# Model saved at epoch 106 with val RMSE 0.2484
# Patience grace period: 32
# ---------------------------------
# Epoch 107/500
# Train RMSE: 0.2492
# Val RMSE: 0.2485, Val MAE: 0.1065
# Test RMSE: 0.3209, Test MAE: 0.1487
# ---------------------------------
# Patience grace period: 30
# ---------------------------------
# Epoch 108/500
# Train RMSE: 0.2492
# Val RMSE: 0.2483, Val MAE: 0.1065
# Test RMSE: 0.3207, Test MAE: 0.1486
# ---------------------------------
# Model saved at epoch 108 with val RMSE 0.2483
# Patience grace period: 29
# ---------------------------------
# Epoch 109/500
# Train RMSE: 0.2491
# Val RMSE: 0.2484, Val MAE: 0.1062
# Test RMSE: 0.3212, Test MAE: 0.1485
# ---------------------------------
# Patience grace period: 27
# ---------------------------------
# Epoch 110/500
# Train RMSE: 0.2491
# Val RMSE: 0.2484, Val MAE: 0.1058
# Test RMSE: 0.3214, Test MAE: 0.1481
# ---------------------------------
# Patience grace period: 26
# ---------------------------------
# Epoch 111/500
# Train RMSE: 0.2491
# Val RMSE: 0.2484, Val MAE: 0.1058
# Test RMSE: 0.3220, Test MAE: 0.1478
# ---------------------------------
# Patience grace period: 24
# ---------------------------------
# Epoch 112/500
# Train RMSE: 0.2491
# Val RMSE: 0.2484, Val MAE: 0.1069
# Test RMSE: 0.3203, Test MAE: 0.1492
# ---------------------------------
# Patience grace period: 22
# ---------------------------------
# Epoch 113/500
# Train RMSE: 0.2491
# Val RMSE: 0.2483, Val MAE: 0.1062
# Test RMSE: 0.3215, Test MAE: 0.1483
# ---------------------------------
# Patience grace period: 21
# ---------------------------------
# Epoch 114/500
# Train RMSE: 0.2490
# Val RMSE: 0.2484, Val MAE: 0.1059
# Test RMSE: 0.3216, Test MAE: 0.1482
# ---------------------------------
# Patience grace period: 19
# ---------------------------------
# Epoch 115/500
# Train RMSE: 0.2490
# Val RMSE: 0.2484, Val MAE: 0.1060
# Test RMSE: 0.3214, Test MAE: 0.1483
# ---------------------------------
# Patience grace period: 18
# ---------------------------------
# Epoch 116/500
# Train RMSE: 0.2490
# Val RMSE: 0.2483, Val MAE: 0.1056
# Test RMSE: 0.3220, Test MAE: 0.1479
# ---------------------------------
# Patience grace period: 17
# ---------------------------------
# Epoch 117/500
# Train RMSE: 0.2490
# Val RMSE: 0.2484, Val MAE: 0.1057
# Test RMSE: 0.3222, Test MAE: 0.1478
# ---------------------------------
# Patience grace period: 15
# ---------------------------------
# Epoch 118/500
# Train RMSE: 0.2489
# Val RMSE: 0.2483, Val MAE: 0.1069
# Test RMSE: 0.3200, Test MAE: 0.1495
# ---------------------------------
# Model saved at epoch 118 with val RMSE 0.2483
# Patience grace period: 14
# ---------------------------------
# Epoch 119/500
# Train RMSE: 0.2489
# Val RMSE: 0.2483, Val MAE: 0.1059
# Test RMSE: 0.3215, Test MAE: 0.1483
# ---------------------------------
# Model saved at epoch 119 with val RMSE 0.2483
# Patience grace period: 12
# ---------------------------------
# Epoch 120/500
# Train RMSE: 0.2489
# Val RMSE: 0.2484, Val MAE: 0.1052
# Test RMSE: 0.3225, Test MAE: 0.1475
# ---------------------------------
# Patience grace period: 10
# ---------------------------------
# Epoch 121/500
# Train RMSE: 0.2489
# Val RMSE: 0.2484, Val MAE: 0.1050
# Test RMSE: 0.3227, Test MAE: 0.1472
# ---------------------------------
# Patience grace period: 9
# ---------------------------------
# Epoch 122/500
# Train RMSE: 0.2488
# Val RMSE: 0.2483, Val MAE: 0.1068
# Test RMSE: 0.3204, Test MAE: 0.1492
# ---------------------------------
# Model saved at epoch 122 with val RMSE 0.2483
# Patience grace period: 8
# ---------------------------------
# Epoch 123/500
# Train RMSE: 0.2488
# Val RMSE: 0.2483, Val MAE: 0.1057
# Test RMSE: 0.3219, Test MAE: 0.1480
# ---------------------------------
# Patience grace period: 6
# ---------------------------------
# Epoch 124/500
# Train RMSE: 0.2488
# Val RMSE: 0.2483, Val MAE: 0.1059
# Test RMSE: 0.3216, Test MAE: 0.1480
# ---------------------------------
# Patience grace period: 5
# ---------------------------------
# Epoch 125/500
# Train RMSE: 0.2488
# Val RMSE: 0.2484, Val MAE: 0.1053
# Test RMSE: 0.3223, Test MAE: 0.1476
# ---------------------------------
# Patience grace period: 3
# ---------------------------------
# Epoch 126/500
# Train RMSE: 0.2488
# Val RMSE: 0.2482, Val MAE: 0.1060
# Test RMSE: 0.3212, Test MAE: 0.1484
# ---------------------------------
# Model saved at epoch 126 with val RMSE 0.2482
# Patience grace period: 2
# ---------------------------------
# Epoch 127/500
# Train RMSE: 0.2487
# Val RMSE: 0.2482, Val MAE: 0.1062
# Test RMSE: 0.3208, Test MAE: 0.1486
# ---------------------------------
# Model saved at epoch 127 with val RMSE 0.2482
# Patience grace period: 1
# ---------------------------------
# Epoch 128/500
# Train RMSE: 0.2487
# Val RMSE: 0.2483, Val MAE: 0.1055
# Test RMSE: 0.3222, Test MAE: 0.1482
# ---------------------------------
# Patience grace period: -1
# Early stopping triggered at epoch 128
# Final Test RMSE: 0.3208, Final Test MAE: 0.1486
# <ipython-input-2-d8b64875fc37>:120: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   self.model.load_state_dict(torch.load(os.path.join(save_dir, 'best_model.pth')))
# Pearson Corr: 0.751360239411511
# Spearman Corr: 0.432204048902537
# p-rmse: 0.3208440464055933
#        rmse       mae  seed                             subtask        method  \
# 0  0.320844  0.148598     1  openproblems_bmmc_cite_phase2_mod2  hierarchical
#
#    pearson p_value_pearson  spearman p_value_spearman
# 0  0.75136          0.0000  0.432204           0.0000
# ---------------------------------
# Epoch 1/500
# Train RMSE: 0.3757
# Val RMSE: 0.3242, Val MAE: 0.1331
# Test RMSE: 0.4006, Test MAE: 0.1780
# ---------------------------------
# Model saved at epoch 1 with val RMSE 0.3242
# Patience grace period: 150
# ---------------------------------
# Epoch 2/500
# Train RMSE: 0.3283
# Val RMSE: 0.2954, Val MAE: 0.1280
# Test RMSE: 0.3683, Test MAE: 0.1695
# ---------------------------------
# Model saved at epoch 2 with val RMSE 0.2954
# Patience grace period: 150
# ---------------------------------
# Epoch 3/500
# Train RMSE: 0.3060
# Val RMSE: 0.2795, Val MAE: 0.1212
# Test RMSE: 0.3532, Test MAE: 0.1621
# ---------------------------------
# Model saved at epoch 3 with val RMSE 0.2795
# Patience grace period: 150
# ---------------------------------
# Epoch 4/500
# Train RMSE: 0.2924
# Val RMSE: 0.2721, Val MAE: 0.1183
# Test RMSE: 0.3461, Test MAE: 0.1589
# ---------------------------------
# Model saved at epoch 4 with val RMSE 0.2721
# Patience grace period: 149
# ---------------------------------
# Epoch 5/500
# Train RMSE: 0.2841
# Val RMSE: 0.2678, Val MAE: 0.1171
# Test RMSE: 0.3415, Test MAE: 0.1576
# ---------------------------------
# Model saved at epoch 5 with val RMSE 0.2678
# Patience grace period: 150
# ---------------------------------
# Epoch 6/500
# Train RMSE: 0.2782
# Val RMSE: 0.2648, Val MAE: 0.1163
# Test RMSE: 0.3379, Test MAE: 0.1565
# ---------------------------------
# Model saved at epoch 6 with val RMSE 0.2648
# Patience grace period: 149
# ---------------------------------
# Epoch 7/500
# Train RMSE: 0.2736
# Val RMSE: 0.2624, Val MAE: 0.1152
# Test RMSE: 0.3350, Test MAE: 0.1552
# ---------------------------------
# Model saved at epoch 7 with val RMSE 0.2624
# Patience grace period: 148
# ---------------------------------
# Epoch 8/500
# Train RMSE: 0.2698
# Val RMSE: 0.2604, Val MAE: 0.1145
# Test RMSE: 0.3322, Test MAE: 0.1544
# ---------------------------------
# Model saved at epoch 8 with val RMSE 0.2604
# Patience grace period: 147
# ---------------------------------
# Epoch 9/500
# Train RMSE: 0.2668
# Val RMSE: 0.2588, Val MAE: 0.1133
# Test RMSE: 0.3307, Test MAE: 0.1534
# ---------------------------------
# Model saved at epoch 9 with val RMSE 0.2588
# Patience grace period: 146
# ---------------------------------
# Epoch 10/500
# Train RMSE: 0.2646
# Val RMSE: 0.2576, Val MAE: 0.1132
# Test RMSE: 0.3293, Test MAE: 0.1535
# ---------------------------------
# Model saved at epoch 10 with val RMSE 0.2576
# Patience grace period: 150
# ---------------------------------
# Epoch 11/500
# Train RMSE: 0.2630
# Val RMSE: 0.2567, Val MAE: 0.1127
# Test RMSE: 0.3285, Test MAE: 0.1530
# ---------------------------------
# Model saved at epoch 11 with val RMSE 0.2567
# Patience grace period: 149
# ---------------------------------
# Epoch 12/500
# Train RMSE: 0.2617
# Val RMSE: 0.2560, Val MAE: 0.1116
# Test RMSE: 0.3282, Test MAE: 0.1523
# ---------------------------------
# Model saved at epoch 12 with val RMSE 0.2560
# Patience grace period: 148
# ---------------------------------
# Epoch 13/500
# Train RMSE: 0.2608
# Val RMSE: 0.2554, Val MAE: 0.1112
# Test RMSE: 0.3279, Test MAE: 0.1518
# ---------------------------------
# Model saved at epoch 13 with val RMSE 0.2554
# Patience grace period: 147
# ---------------------------------
# Epoch 14/500
# Train RMSE: 0.2599
# Val RMSE: 0.2550, Val MAE: 0.1107
# Test RMSE: 0.3277, Test MAE: 0.1515
# ---------------------------------
# Model saved at epoch 14 with val RMSE 0.2550
# Patience grace period: 146
# ---------------------------------
# Epoch 15/500
# Train RMSE: 0.2592
# Val RMSE: 0.2546, Val MAE: 0.1114
# Test RMSE: 0.3269, Test MAE: 0.1524
# ---------------------------------
# Model saved at epoch 15 with val RMSE 0.2546
# Patience grace period: 145
# ---------------------------------
# Epoch 16/500
# Train RMSE: 0.2587
# Val RMSE: 0.2543, Val MAE: 0.1110
# Test RMSE: 0.3266, Test MAE: 0.1520
# ---------------------------------
# Model saved at epoch 16 with val RMSE 0.2543
# Patience grace period: 144
# ---------------------------------
# Epoch 17/500
# Train RMSE: 0.2582
# Val RMSE: 0.2540, Val MAE: 0.1100
# Test RMSE: 0.3268, Test MAE: 0.1511
# ---------------------------------
# Model saved at epoch 17 with val RMSE 0.2540
# Patience grace period: 143
# ---------------------------------
# Epoch 18/500
# Train RMSE: 0.2577
# Val RMSE: 0.2537, Val MAE: 0.1108
# Test RMSE: 0.3260, Test MAE: 0.1520
# ---------------------------------
# Model saved at epoch 18 with val RMSE 0.2537
# Patience grace period: 142
# ---------------------------------
# Epoch 19/500
# Train RMSE: 0.2573
# Val RMSE: 0.2534, Val MAE: 0.1106
# Test RMSE: 0.3256, Test MAE: 0.1518
# ---------------------------------
# Model saved at epoch 19 with val RMSE 0.2534
# Patience grace period: 141
# ---------------------------------
# Epoch 20/500
# Train RMSE: 0.2570
# Val RMSE: 0.2532, Val MAE: 0.1100
# Test RMSE: 0.3255, Test MAE: 0.1512
# ---------------------------------
# Model saved at epoch 20 with val RMSE 0.2532
# Patience grace period: 140
# ---------------------------------
# Epoch 21/500
# Train RMSE: 0.2566
# Val RMSE: 0.2530, Val MAE: 0.1099
# Test RMSE: 0.3253, Test MAE: 0.1512
# ---------------------------------
# Model saved at epoch 21 with val RMSE 0.2530
# Patience grace period: 139
# ---------------------------------
# Epoch 22/500
# Train RMSE: 0.2562
# Val RMSE: 0.2528, Val MAE: 0.1105
# Test RMSE: 0.3246, Test MAE: 0.1518
# ---------------------------------
# Model saved at epoch 22 with val RMSE 0.2528
# Patience grace period: 138
# ---------------------------------
# Epoch 23/500
# Train RMSE: 0.2560
# Val RMSE: 0.2526, Val MAE: 0.1100
# Test RMSE: 0.3247, Test MAE: 0.1515
# ---------------------------------
# Model saved at epoch 23 with val RMSE 0.2526
# Patience grace period: 137
# ---------------------------------
# Epoch 24/500
# Train RMSE: 0.2557
# Val RMSE: 0.2524, Val MAE: 0.1098
# Test RMSE: 0.3247, Test MAE: 0.1513
# ---------------------------------
# Model saved at epoch 24 with val RMSE 0.2524
# Patience grace period: 136
# ---------------------------------
# Epoch 25/500
# Train RMSE: 0.2555
# Val RMSE: 0.2523, Val MAE: 0.1104
# Test RMSE: 0.3239, Test MAE: 0.1519
# ---------------------------------
# Model saved at epoch 25 with val RMSE 0.2523
# Patience grace period: 135
# ---------------------------------
# Epoch 26/500
# Train RMSE: 0.2553
# Val RMSE: 0.2521, Val MAE: 0.1096
# Test RMSE: 0.3242, Test MAE: 0.1513
# ---------------------------------
# Model saved at epoch 26 with val RMSE 0.2521
# Patience grace period: 134
# ---------------------------------
# Epoch 27/500
# Train RMSE: 0.2550
# Val RMSE: 0.2520, Val MAE: 0.1095
# Test RMSE: 0.3243, Test MAE: 0.1511
# ---------------------------------
# Model saved at epoch 27 with val RMSE 0.2520
# Patience grace period: 133
# ---------------------------------
# Epoch 28/500
# Train RMSE: 0.2548
# Val RMSE: 0.2519, Val MAE: 0.1089
# Test RMSE: 0.3244, Test MAE: 0.1506
# ---------------------------------
# Model saved at epoch 28 with val RMSE 0.2519
# Patience grace period: 132
# ---------------------------------
# Epoch 29/500
# Train RMSE: 0.2546
# Val RMSE: 0.2518, Val MAE: 0.1098
# Test RMSE: 0.3234, Test MAE: 0.1517
# ---------------------------------
# Model saved at epoch 29 with val RMSE 0.2518
# Patience grace period: 131
# ---------------------------------
# Epoch 30/500
# Train RMSE: 0.2545
# Val RMSE: 0.2516, Val MAE: 0.1094
# Test RMSE: 0.3236, Test MAE: 0.1512
# ---------------------------------
# ...
# ---------------------------------
# Model saved at epoch 140 with val RMSE 0.2481
# Patience grace period: 109
# ---------------------------------
# Epoch 141/500
# Train RMSE: 0.2485
# Val RMSE: 0.2481, Val MAE: 0.1063
# Test RMSE: 0.3211, Test MAE: 0.1480
# ---------------------------------
# Patience grace period: 107
# ---------------------------------
# Epoch 142/500
# Train RMSE: 0.2485
# Val RMSE: 0.2482, Val MAE: 0.1063
# Test RMSE: 0.3210, Test MAE: 0.1479
# ---------------------------------
# Patience grace period: 105
# ---------------------------------
# Epoch 143/500
# Train RMSE: 0.2485
# Val RMSE: 0.2483, Val MAE: 0.1071
# Test RMSE: 0.3201, Test MAE: 0.1485
# ---------------------------------
# Patience grace period: 103
# ---------------------------------
# Epoch 144/500
# Train RMSE: 0.2484
# Val RMSE: 0.2482, Val MAE: 0.1063
# Test RMSE: 0.3210, Test MAE: 0.1480
# ---------------------------------
# Patience grace period: 102
# ---------------------------------
# Epoch 145/500
# Train RMSE: 0.2484
# Val RMSE: 0.2482, Val MAE: 0.1065
# Test RMSE: 0.3207, Test MAE: 0.1480
# ---------------------------------
# Patience grace period: 100
# ---------------------------------
# Epoch 146/500
# Train RMSE: 0.2484
# Val RMSE: 0.2481, Val MAE: 0.1058
# Test RMSE: 0.3218, Test MAE: 0.1478
# ---------------------------------
# Model saved at epoch 146 with val RMSE 0.2481
# Patience grace period: 99
# ---------------------------------
# Epoch 147/500
# Train RMSE: 0.2484
# Val RMSE: 0.2481, Val MAE: 0.1061
# Test RMSE: 0.3212, Test MAE: 0.1476
# ---------------------------------
# Patience grace period: 97
# ---------------------------------
# Epoch 148/500
# Train RMSE: 0.2484
# Val RMSE: 0.2483, Val MAE: 0.1068
# Test RMSE: 0.3205, Test MAE: 0.1483
# ---------------------------------
# Patience grace period: 95
# ---------------------------------
# Epoch 149/500
# Train RMSE: 0.2484
# Val RMSE: 0.2481, Val MAE: 0.1057
# Test RMSE: 0.3219, Test MAE: 0.1473
# ---------------------------------
# Model saved at epoch 149 with val RMSE 0.2481
# Patience grace period: 94
# ---------------------------------
# Epoch 150/500
# Train RMSE: 0.2483
# Val RMSE: 0.2481, Val MAE: 0.1063
# Test RMSE: 0.3213, Test MAE: 0.1477
# ---------------------------------
# Patience grace period: 92
# ---------------------------------
# Epoch 151/500
# Train RMSE: 0.2483
# Val RMSE: 0.2481, Val MAE: 0.1062
# Test RMSE: 0.3213, Test MAE: 0.1480
# ---------------------------------
# Patience grace period: 91
# ---------------------------------
# Epoch 152/500
# Train RMSE: 0.2483
# Val RMSE: 0.2484, Val MAE: 0.1074
# Test RMSE: 0.3198, Test MAE: 0.1490
# ---------------------------------
# Patience grace period: 89
# ---------------------------------
# Epoch 153/500
# Train RMSE: 0.2482
# Val RMSE: 0.2481, Val MAE: 0.1065
# Test RMSE: 0.3208, Test MAE: 0.1481
# ---------------------------------
# Patience grace period: 88
# ---------------------------------
# Epoch 154/500
# Train RMSE: 0.2482
# Val RMSE: 0.2482, Val MAE: 0.1068
# Test RMSE: 0.3204, Test MAE: 0.1484
# ---------------------------------
# Patience grace period: 86
# ---------------------------------
# Epoch 155/500
# Train RMSE: 0.2482
# Val RMSE: 0.2481, Val MAE: 0.1061
# Test RMSE: 0.3214, Test MAE: 0.1480
# ---------------------------------
# Patience grace period: 85
# ---------------------------------
# Epoch 156/500
# Train RMSE: 0.2482
# Val RMSE: 0.2482, Val MAE: 0.1067
# Test RMSE: 0.3204, Test MAE: 0.1483
# ---------------------------------
# Patience grace period: 83
# ---------------------------------
# Epoch 157/500
# Train RMSE: 0.2482
# Val RMSE: 0.2481, Val MAE: 0.1065
# Test RMSE: 0.3211, Test MAE: 0.1478
# ---------------------------------
# Patience grace period: 82
# ---------------------------------
# Epoch 158/500
# Train RMSE: 0.2482
# Val RMSE: 0.2480, Val MAE: 0.1060
# Test RMSE: 0.3216, Test MAE: 0.1474
# ---------------------------------
# Model saved at epoch 158 with val RMSE 0.2480
# Patience grace period: 81
# ---------------------------------
# Epoch 159/500
# Train RMSE: 0.2482
# Val RMSE: 0.2481, Val MAE: 0.1064
# Test RMSE: 0.3212, Test MAE: 0.1479
# ---------------------------------
# Patience grace period: 79
# ---------------------------------
# Epoch 160/500
# Train RMSE: 0.2482
# Val RMSE: 0.2482, Val MAE: 0.1068
# Test RMSE: 0.3205, Test MAE: 0.1482
# ---------------------------------
# Patience grace period: 77
# ---------------------------------
# Epoch 161/500
# Train RMSE: 0.2482
# Val RMSE: 0.2482, Val MAE: 0.1066
# Test RMSE: 0.3205, Test MAE: 0.1483
# ---------------------------------
# Patience grace period: 75
# ---------------------------------
# Epoch 162/500
# Train RMSE: 0.2481
# Val RMSE: 0.2480, Val MAE: 0.1060
# Test RMSE: 0.3219, Test MAE: 0.1479
# ---------------------------------
# Patience grace period: 74
# ---------------------------------
# Epoch 163/500
# Train RMSE: 0.2481
# Val RMSE: 0.2481, Val MAE: 0.1061
# Test RMSE: 0.3213, Test MAE: 0.1477
# ---------------------------------
# Patience grace period: 72
# ---------------------------------
# Epoch 164/500
# Train RMSE: 0.2481
# Val RMSE: 0.2482, Val MAE: 0.1068
# Test RMSE: 0.3204, Test MAE: 0.1483
# ---------------------------------
# Patience grace period: 70
# ---------------------------------
# Epoch 165/500
# Train RMSE: 0.2481
# Val RMSE: 0.2481, Val MAE: 0.1064
# Test RMSE: 0.3209, Test MAE: 0.1479
# ---------------------------------
# Patience grace period: 69
# ---------------------------------
# Epoch 166/500
# Train RMSE: 0.2481
# Val RMSE: 0.2480, Val MAE: 0.1061
# Test RMSE: 0.3213, Test MAE: 0.1478
# ---------------------------------
# Model saved at epoch 166 with val RMSE 0.2480
# Patience grace period: 68
# ---------------------------------
# Epoch 167/500
# Train RMSE: 0.2481
# Val RMSE: 0.2481, Val MAE: 0.1067
# Test RMSE: 0.3205, Test MAE: 0.1484
# ---------------------------------
# Patience grace period: 66
# ---------------------------------
# Epoch 168/500
# Train RMSE: 0.2481
# Val RMSE: 0.2480, Val MAE: 0.1057
# Test RMSE: 0.3220, Test MAE: 0.1477
# ---------------------------------
# Model saved at epoch 168 with val RMSE 0.2480
# Patience grace period: 65
# ---------------------------------
# Epoch 169/500
# Train RMSE: 0.2480
# Val RMSE: 0.2482, Val MAE: 0.1066
# Test RMSE: 0.3205, Test MAE: 0.1478
# ---------------------------------
# Patience grace period: 63
# ---------------------------------
# Epoch 170/500
# Train RMSE: 0.2480
# Val RMSE: 0.2480, Val MAE: 0.1058
# Test RMSE: 0.3219, Test MAE: 0.1475
# ---------------------------------
# Model saved at epoch 170 with val RMSE 0.2480
# Patience grace period: 62
# ---------------------------------
# Epoch 171/500
# Train RMSE: 0.2480
# Val RMSE: 0.2481, Val MAE: 0.1063
# Test RMSE: 0.3217, Test MAE: 0.1481
# ---------------------------------
# Patience grace period: 60
# ---------------------------------
# Epoch 172/500
# Train RMSE: 0.2480
# Val RMSE: 0.2480, Val MAE: 0.1056
# Test RMSE: 0.3221, Test MAE: 0.1474
# ---------------------------------
# Model saved at epoch 172 with val RMSE 0.2480
# Patience grace period: 59
# ---------------------------------
# Epoch 173/500
# Train RMSE: 0.2480
# Val RMSE: 0.2480, Val MAE: 0.1063
# Test RMSE: 0.3215, Test MAE: 0.1480
# ---------------------------------
# Patience grace period: 57
# ---------------------------------
# Epoch 174/500
# Train RMSE: 0.2480
# Val RMSE: 0.2480, Val MAE: 0.1062
# Test RMSE: 0.3211, Test MAE: 0.1482
# ---------------------------------
# Patience grace period: 56
# ---------------------------------
# Epoch 175/500
# Train RMSE: 0.2479
# Val RMSE: 0.2481, Val MAE: 0.1063
# Test RMSE: 0.3209, Test MAE: 0.1483
# ---------------------------------
# Patience grace period: 54
# ---------------------------------
# Epoch 176/500
# Train RMSE: 0.2479
# Val RMSE: 0.2481, Val MAE: 0.1062
# Test RMSE: 0.3212, Test MAE: 0.1478
# ---------------------------------
# Patience grace period: 52
# ---------------------------------
# Epoch 177/500
# Train RMSE: 0.2479
# Val RMSE: 0.2480, Val MAE: 0.1060
# Test RMSE: 0.3213, Test MAE: 0.1477
# ---------------------------------
# Patience grace period: 51
# ---------------------------------
# Epoch 178/500
# Train RMSE: 0.2479
# Val RMSE: 0.2481, Val MAE: 0.1064
# Test RMSE: 0.3209, Test MAE: 0.1480
# ---------------------------------
# Patience grace period: 49
# ---------------------------------
# Epoch 179/500
# Train RMSE: 0.2479
# Val RMSE: 0.2480, Val MAE: 0.1060
# Test RMSE: 0.3212, Test MAE: 0.1478
# ---------------------------------
# Patience grace period: 48
# ---------------------------------
# Epoch 180/500
# Train RMSE: 0.2479
# Val RMSE: 0.2479, Val MAE: 0.1055
# Test RMSE: 0.3227, Test MAE: 0.1473
# ---------------------------------
# Model saved at epoch 180 with val RMSE 0.2479
# Patience grace period: 47
# ---------------------------------
# Epoch 181/500
# Train RMSE: 0.2479
# Val RMSE: 0.2480, Val MAE: 0.1056
# Test RMSE: 0.3230, Test MAE: 0.1476
# ---------------------------------
# Patience grace period: 45
# ---------------------------------
# Epoch 182/500
# Train RMSE: 0.2479
# Val RMSE: 0.2480, Val MAE: 0.1063
# Test RMSE: 0.3213, Test MAE: 0.1478
# ---------------------------------
# Patience grace period: 44
# ---------------------------------
# Epoch 183/500
# Train RMSE: 0.2478
# Val RMSE: 0.2480, Val MAE: 0.1058
# Test RMSE: 0.3221, Test MAE: 0.1475
# ---------------------------------
# Patience grace period: 43
# ---------------------------------
# Epoch 184/500
# Train RMSE: 0.2478
# Val RMSE: 0.2480, Val MAE: 0.1061
# Test RMSE: 0.3219, Test MAE: 0.1477
# ---------------------------------
# Patience grace period: 41
# ---------------------------------
# Epoch 185/500
# Train RMSE: 0.2478
# Val RMSE: 0.2479, Val MAE: 0.1057
# Test RMSE: 0.3223, Test MAE: 0.1475
# ---------------------------------
# Model saved at epoch 185 with val RMSE 0.2479
# Patience grace period: 40
# ---------------------------------
# Epoch 186/500
# Train RMSE: 0.2478
# Val RMSE: 0.2480, Val MAE: 0.1061
# Test RMSE: 0.3219, Test MAE: 0.1478
# ---------------------------------
# Patience grace period: 38
# ---------------------------------
# Epoch 187/500
# Train RMSE: 0.2478
# Val RMSE: 0.2480, Val MAE: 0.1053
# Test RMSE: 0.3232, Test MAE: 0.1471
# ---------------------------------
# Patience grace period: 37
# ---------------------------------
# Epoch 188/500
# Train RMSE: 0.2478
# Val RMSE: 0.2480, Val MAE: 0.1051
# Test RMSE: 0.3235, Test MAE: 0.1469
# ---------------------------------
# Patience grace period: 36
# ---------------------------------
# Epoch 189/500
# Train RMSE: 0.2478
# Val RMSE: 0.2479, Val MAE: 0.1054
# Test RMSE: 0.3227, Test MAE: 0.1472
# ---------------------------------
# Model saved at epoch 189 with val RMSE 0.2479
# Patience grace period: 35
# ---------------------------------
# Epoch 190/500
# Train RMSE: 0.2478
# Val RMSE: 0.2479, Val MAE: 0.1053
# Test RMSE: 0.3231, Test MAE: 0.1472
# ---------------------------------
# Patience grace period: 33
# ---------------------------------
# Epoch 191/500
# Train RMSE: 0.2477
# Val RMSE: 0.2479, Val MAE: 0.1052
# Test RMSE: 0.3235, Test MAE: 0.1470
# ---------------------------------
# Patience grace period: 31
# ---------------------------------
# Epoch 192/500
# Train RMSE: 0.2478
# Val RMSE: 0.2480, Val MAE: 0.1061
# Test RMSE: 0.3216, Test MAE: 0.1479
# ---------------------------------
# Patience grace period: 29
# ---------------------------------
# Epoch 193/500
# Train RMSE: 0.2479
# Val RMSE: 0.2484, Val MAE: 0.1069
# Test RMSE: 0.3202, Test MAE: 0.1483
# ---------------------------------
# Patience grace period: 27
# ---------------------------------
# Epoch 194/500
# Train RMSE: 0.2479
# Val RMSE: 0.2486, Val MAE: 0.1076
# Test RMSE: 0.3196, Test MAE: 0.1490
# ---------------------------------
# Patience grace period: 25
# ---------------------------------
# Epoch 195/500
# Train RMSE: 0.2478
# Val RMSE: 0.2485, Val MAE: 0.1077
# Test RMSE: 0.3195, Test MAE: 0.1493
# ---------------------------------
# Patience grace period: 24
# ---------------------------------
# Epoch 196/500
# Train RMSE: 0.2477
# Val RMSE: 0.2485, Val MAE: 0.1074
# Test RMSE: 0.3199, Test MAE: 0.1490
# ---------------------------------
# Patience grace period: 23
# ---------------------------------
# Epoch 197/500
# Train RMSE: 0.2477
# Val RMSE: 0.2483, Val MAE: 0.1073
# Test RMSE: 0.3197, Test MAE: 0.1491
# ---------------------------------
# Patience grace period: 22
# ---------------------------------
# Epoch 198/500
# Train RMSE: 0.2477
# Val RMSE: 0.2485, Val MAE: 0.1075
# Test RMSE: 0.3195, Test MAE: 0.1493
# ---------------------------------
# Patience grace period: 20
# ---------------------------------
# Epoch 199/500
# Train RMSE: 0.2477
# Val RMSE: 0.2485, Val MAE: 0.1077
# Test RMSE: 0.3192, Test MAE: 0.1494
# ---------------------------------
# Patience grace period: 18
# ---------------------------------
# Epoch 200/500
# Train RMSE: 0.2477
# Val RMSE: 0.2487, Val MAE: 0.1078
# Test RMSE: 0.3191, Test MAE: 0.1494
# ---------------------------------
# Patience grace period: 16
# ---------------------------------
# Epoch 201/500
# Train RMSE: 0.2477
# Val RMSE: 0.2485, Val MAE: 0.1078
# Test RMSE: 0.3192, Test MAE: 0.1499
# ---------------------------------
# Patience grace period: 15
# ---------------------------------
# Epoch 202/500
# Train RMSE: 0.2477
# Val RMSE: 0.2483, Val MAE: 0.1074
# Test RMSE: 0.3196, Test MAE: 0.1493
# ---------------------------------
# Patience grace period: 14
# ---------------------------------
# Epoch 203/500
# Train RMSE: 0.2476
# Val RMSE: 0.2485, Val MAE: 0.1077
# Test RMSE: 0.3193, Test MAE: 0.1494
# ---------------------------------
# Patience grace period: 12
# ---------------------------------
# Epoch 204/500
# Train RMSE: 0.2476
# Val RMSE: 0.2486, Val MAE: 0.1075
# Test RMSE: 0.3193, Test MAE: 0.1493
# ---------------------------------
# Patience grace period: 10
# ---------------------------------
# Epoch 205/500
# Train RMSE: 0.2476
# Val RMSE: 0.2486, Val MAE: 0.1074
# Test RMSE: 0.3195, Test MAE: 0.1491
# ---------------------------------
# Patience grace period: 9
# ---------------------------------
# Epoch 206/500
# Train RMSE: 0.2476
# Val RMSE: 0.2483, Val MAE: 0.1076
# Test RMSE: 0.3193, Test MAE: 0.1497
# ---------------------------------
# Patience grace period: 8
# ---------------------------------
# Epoch 207/500
# Train RMSE: 0.2476
# Val RMSE: 0.2486, Val MAE: 0.1077
# Test RMSE: 0.3193, Test MAE: 0.1494
# ---------------------------------
# Patience grace period: 6
# ---------------------------------
# Epoch 208/500
# Train RMSE: 0.2476
# Val RMSE: 0.2486, Val MAE: 0.1076
# Test RMSE: 0.3192, Test MAE: 0.1495
# ---------------------------------
# Patience grace period: 4
# ---------------------------------
# Epoch 209/500
# Train RMSE: 0.2476
# Val RMSE: 0.2483, Val MAE: 0.1072
# Test RMSE: 0.3196, Test MAE: 0.1494
# ---------------------------------
# Patience grace period: 3
# ---------------------------------
# Epoch 210/500
# Train RMSE: 0.2475
# Val RMSE: 0.2486, Val MAE: 0.1076
# Test RMSE: 0.3193, Test MAE: 0.1494
# ---------------------------------
# Patience grace period: 1
# ---------------------------------
# Epoch 211/500
# Train RMSE: 0.2475
# Val RMSE: 0.2484, Val MAE: 0.1075
# Test RMSE: 0.3195, Test MAE: 0.1493
# ---------------------------------
# Patience grace period: 0
# Early stopping triggered at epoch 211
# Final Test RMSE: 0.3227, Final Test MAE: 0.1472
# <ipython-input-2-d8b64875fc37>:120: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   self.model.load_state_dict(torch.load(os.path.join(save_dir, 'best_model.pth')))
# Pearson Corr: 0.7509022401746241
# Spearman Corr: 0.43281283391068703
# p-rmse: 0.32271228239098876
#        rmse       mae  seed                             subtask        method  \
# 0  0.322712  0.147236     5  openproblems_bmmc_cite_phase2_mod2  hierarchical
#
#     pearson p_value_pearson  spearman p_value_spearman
# 0  0.750902          0.0000  0.432813           0.0000

# %% [markdown]
# ## **RNA**

# %%
config_RNA = {
    "subtask": "openproblems_bmmc_cite_phase2_rna",
    "batch_size": 520,
    "act": "leaky_relu",
    "conv_flow": ["gat"],
    "agg_flow": [None],
    "device": "cuda",
    "learning_rate": 0.000064,
    "hidden_size": 512,
    "num_heads": 2,
    "n_neigbours": 3,
    "n_components": 1200,
    "metric": "euclidean",
    "dropout_rate": 0.2,
    "num_epochs": 500,
    "seed": 1,
    "es_patience": 40,
    "es_min_delta": 0.001,
    "es_rate_threshold": 0.0001,
    "layer_dim_ex": 3,
    "verbose": True,
    "sample": True,
    "preprocessing_type": "SVD",
    "variant": "original"
}

pipeline(**config_RNA)
# Out:
# Initializing pipeline...
# [INFO][2025-04-06 08:24:51,973][dance][download_file] Downloading: /content/data/openproblems_bmmc_cite_phase2_rna.zip Bytes: 626,273,309
# 100%|██████████| 597M/597M [00:18<00:00, 34.0MB/s]
# [INFO][2025-04-06 08:25:10,422][dance][unzip_file] Unzipping /content/data/openproblems_bmmc_cite_phase2_rna.zip
# [INFO][2025-04-06 08:25:13,609][dance][delete_file] Deleting /content/data/openproblems_bmmc_cite_phase2_rna.zip
# [INFO][2025-04-06 08:25:13,709][dance][_load_raw_data] Loading /content/data/openproblems_bmmc_cite_phase2_rna/openproblems_bmmc_cite_phase2_rna.censor_dataset.output_train_mod1.h5ad
# [INFO][2025-04-06 08:25:21,094][dance][_load_raw_data] Loading /content/data/openproblems_bmmc_cite_phase2_rna/openproblems_bmmc_cite_phase2_rna.censor_dataset.output_train_mod2.h5ad
# [INFO][2025-04-06 08:25:21,740][dance][_load_raw_data] Loading /content/data/openproblems_bmmc_cite_phase2_rna/openproblems_bmmc_cite_phase2_rna.censor_dataset.output_test_mod1.h5ad
# [INFO][2025-04-06 08:25:21,941][dance][_load_raw_data] Loading /content/data/openproblems_bmmc_cite_phase2_rna/openproblems_bmmc_cite_phase2_rna.censor_dataset.output_test_mod2.h5ad
# [INFO][2025-04-06 08:25:21,964][dance][_maybe_preprocess] Preprocessing done.
# /usr/local/lib/python3.11/dist-packages/mudata/_core/mudata.py:1531: FutureWarning: From 0.4 .update() will not pull obs/var columns from individual modalities by default anymore. Set mudata.set_options(pull_on_update=False) to adopt the new behaviour, which will become the default. Use new pull_obs/pull_var and push_obs/push_var methods for more flexibility.
#   self._update_attr("var", axis=0, join_common=join_common)
# /usr/local/lib/python3.11/dist-packages/mudata/_core/mudata.py:931: UserWarning: Cannot join columns with the same name because var_names are intersecting.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/mudata/_core/mudata.py:1429: FutureWarning: From 0.4 .update() will not pull obs/var columns from individual modalities by default anymore. Set mudata.set_options(pull_on_update=False) to adopt the new behaviour, which will become the default. Use new pull_obs/pull_var and push_obs/push_var methods for more flexibility.
#   self._update_attr("obs", axis=1, join_common=join_common)
# /usr/local/lib/python3.11/dist-packages/mudata/_core/mudata.py:1558: UserWarning: Modality names will be prepended to var_names since there are identical var_names in different modalities.
#   warnings.warn(
# [INFO][2025-04-06 08:25:31,105][dance][set_config_from_dict] Setting config 'feature_mod' to 'mod1'
# [INFO][2025-04-06 08:25:31,105][dance][set_config_from_dict] Setting config 'label_mod' to 'mod2'
# [INFO][2025-04-06 08:25:31,106][dance][load_data] Raw data loaded:
# Data object that wraps (.data):
# MuData object with n_obs × n_vars = 67175 × 14087
#   uns:	'dance_config'
#   2 modalities
#     mod1:	67175 x 13953
#       obs:	'batch', 'size_factors'
#       layers:	'counts'
#     mod2:	67175 x 134
#       obs:	'batch', 'size_factors'
#       layers:	'counts'
# [INFO][2025-04-06 08:25:31,220][dance][wrapped_func] Took 0:00:40.769429 to load and process data.
# Performing data processing using GraphCreator...
# Truncated (62866, 1200)
# Data processing using GraphCreator complete and saved.
# ---------------------------------
# Epoch 1/500
# Train RMSE: 0.6721
# Val RMSE: 0.4926, Val MAE: 0.3483
# Test RMSE: 0.5401, Test MAE: 0.3614
# ---------------------------------
# Model saved at epoch 1 with val RMSE 0.4926
# Patience grace period: 40
# ---------------------------------
# Epoch 2/500
# Train RMSE: 0.4766
# Val RMSE: 0.4185, Val MAE: 0.2968
# Test RMSE: 0.4772, Test MAE: 0.3199
# ---------------------------------
# Model saved at epoch 2 with val RMSE 0.4185
# Patience grace period: 40
# ---------------------------------
# Epoch 3/500
# Train RMSE: 0.4230
# Val RMSE: 0.3856, Val MAE: 0.2738
# Test RMSE: 0.4576, Test MAE: 0.3105
# ---------------------------------
# Model saved at epoch 3 with val RMSE 0.3856
# Patience grace period: 40
# ---------------------------------
# Epoch 4/500
# Train RMSE: 0.3976
# Val RMSE: 0.3699, Val MAE: 0.2641
# Test RMSE: 0.4430, Test MAE: 0.3037
# ---------------------------------
# Model saved at epoch 4 with val RMSE 0.3699
# Patience grace period: 40
# ---------------------------------
# Epoch 5/500
# Train RMSE: 0.3818
# Val RMSE: 0.3590, Val MAE: 0.2575
# Test RMSE: 0.4318, Test MAE: 0.2972
# ---------------------------------
# Model saved at epoch 5 with val RMSE 0.3590
# Patience grace period: 40
# ---------------------------------
# Epoch 6/500
# Train RMSE: 0.3704
# Val RMSE: 0.3511, Val MAE: 0.2526
# Test RMSE: 0.4255, Test MAE: 0.2924
# ---------------------------------
# Model saved at epoch 6 with val RMSE 0.3511
# Patience grace period: 40
# ---------------------------------
# Epoch 7/500
# Train RMSE: 0.3625
# Val RMSE: 0.3459, Val MAE: 0.2492
# Test RMSE: 0.4221, Test MAE: 0.2897
# ---------------------------------
# Model saved at epoch 7 with val RMSE 0.3459
# Patience grace period: 40
# ---------------------------------
# Epoch 8/500
# Train RMSE: 0.3563
# Val RMSE: 0.3420, Val MAE: 0.2467
# Test RMSE: 0.4197, Test MAE: 0.2876
# ---------------------------------
# Model saved at epoch 8 with val RMSE 0.3420
# Patience grace period: 40
# ---------------------------------
# Epoch 9/500
# Train RMSE: 0.3515
# Val RMSE: 0.3389, Val MAE: 0.2446
# Test RMSE: 0.4176, Test MAE: 0.2858
# ---------------------------------
# Model saved at epoch 9 with val RMSE 0.3389
# Patience grace period: 40
# ---------------------------------
# Epoch 10/500
# Train RMSE: 0.3473
# Val RMSE: 0.3363, Val MAE: 0.2430
# Test RMSE: 0.4162, Test MAE: 0.2844
# ---------------------------------
# Model saved at epoch 10 with val RMSE 0.3363
# Patience grace period: 40
# ---------------------------------
# Epoch 11/500
# Train RMSE: 0.3436
# Val RMSE: 0.3340, Val MAE: 0.2416
# Test RMSE: 0.4149, Test MAE: 0.2833
# ---------------------------------
# Model saved at epoch 11 with val RMSE 0.3340
# Patience grace period: 40
# ---------------------------------
# Epoch 12/500
# Train RMSE: 0.3405
# Val RMSE: 0.3320, Val MAE: 0.2402
# Test RMSE: 0.4137, Test MAE: 0.2824
# ---------------------------------
# Model saved at epoch 12 with val RMSE 0.3320
# Patience grace period: 40
# ---------------------------------
# Epoch 13/500
# Train RMSE: 0.3375
# Val RMSE: 0.3303, Val MAE: 0.2391
# Test RMSE: 0.4132, Test MAE: 0.2818
# ---------------------------------
# Model saved at epoch 13 with val RMSE 0.3303
# Patience grace period: 40
# ---------------------------------
# Epoch 14/500
# Train RMSE: 0.3349
# Val RMSE: 0.3288, Val MAE: 0.2381
# Test RMSE: 0.4121, Test MAE: 0.2809
# ---------------------------------
# Model saved at epoch 14 with val RMSE 0.3288
# Patience grace period: 40
# ---------------------------------
# Epoch 15/500
# Train RMSE: 0.3326
# Val RMSE: 0.3276, Val MAE: 0.2373
# Test RMSE: 0.4112, Test MAE: 0.2800
# ---------------------------------
# Model saved at epoch 15 with val RMSE 0.3276
# Patience grace period: 40
# ---------------------------------
# Epoch 16/500
# Train RMSE: 0.3305
# Val RMSE: 0.3265, Val MAE: 0.2366
# Test RMSE: 0.4118, Test MAE: 0.2805
# ---------------------------------
# Model saved at epoch 16 with val RMSE 0.3265
# Patience grace period: 40
# ---------------------------------
# Epoch 17/500
# Train RMSE: 0.3285
# Val RMSE: 0.3256, Val MAE: 0.2361
# Test RMSE: 0.4113, Test MAE: 0.2799
# ---------------------------------
# Model saved at epoch 17 with val RMSE 0.3256
# Patience grace period: 39
# ---------------------------------
# Epoch 18/500
# Train RMSE: 0.3266
# Val RMSE: 0.3246, Val MAE: 0.2353
# Test RMSE: 0.4107, Test MAE: 0.2797
# ---------------------------------
# Model saved at epoch 18 with val RMSE 0.3246
# Patience grace period: 40
# ---------------------------------
# Epoch 19/500
# Train RMSE: 0.3251
# Val RMSE: 0.3240, Val MAE: 0.2349
# Test RMSE: 0.4116, Test MAE: 0.2798
# ---------------------------------
# Model saved at epoch 19 with val RMSE 0.3240
# Patience grace period: 39
# ---------------------------------
# Epoch 20/500
# Train RMSE: 0.3236
# Val RMSE: 0.3231, Val MAE: 0.2343
# Test RMSE: 0.4103, Test MAE: 0.2790
# ---------------------------------
# Model saved at epoch 20 with val RMSE 0.3231
# Patience grace period: 40
# ---------------------------------
# Epoch 21/500
# Train RMSE: 0.3219
# Val RMSE: 0.3224, Val MAE: 0.2338
# Test RMSE: 0.4114, Test MAE: 0.2799
# ---------------------------------
# Model saved at epoch 21 with val RMSE 0.3224
# Patience grace period: 39
# ---------------------------------
# Epoch 22/500
# Train RMSE: 0.3206
# Val RMSE: 0.3220, Val MAE: 0.2336
# Test RMSE: 0.4104, Test MAE: 0.2791
# ---------------------------------
# Model saved at epoch 22 with val RMSE 0.3220
# Patience grace period: 40
# ---------------------------------
# Epoch 23/500
# Train RMSE: 0.3193
# Val RMSE: 0.3214, Val MAE: 0.2331
# Test RMSE: 0.4107, Test MAE: 0.2795
# ---------------------------------
# Model saved at epoch 23 with val RMSE 0.3214
# Patience grace period: 39
# ---------------------------------
# Epoch 24/500
# Train RMSE: 0.3181
# Val RMSE: 0.3209, Val MAE: 0.2329
# Test RMSE: 0.4109, Test MAE: 0.2792
# ---------------------------------
# Model saved at epoch 24 with val RMSE 0.3209
# Patience grace period: 40
# ---------------------------------
# Epoch 25/500
# Train RMSE: 0.3169
# Val RMSE: 0.3206, Val MAE: 0.2326
# Test RMSE: 0.4101, Test MAE: 0.2788
# ---------------------------------
# Model saved at epoch 25 with val RMSE 0.3206
# Patience grace period: 39
# ---------------------------------
# Epoch 26/500
# Train RMSE: 0.3156
# Val RMSE: 0.3201, Val MAE: 0.2323
# Test RMSE: 0.4102, Test MAE: 0.2789
# ---------------------------------
# Model saved at epoch 26 with val RMSE 0.3201
# Patience grace period: 38
# ---------------------------------
# Epoch 27/500
# Train RMSE: 0.3145
# Val RMSE: 0.3198, Val MAE: 0.2320
# Test RMSE: 0.4106, Test MAE: 0.2792
# ---------------------------------
# Model saved at epoch 27 with val RMSE 0.3198
# Patience grace period: 40
# ---------------------------------
# Epoch 28/500
# Train RMSE: 0.3135
# Val RMSE: 0.3194, Val MAE: 0.2317
# Test RMSE: 0.4096, Test MAE: 0.2785
# ---------------------------------
# Model saved at epoch 28 with val RMSE 0.3194
# Patience grace period: 39
# ---------------------------------
# Epoch 29/500
# Train RMSE: 0.3126
# Val RMSE: 0.3190, Val MAE: 0.2315
# Test RMSE: 0.4099, Test MAE: 0.2786
# ---------------------------------
# Model saved at epoch 29 with val RMSE 0.3190
# Patience grace period: 38
# ---------------------------------
# Epoch 30/500
# Train RMSE: 0.3116
# Val RMSE: 0.3188, Val MAE: 0.2314
# Test RMSE: 0.4103, Test MAE: 0.2789
# ---------------------------------
# Model saved at epoch 30 with val RMSE 0.3188
# Patience grace period: 40
# ---------------------------------
# Epoch 31/500
# Train RMSE: 0.3106
# Val RMSE: 0.3184, Val MAE: 0.2311
# Test RMSE: 0.4084, Test MAE: 0.2776
# ---------------------------------
# Model saved at epoch 31 with val RMSE 0.3184
# Patience grace period: 39
# ---------------------------------
# Epoch 32/500
# Train RMSE: 0.3098
# Val RMSE: 0.3184, Val MAE: 0.2311
# Test RMSE: 0.4092, Test MAE: 0.2783
# ---------------------------------
# Model saved at epoch 32 with val RMSE 0.3184
# Patience grace period: 38
# ---------------------------------
# Epoch 33/500
# Train RMSE: 0.3089
# Val RMSE: 0.3181, Val MAE: 0.2309
# Test RMSE: 0.4095, Test MAE: 0.2785
# ---------------------------------
# Model saved at epoch 33 with val RMSE 0.3181
# Patience grace period: 37
# ---------------------------------
# Epoch 34/500
# Train RMSE: 0.3081
# Val RMSE: 0.3179, Val MAE: 0.2307
# Test RMSE: 0.4091, Test MAE: 0.2778
# ---------------------------------
# Model saved at epoch 34 with val RMSE 0.3179
# Patience grace period: 36
# ---------------------------------
# Epoch 35/500
# Train RMSE: 0.3073
# Val RMSE: 0.3178, Val MAE: 0.2306
# Test RMSE: 0.4099, Test MAE: 0.2785
# ---------------------------------
# Model saved at epoch 35 with val RMSE 0.3178
# Patience grace period: 35
# ---------------------------------
# Epoch 36/500
# Train RMSE: 0.3064
# Val RMSE: 0.3176, Val MAE: 0.2304
# Test RMSE: 0.4095, Test MAE: 0.2781
# ---------------------------------
# Model saved at epoch 36 with val RMSE 0.3176
# Patience grace period: 40
# ---------------------------------
# Epoch 37/500
# Train RMSE: 0.3057
# Val RMSE: 0.3175, Val MAE: 0.2304
# Test RMSE: 0.4092, Test MAE: 0.2780
# ---------------------------------
# Model saved at epoch 37 with val RMSE 0.3175
# Patience grace period: 39
# ---------------------------------
# Epoch 38/500
# Train RMSE: 0.3051
# Val RMSE: 0.3172, Val MAE: 0.2302
# Test RMSE: 0.4083, Test MAE: 0.2772
# ---------------------------------
# Model saved at epoch 38 with val RMSE 0.3172
# Patience grace period: 38
# ---------------------------------
# Epoch 39/500
# Train RMSE: 0.3042
# Val RMSE: 0.3170, Val MAE: 0.2301
# Test RMSE: 0.4080, Test MAE: 0.2772
# ---------------------------------
# Model saved at epoch 39 with val RMSE 0.3170
# Patience grace period: 37
# ---------------------------------
# Epoch 40/500
# Train RMSE: 0.3036
# Val RMSE: 0.3169, Val MAE: 0.2300
# Test RMSE: 0.4096, Test MAE: 0.2784
# ---------------------------------
# Model saved at epoch 40 with val RMSE 0.3169
# Patience grace period: 36
# ---------------------------------
# Epoch 41/500
# Train RMSE: 0.3029
# Val RMSE: 0.3170, Val MAE: 0.2300
# Test RMSE: 0.4097, Test MAE: 0.2784
# ---------------------------------
# Patience grace period: 34
# ---------------------------------
# Epoch 42/500
# Train RMSE: 0.3023
# Val RMSE: 0.3170, Val MAE: 0.2301
# Test RMSE: 0.4086, Test MAE: 0.2778
# ---------------------------------
# Patience grace period: 32
# ---------------------------------
# Epoch 43/500
# Train RMSE: 0.3017
# Val RMSE: 0.3167, Val MAE: 0.2298
# Test RMSE: 0.4092, Test MAE: 0.2781
# ---------------------------------
# Model saved at epoch 43 with val RMSE 0.3167
# Patience grace period: 31
# ---------------------------------
# Epoch 44/500
# Train RMSE: 0.3011
# Val RMSE: 0.3166, Val MAE: 0.2298
# Test RMSE: 0.4086, Test MAE: 0.2777
# ---------------------------------
# Model saved at epoch 44 with val RMSE 0.3166
# Patience grace period: 30
# ---------------------------------
# Epoch 45/500
# Train RMSE: 0.3005
# Val RMSE: 0.3165, Val MAE: 0.2297
# Test RMSE: 0.4071, Test MAE: 0.2770
# ---------------------------------
# Model saved at epoch 45 with val RMSE 0.3165
# Patience grace period: 40
# ---------------------------------
# Epoch 46/500
# Train RMSE: 0.2997
# Val RMSE: 0.3165, Val MAE: 0.2297
# Test RMSE: 0.4089, Test MAE: 0.2778
# ---------------------------------
# Patience grace period: 38
# ---------------------------------
# Epoch 47/500
# Train RMSE: 0.2993
# Val RMSE: 0.3164, Val MAE: 0.2296
# Test RMSE: 0.4077, Test MAE: 0.2772
# ---------------------------------
# Model saved at epoch 47 with val RMSE 0.3164
# Patience grace period: 37
# ---------------------------------
# Epoch 48/500
# Train RMSE: 0.2988
# Val RMSE: 0.3164, Val MAE: 0.2296
# Test RMSE: 0.4090, Test MAE: 0.2776
# ---------------------------------
# Model saved at epoch 48 with val RMSE 0.3164
# Patience grace period: 36
# ---------------------------------
# Epoch 49/500
# Train RMSE: 0.2982
# Val RMSE: 0.3163, Val MAE: 0.2295
# Test RMSE: 0.4085, Test MAE: 0.2775
# ---------------------------------
# Model saved at epoch 49 with val RMSE 0.3163
# Patience grace period: 34
# ---------------------------------
# Epoch 50/500
# Train RMSE: 0.2977
# Val RMSE: 0.3164, Val MAE: 0.2296
# Test RMSE: 0.4091, Test MAE: 0.2783
# ---------------------------------
# Patience grace period: 32
# ---------------------------------
# Epoch 51/500
# Train RMSE: 0.2973
# Val RMSE: 0.3164, Val MAE: 0.2295
# Test RMSE: 0.4078, Test MAE: 0.2772
# ---------------------------------
# Patience grace period: 30
# ---------------------------------
# Epoch 52/500
# Train RMSE: 0.2968
# Val RMSE: 0.3164, Val MAE: 0.2296
# Test RMSE: 0.4081, Test MAE: 0.2771
# ---------------------------------
# Patience grace period: 28
# ---------------------------------
# Epoch 53/500
# Train RMSE: 0.2962
# Val RMSE: 0.3164, Val MAE: 0.2296
# Test RMSE: 0.4067, Test MAE: 0.2766
# ---------------------------------
# Patience grace period: 26
# ---------------------------------
# Epoch 54/500
# Train RMSE: 0.2958
# Val RMSE: 0.3165, Val MAE: 0.2296
# Test RMSE: 0.4084, Test MAE: 0.2775
# ---------------------------------
# Patience grace period: 24
# ---------------------------------
# Epoch 55/500
# Train RMSE: 0.2955
# Val RMSE: 0.3162, Val MAE: 0.2294
# Test RMSE: 0.4071, Test MAE: 0.2767
# ---------------------------------
# Model saved at epoch 55 with val RMSE 0.3162
# Patience grace period: 23
# ---------------------------------
# Epoch 56/500
# Train RMSE: 0.2950
# Val RMSE: 0.3161, Val MAE: 0.2293
# Test RMSE: 0.4073, Test MAE: 0.2768
# ---------------------------------
# Model saved at epoch 56 with val RMSE 0.3161
# Patience grace period: 22
# ---------------------------------
# Epoch 57/500
# Train RMSE: 0.2946
# Val RMSE: 0.3164, Val MAE: 0.2295
# Test RMSE: 0.4084, Test MAE: 0.2773
# ---------------------------------
# Patience grace period: 20
# ---------------------------------
# Epoch 58/500
# Train RMSE: 0.2942
# Val RMSE: 0.3162, Val MAE: 0.2293
# Test RMSE: 0.4079, Test MAE: 0.2771
# ---------------------------------
# Patience grace period: 19
# ---------------------------------
# Epoch 59/500
# Train RMSE: 0.2939
# Val RMSE: 0.3167, Val MAE: 0.2296
# Test RMSE: 0.4101, Test MAE: 0.2783
# ---------------------------------
# Patience grace period: 17
# ---------------------------------
# Epoch 60/500
# Train RMSE: 0.2934
# Val RMSE: 0.3168, Val MAE: 0.2298
# Test RMSE: 0.4099, Test MAE: 0.2783
# ---------------------------------
# Patience grace period: 15
# ---------------------------------
# Epoch 61/500
# Train RMSE: 0.2933
# Val RMSE: 0.3182, Val MAE: 0.2306
# Test RMSE: 0.4129, Test MAE: 0.2800
# ---------------------------------
# Patience grace period: 13
# ---------------------------------
# Epoch 62/500
# Train RMSE: 0.2931
# Val RMSE: 0.3208, Val MAE: 0.2323
# Test RMSE: 0.4167, Test MAE: 0.2819
# ---------------------------------
# Patience grace period: 11
# ---------------------------------
# Epoch 63/500
# Train RMSE: 0.2933
# Val RMSE: 0.3173, Val MAE: 0.2301
# Test RMSE: 0.4104, Test MAE: 0.2786
# ---------------------------------
# Patience grace period: 10
# ---------------------------------
# Epoch 64/500
# Train RMSE: 0.2924
# Val RMSE: 0.3165, Val MAE: 0.2295
# Test RMSE: 0.4079, Test MAE: 0.2773
# ---------------------------------
# Patience grace period: 9
# ---------------------------------
# Epoch 65/500
# Train RMSE: 0.2919
# Val RMSE: 0.3162, Val MAE: 0.2293
# Test RMSE: 0.4067, Test MAE: 0.2764
# ---------------------------------
# Patience grace period: 8
# ---------------------------------
# Epoch 66/500
# Train RMSE: 0.2913
# Val RMSE: 0.3164, Val MAE: 0.2294
# Test RMSE: 0.4069, Test MAE: 0.2766
# ---------------------------------
# Patience grace period: 6
# ---------------------------------
# Epoch 67/500
# Train RMSE: 0.2911
# Val RMSE: 0.3166, Val MAE: 0.2297
# Test RMSE: 0.4064, Test MAE: 0.2763
# ---------------------------------
# Patience grace period: 4
# ---------------------------------
# Epoch 68/500
# Train RMSE: 0.2907
# Val RMSE: 0.3169, Val MAE: 0.2298
# Test RMSE: 0.4079, Test MAE: 0.2771
# ---------------------------------
# Patience grace period: 2
# ---------------------------------
# Epoch 69/500
# Train RMSE: 0.2904
# Val RMSE: 0.3168, Val MAE: 0.2297
# Test RMSE: 0.4073, Test MAE: 0.2767
# ---------------------------------
# Patience grace period: 1
# ---------------------------------
# Epoch 70/500
# Train RMSE: 0.2901
# Val RMSE: 0.3165, Val MAE: 0.2296
# Test RMSE: 0.4076, Test MAE: 0.2769
# ---------------------------------
# Patience grace period: 0
# Early stopping triggered at epoch 70
# Final Test RMSE: 0.4073, Final Test MAE: 0.2768
# Pearson Corr: 0.8735233012599021
# Spearman Corr: 0.8492621744784414
# p-rmse: 0.4073049895147424
#        rmse       mae  seed                            subtask    method  \
# 0  0.407305  0.276826     1  openproblems_bmmc_cite_phase2_rna  original
#
#     pearson p_value_pearson  spearman p_value_spearman
# 0  0.873523          0.0000  0.849262           0.0000
# <ipython-input-2-d8b64875fc37>:120: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   self.model.load_state_dict(torch.load(os.path.join(save_dir, 'best_model.pth')))
# ---------------------------------
# Epoch 1/500
# Train RMSE: 0.6738
# Val RMSE: 0.4896, Val MAE: 0.3458
# Test RMSE: 0.5399, Test MAE: 0.3605
# ---------------------------------
# Model saved at epoch 1 with val RMSE 0.4896
# Patience grace period: 40
# ---------------------------------
# Epoch 2/500
# Train RMSE: 0.4730
# Val RMSE: 0.4162, Val MAE: 0.2948
# Test RMSE: 0.4762, Test MAE: 0.3193
# ---------------------------------
# Model saved at epoch 2 with val RMSE 0.4162
# Patience grace period: 40
# ---------------------------------
# Epoch 3/500
# Train RMSE: 0.4217
# Val RMSE: 0.3862, Val MAE: 0.2740
# Test RMSE: 0.4578, Test MAE: 0.3106
# ---------------------------------
# Model saved at epoch 3 with val RMSE 0.3862
# Patience grace period: 40
# ---------------------------------
# Epoch 4/500
# Train RMSE: 0.3973
# Val RMSE: 0.3709, Val MAE: 0.2645
# Test RMSE: 0.4447, Test MAE: 0.3050
# ---------------------------------
# Model saved at epoch 4 with val RMSE 0.3709
# Patience grace period: 40
# ---------------------------------
# Epoch 5/500
# Train RMSE: 0.3819
# Val RMSE: 0.3596, Val MAE: 0.2579
# Test RMSE: 0.4334, Test MAE: 0.2983
# ---------------------------------
# Model saved at epoch 5 with val RMSE 0.3596
# Patience grace period: 40
# ---------------------------------
# Epoch 6/500
# Train RMSE: 0.3703
# Val RMSE: 0.3517, Val MAE: 0.2530
# Test RMSE: 0.4264, Test MAE: 0.2932
# ---------------------------------
# Model saved at epoch 6 with val RMSE 0.3517
# Patience grace period: 40
# ---------------------------------
# Epoch 7/500
# Train RMSE: 0.3623
# Val RMSE: 0.3461, Val MAE: 0.2494
# Test RMSE: 0.4225, Test MAE: 0.2898
# ---------------------------------
# Model saved at epoch 7 with val RMSE 0.3461
# Patience grace period: 40
# ---------------------------------
# Epoch 8/500
# Train RMSE: 0.3562
# Val RMSE: 0.3421, Val MAE: 0.2469
# Test RMSE: 0.4195, Test MAE: 0.2873
# ---------------------------------
# Model saved at epoch 8 with val RMSE 0.3421
# Patience grace period: 40
# ---------------------------------
# Epoch 9/500
# Train RMSE: 0.3513
# Val RMSE: 0.3388, Val MAE: 0.2448
# Test RMSE: 0.4180, Test MAE: 0.2858
# ---------------------------------
# Model saved at epoch 9 with val RMSE 0.3388
# Patience grace period: 40
# ---------------------------------
# Epoch 10/500
# Train RMSE: 0.3470
# Val RMSE: 0.3361, Val MAE: 0.2431
# Test RMSE: 0.4167, Test MAE: 0.2847
# ---------------------------------
# Model saved at epoch 10 with val RMSE 0.3361
# Patience grace period: 40
# ---------------------------------
# Epoch 11/500
# Train RMSE: 0.3434
# Val RMSE: 0.3336, Val MAE: 0.2414
# Test RMSE: 0.4150, Test MAE: 0.2832
# ---------------------------------
# Model saved at epoch 11 with val RMSE 0.3336
# Patience grace period: 40
# ---------------------------------
# Epoch 12/500
# Train RMSE: 0.3400
# Val RMSE: 0.3316, Val MAE: 0.2401
# Test RMSE: 0.4142, Test MAE: 0.2824
# ---------------------------------
# Model saved at epoch 12 with val RMSE 0.3316
# Patience grace period: 40
# ---------------------------------
# Epoch 13/500
# Train RMSE: 0.3371
# Val RMSE: 0.3298, Val MAE: 0.2390
# Test RMSE: 0.4134, Test MAE: 0.2818
# ---------------------------------
# Model saved at epoch 13 with val RMSE 0.3298
# Patience grace period: 40
# ---------------------------------
# Epoch 14/500
# Train RMSE: 0.3345
# Val RMSE: 0.3283, Val MAE: 0.2380
# Test RMSE: 0.4125, Test MAE: 0.2813
# ---------------------------------
# Model saved at epoch 14 with val RMSE 0.3283
# Patience grace period: 40
# ---------------------------------
# Epoch 15/500
# Train RMSE: 0.3319
# Val RMSE: 0.3270, Val MAE: 0.2371
# Test RMSE: 0.4120, Test MAE: 0.2807
# ---------------------------------
# Model saved at epoch 15 with val RMSE 0.3270
# Patience grace period: 40
# ---------------------------------
# Epoch 16/500
# Train RMSE: 0.3299
# Val RMSE: 0.3258, Val MAE: 0.2364
# Test RMSE: 0.4110, Test MAE: 0.2799
# ---------------------------------
# Model saved at epoch 16 with val RMSE 0.3258
# Patience grace period: 40
# ---------------------------------
# Epoch 17/500
# Train RMSE: 0.3278
# Val RMSE: 0.3248, Val MAE: 0.2356
# Test RMSE: 0.4107, Test MAE: 0.2796
# ---------------------------------
# Model saved at epoch 17 with val RMSE 0.3248
# Patience grace period: 40
# ---------------------------------
# Epoch 18/500
# Train RMSE: 0.3260
# Val RMSE: 0.3239, Val MAE: 0.2351
# Test RMSE: 0.4101, Test MAE: 0.2792
# ---------------------------------
# Model saved at epoch 18 with val RMSE 0.3239
# Patience grace period: 39
# ---------------------------------
# Epoch 19/500
# Train RMSE: 0.3244
# Val RMSE: 0.3231, Val MAE: 0.2345
# Test RMSE: 0.4105, Test MAE: 0.2793
# ---------------------------------
# Model saved at epoch 19 with val RMSE 0.3231
# Patience grace period: 40
# ---------------------------------
# Epoch 20/500
# Train RMSE: 0.3227
# Val RMSE: 0.3224, Val MAE: 0.2340
# Test RMSE: 0.4099, Test MAE: 0.2788
# ---------------------------------
# Model saved at epoch 20 with val RMSE 0.3224
# Patience grace period: 39
# ---------------------------------
# Epoch 21/500
# Train RMSE: 0.3214
# Val RMSE: 0.3219, Val MAE: 0.2338
# Test RMSE: 0.4104, Test MAE: 0.2791
# ---------------------------------
# Model saved at epoch 21 with val RMSE 0.3219
# Patience grace period: 40
# ---------------------------------
# Epoch 22/500
# Train RMSE: 0.3200
# Val RMSE: 0.3213, Val MAE: 0.2333
# Test RMSE: 0.4106, Test MAE: 0.2793
# ---------------------------------
# Model saved at epoch 22 with val RMSE 0.3213
# Patience grace period: 39
# ---------------------------------
# Epoch 23/500
# Train RMSE: 0.3185
# Val RMSE: 0.3209, Val MAE: 0.2329
# Test RMSE: 0.4102, Test MAE: 0.2788
# ---------------------------------
# Model saved at epoch 23 with val RMSE 0.3209
# Patience grace period: 40
# ---------------------------------
# Epoch 24/500
# Train RMSE: 0.3174
# Val RMSE: 0.3203, Val MAE: 0.2326
# Test RMSE: 0.4098, Test MAE: 0.2786
# ---------------------------------
# Model saved at epoch 24 with val RMSE 0.3203
# Patience grace period: 39
# ---------------------------------
# Epoch 25/500
# Train RMSE: 0.3162
# Val RMSE: 0.3200, Val MAE: 0.2323
# Test RMSE: 0.4092, Test MAE: 0.2780
# ---------------------------------
# Model saved at epoch 25 with val RMSE 0.3200
# Patience grace period: 38
# ---------------------------------
# Epoch 26/500
# Train RMSE: 0.3149
# Val RMSE: 0.3197, Val MAE: 0.2321
# Test RMSE: 0.4102, Test MAE: 0.2786
# ---------------------------------
# Model saved at epoch 26 with val RMSE 0.3197
# Patience grace period: 40
# ---------------------------------
# Epoch 27/500
# Train RMSE: 0.3139
# Val RMSE: 0.3192, Val MAE: 0.2318
# Test RMSE: 0.4101, Test MAE: 0.2785
# ---------------------------------
# Model saved at epoch 27 with val RMSE 0.3192
# Patience grace period: 39
# ---------------------------------
# Epoch 28/500
# Train RMSE: 0.3129
# Val RMSE: 0.3189, Val MAE: 0.2316
# Test RMSE: 0.4101, Test MAE: 0.2784
# ---------------------------------
# Model saved at epoch 28 with val RMSE 0.3189
# Patience grace period: 38
# ---------------------------------
# Epoch 29/500
# Train RMSE: 0.3118
# Val RMSE: 0.3186, Val MAE: 0.2313
# Test RMSE: 0.4091, Test MAE: 0.2779
# ---------------------------------
# Model saved at epoch 29 with val RMSE 0.3186
# Patience grace period: 40
# ---------------------------------
# Epoch 30/500
# Train RMSE: 0.3110
# Val RMSE: 0.3186, Val MAE: 0.2313
# Test RMSE: 0.4105, Test MAE: 0.2786
# ---------------------------------
# Patience grace period: 38
# ---------------------------------
# Epoch 31/500
# Train RMSE: 0.3100
# Val RMSE: 0.3183, Val MAE: 0.2311
# Test RMSE: 0.4096, Test MAE: 0.2782
# ---------------------------------
# Model saved at epoch 31 with val RMSE 0.3183
# Patience grace period: 37
# ---------------------------------
# Epoch 32/500
# Train RMSE: 0.3091
# Val RMSE: 0.3179, Val MAE: 0.2308
# Test RMSE: 0.4092, Test MAE: 0.2779
# ---------------------------------
# Model saved at epoch 32 with val RMSE 0.3179
# Patience grace period: 36
# ---------------------------------
# Epoch 33/500
# Train RMSE: 0.3083
# Val RMSE: 0.3177, Val MAE: 0.2306
# Test RMSE: 0.4090, Test MAE: 0.2774
# ---------------------------------
# Model saved at epoch 33 with val RMSE 0.3177
# Patience grace period: 35
# ---------------------------------
# Epoch 34/500
# Train RMSE: 0.3074
# Val RMSE: 0.3181, Val MAE: 0.2309
# Test RMSE: 0.4101, Test MAE: 0.2782
# ---------------------------------
# Patience grace period: 33
# ---------------------------------
# Epoch 35/500
# Train RMSE: 0.3067
# Val RMSE: 0.3174, Val MAE: 0.2304
# Test RMSE: 0.4096, Test MAE: 0.2779
# ---------------------------------
# Model saved at epoch 35 with val RMSE 0.3174
# Patience grace period: 40
# ---------------------------------
# Epoch 36/500
# Train RMSE: 0.3059
# Val RMSE: 0.3173, Val MAE: 0.2304
# Test RMSE: 0.4099, Test MAE: 0.2784
# ---------------------------------
# Model saved at epoch 36 with val RMSE 0.3173
# Patience grace period: 38
# ---------------------------------
# Epoch 37/500
# Train RMSE: 0.3052
# Val RMSE: 0.3178, Val MAE: 0.2307
# Test RMSE: 0.4114, Test MAE: 0.2790
# ---------------------------------
# Patience grace period: 36
# ---------------------------------
# Epoch 38/500
# Train RMSE: 0.3045
# Val RMSE: 0.3169, Val MAE: 0.2300
# Test RMSE: 0.4095, Test MAE: 0.2781
# ---------------------------------
# Model saved at epoch 38 with val RMSE 0.3169
# Patience grace period: 35
# ---------------------------------
# Epoch 39/500
# Train RMSE: 0.3038
# Val RMSE: 0.3174, Val MAE: 0.2305
# Test RMSE: 0.4100, Test MAE: 0.2782
# ---------------------------------
# Patience grace period: 33
# ---------------------------------
# Epoch 40/500
# Train RMSE: 0.3031
# Val RMSE: 0.3171, Val MAE: 0.2300
# Test RMSE: 0.4108, Test MAE: 0.2786
# ---------------------------------
# Patience grace period: 32
# ---------------------------------
# Epoch 41/500
# Train RMSE: 0.3024
# Val RMSE: 0.3170, Val MAE: 0.2301
# Test RMSE: 0.4098, Test MAE: 0.2781
# ---------------------------------
# Patience grace period: 31
# ---------------------------------
# Epoch 42/500
# Train RMSE: 0.3018
# Val RMSE: 0.3168, Val MAE: 0.2299
# Test RMSE: 0.4096, Test MAE: 0.2778
# ---------------------------------
# Model saved at epoch 42 with val RMSE 0.3168
# Patience grace period: 30
# ---------------------------------
# Epoch 43/500
# Train RMSE: 0.3012
# Val RMSE: 0.3169, Val MAE: 0.2300
# Test RMSE: 0.4089, Test MAE: 0.2771
# ---------------------------------
# Patience grace period: 28
# ---------------------------------
# Epoch 44/500
# Train RMSE: 0.3007
# Val RMSE: 0.3172, Val MAE: 0.2303
# Test RMSE: 0.4114, Test MAE: 0.2787
# ---------------------------------
# Patience grace period: 26
# ---------------------------------
# Epoch 45/500
# Train RMSE: 0.3001
# Val RMSE: 0.3170, Val MAE: 0.2301
# Test RMSE: 0.4111, Test MAE: 0.2786
# ---------------------------------
# Patience grace period: 25
# ---------------------------------
# Epoch 46/500
# Train RMSE: 0.2995
# Val RMSE: 0.3171, Val MAE: 0.2301
# Test RMSE: 0.4105, Test MAE: 0.2783
# ---------------------------------
# Patience grace period: 23
# ---------------------------------
# Epoch 47/500
# Train RMSE: 0.2990
# Val RMSE: 0.3171, Val MAE: 0.2301
# Test RMSE: 0.4109, Test MAE: 0.2786
# ---------------------------------
# Patience grace period: 21
# ---------------------------------
# Epoch 48/500
# Train RMSE: 0.2985
# Val RMSE: 0.3172, Val MAE: 0.2300
# Test RMSE: 0.4121, Test MAE: 0.2793
# ---------------------------------
# Patience grace period: 19
# ---------------------------------
# Epoch 49/500
# Train RMSE: 0.2979
# Val RMSE: 0.3168, Val MAE: 0.2299
# Test RMSE: 0.4090, Test MAE: 0.2774
# ---------------------------------
# Patience grace period: 18
# ---------------------------------
# Epoch 50/500
# Train RMSE: 0.2973
# Val RMSE: 0.3164, Val MAE: 0.2296
# Test RMSE: 0.4099, Test MAE: 0.2779
# ---------------------------------
# Model saved at epoch 50 with val RMSE 0.3164
# Patience grace period: 17
# ---------------------------------
# Epoch 51/500
# Train RMSE: 0.2970
# Val RMSE: 0.3163, Val MAE: 0.2295
# Test RMSE: 0.4094, Test MAE: 0.2775
# ---------------------------------
# Model saved at epoch 51 with val RMSE 0.3163
# Patience grace period: 40
# ---------------------------------
# Epoch 52/500
# Train RMSE: 0.2965
# Val RMSE: 0.3161, Val MAE: 0.2293
# Test RMSE: 0.4079, Test MAE: 0.2765
# ---------------------------------
# Model saved at epoch 52 with val RMSE 0.3161
# Patience grace period: 39
# ---------------------------------
# Epoch 53/500
# Train RMSE: 0.2960
# Val RMSE: 0.3165, Val MAE: 0.2296
# Test RMSE: 0.4101, Test MAE: 0.2778
# ---------------------------------
# Patience grace period: 37
# ---------------------------------
# Epoch 54/500
# Train RMSE: 0.2956
# Val RMSE: 0.3162, Val MAE: 0.2294
# Test RMSE: 0.4079, Test MAE: 0.2764
# ---------------------------------
# Patience grace period: 36
# ---------------------------------
# Epoch 55/500
# Train RMSE: 0.2952
# Val RMSE: 0.3166, Val MAE: 0.2296
# Test RMSE: 0.4100, Test MAE: 0.2777
# ---------------------------------
# Patience grace period: 34
# ---------------------------------
# Epoch 56/500
# Train RMSE: 0.2950
# Val RMSE: 0.3178, Val MAE: 0.2304
# Test RMSE: 0.4123, Test MAE: 0.2791
# ---------------------------------
# Patience grace period: 32
# ---------------------------------
# Epoch 57/500
# Train RMSE: 0.2947
# Val RMSE: 0.3169, Val MAE: 0.2298
# Test RMSE: 0.4097, Test MAE: 0.2774
# ---------------------------------
# Patience grace period: 31
# ---------------------------------
# Epoch 58/500
# Train RMSE: 0.2945
# Val RMSE: 0.3162, Val MAE: 0.2293
# Test RMSE: 0.4074, Test MAE: 0.2758
# ---------------------------------
# Patience grace period: 30
# ---------------------------------
# Epoch 59/500
# Train RMSE: 0.2941
# Val RMSE: 0.3170, Val MAE: 0.2298
# Test RMSE: 0.4089, Test MAE: 0.2767
# ---------------------------------
# Patience grace period: 28
# ---------------------------------
# Epoch 60/500
# Train RMSE: 0.2936
# Val RMSE: 0.3178, Val MAE: 0.2304
# Test RMSE: 0.4108, Test MAE: 0.2778
# ---------------------------------
# Patience grace period: 26
# ---------------------------------
# Epoch 61/500
# Train RMSE: 0.2929
# Val RMSE: 0.3183, Val MAE: 0.2308
# Test RMSE: 0.4119, Test MAE: 0.2783
# ---------------------------------
# Patience grace period: 24
# ---------------------------------
# Epoch 62/500
# Train RMSE: 0.2925
# Val RMSE: 0.3181, Val MAE: 0.2306
# Test RMSE: 0.4110, Test MAE: 0.2778
# ---------------------------------
# Patience grace period: 23
# ---------------------------------
# Epoch 63/500
# Train RMSE: 0.2922
# Val RMSE: 0.3186, Val MAE: 0.2308
# Test RMSE: 0.4123, Test MAE: 0.2785
# ---------------------------------
# Patience grace period: 21
# ---------------------------------
# Epoch 64/500
# Train RMSE: 0.2918
# Val RMSE: 0.3181, Val MAE: 0.2306
# Test RMSE: 0.4103, Test MAE: 0.2774
# ---------------------------------
# Patience grace period: 20
# ---------------------------------
# Epoch 65/500
# Train RMSE: 0.2914
# Val RMSE: 0.3185, Val MAE: 0.2308
# Test RMSE: 0.4119, Test MAE: 0.2784
# ---------------------------------
# Patience grace period: 18
# ---------------------------------
# Epoch 66/500
# Train RMSE: 0.2911
# Val RMSE: 0.3191, Val MAE: 0.2313
# Test RMSE: 0.4132, Test MAE: 0.2791
# ---------------------------------
# Patience grace period: 16
# ---------------------------------
# Epoch 67/500
# Train RMSE: 0.2907
# Val RMSE: 0.3187, Val MAE: 0.2311
# Test RMSE: 0.4102, Test MAE: 0.2774
# ---------------------------------
# Patience grace period: 15
# ---------------------------------
# Epoch 68/500
# Train RMSE: 0.2904
# Val RMSE: 0.3199, Val MAE: 0.2318
# Test RMSE: 0.4128, Test MAE: 0.2792
# ---------------------------------
# Patience grace period: 13
# ---------------------------------
# Epoch 69/500
# Train RMSE: 0.2901
# Val RMSE: 0.3195, Val MAE: 0.2314
# Test RMSE: 0.4121, Test MAE: 0.2787
# ---------------------------------
# Patience grace period: 12
# ---------------------------------
# Epoch 70/500
# Train RMSE: 0.2898
# Val RMSE: 0.3193, Val MAE: 0.2314
# Test RMSE: 0.4118, Test MAE: 0.2784
# ---------------------------------
# Patience grace period: 11
# ---------------------------------
# Epoch 71/500
# Train RMSE: 0.2895
# Val RMSE: 0.3190, Val MAE: 0.2312
# Test RMSE: 0.4119, Test MAE: 0.2782
# ---------------------------------
# Patience grace period: 10
# ---------------------------------
# Epoch 72/500
# Train RMSE: 0.2892
# Val RMSE: 0.3196, Val MAE: 0.2315
# Test RMSE: 0.4121, Test MAE: 0.2784
# ---------------------------------
# Patience grace period: 8
# ---------------------------------
# Epoch 73/500
# Train RMSE: 0.2890
# Val RMSE: 0.3194, Val MAE: 0.2315
# Test RMSE: 0.4119, Test MAE: 0.2782
# ---------------------------------
# Patience grace period: 7
# ---------------------------------
# Epoch 74/500
# Train RMSE: 0.2885
# Val RMSE: 0.3196, Val MAE: 0.2316
# Test RMSE: 0.4108, Test MAE: 0.2774
# ---------------------------------
# Patience grace period: 5
# ---------------------------------
# Epoch 75/500
# Train RMSE: 0.2885
# Val RMSE: 0.3198, Val MAE: 0.2317
# Test RMSE: 0.4104, Test MAE: 0.2771
# ---------------------------------
# Patience grace period: 3
# ---------------------------------
# Epoch 76/500
# Train RMSE: 0.2881
# Val RMSE: 0.3193, Val MAE: 0.2312
# Test RMSE: 0.4124, Test MAE: 0.2786
# ---------------------------------
# Patience grace period: 2
# ---------------------------------
# Epoch 77/500
# Train RMSE: 0.2879
# Val RMSE: 0.3203, Val MAE: 0.2319
# Test RMSE: 0.4126, Test MAE: 0.2789
# ---------------------------------
# Patience grace period: 0
# Early stopping triggered at epoch 77
# Final Test RMSE: 0.4079, Final Test MAE: 0.2765
# Pearson Corr: 0.8739305695973855
# Spearman Corr: 0.8501960108758198
# p-rmse: 0.4078519305170988
#        rmse       mae  seed                            subtask    method  \
# 0  0.407852  0.276474     2  openproblems_bmmc_cite_phase2_rna  original
#
#     pearson p_value_pearson  spearman p_value_spearman
# 0  0.873931          0.0000  0.850196           0.0000
# <ipython-input-2-d8b64875fc37>:120: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   self.model.load_state_dict(torch.load(os.path.join(save_dir, 'best_model.pth')))
# ---------------------------------
# Epoch 1/500
# Train RMSE: 0.6735
# Val RMSE: 0.4924, Val MAE: 0.3486
# Test RMSE: 0.5391, Test MAE: 0.3610
# ---------------------------------
# Model saved at epoch 1 with val RMSE 0.4924
# Patience grace period: 40
# ---------------------------------
# Epoch 2/500
# Train RMSE: 0.4746
# Val RMSE: 0.4152, Val MAE: 0.2941
# Test RMSE: 0.4740, Test MAE: 0.3168
# ---------------------------------
# Model saved at epoch 2 with val RMSE 0.4152
# Patience grace period: 40
# ---------------------------------
# Epoch 3/500
# Train RMSE: 0.4215
# Val RMSE: 0.3852, Val MAE: 0.2733
# Test RMSE: 0.4573, Test MAE: 0.3097
# ---------------------------------
# Model saved at epoch 3 with val RMSE 0.3852
# Patience grace period: 40
# ---------------------------------
# Epoch 4/500
# Train RMSE: 0.3973
# Val RMSE: 0.3696, Val MAE: 0.2639
# Test RMSE: 0.4438, Test MAE: 0.3037
# ---------------------------------
# Model saved at epoch 4 with val RMSE 0.3696
# Patience grace period: 40
# ---------------------------------
# Epoch 5/500
# Train RMSE: 0.3811
# Val RMSE: 0.3579, Val MAE: 0.2569
# Test RMSE: 0.4331, Test MAE: 0.2971
# ---------------------------------
# Model saved at epoch 5 with val RMSE 0.3579
# Patience grace period: 40
# ---------------------------------
# Epoch 6/500
# Train RMSE: 0.3694
# Val RMSE: 0.3502, Val MAE: 0.2522
# Test RMSE: 0.4270, Test MAE: 0.2926
# ---------------------------------
# Model saved at epoch 6 with val RMSE 0.3502
# Patience grace period: 40
# ---------------------------------
# Epoch 7/500
# Train RMSE: 0.3615
# Val RMSE: 0.3452, Val MAE: 0.2488
# Test RMSE: 0.4237, Test MAE: 0.2900
# ---------------------------------
# Model saved at epoch 7 with val RMSE 0.3452
# Patience grace period: 40
# ---------------------------------
# Epoch 8/500
# Train RMSE: 0.3556
# Val RMSE: 0.3414, Val MAE: 0.2464
# Test RMSE: 0.4216, Test MAE: 0.2883
# ---------------------------------
# Model saved at epoch 8 with val RMSE 0.3414
# Patience grace period: 40
# ---------------------------------
# Epoch 9/500
# Train RMSE: 0.3507
# Val RMSE: 0.3383, Val MAE: 0.2443
# Test RMSE: 0.4197, Test MAE: 0.2867
# ---------------------------------
# Model saved at epoch 9 with val RMSE 0.3383
# Patience grace period: 40
# ---------------------------------
# Epoch 10/500
# Train RMSE: 0.3465
# Val RMSE: 0.3356, Val MAE: 0.2426
# Test RMSE: 0.4180, Test MAE: 0.2855
# ---------------------------------
# Model saved at epoch 10 with val RMSE 0.3356
# Patience grace period: 40
# ---------------------------------
# Epoch 11/500
# Train RMSE: 0.3427
# Val RMSE: 0.3333, Val MAE: 0.2411
# Test RMSE: 0.4164, Test MAE: 0.2841
# ---------------------------------
# Model saved at epoch 11 with val RMSE 0.3333
# Patience grace period: 40
# ---------------------------------
# Epoch 12/500
# Train RMSE: 0.3396
# Val RMSE: 0.3313, Val MAE: 0.2398
# Test RMSE: 0.4155, Test MAE: 0.2835
# ---------------------------------
# Model saved at epoch 12 with val RMSE 0.3313
# Patience grace period: 40
# ---------------------------------
# Epoch 13/500
# Train RMSE: 0.3367
# Val RMSE: 0.3296, Val MAE: 0.2386
# Test RMSE: 0.4151, Test MAE: 0.2828
# ---------------------------------
# Model saved at epoch 13 with val RMSE 0.3296
# Patience grace period: 40
# ---------------------------------
# Epoch 14/500
# Train RMSE: 0.3341
# Val RMSE: 0.3281, Val MAE: 0.2376
# Test RMSE: 0.4139, Test MAE: 0.2820
# ---------------------------------
# Model saved at epoch 14 with val RMSE 0.3281
# Patience grace period: 40
# ---------------------------------
# Epoch 15/500
# Train RMSE: 0.3318
# Val RMSE: 0.3269, Val MAE: 0.2369
# Test RMSE: 0.4141, Test MAE: 0.2818
# ---------------------------------
# Model saved at epoch 15 with val RMSE 0.3269
# Patience grace period: 40
# ---------------------------------
# Epoch 16/500
# Train RMSE: 0.3297
# Val RMSE: 0.3259, Val MAE: 0.2362
# Test RMSE: 0.4144, Test MAE: 0.2819
# ---------------------------------
# Model saved at epoch 16 with val RMSE 0.3259
# Patience grace period: 40
# ---------------------------------
# Epoch 17/500
# Train RMSE: 0.3278
# Val RMSE: 0.3248, Val MAE: 0.2355
# Test RMSE: 0.4127, Test MAE: 0.2804
# ---------------------------------
# Model saved at epoch 17 with val RMSE 0.3248
# Patience grace period: 40
# ---------------------------------
# Epoch 18/500
# Train RMSE: 0.3259
# Val RMSE: 0.3238, Val MAE: 0.2347
# Test RMSE: 0.4116, Test MAE: 0.2799
# ---------------------------------
# Model saved at epoch 18 with val RMSE 0.3238
# Patience grace period: 40
# ---------------------------------
# Epoch 19/500
# Train RMSE: 0.3243
# Val RMSE: 0.3231, Val MAE: 0.2344
# Test RMSE: 0.4116, Test MAE: 0.2795
# ---------------------------------
# Model saved at epoch 19 with val RMSE 0.3231
# Patience grace period: 39
# ---------------------------------
# Epoch 20/500
# Train RMSE: 0.3228
# Val RMSE: 0.3223, Val MAE: 0.2337
# Test RMSE: 0.4118, Test MAE: 0.2798
# ---------------------------------
# Model saved at epoch 20 with val RMSE 0.3223
# Patience grace period: 40
# ---------------------------------
# Epoch 21/500
# Train RMSE: 0.3214
# Val RMSE: 0.3217, Val MAE: 0.2333
# Test RMSE: 0.4119, Test MAE: 0.2795
# ---------------------------------
# Model saved at epoch 21 with val RMSE 0.3217
# Patience grace period: 39
# ---------------------------------
# Epoch 22/500
# Train RMSE: 0.3199
# Val RMSE: 0.3212, Val MAE: 0.2331
# Test RMSE: 0.4125, Test MAE: 0.2797
# ---------------------------------
# Model saved at epoch 22 with val RMSE 0.3212
# Patience grace period: 40
# ---------------------------------
# Epoch 23/500
# Train RMSE: 0.3187
# Val RMSE: 0.3206, Val MAE: 0.2326
# Test RMSE: 0.4110, Test MAE: 0.2789
# ---------------------------------
# Model saved at epoch 23 with val RMSE 0.3206
# Patience grace period: 39
# ---------------------------------
# Epoch 24/500
# Train RMSE: 0.3174
# Val RMSE: 0.3200, Val MAE: 0.2323
# Test RMSE: 0.4112, Test MAE: 0.2787
# ---------------------------------
# Model saved at epoch 24 with val RMSE 0.3200
# Patience grace period: 40
# ---------------------------------
# Epoch 25/500
# Train RMSE: 0.3162
# Val RMSE: 0.3197, Val MAE: 0.2319
# Test RMSE: 0.4116, Test MAE: 0.2788
# ---------------------------------
# Model saved at epoch 25 with val RMSE 0.3197
# Patience grace period: 39
# ---------------------------------
# Epoch 26/500
# Train RMSE: 0.3151
# Val RMSE: 0.3194, Val MAE: 0.2318
# Test RMSE: 0.4105, Test MAE: 0.2779
# ---------------------------------
# Model saved at epoch 26 with val RMSE 0.3194
# Patience grace period: 38
# ---------------------------------
# Epoch 27/500
# Train RMSE: 0.3140
# Val RMSE: 0.3191, Val MAE: 0.2317
# Test RMSE: 0.4123, Test MAE: 0.2790
# ---------------------------------
# Model saved at epoch 27 with val RMSE 0.3191
# Patience grace period: 37
# ---------------------------------
# Epoch 28/500
# Train RMSE: 0.3128
# Val RMSE: 0.3186, Val MAE: 0.2313
# Test RMSE: 0.4117, Test MAE: 0.2787
# ---------------------------------
# Model saved at epoch 28 with val RMSE 0.3186
# Patience grace period: 40
# ---------------------------------
# Epoch 29/500
# Train RMSE: 0.3119
# Val RMSE: 0.3183, Val MAE: 0.2310
# Test RMSE: 0.4105, Test MAE: 0.2778
# ---------------------------------
# Model saved at epoch 29 with val RMSE 0.3183
# Patience grace period: 39
# ---------------------------------
# Epoch 30/500
# Train RMSE: 0.3110
# Val RMSE: 0.3180, Val MAE: 0.2309
# Test RMSE: 0.4110, Test MAE: 0.2778
# ---------------------------------
# Model saved at epoch 30 with val RMSE 0.3180
# Patience grace period: 38
# ---------------------------------
# Epoch 31/500
# Train RMSE: 0.3102
# Val RMSE: 0.3179, Val MAE: 0.2308
# Test RMSE: 0.4106, Test MAE: 0.2774
# ---------------------------------
# Model saved at epoch 31 with val RMSE 0.3179
# Patience grace period: 37
# ---------------------------------
# Epoch 32/500
# Train RMSE: 0.3092
# Val RMSE: 0.3177, Val MAE: 0.2305
# Test RMSE: 0.4119, Test MAE: 0.2784
# ---------------------------------
# Model saved at epoch 32 with val RMSE 0.3177
# Patience grace period: 36
# ---------------------------------
# Epoch 33/500
# Train RMSE: 0.3084
# Val RMSE: 0.3172, Val MAE: 0.2303
# Test RMSE: 0.4114, Test MAE: 0.2780
# ---------------------------------
# Model saved at epoch 33 with val RMSE 0.3172
# Patience grace period: 40
# ---------------------------------
# Epoch 34/500
# Train RMSE: 0.3075
# Val RMSE: 0.3169, Val MAE: 0.2301
# Test RMSE: 0.4106, Test MAE: 0.2776
# ---------------------------------
# Model saved at epoch 34 with val RMSE 0.3169
# Patience grace period: 39
# ---------------------------------
# Epoch 35/500
# Train RMSE: 0.3069
# Val RMSE: 0.3171, Val MAE: 0.2302
# Test RMSE: 0.4120, Test MAE: 0.2783
# ---------------------------------
# Patience grace period: 37
# ---------------------------------
# Epoch 36/500
# Train RMSE: 0.3060
# Val RMSE: 0.3167, Val MAE: 0.2299
# Test RMSE: 0.4108, Test MAE: 0.2775
# ---------------------------------
# Model saved at epoch 36 with val RMSE 0.3167
# Patience grace period: 36
# ---------------------------------
# Epoch 37/500
# Train RMSE: 0.3052
# Val RMSE: 0.3166, Val MAE: 0.2298
# Test RMSE: 0.4111, Test MAE: 0.2777
# ---------------------------------
# Model saved at epoch 37 with val RMSE 0.3166
# Patience grace period: 35
# ---------------------------------
# Epoch 38/500
# Train RMSE: 0.3046
# Val RMSE: 0.3165, Val MAE: 0.2298
# Test RMSE: 0.4109, Test MAE: 0.2772
# ---------------------------------
# Model saved at epoch 38 with val RMSE 0.3165
# Patience grace period: 34
# ---------------------------------
# Epoch 39/500
# Train RMSE: 0.3039
# Val RMSE: 0.3165, Val MAE: 0.2297
# ...
# Val RMSE: 0.3462, Val MAE: 0.2496
# Test RMSE: 0.4231, Test MAE: 0.2893
# ---------------------------------
# Model saved at epoch 7 with val RMSE 0.3462
# Patience grace period: 40
# ---------------------------------
# Epoch 8/500
# Train RMSE: 0.3569
# Val RMSE: 0.3424, Val MAE: 0.2471
# Test RMSE: 0.4216, Test MAE: 0.2883
# ---------------------------------
# Model saved at epoch 8 with val RMSE 0.3424
# Patience grace period: 40
# ---------------------------------
# Epoch 9/500
# Train RMSE: 0.3520
# Val RMSE: 0.3392, Val MAE: 0.2451
# Test RMSE: 0.4203, Test MAE: 0.2870
# ---------------------------------
# Model saved at epoch 9 with val RMSE 0.3392
# Patience grace period: 40
# ---------------------------------
# Epoch 10/500
# Train RMSE: 0.3477
# Val RMSE: 0.3364, Val MAE: 0.2433
# Test RMSE: 0.4185, Test MAE: 0.2857
# ---------------------------------
# Model saved at epoch 10 with val RMSE 0.3364
# Patience grace period: 40
# ---------------------------------
# Epoch 11/500
# Train RMSE: 0.3439
# Val RMSE: 0.3341, Val MAE: 0.2417
# Test RMSE: 0.4173, Test MAE: 0.2845
# ---------------------------------
# Model saved at epoch 11 with val RMSE 0.3341
# Patience grace period: 40
# ---------------------------------
# Epoch 12/500
# Train RMSE: 0.3405
# Val RMSE: 0.3321, Val MAE: 0.2405
# Test RMSE: 0.4163, Test MAE: 0.2839
# ---------------------------------
# Model saved at epoch 12 with val RMSE 0.3321
# Patience grace period: 40
# ---------------------------------
# Epoch 13/500
# Train RMSE: 0.3375
# Val RMSE: 0.3303, Val MAE: 0.2393
# Test RMSE: 0.4152, Test MAE: 0.2831
# ---------------------------------
# Model saved at epoch 13 with val RMSE 0.3303
# Patience grace period: 40
# ---------------------------------
# Epoch 14/500
# Train RMSE: 0.3349
# Val RMSE: 0.3288, Val MAE: 0.2382
# Test RMSE: 0.4146, Test MAE: 0.2823
# ---------------------------------
# Model saved at epoch 14 with val RMSE 0.3288
# Patience grace period: 40
# ---------------------------------
# Epoch 15/500
# Train RMSE: 0.3325
# Val RMSE: 0.3274, Val MAE: 0.2373
# Test RMSE: 0.4142, Test MAE: 0.2820
# ---------------------------------
# Model saved at epoch 15 with val RMSE 0.3274
# Patience grace period: 40
# ---------------------------------
# Epoch 16/500
# Train RMSE: 0.3303
# Val RMSE: 0.3263, Val MAE: 0.2365
# Test RMSE: 0.4124, Test MAE: 0.2808
# ---------------------------------
# Model saved at epoch 16 with val RMSE 0.3263
# Patience grace period: 40
# ---------------------------------
# Epoch 17/500
# Train RMSE: 0.3284
# Val RMSE: 0.3254, Val MAE: 0.2359
# Test RMSE: 0.4123, Test MAE: 0.2804
# ---------------------------------
# Model saved at epoch 17 with val RMSE 0.3254
# Patience grace period: 39
# ---------------------------------
# Epoch 18/500
# Train RMSE: 0.3265
# Val RMSE: 0.3244, Val MAE: 0.2352
# Test RMSE: 0.4121, Test MAE: 0.2801
# ---------------------------------
# Model saved at epoch 18 with val RMSE 0.3244
# Patience grace period: 40
# ---------------------------------
# Epoch 19/500
# Train RMSE: 0.3248
# Val RMSE: 0.3236, Val MAE: 0.2347
# Test RMSE: 0.4114, Test MAE: 0.2798
# ---------------------------------
# Model saved at epoch 19 with val RMSE 0.3236
# Patience grace period: 39
# ---------------------------------
# Epoch 20/500
# Train RMSE: 0.3233
# Val RMSE: 0.3228, Val MAE: 0.2341
# Test RMSE: 0.4115, Test MAE: 0.2796
# ---------------------------------
# Model saved at epoch 20 with val RMSE 0.3228
# Patience grace period: 40
# ---------------------------------
# Epoch 21/500
# Train RMSE: 0.3217
# Val RMSE: 0.3222, Val MAE: 0.2337
# Test RMSE: 0.4115, Test MAE: 0.2796
# ---------------------------------
# Model saved at epoch 21 with val RMSE 0.3222
# Patience grace period: 39
# ---------------------------------
# Epoch 22/500
# Train RMSE: 0.3204
# Val RMSE: 0.3216, Val MAE: 0.2333
# Test RMSE: 0.4124, Test MAE: 0.2801
# ---------------------------------
# Model saved at epoch 22 with val RMSE 0.3216
# Patience grace period: 40
# ---------------------------------
# Epoch 23/500
# Train RMSE: 0.3191
# Val RMSE: 0.3211, Val MAE: 0.2330
# Test RMSE: 0.4117, Test MAE: 0.2796
# ---------------------------------
# Model saved at epoch 23 with val RMSE 0.3211
# Patience grace period: 39
# ---------------------------------
# Epoch 24/500
# Train RMSE: 0.3180
# Val RMSE: 0.3205, Val MAE: 0.2325
# Test RMSE: 0.4116, Test MAE: 0.2793
# ---------------------------------
# Model saved at epoch 24 with val RMSE 0.3205
# Patience grace period: 40
# ---------------------------------
# Epoch 25/500
# Train RMSE: 0.3168
# Val RMSE: 0.3201, Val MAE: 0.2323
# Test RMSE: 0.4110, Test MAE: 0.2792
# ---------------------------------
# Model saved at epoch 25 with val RMSE 0.3201
# Patience grace period: 39
# ---------------------------------
# Epoch 26/500
# Train RMSE: 0.3157
# Val RMSE: 0.3199, Val MAE: 0.2322
# Test RMSE: 0.4129, Test MAE: 0.2802
# ---------------------------------
# Model saved at epoch 26 with val RMSE 0.3199
# Patience grace period: 38
# ---------------------------------
# Epoch 27/500
# Train RMSE: 0.3146
# Val RMSE: 0.3196, Val MAE: 0.2320
# Test RMSE: 0.4137, Test MAE: 0.2807
# ---------------------------------
# Model saved at epoch 27 with val RMSE 0.3196
# Patience grace period: 37
# ---------------------------------
# Epoch 28/500
# Train RMSE: 0.3136
# Val RMSE: 0.3191, Val MAE: 0.2316
# Test RMSE: 0.4127, Test MAE: 0.2800
# ---------------------------------
# Model saved at epoch 28 with val RMSE 0.3191
# Patience grace period: 40
# ---------------------------------
# Epoch 29/500
# Train RMSE: 0.3126
# Val RMSE: 0.3187, Val MAE: 0.2314
# Test RMSE: 0.4121, Test MAE: 0.2796
# ---------------------------------
# Model saved at epoch 29 with val RMSE 0.3187
# Patience grace period: 39
# ---------------------------------
# Epoch 30/500
# Train RMSE: 0.3117
# Val RMSE: 0.3184, Val MAE: 0.2311
# Test RMSE: 0.4127, Test MAE: 0.2797
# ---------------------------------
# Model saved at epoch 30 with val RMSE 0.3184
# Patience grace period: 38
# ---------------------------------
# Epoch 31/500
# Train RMSE: 0.3109
# Val RMSE: 0.3180, Val MAE: 0.2309
# Test RMSE: 0.4119, Test MAE: 0.2795
# ---------------------------------
# Model saved at epoch 31 with val RMSE 0.3180
# Patience grace period: 40
# ---------------------------------
# Epoch 32/500
# Train RMSE: 0.3100
# Val RMSE: 0.3179, Val MAE: 0.2307
# Test RMSE: 0.4134, Test MAE: 0.2801
# ---------------------------------
# Model saved at epoch 32 with val RMSE 0.3179
# Patience grace period: 39
# ---------------------------------
# Epoch 33/500
# Train RMSE: 0.3090
# Val RMSE: 0.3176, Val MAE: 0.2306
# Test RMSE: 0.4128, Test MAE: 0.2798
# ---------------------------------
# Model saved at epoch 33 with val RMSE 0.3176
# Patience grace period: 38
# ---------------------------------
# Epoch 34/500
# Train RMSE: 0.3083
# Val RMSE: 0.3174, Val MAE: 0.2304
# Test RMSE: 0.4121, Test MAE: 0.2796
# ---------------------------------
# Model saved at epoch 34 with val RMSE 0.3174
# Patience grace period: 37
# ---------------------------------
# Epoch 35/500
# Train RMSE: 0.3075
# Val RMSE: 0.3174, Val MAE: 0.2304
# Test RMSE: 0.4133, Test MAE: 0.2800
# ---------------------------------
# Model saved at epoch 35 with val RMSE 0.3174
# Patience grace period: 36
# ---------------------------------
# Epoch 36/500
# Train RMSE: 0.3067
# Val RMSE: 0.3172, Val MAE: 0.2302
# Test RMSE: 0.4135, Test MAE: 0.2799
# ---------------------------------
# Model saved at epoch 36 with val RMSE 0.3172
# Patience grace period: 35
# ---------------------------------
# Epoch 37/500
# Train RMSE: 0.3059
# Val RMSE: 0.3170, Val MAE: 0.2301
# Test RMSE: 0.4140, Test MAE: 0.2804
# ---------------------------------
# Model saved at epoch 37 with val RMSE 0.3170
# Patience grace period: 40
# ---------------------------------
# Epoch 38/500
# Train RMSE: 0.3052
# Val RMSE: 0.3170, Val MAE: 0.2301
# Test RMSE: 0.4131, Test MAE: 0.2797
# ---------------------------------
# Patience grace period: 38
# ---------------------------------
# Epoch 39/500
# Train RMSE: 0.3045
# Val RMSE: 0.3165, Val MAE: 0.2298
# Test RMSE: 0.4121, Test MAE: 0.2793
# ---------------------------------
# Model saved at epoch 39 with val RMSE 0.3165
# Patience grace period: 37
# ---------------------------------
# Epoch 40/500
# Train RMSE: 0.3038
# Val RMSE: 0.3163, Val MAE: 0.2295
# Test RMSE: 0.4130, Test MAE: 0.2797
# ---------------------------------
# Model saved at epoch 40 with val RMSE 0.3163
# Patience grace period: 36
# ---------------------------------
# Epoch 41/500
# Train RMSE: 0.3031
# Val RMSE: 0.3165, Val MAE: 0.2297
# Test RMSE: 0.4137, Test MAE: 0.2801
# ---------------------------------
# Patience grace period: 34
# ---------------------------------
# Epoch 42/500
# Train RMSE: 0.3026
# Val RMSE: 0.3165, Val MAE: 0.2297
# Test RMSE: 0.4143, Test MAE: 0.2805
# ---------------------------------
# Patience grace period: 32
# ---------------------------------
# Epoch 43/500
# Train RMSE: 0.3019
# Val RMSE: 0.3161, Val MAE: 0.2294
# Test RMSE: 0.4129, Test MAE: 0.2795
# ---------------------------------
# Model saved at epoch 43 with val RMSE 0.3161
# Patience grace period: 31
# ---------------------------------
# Epoch 44/500
# Train RMSE: 0.3013
# Val RMSE: 0.3161, Val MAE: 0.2294
# Test RMSE: 0.4138, Test MAE: 0.2801
# ---------------------------------
# Model saved at epoch 44 with val RMSE 0.3161
# Patience grace period: 30
# ---------------------------------
# Epoch 45/500
# Train RMSE: 0.3007
# Val RMSE: 0.3159, Val MAE: 0.2292
# Test RMSE: 0.4133, Test MAE: 0.2800
# ---------------------------------
# Model saved at epoch 45 with val RMSE 0.3159
# Patience grace period: 40
# ---------------------------------
# Epoch 46/500
# Train RMSE: 0.3001
# Val RMSE: 0.3160, Val MAE: 0.2293
# Test RMSE: 0.4142, Test MAE: 0.2803
# ---------------------------------
# Patience grace period: 38
# ---------------------------------
# Epoch 47/500
# Train RMSE: 0.2997
# Val RMSE: 0.3160, Val MAE: 0.2293
# Test RMSE: 0.4154, Test MAE: 0.2808
# ---------------------------------
# Patience grace period: 36
# ---------------------------------
# Epoch 48/500
# Train RMSE: 0.2990
# Val RMSE: 0.3159, Val MAE: 0.2292
# Test RMSE: 0.4146, Test MAE: 0.2804
# ---------------------------------
# Model saved at epoch 48 with val RMSE 0.3159
# Patience grace period: 35
# ---------------------------------
# Epoch 49/500
# Train RMSE: 0.2986
# Val RMSE: 0.3160, Val MAE: 0.2293
# Test RMSE: 0.4143, Test MAE: 0.2801
# ---------------------------------
# Patience grace period: 33
# ---------------------------------
# Epoch 50/500
# Train RMSE: 0.2980
# Val RMSE: 0.3157, Val MAE: 0.2290
# Test RMSE: 0.4138, Test MAE: 0.2802
# ---------------------------------
# Model saved at epoch 50 with val RMSE 0.3157
# Patience grace period: 32
# ---------------------------------
# Epoch 51/500
# Train RMSE: 0.2974
# Val RMSE: 0.3155, Val MAE: 0.2289
# Test RMSE: 0.4135, Test MAE: 0.2795
# ---------------------------------
# Model saved at epoch 51 with val RMSE 0.3155
# Patience grace period: 31
# ---------------------------------
# Epoch 52/500
# Train RMSE: 0.2970
# Val RMSE: 0.3160, Val MAE: 0.2293
# Test RMSE: 0.4171, Test MAE: 0.2817
# ---------------------------------
# Patience grace period: 29
# ---------------------------------
# Epoch 53/500
# Train RMSE: 0.2966
# Val RMSE: 0.3158, Val MAE: 0.2291
# Test RMSE: 0.4138, Test MAE: 0.2804
# ---------------------------------
# Patience grace period: 28
# ---------------------------------
# Epoch 54/500
# Train RMSE: 0.2961
# Val RMSE: 0.3159, Val MAE: 0.2292
# Test RMSE: 0.4148, Test MAE: 0.2806
# ---------------------------------
# Patience grace period: 26
# ---------------------------------
# Epoch 55/500
# Train RMSE: 0.2956
# Val RMSE: 0.3160, Val MAE: 0.2292
# Test RMSE: 0.4159, Test MAE: 0.2812
# ---------------------------------
# Patience grace period: 24
# ---------------------------------
# Epoch 56/500
# Train RMSE: 0.2953
# Val RMSE: 0.3156, Val MAE: 0.2289
# Test RMSE: 0.4148, Test MAE: 0.2806
# ---------------------------------
# Patience grace period: 23
# ---------------------------------
# Epoch 57/500
# Train RMSE: 0.2949
# Val RMSE: 0.3158, Val MAE: 0.2291
# Test RMSE: 0.4149, Test MAE: 0.2807
# ---------------------------------
# Patience grace period: 21
# ---------------------------------
# Epoch 58/500
# Train RMSE: 0.2944
# Val RMSE: 0.3161, Val MAE: 0.2292
# Test RMSE: 0.4157, Test MAE: 0.2813
# ---------------------------------
# Patience grace period: 19
# ---------------------------------
# Epoch 59/500
# Train RMSE: 0.2940
# Val RMSE: 0.3163, Val MAE: 0.2293
# Test RMSE: 0.4168, Test MAE: 0.2820
# ---------------------------------
# Patience grace period: 17
# ---------------------------------
# Epoch 60/500
# Train RMSE: 0.2937
# Val RMSE: 0.3162, Val MAE: 0.2292
# Test RMSE: 0.4160, Test MAE: 0.2812
# ---------------------------------
# Patience grace period: 16
# ---------------------------------
# Epoch 61/500
# Train RMSE: 0.2934
# Val RMSE: 0.3157, Val MAE: 0.2291
# Test RMSE: 0.4153, Test MAE: 0.2810
# ---------------------------------
# Patience grace period: 15
# ---------------------------------
# Epoch 62/500
# Train RMSE: 0.2931
# Val RMSE: 0.3154, Val MAE: 0.2288
# Test RMSE: 0.4128, Test MAE: 0.2794
# ---------------------------------
# Model saved at epoch 62 with val RMSE 0.3154
# Patience grace period: 14
# ---------------------------------
# Epoch 63/500
# Train RMSE: 0.2929
# Val RMSE: 0.3158, Val MAE: 0.2291
# Test RMSE: 0.4104, Test MAE: 0.2780
# ---------------------------------
# Patience grace period: 12
# ---------------------------------
# Epoch 64/500
# Train RMSE: 0.2928
# Val RMSE: 0.3153, Val MAE: 0.2287
# Test RMSE: 0.4103, Test MAE: 0.2781
# ---------------------------------
# Model saved at epoch 64 with val RMSE 0.3153
# Patience grace period: 11
# ---------------------------------
# Epoch 65/500
# Train RMSE: 0.2928
# Val RMSE: 0.3150, Val MAE: 0.2285
# Test RMSE: 0.4104, Test MAE: 0.2778
# ---------------------------------
# Model saved at epoch 65 with val RMSE 0.3150
# Patience grace period: 10
# ---------------------------------
# Epoch 66/500
# Train RMSE: 0.2926
# Val RMSE: 0.3167, Val MAE: 0.2295
# Test RMSE: 0.4160, Test MAE: 0.2809
# ---------------------------------
# Patience grace period: 8
# ---------------------------------
# Epoch 67/500
# Train RMSE: 0.2919
# Val RMSE: 0.3174, Val MAE: 0.2301
# Test RMSE: 0.4190, Test MAE: 0.2827
# ---------------------------------
# Patience grace period: 6
# ---------------------------------
# Epoch 68/500
# Train RMSE: 0.2914
# Val RMSE: 0.3172, Val MAE: 0.2298
# Test RMSE: 0.4171, Test MAE: 0.2814
# ---------------------------------
# Patience grace period: 5
# ---------------------------------
# Epoch 69/500
# Train RMSE: 0.2908
# Val RMSE: 0.3173, Val MAE: 0.2298
# Test RMSE: 0.4184, Test MAE: 0.2825
# ---------------------------------
# Patience grace period: 3
# ---------------------------------
# Epoch 70/500
# Train RMSE: 0.2904
# Val RMSE: 0.3176, Val MAE: 0.2300
# Test RMSE: 0.4185, Test MAE: 0.2824
# ---------------------------------
# Patience grace period: 1
# ---------------------------------
# Epoch 71/500
# Train RMSE: 0.2902
# Val RMSE: 0.3185, Val MAE: 0.2307
# Test RMSE: 0.4210, Test MAE: 0.2840
# ---------------------------------
# Patience grace period: -1
# Early stopping triggered at epoch 71
# Final Test RMSE: 0.4104, Final Test MAE: 0.2778
# Pearson Corr: 0.8716131399477894
# Spearman Corr: 0.8483114860707308
# p-rmse: 0.4104147505191022
#        rmse       mae  seed                            subtask    method  \
# 0  0.410415  0.277822     5  openproblems_bmmc_cite_phase2_rna  original
#
#     pearson p_value_pearson  spearman p_value_spearman
# 0  0.871613          0.0000  0.848311           0.0000
# <ipython-input-2-d8b64875fc37>:120: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   self.model.load_state_dict(torch.load(os.path.join(save_dir, 'best_model.pth')))

# %%
config_hierachical_RNA = {
    "subtask": "openproblems_bmmc_cite_phase2_rna",
    "batch_size": 520,
    "act": "leaky_relu",
    "conv_flow": ["gat"],
    "agg_flow": [None],
    "device": "cuda",
    "learning_rate": 0.000064,
    "hidden_size": 512,
    "num_heads": 2,
    "n_neigbours": 3,
    "n_components": 1200,
    "metric": "euclidean",
    "dropout_rate": 0.2,
    "num_epochs": 500,
    "seed": 1,
    "es_patience": 30,
    "es_min_delta": 0.001,
    "es_rate_threshold": 0.0001,
    "layer_dim_ex": 3,
    "verbose": True,
    "sample": True,
    "preprocessing_type": "SVD",
    "variant": "hierarchical",
    "num_clusters": 10
}

pipeline(**config_hierachical_RNA)
# Out:
# [INFO][2025-04-06 08:53:58,211][dance][_load_raw_data] Loading /content/data/openproblems_bmmc_cite_phase2_rna/openproblems_bmmc_cite_phase2_rna.censor_dataset.output_train_mod1.h5ad
# Initializing pipeline...
# [INFO][2025-04-06 08:54:05,452][dance][_load_raw_data] Loading /content/data/openproblems_bmmc_cite_phase2_rna/openproblems_bmmc_cite_phase2_rna.censor_dataset.output_train_mod2.h5ad
# [INFO][2025-04-06 08:54:06,068][dance][_load_raw_data] Loading /content/data/openproblems_bmmc_cite_phase2_rna/openproblems_bmmc_cite_phase2_rna.censor_dataset.output_test_mod1.h5ad
# [INFO][2025-04-06 08:54:06,257][dance][_load_raw_data] Loading /content/data/openproblems_bmmc_cite_phase2_rna/openproblems_bmmc_cite_phase2_rna.censor_dataset.output_test_mod2.h5ad
# [INFO][2025-04-06 08:54:06,282][dance][_maybe_preprocess] Preprocessing done.
# /usr/local/lib/python3.11/dist-packages/mudata/_core/mudata.py:1531: FutureWarning: From 0.4 .update() will not pull obs/var columns from individual modalities by default anymore. Set mudata.set_options(pull_on_update=False) to adopt the new behaviour, which will become the default. Use new pull_obs/pull_var and push_obs/push_var methods for more flexibility.
#   self._update_attr("var", axis=0, join_common=join_common)
# /usr/local/lib/python3.11/dist-packages/mudata/_core/mudata.py:931: UserWarning: Cannot join columns with the same name because var_names are intersecting.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/mudata/_core/mudata.py:1429: FutureWarning: From 0.4 .update() will not pull obs/var columns from individual modalities by default anymore. Set mudata.set_options(pull_on_update=False) to adopt the new behaviour, which will become the default. Use new pull_obs/pull_var and push_obs/push_var methods for more flexibility.
#   self._update_attr("obs", axis=1, join_common=join_common)
# /usr/local/lib/python3.11/dist-packages/mudata/_core/mudata.py:1558: UserWarning: Modality names will be prepended to var_names since there are identical var_names in different modalities.
#   warnings.warn(
# [INFO][2025-04-06 08:54:13,425][dance][set_config_from_dict] Setting config 'feature_mod' to 'mod1'
# [INFO][2025-04-06 08:54:13,425][dance][set_config_from_dict] Setting config 'label_mod' to 'mod2'
# [INFO][2025-04-06 08:54:13,426][dance][load_data] Raw data loaded:
# Data object that wraps (.data):
# MuData object with n_obs × n_vars = 67175 × 14087
#   uns:	'dance_config'
#   2 modalities
#     mod1:	67175 x 13953
#       obs:	'batch', 'size_factors'
#       layers:	'counts'
#     mod2:	67175 x 134
#       obs:	'batch', 'size_factors'
#       layers:	'counts'
# [INFO][2025-04-06 08:54:13,528][dance][wrapped_func] Took 0:00:15.317647 to load and process data.
# <ipython-input-4-15ebac2ab37f>:42: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   data.data.uns['gtrain'] = torch.load(train_graph_path)
# Processed data found. Loading...
# <ipython-input-4-15ebac2ab37f>:43: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   data.data.uns['gval'] = torch.load(val_graph_path)
# <ipython-input-4-15ebac2ab37f>:44: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   data.data.uns['gtest'] = torch.load(test_graph_path)
# <ipython-input-4-15ebac2ab37f>:45: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   train_label = torch.load(train_label_path).numpy()
# <ipython-input-4-15ebac2ab37f>:46: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   val_label = torch.load(val_label_path).numpy()
# <ipython-input-4-15ebac2ab37f>:47: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   test_label = torch.load(test_label_path).numpy()
# <ipython-input-4-15ebac2ab37f>:48: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   kwargs["FEATURE_SIZE"] = torch.load(feature_size_path).item()
# <ipython-input-4-15ebac2ab37f>:49: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   kwargs["OUTPUT_SIZE"] = torch.load(output_size_path).item()
# Processed data loaded.
# ---------------------------------
# Epoch 1/500
# Train RMSE: 0.6611
# Val RMSE: 0.4772, Val MAE: 0.3338
# Test RMSE: 0.5309, Test MAE: 0.3465
# ---------------------------------
# Model saved at epoch 1 with val RMSE 0.4772
# Patience grace period: 30
# ---------------------------------
# Epoch 2/500
# Train RMSE: 0.4687
# Val RMSE: 0.4107, Val MAE: 0.2882
# Test RMSE: 0.4811, Test MAE: 0.3207
# ---------------------------------
# Model saved at epoch 2 with val RMSE 0.4107
# Patience grace period: 30
# ---------------------------------
# Epoch 3/500
# Train RMSE: 0.4194
# Val RMSE: 0.3810, Val MAE: 0.2684
# Test RMSE: 0.4624, Test MAE: 0.3126
# ---------------------------------
# Model saved at epoch 3 with val RMSE 0.3810
# Patience grace period: 30
# ---------------------------------
# Epoch 4/500
# Train RMSE: 0.3942
# Val RMSE: 0.3646, Val MAE: 0.2588
# Test RMSE: 0.4474, Test MAE: 0.3060
# ---------------------------------
# Model saved at epoch 4 with val RMSE 0.3646
# Patience grace period: 30
# ---------------------------------
# Epoch 5/500
# Train RMSE: 0.3773
# Val RMSE: 0.3523, Val MAE: 0.2518
# Test RMSE: 0.4343, Test MAE: 0.2984
# ---------------------------------
# Model saved at epoch 5 with val RMSE 0.3523
# Patience grace period: 30
# ---------------------------------
# Epoch 6/500
# Train RMSE: 0.3653
# Val RMSE: 0.3444, Val MAE: 0.2471
# Test RMSE: 0.4258, Test MAE: 0.2921
# ---------------------------------
# Model saved at epoch 6 with val RMSE 0.3444
# Patience grace period: 30
# ---------------------------------
# Epoch 7/500
# Train RMSE: 0.3570
# Val RMSE: 0.3395, Val MAE: 0.2441
# Test RMSE: 0.4224, Test MAE: 0.2896
# ---------------------------------
# Model saved at epoch 7 with val RMSE 0.3395
# Patience grace period: 30
# ---------------------------------
# Epoch 8/500
# Train RMSE: 0.3510
# Val RMSE: 0.3360, Val MAE: 0.2418
# Test RMSE: 0.4198, Test MAE: 0.2874
# ---------------------------------
# Model saved at epoch 8 with val RMSE 0.3360
# Patience grace period: 30
# ---------------------------------
# Epoch 9/500
# Train RMSE: 0.3463
# Val RMSE: 0.3332, Val MAE: 0.2401
# Test RMSE: 0.4179, Test MAE: 0.2860
# ---------------------------------
# Model saved at epoch 9 with val RMSE 0.3332
# Patience grace period: 30
# ---------------------------------
# Epoch 10/500
# Train RMSE: 0.3423
# Val RMSE: 0.3310, Val MAE: 0.2386
# Test RMSE: 0.4155, Test MAE: 0.2840
# ---------------------------------
# Model saved at epoch 10 with val RMSE 0.3310
# Patience grace period: 30
# ---------------------------------
# Epoch 11/500
# Train RMSE: 0.3387
# Val RMSE: 0.3290, Val MAE: 0.2375
# Test RMSE: 0.4140, Test MAE: 0.2826
# ---------------------------------
# Model saved at epoch 11 with val RMSE 0.3290
# Patience grace period: 30
# ---------------------------------
# Epoch 12/500
# Train RMSE: 0.3358
# Val RMSE: 0.3275, Val MAE: 0.2365
# Test RMSE: 0.4137, Test MAE: 0.2824
# ---------------------------------
# Model saved at epoch 12 with val RMSE 0.3275
# Patience grace period: 30
# ---------------------------------
# Epoch 13/500
# Train RMSE: 0.3333
# Val RMSE: 0.3261, Val MAE: 0.2356
# Test RMSE: 0.4117, Test MAE: 0.2809
# ---------------------------------
# Model saved at epoch 13 with val RMSE 0.3261
# Patience grace period: 30
# ---------------------------------
# Epoch 14/500
# Train RMSE: 0.3307
# Val RMSE: 0.3247, Val MAE: 0.2346
# Test RMSE: 0.4117, Test MAE: 0.2808
# ---------------------------------
# Model saved at epoch 14 with val RMSE 0.3247
# Patience grace period: 30
# ---------------------------------
# Epoch 15/500
# Train RMSE: 0.3285
# Val RMSE: 0.3236, Val MAE: 0.2341
# Test RMSE: 0.4108, Test MAE: 0.2799
# ---------------------------------
# Model saved at epoch 15 with val RMSE 0.3236
# Patience grace period: 30
# ---------------------------------
# Epoch 16/500
# Train RMSE: 0.3266
# Val RMSE: 0.3228, Val MAE: 0.2334
# Test RMSE: 0.4112, Test MAE: 0.2803
# ---------------------------------
# Model saved at epoch 16 with val RMSE 0.3228
# Patience grace period: 29
# ---------------------------------
# Epoch 17/500
# Train RMSE: 0.3246
# Val RMSE: 0.3218, Val MAE: 0.2328
# Test RMSE: 0.4104, Test MAE: 0.2790
# ---------------------------------
# Model saved at epoch 17 with val RMSE 0.3218
# Patience grace period: 30
# ---------------------------------
# Epoch 18/500
# Train RMSE: 0.3232
# Val RMSE: 0.3216, Val MAE: 0.2326
# Test RMSE: 0.4086, Test MAE: 0.2782
# ---------------------------------
# Model saved at epoch 18 with val RMSE 0.3216
# Patience grace period: 29
# ---------------------------------
# Epoch 19/500
# Train RMSE: 0.3220
# Val RMSE: 0.3206, Val MAE: 0.2319
# Test RMSE: 0.4085, Test MAE: 0.2770
# ---------------------------------
# Model saved at epoch 19 with val RMSE 0.3206
# Patience grace period: 30
# ---------------------------------
# Epoch 20/500
# Train RMSE: 0.3213
# Val RMSE: 0.3212, Val MAE: 0.2330
# Test RMSE: 0.4115, Test MAE: 0.2784
# ---------------------------------
# Patience grace period: 28
# ---------------------------------
# Epoch 21/500
# Train RMSE: 0.3209
# Val RMSE: 0.3192, Val MAE: 0.2311
# Test RMSE: 0.4087, Test MAE: 0.2775
# ---------------------------------
# Model saved at epoch 21 with val RMSE 0.3192
# Patience grace period: 30
# ---------------------------------
# Epoch 22/500
# Train RMSE: 0.3192
# Val RMSE: 0.3199, Val MAE: 0.2316
# Test RMSE: 0.4091, Test MAE: 0.2773
# ---------------------------------
# Patience grace period: 28
# ---------------------------------
# Epoch 23/500
# Train RMSE: 0.3186
# Val RMSE: 0.3200, Val MAE: 0.2315
# Test RMSE: 0.4089, Test MAE: 0.2774
# ---------------------------------
# Patience grace period: 26
# ---------------------------------
# Epoch 24/500
# Train RMSE: 0.3188
# Val RMSE: 0.3210, Val MAE: 0.2324
# Test RMSE: 0.4114, Test MAE: 0.2819
# ---------------------------------
# Patience grace period: 24
# ---------------------------------
# Epoch 25/500
# Train RMSE: 0.3167
# Val RMSE: 0.3188, Val MAE: 0.2309
# Test RMSE: 0.4115, Test MAE: 0.2817
# ---------------------------------
# Model saved at epoch 25 with val RMSE 0.3188
# Patience grace period: 23
# ---------------------------------
# Epoch 26/500
# Train RMSE: 0.3152
# Val RMSE: 0.3178, Val MAE: 0.2302
# Test RMSE: 0.4135, Test MAE: 0.2822
# ---------------------------------
# Model saved at epoch 26 with val RMSE 0.3178
# Patience grace period: 30
# ---------------------------------
# Epoch 27/500
# Train RMSE: 0.3141
# Val RMSE: 0.3186, Val MAE: 0.2307
# Test RMSE: 0.4213, Test MAE: 0.2862
# ---------------------------------
# Patience grace period: 28
# ---------------------------------
# Epoch 28/500
# Train RMSE: 0.3134
# Val RMSE: 0.3181, Val MAE: 0.2304
# Test RMSE: 0.4249, Test MAE: 0.2883
# ---------------------------------
# Patience grace period: 27
# ---------------------------------
# Epoch 29/500
# Train RMSE: 0.3127
# Val RMSE: 0.3173, Val MAE: 0.2298
# Test RMSE: 0.4249, Test MAE: 0.2877
# ---------------------------------
# Model saved at epoch 29 with val RMSE 0.3173
# Patience grace period: 26
# ---------------------------------
# Epoch 30/500
# Train RMSE: 0.3120
# Val RMSE: 0.3166, Val MAE: 0.2293
# Test RMSE: 0.4233, Test MAE: 0.2869
# ---------------------------------
# Model saved at epoch 30 with val RMSE 0.3166
# Patience grace period: 30
# ---------------------------------
# Epoch 31/500
# Train RMSE: 0.3115
# Val RMSE: 0.3165, Val MAE: 0.2292
# Test RMSE: 0.4184, Test MAE: 0.2848
# ---------------------------------
# Model saved at epoch 31 with val RMSE 0.3165
# Patience grace period: 29
# ---------------------------------
# Epoch 32/500
# Train RMSE: 0.3113
# Val RMSE: 0.3162, Val MAE: 0.2290
# Test RMSE: 0.4151, Test MAE: 0.2826
# ---------------------------------
# Model saved at epoch 32 with val RMSE 0.3162
# Patience grace period: 28
# ---------------------------------
# Epoch 33/500
# Train RMSE: 0.3111
# Val RMSE: 0.3207, Val MAE: 0.2324
# Test RMSE: 0.4218, Test MAE: 0.2860
# ---------------------------------
# Patience grace period: 26
# ---------------------------------
# Epoch 34/500
# Train RMSE: 0.3106
# Val RMSE: 0.3328, Val MAE: 0.2414
# Test RMSE: 0.4347, Test MAE: 0.2929
# ---------------------------------
# Patience grace period: 24
# ---------------------------------
# Epoch 35/500
# Train RMSE: 0.3102
# Val RMSE: 0.3337, Val MAE: 0.2423
# Test RMSE: 0.4358, Test MAE: 0.2933
# ---------------------------------
# Patience grace period: 22
# ---------------------------------
# Epoch 36/500
# Train RMSE: 0.3101
# Val RMSE: 0.3219, Val MAE: 0.2336
# Test RMSE: 0.4214, Test MAE: 0.2841
# ---------------------------------
# Patience grace period: 21
# ---------------------------------
# Epoch 37/500
# Train RMSE: 0.3095
# Val RMSE: 0.3156, Val MAE: 0.2290
# Test RMSE: 0.4114, Test MAE: 0.2777
# ---------------------------------
# Model saved at epoch 37 with val RMSE 0.3156
# Patience grace period: 20
# ---------------------------------
# Epoch 38/500
# Train RMSE: 0.3086
# Val RMSE: 0.3145, Val MAE: 0.2281
# Test RMSE: 0.4096, Test MAE: 0.2766
# ---------------------------------
# Model saved at epoch 38 with val RMSE 0.3145
# Patience grace period: 30
# ---------------------------------
# Epoch 39/500
# Train RMSE: 0.3077
# Val RMSE: 0.3143, Val MAE: 0.2279
# Test RMSE: 0.4067, Test MAE: 0.2747
# ---------------------------------
# Model saved at epoch 39 with val RMSE 0.3143
# Patience grace period: 29
# ---------------------------------
# Epoch 40/500
# Train RMSE: 0.3074
# Val RMSE: 0.3152, Val MAE: 0.2285
# Test RMSE: 0.4041, Test MAE: 0.2735
# ---------------------------------
# Patience grace period: 27
# ---------------------------------
# Epoch 41/500
# Train RMSE: 0.3067
# Val RMSE: 0.3171, Val MAE: 0.2299
# Test RMSE: 0.4031, Test MAE: 0.2736
# ---------------------------------
# Patience grace period: 25
# ---------------------------------
# Epoch 42/500
# Train RMSE: 0.3060
# Val RMSE: 0.3179, Val MAE: 0.2305
# Test RMSE: 0.4039, Test MAE: 0.2747
# ---------------------------------
# Patience grace period: 23
# ---------------------------------
# Epoch 43/500
# Train RMSE: 0.3054
# Val RMSE: 0.3170, Val MAE: 0.2299
# Test RMSE: 0.4049, Test MAE: 0.2757
# ---------------------------------
# Patience grace period: 22
# ---------------------------------
# Epoch 44/500
# Train RMSE: 0.3048
# Val RMSE: 0.3155, Val MAE: 0.2289
# Test RMSE: 0.4050, Test MAE: 0.2757
# ---------------------------------
# Patience grace period: 21
# ---------------------------------
# Epoch 45/500
# Train RMSE: 0.3042
# Val RMSE: 0.3144, Val MAE: 0.2280
# Test RMSE: 0.4058, Test MAE: 0.2761
# ---------------------------------
# Patience grace period: 20
# ---------------------------------
# Epoch 46/500
# Train RMSE: 0.3036
# Val RMSE: 0.3139, Val MAE: 0.2275
# Test RMSE: 0.4069, Test MAE: 0.2763
# ---------------------------------
# Model saved at epoch 46 with val RMSE 0.3139
# Patience grace period: 19
# ---------------------------------
# Epoch 47/500
# Train RMSE: 0.3027
# Val RMSE: 0.3139, Val MAE: 0.2275
# Test RMSE: 0.4065, Test MAE: 0.2757
# ---------------------------------
# Model saved at epoch 47 with val RMSE 0.3139
# Patience grace period: 17
# ---------------------------------
# Epoch 48/500
# Train RMSE: 0.3021
# Val RMSE: 0.3136, Val MAE: 0.2272
# Test RMSE: 0.4067, Test MAE: 0.2759
# ---------------------------------
# Model saved at epoch 48 with val RMSE 0.3136
# Patience grace period: 16
# ---------------------------------
# Epoch 49/500
# Train RMSE: 0.3015
# Val RMSE: 0.3137, Val MAE: 0.2273
# Test RMSE: 0.4043, Test MAE: 0.2743
# ---------------------------------
# Patience grace period: 14
# ---------------------------------
# Epoch 50/500
# Train RMSE: 0.3010
# Val RMSE: 0.3138, Val MAE: 0.2274
# Test RMSE: 0.4041, Test MAE: 0.2746
# ---------------------------------
# Patience grace period: 12
# ---------------------------------
# Epoch 51/500
# Train RMSE: 0.3007
# Val RMSE: 0.3139, Val MAE: 0.2273
# Test RMSE: 0.4029, Test MAE: 0.2738
# ---------------------------------
# Patience grace period: 10
# ---------------------------------
# Epoch 52/500
# Train RMSE: 0.3005
# Val RMSE: 0.3155, Val MAE: 0.2284
# Test RMSE: 0.4034, Test MAE: 0.2747
# ---------------------------------
# Patience grace period: 8
# ---------------------------------
# Epoch 53/500
# Train RMSE: 0.3002
# Val RMSE: 0.3183, Val MAE: 0.2304
# Test RMSE: 0.4049, Test MAE: 0.2761
# ---------------------------------
# Patience grace period: 6
# ---------------------------------
# Epoch 54/500
# Train RMSE: 0.3002
# Val RMSE: 0.3226, Val MAE: 0.2335
# Test RMSE: 0.4088, Test MAE: 0.2792
# ---------------------------------
# Patience grace period: 4
# ---------------------------------
# Epoch 55/500
# Train RMSE: 0.3005
# Val RMSE: 0.3267, Val MAE: 0.2366
# Test RMSE: 0.4119, Test MAE: 0.2817
# ---------------------------------
# Patience grace period: 2
# ---------------------------------
# Epoch 56/500
# Train RMSE: 0.3005
# Val RMSE: 0.3256, Val MAE: 0.2360
# Test RMSE: 0.4119, Test MAE: 0.2819
# ---------------------------------
# Patience grace period: 1
# ---------------------------------
# Epoch 57/500
# Train RMSE: 0.3010
# Val RMSE: 0.3184, Val MAE: 0.2311
# Test RMSE: 0.4097, Test MAE: 0.2800
# ---------------------------------
# Patience grace period: 0
# Early stopping triggered at epoch 57
# Final Test RMSE: 0.4067, Final Test MAE: 0.2759
# <ipython-input-2-d8b64875fc37>:120: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   self.model.load_state_dict(torch.load(os.path.join(save_dir, 'best_model.pth')))
# Pearson Corr: 0.8743158881133191
# Spearman Corr: 0.8486945226548246
# p-rmse: 0.40667802929963837
#        rmse       mae  seed                            subtask        method  \
# 0  0.406678  0.275908     1  openproblems_bmmc_cite_phase2_rna  hierarchical
#
#     pearson p_value_pearson  spearman p_value_spearman
# 0  0.874316          0.0000  0.848695           0.0000
# ---------------------------------
# Epoch 1/500
# Train RMSE: 0.6635
# Val RMSE: 0.4826, Val MAE: 0.3387
# Test RMSE: 0.5366, Test MAE: 0.3521
# ---------------------------------
# Model saved at epoch 1 with val RMSE 0.4826
# Patience grace period: 30
# ---------------------------------
# Epoch 2/500
# Train RMSE: 0.4721
# Val RMSE: 0.4135, Val MAE: 0.2905
# Test RMSE: 0.4808, Test MAE: 0.3203
# ---------------------------------
# Model saved at epoch 2 with val RMSE 0.4135
# Patience grace period: 30
# ---------------------------------
# Epoch 3/500
# Train RMSE: 0.4203
# Val RMSE: 0.3817, Val MAE: 0.2693
# Test RMSE: 0.4628, Test MAE: 0.3143
# ---------------------------------
# Model saved at epoch 3 with val RMSE 0.3817
# Patience grace period: 30
# ---------------------------------
# Epoch 4/500
# Train RMSE: 0.3942
# Val RMSE: 0.3644, Val MAE: 0.2590
# Test RMSE: 0.4475, Test MAE: 0.3073
# ---------------------------------
# Model saved at epoch 4 with val RMSE 0.3644
# Patience grace period: 30
# ---------------------------------
# Epoch 5/500
# Train RMSE: 0.3771
# Val RMSE: 0.3523, Val MAE: 0.2519
# Test RMSE: 0.4346, Test MAE: 0.2994
# ---------------------------------
# Model saved at epoch 5 with val RMSE 0.3523
# Patience grace period: 30
# ---------------------------------
# Epoch 6/500
# Train RMSE: 0.3651
# Val RMSE: 0.3447, Val MAE: 0.2473
# Test RMSE: 0.4278, Test MAE: 0.2944
# ---------------------------------
# Model saved at epoch 6 with val RMSE 0.3447
# Patience grace period: 30
# ---------------------------------
# Epoch 7/500
# Train RMSE: 0.3574
# Val RMSE: 0.3398, Val MAE: 0.2443
# Test RMSE: 0.4243, Test MAE: 0.2914
# ---------------------------------
# Model saved at epoch 7 with val RMSE 0.3398
# Patience grace period: 30
# ---------------------------------
# Epoch 8/500
# Train RMSE: 0.3515
# Val RMSE: 0.3365, Val MAE: 0.2423
# Test RMSE: 0.4208, Test MAE: 0.2886
# ---------------------------------
# Model saved at epoch 8 with val RMSE 0.3365
# Patience grace period: 30
# ---------------------------------
# Epoch 9/500
# Train RMSE: 0.3469
# Val RMSE: 0.3338, Val MAE: 0.2405
# Test RMSE: 0.4187, Test MAE: 0.2868
# ---------------------------------
# Model saved at epoch 9 with val RMSE 0.3338
# Patience grace period: 30
# ---------------------------------
# Epoch 10/500
# Train RMSE: 0.3428
# Val RMSE: 0.3314, Val MAE: 0.2390
# Test RMSE: 0.4169, Test MAE: 0.2857
# ---------------------------------
# Model saved at epoch 10 with val RMSE 0.3314
# Patience grace period: 30
# ---------------------------------
# Epoch 11/500
# Train RMSE: 0.3394
# Val RMSE: 0.3294, Val MAE: 0.2378
# Test RMSE: 0.4149, Test MAE: 0.2840
# ---------------------------------
# Model saved at epoch 11 with val RMSE 0.3294
# Patience grace period: 30
# ---------------------------------
# Epoch 12/500
# Train RMSE: 0.3362
# Val RMSE: 0.3278, Val MAE: 0.2368
# Test RMSE: 0.4139, Test MAE: 0.2834
# ---------------------------------
# Model saved at epoch 12 with val RMSE 0.3278
# Patience grace period: 30
# ---------------------------------
# Epoch 13/500
# Train RMSE: 0.3337
# Val RMSE: 0.3263, Val MAE: 0.2358
# Test RMSE: 0.4126, Test MAE: 0.2824
# ---------------------------------
# Model saved at epoch 13 with val RMSE 0.3263
# Patience grace period: 30
# ---------------------------------
# Epoch 14/500
# Train RMSE: 0.3313
# Val RMSE: 0.3251, Val MAE: 0.2351
# Test RMSE: 0.4109, Test MAE: 0.2808
# ---------------------------------
# Model saved at epoch 14 with val RMSE 0.3251
# Patience grace period: 30
# ---------------------------------
# Epoch 15/500
# Train RMSE: 0.3290
# Val RMSE: 0.3241, Val MAE: 0.2343
# Test RMSE: 0.4093, Test MAE: 0.2793
# ---------------------------------
# Model saved at epoch 15 with val RMSE 0.3241
# Patience grace period: 30
# ---------------------------------
# Epoch 16/500
# Train RMSE: 0.3273
# Val RMSE: 0.3231, Val MAE: 0.2337
# Test RMSE: 0.4097, Test MAE: 0.2801
# ---------------------------------
# Model saved at epoch 16 with val RMSE 0.3231
# Patience grace period: 29
# ---------------------------------
# Epoch 17/500
# Train RMSE: 0.3255
# Val RMSE: 0.3223, Val MAE: 0.2332
# Test RMSE: 0.4106, Test MAE: 0.2810
# ---------------------------------
# Model saved at epoch 17 with val RMSE 0.3223
# Patience grace period: 30
# ---------------------------------
# Epoch 18/500
# Train RMSE: 0.3246
# Val RMSE: 0.3217, Val MAE: 0.2327
# Test RMSE: 0.4089, Test MAE: 0.2791
# ---------------------------------
# Model saved at epoch 18 with val RMSE 0.3217
# Patience grace period: 29
# ---------------------------------
# Epoch 19/500
# Train RMSE: 0.3241
# Val RMSE: 0.3236, Val MAE: 0.2338
# Test RMSE: 0.4137, Test MAE: 0.2837
# ---------------------------------
# Patience grace period: 27
# ---------------------------------
# Epoch 20/500
# Train RMSE: 0.3224
# Val RMSE: 0.3215, Val MAE: 0.2325
# Test RMSE: 0.4128, Test MAE: 0.2834
# ---------------------------------
# Model saved at epoch 20 with val RMSE 0.3215
# Patience grace period: 26
# ---------------------------------
# Epoch 21/500
# Train RMSE: 0.3209
# Val RMSE: 0.3204, Val MAE: 0.2317
# Test RMSE: 0.4109, Test MAE: 0.2814
# ---------------------------------
# Model saved at epoch 21 with val RMSE 0.3204
# Patience grace period: 30
# ---------------------------------
# Epoch 22/500
# Train RMSE: 0.3202
# Val RMSE: 0.3193, Val MAE: 0.2311
# Test RMSE: 0.4095, Test MAE: 0.2793
# ---------------------------------
# Model saved at epoch 22 with val RMSE 0.3193
# Patience grace period: 30
# ---------------------------------
# Epoch 23/500
# Train RMSE: 0.3195
# Val RMSE: 0.3188, Val MAE: 0.2309
# Test RMSE: 0.4077, Test MAE: 0.2781
# ---------------------------------
# Model saved at epoch 23 with val RMSE 0.3188
# Patience grace period: 29
# ---------------------------------
# Epoch 24/500
# Train RMSE: 0.3184
# Val RMSE: 0.3185, Val MAE: 0.2307
# Test RMSE: 0.4095, Test MAE: 0.2804
# ---------------------------------
# Model saved at epoch 24 with val RMSE 0.3185
# Patience grace period: 28
# ---------------------------------
# Epoch 25/500
# Train RMSE: 0.3170
# Val RMSE: 0.3177, Val MAE: 0.2300
# Test RMSE: 0.4085, Test MAE: 0.2794
# ---------------------------------
# Model saved at epoch 25 with val RMSE 0.3177
# Patience grace period: 30
# ---------------------------------
# Epoch 26/500
# Train RMSE: 0.3161
# Val RMSE: 0.3195, Val MAE: 0.2316
# Test RMSE: 0.4116, Test MAE: 0.2810
# ---------------------------------
# Patience grace period: 28
# ---------------------------------
# Epoch 27/500
# Train RMSE: 0.3154
# Val RMSE: 0.3262, Val MAE: 0.2367
# Test RMSE: 0.4193, Test MAE: 0.2857
# ---------------------------------
# Patience grace period: 26
# ---------------------------------
# Epoch 28/500
# Train RMSE: 0.3148
# Val RMSE: 0.3283, Val MAE: 0.2384
# Test RMSE: 0.4176, Test MAE: 0.2842
# ---------------------------------
# Patience grace period: 24
# ---------------------------------
# Epoch 29/500
# Train RMSE: 0.3141
# Val RMSE: 0.3234, Val MAE: 0.2348
# Test RMSE: 0.4102, Test MAE: 0.2794
# ---------------------------------
# Patience grace period: 23
# ---------------------------------
# Epoch 30/500
# Train RMSE: 0.3136
# Val RMSE: 0.3211, Val MAE: 0.2330
# Test RMSE: 0.4085, Test MAE: 0.2780
# ---------------------------------
# Patience grace period: 22
# ---------------------------------
# Epoch 31/500
# Train RMSE: 0.3134
# Val RMSE: 0.3191, Val MAE: 0.2314
# Test RMSE: 0.4070, Test MAE: 0.2772
# ---------------------------------
# Patience grace period: 21
# ---------------------------------
# Epoch 32/500
# Train RMSE: 0.3135
# Val RMSE: 0.3176, Val MAE: 0.2303
# Test RMSE: 0.4056, Test MAE: 0.2760
# ---------------------------------
# Model saved at epoch 32 with val RMSE 0.3176
# Patience grace period: 20
# ---------------------------------
# Epoch 33/500
# Train RMSE: 0.3142
# Val RMSE: 0.3169, Val MAE: 0.2298
# Test RMSE: 0.4052, Test MAE: 0.2753
# ---------------------------------
# Model saved at epoch 33 with val RMSE 0.3169
# Patience grace period: 19
# ---------------------------------
# Epoch 34/500
# Train RMSE: 0.3142
# Val RMSE: 0.3155, Val MAE: 0.2285
# Test RMSE: 0.4020, Test MAE: 0.2730
# ---------------------------------
# Model saved at epoch 34 with val RMSE 0.3155
# Patience grace period: 30
# ---------------------------------
# Epoch 35/500
# Train RMSE: 0.3135
# Val RMSE: 0.3163, Val MAE: 0.2290
# Test RMSE: 0.4030, Test MAE: 0.2741
# ---------------------------------
# Patience grace period: 28
# ---------------------------------
# Epoch 36/500
# Train RMSE: 0.3113
# Val RMSE: 0.3166, Val MAE: 0.2294
# Test RMSE: 0.4035, Test MAE: 0.2751
# ---------------------------------
# Patience grace period: 26
# ---------------------------------
# Epoch 37/500
# Train RMSE: 0.3093
# Val RMSE: 0.3155, Val MAE: 0.2287
# Test RMSE: 0.4034, Test MAE: 0.2750
# ---------------------------------
# Model saved at epoch 37 with val RMSE 0.3155
# Patience grace period: 25
# ---------------------------------
# Epoch 38/500
# Train RMSE: 0.3079
# Val RMSE: 0.3147, Val MAE: 0.2281
# Test RMSE: 0.4035, Test MAE: 0.2748
# ---------------------------------
# Model saved at epoch 38 with val RMSE 0.3147
# Patience grace period: 24
# ---------------------------------
# Epoch 39/500
# Train RMSE: 0.3066
# Val RMSE: 0.3144, Val MAE: 0.2279
# Test RMSE: 0.4045, Test MAE: 0.2757
# ---------------------------------
# Model saved at epoch 39 with val RMSE 0.3144
# Patience grace period: 30
# ---------------------------------
# Epoch 40/500
# Train RMSE: 0.3057
# Val RMSE: 0.3143, Val MAE: 0.2279
# Test RMSE: 0.4047, Test MAE: 0.2758
# ---------------------------------
# Model saved at epoch 40 with val RMSE 0.3143
# Patience grace period: 29
# ---------------------------------
# Epoch 41/500
# Train RMSE: 0.3049
# Val RMSE: 0.3141, Val MAE: 0.2277
# Test RMSE: 0.4057, Test MAE: 0.2764
# ---------------------------------
# Model saved at epoch 41 with val RMSE 0.3141
# Patience grace period: 28
# ---------------------------------
# Epoch 42/500
# Train RMSE: 0.3042
# Val RMSE: 0.3143, Val MAE: 0.2278
# Test RMSE: 0.4079, Test MAE: 0.2779
# ---------------------------------
# Patience grace period: 26
# ---------------------------------
# Epoch 43/500
# Train RMSE: 0.3036
# Val RMSE: 0.3142, Val MAE: 0.2277
# Test RMSE: 0.4089, Test MAE: 0.2787
# ---------------------------------
# Patience grace period: 25
# ---------------------------------
# Epoch 44/500
# Train RMSE: 0.3031
# Val RMSE: 0.3141, Val MAE: 0.2277
# Test RMSE: 0.4104, Test MAE: 0.2797
# ---------------------------------
# Patience grace period: 23
# ---------------------------------
# Epoch 45/500
# Train RMSE: 0.3024
# Val RMSE: 0.3142, Val MAE: 0.2277
# Test RMSE: 0.4113, Test MAE: 0.2800
# ---------------------------------
# Patience grace period: 21
# ---------------------------------
# Epoch 46/500
# Train RMSE: 0.3018
# Val RMSE: 0.3140, Val MAE: 0.2277
# Test RMSE: 0.4106, Test MAE: 0.2798
# ---------------------------------
# Model saved at epoch 46 with val RMSE 0.3140
# Patience grace period: 20
# ---------------------------------
# Epoch 47/500
# Train RMSE: 0.3014
# Val RMSE: 0.3137, Val MAE: 0.2274
# Test RMSE: 0.4104, Test MAE: 0.2799
# ---------------------------------
# Model saved at epoch 47 with val RMSE 0.3137
# Patience grace period: 19
# ---------------------------------
# Epoch 48/500
# Train RMSE: 0.3010
# Val RMSE: 0.3139, Val MAE: 0.2275
# Test RMSE: 0.4118, Test MAE: 0.2805
# ---------------------------------
# Patience grace period: 17
# ---------------------------------
# Epoch 49/500
# Train RMSE: 0.3004
# Val RMSE: 0.3140, Val MAE: 0.2276
# Test RMSE: 0.4109, Test MAE: 0.2804
# ---------------------------------
# Patience grace period: 15
# ---------------------------------
# Epoch 50/500
# Train RMSE: 0.3001
# Val RMSE: 0.3140, Val MAE: 0.2277
# Test RMSE: 0.4123, Test MAE: 0.2814
# ---------------------------------
# Patience grace period: 13
# ---------------------------------
# Epoch 51/500
# Train RMSE: 0.2998
# Val RMSE: 0.3151, Val MAE: 0.2284
# Test RMSE: 0.4107, Test MAE: 0.2802
# ---------------------------------
# Patience grace period: 11
# ---------------------------------
# Epoch 52/500
# Train RMSE: 0.2993
# Val RMSE: 0.3157, Val MAE: 0.2289
# Test RMSE: 0.4092, Test MAE: 0.2792
# ---------------------------------
# Patience grace period: 9
# ---------------------------------
# Epoch 53/500
# Train RMSE: 0.2994
# Val RMSE: 0.3179, Val MAE: 0.2308
# Test RMSE: 0.4123, Test MAE: 0.2809
# ---------------------------------
# Patience grace period: 7
# ---------------------------------
# Epoch 54/500
# Train RMSE: 0.2996
# Val RMSE: 0.3225, Val MAE: 0.2346
# Test RMSE: 0.4135, Test MAE: 0.2820
# ---------------------------------
# Patience grace period: 5
# ---------------------------------
# Epoch 55/500
# Train RMSE: 0.3009
# Val RMSE: 0.3180, Val MAE: 0.2311
# Test RMSE: 0.4146, Test MAE: 0.2826
# ---------------------------------
# Patience grace period: 4
# ---------------------------------
# Epoch 56/500
# Train RMSE: 0.3049
# Val RMSE: 0.3222, Val MAE: 0.2329
# Test RMSE: 0.4352, Test MAE: 0.2945
# ---------------------------------
# Patience grace period: 2
# ---------------------------------
# Epoch 57/500
# Train RMSE: 0.3107
# Val RMSE: 0.3169, Val MAE: 0.2287
# Test RMSE: 0.4194, Test MAE: 0.2843
# ---------------------------------
# Patience grace period: 1
# ---------------------------------
# Epoch 58/500
# Train RMSE: 0.3090
# Val RMSE: 0.3172, Val MAE: 0.2300
# Test RMSE: 0.4085, Test MAE: 0.2783
# ---------------------------------
# Patience grace period: -1
# Early stopping triggered at epoch 58
# Final Test RMSE: 0.4104, Final Test MAE: 0.2799
# <ipython-input-2-d8b64875fc37>:120: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   self.model.load_state_dict(torch.load(os.path.join(save_dir, 'best_model.pth')))
# Pearson Corr: 0.8722822323374153
# Spearman Corr: 0.8443171153825554
# p-rmse: 0.41041491390312274
#        rmse       mae  seed                            subtask        method  \
# 0  0.410415  0.279931     2  openproblems_bmmc_cite_phase2_rna  hierarchical
#
#     pearson p_value_pearson  spearman p_value_spearman
# 0  0.872282          0.0000  0.844317           0.0000
# ---------------------------------
# Epoch 1/500
# Train RMSE: 0.6614
# Val RMSE: 0.4771, Val MAE: 0.3343
# Test RMSE: 0.5293, Test MAE: 0.3465
# ---------------------------------
# Model saved at epoch 1 with val RMSE 0.4771
# Patience grace period: 30
# ---------------------------------
# Epoch 2/500
# Train RMSE: 0.4688
# Val RMSE: 0.4102, Val MAE: 0.2880
# Test RMSE: 0.4800, Test MAE: 0.3202
# ---------------------------------
# Model saved at epoch 2 with val RMSE 0.4102
# Patience grace period: 30
# ---------------------------------
# Epoch 3/500
# Train RMSE: 0.4192
# Val RMSE: 0.3808, Val MAE: 0.2685
# Test RMSE: 0.4631, Test MAE: 0.3132
# ---------------------------------
# Model saved at epoch 3 with val RMSE 0.3808
# Patience grace period: 30
# ---------------------------------
# Epoch 4/500
# Train RMSE: 0.3944
# Val RMSE: 0.3645, Val MAE: 0.2588
# Test RMSE: 0.4485, Test MAE: 0.3069
# ---------------------------------
# Model saved at epoch 4 with val RMSE 0.3645
# Patience grace period: 30
# ---------------------------------
# Epoch 5/500
# Train RMSE: 0.3776
# Val RMSE: 0.3524, Val MAE: 0.2519
# Test RMSE: 0.4357, Test MAE: 0.2995
# ---------------------------------
# Model saved at epoch 5 with val RMSE 0.3524
# Patience grace period: 30
# ---------------------------------
# Epoch 6/500
# Train RMSE: 0.3654
# Val RMSE: 0.3445, Val MAE: 0.2471
# Test RMSE: 0.4278, Test MAE: 0.2937
# ---------------------------------
# Model saved at epoch 6 with val RMSE 0.3445
# Patience grace period: 30
# ---------------------------------
# Epoch 7/500
# Train RMSE: 0.3573
# Val RMSE: 0.3398, Val MAE: 0.2441
# Test RMSE: 0.4243, Test MAE: 0.2911
# ---------------------------------
# Model saved at epoch 7 with val RMSE 0.3398
# Patience grace period: 30
# ---------------------------------
# Epoch 8/500
# Train RMSE: 0.3515
# Val RMSE: 0.3363, Val MAE: 0.2419
# Test RMSE: 0.4222, Test MAE: 0.2895
# ---------------------------------
# Model saved at epoch 8 with val RMSE 0.3363
# Patience grace period: 30
# ---------------------------------
# Epoch 9/500
# Train RMSE: 0.3468
# Val RMSE: 0.3335, Val MAE: 0.2402
# Test RMSE: 0.4200, Test MAE: 0.2876
# ---------------------------------
# Model saved at epoch 9 with val RMSE 0.3335
# Patience grace period: 30
# ---------------------------------
# Epoch 10/500
# Train RMSE: 0.3427
# Val RMSE: 0.3312, Val MAE: 0.2387
# Test RMSE: 0.4187, Test MAE: 0.2866
# ---------------------------------
# Model saved at epoch 10 with val RMSE 0.3312
# Patience grace period: 30
# ---------------------------------
# Epoch 11/500
# Train RMSE: 0.3391
# Val RMSE: 0.3294, Val MAE: 0.2376
# Test RMSE: 0.4170, Test MAE: 0.2851
# ---------------------------------
# Model saved at epoch 11 with val RMSE 0.3294
# Patience grace period: 30
# ---------------------------------
# Epoch 12/500
# Train RMSE: 0.3361
# Val RMSE: 0.3275, Val MAE: 0.2365
# Test RMSE: 0.4154, Test MAE: 0.2835
# ---------------------------------
# Model saved at epoch 12 with val RMSE 0.3275
# Patience grace period: 30
# ---------------------------------
# Epoch 13/500
# Train RMSE: 0.3334
# Val RMSE: 0.3260, Val MAE: 0.2355
# Test RMSE: 0.4143, Test MAE: 0.2823
# ---------------------------------
# Model saved at epoch 13 with val RMSE 0.3260
# Patience grace period: 30
# ---------------------------------
# Epoch 14/500
# Train RMSE: 0.3309
# Val RMSE: 0.3248, Val MAE: 0.2347
# Test RMSE: 0.4146, Test MAE: 0.2826
# ---------------------------------
# Model saved at epoch 14 with val RMSE 0.3248
# Patience grace period: 30
# ---------------------------------
# Epoch 15/500
# Train RMSE: 0.3286
# Val RMSE: 0.3236, Val MAE: 0.2341
# Test RMSE: 0.4123, Test MAE: 0.2804
# ---------------------------------
# Model saved at epoch 15 with val RMSE 0.3236
# Patience grace period: 30
# ---------------------------------
# Epoch 16/500
# Train RMSE: 0.3267
# Val RMSE: 0.3226, Val MAE: 0.2332
# Test RMSE: 0.4138, Test MAE: 0.2816
# ---------------------------------
# Model saved at epoch 16 with val RMSE 0.3226
# Patience grace period: 30
# ---------------------------------
# Epoch 17/500
# Train RMSE: 0.3251
# Val RMSE: 0.3218, Val MAE: 0.2326
# Test RMSE: 0.4120, Test MAE: 0.2802
# ---------------------------------
# Model saved at epoch 17 with val RMSE 0.3218
# Patience grace period: 29
# ---------------------------------
# Epoch 18/500
# Train RMSE: 0.3242
# Val RMSE: 0.3211, Val MAE: 0.2322
# Test RMSE: 0.4129, Test MAE: 0.2812
# ---------------------------------
# Model saved at epoch 18 with val RMSE 0.3211
# Patience grace period: 30
# ---------------------------------
# Epoch 19/500
# Train RMSE: 0.3243
# Val RMSE: 0.3249, Val MAE: 0.2348
# Test RMSE: 0.4141, Test MAE: 0.2840
# ---------------------------------
# Patience grace period: 28
# ---------------------------------
# Epoch 20/500
# Train RMSE: 0.3231
# Val RMSE: 0.3210, Val MAE: 0.2319
# Test RMSE: 0.4146, Test MAE: 0.2825
# ---------------------------------
# Model saved at epoch 20 with val RMSE 0.3210
# Patience grace period: 27
# ---------------------------------
# Epoch 21/500
# Train RMSE: 0.3210
# Val RMSE: 0.3210, Val MAE: 0.2321
# Test RMSE: 0.4140, Test MAE: 0.2809
# ---------------------------------
# Model saved at epoch 21 with val RMSE 0.3210
# Patience grace period: 25
# ---------------------------------
# Epoch 22/500
# Train RMSE: 0.3192
# Val RMSE: 0.3196, Val MAE: 0.2313
# Test RMSE: 0.4107, Test MAE: 0.2791
# ---------------------------------
# Model saved at epoch 22 with val RMSE 0.3196
# Patience grace period: 30
# ---------------------------------
# Epoch 23/500
# Train RMSE: 0.3177
# Val RMSE: 0.3192, Val MAE: 0.2309
# Test RMSE: 0.4092, Test MAE: 0.2787
# ---------------------------------
# Model saved at epoch 23 with val RMSE 0.3192
# Patience grace period: 29
# ---------------------------------
# Epoch 24/500
# Train RMSE: 0.3166
# Val RMSE: 0.3188, Val MAE: 0.2306
# Test RMSE: 0.4098, Test MAE: 0.2792
# ---------------------------------
# Model saved at epoch 24 with val RMSE 0.3188
# Patience grace period: 28
# ---------------------------------
# Epoch 25/500
# Train RMSE: 0.3156
# Val RMSE: 0.3187, Val MAE: 0.2305
# Test RMSE: 0.4113, Test MAE: 0.2806
# ---------------------------------
# Model saved at epoch 25 with val RMSE 0.3187
# Patience grace period: 27
# ---------------------------------
# Epoch 26/500
# Train RMSE: 0.3147
# Val RMSE: 0.3182, Val MAE: 0.2301
# Test RMSE: 0.4120, Test MAE: 0.2806
# ---------------------------------
# Model saved at epoch 26 with val RMSE 0.3182
# Patience grace period: 30
# ---------------------------------
# Epoch 27/500
# Train RMSE: 0.3139
# Val RMSE: 0.3186, Val MAE: 0.2306
# Test RMSE: 0.4175, Test MAE: 0.2831
# ---------------------------------
# Patience grace period: 28
# ---------------------------------
# Epoch 28/500
# Train RMSE: 0.3135
# Val RMSE: 0.3241, Val MAE: 0.2349
# Test RMSE: 0.4254, Test MAE: 0.2870
# ---------------------------------
# Patience grace period: 26
# ---------------------------------
# Epoch 29/500
# Train RMSE: 0.3136
# Val RMSE: 0.3353, Val MAE: 0.2435
# Test RMSE: 0.4389, Test MAE: 0.2945
# ---------------------------------
# Patience grace period: 24
# ---------------------------------
# Epoch 30/500
# Train RMSE: 0.3155
# Val RMSE: 0.3294, Val MAE: 0.2385
# Test RMSE: 0.4382, Test MAE: 0.2931
# ---------------------------------
# Patience grace period: 23
# ---------------------------------
# Epoch 31/500
# Train RMSE: 0.3179
# Val RMSE: 0.3165, Val MAE: 0.2292
# Test RMSE: 0.4131, Test MAE: 0.2802
# ---------------------------------
# Model saved at epoch 31 with val RMSE 0.3165
# Patience grace period: 30
# ---------------------------------
# Epoch 32/500
# Train RMSE: 0.3140
# Val RMSE: 0.3175, Val MAE: 0.2300
# Test RMSE: 0.4102, Test MAE: 0.2793
# ---------------------------------
# Patience grace period: 28
# ---------------------------------
# Epoch 33/500
# Train RMSE: 0.3104
# Val RMSE: 0.3165, Val MAE: 0.2292
# Test RMSE: 0.4105, Test MAE: 0.2794
# ---------------------------------
# Patience grace period: 27
# ---------------------------------
# Epoch 34/500
# Train RMSE: 0.3091
# Val RMSE: 0.3158, Val MAE: 0.2288
# Test RMSE: 0.4100, Test MAE: 0.2788
# ---------------------------------
# Model saved at epoch 34 with val RMSE 0.3158
# Patience grace period: 26
# ---------------------------------
# Epoch 35/500
# Train RMSE: 0.3079
# Val RMSE: 0.3154, Val MAE: 0.2284
# Test RMSE: 0.4106, Test MAE: 0.2790
# ---------------------------------
# Model saved at epoch 35 with val RMSE 0.3154
# Patience grace period: 30
# ---------------------------------
# Epoch 36/500
# Train RMSE: 0.3071
# Val RMSE: 0.3154, Val MAE: 0.2284
# Test RMSE: 0.4090, Test MAE: 0.2778
# ---------------------------------
# Model saved at epoch 36 with val RMSE 0.3154
# Patience grace period: 28
# ---------------------------------
# Epoch 37/500
# Train RMSE: 0.3063
# Val RMSE: 0.3147, Val MAE: 0.2279
# Test RMSE: 0.4091, Test MAE: 0.2775
# ---------------------------------
# Model saved at epoch 37 with val RMSE 0.3147
# Patience grace period: 27
# ---------------------------------
# Epoch 38/500
# Train RMSE: 0.3055
# Val RMSE: 0.3145, Val MAE: 0.2278
# Test RMSE: 0.4092, Test MAE: 0.2775
# ---------------------------------
# Model saved at epoch 38 with val RMSE 0.3145
# Patience grace period: 26
# ---------------------------------
# Epoch 39/500
# Train RMSE: 0.3049
# Val RMSE: 0.3141, Val MAE: 0.2276
# Test RMSE: 0.4102, Test MAE: 0.2780
# ---------------------------------
# Model saved at epoch 39 with val RMSE 0.3141
# Patience grace period: 30
# ---------------------------------
# Epoch 40/500
# Train RMSE: 0.3042
# Val RMSE: 0.3140, Val MAE: 0.2276
# ...
# Model saved at epoch 3 with val RMSE 0.3816
# Patience grace period: 30
# ---------------------------------
# Epoch 4/500
# Train RMSE: 0.3954
# Val RMSE: 0.3650, Val MAE: 0.2596
# Test RMSE: 0.4473, Test MAE: 0.3059
# ---------------------------------
# Model saved at epoch 4 with val RMSE 0.3650
# Patience grace period: 30
# ---------------------------------
# Epoch 5/500
# Train RMSE: 0.3785
# Val RMSE: 0.3531, Val MAE: 0.2526
# Test RMSE: 0.4352, Test MAE: 0.2988
# ---------------------------------
# Model saved at epoch 5 with val RMSE 0.3531
# Patience grace period: 30
# ---------------------------------
# Epoch 6/500
# Train RMSE: 0.3666
# Val RMSE: 0.3452, Val MAE: 0.2477
# Test RMSE: 0.4289, Test MAE: 0.2945
# ---------------------------------
# Model saved at epoch 6 with val RMSE 0.3452
# Patience grace period: 30
# ---------------------------------
# Epoch 7/500
# Train RMSE: 0.3582
# Val RMSE: 0.3402, Val MAE: 0.2446
# Test RMSE: 0.4254, Test MAE: 0.2916
# ---------------------------------
# Model saved at epoch 7 with val RMSE 0.3402
# Patience grace period: 30
# ---------------------------------
# Epoch 8/500
# Train RMSE: 0.3523
# Val RMSE: 0.3368, Val MAE: 0.2423
# Test RMSE: 0.4235, Test MAE: 0.2901
# ---------------------------------
# Model saved at epoch 8 with val RMSE 0.3368
# Patience grace period: 30
# ---------------------------------
# Epoch 9/500
# Train RMSE: 0.3475
# Val RMSE: 0.3341, Val MAE: 0.2409
# Test RMSE: 0.4212, Test MAE: 0.2882
# ---------------------------------
# Model saved at epoch 9 with val RMSE 0.3341
# Patience grace period: 30
# ---------------------------------
# Epoch 10/500
# Train RMSE: 0.3435
# Val RMSE: 0.3318, Val MAE: 0.2393
# Test RMSE: 0.4198, Test MAE: 0.2871
# ---------------------------------
# Model saved at epoch 10 with val RMSE 0.3318
# Patience grace period: 30
# ---------------------------------
# Epoch 11/500
# Train RMSE: 0.3400
# Val RMSE: 0.3299, Val MAE: 0.2381
# Test RMSE: 0.4187, Test MAE: 0.2863
# ---------------------------------
# Model saved at epoch 11 with val RMSE 0.3299
# Patience grace period: 30
# ---------------------------------
# Epoch 12/500
# Train RMSE: 0.3369
# Val RMSE: 0.3283, Val MAE: 0.2372
# Test RMSE: 0.4170, Test MAE: 0.2851
# ---------------------------------
# Model saved at epoch 12 with val RMSE 0.3283
# Patience grace period: 30
# ---------------------------------
# Epoch 13/500
# Train RMSE: 0.3343
# Val RMSE: 0.3269, Val MAE: 0.2363
# Test RMSE: 0.4157, Test MAE: 0.2838
# ---------------------------------
# Model saved at epoch 13 with val RMSE 0.3269
# Patience grace period: 30
# ---------------------------------
# Epoch 14/500
# Train RMSE: 0.3319
# Val RMSE: 0.3256, Val MAE: 0.2355
# Test RMSE: 0.4150, Test MAE: 0.2832
# ---------------------------------
# Model saved at epoch 14 with val RMSE 0.3256
# Patience grace period: 30
# ---------------------------------
# Epoch 15/500
# Train RMSE: 0.3298
# Val RMSE: 0.3250, Val MAE: 0.2351
# Test RMSE: 0.4151, Test MAE: 0.2834
# ---------------------------------
# Model saved at epoch 15 with val RMSE 0.3250
# Patience grace period: 29
# ---------------------------------
# Epoch 16/500
# Train RMSE: 0.3279
# Val RMSE: 0.3244, Val MAE: 0.2349
# Test RMSE: 0.4146, Test MAE: 0.2825
# ---------------------------------
# Model saved at epoch 16 with val RMSE 0.3244
# Patience grace period: 30
# ---------------------------------
# Epoch 17/500
# Train RMSE: 0.3261
# Val RMSE: 0.3230, Val MAE: 0.2340
# Test RMSE: 0.4138, Test MAE: 0.2815
# ---------------------------------
# Model saved at epoch 17 with val RMSE 0.3230
# Patience grace period: 30
# ---------------------------------
# Epoch 18/500
# Train RMSE: 0.3247
# Val RMSE: 0.3251, Val MAE: 0.2358
# Test RMSE: 0.4169, Test MAE: 0.2827
# ---------------------------------
# Patience grace period: 28
# ---------------------------------
# Epoch 19/500
# Train RMSE: 0.3243
# Val RMSE: 0.3261, Val MAE: 0.2365
# Test RMSE: 0.4239, Test MAE: 0.2875
# ---------------------------------
# Patience grace period: 26
# ---------------------------------
# Epoch 20/500
# Train RMSE: 0.3238
# Val RMSE: 0.3215, Val MAE: 0.2328
# Test RMSE: 0.4142, Test MAE: 0.2834
# ---------------------------------
# Model saved at epoch 20 with val RMSE 0.3215
# Patience grace period: 30
# ---------------------------------
# Epoch 21/500
# Train RMSE: 0.3223
# Val RMSE: 0.3237, Val MAE: 0.2345
# Test RMSE: 0.4186, Test MAE: 0.2870
# ---------------------------------
# Patience grace period: 28
# ---------------------------------
# Epoch 22/500
# Train RMSE: 0.3210
# Val RMSE: 0.3216, Val MAE: 0.2328
# Test RMSE: 0.4172, Test MAE: 0.2855
# ---------------------------------
# Patience grace period: 27
# ---------------------------------
# Epoch 23/500
# Train RMSE: 0.3196
# Val RMSE: 0.3187, Val MAE: 0.2308
# Test RMSE: 0.4141, Test MAE: 0.2820
# ---------------------------------
# Model saved at epoch 23 with val RMSE 0.3187
# Patience grace period: 30
# ---------------------------------
# Epoch 24/500
# Train RMSE: 0.3185
# Val RMSE: 0.3199, Val MAE: 0.2318
# Test RMSE: 0.4164, Test MAE: 0.2825
# ---------------------------------
# Patience grace period: 28
# ---------------------------------
# Epoch 25/500
# Train RMSE: 0.3175
# Val RMSE: 0.3242, Val MAE: 0.2353
# Test RMSE: 0.4212, Test MAE: 0.2848
# ---------------------------------
# Patience grace period: 26
# ---------------------------------
# Epoch 26/500
# Train RMSE: 0.3167
# Val RMSE: 0.3261, Val MAE: 0.2369
# Test RMSE: 0.4240, Test MAE: 0.2865
# ---------------------------------
# Patience grace period: 24
# ---------------------------------
# Epoch 27/500
# Train RMSE: 0.3155
# Val RMSE: 0.3216, Val MAE: 0.2334
# Test RMSE: 0.4162, Test MAE: 0.2818
# ---------------------------------
# Patience grace period: 23
# ---------------------------------
# Epoch 28/500
# Train RMSE: 0.3143
# Val RMSE: 0.3180, Val MAE: 0.2307
# Test RMSE: 0.4096, Test MAE: 0.2779
# ---------------------------------
# Model saved at epoch 28 with val RMSE 0.3180
# Patience grace period: 22
# ---------------------------------
# Epoch 29/500
# Train RMSE: 0.3134
# Val RMSE: 0.3168, Val MAE: 0.2297
# Test RMSE: 0.4085, Test MAE: 0.2779
# ---------------------------------
# Model saved at epoch 29 with val RMSE 0.3168
# Patience grace period: 30
# ---------------------------------
# Epoch 30/500
# Train RMSE: 0.3125
# Val RMSE: 0.3163, Val MAE: 0.2292
# Test RMSE: 0.4094, Test MAE: 0.2787
# ---------------------------------
# Model saved at epoch 30 with val RMSE 0.3163
# Patience grace period: 29
# ---------------------------------
# Epoch 31/500
# Train RMSE: 0.3117
# Val RMSE: 0.3160, Val MAE: 0.2290
# Test RMSE: 0.4098, Test MAE: 0.2790
# ---------------------------------
# Model saved at epoch 31 with val RMSE 0.3160
# Patience grace period: 28
# ---------------------------------
# Epoch 32/500
# Train RMSE: 0.3112
# Val RMSE: 0.3162, Val MAE: 0.2289
# Test RMSE: 0.4105, Test MAE: 0.2790
# ---------------------------------
# Patience grace period: 26
# ---------------------------------
# Epoch 33/500
# Train RMSE: 0.3104
# Val RMSE: 0.3159, Val MAE: 0.2288
# Test RMSE: 0.4102, Test MAE: 0.2787
# ---------------------------------
# Model saved at epoch 33 with val RMSE 0.3159
# Patience grace period: 25
# ---------------------------------
# Epoch 34/500
# Train RMSE: 0.3104
# Val RMSE: 0.3159, Val MAE: 0.2287
# Test RMSE: 0.4074, Test MAE: 0.2773
# ---------------------------------
# Patience grace period: 23
# ---------------------------------
# Epoch 35/500
# Train RMSE: 0.3106
# Val RMSE: 0.3209, Val MAE: 0.2318
# Test RMSE: 0.4134, Test MAE: 0.2814
# ---------------------------------
# Patience grace period: 21
# ---------------------------------
# Epoch 36/500
# Train RMSE: 0.3110
# Val RMSE: 0.3217, Val MAE: 0.2322
# Test RMSE: 0.4175, Test MAE: 0.2841
# ---------------------------------
# Patience grace period: 19
# ---------------------------------
# Epoch 37/500
# Train RMSE: 0.3121
# Val RMSE: 0.3156, Val MAE: 0.2283
# Test RMSE: 0.4084, Test MAE: 0.2779
# ---------------------------------
# Model saved at epoch 37 with val RMSE 0.3156
# Patience grace period: 30
# ---------------------------------
# Epoch 38/500
# Train RMSE: 0.3116
# Val RMSE: 0.3148, Val MAE: 0.2279
# Test RMSE: 0.4090, Test MAE: 0.2790
# ---------------------------------
# Model saved at epoch 38 with val RMSE 0.3148
# Patience grace period: 29
# ---------------------------------
# Epoch 39/500
# Train RMSE: 0.3100
# Val RMSE: 0.3142, Val MAE: 0.2276
# Test RMSE: 0.4117, Test MAE: 0.2802
# ---------------------------------
# Model saved at epoch 39 with val RMSE 0.3142
# Patience grace period: 30
# ---------------------------------
# Epoch 40/500
# Train RMSE: 0.3088
# Val RMSE: 0.3149, Val MAE: 0.2280
# Test RMSE: 0.4173, Test MAE: 0.2831
# ---------------------------------
# Patience grace period: 28
# ---------------------------------
# Epoch 41/500
# Train RMSE: 0.3074
# Val RMSE: 0.3155, Val MAE: 0.2285
# Test RMSE: 0.4219, Test MAE: 0.2860
# ---------------------------------
# Patience grace period: 26
# ---------------------------------
# Epoch 42/500
# Train RMSE: 0.3061
# Val RMSE: 0.3150, Val MAE: 0.2282
# Test RMSE: 0.4202, Test MAE: 0.2847
# ---------------------------------
# Patience grace period: 25
# ---------------------------------
# Epoch 43/500
# Train RMSE: 0.3050
# Val RMSE: 0.3150, Val MAE: 0.2282
# Test RMSE: 0.4203, Test MAE: 0.2847
# ---------------------------------
# Patience grace period: 23
# ---------------------------------
# Epoch 44/500
# Train RMSE: 0.3041
# Val RMSE: 0.3143, Val MAE: 0.2277
# Test RMSE: 0.4169, Test MAE: 0.2824
# ---------------------------------
# Patience grace period: 22
# ---------------------------------
# Epoch 45/500
# Train RMSE: 0.3032
# Val RMSE: 0.3142, Val MAE: 0.2276
# Test RMSE: 0.4159, Test MAE: 0.2816
# ---------------------------------
# Model saved at epoch 45 with val RMSE 0.3142
# Patience grace period: 21
# ---------------------------------
# Epoch 46/500
# Train RMSE: 0.3026
# Val RMSE: 0.3134, Val MAE: 0.2271
# Test RMSE: 0.4112, Test MAE: 0.2785
# ---------------------------------
# Model saved at epoch 46 with val RMSE 0.3134
# Patience grace period: 20
# ---------------------------------
# Epoch 47/500
# Train RMSE: 0.3020
# Val RMSE: 0.3134, Val MAE: 0.2270
# Test RMSE: 0.4089, Test MAE: 0.2770
# ---------------------------------
# Model saved at epoch 47 with val RMSE 0.3134
# Patience grace period: 19
# ---------------------------------
# Epoch 48/500
# Train RMSE: 0.3014
# Val RMSE: 0.3131, Val MAE: 0.2268
# Test RMSE: 0.4071, Test MAE: 0.2758
# ---------------------------------
# Model saved at epoch 48 with val RMSE 0.3131
# Patience grace period: 30
# ---------------------------------
# Epoch 49/500
# Train RMSE: 0.3011
# Val RMSE: 0.3133, Val MAE: 0.2270
# Test RMSE: 0.4059, Test MAE: 0.2749
# ---------------------------------
# Patience grace period: 28
# ---------------------------------
# Epoch 50/500
# Train RMSE: 0.3008
# Val RMSE: 0.3142, Val MAE: 0.2277
# Test RMSE: 0.4068, Test MAE: 0.2758
# ---------------------------------
# Patience grace period: 26
# ---------------------------------
# Epoch 51/500
# Train RMSE: 0.3005
# Val RMSE: 0.3159, Val MAE: 0.2287
# Test RMSE: 0.4091, Test MAE: 0.2770
# ---------------------------------
# Patience grace period: 24
# ---------------------------------
# Epoch 52/500
# Train RMSE: 0.3009
# Val RMSE: 0.3181, Val MAE: 0.2302
# Test RMSE: 0.4135, Test MAE: 0.2803
# ---------------------------------
# Patience grace period: 22
# ---------------------------------
# Epoch 53/500
# Train RMSE: 0.3019
# Val RMSE: 0.3237, Val MAE: 0.2341
# Test RMSE: 0.4222, Test MAE: 0.2874
# ---------------------------------
# Patience grace period: 20
# ---------------------------------
# Epoch 54/500
# Train RMSE: 0.3046
# Val RMSE: 0.3251, Val MAE: 0.2359
# Test RMSE: 0.4230, Test MAE: 0.2912
# ---------------------------------
# Patience grace period: 18
# ---------------------------------
# Epoch 55/500
# Train RMSE: 0.3072
# Val RMSE: 0.3165, Val MAE: 0.2294
# Test RMSE: 0.4231, Test MAE: 0.2886
# ---------------------------------
# Patience grace period: 17
# ---------------------------------
# Epoch 56/500
# Train RMSE: 0.3049
# Val RMSE: 0.3230, Val MAE: 0.2330
# Test RMSE: 0.4403, Test MAE: 0.2962
# ---------------------------------
# Patience grace period: 15
# ---------------------------------
# Epoch 57/500
# Train RMSE: 0.3021
# Val RMSE: 0.3234, Val MAE: 0.2335
# Test RMSE: 0.4422, Test MAE: 0.2969
# ---------------------------------
# Patience grace period: 13
# ---------------------------------
# Epoch 58/500
# Train RMSE: 0.3000
# Val RMSE: 0.3228, Val MAE: 0.2332
# Test RMSE: 0.4386, Test MAE: 0.2947
# ---------------------------------
# Patience grace period: 12
# ---------------------------------
# Epoch 59/500
# Train RMSE: 0.2986
# Val RMSE: 0.3220, Val MAE: 0.2327
# Test RMSE: 0.4360, Test MAE: 0.2931
# ---------------------------------
# Patience grace period: 11
# ---------------------------------
# Epoch 60/500
# Train RMSE: 0.2976
# Val RMSE: 0.3206, Val MAE: 0.2318
# Test RMSE: 0.4306, Test MAE: 0.2896
# ---------------------------------
# Patience grace period: 10
# ---------------------------------
# Epoch 61/500
# Train RMSE: 0.2968
# Val RMSE: 0.3198, Val MAE: 0.2313
# Test RMSE: 0.4294, Test MAE: 0.2889
# ---------------------------------
# Patience grace period: 9
# ---------------------------------
# Epoch 62/500
# Train RMSE: 0.2962
# Val RMSE: 0.3194, Val MAE: 0.2309
# Test RMSE: 0.4269, Test MAE: 0.2872
# ---------------------------------
# Patience grace period: 8
# ---------------------------------
# Epoch 63/500
# Train RMSE: 0.2957
# Val RMSE: 0.3188, Val MAE: 0.2306
# Test RMSE: 0.4255, Test MAE: 0.2866
# ---------------------------------
# Patience grace period: 7
# ---------------------------------
# Epoch 64/500
# Train RMSE: 0.2953
# Val RMSE: 0.3173, Val MAE: 0.2295
# Test RMSE: 0.4203, Test MAE: 0.2834
# ---------------------------------
# Patience grace period: 6
# ---------------------------------
# Epoch 65/500
# Train RMSE: 0.2948
# Val RMSE: 0.3163, Val MAE: 0.2289
# Test RMSE: 0.4179, Test MAE: 0.2820
# ---------------------------------
# Patience grace period: 5
# ---------------------------------
# Epoch 66/500
# Train RMSE: 0.2943
# Val RMSE: 0.3159, Val MAE: 0.2286
# Test RMSE: 0.4178, Test MAE: 0.2820
# ---------------------------------
# Patience grace period: 4
# ---------------------------------
# Epoch 67/500
# Train RMSE: 0.2940
# Val RMSE: 0.3149, Val MAE: 0.2281
# Test RMSE: 0.4168, Test MAE: 0.2814
# ---------------------------------
# Patience grace period: 3
# ---------------------------------
# Epoch 68/500
# Train RMSE: 0.2937
# Val RMSE: 0.3137, Val MAE: 0.2272
# Test RMSE: 0.4126, Test MAE: 0.2788
# ---------------------------------
# Patience grace period: 2
# ---------------------------------
# Epoch 69/500
# Train RMSE: 0.2937
# Val RMSE: 0.3130, Val MAE: 0.2268
# Test RMSE: 0.4077, Test MAE: 0.2756
# ---------------------------------
# Model saved at epoch 69 with val RMSE 0.3130
# Patience grace period: 1
# ---------------------------------
# Epoch 70/500
# Train RMSE: 0.2936
# Val RMSE: 0.3130, Val MAE: 0.2267
# Test RMSE: 0.4052, Test MAE: 0.2738
# ---------------------------------
# Model saved at epoch 70 with val RMSE 0.3130
# Patience grace period: -1
# Early stopping triggered at epoch 70
# Final Test RMSE: 0.4052, Final Test MAE: 0.2738
# <ipython-input-2-d8b64875fc37>:120: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   self.model.load_state_dict(torch.load(os.path.join(save_dir, 'best_model.pth')))
# Pearson Corr: 0.873365272464704
# Spearman Corr: 0.8516076089467006
# p-rmse: 0.4051711171604198
#        rmse       mae  seed                            subtask        method  \
# 0  0.405171  0.273801     5  openproblems_bmmc_cite_phase2_rna  hierarchical
#
#     pearson p_value_pearson  spearman p_value_spearman
# 0  0.873365          0.0000  0.851608           0.0000

# %% [markdown]
# ## **Template CODE for Ablation Study**

# %%
# seed = 1
# random.seed(seed)
# np.random.seed(seed)
# torch.manual_seed(seed)
# torch.cuda.manual_seed(seed)
# torch.backends.cudnn.deterministic = True
# torch.backends.cudnn.benchmark = False

class LayerAttention(nn.Module):
    """
    A layer to compute attention weights over different layers' outputs.

    This layer calculates the attention weights for a set of layer outputs and produces a weighted sum of these outputs.

    Attributes
    ----------
    attention_weights : nn.Parameter
        The learnable attention weights.

    Methods
    -------
    forward(layer_outputs)
        Applies attention mechanism on the given layer outputs.

    Parameters
    ----------
    num_layers : int
        Number of layers for which attention weights are to be learned.
    num_feat : int
        The size of each feature vector.

    Usage
    -----
    - Instantiate this class and pass the outputs of different layers to the forward method to get a weighted sum.
    """
    def __init__(self, num_layers, num_feat):
        super(LayerAttention, self).__init__()
        self.attention_weights = nn.Parameter(torch.empty(num_layers, num_feat))
        nn.init.kaiming_normal_(self.attention_weights, mode='fan_in', nonlinearity='leaky_relu')

    def forward(self, layer_outputs):
        normalized_weights = F.softmax(self.attention_weights, dim=0)
        weighted_sum = sum(w * output for w, output in zip(normalized_weights, layer_outputs))
        return weighted_sum

class scParaLaG(nn.Module):
    """
    A model for graph neural network with parameterized layer aggregation.

    This model includes multiple convolutional, residual, and linear layers with an attention mechanism for aggregating
    the outputs of these layers.

    Attributes
    ----------
    conv_layers : nn.ModuleList
        A list of convolutional layers.
    residual_layers : nn.ModuleList
        A list of residual layers corresponding to the convolutional layers.
    linear_layers : nn.ModuleList
        A list of linear layers for transforming the output of the convolutional and residual layers.
    layer_attention : LayerAttention
        The layer attention mechanism for aggregating layer outputs.
    final_linear : nn.Linear
        The final linear layer for output transformation.
    dropout : nn.Dropout
        The dropout layer for regularization.

    Methods
    -------
    forward(g, features, conv_flow, agg_flow)
        Propagates input through the model layers and returns the final output.

    Parameters
    ----------
    num_heads : int
        Number of attention heads.
    FEATURE_SIZE : int
        Size of input features.
    OUTPUT_SIZE : int
        Size of output features.
    hidden_size : int
        Size of hidden layer features.
    conv_flow : list
        List of convolution layer types.
    agg_flow : list
        List of aggregation types for each convolution layer.
    act : str
        Activation function to use.
    dropout_rate : float
        Dropout rate for regularization.

    Usage
    -----
    - Instantiate this class and call the forward method with a graph, its features, and the convolution and aggregation flows.
    """
    def __init__(self, args):
        super().__init__()
        self.args = args


        num_heads = self.args.num_heads
        self.activation = self.get_activation_function(self.args.act)

        self.conv_layers = nn.ModuleList()
        self.linear_layers = nn.ModuleList()
        self.residual_layers = nn.ModuleList()
        self.layer_attention = LayerAttention(len(self.args.conv_flow) + self.args.layer_dim_ex, self.args.hidden_size)
        self.final_linear = nn.Linear(self.args.hidden_size, self.args.OUTPUT_SIZE)
        self.dropout = nn.Dropout(self.args.dropout_rate)

        in_feats = self.args.FEATURE_SIZE
        out_feats = self.args.hidden_size

        for i, (layer_type, aggregate_type) in enumerate(zip(self.args.conv_flow, self.args.agg_flow)):
            conv_layer = self.layer_factory(layer_type, in_feats, out_feats, aggregate_type, num_heads)
            self.conv_layers.append(conv_layer)

            out_in_dim = out_feats * num_heads if (layer_type == 'gat' and aggregate_type is None) else out_feats
            linear_layer = nn.Linear(in_feats, out_in_dim)
            self.linear_layers.append(linear_layer)

            residual_layer = nn.Linear(out_in_dim, self.args.hidden_size)
            self.residual_layers.append(residual_layer)

    def forward(self, g, features):
        layer_outputs = []

        for i, (conv_layer, residual_layer, linear_layer) in enumerate(
          zip(self.conv_layers, self.residual_layers, self.linear_layers)):
            conv_h = conv_layer(g, features)

            if self.args.conv_flow[i] == 'gat':
                if self.args.agg_flow[i] == 'mean':
                    conv_h = conv_h.mean(1)
                elif self.args.agg_flow[i] is None:
                    conv_h = conv_h.flatten(1)

            linear_h = linear_layer(features)
            conv_linear = conv_h + linear_h

            conv_linear_h = residual_layer(conv_linear)
            conv_linear_h = self.activation(conv_linear_h)
            conv_linear_h = self.dropout(conv_linear_h)
            layer_outputs.append(conv_linear_h)

        h = self.layer_attention(layer_outputs)
        h = self.final_linear(h)
        return h

    @staticmethod
    def layer_factory(layer_type, in_feats, out_feats, aggregate_type=None,
                      num_heads=None):
        """
        Factory method to create a layer based on the specified type.

        This method creates a graph convolutional layer of a specified type. It supports various types of layers like GATConv,
        GraphConv, and SAGEConv.

        Parameters
        ----------
        layer_type : str
            The type of layer to create ('gat', 'gconv', 'sage').
        in_feats : int
            The number of input features.
        out_feats : int
            The number of output features.
        aggregate_type : str, optional
            The type of aggregator for Conv layers.
        num_heads : int, optional
            The number of attention heads for GATConv layers.

        Returns
        -------
        nn.Module
            The created graph convolutional layer.

        Raises
        ------
        ValueError
            If the layer type is unknown.

        Usage
        -----
        - This method is used internally by the scParaLaG class to instantiate layers based on configuration parameters.
        """
        if layer_type == 'gat':
            return GATConv(in_feats=in_feats, out_feats=out_feats,
                           num_heads=num_heads, activation=F.leaky_relu)
        elif layer_type == 'gconv':
            return GraphConv(in_feats=in_feats, out_feats=out_feats)
        elif layer_type == 'sage':
            return SAGEConv(in_feats=in_feats, out_feats=out_feats,
                            aggregator_type=aggregate_type)
        else:
            raise ValueError(f"Unknown layer type: {layer_type}")

    @staticmethod
    def get_activation_function(name):
      """
      Get the specified activation function.

      This method returns an activation function based on the given name. It supports various activation functions like ReLU,
      Sigmoid, Tanh, Leaky ReLU, etc.

      Parameters
      ----------
      name : str
          The name of the activation function.

      Returns
      -------
      callable
          The corresponding activation function.

      Usage
      -----
      - This method is used internally by the scParaLaG class to set the activation function based on configuration parameters.
      """
      activation_functions = {
            'relu': F.relu,
            'relu6': F.relu6,
            'sigmoid': torch.sigmoid,
            'tanh': torch.tanh,
            'leaky_relu': F.leaky_relu,
            'selu': F.selu,
            'gelu': F.gelu,
            'rrelu': F.rrelu
      }
      return activation_functions.get(name)



class scParaLaG_Hierarchical(nn.Module):
    def __init__(self, args, num_clusters=10):
        super(scParaLaG_Hierarchical, self).__init__()
        self.args = args
        self.num_clusters = num_clusters
        num_heads = self.args.num_heads
        self.activation = scParaLaG_Hierarchical.get_activation_function(self.args.act)
        self.conv_layers = nn.ModuleList()
        self.linear_layers = nn.ModuleList()
        self.residual_layers = nn.ModuleList()
        self.layer_attention = LayerAttention(len(self.args.conv_flow) + self.args.layer_dim_ex, self.args.hidden_size)
        self.final_linear = nn.Linear(self.args.hidden_size, self.args.OUTPUT_SIZE)
        self.dropout = nn.Dropout(self.args.dropout_rate)
        # Hierarchical pooling doubles the feature dimension.
        in_feats = self.args.FEATURE_SIZE * 2
        out_feats = self.args.hidden_size
        for i, (layer_type, agg_type) in enumerate(zip(self.args.conv_flow, self.args.agg_flow)):
            conv_layer = scParaLaG_Hierarchical.layer_factory(layer_type, in_feats, out_feats, agg_type, num_heads)
            self.conv_layers.append(conv_layer)
            out_in_dim = out_feats * num_heads if (layer_type == 'gat' and agg_type is None) else out_feats
            linear_layer = nn.Linear(in_feats, out_in_dim)
            self.linear_layers.append(linear_layer)
            residual_layer = nn.Linear(out_in_dim, self.args.hidden_size)
            self.residual_layers.append(residual_layer)
            in_feats = self.args.hidden_size

    def hierarchical_pool(self, features):
        # features: [N, FEATURE_SIZE]
        N, feat_dim = features.shape
        features_np = features.detach().cpu().numpy()
        kmeans = KMeans(n_clusters=self.num_clusters, random_state=0).fit(features_np)
        labels = kmeans.labels_
        centroids = torch.tensor(kmeans.cluster_centers_, dtype=features.dtype, device=features.device)
        centroid_feats = centroids[torch.tensor(labels, device=features.device)]
        new_features = torch.cat([features, centroid_feats], dim=1)
        return new_features

    def forward(self, g, features):
        x = self.hierarchical_pool(features)  # now [N, FEATURE_SIZE*2]
        layer_outputs = []
        for i, (conv, linear, residual) in enumerate(zip(self.conv_layers, self.linear_layers, self.residual_layers)):
            conv_h = conv(g, x)
            if self.args.conv_flow[i] == 'gat':
                if self.args.agg_flow[i] == 'mean':
                    conv_h = conv_h.mean(1)
                elif self.args.agg_flow[i] is None:
                    conv_h = conv_h.flatten(1)
            linear_h = linear(x)
            combined = conv_h + linear_h
            res = residual(combined)
            res = self.activation(res)
            res = self.dropout(res)
            layer_outputs.append(res)
            x = res
        h = self.layer_attention(layer_outputs)
        h = self.final_linear(h)
        return h

    @staticmethod
    def layer_factory(layer_type, in_feats, out_feats, agg_type=None, num_heads=None):
        if layer_type == 'gat':
            return GATConv(in_feats=in_feats, out_feats=out_feats,
                           num_heads=num_heads, activation=F.leaky_relu)
        elif layer_type == 'gconv':
            return GraphConv(in_feats=in_feats, out_feats=out_feats)
        elif layer_type == 'sage':
            return SAGEConv(in_feats=in_feats, out_feats=out_feats,
                            aggregator_type=agg_type)
        else:
            raise ValueError(f"Unknown layer type: {layer_type}")

    @staticmethod
    def get_activation_function(name):
        funcs = {
            'relu': F.relu,
            'relu6': F.relu6,
            'sigmoid': torch.sigmoid,
            'tanh': torch.tanh,
            'leaky_relu': F.leaky_relu,
            'selu': F.selu,
            'gelu': F.gelu,
            'rrelu': F.rrelu
        }
        return funcs.get(name)


class scParaLaG_NoResidual(nn.Module):
    """
    scParaLaG variation without the residual connections (linear path from input).
    """
    def __init__(self, args):
        super().__init__()
        self.args = args
        self.num_layers_used = len(self.args.conv_flow)

        num_heads = self.args.num_heads
        self.activation = scParaLaG.get_activation_function(self.args.act) # Use static method

        self.conv_layers = nn.ModuleList()
        # REMOVED: self.linear_layers = nn.ModuleList()
        self.post_conv_layers = nn.ModuleList() # Renamed residual_layers for clarity
        self.layer_attention = LayerAttention(self.num_layers_used, self.args.hidden_size)
        self.final_linear = nn.Linear(self.args.hidden_size, self.args.OUTPUT_SIZE)
        self.dropout = nn.Dropout(self.args.dropout_rate)

        in_feats = self.args.FEATURE_SIZE
        out_feats = self.args.hidden_size

        for i, (layer_type, aggregate_type) in enumerate(zip(self.args.conv_flow, self.args.agg_flow)):
            current_in_feats = in_feats if i == 0 else self.args.hidden_size

            conv_layer = scParaLaG.layer_factory(layer_type, current_in_feats, out_feats, aggregate_type, num_heads)
            self.conv_layers.append(conv_layer)

            conv_out_dim = out_feats * num_heads if (layer_type == 'gat' and aggregate_type is None) else out_feats

            # REMOVED: linear_layer
            # Add a layer after convolution to ensure output is hidden_size
            post_conv_layer = nn.Linear(conv_out_dim, self.args.hidden_size)
            self.post_conv_layers.append(post_conv_layer)

    def forward(self, g, features):
        layer_outputs = []
        current_features = features

        # Note: No linear_layers to zip with
        for i, (conv_layer, post_conv_layer) in enumerate(zip(self.conv_layers, self.post_conv_layers)):
            conv_h = conv_layer(g, current_features)

            # Handle GAT output aggregation/flattening
            if self.args.conv_flow[i] == 'gat':
                if self.args.agg_flow[i] == 'mean':
                    conv_h = conv_h.mean(1)
                elif self.args.agg_flow[i] is None:
                    conv_h = conv_h.flatten(1)

            # REMOVED: linear_h = linear_layer(current_features)
            # REMOVED: conv_linear = conv_h + linear_h

            # Apply post-convolution layer, activation, and dropout
            processed_h = post_conv_layer(conv_h) # Apply the linear layer directly
            processed_h = self.activation(processed_h) if self.activation else processed_h
            processed_h = self.dropout(processed_h)

            layer_outputs.append(processed_h)
            current_features = processed_h # Update features for the next layer

        h = self.layer_attention(layer_outputs)
        h = self.final_linear(h)
        return h

class scParaLaG_NoAttention(nn.Module):
    """
    scParaLaG variation without the final LayerAttention aggregation.
    Uses the output of the *last* GNN layer instead.
    """
    def __init__(self, args):
        super().__init__()
        # Initialization is the same as base scParaLaG, except LayerAttention
        self.args = args
        self.num_layers_used = len(self.args.conv_flow)

        num_heads = self.args.num_heads
        self.activation = scParaLaG.get_activation_function(self.args.act)

        self.conv_layers = nn.ModuleList()
        self.linear_layers = nn.ModuleList()
        self.residual_layers = nn.ModuleList()
        # REMOVED: self.layer_attention = LayerAttention(...)
        self.final_linear = nn.Linear(self.args.hidden_size, self.args.OUTPUT_SIZE)
        self.dropout = nn.Dropout(self.args.dropout_rate)

        in_feats = self.args.FEATURE_SIZE
        out_feats = self.args.hidden_size

        for i, (layer_type, aggregate_type) in enumerate(zip(self.args.conv_flow, self.args.agg_flow)):
            current_in_feats = in_feats if i == 0 else self.args.hidden_size
            conv_layer = scParaLaG.layer_factory(layer_type, current_in_feats, out_feats, aggregate_type, num_heads)
            self.conv_layers.append(conv_layer)
            conv_out_dim = out_feats * num_heads if (layer_type == 'gat' and aggregate_type is None) else out_feats
            linear_layer = nn.Linear(current_in_feats, conv_out_dim)
            self.linear_layers.append(linear_layer)
            residual_layer = nn.Linear(conv_out_dim, self.args.hidden_size)
            self.residual_layers.append(residual_layer)

    def forward(self, g, features):
        # MODIFIED: No need to collect all layer_outputs
        # layer_outputs = []
        current_features = features
        last_layer_output = None # Keep track of the last output

        for i, (conv_layer, residual_layer, linear_layer) in enumerate(
          zip(self.conv_layers, self.residual_layers, self.linear_layers)):

            conv_h = conv_layer(g, current_features)

            if self.args.conv_flow[i] == 'gat':
                if self.args.agg_flow[i] == 'mean':
                    conv_h = conv_h.mean(1)
                elif self.args.agg_flow[i] is None:
                    conv_h = conv_h.flatten(1)

            linear_h = linear_layer(current_features)
            conv_linear = conv_h + linear_h
            conv_linear_h = residual_layer(conv_linear)
            conv_linear_h = self.activation(conv_linear_h) if self.activation else conv_linear_h
            conv_linear_h = self.dropout(conv_linear_h)

            # MODIFIED: Don't append, just update the latest output and features
            # layer_outputs.append(conv_linear_h)
            last_layer_output = conv_linear_h
            current_features = conv_linear_h # Update features for the next layer

        # REMOVED: h = self.layer_attention(layer_outputs)
        # Use the output of the last layer directly
        if last_layer_output is None:
             # Handle case with zero layers if necessary
             raise ValueError("Model has no layers to produce output.")
        h = last_layer_output

        h = self.final_linear(h)
        return h

# %%
class GraphCreator:
    def __init__(self, preprocess_type, n_neighbors=20, n_components=1200,
                 metric='euclidean', weight_type='gaussian', sigma=1.0):
        self.preprocess_type = preprocess_type
        self.n_neighbors = n_neighbors
        self.n_components = n_components
        self.metric = metric
        self.weight_type = weight_type
        self.sigma = sigma

    def _compute_edge_weights(self, distances):
        if self.weight_type == 'gaussian':
            return np.exp(-distances**2 / (2 * self.sigma**2))
        elif self.weight_type == 'cosine':
            return 1 - distances
        return distances

    def _build_knn_graph(self, features):
        A = kneighbors_graph(features, n_neighbors=self.n_neighbors,
                           metric=self.metric, mode='distance',
                           include_self=True)
        # Convert distances to weights
        weights = self._compute_edge_weights(A.data)
        A.data = weights

        graph = dgl.from_scipy(A)
        graph.edata['weight'] = torch.tensor(weights, dtype=torch.float32)
        return graph

    def _create_graphs(self, train_features, val_features, test_features):
        """
        Create training and testing graphs using the provided feature sets.

        Parameters
        ----------
        train_features : array-like
            The feature set for training data.
        val_features : array-like
            The feature set for validation data.
        test_features : array-like
            The feature set for testing data.

        Returns
        -------
        tuple
            A tuple containing the training, validation and testing graphs (dgl.DGLGraph, dgl.DGLGraph, dgl.DGLGraph).
        """
        train_graph = self._build_knn_graph(train_features)
        val_graph = self._build_knn_graph(val_features)
        test_graph = self._build_knn_graph(test_features)
        return train_graph, val_graph, test_graph

    def __call__(self, data: Data) -> Data:
        """
        Call method to process the data and create graphs.

        Parameters
        ----------
        data : Data
            The data object containing training and testing data.

        Returns
        -------
        Data
            The updated data object with training and testing graphs added.
        train_label : torch.Tensor
            Labels corresponding to the training data.
        val_label : torch.Tensor
            Labels corresponding to the validation data.
        test_label : torch.Tensor
            Labels corresponding to the testing data.
        ftl_shape : tuple
            Feature and Label size of the dataset.
        """
        input, label = data.get_train_data(return_type="numpy")
        test_input, test_label = data.get_test_data(return_type="numpy")
        train_input, val_input, train_label, val_label = train_test_split(
            input, label, test_size=0.05, random_state=42)



        if self.preprocess_type == 'SVD':
            embedder = TruncatedSVD(n_components=self.n_components)
            train_input = embedder.fit_transform(
                scipy.sparse.csr_matrix(train_input))
            val_input = embedder.transform(scipy.sparse.csr_matrix(val_input))
            test_input = embedder.transform(scipy.sparse.csr_matrix(test_input))
            print("Truncated", train_input.shape)

        train_graph, val_graph, test_graph = self._create_graphs(
            train_input, val_input, test_input)
        train_graph.ndata['feat'] = torch.tensor(train_input, dtype=torch.float32)
        val_graph.ndata['feat'] = torch.tensor(val_input, dtype=torch.float32)
        test_graph.ndata['feat'] = torch.tensor(test_input, dtype=torch.float32)

        data.data.uns['gtrain'] = train_graph
        data.data.uns['gval'] = val_graph
        data.data.uns['gtest'] = test_graph
        ftl_shape = (train_input.shape[1], train_label.shape[1])

        return data, train_label, val_label, test_label, ftl_shape

# %%
class CustomEarlyStopping:
    def __init__(self, patience=10, min_delta=0.001, rate_threshold=0.001):
        self.patience = patience
        self.min_delta = min_delta
        self.rate_threshold = rate_threshold
        self.best_loss = float('inf')
        self.best_epoch = -1
        self.epochs_since_improvement = 0
        self.prev_loss = float('inf')
    def update(self, current_loss, current_epoch):
        if current_loss < self.best_loss - self.min_delta:
            self.best_loss = current_loss
            self.best_epoch = current_epoch
            self.epochs_since_improvement = 0
        else:
            self.epochs_since_improvement += 1
        rate_of_improvement = (self.prev_loss - current_loss) / self.prev_loss if self.prev_loss != 0 else 0
        if rate_of_improvement < self.rate_threshold:
            self.epochs_since_improvement += 1
        print(f'Patience grace period: {self.patience - self.epochs_since_improvement}')
        self.prev_loss = current_loss
    def should_stop(self):
        return self.epochs_since_improvement >= self.patience

# Unified wrapper that selects a model variant based on args.variant.
class scParaLaGWrapper:
    def __init__(self, args):
        self.args = args
        if hasattr(self.args, 'variant'):
            variant = self.args.variant
        else:
            variant = "original"
        if variant == "original":
            ModelClass = scParaLaG
        elif variant == "hierarchical":
            ModelClass = scParaLaG_Hierarchical
        elif variant == "no_residual":
            ModelClass = scParaLaG_NoResidual
        elif variant == "no_attention":
            ModelClass = scParaLaG_NoAttention
        else:
            raise ValueError(f"Unknown variant: {variant}")
        self.model = ModelClass(self.args).to(self.args.device)

    def predict(self, graph, idx=None):
        self.model.eval()
        with torch.no_grad():
            if idx is not None:
                graph = graph.subgraph(idx).to(self.args.device)
            else:
                graph = graph.to(self.args.device)
            outputs = self.model(graph, graph.ndata['feat'])
        return outputs

    def score(self, graph, labels, idx=None):
        self.model.eval()
        with torch.no_grad():
            preds = self.predict(graph, idx)
            if idx is not None:
                preds = preds[idx]
                labels = labels[idx]
            mse_loss = F.mse_loss(preds, labels.to(self.args.device).float())
            rmse = math.sqrt(mse_loss.item())
            mae = mean_absolute_error(labels.cpu().numpy(), preds.cpu().numpy())
            return rmse, mae

    def fit(self, train_graph, val_graph, test_graph, train_label, val_label,
            test_label, num_epochs=500, batch_size=520, verbose=True,
            es_patience=20, es_min_delta=0.01, es_rate_threshold=0.001,
            learning_rate=0.000028, sample=True, l2_lambda=0.0):
        torch.manual_seed(self.args.seed)
        if self.args.device == "cuda":
            torch.cuda.manual_seed_all(self.args.seed)
        early_stopping = CustomEarlyStopping(patience=es_patience,
                                            min_delta=es_min_delta,
                                            rate_threshold=es_rate_threshold)
        optimizer = optim.Adam(self.model.parameters(), lr=learning_rate, weight_decay=l2_lambda)
        save_dir = "model_checkpoints"
        os.makedirs(save_dir, exist_ok=True)
        best_val_loss = float('inf')
        num_nodes = len(train_graph.ndata['feat'])
        indices = torch.randperm(num_nodes) if sample else torch.arange(num_nodes)
        for epoch in range(num_epochs):
            self.model.train()
            epoch_loss = 0
            for i in range(0, num_nodes, batch_size):
                batch_indices = indices[i:i+batch_size]
                subgraph = train_graph.subgraph(batch_indices).to(self.args.device)
                batch_labels = train_label[batch_indices].to(self.args.device).float()
                optimizer.zero_grad()
                outputs = self.model(subgraph, subgraph.ndata['feat'])
                loss = F.mse_loss(outputs, batch_labels)
                loss.backward()
                optimizer.step()
                epoch_loss += loss.item()
            avg_loss = math.sqrt(epoch_loss / (len(indices)/batch_size))
            val_rmse, val_mae = self.score(val_graph, val_label.float())
            test_rmse, test_mae = self.score(test_graph, test_label.float())
            if verbose:
                print('---------------------------------')
                print(f'Epoch {epoch+1}/{num_epochs}')
                print(f'Train RMSE: {avg_loss:.4f}')
                print(f'Val RMSE: {val_rmse:.4f}, Val MAE: {val_mae:.4f}')
                print(f'Test RMSE: {test_rmse:.4f}, Test MAE: {test_mae:.4f}')
                print('---------------------------------')
            if val_rmse < best_val_loss:
                best_val_loss = val_rmse
                torch.save(self.model.state_dict(), os.path.join(save_dir, 'best_model.pth'))
                print(f'Model saved at epoch {epoch+1} with val RMSE {val_rmse:.4f}')
            early_stopping.update(val_rmse, epoch)
            if early_stopping.should_stop():
                print(f"Early stopping triggered at epoch {epoch+1}")
                break
        self.model.load_state_dict(torch.load(os.path.join(save_dir, 'best_model.pth')))
        self.model.eval()
        final_test_rmse, final_test_mae = self.score(test_graph, test_label.float())
        print(f'Final Test RMSE: {final_test_rmse:.4f}, Final Test MAE: {final_test_mae:.4f}')
        # Compute correlation.
        test_graph = test_graph.to(self.args.device)
        test_feat = test_graph.ndata['feat'].to(self.args.device)
        test_label = test_label.to(self.args.device)
        outputs = self.model(test_graph, test_feat).to(self.args.device)
        rmse = math.sqrt(F.mse_loss(outputs, test_label))
        pred_cpu = outputs.cpu().detach().numpy()
        test_cpu = test_label.cpu().detach().numpy()
        pearson_corr, p_value_pearson = pearsonr(pred_cpu.flatten(), test_cpu.flatten())
        spearman_corr, p_value_spearman = spearmanr(pred_cpu.flatten(), test_cpu.flatten())
        p_value_pearson = Decimal(str(p_value_pearson)).quantize(Decimal('1.0000e+0')) if not math.isnan(p_value_pearson) else "NaN"
        p_value_spearman = Decimal(str(p_value_spearman)).quantize(Decimal('1.0000e+0')) if not math.isnan(p_value_spearman) else "NaN"
        print('Pearson Corr:', pearson_corr)
        print('Spearman Corr:', spearman_corr)
        print('p-rmse:', rmse)
        result = pd.DataFrame({
            'rmse': [rmse],
            'mae': [final_test_mae],
            'seed': [self.args.seed],
            'subtask': [self.args.subtask],
            'method': [self.args.variant if hasattr(self.args, 'variant') else 'original'],
            'pearson': [pearson_corr],
            'p_value_pearson': [p_value_pearson],
            'spearman': [spearman_corr],
            'p_value_spearman': [p_value_spearman]
        })
        print(result)
        # Clean up.
        del train_graph, val_graph, test_graph
        del train_label, val_label, test_label
        del outputs, test_feat, pred_cpu, test_cpu
        if self.args.device == "cuda":
            torch.cuda.empty_cache()
        gc.collect()

# %%
def pipeline(**kwargs):
    print("\nInitializing pipeline...")
    subtask = kwargs["subtask"]
    dataset = ModalityPredictionDataset(subtask, preprocess='feature_selection')
    data = dataset.load_data()

    # Define a base name for the saved files, specific to the subtask
    base_file_name = f"processed_data_{kwargs['subtask']}"

    # Define paths for all the processed data components
    train_graph_path = f"{base_file_name}_train_graph.pt"
    val_graph_path = f"{base_file_name}_val_graph.pt"
    test_graph_path = f"{base_file_name}_test_graph.pt"
    train_label_path = f"{base_file_name}_train_label.pt"
    val_label_path = f"{base_file_name}_val_label.pt"
    test_label_path = f"{base_file_name}_test_label.pt"
    feature_size_path = f"{base_file_name}_feature_size.pt"
    output_size_path = f"{base_file_name}_output_size.pt"
    processed_flag_path = f"{base_file_name}_processed.flag"

    # Check if the processed data files exist
    if os.path.exists(processed_flag_path) and \
       os.path.exists(train_graph_path) and \
       os.path.exists(val_graph_path) and \
       os.path.exists(test_graph_path) and \
       os.path.exists(train_label_path) and \
       os.path.exists(val_label_path) and \
       os.path.exists(test_label_path) and \
       os.path.exists(feature_size_path) and \
       os.path.exists(output_size_path):
        print("Processed data found. Loading...")
        data.data.uns['gtrain'] = torch.load(train_graph_path)
        data.data.uns['gval'] = torch.load(val_graph_path)
        data.data.uns['gtest'] = torch.load(test_graph_path)
        train_label = torch.load(train_label_path).numpy()
        val_label = torch.load(val_label_path).numpy()
        test_label = torch.load(test_label_path).numpy()
        kwargs["FEATURE_SIZE"] = torch.load(feature_size_path).item()
        kwargs["OUTPUT_SIZE"] = torch.load(output_size_path).item()
        kwargs["processed"] = True
        print("Processed data loaded.")
    else:
        kwargs["processed"] = False

    # If necessary, override preprocessing_type based on subtask.
    if kwargs["subtask"] == "openproblems_bmmc_cite_phase2_mod2":
        kwargs["preprocessing_type"] = "None"

    # Create cell-based graph as before.
    if not kwargs["processed"]:
        print("Performing data processing using GraphCreator...")
        data, train_label, val_label, test_label, ftl_shape = GraphCreator(
            kwargs["preprocessing_type"], kwargs["n_neigbours"],
            kwargs["n_components"], kwargs["metric"])(data)
        if kwargs["preprocessing_type"] == "SVD":
            kwargs["FEATURE_SIZE"] = kwargs["n_components"]
        else:
            kwargs["FEATURE_SIZE"] = ftl_shape[0]
        kwargs["OUTPUT_SIZE"] = ftl_shape[1]
        train_graph = data.data.uns['gtrain']
        val_graph = data.data.uns['gval']
        test_graph = data.data.uns['gtest']

        # Save the processed data
        torch.save(train_graph, train_graph_path)
        torch.save(val_graph, val_graph_path)
        torch.save(test_graph, test_graph_path)
        torch.save(torch.tensor(train_label), train_label_path)
        torch.save(torch.tensor(val_label), val_label_path)
        torch.save(torch.tensor(test_label), test_label_path)
        torch.save(torch.tensor([kwargs["FEATURE_SIZE"]]), feature_size_path)
        torch.save(torch.tensor([kwargs["OUTPUT_SIZE"]]), output_size_path)

        # Create the flag file
        with open(processed_flag_path, 'w') as f:
            f.write('')
        print("Data processing using GraphCreator complete and saved.")
        kwargs["processed"] = True
    else:
        train_graph = data.data.uns['gtrain']
        val_graph = data.data.uns['gval']
        test_graph = data.data.uns['gtest']

    for rand_seed in range(1, 6):
        kwargs["seed"] = rand_seed
        # Instantiate the unified wrapper.
        model = scParaLaGWrapper(Namespace(**kwargs))
        model.fit(train_graph, val_graph, test_graph,
                  torch.tensor(train_label) if 'train_label' in locals() else None,
                  torch.tensor(val_label) if 'val_label' in locals() else None,
                  torch.tensor(test_label) if 'test_label' in locals() else None,
                  num_epochs=kwargs["num_epochs"],
                  batch_size=kwargs["batch_size"],
                  verbose=kwargs["verbose"],
                  es_patience=kwargs["es_patience"],
                  es_min_delta=kwargs["es_min_delta"],
                  es_rate_threshold=kwargs["es_rate_threshold"],
                  learning_rate=kwargs["learning_rate"],
                  sample=kwargs["sample"])


parser = argparse.ArgumentParser()
parser.add_argument("-st", "--subtask", default="openproblems_bmmc_cite_phase2_mod2")
parser.add_argument("-bs", "--batch_size", default=300, type=int) #400
parser.add_argument("-ac", "--act", default="leaky_relu", choices=["relu", "relu6", "gelu", "leaky_relu"])
parser.add_argument("-convf", "--conv_flow", nargs='*', choices=['gat', 'sage', 'gconv'], default=['gat'])
parser.add_argument("-aggf", "--agg_flow", nargs='*', choices=[None, 'mean'], default=[None])
parser.add_argument("-device", "--device", default="cuda")
parser.add_argument("-lr", "--learning_rate", type=float, default=0.000064)
parser.add_argument("-hid", "--hidden_size", type=int, default=520)
parser.add_argument("-nh", "--num_heads", type=int, default=3)
parser.add_argument("-nneig", "--n_neigbours", type=int, default=18) #18
parser.add_argument("-ncomp", "--n_components", type=int, default=1200)
parser.add_argument("-m", "--metric", type=str, default='euclidean')
parser.add_argument("-dr", "--dropout_rate", type=float, default=0.2)
parser.add_argument("-ne", "--num_epochs", type=int, default=500)
parser.add_argument("-sd", "--seed", type=int, default=1)
parser.add_argument("-pat", "--es_patience", type=int, default=40)
parser.add_argument("-esmd", "--es_min_delta", type=float, default=0.01)
parser.add_argument("-esrt", "--es_rate_threshold", type=float, default=0.0008)
parser.add_argument("-lde", "--layer_dim_ex", type=int, default=3)
parser.add_argument("-v", "--verbose", type=bool, default=True)
parser.add_argument("-sam", "--sample", type=bool, default=True)
parser.add_argument("-prep", "--preprocessing_type", default="None", choices=["None", "SVD"])
parser.add_argument("-ispro", "--processed", type=bool, default=False)
# New argument to select the variant.
parser.add_argument("-var", "--variant", type=str, default="original",
                    choices=["original", "no_residual", "no_attention", "hierarchical"])
# If hierarchical variant is used, we may also want to set the number of clusters.
parser.add_argument("-nc", "--num_clusters", type=int, default=10)

args, unk = parser.parse_known_args()
torch.set_num_threads(1)
#pipeline(**vars(args))

# %% [markdown]
# ## **Ablation Study**

# %%
config_hierachical_PROTEIN = {
    "subtask": "openproblems_bmmc_cite_phase2_mod2",
    "batch_size": 520,
    "act": "relu",
    "conv_flow": ["gat"],
    "agg_flow": [None],
    "device": "cuda",
    "learning_rate": 0.000064,
    "hidden_size": 280,
    "num_heads": 6,
    "n_neigbours": 3,
    "metric": "euclidean",
    "n_components": 1200,
    "dropout_rate": 0.2,
    "num_epochs": 500,
    "seed": 1,
    "es_patience": 40,
    "es_min_delta": 0.0001,
    "es_rate_threshold": 0.00002,
    "layer_dim_ex": 3,
    "verbose": True,
    "sample": True,
    "preprocessing_type": "None",
    "variant": "original",
    "num_clusters": 10
}

pipeline(**config_hierachical_PROTEIN)
# Out:
# Initializing pipeline...
# [INFO][2025-04-15 18:02:38,733][dance][download_file] Downloading: /content/data/openproblems_bmmc_cite_phase2_mod2.zip Bytes: 625,243,451
# 100%|██████████| 596M/596M [00:29<00:00, 21.0MB/s]
# [INFO][2025-04-15 18:03:08,439][dance][unzip_file] Unzipping /content/data/openproblems_bmmc_cite_phase2_mod2.zip
# [INFO][2025-04-15 18:03:11,812][dance][delete_file] Deleting /content/data/openproblems_bmmc_cite_phase2_mod2.zip
# [INFO][2025-04-15 18:03:11,914][dance][_load_raw_data] Loading /content/data/openproblems_bmmc_cite_phase2_mod2/openproblems_bmmc_cite_phase2_mod2.censor_dataset.output_train_mod1.h5ad
# [INFO][2025-04-15 18:03:12,625][dance][_load_raw_data] Loading /content/data/openproblems_bmmc_cite_phase2_mod2/openproblems_bmmc_cite_phase2_mod2.censor_dataset.output_train_mod2.h5ad
# [INFO][2025-04-15 18:03:20,349][dance][_load_raw_data] Loading /content/data/openproblems_bmmc_cite_phase2_mod2/openproblems_bmmc_cite_phase2_mod2.censor_dataset.output_test_mod1.h5ad
# [INFO][2025-04-15 18:03:20,374][dance][_load_raw_data] Loading /content/data/openproblems_bmmc_cite_phase2_mod2/openproblems_bmmc_cite_phase2_mod2.censor_dataset.output_test_mod2.h5ad
# [INFO][2025-04-15 18:03:20,595][dance][_maybe_preprocess] Preprocessing done.
# /usr/local/lib/python3.11/dist-packages/mudata/_core/mudata.py:1531: FutureWarning: From 0.4 .update() will not pull obs/var columns from individual modalities by default anymore. Set mudata.set_options(pull_on_update=False) to adopt the new behaviour, which will become the default. Use new pull_obs/pull_var and push_obs/push_var methods for more flexibility.
#   self._update_attr("var", axis=0, join_common=join_common)
# /usr/local/lib/python3.11/dist-packages/mudata/_core/mudata.py:931: UserWarning: Cannot join columns with the same name because var_names are intersecting.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/mudata/_core/mudata.py:1429: FutureWarning: From 0.4 .update() will not pull obs/var columns from individual modalities by default anymore. Set mudata.set_options(pull_on_update=False) to adopt the new behaviour, which will become the default. Use new pull_obs/pull_var and push_obs/push_var methods for more flexibility.
#   self._update_attr("obs", axis=1, join_common=join_common)
# /usr/local/lib/python3.11/dist-packages/mudata/_core/mudata.py:1558: UserWarning: Modality names will be prepended to var_names since there are identical var_names in different modalities.
#   warnings.warn(
# [INFO][2025-04-15 18:03:29,542][dance][set_config_from_dict] Setting config 'feature_mod' to 'mod1'
# [INFO][2025-04-15 18:03:29,543][dance][set_config_from_dict] Setting config 'label_mod' to 'mod2'
# [INFO][2025-04-15 18:03:29,544][dance][load_data] Raw data loaded:
# Data object that wraps (.data):
# MuData object with n_obs × n_vars = 67175 × 14087
#   uns:	'dance_config'
#   2 modalities
#     mod1:	67175 x 134
#       obs:	'batch'
#       layers:	'counts'
#     mod2:	67175 x 13953
#       obs:	'batch'
#       layers:	'counts'
# [INFO][2025-04-15 18:03:29,662][dance][wrapped_func] Took 0:00:52.414029 to load and process data.
# Performing data processing using GraphCreator...
# Data processing using GraphCreator complete and saved.
# ---------------------------------
# Epoch 1/500
# Train RMSE: 0.3763
# Val RMSE: 0.3256, Val MAE: 0.1336
# Test RMSE: 0.4028, Test MAE: 0.1778
# ---------------------------------
# Model saved at epoch 1 with val RMSE 0.3256
# Patience grace period: 40
# ---------------------------------
# Epoch 2/500
# Train RMSE: 0.3284
# Val RMSE: 0.2950, Val MAE: 0.1266
# Test RMSE: 0.3703, Test MAE: 0.1676
# ---------------------------------
# Model saved at epoch 2 with val RMSE 0.2950
# Patience grace period: 40
# ---------------------------------
# Epoch 3/500
# Train RMSE: 0.3052
# Val RMSE: 0.2793, Val MAE: 0.1203
# Test RMSE: 0.3554, Test MAE: 0.1603
# ---------------------------------
# Model saved at epoch 3 with val RMSE 0.2793
# Patience grace period: 40
# ---------------------------------
# Epoch 4/500
# Train RMSE: 0.2918
# Val RMSE: 0.2722, Val MAE: 0.1181
# Test RMSE: 0.3488, Test MAE: 0.1577
# ---------------------------------
# Model saved at epoch 4 with val RMSE 0.2722
# Patience grace period: 40
# ---------------------------------
# Epoch 5/500
# Train RMSE: 0.2837
# Val RMSE: 0.2682, Val MAE: 0.1169
# Test RMSE: 0.3452, Test MAE: 0.1561
# ---------------------------------
# Model saved at epoch 5 with val RMSE 0.2682
# Patience grace period: 40
# ---------------------------------
# Epoch 6/500
# Train RMSE: 0.2778
# Val RMSE: 0.2652, Val MAE: 0.1152
# Test RMSE: 0.3426, Test MAE: 0.1539
# ---------------------------------
# Model saved at epoch 6 with val RMSE 0.2652
# Patience grace period: 40
# ---------------------------------
# Epoch 7/500
# Train RMSE: 0.2731
# Val RMSE: 0.2624, Val MAE: 0.1144
# Test RMSE: 0.3392, Test MAE: 0.1524
# ---------------------------------
# Model saved at epoch 7 with val RMSE 0.2624
# Patience grace period: 40
# ---------------------------------
# Epoch 8/500
# Train RMSE: 0.2695
# Val RMSE: 0.2609, Val MAE: 0.1121
# Test RMSE: 0.3394, Test MAE: 0.1503
# ---------------------------------
# Model saved at epoch 8 with val RMSE 0.2609
# Patience grace period: 40
# ---------------------------------
# Epoch 9/500
# Train RMSE: 0.2667
# Val RMSE: 0.2593, Val MAE: 0.1116
# Test RMSE: 0.3378, Test MAE: 0.1496
# ---------------------------------
# Model saved at epoch 9 with val RMSE 0.2593
# Patience grace period: 40
# ---------------------------------
# Epoch 10/500
# Train RMSE: 0.2646
# Val RMSE: 0.2581, Val MAE: 0.1110
# Test RMSE: 0.3368, Test MAE: 0.1490
# ---------------------------------
# Model saved at epoch 10 with val RMSE 0.2581
# Patience grace period: 40
# ---------------------------------
# Epoch 11/500
# Train RMSE: 0.2630
# Val RMSE: 0.2572, Val MAE: 0.1108
# Test RMSE: 0.3359, Test MAE: 0.1487
# ---------------------------------
# Model saved at epoch 11 with val RMSE 0.2572
# Patience grace period: 40
# ---------------------------------
# Epoch 12/500
# Train RMSE: 0.2618
# Val RMSE: 0.2564, Val MAE: 0.1109
# Test RMSE: 0.3345, Test MAE: 0.1490
# ---------------------------------
# Model saved at epoch 12 with val RMSE 0.2564
# Patience grace period: 40
# ---------------------------------
# Epoch 13/500
# Train RMSE: 0.2608
# Val RMSE: 0.2559, Val MAE: 0.1101
# Test RMSE: 0.3348, Test MAE: 0.1483
# ---------------------------------
# Model saved at epoch 13 with val RMSE 0.2559
# Patience grace period: 40
# ---------------------------------
# Epoch 14/500
# Train RMSE: 0.2600
# Val RMSE: 0.2553, Val MAE: 0.1096
# Test RMSE: 0.3346, Test MAE: 0.1479
# ---------------------------------
# Model saved at epoch 14 with val RMSE 0.2553
# Patience grace period: 40
# ---------------------------------
# Epoch 15/500
# Train RMSE: 0.2592
# Val RMSE: 0.2549, Val MAE: 0.1093
# Test RMSE: 0.3340, Test MAE: 0.1478
# ---------------------------------
# Model saved at epoch 15 with val RMSE 0.2549
# Patience grace period: 40
# ---------------------------------
# Epoch 16/500
# Train RMSE: 0.2586
# Val RMSE: 0.2545, Val MAE: 0.1089
# Test RMSE: 0.3337, Test MAE: 0.1476
# ---------------------------------
# Model saved at epoch 16 with val RMSE 0.2545
# Patience grace period: 40
# ---------------------------------
# Epoch 17/500
# Train RMSE: 0.2580
# Val RMSE: 0.2541, Val MAE: 0.1090
# Test RMSE: 0.3324, Test MAE: 0.1477
# ---------------------------------
# Model saved at epoch 17 with val RMSE 0.2541
# Patience grace period: 40
# ---------------------------------
# Epoch 18/500
# Train RMSE: 0.2575
# Val RMSE: 0.2537, Val MAE: 0.1091
# Test RMSE: 0.3315, Test MAE: 0.1476
# ---------------------------------
# Model saved at epoch 18 with val RMSE 0.2537
# Patience grace period: 40
# ---------------------------------
# Epoch 19/500
# Train RMSE: 0.2571
# Val RMSE: 0.2534, Val MAE: 0.1089
# Test RMSE: 0.3312, Test MAE: 0.1476
# ---------------------------------
# Model saved at epoch 19 with val RMSE 0.2534
# Patience grace period: 40
# ---------------------------------
# Epoch 20/500
# Train RMSE: 0.2567
# Val RMSE: 0.2532, Val MAE: 0.1087
# Test RMSE: 0.3309, Test MAE: 0.1475
# ---------------------------------
# Model saved at epoch 20 with val RMSE 0.2532
# Patience grace period: 40
# ---------------------------------
# Epoch 21/500
# Train RMSE: 0.2564
# Val RMSE: 0.2530, Val MAE: 0.1084
# Test RMSE: 0.3313, Test MAE: 0.1473
# ---------------------------------
# Model saved at epoch 21 with val RMSE 0.2530
# Patience grace period: 40
# ---------------------------------
# Epoch 22/500
# Train RMSE: 0.2561
# Val RMSE: 0.2528, Val MAE: 0.1084
# Test RMSE: 0.3309, Test MAE: 0.1475
# ---------------------------------
# Model saved at epoch 22 with val RMSE 0.2528
# Patience grace period: 40
# ---------------------------------
# Epoch 23/500
# Train RMSE: 0.2558
# Val RMSE: 0.2526, Val MAE: 0.1081
# Test RMSE: 0.3309, Test MAE: 0.1474
# ---------------------------------
# Model saved at epoch 23 with val RMSE 0.2526
# Patience grace period: 40
# ---------------------------------
# Epoch 24/500
# Train RMSE: 0.2555
# Val RMSE: 0.2525, Val MAE: 0.1076
# Test RMSE: 0.3311, Test MAE: 0.1471
# ---------------------------------
# Model saved at epoch 24 with val RMSE 0.2525
# Patience grace period: 39
# ---------------------------------
# Epoch 25/500
# Train RMSE: 0.2553
# Val RMSE: 0.2523, Val MAE: 0.1077
# Test RMSE: 0.3307, Test MAE: 0.1472
# ---------------------------------
# Model saved at epoch 25 with val RMSE 0.2523
# Patience grace period: 40
# ---------------------------------
# Epoch 26/500
# Train RMSE: 0.2550
# Val RMSE: 0.2522, Val MAE: 0.1079
# Test RMSE: 0.3303, Test MAE: 0.1475
# ---------------------------------
# Model saved at epoch 26 with val RMSE 0.2522
# Patience grace period: 40
# ---------------------------------
# Epoch 27/500
# Train RMSE: 0.2548
# Val RMSE: 0.2520, Val MAE: 0.1075
# Test RMSE: 0.3302, Test MAE: 0.1473
# ---------------------------------
# Model saved at epoch 27 with val RMSE 0.2520
# Patience grace period: 40
# ---------------------------------
# Epoch 28/500
# Train RMSE: 0.2546
# Val RMSE: 0.2519, Val MAE: 0.1077
# Test RMSE: 0.3296, Test MAE: 0.1476
# ---------------------------------
# Model saved at epoch 28 with val RMSE 0.2519
# Patience grace period: 40
# ---------------------------------
# Epoch 29/500
# Train RMSE: 0.2544
# Val RMSE: 0.2517, Val MAE: 0.1074
# Test RMSE: 0.3300, Test MAE: 0.1474
# ---------------------------------
# Model saved at epoch 29 with val RMSE 0.2517
# Patience grace period: 40
# ---------------------------------
# Epoch 30/500
# Train RMSE: 0.2542
# Val RMSE: 0.2516, Val MAE: 0.1075
# Test RMSE: 0.3297, Test MAE: 0.1477
# ---------------------------------
# Model saved at epoch 30 with val RMSE 0.2516
# Patience grace period: 40
# ---------------------------------
# Epoch 31/500
# Train RMSE: 0.2540
# Val RMSE: 0.2515, Val MAE: 0.1076
# Test RMSE: 0.3291, Test MAE: 0.1478
# ---------------------------------
# Model saved at epoch 31 with val RMSE 0.2515
# Patience grace period: 40
# ---------------------------------
# Epoch 32/500
# Train RMSE: 0.2538
# Val RMSE: 0.2513, Val MAE: 0.1079
# Test RMSE: 0.3284, Test MAE: 0.1479
# ---------------------------------
# Model saved at epoch 32 with val RMSE 0.2513
# Patience grace period: 40
# ---------------------------------
# Epoch 33/500
# Train RMSE: 0.2537
# Val RMSE: 0.2512, Val MAE: 0.1078
# Test RMSE: 0.3285, Test MAE: 0.1482
# ---------------------------------
# Model saved at epoch 33 with val RMSE 0.2512
# Patience grace period: 39
# ---------------------------------
# Epoch 34/500
# Train RMSE: 0.2535
# Val RMSE: 0.2512, Val MAE: 0.1073
# Test RMSE: 0.3294, Test MAE: 0.1477
# ---------------------------------
# Model saved at epoch 34 with val RMSE 0.2512
# Patience grace period: 40
# ---------------------------------
# Epoch 35/500
# Train RMSE: 0.2533
# Val RMSE: 0.2511, Val MAE: 0.1072
# Test RMSE: 0.3288, Test MAE: 0.1480
# ---------------------------------
# Model saved at epoch 35 with val RMSE 0.2511
# Patience grace period: 40
# ---------------------------------
# Epoch 36/500
# Train RMSE: 0.2532
# Val RMSE: 0.2510, Val MAE: 0.1072
# Test RMSE: 0.3287, Test MAE: 0.1479
# ---------------------------------
# Model saved at epoch 36 with val RMSE 0.2510
# Patience grace period: 39
# ---------------------------------
# Epoch 37/500
# Train RMSE: 0.2530
# Val RMSE: 0.2509, Val MAE: 0.1071
# Test RMSE: 0.3288, Test MAE: 0.1480
# ---------------------------------
# Model saved at epoch 37 with val RMSE 0.2509
# Patience grace period: 40
# ---------------------------------
# Epoch 38/500
# Train RMSE: 0.2529
# Val RMSE: 0.2508, Val MAE: 0.1077
# Test RMSE: 0.3278, Test MAE: 0.1485
# ---------------------------------
# Model saved at epoch 38 with val RMSE 0.2508
# Patience grace period: 40
# ---------------------------------
# Epoch 39/500
# Train RMSE: 0.2528
# Val RMSE: 0.2509, Val MAE: 0.1068
# Test RMSE: 0.3292, Test MAE: 0.1479
# ---------------------------------
# Patience grace period: 38
# ---------------------------------
# Epoch 40/500
# Train RMSE: 0.2527
# Val RMSE: 0.2507, Val MAE: 0.1074
# Test RMSE: 0.3280, Test MAE: 0.1482
# ---------------------------------
# Model saved at epoch 40 with val RMSE 0.2507
# Patience grace period: 37
# ---------------------------------
# Epoch 41/500
# Train RMSE: 0.2526
# Val RMSE: 0.2507, Val MAE: 0.1066
# Test RMSE: 0.3291, Test MAE: 0.1479
# ---------------------------------
# Model saved at epoch 41 with val RMSE 0.2507
# Patience grace period: 35
# ---------------------------------
# Epoch 42/500
# Train RMSE: 0.2524
# Val RMSE: 0.2505, Val MAE: 0.1078
# Test RMSE: 0.3268, Test MAE: 0.1486
# ---------------------------------
# Model saved at epoch 42 with val RMSE 0.2505
# Patience grace period: 40
# ---------------------------------
# Epoch 43/500
# Train RMSE: 0.2524
# Val RMSE: 0.2505, Val MAE: 0.1069
# Test RMSE: 0.3282, Test MAE: 0.1482
# ---------------------------------
# Patience grace period: 38
# ---------------------------------
# Epoch 44/500
# Train RMSE: 0.2522
# Val RMSE: 0.2504, Val MAE: 0.1070
# Test RMSE: 0.3275, Test MAE: 0.1483
# ---------------------------------
# Model saved at epoch 44 with val RMSE 0.2504
# Patience grace period: 40
# ---------------------------------
# Epoch 45/500
# Train RMSE: 0.2521
# Val RMSE: 0.2504, Val MAE: 0.1069
# Test RMSE: 0.3283, Test MAE: 0.1482
# ---------------------------------
# Model saved at epoch 45 with val RMSE 0.2504
# Patience grace period: 39
# ---------------------------------
# Epoch 46/500
# Train RMSE: 0.2520
# Val RMSE: 0.2502, Val MAE: 0.1074
# Test RMSE: 0.3266, Test MAE: 0.1486
# ---------------------------------
# Model saved at epoch 46 with val RMSE 0.2502
# Patience grace period: 40
# ---------------------------------
# Epoch 47/500
# Train RMSE: 0.2519
# Val RMSE: 0.2502, Val MAE: 0.1074
# Test RMSE: 0.3265, Test MAE: 0.1486
# ---------------------------------
# Model saved at epoch 47 with val RMSE 0.2502
# Patience grace period: 39
# ---------------------------------
# Epoch 48/500
# Train RMSE: 0.2518
# Val RMSE: 0.2502, Val MAE: 0.1073
# Test RMSE: 0.3267, Test MAE: 0.1485
# ---------------------------------
# Patience grace period: 37
# ---------------------------------
# Epoch 49/500
# Train RMSE: 0.2517
# Val RMSE: 0.2501, Val MAE: 0.1065
# Test RMSE: 0.3280, Test MAE: 0.1482
# ---------------------------------
# Model saved at epoch 49 with val RMSE 0.2501
# Patience grace period: 36
# ---------------------------------
# Epoch 50/500
# Train RMSE: 0.2516
# Val RMSE: 0.2500, Val MAE: 0.1073
# Test RMSE: 0.3267, Test MAE: 0.1488
# ---------------------------------
# Model saved at epoch 50 with val RMSE 0.2500
# Patience grace period: 40
# ---------------------------------
# Epoch 51/500
# Train RMSE: 0.2516
# Val RMSE: 0.2500, Val MAE: 0.1069
# Test RMSE: 0.3270, Test MAE: 0.1485
# ---------------------------------
# Model saved at epoch 51 with val RMSE 0.2500
# Patience grace period: 39
# ---------------------------------
# Epoch 52/500
# Train RMSE: 0.2515
# Val RMSE: 0.2499, Val MAE: 0.1070
# Test RMSE: 0.3266, Test MAE: 0.1487
# ---------------------------------
# Model saved at epoch 52 with val RMSE 0.2499
# Patience grace period: 40
# ---------------------------------
# Epoch 53/500
# Train RMSE: 0.2514
# Val RMSE: 0.2499, Val MAE: 0.1071
# Test RMSE: 0.3264, Test MAE: 0.1487
# ---------------------------------
# Model saved at epoch 53 with val RMSE 0.2499
# Patience grace period: 39
# ---------------------------------
# Epoch 54/500
# Train RMSE: 0.2513
# Val RMSE: 0.2498, Val MAE: 0.1074
# Test RMSE: 0.3257, Test MAE: 0.1489
# ---------------------------------
# Model saved at epoch 54 with val RMSE 0.2498
# Patience grace period: 40
# ---------------------------------
# Epoch 55/500
# Train RMSE: 0.2512
# Val RMSE: 0.2498, Val MAE: 0.1072
# Test RMSE: 0.3261, Test MAE: 0.1489
# ---------------------------------
# Model saved at epoch 55 with val RMSE 0.2498
# Patience grace period: 39
# ---------------------------------
# Epoch 56/500
# Train RMSE: 0.2511
# Val RMSE: 0.2498, Val MAE: 0.1076
# Test RMSE: 0.3253, Test MAE: 0.1493
# ---------------------------------
# Model saved at epoch 56 with val RMSE 0.2498
# Patience grace period: 37
# ---------------------------------
# Epoch 57/500
# Train RMSE: 0.2511
# Val RMSE: 0.2497, Val MAE: 0.1074
# Test RMSE: 0.3258, Test MAE: 0.1491
# ---------------------------------
# Model saved at epoch 57 with val RMSE 0.2497
# Patience grace period: 40
# ---------------------------------
# Epoch 58/500
# Train RMSE: 0.2510
# Val RMSE: 0.2497, Val MAE: 0.1072
# Test RMSE: 0.3261, Test MAE: 0.1490
# ---------------------------------
# Patience grace period: 38
# ---------------------------------
# Epoch 59/500
# Train RMSE: 0.2510
# Val RMSE: 0.2497, Val MAE: 0.1067
# Test RMSE: 0.3265, Test MAE: 0.1490
# ---------------------------------
# Patience grace period: 36
# ---------------------------------
# Epoch 60/500
# Train RMSE: 0.2509
# Val RMSE: 0.2496, Val MAE: 0.1071
# Test RMSE: 0.3255, Test MAE: 0.1492
# ---------------------------------
# Model saved at epoch 60 with val RMSE 0.2496
# Patience grace period: 40
# ---------------------------------
# Epoch 61/500
# Train RMSE: 0.2508
# Val RMSE: 0.2495, Val MAE: 0.1071
# Test RMSE: 0.3257, Test MAE: 0.1493
# ---------------------------------
# Model saved at epoch 61 with val RMSE 0.2495
# Patience grace period: 39
# ---------------------------------
# Epoch 62/500
# Train RMSE: 0.2507
# Val RMSE: 0.2495, Val MAE: 0.1068
# Test RMSE: 0.3265, Test MAE: 0.1491
# ---------------------------------
# Model saved at epoch 62 with val RMSE 0.2495
# Patience grace period: 38
# ---------------------------------
# Epoch 63/500
# Train RMSE: 0.2507
# Val RMSE: 0.2494, Val MAE: 0.1071
# Test RMSE: 0.3259, Test MAE: 0.1494
# ---------------------------------
# Model saved at epoch 63 with val RMSE 0.2494
# Patience grace period: 40
# ---------------------------------
# Epoch 64/500
# Train RMSE: 0.2506
# Val RMSE: 0.2495, Val MAE: 0.1063
# Test RMSE: 0.3273, Test MAE: 0.1486
# ---------------------------------
# Patience grace period: 38
# ---------------------------------
# Epoch 65/500
# Train RMSE: 0.2506
# Val RMSE: 0.2495, Val MAE: 0.1068
# Test RMSE: 0.3265, Test MAE: 0.1494
# ---------------------------------
# Patience grace period: 37
# ---------------------------------
# Epoch 66/500
# Train RMSE: 0.2505
# Val RMSE: 0.2494, Val MAE: 0.1064
# Test RMSE: 0.3270, Test MAE: 0.1490
# ---------------------------------
# Model saved at epoch 66 with val RMSE 0.2494
# Patience grace period: 36
# ---------------------------------
# Epoch 67/500
# Train RMSE: 0.2505
# Val RMSE: 0.2494, Val MAE: 0.1064
# Test RMSE: 0.3268, Test MAE: 0.1491
# ---------------------------------
# Model saved at epoch 67 with val RMSE 0.2494
# Patience grace period: 35
# ---------------------------------
# Epoch 68/500
# Train RMSE: 0.2504
# Val RMSE: 0.2494, Val MAE: 0.1071
# Test RMSE: 0.3256, Test MAE: 0.1496
# ---------------------------------
# Model saved at epoch 68 with val RMSE 0.2494
# Patience grace period: 34
# ---------------------------------
# Epoch 69/500
# Train RMSE: 0.2504
# Val RMSE: 0.2493, Val MAE: 0.1072
# Test RMSE: 0.3253, Test MAE: 0.1496
# ---------------------------------
# Model saved at epoch 69 with val RMSE 0.2493
# Patience grace period: 40
# ---------------------------------
# Epoch 70/500
# Train RMSE: 0.2503
# Val RMSE: 0.2493, Val MAE: 0.1067
# Test RMSE: 0.3258, Test MAE: 0.1492
# ---------------------------------
# Model saved at epoch 70 with val RMSE 0.2493
# Patience grace period: 39
# ---------------------------------
# Epoch 71/500
# Train RMSE: 0.2503
# Val RMSE: 0.2492, Val MAE: 0.1069
# Test RMSE: 0.3257, Test MAE: 0.1497
# ---------------------------------
# Model saved at epoch 71 with val RMSE 0.2492
# Patience grace period: 38
# ---------------------------------
# Epoch 72/500
# Train RMSE: 0.2502
# Val RMSE: 0.2492, Val MAE: 0.1074
# Test RMSE: 0.3247, Test MAE: 0.1498
# ---------------------------------
# Model saved at epoch 72 with val RMSE 0.2492
# Patience grace period: 37
# ---------------------------------
# Epoch 73/500
# Train RMSE: 0.2502
# Val RMSE: 0.2492, Val MAE: 0.1064
# Test RMSE: 0.3264, Test MAE: 0.1494
# ---------------------------------
# Model saved at epoch 73 with val RMSE 0.2492
# Patience grace period: 39
# ---------------------------------
# Epoch 74/500
# Train RMSE: 0.2501
# Val RMSE: 0.2492, Val MAE: 0.1067
# Test RMSE: 0.3258, Test MAE: 0.1496
# ---------------------------------
# Model saved at epoch 74 with val RMSE 0.2492
# Patience grace period: 38
# ---------------------------------
# Epoch 75/500
# Train RMSE: 0.2501
# Val RMSE: 0.2492, Val MAE: 0.1063
# Test RMSE: 0.3263, Test MAE: 0.1494
# ---------------------------------
# Model saved at epoch 75 with val RMSE 0.2492
# Patience grace period: 37
# ---------------------------------
# Epoch 76/500
# Train RMSE: 0.2501
# Val RMSE: 0.2491, Val MAE: 0.1068
# Test RMSE: 0.3256, Test MAE: 0.1497
# ---------------------------------
# Model saved at epoch 76 with val RMSE 0.2491
# Patience grace period: 36
# ---------------------------------
# Epoch 77/500
# Train RMSE: 0.2500
# Val RMSE: 0.2491, Val MAE: 0.1070
# Test RMSE: 0.3247, Test MAE: 0.1500
# ---------------------------------
# Model saved at epoch 77 with val RMSE 0.2491
# Patience grace period: 40
# ---------------------------------
# Epoch 78/500
# Train RMSE: 0.2500
# Val RMSE: 0.2491, Val MAE: 0.1067
# Test RMSE: 0.3256, Test MAE: 0.1497
# ---------------------------------
# Model saved at epoch 78 with val RMSE 0.2491
# Patience grace period: 39
# ---------------------------------
# Epoch 79/500
# Train RMSE: 0.2499
# Val RMSE: 0.2490, Val MAE: 0.1072
# Test RMSE: 0.3250, Test MAE: 0.1500
# ---------------------------------
# Model saved at epoch 79 with val RMSE 0.2490
# Patience grace period: 38
# ---------------------------------
# Epoch 80/500
# Train RMSE: 0.2499
# Val RMSE: 0.2490, Val MAE: 0.1068
# Test RMSE: 0.3254, Test MAE: 0.1499
# ---------------------------------
# Model saved at epoch 80 with val RMSE 0.2490
# Patience grace period: 37
# ---------------------------------
# Epoch 81/500
# Train RMSE: 0.2498
# Val RMSE: 0.2490, Val MAE: 0.1066
# Test RMSE: 0.3255, Test MAE: 0.1496
# ---------------------------------
# Patience grace period: 35
# ---------------------------------
# Epoch 82/500
# Train RMSE: 0.2498
# Val RMSE: 0.2490, Val MAE: 0.1064
# Test RMSE: 0.3257, Test MAE: 0.1494
# ---------------------------------
# Model saved at epoch 82 with val RMSE 0.2490
# Patience grace period: 40
# ---------------------------------
# Epoch 83/500
# Train RMSE: 0.2497
# Val RMSE: 0.2489, Val MAE: 0.1066
# Test RMSE: 0.3257, Test MAE: 0.1496
# ---------------------------------
# Model saved at epoch 83 with val RMSE 0.2489
# Patience grace period: 39
# ---------------------------------
# Epoch 84/500
# Train RMSE: 0.2497
# Val RMSE: 0.2489, Val MAE: 0.1064
# Test RMSE: 0.3256, Test MAE: 0.1496
# ---------------------------------
# Model saved at epoch 84 with val RMSE 0.2489
# Patience grace period: 38
# ---------------------------------
# Epoch 85/500
# Train RMSE: 0.2497
# Val RMSE: 0.2489, Val MAE: 0.1068
# Test RMSE: 0.3250, Test MAE: 0.1499
# ---------------------------------
# Model saved at epoch 85 with val RMSE 0.2489
# Patience grace period: 37
# ---------------------------------
# Epoch 86/500
# Train RMSE: 0.2497
# Val RMSE: 0.2489, Val MAE: 0.1065
# Test RMSE: 0.3257, Test MAE: 0.1496
# ---------------------------------
# Model saved at epoch 86 with val RMSE 0.2489
# Patience grace period: 35
# ---------------------------------
# Epoch 87/500
# Train RMSE: 0.2496
# Val RMSE: 0.2489, Val MAE: 0.1064
# Test RMSE: 0.3257, Test MAE: 0.1496
# ---------------------------------
# Model saved at epoch 87 with val RMSE 0.2489
# Patience grace period: 34
# ---------------------------------
# Epoch 88/500
# Train RMSE: 0.2496
# Val RMSE: 0.2489, Val MAE: 0.1068
# Test RMSE: 0.3253, Test MAE: 0.1499
# ---------------------------------
# Model saved at epoch 88 with val RMSE 0.2489
# Patience grace period: 40
# ---------------------------------
# Epoch 89/500
# Train RMSE: 0.2495
# Val RMSE: 0.2488, Val MAE: 0.1071
# Test RMSE: 0.3245, Test MAE: 0.1503
# ---------------------------------
# Model saved at epoch 89 with val RMSE 0.2488
# Patience grace period: 39
# ---------------------------------
# Epoch 90/500
# Train RMSE: 0.2495
# Val RMSE: 0.2488, Val MAE: 0.1071
# Test RMSE: 0.3244, Test MAE: 0.1503
# ---------------------------------
# Model saved at epoch 90 with val RMSE 0.2488
# Patience grace period: 37
# ---------------------------------
# Epoch 91/500
# Train RMSE: 0.2495
# Val RMSE: 0.2488, Val MAE: 0.1067
# Test RMSE: 0.3251, Test MAE: 0.1498
# ---------------------------------
# Model saved at epoch 91 with val RMSE 0.2488
# Patience grace period: 36
# ---------------------------------
# Epoch 92/500
# Train RMSE: 0.2494
# Val RMSE: 0.2488, Val MAE: 0.1065
# Test RMSE: 0.3253, Test MAE: 0.1498
# ---------------------------------
# Model saved at epoch 92 with val RMSE 0.2488
# Patience grace period: 35
# ---------------------------------
# Epoch 93/500
# Train RMSE: 0.2494
# Val RMSE: 0.2487, Val MAE: 0.1068
# Test RMSE: 0.3248, Test MAE: 0.1501
# ---------------------------------
# Model saved at epoch 93 with val RMSE 0.2487
# Patience grace period: 40
# ---------------------------------
# Epoch 94/500
# Train RMSE: 0.2494
# Val RMSE: 0.2488, Val MAE: 0.1067
# Test RMSE: 0.3247, Test MAE: 0.1501
# ---------------------------------
# Patience grace period: 38
# ---------------------------------
# Epoch 95/500
# Train RMSE: 0.2493
# Val RMSE: 0.2488, Val MAE: 0.1069
# Test RMSE: 0.3244, Test MAE: 0.1500
# ---------------------------------
# Patience grace period: 36
# ---------------------------------
# Epoch 96/500
# Train RMSE: 0.2493
# Val RMSE: 0.2487, Val MAE: 0.1065
# Test RMSE: 0.3252, Test MAE: 0.1498
# ---------------------------------
# Model saved at epoch 96 with val RMSE 0.2487
# Patience grace period: 35
# ---------------------------------
# Epoch 97/500
# Train RMSE: 0.2493
# Val RMSE: 0.2487, Val MAE: 0.1071
# Test RMSE: 0.3243, Test MAE: 0.1500
# ---------------------------------
# Model saved at epoch 97 with val RMSE 0.2487
# Patience grace period: 34
# ---------------------------------
# Epoch 98/500
# Train RMSE: 0.2493
# Val RMSE: 0.2487, Val MAE: 0.1064
# Test RMSE: 0.3253, Test MAE: 0.1498
# ---------------------------------
# Patience grace period: 32
# ---------------------------------
# Epoch 99/500
# Train RMSE: 0.2492
# Val RMSE: 0.2487, Val MAE: 0.1069
# Test RMSE: 0.3242, Test MAE: 0.1504
# ---------------------------------
# Patience grace period: 30
# ---------------------------------
# Epoch 100/500
# Train RMSE: 0.2492
# Val RMSE: 0.2486, Val MAE: 0.1067
# Test RMSE: 0.3247, Test MAE: 0.1501
# ---------------------------------
# Model saved at epoch 100 with val RMSE 0.2486
# Patience grace period: 40
# ---------------------------------
# Epoch 101/500
# Train RMSE: 0.2492
# Val RMSE: 0.2487, Val MAE: 0.1065
# Test RMSE: 0.3255, Test MAE: 0.1500
# ---------------------------------
# Patience grace period: 38
# ---------------------------------
# Epoch 102/500
# Train RMSE: 0.2492
# Val RMSE: 0.2486, Val MAE: 0.1068
# Test RMSE: 0.3244, Test MAE: 0.1503
# ---------------------------------
# Model saved at epoch 102 with val RMSE 0.2486
# Patience grace period: 37
# ---------------------------------
# Epoch 103/500
# Train RMSE: 0.2491
# Val RMSE: 0.2487, Val MAE: 0.1064
# Test RMSE: 0.3250, Test MAE: 0.1500
# ---------------------------------
# Patience grace period: 35
# ---------------------------------
# Epoch 104/500
# Train RMSE: 0.2491
# Val RMSE: 0.2487, Val MAE: 0.1065
# Test RMSE: 0.3250, Test MAE: 0.1500
# ---------------------------------
# Patience grace period: 33
# ---------------------------------
# Epoch 105/500
# Train RMSE: 0.2491
# Val RMSE: 0.2486, Val MAE: 0.1063
# Test RMSE: 0.3254, Test MAE: 0.1498
# ---------------------------------
# Patience grace period: 32
# ---------------------------------
# Epoch 106/500
# Train RMSE: 0.2491
# Val RMSE: 0.2486, Val MAE: 0.1069
# Test RMSE: 0.3242, Test MAE: 0.1502
# ---------------------------------
# Model saved at epoch 106 with val RMSE 0.2486
# Patience grace period: 31
# ---------------------------------
# Epoch 107/500
# Train RMSE: 0.2490
# Val RMSE: 0.2485, Val MAE: 0.1067
# Test RMSE: 0.3247, Test MAE: 0.1499
# ---------------------------------
# Model saved at epoch 107 with val RMSE 0.2485
# Patience grace period: 40
# ---------------------------------
# Epoch 108/500
# Train RMSE: 0.2490
# Val RMSE: 0.2486, Val MAE: 0.1063
# Test RMSE: 0.3254, Test MAE: 0.1498
# ---------------------------------
# Patience grace period: 38
# ---------------------------------
# Epoch 109/500
# Train RMSE: 0.2490
# Val RMSE: 0.2485, Val MAE: 0.1066
# Test RMSE: 0.3248, Test MAE: 0.1501
# ---------------------------------
# Model saved at epoch 109 with val RMSE 0.2485
# Patience grace period: 37
# ---------------------------------
# Epoch 110/500
# Train RMSE: 0.2490
# Val RMSE: 0.2486, Val MAE: 0.1062
# Test RMSE: 0.3255, Test MAE: 0.1499
# ---------------------------------
# Patience grace period: 35
# ---------------------------------
# Epoch 111/500
# Train RMSE: 0.2489
# Val RMSE: 0.2485, Val MAE: 0.1067
# Test RMSE: 0.3246, Test MAE: 0.1501
# ---------------------------------
# Patience grace period: 34
# ---------------------------------
# Epoch 112/500
# Train RMSE: 0.2489
# Val RMSE: 0.2486, Val MAE: 0.1064
# Test RMSE: 0.3252, Test MAE: 0.1500
# ---------------------------------
# Patience grace period: 32
# ---------------------------------
# Epoch 113/500
# Train RMSE: 0.2489
# Val RMSE: 0.2486, Val MAE: 0.1063
# Test RMSE: 0.3250, Test MAE: 0.1500
# ---------------------------------
# Patience grace period: 30
# ---------------------------------
# Epoch 114/500
# Train RMSE: 0.2489
# Val RMSE: 0.2486, Val MAE: 0.1063
# Test RMSE: 0.3252, Test MAE: 0.1498
# ---------------------------------
# Patience grace period: 28
# ---------------------------------
# Epoch 115/500
# Train RMSE: 0.2489
# Val RMSE: 0.2485, Val MAE: 0.1070
# Test RMSE: 0.3241, Test MAE: 0.1502
# ---------------------------------
# Model saved at epoch 115 with val RMSE 0.2485
# Patience grace period: 27
# ---------------------------------
# Epoch 116/500
# Train RMSE: 0.2488
# Val RMSE: 0.2485, Val MAE: 0.1064
# Test RMSE: 0.3250, Test MAE: 0.1498
# ---------------------------------
# Patience grace period: 25
# ---------------------------------
# Epoch 117/500
# Train RMSE: 0.2488
# Val RMSE: 0.2485, Val MAE: 0.1064
# Test RMSE: 0.3251, Test MAE: 0.1498
# ---------------------------------
# Model saved at epoch 117 with val RMSE 0.2485
# Patience grace period: 24
# ---------------------------------
# Epoch 118/500
# Train RMSE: 0.2488
# Val RMSE: 0.2485, Val MAE: 0.1075
# Test RMSE: 0.3231, Test MAE: 0.1510
# ---------------------------------
# Patience grace period: 22
# ---------------------------------
# Epoch 119/500
# Train RMSE: 0.2488
# Val RMSE: 0.2484, Val MAE: 0.1066
# Test RMSE: 0.3245, Test MAE: 0.1499
# ---------------------------------
# Model saved at epoch 119 with val RMSE 0.2484
# Patience grace period: 21
# ---------------------------------
# Epoch 120/500
# Train RMSE: 0.2488
# Val RMSE: 0.2485, Val MAE: 0.1064
# Test RMSE: 0.3246, Test MAE: 0.1501
# ---------------------------------
# Patience grace period: 19
# ---------------------------------
# Epoch 121/500
# Train RMSE: 0.2487
# Val RMSE: 0.2485, Val MAE: 0.1059
# Test RMSE: 0.3255, Test MAE: 0.1496
# ---------------------------------
# Patience grace period: 17
# ---------------------------------
# Epoch 122/500
# Train RMSE: 0.2487
# Val RMSE: 0.2485, Val MAE: 0.1069
# Test RMSE: 0.3237, Test MAE: 0.1503
# ---------------------------------
# Patience grace period: 15
# ---------------------------------
# Epoch 123/500
# Train RMSE: 0.2487
# Val RMSE: 0.2484, Val MAE: 0.1068
# Test RMSE: 0.3240, Test MAE: 0.1505
# ---------------------------------
# Model saved at epoch 123 with val RMSE 0.2484
# Patience grace period: 14
# ---------------------------------
# Epoch 124/500
# Train RMSE: 0.2487
# Val RMSE: 0.2484, Val MAE: 0.1068
# Test RMSE: 0.3243, Test MAE: 0.1503
# ---------------------------------
# Model saved at epoch 124 with val RMSE 0.2484
# Patience grace period: 40
# ---------------------------------
# Epoch 125/500
# Train RMSE: 0.2486
# Val RMSE: 0.2484, Val MAE: 0.1067
# Test RMSE: 0.3243, Test MAE: 0.1502
# ---------------------------------
# Model saved at epoch 125 with val RMSE 0.2484
# Patience grace period: 39
# ---------------------------------
# Epoch 126/500
# Train RMSE: 0.2486
# Val RMSE: 0.2484, Val MAE: 0.1069
# Test RMSE: 0.3240, Test MAE: 0.1503
# ---------------------------------
# Model saved at epoch 126 with val RMSE 0.2484
# Patience grace period: 38
# ---------------------------------
# Epoch 127/500
# Train RMSE: 0.2486
# Val RMSE: 0.2484, Val MAE: 0.1070
# Test RMSE: 0.3236, Test MAE: 0.1505
# ---------------------------------
# Patience grace period: 36
# ---------------------------------
# Epoch 128/500
# Train RMSE: 0.2486
# Val RMSE: 0.2484, Val MAE: 0.1064
# Test RMSE: 0.3246, Test MAE: 0.1502
# ---------------------------------
# Model saved at epoch 128 with val RMSE 0.2484
# Patience grace period: 35
# ---------------------------------
# Epoch 129/500
# Train RMSE: 0.2486
# Val RMSE: 0.2484, Val MAE: 0.1070
# Test RMSE: 0.3238, Test MAE: 0.1504
# ---------------------------------
# Patience grace period: 33
# ---------------------------------
# Epoch 130/500
# Train RMSE: 0.2485
# Val RMSE: 0.2484, Val MAE: 0.1066
# Test RMSE: 0.3241, Test MAE: 0.1503
# ---------------------------------
# Patience grace period: 32
# ---------------------------------
# Epoch 131/500
# Train RMSE: 0.2485
# Val RMSE: 0.2484, Val MAE: 0.1065
# Test RMSE: 0.3242, Test MAE: 0.1501
# ---------------------------------
# Patience grace period: 31
# ---------------------------------
# Epoch 132/500
# Train RMSE: 0.2485
# Val RMSE: 0.2484, Val MAE: 0.1068
# Test RMSE: 0.3237, Test MAE: 0.1505
# ---------------------------------
# Patience grace period: 29
# ---------------------------------
# Epoch 133/500
# Train RMSE: 0.2485
# Val RMSE: 0.2483, Val MAE: 0.1066
# Test RMSE: 0.3243, Test MAE: 0.1503
# ---------------------------------
# Model saved at epoch 133 with val RMSE 0.2483
# Patience grace period: 28
# ---------------------------------
# Epoch 134/500
# Train RMSE: 0.2484
# Val RMSE: 0.2484, Val MAE: 0.1062
# Test RMSE: 0.3248, Test MAE: 0.1503
# ---------------------------------
# Patience grace period: 26
# ---------------------------------
# Epoch 135/500
# Train RMSE: 0.2485
# Val RMSE: 0.2484, Val MAE: 0.1057
# Test RMSE: 0.3261, Test MAE: 0.1494
# ---------------------------------
# Patience grace period: 24
# ---------------------------------
# Epoch 136/500
# Train RMSE: 0.2484
# Val RMSE: 0.2483, Val MAE: 0.1064
# Test RMSE: 0.3246, Test MAE: 0.1502
# ---------------------------------
# Model saved at epoch 136 with val RMSE 0.2483
# Patience grace period: 40
# ---------------------------------
# Epoch 137/500
# Train RMSE: 0.2484
# Val RMSE: 0.2483, Val MAE: 0.1065
# Test RMSE: 0.3243, Test MAE: 0.1505
# ---------------------------------
# Patience grace period: 38
# ---------------------------------
# Epoch 138/500
# Train RMSE: 0.2484
# Val RMSE: 0.2483, Val MAE: 0.1063
# Test RMSE: 0.3250, Test MAE: 0.1500
# ---------------------------------
# Model saved at epoch 138 with val RMSE 0.2483
# Patience grace period: 37
# ---------------------------------
# Epoch 139/500
# Train RMSE: 0.2484
# Val RMSE: 0.2483, Val MAE: 0.1062
# Test RMSE: 0.3252, Test MAE: 0.1500
# ---------------------------------
# Patience grace period: 35
# ---------------------------------
# Epoch 140/500
# Train RMSE: 0.2484
# Val RMSE: 0.2484, Val MAE: 0.1059
# Test RMSE: 0.3254, Test MAE: 0.1498
# ---------------------------------
# Patience grace period: 33
# ---------------------------------
# Epoch 141/500
# Train RMSE: 0.2484
# Val RMSE: 0.2483, Val MAE: 0.1064
# Test RMSE: 0.3247, Test MAE: 0.1502
# ---------------------------------
# Model saved at epoch 141 with val RMSE 0.2483
# Patience grace period: 32
# ---------------------------------
# Epoch 142/500
# Train RMSE: 0.2483
# Val RMSE: 0.2483, Val MAE: 0.1060
# Test RMSE: 0.3254, Test MAE: 0.1497
# ---------------------------------
# Patience grace period: 30
# ---------------------------------
# Epoch 143/500
# Train RMSE: 0.2483
# Val RMSE: 0.2484, Val MAE: 0.1063
# Test RMSE: 0.3252, Test MAE: 0.1501
# ---------------------------------
# Patience grace period: 28
# ---------------------------------
# Epoch 144/500
# Train RMSE: 0.2483
# Val RMSE: 0.2483, Val MAE: 0.1066
# Test RMSE: 0.3242, Test MAE: 0.1505
# ---------------------------------
# Patience grace period: 27
# ---------------------------------
# Epoch 145/500
# Train RMSE: 0.2483
# Val RMSE: 0.2483, Val MAE: 0.1063
# Test RMSE: 0.3240, Test MAE: 0.1501
# ---------------------------------
# Patience grace period: 25
# ---------------------------------
# Epoch 146/500
# Train RMSE: 0.2483
# Val RMSE: 0.2483, Val MAE: 0.1066
# Test RMSE: 0.3242, Test MAE: 0.1506
# ---------------------------------
# Patience grace period: 23
# ---------------------------------
# Epoch 147/500
# Train RMSE: 0.2483
# Val RMSE: 0.2483, Val MAE: 0.1056
# Test RMSE: 0.3259, Test MAE: 0.1496
# ---------------------------------
# Patience grace period: 21
# ---------------------------------
# Epoch 148/500
# Train RMSE: 0.2482
# Val RMSE: 0.2483, Val MAE: 0.1063
# Test RMSE: 0.3243, Test MAE: 0.1502
# ---------------------------------
# Patience grace period: 20
# ---------------------------------
# Epoch 149/500
# Train RMSE: 0.2482
# Val RMSE: 0.2483, Val MAE: 0.1059
# Test RMSE: 0.3253, Test MAE: 0.1499
# ---------------------------------
# Patience grace period: 18
# ---------------------------------
# Epoch 150/500
# Train RMSE: 0.2482
# Val RMSE: 0.2483, Val MAE: 0.1062
# Test RMSE: 0.3249, Test MAE: 0.1501
# ---------------------------------
# Model saved at epoch 150 with val RMSE 0.2483
# Patience grace period: 17
# ---------------------------------
# Epoch 151/500
# Train RMSE: 0.2482
# Val RMSE: 0.2484, Val MAE: 0.1068
# Test RMSE: 0.3237, Test MAE: 0.1507
# ---------------------------------
# Patience grace period: 15
# ---------------------------------
# Epoch 152/500
# Train RMSE: 0.2482
# Val RMSE: 0.2482, Val MAE: 0.1060
# Test RMSE: 0.3250, Test MAE: 0.1499
# ---------------------------------
# Model saved at epoch 152 with val RMSE 0.2482
# Patience grace period: 14
# ---------------------------------
# Epoch 153/500
# Train RMSE: 0.2481
# Val RMSE: 0.2483, Val MAE: 0.1061
# Test RMSE: 0.3250, Test MAE: 0.1501
# ---------------------------------
# Patience grace period: 12
# ---------------------------------
# Epoch 154/500
# Train RMSE: 0.2481
# Val RMSE: 0.2483, Val MAE: 0.1063
# Test RMSE: 0.3244, Test MAE: 0.1505
# ---------------------------------
# Patience grace period: 11
# ---------------------------------
# Epoch 155/500
# Train RMSE: 0.2481
# Val RMSE: 0.2483, Val MAE: 0.1060
# Test RMSE: 0.3249, Test MAE: 0.1502
# ---------------------------------
# Patience grace period: 9
# ---------------------------------
# Epoch 156/500
# Train RMSE: 0.2481
# Val RMSE: 0.2482, Val MAE: 0.1063
# Test RMSE: 0.3248, Test MAE: 0.1503
# ---------------------------------
# Patience grace period: 8
# ---------------------------------
# Epoch 157/500
# Train RMSE: 0.2481
# Val RMSE: 0.2482, Val MAE: 0.1060
# Test RMSE: 0.3250, Test MAE: 0.1502
# ---------------------------------
# Model saved at epoch 157 with val RMSE 0.2482
# Patience grace period: 7
# ---------------------------------
# Epoch 158/500
# Train RMSE: 0.2480
# Val RMSE: 0.2482, Val MAE: 0.1064
# Test RMSE: 0.3240, Test MAE: 0.1506
# ---------------------------------
# Patience grace period: 5
# ---------------------------------
# Epoch 159/500
# Train RMSE: 0.2481
# Val RMSE: 0.2482, Val MAE: 0.1061
# Test RMSE: 0.3250, Test MAE: 0.1500
# ---------------------------------
# Patience grace period: 3
# ---------------------------------
# Epoch 160/500
# Train RMSE: 0.2480
# Val RMSE: 0.2483, Val MAE: 0.1066
# Test RMSE: 0.3242, Test MAE: 0.1508
# ---------------------------------
# Patience grace period: 1
# ---------------------------------
# Epoch 161/500
# Train RMSE: 0.2480
# Val RMSE: 0.2483, Val MAE: 0.1063
# Test RMSE: 0.3244, Test MAE: 0.1503
# ---------------------------------
# Patience grace period: -1
# Early stopping triggered at epoch 161
# Final Test RMSE: 0.3250, Final Test MAE: 0.1502
# <ipython-input-3-2a228d64b832>:126: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   self.model.load_state_dict(torch.load(os.path.join(save_dir, 'best_model.pth')))
# Pearson Corr: 0.7486146203084426
# Spearman Corr: 0.43041760721203637
# p-rmse: 0.32504833898153657
#        rmse       mae  seed                             subtask    method  \
# 0  0.325048  0.150217     1  openproblems_bmmc_cite_phase2_mod2  original
#
#     pearson p_value_pearson  spearman p_value_spearman
# 0  0.748615          0.0000  0.430418           0.0000
# ---------------------------------
# Epoch 1/500
# Train RMSE: 0.3746
# Val RMSE: 0.3227, Val MAE: 0.1329
# Test RMSE: 0.3993, Test MAE: 0.1770
# ---------------------------------
# Model saved at epoch 1 with val RMSE 0.3227
# Patience grace period: 40
# ---------------------------------
# Epoch 2/500
# Train RMSE: 0.3272
# Val RMSE: 0.2941, Val MAE: 0.1276
# Test RMSE: 0.3683, Test MAE: 0.1683
# ---------------------------------
# Model saved at epoch 2 with val RMSE 0.2941
# Patience grace period: 40
# ---------------------------------
# Epoch 3/500
# Train RMSE: 0.3051
# Val RMSE: 0.2794, Val MAE: 0.1207
# Test RMSE: 0.3553, Test MAE: 0.1606
# ---------------------------------
# Model saved at epoch 3 with val RMSE 0.2794
# Patience grace period: 40
# ---------------------------------
# Epoch 4/500
# Train RMSE: 0.2921
# Val RMSE: 0.2727, Val MAE: 0.1180
# Test RMSE: 0.3496, Test MAE: 0.1577
# ---------------------------------
# Model saved at epoch 4 with val RMSE 0.2727
# Patience grace period: 40
# ---------------------------------
# Epoch 5/500
# Train RMSE: 0.2841
# Val RMSE: 0.2685, Val MAE: 0.1168
# Test RMSE: 0.3457, Test MAE: 0.1561
# ---------------------------------
# Model saved at epoch 5 with val RMSE 0.2685
# Patience grace period: 40
# ---------------------------------
# Epoch 6/500
# Train RMSE: 0.2782
# Val RMSE: 0.2653, Val MAE: 0.1156
# Test RMSE: 0.3419, Test MAE: 0.1541
# ---------------------------------
# Model saved at epoch 6 with val RMSE 0.2653
# Patience grace period: 40
# ---------------------------------
# Epoch 7/500
# Train RMSE: 0.2736
# Val RMSE: 0.2627, Val MAE: 0.1145
# Test RMSE: 0.3391, Test MAE: 0.1525
# ---------------------------------
# Model saved at epoch 7 with val RMSE 0.2627
# Patience grace period: 40
# ---------------------------------
# Epoch 8/500
# Train RMSE: 0.2698
# Val RMSE: 0.2606, Val MAE: 0.1136
# Test RMSE: 0.3369, Test MAE: 0.1512
# ---------------------------------
# Model saved at epoch 8 with val RMSE 0.2606
# Patience grace period: 40
# ---------------------------------
# Epoch 9/500
# Train RMSE: 0.2667
# Val RMSE: 0.2590, Val MAE: 0.1118
# Test RMSE: 0.3366, Test MAE: 0.1496
# ---------------------------------
# Model saved at epoch 9 with val RMSE 0.2590
# Patience grace period: 40
# ---------------------------------
# Epoch 10/500
# Train RMSE: 0.2644
# Val RMSE: 0.2577, Val MAE: 0.1108
# Test RMSE: 0.3365, Test MAE: 0.1488
# ---------------------------------
# Model saved at epoch 10 with val RMSE 0.2577
# Patience grace period: 40
# ---------------------------------
# Epoch 11/500
# Train RMSE: 0.2626
# Val RMSE: 0.2565, Val MAE: 0.1111
# Test RMSE: 0.3343, Test MAE: 0.1488
# ---------------------------------
# Model saved at epoch 11 with val RMSE 0.2565
# Patience grace period: 40
# ---------------------------------
# Epoch 12/500
# Train RMSE: 0.2612
# Val RMSE: 0.2557, Val MAE: 0.1104
# Test RMSE: 0.3338, Test MAE: 0.1484
# ---------------------------------
# Model saved at epoch 12 with val RMSE 0.2557
# Patience grace period: 40
# ---------------------------------
# Epoch 13/500
# Train RMSE: 0.2602
# Val RMSE: 0.2551, Val MAE: 0.1095
# Test RMSE: 0.3337, Test MAE: 0.1475
# ---------------------------------
# Model saved at epoch 13 with val RMSE 0.2551
# Patience grace period: 40
# ---------------------------------
# Epoch 14/500
# Train RMSE: 0.2593
# Val RMSE: 0.2547, Val MAE: 0.1090
# Test RMSE: 0.3336, Test MAE: 0.1472
# ---------------------------------
# Model saved at epoch 14 with val RMSE 0.2547
# Patience grace period: 40
# ---------------------------------
# Epoch 15/500
# Train RMSE: 0.2586
# Val RMSE: 0.2542, Val MAE: 0.1092
# Test RMSE: 0.3326, Test MAE: 0.1474
# ---------------------------------
# Model saved at epoch 15 with val RMSE 0.2542
# Patience grace period: 40
# ---------------------------------
# Epoch 16/500
# Train RMSE: 0.2580
# Val RMSE: 0.2539, Val MAE: 0.1086
# Test RMSE: 0.3327, Test MAE: 0.1469
# ---------------------------------
# Model saved at epoch 16 with val RMSE 0.2539
# Patience grace period: 40
# ---------------------------------
# Epoch 17/500
# Train RMSE: 0.2575
# Val RMSE: 0.2537, Val MAE: 0.1081
# Test RMSE: 0.3327, Test MAE: 0.1467
# ---------------------------------
# Model saved at epoch 17 with val RMSE 0.2537
# Patience grace period: 40
# ---------------------------------
# Epoch 18/500
# Train RMSE: 0.2571
# Val RMSE: 0.2533, Val MAE: 0.1085
# Test RMSE: 0.3316, Test MAE: 0.1471
# ---------------------------------
# Model saved at epoch 18 with val RMSE 0.2533
# Patience grace period: 40
# ---------------------------------
# Epoch 19/500
# Train RMSE: 0.2567
# Val RMSE: 0.2530, Val MAE: 0.1090
# Test RMSE: 0.3305, Test MAE: 0.1473
# ---------------------------------
# Model saved at epoch 19 with val RMSE 0.2530
# Patience grace period: 40
# ---------------------------------
# Epoch 20/500
# Train RMSE: 0.2563
# Val RMSE: 0.2528, Val MAE: 0.1084
# Test RMSE: 0.3312, Test MAE: 0.1470
# ---------------------------------
# Model saved at epoch 20 with val RMSE 0.2528
# Patience grace period: 40
# ---------------------------------
# Epoch 21/500
# Train RMSE: 0.2560
# Val RMSE: 0.2527, Val MAE: 0.1080
# Test RMSE: 0.3313, Test MAE: 0.1469
# ---------------------------------
# Model saved at epoch 21 with val RMSE 0.2527
# Patience grace period: 40
# ---------------------------------
# Epoch 22/500
# Train RMSE: 0.2557
# Val RMSE: 0.2524, Val MAE: 0.1082
# Test RMSE: 0.3302, Test MAE: 0.1472
# ---------------------------------
# Model saved at epoch 22 with val RMSE 0.2524
# Patience grace period: 40
# ---------------------------------
# Epoch 23/500
# Train RMSE: 0.2554
# Val RMSE: 0.2522, Val MAE: 0.1081
# Test RMSE: 0.3303, Test MAE: 0.1472
# ---------------------------------
# Model saved at epoch 23 with val RMSE 0.2522
# Patience grace period: 40
# ---------------------------------
# Epoch 24/500
# Train RMSE: 0.2551
# Val RMSE: 0.2520, Val MAE: 0.1081
# Test RMSE: 0.3297, Test MAE: 0.1471
# ---------------------------------
# Model saved at epoch 24 with val RMSE 0.2520
# Patience grace period: 40
# ---------------------------------
# Epoch 25/500
# Train RMSE: 0.2549
# Val RMSE: 0.2519, Val MAE: 0.1074
# Test RMSE: 0.3301, Test MAE: 0.1469
# ---------------------------------
# Model saved at epoch 25 with val RMSE 0.2519
# Patience grace period: 39
# ---------------------------------
# Epoch 26/500
# Train RMSE: 0.2547
# Val RMSE: 0.2517, Val MAE: 0.1079
# Test RMSE: 0.3292, Test MAE: 0.1472
# ---------------------------------
# Model saved at epoch 26 with val RMSE 0.2517
# Patience grace period: 40
# ---------------------------------
# Epoch 27/500
# Train RMSE: 0.2544
# Val RMSE: 0.2517, Val MAE: 0.1073
# Test RMSE: 0.3301, Test MAE: 0.1469
# ---------------------------------
# Model saved at epoch 27 with val RMSE 0.2517
# Patience grace period: 39
# ---------------------------------
# Epoch 28/500
# Train RMSE: 0.2542
# Val RMSE: 0.2516, Val MAE: 0.1071
# Test RMSE: 0.3300, Test MAE: 0.1469
# ---------------------------------
# Model saved at epoch 28 with val RMSE 0.2516
# Patience grace period: 40
# ---------------------------------
# Epoch 29/500
# Train RMSE: 0.2541
# Val RMSE: 0.2514, Val MAE: 0.1070
# Test RMSE: 0.3296, Test MAE: 0.1470
# ---------------------------------
# ...
# Val RMSE: 0.2485, Val MAE: 0.1063
# Test RMSE: 0.3251, Test MAE: 0.1495
# ---------------------------------
# Model saved at epoch 100 with val RMSE 0.2485
# Patience grace period: 29
# ---------------------------------
# Epoch 101/500
# Train RMSE: 0.2492
# Val RMSE: 0.2486, Val MAE: 0.1060
# Test RMSE: 0.3258, Test MAE: 0.1493
# ---------------------------------
# Patience grace period: 27
# ---------------------------------
# Epoch 102/500
# Train RMSE: 0.2491
# Val RMSE: 0.2485, Val MAE: 0.1067
# Test RMSE: 0.3246, Test MAE: 0.1497
# ---------------------------------
# Model saved at epoch 102 with val RMSE 0.2485
# Patience grace period: 40
# ---------------------------------
# Epoch 103/500
# Train RMSE: 0.2491
# Val RMSE: 0.2485, Val MAE: 0.1058
# Test RMSE: 0.3256, Test MAE: 0.1491
# ---------------------------------
# Model saved at epoch 103 with val RMSE 0.2485
# Patience grace period: 39
# ---------------------------------
# Epoch 104/500
# Train RMSE: 0.2491
# Val RMSE: 0.2485, Val MAE: 0.1058
# Test RMSE: 0.3254, Test MAE: 0.1491
# ---------------------------------
# Model saved at epoch 104 with val RMSE 0.2485
# Patience grace period: 38
# ---------------------------------
# Epoch 105/500
# Train RMSE: 0.2490
# Val RMSE: 0.2485, Val MAE: 0.1069
# Test RMSE: 0.3240, Test MAE: 0.1498
# ---------------------------------
# Patience grace period: 36
# ---------------------------------
# Epoch 106/500
# Train RMSE: 0.2490
# Val RMSE: 0.2485, Val MAE: 0.1065
# Test RMSE: 0.3248, Test MAE: 0.1497
# ---------------------------------
# Model saved at epoch 106 with val RMSE 0.2485
# Patience grace period: 35
# ---------------------------------
# Epoch 107/500
# Train RMSE: 0.2490
# Val RMSE: 0.2485, Val MAE: 0.1066
# Test RMSE: 0.3242, Test MAE: 0.1498
# ---------------------------------
# Model saved at epoch 107 with val RMSE 0.2485
# Patience grace period: 34
# ---------------------------------
# Epoch 108/500
# Train RMSE: 0.2490
# Val RMSE: 0.2485, Val MAE: 0.1061
# Test RMSE: 0.3255, Test MAE: 0.1494
# ---------------------------------
# Patience grace period: 32
# ---------------------------------
# Epoch 109/500
# Train RMSE: 0.2490
# Val RMSE: 0.2484, Val MAE: 0.1064
# Test RMSE: 0.3247, Test MAE: 0.1496
# ---------------------------------
# Model saved at epoch 109 with val RMSE 0.2484
# Patience grace period: 31
# ---------------------------------
# Epoch 110/500
# Train RMSE: 0.2489
# Val RMSE: 0.2484, Val MAE: 0.1061
# Test RMSE: 0.3250, Test MAE: 0.1494
# ---------------------------------
# Model saved at epoch 110 with val RMSE 0.2484
# Patience grace period: 40
# ---------------------------------
# Epoch 111/500
# Train RMSE: 0.2489
# Val RMSE: 0.2485, Val MAE: 0.1063
# Test RMSE: 0.3246, Test MAE: 0.1497
# ---------------------------------
# Patience grace period: 38
# ---------------------------------
# Epoch 112/500
# Train RMSE: 0.2489
# Val RMSE: 0.2484, Val MAE: 0.1062
# Test RMSE: 0.3249, Test MAE: 0.1495
# ---------------------------------
# Patience grace period: 37
# ---------------------------------
# Epoch 113/500
# Train RMSE: 0.2489
# Val RMSE: 0.2484, Val MAE: 0.1061
# Test RMSE: 0.3251, Test MAE: 0.1493
# ---------------------------------
# Model saved at epoch 113 with val RMSE 0.2484
# Patience grace period: 36
# ---------------------------------
# Epoch 114/500
# Train RMSE: 0.2488
# Val RMSE: 0.2484, Val MAE: 0.1065
# Test RMSE: 0.3249, Test MAE: 0.1497
# ---------------------------------
# Model saved at epoch 114 with val RMSE 0.2484
# Patience grace period: 35
# ---------------------------------
# Epoch 115/500
# Train RMSE: 0.2488
# Val RMSE: 0.2484, Val MAE: 0.1062
# Test RMSE: 0.3249, Test MAE: 0.1495
# ---------------------------------
# Patience grace period: 33
# ---------------------------------
# Epoch 116/500
# Train RMSE: 0.2488
# Val RMSE: 0.2484, Val MAE: 0.1066
# Test RMSE: 0.3242, Test MAE: 0.1497
# ---------------------------------
# Model saved at epoch 116 with val RMSE 0.2484
# Patience grace period: 32
# ---------------------------------
# Epoch 117/500
# Train RMSE: 0.2487
# Val RMSE: 0.2484, Val MAE: 0.1063
# Test RMSE: 0.3248, Test MAE: 0.1495
# ---------------------------------
# Patience grace period: 30
# ---------------------------------
# Epoch 118/500
# Train RMSE: 0.2488
# Val RMSE: 0.2483, Val MAE: 0.1061
# Test RMSE: 0.3250, Test MAE: 0.1492
# ---------------------------------
# Model saved at epoch 118 with val RMSE 0.2483
# Patience grace period: 29
# ---------------------------------
# Epoch 119/500
# Train RMSE: 0.2487
# Val RMSE: 0.2484, Val MAE: 0.1064
# Test RMSE: 0.3250, Test MAE: 0.1497
# ---------------------------------
# Patience grace period: 27
# ---------------------------------
# Epoch 120/500
# Train RMSE: 0.2487
# Val RMSE: 0.2483, Val MAE: 0.1063
# Test RMSE: 0.3249, Test MAE: 0.1494
# ---------------------------------
# Model saved at epoch 120 with val RMSE 0.2483
# Patience grace period: 26
# ---------------------------------
# Epoch 121/500
# Train RMSE: 0.2487
# Val RMSE: 0.2483, Val MAE: 0.1062
# Test RMSE: 0.3246, Test MAE: 0.1495
# ---------------------------------
# Patience grace period: 24
# ---------------------------------
# Epoch 122/500
# Train RMSE: 0.2487
# Val RMSE: 0.2483, Val MAE: 0.1063
# Test RMSE: 0.3252, Test MAE: 0.1498
# ---------------------------------
# Patience grace period: 22
# ---------------------------------
# Epoch 123/500
# Train RMSE: 0.2486
# Val RMSE: 0.2484, Val MAE: 0.1068
# Test RMSE: 0.3243, Test MAE: 0.1501
# ---------------------------------
# Patience grace period: 20
# ---------------------------------
# Epoch 124/500
# Train RMSE: 0.2486
# Val RMSE: 0.2483, Val MAE: 0.1063
# Test RMSE: 0.3250, Test MAE: 0.1497
# ---------------------------------
# Model saved at epoch 124 with val RMSE 0.2483
# Patience grace period: 19
# ---------------------------------
# Epoch 125/500
# Train RMSE: 0.2486
# Val RMSE: 0.2483, Val MAE: 0.1063
# Test RMSE: 0.3249, Test MAE: 0.1497
# ---------------------------------
# Model saved at epoch 125 with val RMSE 0.2483
# Patience grace period: 40
# ---------------------------------
# Epoch 126/500
# Train RMSE: 0.2486
# Val RMSE: 0.2483, Val MAE: 0.1064
# Test RMSE: 0.3244, Test MAE: 0.1498
# ---------------------------------
# Model saved at epoch 126 with val RMSE 0.2483
# Patience grace period: 38
# ---------------------------------
# Epoch 127/500
# Train RMSE: 0.2486
# Val RMSE: 0.2483, Val MAE: 0.1064
# Test RMSE: 0.3242, Test MAE: 0.1499
# ---------------------------------
# Model saved at epoch 127 with val RMSE 0.2483
# Patience grace period: 36
# ---------------------------------
# Epoch 128/500
# Train RMSE: 0.2486
# Val RMSE: 0.2483, Val MAE: 0.1062
# Test RMSE: 0.3245, Test MAE: 0.1497
# ---------------------------------
# Model saved at epoch 128 with val RMSE 0.2483
# Patience grace period: 35
# ---------------------------------
# Epoch 129/500
# Train RMSE: 0.2485
# Val RMSE: 0.2483, Val MAE: 0.1067
# Test RMSE: 0.3243, Test MAE: 0.1499
# ---------------------------------
# Patience grace period: 33
# ---------------------------------
# Epoch 130/500
# Train RMSE: 0.2485
# Val RMSE: 0.2483, Val MAE: 0.1064
# Test RMSE: 0.3244, Test MAE: 0.1499
# ---------------------------------
# Model saved at epoch 130 with val RMSE 0.2483
# Patience grace period: 32
# ---------------------------------
# Epoch 131/500
# Train RMSE: 0.2485
# Val RMSE: 0.2483, Val MAE: 0.1061
# Test RMSE: 0.3249, Test MAE: 0.1496
# ---------------------------------
# Model saved at epoch 131 with val RMSE 0.2483
# Patience grace period: 30
# ---------------------------------
# Epoch 132/500
# Train RMSE: 0.2485
# Val RMSE: 0.2483, Val MAE: 0.1060
# Test RMSE: 0.3257, Test MAE: 0.1492
# ---------------------------------
# Model saved at epoch 132 with val RMSE 0.2483
# Patience grace period: 29
# ---------------------------------
# Epoch 133/500
# Train RMSE: 0.2485
# Val RMSE: 0.2483, Val MAE: 0.1061
# Test RMSE: 0.3249, Test MAE: 0.1497
# ---------------------------------
# Patience grace period: 27
# ---------------------------------
# Epoch 134/500
# Train RMSE: 0.2485
# Val RMSE: 0.2482, Val MAE: 0.1057
# Test RMSE: 0.3252, Test MAE: 0.1492
# ---------------------------------
# Model saved at epoch 134 with val RMSE 0.2482
# Patience grace period: 26
# ---------------------------------
# Epoch 135/500
# Train RMSE: 0.2484
# Val RMSE: 0.2483, Val MAE: 0.1061
# Test RMSE: 0.3250, Test MAE: 0.1497
# ---------------------------------
# Patience grace period: 24
# ---------------------------------
# Epoch 136/500
# Train RMSE: 0.2484
# Val RMSE: 0.2482, Val MAE: 0.1059
# Test RMSE: 0.3249, Test MAE: 0.1497
# ---------------------------------
# Model saved at epoch 136 with val RMSE 0.2482
# Patience grace period: 23
# ---------------------------------
# Epoch 137/500
# Train RMSE: 0.2484
# Val RMSE: 0.2483, Val MAE: 0.1055
# Test RMSE: 0.3260, Test MAE: 0.1492
# ---------------------------------
# Patience grace period: 21
# ---------------------------------
# Epoch 138/500
# Train RMSE: 0.2484
# Val RMSE: 0.2482, Val MAE: 0.1057
# Test RMSE: 0.3257, Test MAE: 0.1497
# ---------------------------------
# Patience grace period: 20
# ---------------------------------
# Epoch 139/500
# Train RMSE: 0.2484
# Val RMSE: 0.2482, Val MAE: 0.1061
# Test RMSE: 0.3250, Test MAE: 0.1495
# ---------------------------------
# Model saved at epoch 139 with val RMSE 0.2482
# Patience grace period: 19
# ---------------------------------
# Epoch 140/500
# Train RMSE: 0.2483
# Val RMSE: 0.2482, Val MAE: 0.1064
# Test RMSE: 0.3248, Test MAE: 0.1501
# ---------------------------------
# Patience grace period: 17
# ---------------------------------
# Epoch 141/500
# Train RMSE: 0.2484
# Val RMSE: 0.2482, Val MAE: 0.1062
# Test RMSE: 0.3247, Test MAE: 0.1499
# ---------------------------------
# Model saved at epoch 141 with val RMSE 0.2482
# Patience grace period: 40
# ---------------------------------
# Epoch 142/500
# Train RMSE: 0.2483
# Val RMSE: 0.2482, Val MAE: 0.1060
# Test RMSE: 0.3252, Test MAE: 0.1497
# ---------------------------------
# Patience grace period: 38
# ---------------------------------
# Epoch 143/500
# Train RMSE: 0.2483
# Val RMSE: 0.2482, Val MAE: 0.1067
# Test RMSE: 0.3238, Test MAE: 0.1502
# ---------------------------------
# Patience grace period: 36
# ---------------------------------
# Epoch 144/500
# Train RMSE: 0.2483
# Val RMSE: 0.2482, Val MAE: 0.1056
# Test RMSE: 0.3254, Test MAE: 0.1494
# ---------------------------------
# Patience grace period: 35
# ---------------------------------
# Epoch 145/500
# Train RMSE: 0.2483
# Val RMSE: 0.2482, Val MAE: 0.1056
# Test RMSE: 0.3257, Test MAE: 0.1496
# ---------------------------------
# Patience grace period: 33
# ---------------------------------
# Epoch 146/500
# Train RMSE: 0.2483
# Val RMSE: 0.2482, Val MAE: 0.1058
# Test RMSE: 0.3255, Test MAE: 0.1496
# ---------------------------------
# Patience grace period: 32
# ---------------------------------
# Epoch 147/500
# Train RMSE: 0.2482
# Val RMSE: 0.2482, Val MAE: 0.1065
# Test RMSE: 0.3244, Test MAE: 0.1501
# ---------------------------------
# Patience grace period: 30
# ---------------------------------
# Epoch 148/500
# Train RMSE: 0.2482
# Val RMSE: 0.2482, Val MAE: 0.1065
# Test RMSE: 0.3242, Test MAE: 0.1500
# ---------------------------------
# Patience grace period: 28
# ---------------------------------
# Epoch 149/500
# Train RMSE: 0.2482
# Val RMSE: 0.2482, Val MAE: 0.1055
# Test RMSE: 0.3260, Test MAE: 0.1491
# ---------------------------------
# Model saved at epoch 149 with val RMSE 0.2482
# Patience grace period: 27
# ---------------------------------
# Epoch 150/500
# Train RMSE: 0.2482
# Val RMSE: 0.2482, Val MAE: 0.1061
# Test RMSE: 0.3248, Test MAE: 0.1497
# ---------------------------------
# Model saved at epoch 150 with val RMSE 0.2482
# Patience grace period: 26
# ---------------------------------
# Epoch 151/500
# Train RMSE: 0.2482
# Val RMSE: 0.2482, Val MAE: 0.1063
# Test RMSE: 0.3246, Test MAE: 0.1501
# ---------------------------------
# Patience grace period: 24
# ---------------------------------
# Epoch 152/500
# Train RMSE: 0.2482
# Val RMSE: 0.2483, Val MAE: 0.1067
# Test RMSE: 0.3236, Test MAE: 0.1505
# ---------------------------------
# Patience grace period: 22
# ---------------------------------
# Epoch 153/500
# Train RMSE: 0.2482
# Val RMSE: 0.2482, Val MAE: 0.1062
# Test RMSE: 0.3246, Test MAE: 0.1501
# ---------------------------------
# Model saved at epoch 153 with val RMSE 0.2482
# Patience grace period: 21
# ---------------------------------
# Epoch 154/500
# Train RMSE: 0.2481
# Val RMSE: 0.2482, Val MAE: 0.1061
# Test RMSE: 0.3247, Test MAE: 0.1499
# ---------------------------------
# Model saved at epoch 154 with val RMSE 0.2482
# Patience grace period: 20
# ---------------------------------
# Epoch 155/500
# Train RMSE: 0.2481
# Val RMSE: 0.2482, Val MAE: 0.1062
# Test RMSE: 0.3248, Test MAE: 0.1501
# ---------------------------------
# Patience grace period: 18
# ---------------------------------
# Epoch 156/500
# Train RMSE: 0.2481
# Val RMSE: 0.2482, Val MAE: 0.1063
# Test RMSE: 0.3241, Test MAE: 0.1503
# ---------------------------------
# Patience grace period: 17
# ---------------------------------
# Epoch 157/500
# Train RMSE: 0.2481
# Val RMSE: 0.2482, Val MAE: 0.1063
# Test RMSE: 0.3245, Test MAE: 0.1501
# ---------------------------------
# Patience grace period: 15
# ---------------------------------
# Epoch 158/500
# Train RMSE: 0.2481
# Val RMSE: 0.2481, Val MAE: 0.1059
# Test RMSE: 0.3249, Test MAE: 0.1496
# ---------------------------------
# Model saved at epoch 158 with val RMSE 0.2481
# Patience grace period: 14
# ---------------------------------
# Epoch 159/500
# Train RMSE: 0.2481
# Val RMSE: 0.2482, Val MAE: 0.1064
# Test RMSE: 0.3245, Test MAE: 0.1502
# ---------------------------------
# Patience grace period: 12
# ---------------------------------
# Epoch 160/500
# Train RMSE: 0.2480
# Val RMSE: 0.2482, Val MAE: 0.1065
# Test RMSE: 0.3241, Test MAE: 0.1503
# ---------------------------------
# Patience grace period: 10
# ---------------------------------
# Epoch 161/500
# Train RMSE: 0.2480
# Val RMSE: 0.2482, Val MAE: 0.1065
# Test RMSE: 0.3239, Test MAE: 0.1505
# ---------------------------------
# Patience grace period: 8
# ---------------------------------
# Epoch 162/500
# Train RMSE: 0.2480
# Val RMSE: 0.2482, Val MAE: 0.1059
# Test RMSE: 0.3250, Test MAE: 0.1498
# ---------------------------------
# Patience grace period: 7
# ---------------------------------
# Epoch 163/500
# Train RMSE: 0.2480
# Val RMSE: 0.2482, Val MAE: 0.1057
# Test RMSE: 0.3250, Test MAE: 0.1497
# ---------------------------------
# Patience grace period: 5
# ---------------------------------
# Epoch 164/500
# Train RMSE: 0.2480
# Val RMSE: 0.2482, Val MAE: 0.1067
# Test RMSE: 0.3235, Test MAE: 0.1503
# ---------------------------------
# Patience grace period: 3
# ---------------------------------
# Epoch 165/500
# Train RMSE: 0.2480
# Val RMSE: 0.2481, Val MAE: 0.1058
# Test RMSE: 0.3253, Test MAE: 0.1497
# ---------------------------------
# Model saved at epoch 165 with val RMSE 0.2481
# Patience grace period: 2
# ---------------------------------
# Epoch 166/500
# Train RMSE: 0.2480
# Val RMSE: 0.2482, Val MAE: 0.1063
# Test RMSE: 0.3241, Test MAE: 0.1501
# ---------------------------------
# Patience grace period: 0
# Early stopping triggered at epoch 166
# Final Test RMSE: 0.3253, Final Test MAE: 0.1497
# <ipython-input-3-2a228d64b832>:126: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   self.model.load_state_dict(torch.load(os.path.join(save_dir, 'best_model.pth')))
# Pearson Corr: 0.7481616425289367
# Spearman Corr: 0.4305377827389911
# p-rmse: 0.3252962889282863
#        rmse       mae  seed                             subtask    method  \
# 0  0.325296  0.149724     5  openproblems_bmmc_cite_phase2_mod2  original
#
#     pearson p_value_pearson  spearman p_value_spearman
# 0  0.748162          0.0000  0.430538           0.0000

# %%
config_hierachical_PROTEIN = {
    "subtask": "openproblems_bmmc_cite_phase2_mod2",
    "batch_size": 520,
    "act": "relu",
    "conv_flow": ["sage"],
    "agg_flow": ['lstm'],
    "device": "cuda",
    "learning_rate": 0.000064,
    "hidden_size": 280,
    "num_heads": 6,
    "n_neigbours": 3,
    "metric": "euclidean",
    "n_components": 1200,
    "dropout_rate": 0.2,
    "num_epochs": 500,
    "seed": 1,
    "es_patience": 40,
    "es_min_delta": 0.0001,
    "es_rate_threshold": 0.00002,
    "layer_dim_ex": 3,
    "verbose": True,
    "sample": True,
    "preprocessing_type": "None",
    "variant": "original",
    "num_clusters": 10
}

pipeline(**config_hierachical_PROTEIN)
# Out:
# [INFO][2025-04-15 18:50:14,128][dance][_load_raw_data] Loading /content/data/openproblems_bmmc_cite_phase2_mod2/openproblems_bmmc_cite_phase2_mod2.censor_dataset.output_train_mod1.h5ad
# Initializing pipeline...
# [INFO][2025-04-15 18:50:14,800][dance][_load_raw_data] Loading /content/data/openproblems_bmmc_cite_phase2_mod2/openproblems_bmmc_cite_phase2_mod2.censor_dataset.output_train_mod2.h5ad
# [INFO][2025-04-15 18:50:22,521][dance][_load_raw_data] Loading /content/data/openproblems_bmmc_cite_phase2_mod2/openproblems_bmmc_cite_phase2_mod2.censor_dataset.output_test_mod1.h5ad
# [INFO][2025-04-15 18:50:22,545][dance][_load_raw_data] Loading /content/data/openproblems_bmmc_cite_phase2_mod2/openproblems_bmmc_cite_phase2_mod2.censor_dataset.output_test_mod2.h5ad
# [INFO][2025-04-15 18:50:22,753][dance][_maybe_preprocess] Preprocessing done.
# /usr/local/lib/python3.11/dist-packages/mudata/_core/mudata.py:1531: FutureWarning: From 0.4 .update() will not pull obs/var columns from individual modalities by default anymore. Set mudata.set_options(pull_on_update=False) to adopt the new behaviour, which will become the default. Use new pull_obs/pull_var and push_obs/push_var methods for more flexibility.
#   self._update_attr("var", axis=0, join_common=join_common)
# /usr/local/lib/python3.11/dist-packages/mudata/_core/mudata.py:931: UserWarning: Cannot join columns with the same name because var_names are intersecting.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/mudata/_core/mudata.py:1429: FutureWarning: From 0.4 .update() will not pull obs/var columns from individual modalities by default anymore. Set mudata.set_options(pull_on_update=False) to adopt the new behaviour, which will become the default. Use new pull_obs/pull_var and push_obs/push_var methods for more flexibility.
#   self._update_attr("obs", axis=1, join_common=join_common)
# /usr/local/lib/python3.11/dist-packages/mudata/_core/mudata.py:1558: UserWarning: Modality names will be prepended to var_names since there are identical var_names in different modalities.
#   warnings.warn(
# [INFO][2025-04-15 18:50:29,757][dance][set_config_from_dict] Setting config 'feature_mod' to 'mod1'
# [INFO][2025-04-15 18:50:29,758][dance][set_config_from_dict] Setting config 'label_mod' to 'mod2'
# [INFO][2025-04-15 18:50:29,759][dance][load_data] Raw data loaded:
# Data object that wraps (.data):
# MuData object with n_obs × n_vars = 67175 × 14087
#   uns:	'dance_config'
#   2 modalities
#     mod1:	67175 x 134
#       obs:	'batch'
#       layers:	'counts'
#     mod2:	67175 x 13953
#       obs:	'batch'
#       layers:	'counts'
# [INFO][2025-04-15 18:50:29,875][dance][wrapped_func] Took 0:00:15.746768 to load and process data.
# <ipython-input-4-038168299b8a>:42: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   data.data.uns['gtrain'] = torch.load(train_graph_path)
# <ipython-input-4-038168299b8a>:43: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   data.data.uns['gval'] = torch.load(val_graph_path)
# <ipython-input-4-038168299b8a>:44: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   data.data.uns['gtest'] = torch.load(test_graph_path)
# <ipython-input-4-038168299b8a>:45: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   train_label = torch.load(train_label_path).numpy()
# Processed data found. Loading...
# <ipython-input-4-038168299b8a>:46: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   val_label = torch.load(val_label_path).numpy()
# <ipython-input-4-038168299b8a>:47: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   test_label = torch.load(test_label_path).numpy()
# <ipython-input-4-038168299b8a>:48: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   kwargs["FEATURE_SIZE"] = torch.load(feature_size_path).item()
# <ipython-input-4-038168299b8a>:49: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   kwargs["OUTPUT_SIZE"] = torch.load(output_size_path).item()
# Processed data loaded.
# ---------------------------------
# Epoch 1/500
# Train RMSE: 0.3784
# Val RMSE: 0.3200, Val MAE: 0.1402
# Test RMSE: 0.3927, Test MAE: 0.1848
# ---------------------------------
# Model saved at epoch 1 with val RMSE 0.3200
# Patience grace period: 40
# ---------------------------------
# Epoch 2/500
# Train RMSE: 0.3235
# Val RMSE: 0.2908, Val MAE: 0.1301
# Test RMSE: 0.3600, Test MAE: 0.1716
# ---------------------------------
# Model saved at epoch 2 with val RMSE 0.2908
# Patience grace period: 40
# ---------------------------------
# Epoch 3/500
# Train RMSE: 0.3017
# Val RMSE: 0.2777, Val MAE: 0.1231
# Test RMSE: 0.3514, Test MAE: 0.1634
# ---------------------------------
# Model saved at epoch 3 with val RMSE 0.2777
# Patience grace period: 40
# ---------------------------------
# Epoch 4/500
# Train RMSE: 0.2895
# Val RMSE: 0.2718, Val MAE: 0.1198
# Test RMSE: 0.3503, Test MAE: 0.1595
# ---------------------------------
# Model saved at epoch 4 with val RMSE 0.2718
# Patience grace period: 40
# ---------------------------------
# Epoch 5/500
# Train RMSE: 0.2822
# Val RMSE: 0.2679, Val MAE: 0.1185
# Test RMSE: 0.3477, Test MAE: 0.1575
# ---------------------------------
# Model saved at epoch 5 with val RMSE 0.2679
# Patience grace period: 40
# ---------------------------------
# Epoch 6/500
# Train RMSE: 0.2771
# Val RMSE: 0.2652, Val MAE: 0.1171
# Test RMSE: 0.3459, Test MAE: 0.1557
# ---------------------------------
# Model saved at epoch 6 with val RMSE 0.2652
# Patience grace period: 40
# ---------------------------------
# Epoch 7/500
# Train RMSE: 0.2732
# Val RMSE: 0.2630, Val MAE: 0.1160
# Test RMSE: 0.3441, Test MAE: 0.1542
# ---------------------------------
# Model saved at epoch 7 with val RMSE 0.2630
# Patience grace period: 40
# ---------------------------------
# Epoch 8/500
# Train RMSE: 0.2701
# Val RMSE: 0.2614, Val MAE: 0.1146
# Test RMSE: 0.3433, Test MAE: 0.1528
# ---------------------------------
# Model saved at epoch 8 with val RMSE 0.2614
# Patience grace period: 40
# ---------------------------------
# Epoch 9/500
# Train RMSE: 0.2675
# Val RMSE: 0.2599, Val MAE: 0.1138
# Test RMSE: 0.3415, Test MAE: 0.1517
# ---------------------------------
# Model saved at epoch 9 with val RMSE 0.2599
# Patience grace period: 40
# ---------------------------------
# Epoch 10/500
# Train RMSE: 0.2654
# Val RMSE: 0.2586, Val MAE: 0.1131
# Test RMSE: 0.3402, Test MAE: 0.1509
# ---------------------------------
# Model saved at epoch 10 with val RMSE 0.2586
# Patience grace period: 40
# ---------------------------------
# Epoch 11/500
# Train RMSE: 0.2636
# Val RMSE: 0.2577, Val MAE: 0.1122
# Test RMSE: 0.3396, Test MAE: 0.1502
# ---------------------------------
# Model saved at epoch 11 with val RMSE 0.2577
# Patience grace period: 40
# ---------------------------------
# Epoch 12/500
# Train RMSE: 0.2622
# Val RMSE: 0.2568, Val MAE: 0.1118
# Test RMSE: 0.3381, Test MAE: 0.1500
# ---------------------------------
# Model saved at epoch 12 with val RMSE 0.2568
# Patience grace period: 40
# ---------------------------------
# Epoch 13/500
# Train RMSE: 0.2611
# Val RMSE: 0.2562, Val MAE: 0.1113
# Test RMSE: 0.3375, Test MAE: 0.1496
# ---------------------------------
# Model saved at epoch 13 with val RMSE 0.2562
# Patience grace period: 40
# ---------------------------------
# Epoch 14/500
# Train RMSE: 0.2602
# Val RMSE: 0.2558, Val MAE: 0.1111
# Test RMSE: 0.3364, Test MAE: 0.1493
# ---------------------------------
# Model saved at epoch 14 with val RMSE 0.2558
# Patience grace period: 40
# ---------------------------------
# Epoch 15/500
# Train RMSE: 0.2594
# Val RMSE: 0.2555, Val MAE: 0.1114
# Test RMSE: 0.3347, Test MAE: 0.1494
# ---------------------------------
# Model saved at epoch 15 with val RMSE 0.2555
# Patience grace period: 40
# ---------------------------------
# Epoch 16/500
# Train RMSE: 0.2588
# Val RMSE: 0.2551, Val MAE: 0.1107
# Test RMSE: 0.3346, Test MAE: 0.1491
# ---------------------------------
# Model saved at epoch 16 with val RMSE 0.2551
# Patience grace period: 40
# ---------------------------------
# Epoch 17/500
# Train RMSE: 0.2582
# Val RMSE: 0.2548, Val MAE: 0.1105
# Test RMSE: 0.3344, Test MAE: 0.1489
# ---------------------------------
# Model saved at epoch 17 with val RMSE 0.2548
# Patience grace period: 40
# ---------------------------------
# Epoch 18/500
# Train RMSE: 0.2578
# Val RMSE: 0.2545, Val MAE: 0.1101
# Test RMSE: 0.3341, Test MAE: 0.1487
# ---------------------------------
# Model saved at epoch 18 with val RMSE 0.2545
# Patience grace period: 40
# ---------------------------------
# Epoch 19/500
# Train RMSE: 0.2573
# Val RMSE: 0.2542, Val MAE: 0.1099
# Test RMSE: 0.3337, Test MAE: 0.1485
# ---------------------------------
# Model saved at epoch 19 with val RMSE 0.2542
# Patience grace period: 40
# ---------------------------------
# Epoch 20/500
# Train RMSE: 0.2569
# Val RMSE: 0.2540, Val MAE: 0.1100
# Test RMSE: 0.3328, Test MAE: 0.1487
# ---------------------------------
# Model saved at epoch 20 with val RMSE 0.2540
# Patience grace period: 40
# ---------------------------------
# Epoch 21/500
# Train RMSE: 0.2566
# Val RMSE: 0.2540, Val MAE: 0.1106
# Test RMSE: 0.3313, Test MAE: 0.1490
# ---------------------------------
# Model saved at epoch 21 with val RMSE 0.2540
# Patience grace period: 39
# ---------------------------------
# Epoch 22/500
# Train RMSE: 0.2562
# Val RMSE: 0.2537, Val MAE: 0.1101
# Test RMSE: 0.3317, Test MAE: 0.1486
# ---------------------------------
# Model saved at epoch 22 with val RMSE 0.2537
# Patience grace period: 40
# ---------------------------------
# Epoch 23/500
# Train RMSE: 0.2559
# Val RMSE: 0.2536, Val MAE: 0.1104
# Test RMSE: 0.3307, Test MAE: 0.1487
# ---------------------------------
# Model saved at epoch 23 with val RMSE 0.2536
# Patience grace period: 39
# ---------------------------------
# Epoch 24/500
# Train RMSE: 0.2556
# Val RMSE: 0.2534, Val MAE: 0.1093
# Test RMSE: 0.3321, Test MAE: 0.1482
# ---------------------------------
# Model saved at epoch 24 with val RMSE 0.2534
# Patience grace period: 40
# ---------------------------------
# Epoch 25/500
# Train RMSE: 0.2554
# Val RMSE: 0.2532, Val MAE: 0.1093
# Test RMSE: 0.3316, Test MAE: 0.1483
# ---------------------------------
# Model saved at epoch 25 with val RMSE 0.2532
# Patience grace period: 40
# ---------------------------------
# Epoch 26/500
# Train RMSE: 0.2551
# Val RMSE: 0.2530, Val MAE: 0.1091
# Test RMSE: 0.3312, Test MAE: 0.1483
# ---------------------------------
# Model saved at epoch 26 with val RMSE 0.2530
# Patience grace period: 40
# ---------------------------------
# Epoch 27/500
# Train RMSE: 0.2549
# Val RMSE: 0.2529, Val MAE: 0.1095
# Test RMSE: 0.3303, Test MAE: 0.1485
# ---------------------------------
# Model saved at epoch 27 with val RMSE 0.2529
# Patience grace period: 39
# ---------------------------------
# Epoch 28/500
# Train RMSE: 0.2547
# Val RMSE: 0.2528, Val MAE: 0.1090
# Test RMSE: 0.3306, Test MAE: 0.1483
# ---------------------------------
# Model saved at epoch 28 with val RMSE 0.2528
# Patience grace period: 40
# ---------------------------------
# Epoch 29/500
# Train RMSE: 0.2545
# Val RMSE: 0.2526, Val MAE: 0.1087
# Test RMSE: 0.3309, Test MAE: 0.1481
# ---------------------------------
# Model saved at epoch 29 with val RMSE 0.2526
# Patience grace period: 40
# ---------------------------------
# Epoch 30/500
# Train RMSE: 0.2543
# Val RMSE: 0.2526, Val MAE: 0.1092
# Test RMSE: 0.3297, Test MAE: 0.1484
# ---------------------------------
# Model saved at epoch 30 with val RMSE 0.2526
# Patience grace period: 39
# ---------------------------------
# Epoch 31/500
# Train RMSE: 0.2541
# Val RMSE: 0.2525, Val MAE: 0.1089
# Test RMSE: 0.3296, Test MAE: 0.1483
# ---------------------------------
# Model saved at epoch 31 with val RMSE 0.2525
# Patience grace period: 40
# ---------------------------------
# Epoch 32/500
# Train RMSE: 0.2540
# Val RMSE: 0.2524, Val MAE: 0.1090
# Test RMSE: 0.3293, Test MAE: 0.1485
# ---------------------------------
# Model saved at epoch 32 with val RMSE 0.2524
# Patience grace period: 39
# ---------------------------------
# Epoch 33/500
# Train RMSE: 0.2538
# Val RMSE: 0.2523, Val MAE: 0.1092
# Test RMSE: 0.3291, Test MAE: 0.1484
# ---------------------------------
# Model saved at epoch 33 with val RMSE 0.2523
# Patience grace period: 40
# ---------------------------------
# Epoch 34/500
# Train RMSE: 0.2536
# Val RMSE: 0.2522, Val MAE: 0.1087
# Test RMSE: 0.3299, Test MAE: 0.1481
# ---------------------------------
# Model saved at epoch 34 with val RMSE 0.2522
# Patience grace period: 39
# ---------------------------------
# Epoch 35/500
# Train RMSE: 0.2535
# Val RMSE: 0.2522, Val MAE: 0.1090
# Test RMSE: 0.3287, Test MAE: 0.1487
# ---------------------------------
# Model saved at epoch 35 with val RMSE 0.2522
# Patience grace period: 38
# ---------------------------------
# Epoch 36/500
# Train RMSE: 0.2533
# Val RMSE: 0.2522, Val MAE: 0.1091
# Test RMSE: 0.3283, Test MAE: 0.1487
# ---------------------------------
# Model saved at epoch 36 with val RMSE 0.2522
# Patience grace period: 40
# ---------------------------------
# Epoch 37/500
# Train RMSE: 0.2532
# Val RMSE: 0.2521, Val MAE: 0.1085
# Test RMSE: 0.3292, Test MAE: 0.1483
# ---------------------------------
# Model saved at epoch 37 with val RMSE 0.2521
# Patience grace period: 39
# ---------------------------------
# Epoch 38/500
# Train RMSE: 0.2531
# Val RMSE: 0.2520, Val MAE: 0.1085
# Test RMSE: 0.3290, Test MAE: 0.1484
# ---------------------------------
# Model saved at epoch 38 with val RMSE 0.2520
# Patience grace period: 40
# ---------------------------------
# Epoch 39/500
# Train RMSE: 0.2530
# Val RMSE: 0.2519, Val MAE: 0.1086
# Test RMSE: 0.3288, Test MAE: 0.1485
# ---------------------------------
# Model saved at epoch 39 with val RMSE 0.2519
# Patience grace period: 39
# ---------------------------------
# Epoch 40/500
# Train RMSE: 0.2528
# Val RMSE: 0.2520, Val MAE: 0.1090
# Test RMSE: 0.3280, Test MAE: 0.1487
# ---------------------------------
# Patience grace period: 37
# ---------------------------------
# Epoch 41/500
# Train RMSE: 0.2527
# Val RMSE: 0.2521, Val MAE: 0.1093
# Test RMSE: 0.3276, Test MAE: 0.1489
# ---------------------------------
# Patience grace period: 35
# ---------------------------------
# Epoch 42/500
# Train RMSE: 0.2526
# Val RMSE: 0.2517, Val MAE: 0.1084
# Test RMSE: 0.3284, Test MAE: 0.1486
# ---------------------------------
# Model saved at epoch 42 with val RMSE 0.2517
# Patience grace period: 40
# ---------------------------------
# Epoch 43/500
# Train RMSE: 0.2526
# Val RMSE: 0.2518, Val MAE: 0.1086
# Test RMSE: 0.3279, Test MAE: 0.1486
# ---------------------------------
# Patience grace period: 38
# ---------------------------------
# Epoch 44/500
# Train RMSE: 0.2524
# Val RMSE: 0.2517, Val MAE: 0.1087
# Test RMSE: 0.3274, Test MAE: 0.1488
# ---------------------------------
# Model saved at epoch 44 with val RMSE 0.2517
# Patience grace period: 37
# ---------------------------------
# Epoch 45/500
# Train RMSE: 0.2524
# Val RMSE: 0.2516, Val MAE: 0.1081
# Test RMSE: 0.3285, Test MAE: 0.1484
# ---------------------------------
# Model saved at epoch 45 with val RMSE 0.2516
# Patience grace period: 36
# ---------------------------------
# Epoch 46/500
# Train RMSE: 0.2522
# Val RMSE: 0.2517, Val MAE: 0.1086
# Test RMSE: 0.3276, Test MAE: 0.1489
# ---------------------------------
# Patience grace period: 34
# ---------------------------------
# Epoch 47/500
# Train RMSE: 0.2522
# Val RMSE: 0.2516, Val MAE: 0.1085
# Test RMSE: 0.3276, Test MAE: 0.1487
# ---------------------------------
# Patience grace period: 33
# ---------------------------------
# Epoch 48/500
# Train RMSE: 0.2521
# Val RMSE: 0.2517, Val MAE: 0.1085
# Test RMSE: 0.3277, Test MAE: 0.1487
# ---------------------------------
# Patience grace period: 31
# ---------------------------------
# Epoch 49/500
# Train RMSE: 0.2520
# Val RMSE: 0.2517, Val MAE: 0.1087
# Test RMSE: 0.3274, Test MAE: 0.1487
# ---------------------------------
# Patience grace period: 29
# ---------------------------------
# Epoch 50/500
# Train RMSE: 0.2519
# Val RMSE: 0.2516, Val MAE: 0.1083
# Test RMSE: 0.3277, Test MAE: 0.1485
# ---------------------------------
# Model saved at epoch 50 with val RMSE 0.2516
# Patience grace period: 40
# ---------------------------------
# Epoch 51/500
# Train RMSE: 0.2518
# Val RMSE: 0.2516, Val MAE: 0.1079
# Test RMSE: 0.3284, Test MAE: 0.1483
# ---------------------------------
# Model saved at epoch 51 with val RMSE 0.2516
# Patience grace period: 38
# ---------------------------------
# Epoch 52/500
# Train RMSE: 0.2518
# Val RMSE: 0.2515, Val MAE: 0.1080
# Test RMSE: 0.3278, Test MAE: 0.1485
# ---------------------------------
# Model saved at epoch 52 with val RMSE 0.2515
# Patience grace period: 37
# ---------------------------------
# Epoch 53/500
# Train RMSE: 0.2517
# Val RMSE: 0.2516, Val MAE: 0.1084
# Test RMSE: 0.3270, Test MAE: 0.1489
# ---------------------------------
# Patience grace period: 35
# ---------------------------------
# Epoch 54/500
# Train RMSE: 0.2516
# Val RMSE: 0.2515, Val MAE: 0.1085
# Test RMSE: 0.3269, Test MAE: 0.1490
# ---------------------------------
# Patience grace period: 34
# ---------------------------------
# Epoch 55/500
# Train RMSE: 0.2516
# Val RMSE: 0.2517, Val MAE: 0.1088
# Test RMSE: 0.3266, Test MAE: 0.1491
# ---------------------------------
# Patience grace period: 32
# ---------------------------------
# Epoch 56/500
# Train RMSE: 0.2515
# Val RMSE: 0.2516, Val MAE: 0.1085
# Test RMSE: 0.3267, Test MAE: 0.1490
# ---------------------------------
# Patience grace period: 31
# ---------------------------------
# Epoch 57/500
# Train RMSE: 0.2515
# Val RMSE: 0.2515, Val MAE: 0.1076
# Test RMSE: 0.3282, Test MAE: 0.1483
# ---------------------------------
# Patience grace period: 30
# ---------------------------------
# Epoch 58/500
# Train RMSE: 0.2514
# Val RMSE: 0.2517, Val MAE: 0.1085
# Test RMSE: 0.3268, Test MAE: 0.1489
# ---------------------------------
# Patience grace period: 28
# ---------------------------------
# Epoch 59/500
# Train RMSE: 0.2513
# Val RMSE: 0.2516, Val MAE: 0.1082
# Test RMSE: 0.3273, Test MAE: 0.1486
# ---------------------------------
# Patience grace period: 27
# ---------------------------------
# Epoch 60/500
# Train RMSE: 0.2513
# Val RMSE: 0.2517, Val MAE: 0.1088
# Test RMSE: 0.3265, Test MAE: 0.1491
# ---------------------------------
# Patience grace period: 25
# ---------------------------------
# Epoch 61/500
# Train RMSE: 0.2512
# Val RMSE: 0.2517, Val MAE: 0.1081
# Test RMSE: 0.3274, Test MAE: 0.1486
# ---------------------------------
# Patience grace period: 23
# ---------------------------------
# Epoch 62/500
# Train RMSE: 0.2512
# Val RMSE: 0.2517, Val MAE: 0.1084
# Test RMSE: 0.3268, Test MAE: 0.1489
# ---------------------------------
# Patience grace period: 21
# ---------------------------------
# Epoch 63/500
# Train RMSE: 0.2511
# Val RMSE: 0.2517, Val MAE: 0.1082
# Test RMSE: 0.3275, Test MAE: 0.1486
# ---------------------------------
# Patience grace period: 20
# ---------------------------------
# Epoch 64/500
# Train RMSE: 0.2510
# Val RMSE: 0.2517, Val MAE: 0.1082
# Test RMSE: 0.3273, Test MAE: 0.1487
# ---------------------------------
# Patience grace period: 19
# ---------------------------------
# Epoch 65/500
# Train RMSE: 0.2510
# Val RMSE: 0.2517, Val MAE: 0.1082
# Test RMSE: 0.3271, Test MAE: 0.1489
# ---------------------------------
# Patience grace period: 17
# ---------------------------------
# Epoch 66/500
# Train RMSE: 0.2510
# Val RMSE: 0.2518, Val MAE: 0.1088
# Test RMSE: 0.3261, Test MAE: 0.1492
# ---------------------------------
# Patience grace period: 15
# ---------------------------------
# Epoch 67/500
# Train RMSE: 0.2509
# Val RMSE: 0.2519, Val MAE: 0.1087
# Test RMSE: 0.3263, Test MAE: 0.1491
# ---------------------------------
# Patience grace period: 13
# ---------------------------------
# Epoch 68/500
# Train RMSE: 0.2509
# Val RMSE: 0.2518, Val MAE: 0.1081
# Test RMSE: 0.3275, Test MAE: 0.1487
# ---------------------------------
# Patience grace period: 12
# ---------------------------------
# Epoch 69/500
# Train RMSE: 0.2508
# Val RMSE: 0.2517, Val MAE: 0.1081
# Test RMSE: 0.3272, Test MAE: 0.1488
# ---------------------------------
# Patience grace period: 11
# ---------------------------------
# Epoch 70/500
# Train RMSE: 0.2508
# Val RMSE: 0.2518, Val MAE: 0.1081
# Test RMSE: 0.3273, Test MAE: 0.1488
# ---------------------------------
# Patience grace period: 9
# ---------------------------------
# Epoch 71/500
# Train RMSE: 0.2508
# Val RMSE: 0.2519, Val MAE: 0.1084
# Test RMSE: 0.3268, Test MAE: 0.1491
# ---------------------------------
# Patience grace period: 7
# ---------------------------------
# Epoch 72/500
# Train RMSE: 0.2507
# Val RMSE: 0.2517, Val MAE: 0.1081
# Test RMSE: 0.3271, Test MAE: 0.1489
# ---------------------------------
# Patience grace period: 6
# ---------------------------------
# Epoch 73/500
# Train RMSE: 0.2506
# Val RMSE: 0.2517, Val MAE: 0.1081
# Test RMSE: 0.3268, Test MAE: 0.1490
# ---------------------------------
# Patience grace period: 4
# ---------------------------------
# Epoch 74/500
# Train RMSE: 0.2506
# Val RMSE: 0.2519, Val MAE: 0.1084
# Test RMSE: 0.3266, Test MAE: 0.1492
# ---------------------------------
# Patience grace period: 2
# ---------------------------------
# Epoch 75/500
# Train RMSE: 0.2506
# Val RMSE: 0.2518, Val MAE: 0.1081
# Test RMSE: 0.3268, Test MAE: 0.1491
# ---------------------------------
# Patience grace period: 1
# ---------------------------------
# Epoch 76/500
# Train RMSE: 0.2506
# Val RMSE: 0.2517, Val MAE: 0.1076
# Test RMSE: 0.3278, Test MAE: 0.1487
# ---------------------------------
# Patience grace period: 0
# Early stopping triggered at epoch 76
# Final Test RMSE: 0.3278, Final Test MAE: 0.1485
# <ipython-input-3-2a228d64b832>:126: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   self.model.load_state_dict(torch.load(os.path.join(save_dir, 'best_model.pth')))
# Pearson Corr: 0.7444499037603849
# Spearman Corr: 0.4262422558528901
# p-rmse: 0.3277958513328729
#        rmse       mae  seed                             subtask    method  \
# 0  0.327796  0.148474     1  openproblems_bmmc_cite_phase2_mod2  original
#
#    pearson p_value_pearson  spearman p_value_spearman
# 0  0.74445          0.0000  0.426242           0.0000
# ---------------------------------
# Epoch 1/500
# Train RMSE: 0.3784
# Val RMSE: 0.3213, Val MAE: 0.1398
# Test RMSE: 0.3952, Test MAE: 0.1839
# ---------------------------------
# Model saved at epoch 1 with val RMSE 0.3213
# Patience grace period: 40
# ---------------------------------
# Epoch 2/500
# Train RMSE: 0.3238
# Val RMSE: 0.2912, Val MAE: 0.1301
# Test RMSE: 0.3605, Test MAE: 0.1717
# ---------------------------------
# Model saved at epoch 2 with val RMSE 0.2912
# Patience grace period: 40
# ---------------------------------
# Epoch 3/500
# Train RMSE: 0.3019
# Val RMSE: 0.2780, Val MAE: 0.1230
# Test RMSE: 0.3511, Test MAE: 0.1633
# ---------------------------------
# Model saved at epoch 3 with val RMSE 0.2780
# Patience grace period: 40
# ---------------------------------
# Epoch 4/500
# Train RMSE: 0.2895
# Val RMSE: 0.2722, Val MAE: 0.1195
# Test RMSE: 0.3498, Test MAE: 0.1592
# ---------------------------------
# Model saved at epoch 4 with val RMSE 0.2722
# Patience grace period: 40
# ---------------------------------
# Epoch 5/500
# Train RMSE: 0.2823
# Val RMSE: 0.2684, Val MAE: 0.1179
# Test RMSE: 0.3480, Test MAE: 0.1569
# ---------------------------------
# Model saved at epoch 5 with val RMSE 0.2684
# Patience grace period: 40
# ---------------------------------
# Epoch 6/500
# Train RMSE: 0.2772
# Val RMSE: 0.2656, Val MAE: 0.1169
# Test RMSE: 0.3461, Test MAE: 0.1552
# ---------------------------------
# Model saved at epoch 6 with val RMSE 0.2656
# Patience grace period: 40
# ---------------------------------
# Epoch 7/500
# Train RMSE: 0.2734
# Val RMSE: 0.2637, Val MAE: 0.1157
# Test RMSE: 0.3450, Test MAE: 0.1538
# ---------------------------------
# Model saved at epoch 7 with val RMSE 0.2637
# Patience grace period: 40
# ---------------------------------
# Epoch 8/500
# Train RMSE: 0.2703
# Val RMSE: 0.2620, Val MAE: 0.1150
# Test RMSE: 0.3433, Test MAE: 0.1527
# ---------------------------------
# Model saved at epoch 8 with val RMSE 0.2620
# Patience grace period: 40
# ---------------------------------
# Epoch 9/500
# Train RMSE: 0.2677
# Val RMSE: 0.2606, Val MAE: 0.1141
# Test RMSE: 0.3417, Test MAE: 0.1520
# ---------------------------------
# Model saved at epoch 9 with val RMSE 0.2606
# Patience grace period: 40
# ---------------------------------
# Epoch 10/500
# Train RMSE: 0.2656
# Val RMSE: 0.2595, Val MAE: 0.1130
# Test RMSE: 0.3417, Test MAE: 0.1512
# ---------------------------------
# Model saved at epoch 10 with val RMSE 0.2595
# Patience grace period: 40
# ---------------------------------
# Epoch 11/500
# Train RMSE: 0.2638
# Val RMSE: 0.2584, Val MAE: 0.1124
# Test RMSE: 0.3408, Test MAE: 0.1508
# ---------------------------------
# Model saved at epoch 11 with val RMSE 0.2584
# Patience grace period: 40
# ---------------------------------
# Epoch 12/500
# Train RMSE: 0.2624
# Val RMSE: 0.2575, Val MAE: 0.1118
# Test RMSE: 0.3397, Test MAE: 0.1505
# ---------------------------------
# Model saved at epoch 12 with val RMSE 0.2575
# Patience grace period: 40
# ---------------------------------
# Epoch 13/500
# Train RMSE: 0.2613
# Val RMSE: 0.2568, Val MAE: 0.1113
# Test RMSE: 0.3391, Test MAE: 0.1502
# ---------------------------------
# Model saved at epoch 13 with val RMSE 0.2568
# Patience grace period: 40
# ---------------------------------
# Epoch 14/500
# Train RMSE: 0.2602
# Val RMSE: 0.2563, Val MAE: 0.1105
# Test RMSE: 0.3396, Test MAE: 0.1499
# ---------------------------------
# Model saved at epoch 14 with val RMSE 0.2563
# Patience grace period: 40
# ---------------------------------
# Epoch 15/500
# Train RMSE: 0.2594
# Val RMSE: 0.2559, Val MAE: 0.1104
# Test RMSE: 0.3390, Test MAE: 0.1497
# ---------------------------------
# Model saved at epoch 15 with val RMSE 0.2559
# Patience grace period: 40
# ---------------------------------
# Epoch 16/500
# Train RMSE: 0.2588
# Val RMSE: 0.2553, Val MAE: 0.1110
# Test RMSE: 0.3360, Test MAE: 0.1497
# ---------------------------------
# Model saved at epoch 16 with val RMSE 0.2553
# Patience grace period: 40
# ---------------------------------
# Epoch 17/500
# Train RMSE: 0.2581
# Val RMSE: 0.2550, Val MAE: 0.1097
# Test RMSE: 0.3375, Test MAE: 0.1490
# ---------------------------------
# Model saved at epoch 17 with val RMSE 0.2550
# Patience grace period: 40
# ---------------------------------
# Epoch 18/500
# Train RMSE: 0.2576
# Val RMSE: 0.2547, Val MAE: 0.1098
# Test RMSE: 0.3365, Test MAE: 0.1489
# ---------------------------------
# Model saved at epoch 18 with val RMSE 0.2547
# Patience grace period: 40
# ---------------------------------
# Epoch 19/500
# Train RMSE: 0.2572
# Val RMSE: 0.2544, Val MAE: 0.1096
# Test RMSE: 0.3365, Test MAE: 0.1487
# ---------------------------------
# Model saved at epoch 19 with val RMSE 0.2544
# Patience grace period: 40
# ---------------------------------
# Epoch 20/500
# Train RMSE: 0.2568
# Val RMSE: 0.2542, Val MAE: 0.1092
# Test RMSE: 0.3363, Test MAE: 0.1484
# ---------------------------------
# Model saved at epoch 20 with val RMSE 0.2542
# Patience grace period: 40
# ---------------------------------
# Epoch 21/500
# Train RMSE: 0.2564
# Val RMSE: 0.2540, Val MAE: 0.1095
# Test RMSE: 0.3351, Test MAE: 0.1484
# ---------------------------------
# Model saved at epoch 21 with val RMSE 0.2540
# Patience grace period: 40
# ---------------------------------
# Epoch 22/500
# Train RMSE: 0.2560
# Val RMSE: 0.2538, Val MAE: 0.1093
# Test RMSE: 0.3347, Test MAE: 0.1483
# ---------------------------------
# Model saved at epoch 22 with val RMSE 0.2538
# Patience grace period: 40
# ---------------------------------
# Epoch 23/500
# Train RMSE: 0.2557
# Val RMSE: 0.2537, Val MAE: 0.1088
# Test RMSE: 0.3354, Test MAE: 0.1479
# ---------------------------------
# Model saved at epoch 23 with val RMSE 0.2537
# Patience grace period: 39
# ---------------------------------
# Epoch 24/500
# Train RMSE: 0.2555
# Val RMSE: 0.2535, Val MAE: 0.1085
# Test RMSE: 0.3353, Test MAE: 0.1478
# ---------------------------------
# Model saved at epoch 24 with val RMSE 0.2535
# Patience grace period: 40
# ---------------------------------
# Epoch 25/500
# Train RMSE: 0.2552
# Val RMSE: 0.2533, Val MAE: 0.1087
# Test RMSE: 0.3344, Test MAE: 0.1477
# ---------------------------------
# Model saved at epoch 25 with val RMSE 0.2533
# Patience grace period: 40
# ---------------------------------
# Epoch 26/500
# Train RMSE: 0.2550
# Val RMSE: 0.2532, Val MAE: 0.1089
# Test RMSE: 0.3337, Test MAE: 0.1480
# ---------------------------------
# Model saved at epoch 26 with val RMSE 0.2532
# Patience grace period: 40
# ---------------------------------
# Epoch 27/500
# Train RMSE: 0.2548
# Val RMSE: 0.2530, Val MAE: 0.1086
# Test RMSE: 0.3335, Test MAE: 0.1477
# ---------------------------------
# Model saved at epoch 27 with val RMSE 0.2530
# Patience grace period: 40
# ---------------------------------
# Epoch 28/500
# Train RMSE: 0.2546
# Val RMSE: 0.2528, Val MAE: 0.1088
# Test RMSE: 0.3334, Test MAE: 0.1476
# ---------------------------------
# Model saved at epoch 28 with val RMSE 0.2528
# Patience grace period: 40
# ---------------------------------
# Epoch 29/500
# Train RMSE: 0.2544
# Val RMSE: 0.2528, Val MAE: 0.1089
# Test RMSE: 0.3329, Test MAE: 0.1477
# ---------------------------------
# Model saved at epoch 29 with val RMSE 0.2528
# Patience grace period: 39
# ---------------------------------
# Epoch 30/500
# Train RMSE: 0.2542
# Val RMSE: 0.2527, Val MAE: 0.1084
# Test RMSE: 0.3336, Test MAE: 0.1474
# ---------------------------------
# Model saved at epoch 30 with val RMSE 0.2527
# Patience grace period: 40
# ---------------------------------
# Epoch 31/500
# Train RMSE: 0.2540
# Val RMSE: 0.2527, Val MAE: 0.1084
# Test RMSE: 0.3332, Test MAE: 0.1474
# ---------------------------------
# Model saved at epoch 31 with val RMSE 0.2527
# Patience grace period: 39
# ---------------------------------
# Epoch 32/500
# Train RMSE: 0.2539
# Val RMSE: 0.2527, Val MAE: 0.1080
# Test RMSE: 0.3338, Test MAE: 0.1474
# ---------------------------------
# Model saved at epoch 32 with val RMSE 0.2527
# Patience grace period: 37
# ---------------------------------
# Epoch 33/500
# Train RMSE: 0.2537
# Val RMSE: 0.2526, Val MAE: 0.1088
# Test RMSE: 0.3322, Test MAE: 0.1478
# ---------------------------------
# Model saved at epoch 33 with val RMSE 0.2526
# Patience grace period: 36
# ---------------------------------
# Epoch 34/500
# Train RMSE: 0.2536
# Val RMSE: 0.2525, Val MAE: 0.1085
# Test RMSE: 0.3321, Test MAE: 0.1476
# ---------------------------------
# Model saved at epoch 34 with val RMSE 0.2525
# Patience grace period: 40
# ---------------------------------
# Epoch 35/500
# Train RMSE: 0.2535
# Val RMSE: 0.2524, Val MAE: 0.1085
# Test RMSE: 0.3317, Test MAE: 0.1477
# ---------------------------------
# Model saved at epoch 35 with val RMSE 0.2524
# Patience grace period: 40
# ---------------------------------
# Epoch 36/500
# Train RMSE: 0.2533
# Val RMSE: 0.2524, Val MAE: 0.1083
# Test RMSE: 0.3317, Test MAE: 0.1476
# ---------------------------------
# Model saved at epoch 36 with val RMSE 0.2524
# Patience grace period: 39
# ---------------------------------
# Epoch 37/500
# Train RMSE: 0.2532
# Val RMSE: 0.2522, Val MAE: 0.1080
# Test RMSE: 0.3321, Test MAE: 0.1475
# ---------------------------------
# Model saved at epoch 37 with val RMSE 0.2522
# Patience grace period: 40
# ---------------------------------
# Epoch 38/500
# Train RMSE: 0.2531
# Val RMSE: 0.2523, Val MAE: 0.1085
# Test RMSE: 0.3313, Test MAE: 0.1480
# ---------------------------------
# Patience grace period: 38
# ---------------------------------
# Epoch 39/500
# Train RMSE: 0.2529
# Val RMSE: 0.2522, Val MAE: 0.1076
# Test RMSE: 0.3328, Test MAE: 0.1475
# ---------------------------------
# Model saved at epoch 39 with val RMSE 0.2522
# Patience grace period: 37
# ---------------------------------
# Epoch 40/500
# Train RMSE: 0.2528
# Val RMSE: 0.2522, Val MAE: 0.1074
# Test RMSE: 0.3329, Test MAE: 0.1475
# ---------------------------------
# Patience grace period: 35
# ---------------------------------
# Epoch 41/500
# Train RMSE: 0.2527
# Val RMSE: 0.2521, Val MAE: 0.1082
# Test RMSE: 0.3315, Test MAE: 0.1479
# ---------------------------------
# Model saved at epoch 41 with val RMSE 0.2521
# Patience grace period: 40
# ---------------------------------
# Epoch 42/500
# Train RMSE: 0.2526
# Val RMSE: 0.2521, Val MAE: 0.1077
# Test RMSE: 0.3319, Test MAE: 0.1477
# ---------------------------------
# Model saved at epoch 42 with val RMSE 0.2521
# Patience grace period: 39
# ---------------------------------
# Epoch 43/500
# Train RMSE: 0.2525
# Val RMSE: 0.2520, Val MAE: 0.1074
# Test RMSE: 0.3324, Test MAE: 0.1477
# ---------------------------------
# Model saved at epoch 43 with val RMSE 0.2520
# Patience grace period: 40
# ---------------------------------
# Epoch 44/500
# Train RMSE: 0.2524
# Val RMSE: 0.2519, Val MAE: 0.1076
# Test RMSE: 0.3314, Test MAE: 0.1478
# ---------------------------------
# Model saved at epoch 44 with val RMSE 0.2519
# Patience grace period: 39
# ---------------------------------
# Epoch 45/500
# Train RMSE: 0.2523
# Val RMSE: 0.2518, Val MAE: 0.1079
# Test RMSE: 0.3307, Test MAE: 0.1479
# ---------------------------------
# Model saved at epoch 45 with val RMSE 0.2518
# Patience grace period: 40
# ---------------------------------
# Epoch 46/500
# Train RMSE: 0.2523
# Val RMSE: 0.2518, Val MAE: 0.1079
# Test RMSE: 0.3309, Test MAE: 0.1480
# ---------------------------------
# Patience grace period: 38
# ---------------------------------
# Epoch 47/500
# Train RMSE: 0.2522
# Val RMSE: 0.2518, Val MAE: 0.1078
# Test RMSE: 0.3308, Test MAE: 0.1482
# ---------------------------------
# Patience grace period: 36
# ---------------------------------
# Epoch 48/500
# Train RMSE: 0.2521
# Val RMSE: 0.2519, Val MAE: 0.1072
# Test RMSE: 0.3316, Test MAE: 0.1478
# ---------------------------------
# Patience grace period: 34
# ---------------------------------
# Epoch 49/500
# Train RMSE: 0.2520
# Val RMSE: 0.2518, Val MAE: 0.1075
# Test RMSE: 0.3313, Test MAE: 0.1483
# ---------------------------------
# Patience grace period: 33
# ---------------------------------
# Epoch 50/500
# Train RMSE: 0.2519
# Val RMSE: 0.2518, Val MAE: 0.1073
# Test RMSE: 0.3318, Test MAE: 0.1480
# ---------------------------------
# Patience grace period: 31
# ---------------------------------
# Epoch 51/500
# Train RMSE: 0.2519
# Val RMSE: 0.2517, Val MAE: 0.1076
# Test RMSE: 0.3309, Test MAE: 0.1482
# ---------------------------------
# Model saved at epoch 51 with val RMSE 0.2517
# Patience grace period: 40
# ---------------------------------
# Epoch 52/500
# Train RMSE: 0.2518
# Val RMSE: 0.2516, Val MAE: 0.1080
# Test RMSE: 0.3296, Test MAE: 0.1487
# ---------------------------------
# Model saved at epoch 52 with val RMSE 0.2516
# Patience grace period: 39
# ---------------------------------
# Epoch 53/500
# Train RMSE: 0.2517
# Val RMSE: 0.2517, Val MAE: 0.1074
# Test RMSE: 0.3305, Test MAE: 0.1484
# ---------------------------------
# Patience grace period: 37
# ---------------------------------
# Epoch 54/500
# Train RMSE: 0.2517
# Val RMSE: 0.2516, Val MAE: 0.1074
# Test RMSE: 0.3303, Test MAE: 0.1485
# ---------------------------------
# Model saved at epoch 54 with val RMSE 0.2516
# Patience grace period: 40
# ---------------------------------
# Epoch 55/500
# Train RMSE: 0.2516
# Val RMSE: 0.2516, Val MAE: 0.1079
# Test RMSE: 0.3293, Test MAE: 0.1488
# ---------------------------------
# Model saved at epoch 55 with val RMSE 0.2516
# Patience grace period: 39
# ---------------------------------
# Epoch 56/500
# Train RMSE: 0.2515
# Val RMSE: 0.2515, Val MAE: 0.1078
# Test RMSE: 0.3293, Test MAE: 0.1488
# ---------------------------------
# Model saved at epoch 56 with val RMSE 0.2515
# Patience grace period: 38
# ---------------------------------
# Epoch 57/500
# Train RMSE: 0.2514
# Val RMSE: 0.2516, Val MAE: 0.1074
# Test RMSE: 0.3305, Test MAE: 0.1486
# ---------------------------------
# Patience grace period: 36
# ---------------------------------
# Epoch 58/500
# Train RMSE: 0.2514
# Val RMSE: 0.2516, Val MAE: 0.1073
# Test RMSE: 0.3300, Test MAE: 0.1486
# ---------------------------------
# Patience grace period: 35
# ---------------------------------
# Epoch 59/500
# Train RMSE: 0.2513
# Val RMSE: 0.2516, Val MAE: 0.1067
# Test RMSE: 0.3313, Test MAE: 0.1484
# ---------------------------------
# Patience grace period: 33
# ---------------------------------
# Epoch 60/500
# Train RMSE: 0.2513
# Val RMSE: 0.2516, Val MAE: 0.1069
# Test RMSE: 0.3309, Test MAE: 0.1486
# ---------------------------------
# Patience grace period: 32
# ---------------------------------
# Epoch 61/500
# Train RMSE: 0.2512
# Val RMSE: 0.2515, Val MAE: 0.1071
# Test RMSE: 0.3302, Test MAE: 0.1487
# ---------------------------------
# Patience grace period: 31
# ---------------------------------
# Epoch 62/500
# Train RMSE: 0.2511
# Val RMSE: 0.2516, Val MAE: 0.1071
# Test RMSE: 0.3304, Test MAE: 0.1486
# ---------------------------------
# Patience grace period: 29
# ---------------------------------
# Epoch 63/500
# Train RMSE: 0.2511
# Val RMSE: 0.2515, Val MAE: 0.1068
# Test RMSE: 0.3307, Test MAE: 0.1486
# ---------------------------------
# Model saved at epoch 63 with val RMSE 0.2515
# Patience grace period: 40
# ---------------------------------
# Epoch 64/500
# Train RMSE: 0.2510
# Val RMSE: 0.2514, Val MAE: 0.1071
# Test RMSE: 0.3298, Test MAE: 0.1489
# ---------------------------------
# Model saved at epoch 64 with val RMSE 0.2514
# Patience grace period: 39
# ---------------------------------
# Epoch 65/500
# Train RMSE: 0.2510
# Val RMSE: 0.2514, Val MAE: 0.1065
# Test RMSE: 0.3309, Test MAE: 0.1486
# ---------------------------------
# Model saved at epoch 65 with val RMSE 0.2514
# Patience grace period: 38
# ---------------------------------
# Epoch 66/500
# Train RMSE: 0.2510
# Val RMSE: 0.2514, Val MAE: 0.1073
# Test RMSE: 0.3294, Test MAE: 0.1492
# ---------------------------------
# Model saved at epoch 66 with val RMSE 0.2514
# Patience grace period: 37
# ---------------------------------
# Epoch 67/500
# Train RMSE: 0.2509
# Val RMSE: 0.2514, Val MAE: 0.1067
# Test RMSE: 0.3305, Test MAE: 0.1487
# ---------------------------------
# Patience grace period: 35
# ---------------------------------
# Epoch 68/500
# Train RMSE: 0.2509
# Val RMSE: 0.2514, Val MAE: 0.1078
# Test RMSE: 0.3287, Test MAE: 0.1495
# ---------------------------------
# Patience grace period: 33
# ---------------------------------
# Epoch 69/500
# Train RMSE: 0.2508
# Val RMSE: 0.2514, Val MAE: 0.1070
# Test RMSE: 0.3295, Test MAE: 0.1491
# ---------------------------------
# Model saved at epoch 69 with val RMSE 0.2514
# Patience grace period: 40
# ---------------------------------
# Epoch 70/500
# Train RMSE: 0.2508
# Val RMSE: 0.2515, Val MAE: 0.1071
# Test RMSE: 0.3293, Test MAE: 0.1492
# ---------------------------------
# Patience grace period: 38
# ---------------------------------
# Epoch 71/500
# Train RMSE: 0.2507
# Val RMSE: 0.2514, Val MAE: 0.1074
# Test RMSE: 0.3289, Test MAE: 0.1493
# ---------------------------------
# Patience grace period: 37
# ---------------------------------
# Epoch 72/500
# Train RMSE: 0.2507
# Val RMSE: 0.2513, Val MAE: 0.1072
# Test RMSE: 0.3295, Test MAE: 0.1493
# ---------------------------------
# Model saved at epoch 72 with val RMSE 0.2513
# Patience grace period: 36
# ---------------------------------
# Epoch 73/500
# Train RMSE: 0.2506
# Val RMSE: 0.2514, Val MAE: 0.1077
# Test RMSE: 0.3285, Test MAE: 0.1496
# ---------------------------------
# Patience grace period: 34
# ---------------------------------
# Epoch 74/500
# Train RMSE: 0.2506
# Val RMSE: 0.2514, Val MAE: 0.1069
# Test RMSE: 0.3294, Test MAE: 0.1493
# ---------------------------------
# Patience grace period: 33
# ---------------------------------
# Epoch 75/500
# Train RMSE: 0.2506
# Val RMSE: 0.2513, Val MAE: 0.1073
# Test RMSE: 0.3288, Test MAE: 0.1496
# ---------------------------------
# Patience grace period: 32
# ---------------------------------
# Epoch 76/500
# Train RMSE: 0.2505
# Val RMSE: 0.2514, Val MAE: 0.1077
# Test RMSE: 0.3282, Test MAE: 0.1497
# ---------------------------------
# Patience grace period: 30
# ---------------------------------
# Epoch 77/500
# Train RMSE: 0.2505
# Val RMSE: 0.2514, Val MAE: 0.1072
# Test RMSE: 0.3288, Test MAE: 0.1497
# ---------------------------------
# Patience grace period: 28
# ---------------------------------
# Epoch 78/500
# Train RMSE: 0.2505
# Val RMSE: 0.2513, Val MAE: 0.1072
# Test RMSE: 0.3289, Test MAE: 0.1496
# ---------------------------------
# Model saved at epoch 78 with val RMSE 0.2513
# Patience grace period: 27
# ---------------------------------
# Epoch 79/500
# Train RMSE: 0.2504
# Val RMSE: 0.2514, Val MAE: 0.1066
# Test RMSE: 0.3299, Test MAE: 0.1493
# ---------------------------------
# Patience grace period: 25
# ---------------------------------
# Epoch 80/500
# Train RMSE: 0.2504
# Val RMSE: 0.2515, Val MAE: 0.1064
# Test RMSE: 0.3299, Test MAE: 0.1494
# ---------------------------------
# Patience grace period: 23
# ---------------------------------
# Epoch 81/500
# Train RMSE: 0.2504
# Val RMSE: 0.2514, Val MAE: 0.1069
# Test RMSE: 0.3291, Test MAE: 0.1496
# ---------------------------------
# Patience grace period: 22
# ---------------------------------
# Epoch 82/500
# Train RMSE: 0.2503
# Val RMSE: 0.2515, Val MAE: 0.1067
# Test RMSE: 0.3299, Test MAE: 0.1494
# ---------------------------------
# Patience grace period: 20
# ---------------------------------
# Epoch 83/500
# Train RMSE: 0.2503
# Val RMSE: 0.2514, Val MAE: 0.1068
# Test RMSE: 0.3294, Test MAE: 0.1495
# ---------------------------------
# Patience grace period: 19
# ---------------------------------
# Epoch 84/500
# Train RMSE: 0.2503
# Val RMSE: 0.2514, Val MAE: 0.1069
# Test RMSE: 0.3292, Test MAE: 0.1497
# ---------------------------------
# Patience grace period: 18
# ---------------------------------
# Epoch 85/500
# Train RMSE: 0.2503
# Val RMSE: 0.2513, Val MAE: 0.1069
# Test RMSE: 0.3290, Test MAE: 0.1497
# ---------------------------------
# Model saved at epoch 85 with val RMSE 0.2513
# Patience grace period: 17
# ---------------------------------
# Epoch 86/500
# Train RMSE: 0.2502
# ...
# Model saved at epoch 25 with val RMSE 0.2531
# Patience grace period: 39
# ---------------------------------
# Epoch 26/500
# Train RMSE: 0.2551
# Val RMSE: 0.2530, Val MAE: 0.1090
# Test RMSE: 0.3324, Test MAE: 0.1487
# ---------------------------------
# Model saved at epoch 26 with val RMSE 0.2530
# Patience grace period: 40
# ---------------------------------
# Epoch 27/500
# Train RMSE: 0.2548
# Val RMSE: 0.2529, Val MAE: 0.1087
# Test RMSE: 0.3327, Test MAE: 0.1486
# ---------------------------------
# Model saved at epoch 27 with val RMSE 0.2529
# Patience grace period: 40
# ---------------------------------
# Epoch 28/500
# Train RMSE: 0.2546
# Val RMSE: 0.2528, Val MAE: 0.1083
# Test RMSE: 0.3337, Test MAE: 0.1485
# ---------------------------------
# Model saved at epoch 28 with val RMSE 0.2528
# Patience grace period: 40
# ---------------------------------
# Epoch 29/500
# Train RMSE: 0.2545
# Val RMSE: 0.2527, Val MAE: 0.1090
# Test RMSE: 0.3317, Test MAE: 0.1490
# ---------------------------------
# Model saved at epoch 29 with val RMSE 0.2527
# Patience grace period: 40
# ---------------------------------
# Epoch 30/500
# Train RMSE: 0.2543
# Val RMSE: 0.2526, Val MAE: 0.1088
# Test RMSE: 0.3317, Test MAE: 0.1488
# ---------------------------------
# Model saved at epoch 30 with val RMSE 0.2526
# Patience grace period: 39
# ---------------------------------
# Epoch 31/500
# Train RMSE: 0.2541
# Val RMSE: 0.2525, Val MAE: 0.1082
# Test RMSE: 0.3328, Test MAE: 0.1485
# ---------------------------------
# Model saved at epoch 31 with val RMSE 0.2525
# Patience grace period: 40
# ---------------------------------
# Epoch 32/500
# Train RMSE: 0.2539
# Val RMSE: 0.2524, Val MAE: 0.1087
# Test RMSE: 0.3314, Test MAE: 0.1489
# ---------------------------------
# Model saved at epoch 32 with val RMSE 0.2524
# Patience grace period: 39
# ---------------------------------
# Epoch 33/500
# Train RMSE: 0.2538
# Val RMSE: 0.2523, Val MAE: 0.1088
# Test RMSE: 0.3311, Test MAE: 0.1489
# ---------------------------------
# Model saved at epoch 33 with val RMSE 0.2523
# Patience grace period: 40
# ---------------------------------
# Epoch 34/500
# Train RMSE: 0.2536
# Val RMSE: 0.2522, Val MAE: 0.1079
# Test RMSE: 0.3320, Test MAE: 0.1485
# ---------------------------------
# Model saved at epoch 34 with val RMSE 0.2522
# Patience grace period: 39
# ---------------------------------
# Epoch 35/500
# Train RMSE: 0.2535
# Val RMSE: 0.2522, Val MAE: 0.1081
# Test RMSE: 0.3315, Test MAE: 0.1487
# ---------------------------------
# Model saved at epoch 35 with val RMSE 0.2522
# Patience grace period: 40
# ---------------------------------
# Epoch 36/500
# Train RMSE: 0.2533
# Val RMSE: 0.2522, Val MAE: 0.1083
# Test RMSE: 0.3309, Test MAE: 0.1488
# ---------------------------------
# Model saved at epoch 36 with val RMSE 0.2522
# Patience grace period: 39
# ---------------------------------
# Epoch 37/500
# Train RMSE: 0.2532
# Val RMSE: 0.2522, Val MAE: 0.1091
# Test RMSE: 0.3296, Test MAE: 0.1494
# ---------------------------------
# Model saved at epoch 37 with val RMSE 0.2522
# Patience grace period: 37
# ---------------------------------
# Epoch 38/500
# Train RMSE: 0.2531
# Val RMSE: 0.2521, Val MAE: 0.1084
# Test RMSE: 0.3305, Test MAE: 0.1491
# ---------------------------------
# Model saved at epoch 38 with val RMSE 0.2521
# Patience grace period: 40
# ---------------------------------
# Epoch 39/500
# Train RMSE: 0.2530
# Val RMSE: 0.2520, Val MAE: 0.1084
# Test RMSE: 0.3303, Test MAE: 0.1491
# ---------------------------------
# Model saved at epoch 39 with val RMSE 0.2520
# Patience grace period: 39
# ---------------------------------
# Epoch 40/500
# Train RMSE: 0.2529
# Val RMSE: 0.2519, Val MAE: 0.1081
# Test RMSE: 0.3307, Test MAE: 0.1489
# ---------------------------------
# Model saved at epoch 40 with val RMSE 0.2519
# Patience grace period: 40
# ---------------------------------
# Epoch 41/500
# Train RMSE: 0.2527
# Val RMSE: 0.2519, Val MAE: 0.1082
# Test RMSE: 0.3304, Test MAE: 0.1489
# ---------------------------------
# Model saved at epoch 41 with val RMSE 0.2519
# Patience grace period: 39
# ---------------------------------
# Epoch 42/500
# Train RMSE: 0.2527
# Val RMSE: 0.2518, Val MAE: 0.1080
# Test RMSE: 0.3308, Test MAE: 0.1490
# ---------------------------------
# Model saved at epoch 42 with val RMSE 0.2518
# Patience grace period: 40
# ---------------------------------
# Epoch 43/500
# Train RMSE: 0.2526
# Val RMSE: 0.2518, Val MAE: 0.1084
# Test RMSE: 0.3298, Test MAE: 0.1493
# ---------------------------------
# Model saved at epoch 43 with val RMSE 0.2518
# Patience grace period: 39
# ---------------------------------
# Epoch 44/500
# Train RMSE: 0.2525
# Val RMSE: 0.2519, Val MAE: 0.1087
# Test RMSE: 0.3291, Test MAE: 0.1494
# ---------------------------------
# Patience grace period: 37
# ---------------------------------
# Epoch 45/500
# Train RMSE: 0.2524
# Val RMSE: 0.2518, Val MAE: 0.1083
# Test RMSE: 0.3298, Test MAE: 0.1492
# ---------------------------------
# Patience grace period: 36
# ---------------------------------
# Epoch 46/500
# Train RMSE: 0.2523
# Val RMSE: 0.2519, Val MAE: 0.1087
# Test RMSE: 0.3289, Test MAE: 0.1495
# ---------------------------------
# Patience grace period: 34
# ---------------------------------
# Epoch 47/500
# Train RMSE: 0.2522
# Val RMSE: 0.2518, Val MAE: 0.1084
# Test RMSE: 0.3292, Test MAE: 0.1495
# ---------------------------------
# Patience grace period: 33
# ---------------------------------
# Epoch 48/500
# Train RMSE: 0.2521
# Val RMSE: 0.2519, Val MAE: 0.1083
# Test RMSE: 0.3292, Test MAE: 0.1496
# ---------------------------------
# Patience grace period: 31
# ---------------------------------
# Epoch 49/500
# Train RMSE: 0.2520
# Val RMSE: 0.2517, Val MAE: 0.1084
# Test RMSE: 0.3291, Test MAE: 0.1497
# ---------------------------------
# Model saved at epoch 49 with val RMSE 0.2517
# Patience grace period: 40
# ---------------------------------
# Epoch 50/500
# Train RMSE: 0.2520
# Val RMSE: 0.2516, Val MAE: 0.1082
# Test RMSE: 0.3290, Test MAE: 0.1496
# ---------------------------------
# Model saved at epoch 50 with val RMSE 0.2516
# Patience grace period: 40
# ---------------------------------
# Epoch 51/500
# Train RMSE: 0.2519
# Val RMSE: 0.2516, Val MAE: 0.1083
# Test RMSE: 0.3287, Test MAE: 0.1498
# ---------------------------------
# Patience grace period: 38
# ---------------------------------
# Epoch 52/500
# Train RMSE: 0.2518
# Val RMSE: 0.2516, Val MAE: 0.1082
# Test RMSE: 0.3293, Test MAE: 0.1496
# ---------------------------------
# Patience grace period: 37
# ---------------------------------
# Epoch 53/500
# Train RMSE: 0.2517
# Val RMSE: 0.2517, Val MAE: 0.1085
# Test RMSE: 0.3287, Test MAE: 0.1498
# ---------------------------------
# Patience grace period: 35
# ---------------------------------
# Epoch 54/500
# Train RMSE: 0.2517
# Val RMSE: 0.2517, Val MAE: 0.1086
# Test RMSE: 0.3282, Test MAE: 0.1500
# ---------------------------------
# Patience grace period: 34
# ---------------------------------
# Epoch 55/500
# Train RMSE: 0.2516
# Val RMSE: 0.2517, Val MAE: 0.1085
# Test RMSE: 0.3280, Test MAE: 0.1500
# ---------------------------------
# Patience grace period: 32
# ---------------------------------
# Epoch 56/500
# Train RMSE: 0.2516
# Val RMSE: 0.2517, Val MAE: 0.1086
# Test RMSE: 0.3281, Test MAE: 0.1501
# ---------------------------------
# Patience grace period: 30
# ---------------------------------
# Epoch 57/500
# Train RMSE: 0.2515
# Val RMSE: 0.2516, Val MAE: 0.1081
# Test RMSE: 0.3287, Test MAE: 0.1497
# ---------------------------------
# Model saved at epoch 57 with val RMSE 0.2516
# Patience grace period: 29
# ---------------------------------
# Epoch 58/500
# Train RMSE: 0.2514
# Val RMSE: 0.2517, Val MAE: 0.1086
# Test RMSE: 0.3277, Test MAE: 0.1503
# ---------------------------------
# Patience grace period: 27
# ---------------------------------
# Epoch 59/500
# Train RMSE: 0.2514
# Val RMSE: 0.2514, Val MAE: 0.1078
# Test RMSE: 0.3290, Test MAE: 0.1497
# ---------------------------------
# Model saved at epoch 59 with val RMSE 0.2514
# Patience grace period: 40
# ---------------------------------
# Epoch 60/500
# Train RMSE: 0.2513
# Val RMSE: 0.2515, Val MAE: 0.1082
# Test RMSE: 0.3283, Test MAE: 0.1499
# ---------------------------------
# Patience grace period: 38
# ---------------------------------
# Epoch 61/500
# Train RMSE: 0.2513
# Val RMSE: 0.2514, Val MAE: 0.1076
# Test RMSE: 0.3294, Test MAE: 0.1494
# ---------------------------------
# Model saved at epoch 61 with val RMSE 0.2514
# Patience grace period: 37
# ---------------------------------
# Epoch 62/500
# Train RMSE: 0.2512
# Val RMSE: 0.2514, Val MAE: 0.1077
# Test RMSE: 0.3292, Test MAE: 0.1496
# ---------------------------------
# Patience grace period: 35
# ---------------------------------
# Epoch 63/500
# Train RMSE: 0.2512
# Val RMSE: 0.2514, Val MAE: 0.1075
# Test RMSE: 0.3291, Test MAE: 0.1498
# ---------------------------------
# Patience grace period: 33
# ---------------------------------
# Epoch 64/500
# Train RMSE: 0.2511
# Val RMSE: 0.2515, Val MAE: 0.1081
# Test RMSE: 0.3280, Test MAE: 0.1499
# ---------------------------------
# Patience grace period: 31
# ---------------------------------
# Epoch 65/500
# Train RMSE: 0.2510
# Val RMSE: 0.2513, Val MAE: 0.1077
# Test RMSE: 0.3284, Test MAE: 0.1500
# ---------------------------------
# Model saved at epoch 65 with val RMSE 0.2513
# Patience grace period: 30
# ---------------------------------
# Epoch 66/500
# Train RMSE: 0.2510
# Val RMSE: 0.2517, Val MAE: 0.1086
# Test RMSE: 0.3276, Test MAE: 0.1502
# ---------------------------------
# Patience grace period: 28
# ---------------------------------
# Epoch 67/500
# Train RMSE: 0.2509
# Val RMSE: 0.2514, Val MAE: 0.1080
# Test RMSE: 0.3280, Test MAE: 0.1501
# ---------------------------------
# Patience grace period: 27
# ---------------------------------
# Epoch 68/500
# Train RMSE: 0.2509
# Val RMSE: 0.2513, Val MAE: 0.1073
# Test RMSE: 0.3298, Test MAE: 0.1495
# ---------------------------------
# Model saved at epoch 68 with val RMSE 0.2513
# Patience grace period: 40
# ---------------------------------
# Epoch 69/500
# Train RMSE: 0.2508
# Val RMSE: 0.2515, Val MAE: 0.1084
# Test RMSE: 0.3278, Test MAE: 0.1502
# ---------------------------------
# Patience grace period: 38
# ---------------------------------
# Epoch 70/500
# Train RMSE: 0.2508
# Val RMSE: 0.2515, Val MAE: 0.1085
# Test RMSE: 0.3284, Test MAE: 0.1501
# ---------------------------------
# Patience grace period: 37
# ---------------------------------
# Epoch 71/500
# Train RMSE: 0.2508
# Val RMSE: 0.2513, Val MAE: 0.1076
# Test RMSE: 0.3288, Test MAE: 0.1499
# ---------------------------------
# Model saved at epoch 71 with val RMSE 0.2513
# Patience grace period: 36
# ---------------------------------
# Epoch 72/500
# Train RMSE: 0.2507
# Val RMSE: 0.2513, Val MAE: 0.1079
# Test RMSE: 0.3285, Test MAE: 0.1499
# ---------------------------------
# Patience grace period: 34
# ---------------------------------
# Epoch 73/500
# Train RMSE: 0.2507
# Val RMSE: 0.2516, Val MAE: 0.1086
# Test RMSE: 0.3274, Test MAE: 0.1504
# ---------------------------------
# Patience grace period: 32
# ---------------------------------
# Epoch 74/500
# Train RMSE: 0.2507
# Val RMSE: 0.2518, Val MAE: 0.1093
# Test RMSE: 0.3267, Test MAE: 0.1507
# ---------------------------------
# Patience grace period: 30
# ---------------------------------
# Epoch 75/500
# Train RMSE: 0.2506
# Val RMSE: 0.2514, Val MAE: 0.1080
# Test RMSE: 0.3282, Test MAE: 0.1501
# ---------------------------------
# Patience grace period: 29
# ---------------------------------
# Epoch 76/500
# Train RMSE: 0.2506
# Val RMSE: 0.2516, Val MAE: 0.1088
# Test RMSE: 0.3274, Test MAE: 0.1505
# ---------------------------------
# Patience grace period: 27
# ---------------------------------
# Epoch 77/500
# Train RMSE: 0.2505
# Val RMSE: 0.2513, Val MAE: 0.1078
# Test RMSE: 0.3288, Test MAE: 0.1500
# ---------------------------------
# Patience grace period: 26
# ---------------------------------
# Epoch 78/500
# Train RMSE: 0.2505
# Val RMSE: 0.2516, Val MAE: 0.1084
# Test RMSE: 0.3274, Test MAE: 0.1504
# ---------------------------------
# Patience grace period: 24
# ---------------------------------
# Epoch 79/500
# Train RMSE: 0.2505
# Val RMSE: 0.2516, Val MAE: 0.1085
# Test RMSE: 0.3275, Test MAE: 0.1504
# ---------------------------------
# Patience grace period: 22
# ---------------------------------
# Epoch 80/500
# Train RMSE: 0.2504
# Val RMSE: 0.2513, Val MAE: 0.1077
# Test RMSE: 0.3287, Test MAE: 0.1502
# ---------------------------------
# Patience grace period: 21
# ---------------------------------
# Epoch 81/500
# Train RMSE: 0.2504
# Val RMSE: 0.2513, Val MAE: 0.1080
# Test RMSE: 0.3284, Test MAE: 0.1502
# ---------------------------------
# Patience grace period: 19
# ---------------------------------
# Epoch 82/500
# Train RMSE: 0.2504
# Val RMSE: 0.2514, Val MAE: 0.1079
# Test RMSE: 0.3285, Test MAE: 0.1501
# ---------------------------------
# Patience grace period: 17
# ---------------------------------
# Epoch 83/500
# Train RMSE: 0.2503
# Val RMSE: 0.2514, Val MAE: 0.1082
# Test RMSE: 0.3281, Test MAE: 0.1502
# ---------------------------------
# Patience grace period: 16
# ---------------------------------
# Epoch 84/500
# Train RMSE: 0.2503
# Val RMSE: 0.2515, Val MAE: 0.1081
# Test RMSE: 0.3285, Test MAE: 0.1502
# ---------------------------------
# Patience grace period: 14
# ---------------------------------
# Epoch 85/500
# Train RMSE: 0.2503
# Val RMSE: 0.2513, Val MAE: 0.1074
# Test RMSE: 0.3298, Test MAE: 0.1497
# ---------------------------------
# Patience grace period: 13
# ---------------------------------
# Epoch 86/500
# Train RMSE: 0.2502
# Val RMSE: 0.2515, Val MAE: 0.1085
# Test RMSE: 0.3277, Test MAE: 0.1505
# ---------------------------------
# Patience grace period: 11
# ---------------------------------
# Epoch 87/500
# Train RMSE: 0.2502
# Val RMSE: 0.2515, Val MAE: 0.1080
# Test RMSE: 0.3284, Test MAE: 0.1502
# ---------------------------------
# Patience grace period: 10
# ---------------------------------
# Epoch 88/500
# Train RMSE: 0.2502
# Val RMSE: 0.2513, Val MAE: 0.1079
# Test RMSE: 0.3282, Test MAE: 0.1502
# ---------------------------------
# Patience grace period: 9
# ---------------------------------
# Epoch 89/500
# Train RMSE: 0.2501
# Val RMSE: 0.2514, Val MAE: 0.1078
# Test RMSE: 0.3284, Test MAE: 0.1501
# ---------------------------------
# Patience grace period: 7
# ---------------------------------
# Epoch 90/500
# Train RMSE: 0.2501
# Val RMSE: 0.2513, Val MAE: 0.1080
# Test RMSE: 0.3283, Test MAE: 0.1502
# ---------------------------------
# Patience grace period: 6
# ---------------------------------
# Epoch 91/500
# Train RMSE: 0.2501
# Val RMSE: 0.2514, Val MAE: 0.1082
# Test RMSE: 0.3282, Test MAE: 0.1505
# ---------------------------------
# Patience grace period: 4
# ---------------------------------
# Epoch 92/500
# Train RMSE: 0.2501
# Val RMSE: 0.2516, Val MAE: 0.1085
# Test RMSE: 0.3279, Test MAE: 0.1506
# ---------------------------------
# Patience grace period: 2
# ---------------------------------
# Epoch 93/500
# Train RMSE: 0.2500
# Val RMSE: 0.2516, Val MAE: 0.1083
# Test RMSE: 0.3282, Test MAE: 0.1503
# ---------------------------------
# Patience grace period: 0
# Early stopping triggered at epoch 93
# Final Test RMSE: 0.3288, Final Test MAE: 0.1499
# <ipython-input-3-2a228d64b832>:126: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   self.model.load_state_dict(torch.load(os.path.join(save_dir, 'best_model.pth')))
# Pearson Corr: 0.7429449991293895
# Spearman Corr: 0.4230302606047667
# p-rmse: 0.3287553749261527
#        rmse       mae  seed                             subtask    method  \
# 0  0.328755  0.149904     5  openproblems_bmmc_cite_phase2_mod2  original
#
#     pearson p_value_pearson  spearman p_value_spearman
# 0  0.742945          0.0000   0.42303           0.0000

# %%
config_hierachical_PROTEIN = {
    "subtask": "openproblems_bmmc_cite_phase2_mod2",
    "batch_size": 520,
    "act": "relu",
    "conv_flow": ["gconv"],
    "agg_flow": [None],
    "device": "cuda",
    "learning_rate": 0.000064,
    "hidden_size": 280,
    "num_heads": 6,
    "n_neigbours": 3,
    "metric": "euclidean",
    "n_components": 1200,
    "dropout_rate": 0.2,
    "num_epochs": 500,
    "seed": 1,
    "es_patience": 40,
    "es_min_delta": 0.0001,
    "es_rate_threshold": 0.00002,
    "layer_dim_ex": 3,
    "verbose": True,
    "sample": True,
    "preprocessing_type": "None",
    "variant": "original",
    "num_clusters": 10
}

pipeline(**config_hierachical_PROTEIN)
# Out:
# [INFO][2025-04-15 19:17:19,995][dance][_load_raw_data] Loading /content/data/openproblems_bmmc_cite_phase2_mod2/openproblems_bmmc_cite_phase2_mod2.censor_dataset.output_train_mod1.h5ad
# Initializing pipeline...
# [INFO][2025-04-15 19:17:20,645][dance][_load_raw_data] Loading /content/data/openproblems_bmmc_cite_phase2_mod2/openproblems_bmmc_cite_phase2_mod2.censor_dataset.output_train_mod2.h5ad
# [INFO][2025-04-15 19:17:28,323][dance][_load_raw_data] Loading /content/data/openproblems_bmmc_cite_phase2_mod2/openproblems_bmmc_cite_phase2_mod2.censor_dataset.output_test_mod1.h5ad
# [INFO][2025-04-15 19:17:28,348][dance][_load_raw_data] Loading /content/data/openproblems_bmmc_cite_phase2_mod2/openproblems_bmmc_cite_phase2_mod2.censor_dataset.output_test_mod2.h5ad
# [INFO][2025-04-15 19:17:28,547][dance][_maybe_preprocess] Preprocessing done.
# /usr/local/lib/python3.11/dist-packages/mudata/_core/mudata.py:1531: FutureWarning: From 0.4 .update() will not pull obs/var columns from individual modalities by default anymore. Set mudata.set_options(pull_on_update=False) to adopt the new behaviour, which will become the default. Use new pull_obs/pull_var and push_obs/push_var methods for more flexibility.
#   self._update_attr("var", axis=0, join_common=join_common)
# /usr/local/lib/python3.11/dist-packages/mudata/_core/mudata.py:931: UserWarning: Cannot join columns with the same name because var_names are intersecting.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/mudata/_core/mudata.py:1429: FutureWarning: From 0.4 .update() will not pull obs/var columns from individual modalities by default anymore. Set mudata.set_options(pull_on_update=False) to adopt the new behaviour, which will become the default. Use new pull_obs/pull_var and push_obs/push_var methods for more flexibility.
#   self._update_attr("obs", axis=1, join_common=join_common)
# /usr/local/lib/python3.11/dist-packages/mudata/_core/mudata.py:1558: UserWarning: Modality names will be prepended to var_names since there are identical var_names in different modalities.
#   warnings.warn(
# [INFO][2025-04-15 19:17:35,721][dance][set_config_from_dict] Setting config 'feature_mod' to 'mod1'
# [INFO][2025-04-15 19:17:35,722][dance][set_config_from_dict] Setting config 'label_mod' to 'mod2'
# [INFO][2025-04-15 19:17:35,723][dance][load_data] Raw data loaded:
# Data object that wraps (.data):
# MuData object with n_obs × n_vars = 67175 × 14087
#   uns:	'dance_config'
#   2 modalities
#     mod1:	67175 x 134
#       obs:	'batch'
#       layers:	'counts'
#     mod2:	67175 x 13953
#       obs:	'batch'
#       layers:	'counts'
# [INFO][2025-04-15 19:17:35,842][dance][wrapped_func] Took 0:00:15.847356 to load and process data.
# <ipython-input-4-038168299b8a>:42: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   data.data.uns['gtrain'] = torch.load(train_graph_path)
# <ipython-input-4-038168299b8a>:43: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   data.data.uns['gval'] = torch.load(val_graph_path)
# <ipython-input-4-038168299b8a>:44: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   data.data.uns['gtest'] = torch.load(test_graph_path)
# <ipython-input-4-038168299b8a>:45: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   train_label = torch.load(train_label_path).numpy()
# Processed data found. Loading...
# <ipython-input-4-038168299b8a>:46: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   val_label = torch.load(val_label_path).numpy()
# <ipython-input-4-038168299b8a>:47: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   test_label = torch.load(test_label_path).numpy()
# <ipython-input-4-038168299b8a>:48: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   kwargs["FEATURE_SIZE"] = torch.load(feature_size_path).item()
# <ipython-input-4-038168299b8a>:49: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   kwargs["OUTPUT_SIZE"] = torch.load(output_size_path).item()
# Processed data loaded.
# ---------------------------------
# Epoch 1/500
# Train RMSE: 0.3759
# Val RMSE: 0.3230, Val MAE: 0.1360
# Test RMSE: 0.3938, Test MAE: 0.1812
# ---------------------------------
# Model saved at epoch 1 with val RMSE 0.3230
# Patience grace period: 40
# ---------------------------------
# Epoch 2/500
# Train RMSE: 0.3220
# Val RMSE: 0.2978, Val MAE: 0.1287
# Test RMSE: 0.3634, Test MAE: 0.1711
# ---------------------------------
# Model saved at epoch 2 with val RMSE 0.2978
# Patience grace period: 40
# ---------------------------------
# Epoch 3/500
# Train RMSE: 0.3017
# Val RMSE: 0.2855, Val MAE: 0.1231
# Test RMSE: 0.3527, Test MAE: 0.1642
# ---------------------------------
# Model saved at epoch 3 with val RMSE 0.2855
# Patience grace period: 40
# ---------------------------------
# Epoch 4/500
# Train RMSE: 0.2903
# Val RMSE: 0.2792, Val MAE: 0.1205
# Test RMSE: 0.3486, Test MAE: 0.1610
# ---------------------------------
# Model saved at epoch 4 with val RMSE 0.2792
# Patience grace period: 40
# ---------------------------------
# Epoch 5/500
# Train RMSE: 0.2836
# Val RMSE: 0.2748, Val MAE: 0.1192
# Test RMSE: 0.3453, Test MAE: 0.1593
# ---------------------------------
# Model saved at epoch 5 with val RMSE 0.2748
# Patience grace period: 40
# ---------------------------------
# Epoch 6/500
# Train RMSE: 0.2789
# Val RMSE: 0.2715, Val MAE: 0.1179
# Test RMSE: 0.3423, Test MAE: 0.1579
# ---------------------------------
# Model saved at epoch 6 with val RMSE 0.2715
# Patience grace period: 40
# ---------------------------------
# Epoch 7/500
# Train RMSE: 0.2752
# Val RMSE: 0.2687, Val MAE: 0.1167
# Test RMSE: 0.3397, Test MAE: 0.1564
# ---------------------------------
# Model saved at epoch 7 with val RMSE 0.2687
# Patience grace period: 40
# ---------------------------------
# Epoch 8/500
# Train RMSE: 0.2722
# Val RMSE: 0.2664, Val MAE: 0.1158
# Test RMSE: 0.3374, Test MAE: 0.1553
# ---------------------------------
# Model saved at epoch 8 with val RMSE 0.2664
# Patience grace period: 40
# ---------------------------------
# Epoch 9/500
# Train RMSE: 0.2698
# Val RMSE: 0.2645, Val MAE: 0.1150
# Test RMSE: 0.3356, Test MAE: 0.1544
# ---------------------------------
# Model saved at epoch 9 with val RMSE 0.2645
# Patience grace period: 40
# ---------------------------------
# Epoch 10/500
# Train RMSE: 0.2678
# Val RMSE: 0.2630, Val MAE: 0.1144
# Test RMSE: 0.3345, Test MAE: 0.1538
# ---------------------------------
# Model saved at epoch 10 with val RMSE 0.2630
# Patience grace period: 40
# ---------------------------------
# Epoch 11/500
# Train RMSE: 0.2662
# Val RMSE: 0.2617, Val MAE: 0.1136
# Test RMSE: 0.3339, Test MAE: 0.1530
# ---------------------------------
# Model saved at epoch 11 with val RMSE 0.2617
# Patience grace period: 40
# ---------------------------------
# Epoch 12/500
# Train RMSE: 0.2648
# Val RMSE: 0.2606, Val MAE: 0.1133
# Test RMSE: 0.3329, Test MAE: 0.1526
# ---------------------------------
# Model saved at epoch 12 with val RMSE 0.2606
# Patience grace period: 40
# ---------------------------------
# Epoch 13/500
# Train RMSE: 0.2637
# Val RMSE: 0.2597, Val MAE: 0.1131
# Test RMSE: 0.3325, Test MAE: 0.1523
# ---------------------------------
# Model saved at epoch 13 with val RMSE 0.2597
# Patience grace period: 40
# ---------------------------------
# Epoch 14/500
# Train RMSE: 0.2628
# Val RMSE: 0.2590, Val MAE: 0.1127
# Test RMSE: 0.3324, Test MAE: 0.1518
# ---------------------------------
# Model saved at epoch 14 with val RMSE 0.2590
# Patience grace period: 40
# ---------------------------------
# Epoch 15/500
# Train RMSE: 0.2619
# Val RMSE: 0.2584, Val MAE: 0.1126
# Test RMSE: 0.3322, Test MAE: 0.1514
# ---------------------------------
# Model saved at epoch 15 with val RMSE 0.2584
# Patience grace period: 40
# ---------------------------------
# Epoch 16/500
# Train RMSE: 0.2612
# Val RMSE: 0.2579, Val MAE: 0.1125
# Test RMSE: 0.3320, Test MAE: 0.1511
# ---------------------------------
# Model saved at epoch 16 with val RMSE 0.2579
# Patience grace period: 40
# ---------------------------------
# Epoch 17/500
# Train RMSE: 0.2606
# Val RMSE: 0.2574, Val MAE: 0.1126
# Test RMSE: 0.3318, Test MAE: 0.1508
# ---------------------------------
# Model saved at epoch 17 with val RMSE 0.2574
# Patience grace period: 40
# ---------------------------------
# Epoch 18/500
# Train RMSE: 0.2601
# Val RMSE: 0.2570, Val MAE: 0.1124
# Test RMSE: 0.3320, Test MAE: 0.1506
# ---------------------------------
# Model saved at epoch 18 with val RMSE 0.2570
# Patience grace period: 40
# ---------------------------------
# Epoch 19/500
# Train RMSE: 0.2595
# Val RMSE: 0.2567, Val MAE: 0.1121
# Test RMSE: 0.3322, Test MAE: 0.1501
# ---------------------------------
# Model saved at epoch 19 with val RMSE 0.2567
# Patience grace period: 40
# ---------------------------------
# Epoch 20/500
# Train RMSE: 0.2591
# Val RMSE: 0.2564, Val MAE: 0.1123
# Test RMSE: 0.3321, Test MAE: 0.1501
# ---------------------------------
# Model saved at epoch 20 with val RMSE 0.2564
# Patience grace period: 40
# ---------------------------------
# Epoch 21/500
# Train RMSE: 0.2587
# Val RMSE: 0.2561, Val MAE: 0.1120
# Test RMSE: 0.3326, Test MAE: 0.1497
# ---------------------------------
# Model saved at epoch 21 with val RMSE 0.2561
# Patience grace period: 40
# ---------------------------------
# Epoch 22/500
# Train RMSE: 0.2583
# Val RMSE: 0.2559, Val MAE: 0.1117
# Test RMSE: 0.3328, Test MAE: 0.1493
# ---------------------------------
# Model saved at epoch 22 with val RMSE 0.2559
# Patience grace period: 40
# ---------------------------------
# Epoch 23/500
# Train RMSE: 0.2579
# Val RMSE: 0.2556, Val MAE: 0.1117
# Test RMSE: 0.3329, Test MAE: 0.1491
# ---------------------------------
# Model saved at epoch 23 with val RMSE 0.2556
# Patience grace period: 40
# ---------------------------------
# Epoch 24/500
# Train RMSE: 0.2576
# Val RMSE: 0.2554, Val MAE: 0.1115
# Test RMSE: 0.3330, Test MAE: 0.1488
# ---------------------------------
# Model saved at epoch 24 with val RMSE 0.2554
# Patience grace period: 40
# ---------------------------------
# Epoch 25/500
# Train RMSE: 0.2573
# Val RMSE: 0.2552, Val MAE: 0.1117
# Test RMSE: 0.3331, Test MAE: 0.1487
# ---------------------------------
# Model saved at epoch 25 with val RMSE 0.2552
# Patience grace period: 40
# ---------------------------------
# Epoch 26/500
# Train RMSE: 0.2570
# Val RMSE: 0.2550, Val MAE: 0.1114
# Test RMSE: 0.3332, Test MAE: 0.1485
# ---------------------------------
# Model saved at epoch 26 with val RMSE 0.2550
# Patience grace period: 40
# ---------------------------------
# Epoch 27/500
# Train RMSE: 0.2568
# Val RMSE: 0.2548, Val MAE: 0.1111
# Test RMSE: 0.3339, Test MAE: 0.1482
# ---------------------------------
# Model saved at epoch 27 with val RMSE 0.2548
# Patience grace period: 40
# ---------------------------------
# Epoch 28/500
# Train RMSE: 0.2565
# Val RMSE: 0.2547, Val MAE: 0.1112
# Test RMSE: 0.3337, Test MAE: 0.1481
# ---------------------------------
# Model saved at epoch 28 with val RMSE 0.2547
# Patience grace period: 40
# ---------------------------------
# Epoch 29/500
# Train RMSE: 0.2563
# Val RMSE: 0.2545, Val MAE: 0.1109
# Test RMSE: 0.3338, Test MAE: 0.1479
# ---------------------------------
# Model saved at epoch 29 with val RMSE 0.2545
# Patience grace period: 40
# ---------------------------------
# Epoch 30/500
# Train RMSE: 0.2561
# Val RMSE: 0.2543, Val MAE: 0.1108
# Test RMSE: 0.3339, Test MAE: 0.1476
# ---------------------------------
# Model saved at epoch 30 with val RMSE 0.2543
# Patience grace period: 40
# ---------------------------------
# Epoch 31/500
# Train RMSE: 0.2559
# Val RMSE: 0.2542, Val MAE: 0.1105
# Test RMSE: 0.3345, Test MAE: 0.1474
# ---------------------------------
# Model saved at epoch 31 with val RMSE 0.2542
# Patience grace period: 40
# ---------------------------------
# Epoch 32/500
# Train RMSE: 0.2557
# Val RMSE: 0.2540, Val MAE: 0.1105
# Test RMSE: 0.3343, Test MAE: 0.1475
# ---------------------------------
# Model saved at epoch 32 with val RMSE 0.2540
# Patience grace period: 40
# ---------------------------------
# Epoch 33/500
# Train RMSE: 0.2555
# Val RMSE: 0.2539, Val MAE: 0.1107
# Test RMSE: 0.3340, Test MAE: 0.1475
# ---------------------------------
# Model saved at epoch 33 with val RMSE 0.2539
# Patience grace period: 40
# ---------------------------------
# Epoch 34/500
# Train RMSE: 0.2554
# Val RMSE: 0.2538, Val MAE: 0.1101
# Test RMSE: 0.3352, Test MAE: 0.1471
# ---------------------------------
# Model saved at epoch 34 with val RMSE 0.2538
# Patience grace period: 40
# ---------------------------------
# Epoch 35/500
# Train RMSE: 0.2552
# Val RMSE: 0.2537, Val MAE: 0.1104
# Test RMSE: 0.3344, Test MAE: 0.1473
# ---------------------------------
# Model saved at epoch 35 with val RMSE 0.2537
# Patience grace period: 40
# ---------------------------------
# Epoch 36/500
# Train RMSE: 0.2551
# Val RMSE: 0.2536, Val MAE: 0.1101
# Test RMSE: 0.3350, Test MAE: 0.1471
# ---------------------------------
# Model saved at epoch 36 with val RMSE 0.2536
# Patience grace period: 40
# ---------------------------------
# Epoch 37/500
# Train RMSE: 0.2549
# Val RMSE: 0.2535, Val MAE: 0.1100
# Test RMSE: 0.3350, Test MAE: 0.1471
# ---------------------------------
# Model saved at epoch 37 with val RMSE 0.2535
# Patience grace period: 39
# ---------------------------------
# Epoch 38/500
# Train RMSE: 0.2548
# Val RMSE: 0.2534, Val MAE: 0.1098
# Test RMSE: 0.3351, Test MAE: 0.1472
# ---------------------------------
# Model saved at epoch 38 with val RMSE 0.2534
# Patience grace period: 40
# ---------------------------------
# Epoch 39/500
# Train RMSE: 0.2547
# Val RMSE: 0.2533, Val MAE: 0.1098
# Test RMSE: 0.3352, Test MAE: 0.1471
# ---------------------------------
# Model saved at epoch 39 with val RMSE 0.2533
# Patience grace period: 39
# ---------------------------------
# Epoch 40/500
# Train RMSE: 0.2546
# Val RMSE: 0.2532, Val MAE: 0.1097
# Test RMSE: 0.3353, Test MAE: 0.1469
# ---------------------------------
# Model saved at epoch 40 with val RMSE 0.2532
# Patience grace period: 40
# ---------------------------------
# Epoch 41/500
# Train RMSE: 0.2545
# Val RMSE: 0.2532, Val MAE: 0.1101
# Test RMSE: 0.3348, Test MAE: 0.1470
# ---------------------------------
# Model saved at epoch 41 with val RMSE 0.2532
# Patience grace period: 39
# ---------------------------------
# Epoch 42/500
# Train RMSE: 0.2544
# Val RMSE: 0.2530, Val MAE: 0.1096
# Test RMSE: 0.3355, Test MAE: 0.1470
# ---------------------------------
# Model saved at epoch 42 with val RMSE 0.2530
# Patience grace period: 40
# ---------------------------------
# Epoch 43/500
# Train RMSE: 0.2543
# Val RMSE: 0.2530, Val MAE: 0.1094
# Test RMSE: 0.3356, Test MAE: 0.1469
# ---------------------------------
# Model saved at epoch 43 with val RMSE 0.2530
# Patience grace period: 39
# ---------------------------------
# Epoch 44/500
# Train RMSE: 0.2542
# Val RMSE: 0.2529, Val MAE: 0.1095
# Test RMSE: 0.3355, Test MAE: 0.1470
# ---------------------------------
# Model saved at epoch 44 with val RMSE 0.2529
# Patience grace period: 40
# ---------------------------------
# Epoch 45/500
# Train RMSE: 0.2541
# Val RMSE: 0.2528, Val MAE: 0.1092
# Test RMSE: 0.3362, Test MAE: 0.1470
# ---------------------------------
# Model saved at epoch 45 with val RMSE 0.2528
# Patience grace period: 39
# ---------------------------------
# Epoch 46/500
# Train RMSE: 0.2541
# Val RMSE: 0.2528, Val MAE: 0.1091
# Test RMSE: 0.3361, Test MAE: 0.1469
# ---------------------------------
# Model saved at epoch 46 with val RMSE 0.2528
# Patience grace period: 40
# ---------------------------------
# Epoch 47/500
# Train RMSE: 0.2540
# Val RMSE: 0.2527, Val MAE: 0.1090
# Test RMSE: 0.3361, Test MAE: 0.1469
# ---------------------------------
# Model saved at epoch 47 with val RMSE 0.2527
# Patience grace period: 39
# ---------------------------------
# Epoch 48/500
# Train RMSE: 0.2539
# Val RMSE: 0.2527, Val MAE: 0.1090
# Test RMSE: 0.3362, Test MAE: 0.1468
# ---------------------------------
# Model saved at epoch 48 with val RMSE 0.2527
# Patience grace period: 40
# ---------------------------------
# Epoch 49/500
# Train RMSE: 0.2538
# Val RMSE: 0.2526, Val MAE: 0.1089
# Test RMSE: 0.3363, Test MAE: 0.1468
# ---------------------------------
# Model saved at epoch 49 with val RMSE 0.2526
# Patience grace period: 39
# ---------------------------------
# Epoch 50/500
# Train RMSE: 0.2538
# Val RMSE: 0.2526, Val MAE: 0.1093
# Test RMSE: 0.3354, Test MAE: 0.1470
# ---------------------------------
# Model saved at epoch 50 with val RMSE 0.2526
# Patience grace period: 38
# ---------------------------------
# Epoch 51/500
# Train RMSE: 0.2537
# Val RMSE: 0.2525, Val MAE: 0.1089
# Test RMSE: 0.3362, Test MAE: 0.1469
# ---------------------------------
# Model saved at epoch 51 with val RMSE 0.2525
# Patience grace period: 40
# ---------------------------------
# Epoch 52/500
# Train RMSE: 0.2536
# Val RMSE: 0.2525, Val MAE: 0.1088
# Test RMSE: 0.3364, Test MAE: 0.1470
# ---------------------------------
# Model saved at epoch 52 with val RMSE 0.2525
# Patience grace period: 39
# ---------------------------------
# Epoch 53/500
# Train RMSE: 0.2536
# Val RMSE: 0.2524, Val MAE: 0.1087
# Test RMSE: 0.3361, Test MAE: 0.1470
# ---------------------------------
# Model saved at epoch 53 with val RMSE 0.2524
# Patience grace period: 38
# ---------------------------------
# Epoch 54/500
# Train RMSE: 0.2535
# Val RMSE: 0.2524, Val MAE: 0.1083
# Test RMSE: 0.3370, Test MAE: 0.1470
# ---------------------------------
# Model saved at epoch 54 with val RMSE 0.2524
# Patience grace period: 40
# ---------------------------------
# Epoch 55/500
# Train RMSE: 0.2534
# Val RMSE: 0.2523, Val MAE: 0.1082
# Test RMSE: 0.3370, Test MAE: 0.1469
# ---------------------------------
# Model saved at epoch 55 with val RMSE 0.2523
# Patience grace period: 39
# ---------------------------------
# Epoch 56/500
# Train RMSE: 0.2534
# Val RMSE: 0.2523, Val MAE: 0.1086
# Test RMSE: 0.3364, Test MAE: 0.1470
# ---------------------------------
# Model saved at epoch 56 with val RMSE 0.2523
# Patience grace period: 38
# ---------------------------------
# Epoch 57/500
# Train RMSE: 0.2533
# Val RMSE: 0.2522, Val MAE: 0.1083
# Test RMSE: 0.3368, Test MAE: 0.1470
# ---------------------------------
# Model saved at epoch 57 with val RMSE 0.2522
# Patience grace period: 40
# ---------------------------------
# Epoch 58/500
# Train RMSE: 0.2532
# Val RMSE: 0.2522, Val MAE: 0.1082
# Test RMSE: 0.3367, Test MAE: 0.1470
# ---------------------------------
# Model saved at epoch 58 with val RMSE 0.2522
# Patience grace period: 39
# ---------------------------------
# Epoch 59/500
# Train RMSE: 0.2532
# Val RMSE: 0.2521, Val MAE: 0.1083
# Test RMSE: 0.3363, Test MAE: 0.1471
# ---------------------------------
# Model saved at epoch 59 with val RMSE 0.2521
# Patience grace period: 40
# ---------------------------------
# Epoch 60/500
# Train RMSE: 0.2531
# Val RMSE: 0.2521, Val MAE: 0.1081
# Test RMSE: 0.3363, Test MAE: 0.1471
# ---------------------------------
# Model saved at epoch 60 with val RMSE 0.2521
# Patience grace period: 39
# ---------------------------------
# Epoch 61/500
# Train RMSE: 0.2531
# Val RMSE: 0.2520, Val MAE: 0.1079
# Test RMSE: 0.3367, Test MAE: 0.1472
# ---------------------------------
# Model saved at epoch 61 with val RMSE 0.2520
# Patience grace period: 38
# ---------------------------------
# Epoch 62/500
# Train RMSE: 0.2530
# Val RMSE: 0.2520, Val MAE: 0.1079
# Test RMSE: 0.3364, Test MAE: 0.1472
# ---------------------------------
# Model saved at epoch 62 with val RMSE 0.2520
# Patience grace period: 40
# ---------------------------------
# Epoch 63/500
# Train RMSE: 0.2530
# Val RMSE: 0.2519, Val MAE: 0.1079
# Test RMSE: 0.3363, Test MAE: 0.1472
# ---------------------------------
# Model saved at epoch 63 with val RMSE 0.2519
# Patience grace period: 39
# ---------------------------------
# Epoch 64/500
# Train RMSE: 0.2529
# Val RMSE: 0.2519, Val MAE: 0.1078
# Test RMSE: 0.3368, Test MAE: 0.1472
# ---------------------------------
# Model saved at epoch 64 with val RMSE 0.2519
# Patience grace period: 38
# ---------------------------------
# Epoch 65/500
# Train RMSE: 0.2529
# Val RMSE: 0.2518, Val MAE: 0.1078
# Test RMSE: 0.3364, Test MAE: 0.1473
# ---------------------------------
# Model saved at epoch 65 with val RMSE 0.2518
# Patience grace period: 40
# ---------------------------------
# Epoch 66/500
# Train RMSE: 0.2528
# Val RMSE: 0.2518, Val MAE: 0.1076
# Test RMSE: 0.3366, Test MAE: 0.1473
# ---------------------------------
# Model saved at epoch 66 with val RMSE 0.2518
# Patience grace period: 39
# ---------------------------------
# Epoch 67/500
# Train RMSE: 0.2527
# Val RMSE: 0.2517, Val MAE: 0.1076
# Test RMSE: 0.3363, Test MAE: 0.1474
# ---------------------------------
# Model saved at epoch 67 with val RMSE 0.2517
# Patience grace period: 38
# ---------------------------------
# Epoch 68/500
# Train RMSE: 0.2527
# Val RMSE: 0.2517, Val MAE: 0.1076
# Test RMSE: 0.3366, Test MAE: 0.1473
# ---------------------------------
# Model saved at epoch 68 with val RMSE 0.2517
# Patience grace period: 40
# ---------------------------------
# Epoch 69/500
# Train RMSE: 0.2526
# Val RMSE: 0.2516, Val MAE: 0.1078
# Test RMSE: 0.3357, Test MAE: 0.1474
# ---------------------------------
# Model saved at epoch 69 with val RMSE 0.2516
# Patience grace period: 39
# ---------------------------------
# Epoch 70/500
# Train RMSE: 0.2526
# Val RMSE: 0.2516, Val MAE: 0.1078
# Test RMSE: 0.3358, Test MAE: 0.1476
# ---------------------------------
# Model saved at epoch 70 with val RMSE 0.2516
# Patience grace period: 40
# ---------------------------------
# Epoch 71/500
# Train RMSE: 0.2526
# Val RMSE: 0.2516, Val MAE: 0.1075
# Test RMSE: 0.3362, Test MAE: 0.1474
# ---------------------------------
# Model saved at epoch 71 with val RMSE 0.2516
# Patience grace period: 39
# ---------------------------------
# Epoch 72/500
# Train RMSE: 0.2525
# Val RMSE: 0.2515, Val MAE: 0.1076
# Test RMSE: 0.3357, Test MAE: 0.1475
# ---------------------------------
# Model saved at epoch 72 with val RMSE 0.2515
# Patience grace period: 38
# ---------------------------------
# Epoch 73/500
# Train RMSE: 0.2525
# Val RMSE: 0.2515, Val MAE: 0.1075
# Test RMSE: 0.3355, Test MAE: 0.1475
# ---------------------------------
# Model saved at epoch 73 with val RMSE 0.2515
# Patience grace period: 40
# ---------------------------------
# Epoch 74/500
# Train RMSE: 0.2524
# Val RMSE: 0.2514, Val MAE: 0.1074
# Test RMSE: 0.3360, Test MAE: 0.1476
# ---------------------------------
# Model saved at epoch 74 with val RMSE 0.2514
# Patience grace period: 39
# ---------------------------------
# Epoch 75/500
# Train RMSE: 0.2524
# Val RMSE: 0.2514, Val MAE: 0.1072
# Test RMSE: 0.3363, Test MAE: 0.1476
# ---------------------------------
# Model saved at epoch 75 with val RMSE 0.2514
# Patience grace period: 38
# ---------------------------------
# Epoch 76/500
# Train RMSE: 0.2523
# Val RMSE: 0.2514, Val MAE: 0.1072
# Test RMSE: 0.3360, Test MAE: 0.1475
# ---------------------------------
# Model saved at epoch 76 with val RMSE 0.2514
# Patience grace period: 37
# ---------------------------------
# Epoch 77/500
# Train RMSE: 0.2523
# Val RMSE: 0.2513, Val MAE: 0.1071
# Test RMSE: 0.3362, Test MAE: 0.1475
# ---------------------------------
# Model saved at epoch 77 with val RMSE 0.2513
# Patience grace period: 40
# ---------------------------------
# Epoch 78/500
# Train RMSE: 0.2523
# Val RMSE: 0.2513, Val MAE: 0.1073
# Test RMSE: 0.3360, Test MAE: 0.1476
# ---------------------------------
# Model saved at epoch 78 with val RMSE 0.2513
# Patience grace period: 39
# ---------------------------------
# Epoch 79/500
# Train RMSE: 0.2522
# Val RMSE: 0.2512, Val MAE: 0.1072
# Test RMSE: 0.3359, Test MAE: 0.1477
# ---------------------------------
# Model saved at epoch 79 with val RMSE 0.2512
# Patience grace period: 38
# ---------------------------------
# Epoch 80/500
# Train RMSE: 0.2522
# Val RMSE: 0.2512, Val MAE: 0.1071
# Test RMSE: 0.3357, Test MAE: 0.1475
# ---------------------------------
# Model saved at epoch 80 with val RMSE 0.2512
# Patience grace period: 40
# ---------------------------------
# Epoch 81/500
# Train RMSE: 0.2521
# Val RMSE: 0.2512, Val MAE: 0.1073
# Test RMSE: 0.3351, Test MAE: 0.1478
# ---------------------------------
# Model saved at epoch 81 with val RMSE 0.2512
# Patience grace period: 39
# ---------------------------------
# Epoch 82/500
# Train RMSE: 0.2521
# Val RMSE: 0.2511, Val MAE: 0.1072
# Test RMSE: 0.3355, Test MAE: 0.1478
# ---------------------------------
# Model saved at epoch 82 with val RMSE 0.2511
# Patience grace period: 38
# ---------------------------------
# Epoch 83/500
# Train RMSE: 0.2521
# Val RMSE: 0.2511, Val MAE: 0.1071
# Test RMSE: 0.3353, Test MAE: 0.1478
# ---------------------------------
# Model saved at epoch 83 with val RMSE 0.2511
# Patience grace period: 40
# ---------------------------------
# Epoch 84/500
# Train RMSE: 0.2520
# Val RMSE: 0.2511, Val MAE: 0.1070
# Test RMSE: 0.3354, Test MAE: 0.1478
# ---------------------------------
# Model saved at epoch 84 with val RMSE 0.2511
# Patience grace period: 39
# ---------------------------------
# Epoch 85/500
# Train RMSE: 0.2520
# Val RMSE: 0.2510, Val MAE: 0.1071
# Test RMSE: 0.3352, Test MAE: 0.1478
# ---------------------------------
# Model saved at epoch 85 with val RMSE 0.2510
# Patience grace period: 38
# ---------------------------------
# Epoch 86/500
# Train RMSE: 0.2520
# Val RMSE: 0.2510, Val MAE: 0.1069
# Test RMSE: 0.3354, Test MAE: 0.1478
# ---------------------------------
# Model saved at epoch 86 with val RMSE 0.2510
# Patience grace period: 37
# ---------------------------------
# Epoch 87/500
# Train RMSE: 0.2519
# Val RMSE: 0.2510, Val MAE: 0.1069
# Test RMSE: 0.3354, Test MAE: 0.1478
# ---------------------------------
# Model saved at epoch 87 with val RMSE 0.2510
# Patience grace period: 40
# ---------------------------------
# Epoch 88/500
# Train RMSE: 0.2519
# Val RMSE: 0.2509, Val MAE: 0.1069
# Test RMSE: 0.3355, Test MAE: 0.1477
# ---------------------------------
# Model saved at epoch 88 with val RMSE 0.2509
# Patience grace period: 39
# ---------------------------------
# Epoch 89/500
# Train RMSE: 0.2519
# Val RMSE: 0.2509, Val MAE: 0.1067
# Test RMSE: 0.3355, Test MAE: 0.1476
# ---------------------------------
# Model saved at epoch 89 with val RMSE 0.2509
# Patience grace period: 38
# ---------------------------------
# Epoch 90/500
# Train RMSE: 0.2518
# Val RMSE: 0.2509, Val MAE: 0.1066
# Test RMSE: 0.3358, Test MAE: 0.1477
# ---------------------------------
# Patience grace period: 36
# ---------------------------------
# Epoch 91/500
# Train RMSE: 0.2518
# Val RMSE: 0.2509, Val MAE: 0.1066
# Test RMSE: 0.3356, Test MAE: 0.1477
# ---------------------------------
# Model saved at epoch 91 with val RMSE 0.2509
# Patience grace period: 40
# ---------------------------------
# Epoch 92/500
# Train RMSE: 0.2518
# Val RMSE: 0.2508, Val MAE: 0.1065
# Test RMSE: 0.3361, Test MAE: 0.1478
# ---------------------------------
# Model saved at epoch 92 with val RMSE 0.2508
# Patience grace period: 39
# ---------------------------------
# Epoch 93/500
# Train RMSE: 0.2517
# Val RMSE: 0.2508, Val MAE: 0.1066
# Test RMSE: 0.3355, Test MAE: 0.1478
# ---------------------------------
# Model saved at epoch 93 with val RMSE 0.2508
# Patience grace period: 38
# ---------------------------------
# Epoch 94/500
# Train RMSE: 0.2517
# Val RMSE: 0.2508, Val MAE: 0.1068
# Test RMSE: 0.3348, Test MAE: 0.1479
# ---------------------------------
# Model saved at epoch 94 with val RMSE 0.2508
# Patience grace period: 40
# ---------------------------------
# Epoch 95/500
# Train RMSE: 0.2517
# Val RMSE: 0.2507, Val MAE: 0.1069
# Test RMSE: 0.3350, Test MAE: 0.1481
# ---------------------------------
# Model saved at epoch 95 with val RMSE 0.2507
# Patience grace period: 39
# ---------------------------------
# Epoch 96/500
# Train RMSE: 0.2516
# Val RMSE: 0.2507, Val MAE: 0.1067
# Test RMSE: 0.3348, Test MAE: 0.1478
# ---------------------------------
# Model saved at epoch 96 with val RMSE 0.2507
# Patience grace period: 38
# ---------------------------------
# Epoch 97/500
# Train RMSE: 0.2516
# Val RMSE: 0.2507, Val MAE: 0.1068
# Test RMSE: 0.3351, Test MAE: 0.1481
# ---------------------------------
# Model saved at epoch 97 with val RMSE 0.2507
# Patience grace period: 37
# ---------------------------------
# Epoch 98/500
# Train RMSE: 0.2516
# Val RMSE: 0.2507, Val MAE: 0.1066
# Test RMSE: 0.3354, Test MAE: 0.1480
# ---------------------------------
# Model saved at epoch 98 with val RMSE 0.2507
# Patience grace period: 36
# ---------------------------------
# Epoch 99/500
# Train RMSE: 0.2515
# Val RMSE: 0.2506, Val MAE: 0.1066
# Test RMSE: 0.3353, Test MAE: 0.1479
# ---------------------------------
# Model saved at epoch 99 with val RMSE 0.2506
# Patience grace period: 40
# ---------------------------------
# Epoch 100/500
# Train RMSE: 0.2515
# Val RMSE: 0.2506, Val MAE: 0.1064
# Test RMSE: 0.3355, Test MAE: 0.1479
# ---------------------------------
# Patience grace period: 38
# ---------------------------------
# Epoch 101/500
# Train RMSE: 0.2515
# Val RMSE: 0.2506, Val MAE: 0.1065
# Test RMSE: 0.3350, Test MAE: 0.1479
# ---------------------------------
# Model saved at epoch 101 with val RMSE 0.2506
# Patience grace period: 37
# ---------------------------------
# Epoch 102/500
# Train RMSE: 0.2515
# Val RMSE: 0.2506, Val MAE: 0.1065
# Test RMSE: 0.3351, Test MAE: 0.1479
# ---------------------------------
# Model saved at epoch 102 with val RMSE 0.2506
# Patience grace period: 36
# ---------------------------------
# Epoch 103/500
# Train RMSE: 0.2515
# Val RMSE: 0.2506, Val MAE: 0.1065
# Test RMSE: 0.3353, Test MAE: 0.1480
# ---------------------------------
# Model saved at epoch 103 with val RMSE 0.2506
# Patience grace period: 35
# ---------------------------------
# Epoch 104/500
# Train RMSE: 0.2514
# Val RMSE: 0.2505, Val MAE: 0.1065
# Test RMSE: 0.3351, Test MAE: 0.1480
# ---------------------------------
# Model saved at epoch 104 with val RMSE 0.2505
# Patience grace period: 40
# ---------------------------------
# Epoch 105/500
# Train RMSE: 0.2515
# Val RMSE: 0.2505, Val MAE: 0.1062
# Test RMSE: 0.3357, Test MAE: 0.1478
# ---------------------------------
# Patience grace period: 38
# ---------------------------------
# Epoch 106/500
# Train RMSE: 0.2514
# Val RMSE: 0.2505, Val MAE: 0.1064
# Test RMSE: 0.3350, Test MAE: 0.1479
# ---------------------------------
# Model saved at epoch 106 with val RMSE 0.2505
# Patience grace period: 37
# ---------------------------------
# Epoch 107/500
# Train RMSE: 0.2514
# Val RMSE: 0.2505, Val MAE: 0.1063
# Test RMSE: 0.3356, Test MAE: 0.1480
# ---------------------------------
# Patience grace period: 35
# ---------------------------------
# Epoch 108/500
# Train RMSE: 0.2513
# Val RMSE: 0.2504, Val MAE: 0.1063
# Test RMSE: 0.3353, Test MAE: 0.1480
# ---------------------------------
# Model saved at epoch 108 with val RMSE 0.2504
# Patience grace period: 34
# ---------------------------------
# Epoch 109/500
# Train RMSE: 0.2513
# Val RMSE: 0.2504, Val MAE: 0.1064
# Test RMSE: 0.3352, Test MAE: 0.1480
# ---------------------------------
# Model saved at epoch 109 with val RMSE 0.2504
# Patience grace period: 33
# ---------------------------------
# Epoch 110/500
# Train RMSE: 0.2513
# Val RMSE: 0.2504, Val MAE: 0.1063
# Test RMSE: 0.3352, Test MAE: 0.1482
# ---------------------------------
# Model saved at epoch 110 with val RMSE 0.2504
# Patience grace period: 40
# ---------------------------------
# Epoch 111/500
# Train RMSE: 0.2513
# Val RMSE: 0.2504, Val MAE: 0.1063
# Test RMSE: 0.3355, Test MAE: 0.1480
# ---------------------------------
# Model saved at epoch 111 with val RMSE 0.2504
# Patience grace period: 39
# ---------------------------------
# Epoch 112/500
# Train RMSE: 0.2512
# Val RMSE: 0.2503, Val MAE: 0.1066
# Test RMSE: 0.3347, Test MAE: 0.1481
# ---------------------------------
# Model saved at epoch 112 with val RMSE 0.2503
# Patience grace period: 38
# ---------------------------------
# Epoch 113/500
# Train RMSE: 0.2512
# Val RMSE: 0.2503, Val MAE: 0.1065
# Test RMSE: 0.3342, Test MAE: 0.1479
# ---------------------------------
# Model saved at epoch 113 with val RMSE 0.2503
# Patience grace period: 40
# ---------------------------------
# Epoch 114/500
# Train RMSE: 0.2512
# Val RMSE: 0.2503, Val MAE: 0.1063
# Test RMSE: 0.3347, Test MAE: 0.1480
# ---------------------------------
# Patience grace period: 38
# ---------------------------------
# Epoch 115/500
# Train RMSE: 0.2512
# Val RMSE: 0.2503, Val MAE: 0.1063
# Test RMSE: 0.3352, Test MAE: 0.1481
# ---------------------------------
# Patience grace period: 36
# ---------------------------------
# Epoch 116/500
# Train RMSE: 0.2512
# Val RMSE: 0.2503, Val MAE: 0.1063
# Test RMSE: 0.3350, Test MAE: 0.1479
# ---------------------------------
# Model saved at epoch 116 with val RMSE 0.2503
# Patience grace period: 35
# ---------------------------------
# Epoch 117/500
# Train RMSE: 0.2512
# Val RMSE: 0.2503, Val MAE: 0.1065
# Test RMSE: 0.3348, Test MAE: 0.1482
# ---------------------------------
# Model saved at epoch 117 with val RMSE 0.2503
# Patience grace period: 34
# ---------------------------------
# Epoch 118/500
# Train RMSE: 0.2512
# Val RMSE: 0.2503, Val MAE: 0.1062
# Test RMSE: 0.3350, Test MAE: 0.1480
# ---------------------------------
# Model saved at epoch 118 with val RMSE 0.2503
# Patience grace period: 33
# ---------------------------------
# Epoch 119/500
# Train RMSE: 0.2511
# Val RMSE: 0.2502, Val MAE: 0.1063
# Test RMSE: 0.3352, Test MAE: 0.1482
# ---------------------------------
# Model saved at epoch 119 with val RMSE 0.2502
# Patience grace period: 31
# ---------------------------------
# Epoch 120/500
# Train RMSE: 0.2511
# Val RMSE: 0.2502, Val MAE: 0.1063
# Test RMSE: 0.3352, Test MAE: 0.1480
# ---------------------------------
# Model saved at epoch 120 with val RMSE 0.2502
# Patience grace period: 30
# ---------------------------------
# Epoch 121/500
# Train RMSE: 0.2511
# Val RMSE: 0.2502, Val MAE: 0.1064
# Test RMSE: 0.3346, Test MAE: 0.1480
# ---------------------------------
# Model saved at epoch 121 with val RMSE 0.2502
# Patience grace period: 40
# ---------------------------------
# Epoch 122/500
# Train RMSE: 0.2511
# Val RMSE: 0.2502, Val MAE: 0.1064
# Test RMSE: 0.3349, Test MAE: 0.1480
# ---------------------------------
# Model saved at epoch 122 with val RMSE 0.2502
# Patience grace period: 39
# ---------------------------------
# Epoch 123/500
# Train RMSE: 0.2511
# Val RMSE: 0.2502, Val MAE: 0.1062
# Test RMSE: 0.3354, Test MAE: 0.1480
# ---------------------------------
# Patience grace period: 37
# ---------------------------------
# Epoch 124/500
# Train RMSE: 0.2511
# Val RMSE: 0.2502, Val MAE: 0.1062
# Test RMSE: 0.3354, Test MAE: 0.1481
# ---------------------------------
# Patience grace period: 36
# ---------------------------------
# Epoch 125/500
# Train RMSE: 0.2510
# Val RMSE: 0.2501, Val MAE: 0.1062
# Test RMSE: 0.3350, Test MAE: 0.1481
# ---------------------------------
# Model saved at epoch 125 with val RMSE 0.2501
# Patience grace period: 35
# ---------------------------------
# Epoch 126/500
# Train RMSE: 0.2510
# Val RMSE: 0.2501, Val MAE: 0.1065
# Test RMSE: 0.3347, Test MAE: 0.1481
# ---------------------------------
# Model saved at epoch 126 with val RMSE 0.2501
# Patience grace period: 34
# ---------------------------------
# Epoch 127/500
# Train RMSE: 0.2510
# Val RMSE: 0.2501, Val MAE: 0.1063
# Test RMSE: 0.3349, Test MAE: 0.1482
# ---------------------------------
# Model saved at epoch 127 with val RMSE 0.2501
# Patience grace period: 32
# ---------------------------------
# Epoch 128/500
# Train RMSE: 0.2510
# Val RMSE: 0.2501, Val MAE: 0.1064
# Test RMSE: 0.3348, Test MAE: 0.1481
# ---------------------------------
# Model saved at epoch 128 with val RMSE 0.2501
# Patience grace period: 40
# ---------------------------------
# Epoch 129/500
# Train RMSE: 0.2509
# Val RMSE: 0.2501, Val MAE: 0.1063
# Test RMSE: 0.3350, Test MAE: 0.1481
# ---------------------------------
# Model saved at epoch 129 with val RMSE 0.2501
# Patience grace period: 39
# ---------------------------------
# Epoch 130/500
# Train RMSE: 0.2509
# Val RMSE: 0.2501, Val MAE: 0.1062
# Test RMSE: 0.3354, Test MAE: 0.1481
# ---------------------------------
# Patience grace period: 37
# ---------------------------------
# Epoch 131/500
# Train RMSE: 0.2510
# Val RMSE: 0.2501, Val MAE: 0.1063
# Test RMSE: 0.3350, Test MAE: 0.1482
# ---------------------------------
# Model saved at epoch 131 with val RMSE 0.2501
# Patience grace period: 36
# ---------------------------------
# Epoch 132/500
# Train RMSE: 0.2509
# Val RMSE: 0.2501, Val MAE: 0.1063
# Test RMSE: 0.3354, Test MAE: 0.1483
# ---------------------------------
# Patience grace period: 34
# ---------------------------------
# Epoch 133/500
# Train RMSE: 0.2509
# Val RMSE: 0.2500, Val MAE: 0.1061
# Test RMSE: 0.3353, Test MAE: 0.1480
# ---------------------------------
# Model saved at epoch 133 with val RMSE 0.2500
# Patience grace period: 33
# ---------------------------------
# Epoch 134/500
# Train RMSE: 0.2509
# Val RMSE: 0.2500, Val MAE: 0.1063
# Test RMSE: 0.3349, Test MAE: 0.1483
# ---------------------------------
# Model saved at epoch 134 with val RMSE 0.2500
# Patience grace period: 32
# ---------------------------------
# Epoch 135/500
# Train RMSE: 0.2509
# Val RMSE: 0.2500, Val MAE: 0.1060
# Test RMSE: 0.3356, Test MAE: 0.1479
# ---------------------------------
# Patience grace period: 30
# ---------------------------------
# Epoch 136/500
# Train RMSE: 0.2509
# Val RMSE: 0.2500, Val MAE: 0.1063
# Test RMSE: 0.3351, Test MAE: 0.1482
# ---------------------------------
# Model saved at epoch 136 with val RMSE 0.2500
# Patience grace period: 29
# ---------------------------------
# Epoch 137/500
# Train RMSE: 0.2509
# Val RMSE: 0.2500, Val MAE: 0.1063
# Test RMSE: 0.3350, Test MAE: 0.1483
# ---------------------------------
# Model saved at epoch 137 with val RMSE 0.2500
# Patience grace period: 28
# ---------------------------------
# Epoch 138/500
# Train RMSE: 0.2509
# Val RMSE: 0.2500, Val MAE: 0.1064
# Test RMSE: 0.3349, Test MAE: 0.1483
# ---------------------------------
# Model saved at epoch 138 with val RMSE 0.2500
# Patience grace period: 40
# ---------------------------------
# Epoch 139/500
# Train RMSE: 0.2508
# Val RMSE: 0.2500, Val MAE: 0.1062
# Test RMSE: 0.3350, Test MAE: 0.1482
# ---------------------------------
# Model saved at epoch 139 with val RMSE 0.2500
# Patience grace period: 38
# ---------------------------------
# Epoch 140/500
# Train RMSE: 0.2509
# Val RMSE: 0.2500, Val MAE: 0.1061
# Test RMSE: 0.3351, Test MAE: 0.1482
# ---------------------------------
# Patience grace period: 36
# ---------------------------------
# Epoch 141/500
# Train RMSE: 0.2508
# Val RMSE: 0.2499, Val MAE: 0.1064
# Test RMSE: 0.3347, Test MAE: 0.1484
# ---------------------------------
# Model saved at epoch 141 with val RMSE 0.2499
# Patience grace period: 35
# ---------------------------------
# Epoch 142/500
# Train RMSE: 0.2508
# Val RMSE: 0.2499, Val MAE: 0.1065
# Test RMSE: 0.3346, Test MAE: 0.1484
# ---------------------------------
# Model saved at epoch 142 with val RMSE 0.2499
# Patience grace period: 34
# ---------------------------------
# Epoch 143/500
# Train RMSE: 0.2508
# Val RMSE: 0.2499, Val MAE: 0.1064
# Test RMSE: 0.3347, Test MAE: 0.1485
# ---------------------------------
# Patience grace period: 32
# ---------------------------------
# Epoch 144/500
# Train RMSE: 0.2508
# Val RMSE: 0.2499, Val MAE: 0.1061
# Test RMSE: 0.3350, Test MAE: 0.1483
# ---------------------------------
# Patience grace period: 30
# ---------------------------------
# Epoch 145/500
# Train RMSE: 0.2508
# Val RMSE: 0.2499, Val MAE: 0.1064
# Test RMSE: 0.3346, Test MAE: 0.1486
# ---------------------------------
# Model saved at epoch 145 with val RMSE 0.2499
# Patience grace period: 29
# ---------------------------------
# Epoch 146/500
# Train RMSE: 0.2508
# Val RMSE: 0.2499, Val MAE: 0.1062
# Test RMSE: 0.3351, Test MAE: 0.1484
# ---------------------------------
# Patience grace period: 27
# ---------------------------------
# Epoch 147/500
# Train RMSE: 0.2508
# Val RMSE: 0.2499, Val MAE: 0.1063
# Test RMSE: 0.3349, Test MAE: 0.1482
# ---------------------------------
# Model saved at epoch 147 with val RMSE 0.2499
# Patience grace period: 40
# ---------------------------------
# Epoch 148/500
# Train RMSE: 0.2507
# Val RMSE: 0.2499, Val MAE: 0.1061
# Test RMSE: 0.3354, Test MAE: 0.1484
# ---------------------------------
# Patience grace period: 38
# ---------------------------------
# Epoch 149/500
# Train RMSE: 0.2507
# Val RMSE: 0.2499, Val MAE: 0.1062
# Test RMSE: 0.3349, Test MAE: 0.1482
# ---------------------------------
# Patience grace period: 37
# ---------------------------------
# Epoch 150/500
# Train RMSE: 0.2507
# Val RMSE: 0.2498, Val MAE: 0.1064
# Test RMSE: 0.3343, Test MAE: 0.1484
# ---------------------------------
# Model saved at epoch 150 with val RMSE 0.2498
# Patience grace period: 36
# ---------------------------------
# Epoch 151/500
# Train RMSE: 0.2507
# Val RMSE: 0.2498, Val MAE: 0.1061
# Test RMSE: 0.3354, Test MAE: 0.1484
# ---------------------------------
# Patience grace period: 34
# ---------------------------------
# Epoch 152/500
# Train RMSE: 0.2507
# Val RMSE: 0.2498, Val MAE: 0.1063
# Test RMSE: 0.3347, Test MAE: 0.1485
# ---------------------------------
# Model saved at epoch 152 with val RMSE 0.2498
# Patience grace period: 33
# ---------------------------------
# Epoch 153/500
# Train RMSE: 0.2507
# Val RMSE: 0.2498, Val MAE: 0.1061
# Test RMSE: 0.3349, Test MAE: 0.1485
# ---------------------------------
# Patience grace period: 31
# ---------------------------------
# Epoch 154/500
# Train RMSE: 0.2507
# Val RMSE: 0.2498, Val MAE: 0.1064
# Test RMSE: 0.3345, Test MAE: 0.1485
# ---------------------------------
# Model saved at epoch 154 with val RMSE 0.2498
# Patience grace period: 30
# ---------------------------------
# Epoch 155/500
# Train RMSE: 0.2507
# Val RMSE: 0.2498, Val MAE: 0.1060
# Test RMSE: 0.3353, Test MAE: 0.1482
# ---------------------------------
# Patience grace period: 28
# ---------------------------------
# Epoch 156/500
# Train RMSE: 0.2506
# Val RMSE: 0.2498, Val MAE: 0.1063
# Test RMSE: 0.3348, Test MAE: 0.1486
# ---------------------------------
# Model saved at epoch 156 with val RMSE 0.2498
# Patience grace period: 27
# ---------------------------------
# Epoch 157/500
# Train RMSE: 0.2507
# Val RMSE: 0.2497, Val MAE: 0.1063
# Test RMSE: 0.3343, Test MAE: 0.1485
# ---------------------------------
# Model saved at epoch 157 with val RMSE 0.2497
# Patience grace period: 40
# ---------------------------------
# Epoch 158/500
# Train RMSE: 0.2506
# Val RMSE: 0.2497, Val MAE: 0.1063
# Test RMSE: 0.3348, Test MAE: 0.1486
# ---------------------------------
# Model saved at epoch 158 with val RMSE 0.2497
# Patience grace period: 38
# ---------------------------------
# Epoch 159/500
# Train RMSE: 0.2506
# Val RMSE: 0.2497, Val MAE: 0.1064
# Test RMSE: 0.3342, Test MAE: 0.1487
# ---------------------------------
# Model saved at epoch 159 with val RMSE 0.2497
# Patience grace period: 37
# ---------------------------------
# Epoch 160/500
# Train RMSE: 0.2506
# ...
# Epoch 195/500
# Train RMSE: 0.2504
# Val RMSE: 0.2494, Val MAE: 0.1063
# Test RMSE: 0.3336, Test MAE: 0.1486
# ---------------------------------
# Model saved at epoch 195 with val RMSE 0.2494
# Patience grace period: 40
# ---------------------------------
# Epoch 196/500
# Train RMSE: 0.2503
# Val RMSE: 0.2494, Val MAE: 0.1062
# Test RMSE: 0.3337, Test MAE: 0.1487
# ---------------------------------
# Patience grace period: 38
# ---------------------------------
# Epoch 197/500
# Train RMSE: 0.2504
# Val RMSE: 0.2494, Val MAE: 0.1060
# Test RMSE: 0.3342, Test MAE: 0.1485
# ---------------------------------
# Patience grace period: 36
# ---------------------------------
# Epoch 198/500
# Train RMSE: 0.2503
# Val RMSE: 0.2494, Val MAE: 0.1059
# Test RMSE: 0.3343, Test MAE: 0.1485
# ---------------------------------
# Patience grace period: 34
# ---------------------------------
# Epoch 199/500
# Train RMSE: 0.2503
# Val RMSE: 0.2493, Val MAE: 0.1062
# Test RMSE: 0.3336, Test MAE: 0.1487
# ---------------------------------
# Model saved at epoch 199 with val RMSE 0.2493
# Patience grace period: 33
# ---------------------------------
# Epoch 200/500
# Train RMSE: 0.2503
# Val RMSE: 0.2494, Val MAE: 0.1061
# Test RMSE: 0.3339, Test MAE: 0.1487
# ---------------------------------
# Patience grace period: 31
# ---------------------------------
# Epoch 201/500
# Train RMSE: 0.2503
# Val RMSE: 0.2493, Val MAE: 0.1062
# Test RMSE: 0.3334, Test MAE: 0.1487
# ---------------------------------
# Model saved at epoch 201 with val RMSE 0.2493
# Patience grace period: 30
# ---------------------------------
# Epoch 202/500
# Train RMSE: 0.2503
# Val RMSE: 0.2493, Val MAE: 0.1062
# Test RMSE: 0.3331, Test MAE: 0.1485
# ---------------------------------
# Model saved at epoch 202 with val RMSE 0.2493
# Patience grace period: 29
# ---------------------------------
# Epoch 203/500
# Train RMSE: 0.2503
# Val RMSE: 0.2493, Val MAE: 0.1062
# Test RMSE: 0.3336, Test MAE: 0.1488
# ---------------------------------
# Patience grace period: 27
# ---------------------------------
# Epoch 204/500
# Train RMSE: 0.2503
# Val RMSE: 0.2493, Val MAE: 0.1061
# Test RMSE: 0.3334, Test MAE: 0.1487
# ---------------------------------
# Patience grace period: 25
# ---------------------------------
# Epoch 205/500
# Train RMSE: 0.2502
# Val RMSE: 0.2493, Val MAE: 0.1062
# Test RMSE: 0.3335, Test MAE: 0.1488
# ---------------------------------
# Model saved at epoch 205 with val RMSE 0.2493
# Patience grace period: 24
# ---------------------------------
# Epoch 206/500
# Train RMSE: 0.2502
# Val RMSE: 0.2493, Val MAE: 0.1061
# Test RMSE: 0.3335, Test MAE: 0.1488
# ---------------------------------
# Patience grace period: 22
# ---------------------------------
# Epoch 207/500
# Train RMSE: 0.2502
# Val RMSE: 0.2493, Val MAE: 0.1062
# Test RMSE: 0.3333, Test MAE: 0.1489
# ---------------------------------
# Model saved at epoch 207 with val RMSE 0.2493
# Patience grace period: 21
# ---------------------------------
# Epoch 208/500
# Train RMSE: 0.2502
# Val RMSE: 0.2493, Val MAE: 0.1062
# Test RMSE: 0.3332, Test MAE: 0.1487
# ---------------------------------
# Model saved at epoch 208 with val RMSE 0.2493
# Patience grace period: 20
# ---------------------------------
# Epoch 209/500
# Train RMSE: 0.2502
# Val RMSE: 0.2493, Val MAE: 0.1061
# Test RMSE: 0.3336, Test MAE: 0.1487
# ---------------------------------
# Patience grace period: 18
# ---------------------------------
# Epoch 210/500
# Train RMSE: 0.2502
# Val RMSE: 0.2493, Val MAE: 0.1061
# Test RMSE: 0.3334, Test MAE: 0.1488
# ---------------------------------
# Model saved at epoch 210 with val RMSE 0.2493
# Patience grace period: 17
# ---------------------------------
# Epoch 211/500
# Train RMSE: 0.2502
# Val RMSE: 0.2493, Val MAE: 0.1062
# Test RMSE: 0.3333, Test MAE: 0.1488
# ---------------------------------
# Patience grace period: 15
# ---------------------------------
# Epoch 212/500
# Train RMSE: 0.2502
# Val RMSE: 0.2492, Val MAE: 0.1062
# Test RMSE: 0.3328, Test MAE: 0.1489
# ---------------------------------
# Model saved at epoch 212 with val RMSE 0.2492
# Patience grace period: 40
# ---------------------------------
# Epoch 213/500
# Train RMSE: 0.2502
# Val RMSE: 0.2492, Val MAE: 0.1063
# Test RMSE: 0.3323, Test MAE: 0.1488
# ---------------------------------
# Model saved at epoch 213 with val RMSE 0.2492
# Patience grace period: 39
# ---------------------------------
# Epoch 214/500
# Train RMSE: 0.2501
# Val RMSE: 0.2492, Val MAE: 0.1061
# Test RMSE: 0.3332, Test MAE: 0.1488
# ---------------------------------
# Patience grace period: 37
# ---------------------------------
# Epoch 215/500
# Train RMSE: 0.2502
# Val RMSE: 0.2493, Val MAE: 0.1059
# Test RMSE: 0.3338, Test MAE: 0.1488
# ---------------------------------
# Patience grace period: 35
# ---------------------------------
# Epoch 216/500
# Train RMSE: 0.2502
# Val RMSE: 0.2492, Val MAE: 0.1063
# Test RMSE: 0.3326, Test MAE: 0.1491
# ---------------------------------
# Patience grace period: 34
# ---------------------------------
# Epoch 217/500
# Train RMSE: 0.2501
# Val RMSE: 0.2492, Val MAE: 0.1061
# Test RMSE: 0.3330, Test MAE: 0.1489
# ---------------------------------
# Patience grace period: 32
# ---------------------------------
# Epoch 218/500
# Train RMSE: 0.2502
# Val RMSE: 0.2492, Val MAE: 0.1061
# Test RMSE: 0.3332, Test MAE: 0.1488
# ---------------------------------
# Patience grace period: 31
# ---------------------------------
# Epoch 219/500
# Train RMSE: 0.2502
# Val RMSE: 0.2492, Val MAE: 0.1063
# Test RMSE: 0.3328, Test MAE: 0.1490
# ---------------------------------
# Model saved at epoch 219 with val RMSE 0.2492
# Patience grace period: 30
# ---------------------------------
# Epoch 220/500
# Train RMSE: 0.2501
# Val RMSE: 0.2492, Val MAE: 0.1063
# Test RMSE: 0.3326, Test MAE: 0.1489
# ---------------------------------
# Model saved at epoch 220 with val RMSE 0.2492
# Patience grace period: 29
# ---------------------------------
# Epoch 221/500
# Train RMSE: 0.2501
# Val RMSE: 0.2492, Val MAE: 0.1061
# Test RMSE: 0.3332, Test MAE: 0.1488
# ---------------------------------
# Patience grace period: 27
# ---------------------------------
# Epoch 222/500
# Train RMSE: 0.2501
# Val RMSE: 0.2492, Val MAE: 0.1060
# Test RMSE: 0.3333, Test MAE: 0.1488
# ---------------------------------
# Patience grace period: 26
# ---------------------------------
# Epoch 223/500
# Train RMSE: 0.2501
# Val RMSE: 0.2492, Val MAE: 0.1061
# Test RMSE: 0.3330, Test MAE: 0.1489
# ---------------------------------
# Patience grace period: 24
# ---------------------------------
# Epoch 224/500
# Train RMSE: 0.2501
# Val RMSE: 0.2492, Val MAE: 0.1061
# Test RMSE: 0.3326, Test MAE: 0.1487
# ---------------------------------
# Model saved at epoch 224 with val RMSE 0.2492
# Patience grace period: 23
# ---------------------------------
# Epoch 225/500
# Train RMSE: 0.2501
# Val RMSE: 0.2492, Val MAE: 0.1062
# Test RMSE: 0.3328, Test MAE: 0.1491
# ---------------------------------
# Patience grace period: 21
# ---------------------------------
# Epoch 226/500
# Train RMSE: 0.2501
# Val RMSE: 0.2492, Val MAE: 0.1062
# Test RMSE: 0.3323, Test MAE: 0.1490
# ---------------------------------
# Model saved at epoch 226 with val RMSE 0.2492
# Patience grace period: 20
# ---------------------------------
# Epoch 227/500
# Train RMSE: 0.2501
# Val RMSE: 0.2492, Val MAE: 0.1060
# Test RMSE: 0.3329, Test MAE: 0.1490
# ---------------------------------
# Patience grace period: 18
# ---------------------------------
# Epoch 228/500
# Train RMSE: 0.2501
# Val RMSE: 0.2492, Val MAE: 0.1062
# Test RMSE: 0.3324, Test MAE: 0.1489
# ---------------------------------
# Model saved at epoch 228 with val RMSE 0.2492
# Patience grace period: 17
# ---------------------------------
# Epoch 229/500
# Train RMSE: 0.2501
# Val RMSE: 0.2492, Val MAE: 0.1061
# Test RMSE: 0.3326, Test MAE: 0.1490
# ---------------------------------
# Patience grace period: 15
# ---------------------------------
# Epoch 230/500
# Train RMSE: 0.2501
# Val RMSE: 0.2492, Val MAE: 0.1060
# Test RMSE: 0.3330, Test MAE: 0.1488
# ---------------------------------
# Patience grace period: 13
# ---------------------------------
# Epoch 231/500
# Train RMSE: 0.2501
# Val RMSE: 0.2492, Val MAE: 0.1059
# Test RMSE: 0.3328, Test MAE: 0.1490
# ---------------------------------
# Patience grace period: 11
# ---------------------------------
# Epoch 232/500
# Train RMSE: 0.2501
# Val RMSE: 0.2492, Val MAE: 0.1061
# Test RMSE: 0.3329, Test MAE: 0.1490
# ---------------------------------
# Patience grace period: 9
# ---------------------------------
# Epoch 233/500
# Train RMSE: 0.2501
# Val RMSE: 0.2492, Val MAE: 0.1060
# Test RMSE: 0.3332, Test MAE: 0.1489
# ---------------------------------
# Patience grace period: 7
# ---------------------------------
# Epoch 234/500
# Train RMSE: 0.2501
# Val RMSE: 0.2492, Val MAE: 0.1061
# Test RMSE: 0.3325, Test MAE: 0.1491
# ---------------------------------
# Model saved at epoch 234 with val RMSE 0.2492
# Patience grace period: 6
# ---------------------------------
# Epoch 235/500
# Train RMSE: 0.2500
# Val RMSE: 0.2492, Val MAE: 0.1061
# Test RMSE: 0.3327, Test MAE: 0.1491
# ---------------------------------
# Patience grace period: 4
# ---------------------------------
# Epoch 236/500
# Train RMSE: 0.2500
# Val RMSE: 0.2491, Val MAE: 0.1062
# Test RMSE: 0.3322, Test MAE: 0.1490
# ---------------------------------
# Model saved at epoch 236 with val RMSE 0.2491
# Patience grace period: 40
# ---------------------------------
# Epoch 237/500
# Train RMSE: 0.2500
# Val RMSE: 0.2492, Val MAE: 0.1060
# Test RMSE: 0.3326, Test MAE: 0.1491
# ---------------------------------
# Patience grace period: 38
# ---------------------------------
# Epoch 238/500
# Train RMSE: 0.2501
# Val RMSE: 0.2491, Val MAE: 0.1061
# Test RMSE: 0.3320, Test MAE: 0.1490
# ---------------------------------
# Patience grace period: 37
# ---------------------------------
# Epoch 239/500
# Train RMSE: 0.2501
# Val RMSE: 0.2491, Val MAE: 0.1060
# Test RMSE: 0.3327, Test MAE: 0.1490
# ---------------------------------
# Patience grace period: 35
# ---------------------------------
# Epoch 240/500
# Train RMSE: 0.2500
# Val RMSE: 0.2491, Val MAE: 0.1061
# Test RMSE: 0.3323, Test MAE: 0.1490
# ---------------------------------
# Model saved at epoch 240 with val RMSE 0.2491
# Patience grace period: 34
# ---------------------------------
# Epoch 241/500
# Train RMSE: 0.2500
# Val RMSE: 0.2491, Val MAE: 0.1060
# Test RMSE: 0.3328, Test MAE: 0.1491
# ---------------------------------
# Patience grace period: 32
# ---------------------------------
# Epoch 242/500
# Train RMSE: 0.2500
# Val RMSE: 0.2491, Val MAE: 0.1061
# Test RMSE: 0.3322, Test MAE: 0.1489
# ---------------------------------
# Model saved at epoch 242 with val RMSE 0.2491
# Patience grace period: 31
# ---------------------------------
# Epoch 243/500
# Train RMSE: 0.2500
# Val RMSE: 0.2491, Val MAE: 0.1060
# Test RMSE: 0.3324, Test MAE: 0.1489
# ---------------------------------
# Patience grace period: 29
# ---------------------------------
# Epoch 244/500
# Train RMSE: 0.2500
# Val RMSE: 0.2491, Val MAE: 0.1062
# Test RMSE: 0.3323, Test MAE: 0.1490
# ---------------------------------
# Model saved at epoch 244 with val RMSE 0.2491
# Patience grace period: 28
# ---------------------------------
# Epoch 245/500
# Train RMSE: 0.2500
# Val RMSE: 0.2491, Val MAE: 0.1061
# Test RMSE: 0.3324, Test MAE: 0.1491
# ---------------------------------
# Patience grace period: 26
# ---------------------------------
# Epoch 246/500
# Train RMSE: 0.2500
# Val RMSE: 0.2491, Val MAE: 0.1061
# Test RMSE: 0.3321, Test MAE: 0.1491
# ---------------------------------
# Model saved at epoch 246 with val RMSE 0.2491
# Patience grace period: 25
# ---------------------------------
# Epoch 247/500
# Train RMSE: 0.2500
# Val RMSE: 0.2491, Val MAE: 0.1059
# Test RMSE: 0.3326, Test MAE: 0.1490
# ---------------------------------
# Patience grace period: 23
# ---------------------------------
# Epoch 248/500
# Train RMSE: 0.2499
# Val RMSE: 0.2491, Val MAE: 0.1061
# Test RMSE: 0.3321, Test MAE: 0.1490
# ---------------------------------
# Model saved at epoch 248 with val RMSE 0.2491
# Patience grace period: 22
# ---------------------------------
# Epoch 249/500
# Train RMSE: 0.2500
# Val RMSE: 0.2491, Val MAE: 0.1062
# Test RMSE: 0.3322, Test MAE: 0.1491
# ---------------------------------
# Patience grace period: 20
# ---------------------------------
# Epoch 250/500
# Train RMSE: 0.2500
# Val RMSE: 0.2491, Val MAE: 0.1063
# Test RMSE: 0.3314, Test MAE: 0.1493
# ---------------------------------
# Model saved at epoch 250 with val RMSE 0.2491
# Patience grace period: 19
# ---------------------------------
# Epoch 251/500
# Train RMSE: 0.2499
# Val RMSE: 0.2491, Val MAE: 0.1061
# Test RMSE: 0.3320, Test MAE: 0.1491
# ---------------------------------
# Patience grace period: 17
# ---------------------------------
# Epoch 252/500
# Train RMSE: 0.2500
# Val RMSE: 0.2491, Val MAE: 0.1060
# Test RMSE: 0.3321, Test MAE: 0.1491
# ---------------------------------
# Patience grace period: 15
# ---------------------------------
# Epoch 253/500
# Train RMSE: 0.2499
# Val RMSE: 0.2491, Val MAE: 0.1063
# Test RMSE: 0.3316, Test MAE: 0.1491
# ---------------------------------
# Model saved at epoch 253 with val RMSE 0.2491
# Patience grace period: 14
# ---------------------------------
# Epoch 254/500
# Train RMSE: 0.2499
# Val RMSE: 0.2491, Val MAE: 0.1061
# Test RMSE: 0.3318, Test MAE: 0.1490
# ---------------------------------
# Patience grace period: 12
# ---------------------------------
# Epoch 255/500
# Train RMSE: 0.2499
# Val RMSE: 0.2491, Val MAE: 0.1060
# Test RMSE: 0.3320, Test MAE: 0.1491
# ---------------------------------
# Patience grace period: 10
# ---------------------------------
# Epoch 256/500
# Train RMSE: 0.2500
# Val RMSE: 0.2491, Val MAE: 0.1062
# Test RMSE: 0.3319, Test MAE: 0.1493
# ---------------------------------
# Model saved at epoch 256 with val RMSE 0.2491
# Patience grace period: 9
# ---------------------------------
# Epoch 257/500
# Train RMSE: 0.2499
# Val RMSE: 0.2491, Val MAE: 0.1061
# Test RMSE: 0.3322, Test MAE: 0.1492
# ---------------------------------
# Patience grace period: 7
# ---------------------------------
# Epoch 258/500
# Train RMSE: 0.2499
# Val RMSE: 0.2491, Val MAE: 0.1060
# Test RMSE: 0.3322, Test MAE: 0.1491
# ---------------------------------
# Patience grace period: 6
# ---------------------------------
# Epoch 259/500
# Train RMSE: 0.2499
# Val RMSE: 0.2491, Val MAE: 0.1061
# Test RMSE: 0.3316, Test MAE: 0.1490
# ---------------------------------
# Patience grace period: 5
# ---------------------------------
# Epoch 260/500
# Train RMSE: 0.2499
# Val RMSE: 0.2491, Val MAE: 0.1062
# Test RMSE: 0.3317, Test MAE: 0.1492
# ---------------------------------
# Model saved at epoch 260 with val RMSE 0.2491
# Patience grace period: 4
# ---------------------------------
# Epoch 261/500
# Train RMSE: 0.2499
# Val RMSE: 0.2491, Val MAE: 0.1061
# Test RMSE: 0.3315, Test MAE: 0.1493
# ---------------------------------
# Patience grace period: 2
# ---------------------------------
# Epoch 262/500
# Train RMSE: 0.2499
# Val RMSE: 0.2491, Val MAE: 0.1060
# Test RMSE: 0.3322, Test MAE: 0.1492
# ---------------------------------
# Patience grace period: 0
# Early stopping triggered at epoch 262
# Final Test RMSE: 0.3317, Final Test MAE: 0.1492
# <ipython-input-3-2a228d64b832>:126: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   self.model.load_state_dict(torch.load(os.path.join(save_dir, 'best_model.pth')))
# Pearson Corr: 0.7456589937020245
# Spearman Corr: 0.427913122565162
# p-rmse: 0.33167782093026504
#        rmse       mae  seed                             subtask    method  \
# 0  0.331678  0.149194     5  openproblems_bmmc_cite_phase2_mod2  original
#
#     pearson p_value_pearson  spearman p_value_spearman
# 0  0.745659          0.0000  0.427913           0.0000

# %%
config_hierachical_PROTEIN = {
    "subtask": "openproblems_bmmc_cite_phase2_mod2",
    "batch_size": 520,
    "act": "relu",
    "conv_flow": ["gat"],
    "agg_flow": [None],
    "device": "cuda",
    "learning_rate": 0.000064,
    "hidden_size": 280,
    "num_heads": 6,
    "n_neigbours": 3,
    "metric": "euclidean",
    "n_components": 1200,
    "dropout_rate": 0.2,
    "num_epochs": 500,
    "seed": 1,
    "es_patience": 40,
    "es_min_delta": 0.0001,
    "es_rate_threshold": 0.00002,
    "layer_dim_ex": 3,
    "verbose": True,
    "sample": True,
    "preprocessing_type": "None",
    "variant": "no_residual",
    "num_clusters": 10
}

pipeline(**config_hierachical_PROTEIN)
# Out:
# [INFO][2025-04-15 20:22:58,099][dance][_load_raw_data] Loading /content/data/openproblems_bmmc_cite_phase2_mod2/openproblems_bmmc_cite_phase2_mod2.censor_dataset.output_train_mod1.h5ad
# Initializing pipeline...
# [INFO][2025-04-15 20:22:58,749][dance][_load_raw_data] Loading /content/data/openproblems_bmmc_cite_phase2_mod2/openproblems_bmmc_cite_phase2_mod2.censor_dataset.output_train_mod2.h5ad
# [INFO][2025-04-15 20:23:06,437][dance][_load_raw_data] Loading /content/data/openproblems_bmmc_cite_phase2_mod2/openproblems_bmmc_cite_phase2_mod2.censor_dataset.output_test_mod1.h5ad
# [INFO][2025-04-15 20:23:06,461][dance][_load_raw_data] Loading /content/data/openproblems_bmmc_cite_phase2_mod2/openproblems_bmmc_cite_phase2_mod2.censor_dataset.output_test_mod2.h5ad
# [INFO][2025-04-15 20:23:06,661][dance][_maybe_preprocess] Preprocessing done.
# /usr/local/lib/python3.11/dist-packages/mudata/_core/mudata.py:1531: FutureWarning: From 0.4 .update() will not pull obs/var columns from individual modalities by default anymore. Set mudata.set_options(pull_on_update=False) to adopt the new behaviour, which will become the default. Use new pull_obs/pull_var and push_obs/push_var methods for more flexibility.
#   self._update_attr("var", axis=0, join_common=join_common)
# /usr/local/lib/python3.11/dist-packages/mudata/_core/mudata.py:931: UserWarning: Cannot join columns with the same name because var_names are intersecting.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/mudata/_core/mudata.py:1429: FutureWarning: From 0.4 .update() will not pull obs/var columns from individual modalities by default anymore. Set mudata.set_options(pull_on_update=False) to adopt the new behaviour, which will become the default. Use new pull_obs/pull_var and push_obs/push_var methods for more flexibility.
#   self._update_attr("obs", axis=1, join_common=join_common)
# /usr/local/lib/python3.11/dist-packages/mudata/_core/mudata.py:1558: UserWarning: Modality names will be prepended to var_names since there are identical var_names in different modalities.
#   warnings.warn(
# [INFO][2025-04-15 20:23:14,011][dance][set_config_from_dict] Setting config 'feature_mod' to 'mod1'
# [INFO][2025-04-15 20:23:14,011][dance][set_config_from_dict] Setting config 'label_mod' to 'mod2'
# [INFO][2025-04-15 20:23:14,012][dance][load_data] Raw data loaded:
# Data object that wraps (.data):
# MuData object with n_obs × n_vars = 67175 × 14087
#   uns:	'dance_config'
#   2 modalities
#     mod1:	67175 x 134
#       obs:	'batch'
#       layers:	'counts'
#     mod2:	67175 x 13953
#       obs:	'batch'
#       layers:	'counts'
# [INFO][2025-04-15 20:23:14,134][dance][wrapped_func] Took 0:00:16.035441 to load and process data.
# <ipython-input-4-038168299b8a>:42: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   data.data.uns['gtrain'] = torch.load(train_graph_path)
# <ipython-input-4-038168299b8a>:43: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   data.data.uns['gval'] = torch.load(val_graph_path)
# <ipython-input-4-038168299b8a>:44: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   data.data.uns['gtest'] = torch.load(test_graph_path)
# <ipython-input-4-038168299b8a>:45: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   train_label = torch.load(train_label_path).numpy()
# Processed data found. Loading...
# <ipython-input-4-038168299b8a>:46: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   val_label = torch.load(val_label_path).numpy()
# <ipython-input-4-038168299b8a>:47: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   test_label = torch.load(test_label_path).numpy()
# <ipython-input-4-038168299b8a>:48: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   kwargs["FEATURE_SIZE"] = torch.load(feature_size_path).item()
# <ipython-input-4-038168299b8a>:49: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   kwargs["OUTPUT_SIZE"] = torch.load(output_size_path).item()
# Processed data loaded.
# ---------------------------------
# Epoch 1/500
# Train RMSE: 0.3804
# Val RMSE: 0.3305, Val MAE: 0.1352
# Test RMSE: 0.4104, Test MAE: 0.1800
# ---------------------------------
# Model saved at epoch 1 with val RMSE 0.3305
# Patience grace period: 40
# ---------------------------------
# Epoch 2/500
# Train RMSE: 0.3321
# Val RMSE: 0.3000, Val MAE: 0.1283
# Test RMSE: 0.3785, Test MAE: 0.1692
# ---------------------------------
# Model saved at epoch 2 with val RMSE 0.3000
# Patience grace period: 40
# ---------------------------------
# Epoch 3/500
# Train RMSE: 0.3083
# Val RMSE: 0.2827, Val MAE: 0.1216
# Test RMSE: 0.3627, Test MAE: 0.1615
# ---------------------------------
# Model saved at epoch 3 with val RMSE 0.2827
# Patience grace period: 40
# ---------------------------------
# Epoch 4/500
# Train RMSE: 0.2931
# Val RMSE: 0.2735, Val MAE: 0.1179
# Test RMSE: 0.3536, Test MAE: 0.1573
# ---------------------------------
# Model saved at epoch 4 with val RMSE 0.2735
# Patience grace period: 40
# ---------------------------------
# Epoch 5/500
# Train RMSE: 0.2837
# Val RMSE: 0.2688, Val MAE: 0.1161
# Test RMSE: 0.3483, Test MAE: 0.1556
# ---------------------------------
# Model saved at epoch 5 with val RMSE 0.2688
# Patience grace period: 40
# ---------------------------------
# Epoch 6/500
# Train RMSE: 0.2773
# Val RMSE: 0.2653, Val MAE: 0.1146
# Test RMSE: 0.3438, Test MAE: 0.1539
# ---------------------------------
# Model saved at epoch 6 with val RMSE 0.2653
# Patience grace period: 40
# ---------------------------------
# Epoch 7/500
# Train RMSE: 0.2724
# Val RMSE: 0.2625, Val MAE: 0.1134
# Test RMSE: 0.3400, Test MAE: 0.1526
# ---------------------------------
# Model saved at epoch 7 with val RMSE 0.2625
# Patience grace period: 40
# ---------------------------------
# Epoch 8/500
# Train RMSE: 0.2686
# Val RMSE: 0.2605, Val MAE: 0.1120
# Test RMSE: 0.3380, Test MAE: 0.1514
# ---------------------------------
# Model saved at epoch 8 with val RMSE 0.2605
# Patience grace period: 40
# ---------------------------------
# Epoch 9/500
# Train RMSE: 0.2657
# Val RMSE: 0.2586, Val MAE: 0.1115
# Test RMSE: 0.3347, Test MAE: 0.1514
# ---------------------------------
# Model saved at epoch 9 with val RMSE 0.2586
# Patience grace period: 40
# ---------------------------------
# Epoch 10/500
# Train RMSE: 0.2636
# Val RMSE: 0.2576, Val MAE: 0.1105
# Test RMSE: 0.3340, Test MAE: 0.1509
# ---------------------------------
# Model saved at epoch 10 with val RMSE 0.2576
# Patience grace period: 40
# ---------------------------------
# Epoch 11/500
# Train RMSE: 0.2620
# Val RMSE: 0.2567, Val MAE: 0.1101
# Test RMSE: 0.3331, Test MAE: 0.1509
# ---------------------------------
# Model saved at epoch 11 with val RMSE 0.2567
# Patience grace period: 40
# ---------------------------------
# Epoch 12/500
# Train RMSE: 0.2608
# Val RMSE: 0.2559, Val MAE: 0.1101
# Test RMSE: 0.3319, Test MAE: 0.1511
# ---------------------------------
# Model saved at epoch 12 with val RMSE 0.2559
# Patience grace period: 40
# ---------------------------------
# Epoch 13/500
# Train RMSE: 0.2598
# Val RMSE: 0.2555, Val MAE: 0.1090
# Test RMSE: 0.3319, Test MAE: 0.1504
# ---------------------------------
# Model saved at epoch 13 with val RMSE 0.2555
# Patience grace period: 40
# ---------------------------------
# Epoch 14/500
# Train RMSE: 0.2590
# Val RMSE: 0.2548, Val MAE: 0.1099
# Test RMSE: 0.3301, Test MAE: 0.1512
# ---------------------------------
# Model saved at epoch 14 with val RMSE 0.2548
# Patience grace period: 40
# ---------------------------------
# Epoch 15/500
# Train RMSE: 0.2584
# Val RMSE: 0.2546, Val MAE: 0.1088
# Test RMSE: 0.3307, Test MAE: 0.1504
# ---------------------------------
# Model saved at epoch 15 with val RMSE 0.2546
# Patience grace period: 40
# ---------------------------------
# Epoch 16/500
# Train RMSE: 0.2578
# Val RMSE: 0.2542, Val MAE: 0.1088
# Test RMSE: 0.3301, Test MAE: 0.1506
# ---------------------------------
# Model saved at epoch 16 with val RMSE 0.2542
# Patience grace period: 40
# ---------------------------------
# Epoch 17/500
# Train RMSE: 0.2573
# Val RMSE: 0.2537, Val MAE: 0.1093
# Test RMSE: 0.3289, Test MAE: 0.1511
# ---------------------------------
# Model saved at epoch 17 with val RMSE 0.2537
# Patience grace period: 40
# ---------------------------------
# Epoch 18/500
# Train RMSE: 0.2569
# Val RMSE: 0.2536, Val MAE: 0.1086
# Test RMSE: 0.3296, Test MAE: 0.1505
# ---------------------------------
# Model saved at epoch 18 with val RMSE 0.2536
# Patience grace period: 40
# ---------------------------------
# Epoch 19/500
# Train RMSE: 0.2564
# Val RMSE: 0.2533, Val MAE: 0.1084
# Test RMSE: 0.3289, Test MAE: 0.1506
# ---------------------------------
# Model saved at epoch 19 with val RMSE 0.2533
# Patience grace period: 40
# ---------------------------------
# Epoch 20/500
# Train RMSE: 0.2561
# Val RMSE: 0.2529, Val MAE: 0.1089
# Test RMSE: 0.3281, Test MAE: 0.1509
# ---------------------------------
# Model saved at epoch 20 with val RMSE 0.2529
# Patience grace period: 40
# ---------------------------------
# Epoch 21/500
# Train RMSE: 0.2558
# Val RMSE: 0.2528, Val MAE: 0.1082
# Test RMSE: 0.3284, Test MAE: 0.1504
# ---------------------------------
# Model saved at epoch 21 with val RMSE 0.2528
# Patience grace period: 39
# ---------------------------------
# Epoch 22/500
# Train RMSE: 0.2554
# Val RMSE: 0.2525, Val MAE: 0.1083
# Test RMSE: 0.3280, Test MAE: 0.1505
# ---------------------------------
# Model saved at epoch 22 with val RMSE 0.2525
# Patience grace period: 40
# ---------------------------------
# Epoch 23/500
# Train RMSE: 0.2552
# Val RMSE: 0.2524, Val MAE: 0.1080
# Test RMSE: 0.3277, Test MAE: 0.1503
# ---------------------------------
# Model saved at epoch 23 with val RMSE 0.2524
# Patience grace period: 40
# ---------------------------------
# Epoch 24/500
# Train RMSE: 0.2549
# Val RMSE: 0.2523, Val MAE: 0.1076
# Test RMSE: 0.3282, Test MAE: 0.1497
# ---------------------------------
# Model saved at epoch 24 with val RMSE 0.2523
# Patience grace period: 39
# ---------------------------------
# Epoch 25/500
# Train RMSE: 0.2546
# Val RMSE: 0.2520, Val MAE: 0.1082
# Test RMSE: 0.3271, Test MAE: 0.1505
# ---------------------------------
# Model saved at epoch 25 with val RMSE 0.2520
# Patience grace period: 40
# ---------------------------------
# Epoch 26/500
# Train RMSE: 0.2544
# Val RMSE: 0.2518, Val MAE: 0.1080
# Test RMSE: 0.3268, Test MAE: 0.1505
# ---------------------------------
# Model saved at epoch 26 with val RMSE 0.2518
# Patience grace period: 40
# ---------------------------------
# Epoch 27/500
# Train RMSE: 0.2542
# Val RMSE: 0.2518, Val MAE: 0.1076
# Test RMSE: 0.3274, Test MAE: 0.1499
# ---------------------------------
# Model saved at epoch 27 with val RMSE 0.2518
# Patience grace period: 39
# ---------------------------------
# Epoch 28/500
# Train RMSE: 0.2540
# Val RMSE: 0.2516, Val MAE: 0.1079
# Test RMSE: 0.3266, Test MAE: 0.1503
# ---------------------------------
# Model saved at epoch 28 with val RMSE 0.2516
# Patience grace period: 40
# ---------------------------------
# Epoch 29/500
# Train RMSE: 0.2538
# Val RMSE: 0.2515, Val MAE: 0.1083
# Test RMSE: 0.3264, Test MAE: 0.1508
# ---------------------------------
# Model saved at epoch 29 with val RMSE 0.2515
# Patience grace period: 40
# ---------------------------------
# Epoch 30/500
# Train RMSE: 0.2536
# Val RMSE: 0.2514, Val MAE: 0.1076
# Test RMSE: 0.3266, Test MAE: 0.1500
# ---------------------------------
# Model saved at epoch 30 with val RMSE 0.2514
# Patience grace period: 40
# ---------------------------------
# Epoch 31/500
# Train RMSE: 0.2535
# Val RMSE: 0.2512, Val MAE: 0.1083
# Test RMSE: 0.3261, Test MAE: 0.1507
# ---------------------------------
# Model saved at epoch 31 with val RMSE 0.2512
# Patience grace period: 40
# ---------------------------------
# Epoch 32/500
# Train RMSE: 0.2533
# Val RMSE: 0.2511, Val MAE: 0.1077
# Test RMSE: 0.3263, Test MAE: 0.1501
# ---------------------------------
# Model saved at epoch 32 with val RMSE 0.2511
# Patience grace period: 40
# ---------------------------------
# Epoch 33/500
# Train RMSE: 0.2531
# Val RMSE: 0.2510, Val MAE: 0.1075
# Test RMSE: 0.3264, Test MAE: 0.1502
# ---------------------------------
# Model saved at epoch 33 with val RMSE 0.2510
# Patience grace period: 39
# ---------------------------------
# Epoch 34/500
# Train RMSE: 0.2529
# Val RMSE: 0.2509, Val MAE: 0.1074
# Test RMSE: 0.3267, Test MAE: 0.1498
# ---------------------------------
# Model saved at epoch 34 with val RMSE 0.2509
# Patience grace period: 40
# ---------------------------------
# Epoch 35/500
# Train RMSE: 0.2528
# Val RMSE: 0.2508, Val MAE: 0.1077
# Test RMSE: 0.3260, Test MAE: 0.1502
# ---------------------------------
# Model saved at epoch 35 with val RMSE 0.2508
# Patience grace period: 40
# ---------------------------------
# Epoch 36/500
# Train RMSE: 0.2527
# Val RMSE: 0.2507, Val MAE: 0.1078
# Test RMSE: 0.3261, Test MAE: 0.1502
# ---------------------------------
# Model saved at epoch 36 with val RMSE 0.2507
# Patience grace period: 40
# ---------------------------------
# Epoch 37/500
# Train RMSE: 0.2525
# Val RMSE: 0.2507, Val MAE: 0.1077
# Test RMSE: 0.3256, Test MAE: 0.1501
# ---------------------------------
# Model saved at epoch 37 with val RMSE 0.2507
# Patience grace period: 39
# ---------------------------------
# Epoch 38/500
# Train RMSE: 0.2524
# Val RMSE: 0.2506, Val MAE: 0.1079
# Test RMSE: 0.3254, Test MAE: 0.1505
# ---------------------------------
# Model saved at epoch 38 with val RMSE 0.2506
# Patience grace period: 40
# ---------------------------------
# Epoch 39/500
# Train RMSE: 0.2523
# Val RMSE: 0.2505, Val MAE: 0.1078
# Test RMSE: 0.3253, Test MAE: 0.1502
# ---------------------------------
# Model saved at epoch 39 with val RMSE 0.2505
# Patience grace period: 39
# ---------------------------------
# Epoch 40/500
# Train RMSE: 0.2522
# Val RMSE: 0.2504, Val MAE: 0.1077
# Test RMSE: 0.3253, Test MAE: 0.1503
# ---------------------------------
# Model saved at epoch 40 with val RMSE 0.2504
# Patience grace period: 40
# ---------------------------------
# Epoch 41/500
# Train RMSE: 0.2521
# Val RMSE: 0.2504, Val MAE: 0.1078
# Test RMSE: 0.3252, Test MAE: 0.1500
# ---------------------------------
# Model saved at epoch 41 with val RMSE 0.2504
# Patience grace period: 39
# ---------------------------------
# Epoch 42/500
# Train RMSE: 0.2520
# Val RMSE: 0.2504, Val MAE: 0.1068
# Test RMSE: 0.3263, Test MAE: 0.1492
# ---------------------------------
# Patience grace period: 37
# ---------------------------------
# Epoch 43/500
# Train RMSE: 0.2518
# Val RMSE: 0.2503, Val MAE: 0.1078
# Test RMSE: 0.3249, Test MAE: 0.1501
# ---------------------------------
# Model saved at epoch 43 with val RMSE 0.2503
# Patience grace period: 40
# ---------------------------------
# Epoch 44/500
# Train RMSE: 0.2518
# Val RMSE: 0.2502, Val MAE: 0.1075
# Test RMSE: 0.3254, Test MAE: 0.1497
# ---------------------------------
# Model saved at epoch 44 with val RMSE 0.2502
# Patience grace period: 39
# ---------------------------------
# Epoch 45/500
# Train RMSE: 0.2517
# Val RMSE: 0.2502, Val MAE: 0.1070
# Test RMSE: 0.3260, Test MAE: 0.1495
# ---------------------------------
# Model saved at epoch 45 with val RMSE 0.2502
# Patience grace period: 38
# ---------------------------------
# Epoch 46/500
# Train RMSE: 0.2516
# Val RMSE: 0.2501, Val MAE: 0.1071
# Test RMSE: 0.3253, Test MAE: 0.1497
# ---------------------------------
# Model saved at epoch 46 with val RMSE 0.2501
# Patience grace period: 40
# ---------------------------------
# Epoch 47/500
# Train RMSE: 0.2515
# Val RMSE: 0.2500, Val MAE: 0.1071
# Test RMSE: 0.3253, Test MAE: 0.1496
# ---------------------------------
# Model saved at epoch 47 with val RMSE 0.2500
# Patience grace period: 39
# ---------------------------------
# Epoch 48/500
# Train RMSE: 0.2514
# Val RMSE: 0.2500, Val MAE: 0.1076
# Test RMSE: 0.3250, Test MAE: 0.1501
# ---------------------------------
# Model saved at epoch 48 with val RMSE 0.2500
# Patience grace period: 40
# ---------------------------------
# Epoch 49/500
# Train RMSE: 0.2514
# Val RMSE: 0.2500, Val MAE: 0.1073
# Test RMSE: 0.3257, Test MAE: 0.1497
# ---------------------------------
# Model saved at epoch 49 with val RMSE 0.2500
# Patience grace period: 39
# ---------------------------------
# Epoch 50/500
# Train RMSE: 0.2513
# Val RMSE: 0.2499, Val MAE: 0.1075
# Test RMSE: 0.3253, Test MAE: 0.1498
# ---------------------------------
# Model saved at epoch 50 with val RMSE 0.2499
# Patience grace period: 38
# ---------------------------------
# Epoch 51/500
# Train RMSE: 0.2512
# Val RMSE: 0.2498, Val MAE: 0.1073
# Test RMSE: 0.3249, Test MAE: 0.1496
# ---------------------------------
# Model saved at epoch 51 with val RMSE 0.2498
# Patience grace period: 40
# ---------------------------------
# Epoch 52/500
# Train RMSE: 0.2511
# Val RMSE: 0.2499, Val MAE: 0.1069
# Test RMSE: 0.3255, Test MAE: 0.1493
# ---------------------------------
# Patience grace period: 38
# ---------------------------------
# Epoch 53/500
# Train RMSE: 0.2510
# Val RMSE: 0.2498, Val MAE: 0.1071
# Test RMSE: 0.3254, Test MAE: 0.1493
# ---------------------------------
# Patience grace period: 37
# ---------------------------------
# Epoch 54/500
# Train RMSE: 0.2509
# Val RMSE: 0.2497, Val MAE: 0.1074
# Test RMSE: 0.3250, Test MAE: 0.1497
# ---------------------------------
# Model saved at epoch 54 with val RMSE 0.2497
# Patience grace period: 36
# ---------------------------------
# Epoch 55/500
# Train RMSE: 0.2509
# Val RMSE: 0.2497, Val MAE: 0.1078
# Test RMSE: 0.3244, Test MAE: 0.1499
# ---------------------------------
# Model saved at epoch 55 with val RMSE 0.2497
# Patience grace period: 40
# ---------------------------------
# Epoch 56/500
# Train RMSE: 0.2508
# Val RMSE: 0.2497, Val MAE: 0.1074
# Test RMSE: 0.3249, Test MAE: 0.1496
# ---------------------------------
# Model saved at epoch 56 with val RMSE 0.2497
# Patience grace period: 39
# ---------------------------------
# Epoch 57/500
# Train RMSE: 0.2508
# Val RMSE: 0.2496, Val MAE: 0.1079
# Test RMSE: 0.3246, Test MAE: 0.1498
# ---------------------------------
# Model saved at epoch 57 with val RMSE 0.2496
# Patience grace period: 38
# ---------------------------------
# Epoch 58/500
# Train RMSE: 0.2507
# Val RMSE: 0.2496, Val MAE: 0.1072
# Test RMSE: 0.3251, Test MAE: 0.1494
# ---------------------------------
# Model saved at epoch 58 with val RMSE 0.2496
# Patience grace period: 37
# ---------------------------------
# Epoch 59/500
# Train RMSE: 0.2506
# Val RMSE: 0.2496, Val MAE: 0.1070
# Test RMSE: 0.3250, Test MAE: 0.1492
# ---------------------------------
# Model saved at epoch 59 with val RMSE 0.2496
# Patience grace period: 40
# ---------------------------------
# Epoch 60/500
# Train RMSE: 0.2506
# Val RMSE: 0.2495, Val MAE: 0.1075
# Test RMSE: 0.3250, Test MAE: 0.1499
# ---------------------------------
# Model saved at epoch 60 with val RMSE 0.2495
# Patience grace period: 39
# ---------------------------------
# Epoch 61/500
# Train RMSE: 0.2505
# Val RMSE: 0.2495, Val MAE: 0.1070
# Test RMSE: 0.3253, Test MAE: 0.1493
# ---------------------------------
# Model saved at epoch 61 with val RMSE 0.2495
# Patience grace period: 38
# ---------------------------------
# Epoch 62/500
# Train RMSE: 0.2504
# Val RMSE: 0.2495, Val MAE: 0.1072
# Test RMSE: 0.3251, Test MAE: 0.1495
# ---------------------------------
# Model saved at epoch 62 with val RMSE 0.2495
# Patience grace period: 36
# ---------------------------------
# Epoch 63/500
# Train RMSE: 0.2504
# Val RMSE: 0.2494, Val MAE: 0.1070
# Test RMSE: 0.3255, Test MAE: 0.1493
# ---------------------------------
# Model saved at epoch 63 with val RMSE 0.2494
# Patience grace period: 40
# ---------------------------------
# Epoch 64/500
# Train RMSE: 0.2503
# Val RMSE: 0.2494, Val MAE: 0.1067
# Test RMSE: 0.3262, Test MAE: 0.1489
# ---------------------------------
# Patience grace period: 38
# ---------------------------------
# Epoch 65/500
# Train RMSE: 0.2503
# Val RMSE: 0.2494, Val MAE: 0.1072
# Test RMSE: 0.3249, Test MAE: 0.1494
# ---------------------------------
# Model saved at epoch 65 with val RMSE 0.2494
# Patience grace period: 37
# ---------------------------------
# Epoch 66/500
# Train RMSE: 0.2502
# Val RMSE: 0.2493, Val MAE: 0.1072
# Test RMSE: 0.3251, Test MAE: 0.1494
# ---------------------------------
# Model saved at epoch 66 with val RMSE 0.2493
# Patience grace period: 40
# ---------------------------------
# Epoch 67/500
# Train RMSE: 0.2501
# Val RMSE: 0.2494, Val MAE: 0.1069
# Test RMSE: 0.3261, Test MAE: 0.1494
# ---------------------------------
# Patience grace period: 38
# ---------------------------------
# Epoch 68/500
# Train RMSE: 0.2501
# Val RMSE: 0.2493, Val MAE: 0.1071
# Test RMSE: 0.3253, Test MAE: 0.1493
# ---------------------------------
# Model saved at epoch 68 with val RMSE 0.2493
# Patience grace period: 37
# ---------------------------------
# Epoch 69/500
# Train RMSE: 0.2500
# Val RMSE: 0.2493, Val MAE: 0.1071
# Test RMSE: 0.3252, Test MAE: 0.1491
# ---------------------------------
# Model saved at epoch 69 with val RMSE 0.2493
# Patience grace period: 36
# ---------------------------------
# Epoch 70/500
# Train RMSE: 0.2500
# Val RMSE: 0.2492, Val MAE: 0.1070
# Test RMSE: 0.3253, Test MAE: 0.1494
# ---------------------------------
# Model saved at epoch 70 with val RMSE 0.2492
# Patience grace period: 35
# ---------------------------------
# Epoch 71/500
# Train RMSE: 0.2499
# Val RMSE: 0.2492, Val MAE: 0.1072
# Test RMSE: 0.3250, Test MAE: 0.1494
# ---------------------------------
# Model saved at epoch 71 with val RMSE 0.2492
# Patience grace period: 34
# ---------------------------------
# Epoch 72/500
# Train RMSE: 0.2499
# Val RMSE: 0.2492, Val MAE: 0.1069
# Test RMSE: 0.3253, Test MAE: 0.1492
# ---------------------------------
# Model saved at epoch 72 with val RMSE 0.2492
# Patience grace period: 39
# ---------------------------------
# Epoch 73/500
# Train RMSE: 0.2499
# Val RMSE: 0.2492, Val MAE: 0.1069
# Test RMSE: 0.3251, Test MAE: 0.1491
# ---------------------------------
# Model saved at epoch 73 with val RMSE 0.2492
# Patience grace period: 38
# ---------------------------------
# Epoch 74/500
# Train RMSE: 0.2498
# Val RMSE: 0.2492, Val MAE: 0.1076
# Test RMSE: 0.3246, Test MAE: 0.1495
# ---------------------------------
# Patience grace period: 36
# ---------------------------------
# Epoch 75/500
# Train RMSE: 0.2498
# Val RMSE: 0.2491, Val MAE: 0.1072
# Test RMSE: 0.3248, Test MAE: 0.1493
# ---------------------------------
# Model saved at epoch 75 with val RMSE 0.2491
# Patience grace period: 40
# ---------------------------------
# Epoch 76/500
# Train RMSE: 0.2497
# Val RMSE: 0.2491, Val MAE: 0.1070
# Test RMSE: 0.3253, Test MAE: 0.1490
# ---------------------------------
# Model saved at epoch 76 with val RMSE 0.2491
# Patience grace period: 39
# ---------------------------------
# Epoch 77/500
# Train RMSE: 0.2497
# Val RMSE: 0.2491, Val MAE: 0.1073
# Test RMSE: 0.3243, Test MAE: 0.1492
# ---------------------------------
# Patience grace period: 37
# ---------------------------------
# Epoch 78/500
# Train RMSE: 0.2497
# Val RMSE: 0.2491, Val MAE: 0.1070
# Test RMSE: 0.3255, Test MAE: 0.1493
# ---------------------------------
# Patience grace period: 35
# ---------------------------------
# Epoch 79/500
# Train RMSE: 0.2496
# Val RMSE: 0.2490, Val MAE: 0.1072
# Test RMSE: 0.3253, Test MAE: 0.1494
# ---------------------------------
# Model saved at epoch 79 with val RMSE 0.2490
# Patience grace period: 34
# ---------------------------------
# Epoch 80/500
# Train RMSE: 0.2496
# Val RMSE: 0.2491, Val MAE: 0.1067
# Test RMSE: 0.3256, Test MAE: 0.1491
# ---------------------------------
# Patience grace period: 32
# ---------------------------------
# Epoch 81/500
# Train RMSE: 0.2495
# Val RMSE: 0.2490, Val MAE: 0.1069
# Test RMSE: 0.3253, Test MAE: 0.1492
# ---------------------------------
# Model saved at epoch 81 with val RMSE 0.2490
# Patience grace period: 40
# ---------------------------------
# Epoch 82/500
# Train RMSE: 0.2495
# Val RMSE: 0.2490, Val MAE: 0.1065
# Test RMSE: 0.3257, Test MAE: 0.1487
# ---------------------------------
# Model saved at epoch 82 with val RMSE 0.2490
# Patience grace period: 39
# ---------------------------------
# Epoch 83/500
# Train RMSE: 0.2495
# Val RMSE: 0.2489, Val MAE: 0.1074
# Test RMSE: 0.3247, Test MAE: 0.1495
# ---------------------------------
# Model saved at epoch 83 with val RMSE 0.2489
# Patience grace period: 38
# ---------------------------------
# Epoch 84/500
# Train RMSE: 0.2494
# Val RMSE: 0.2489, Val MAE: 0.1071
# Test RMSE: 0.3246, Test MAE: 0.1493
# ---------------------------------
# Model saved at epoch 84 with val RMSE 0.2489
# Patience grace period: 36
# ---------------------------------
# Epoch 85/500
# Train RMSE: 0.2494
# Val RMSE: 0.2489, Val MAE: 0.1073
# Test RMSE: 0.3245, Test MAE: 0.1494
# ---------------------------------
# Model saved at epoch 85 with val RMSE 0.2489
# Patience grace period: 40
# ---------------------------------
# Epoch 86/500
# Train RMSE: 0.2493
# Val RMSE: 0.2489, Val MAE: 0.1066
# Test RMSE: 0.3264, Test MAE: 0.1489
# ---------------------------------
# Patience grace period: 38
# ---------------------------------
# Epoch 87/500
# Train RMSE: 0.2493
# Val RMSE: 0.2489, Val MAE: 0.1074
# Test RMSE: 0.3244, Test MAE: 0.1494
# ---------------------------------
# Model saved at epoch 87 with val RMSE 0.2489
# Patience grace period: 37
# ---------------------------------
# Epoch 88/500
# Train RMSE: 0.2492
# Val RMSE: 0.2489, Val MAE: 0.1070
# Test RMSE: 0.3257, Test MAE: 0.1491
# ---------------------------------
# Patience grace period: 35
# ---------------------------------
# Epoch 89/500
# Train RMSE: 0.2492
# Val RMSE: 0.2488, Val MAE: 0.1069
# Test RMSE: 0.3250, Test MAE: 0.1493
# ---------------------------------
# Model saved at epoch 89 with val RMSE 0.2488
# Patience grace period: 34
# ---------------------------------
# Epoch 90/500
# Train RMSE: 0.2492
# Val RMSE: 0.2488, Val MAE: 0.1067
# Test RMSE: 0.3257, Test MAE: 0.1490
# ---------------------------------
# Model saved at epoch 90 with val RMSE 0.2488
# Patience grace period: 33
# ---------------------------------
# Epoch 91/500
# Train RMSE: 0.2491
# Val RMSE: 0.2488, Val MAE: 0.1072
# Test RMSE: 0.3246, Test MAE: 0.1493
# ---------------------------------
# Model saved at epoch 91 with val RMSE 0.2488
# Patience grace period: 32
# ---------------------------------
# Epoch 92/500
# Train RMSE: 0.2491
# Val RMSE: 0.2488, Val MAE: 0.1069
# Test RMSE: 0.3250, Test MAE: 0.1493
# ---------------------------------
# Patience grace period: 30
# ---------------------------------
# Epoch 93/500
# Train RMSE: 0.2491
# Val RMSE: 0.2488, Val MAE: 0.1067
# Test RMSE: 0.3257, Test MAE: 0.1490
# ---------------------------------
# Patience grace period: 29
# ---------------------------------
# Epoch 94/500
# Train RMSE: 0.2491
# Val RMSE: 0.2488, Val MAE: 0.1072
# Test RMSE: 0.3248, Test MAE: 0.1496
# ---------------------------------
# Patience grace period: 27
# ---------------------------------
# Epoch 95/500
# Train RMSE: 0.2490
# Val RMSE: 0.2488, Val MAE: 0.1071
# Test RMSE: 0.3251, Test MAE: 0.1493
# ---------------------------------
# Model saved at epoch 95 with val RMSE 0.2488
# Patience grace period: 40
# ---------------------------------
# Epoch 96/500
# Train RMSE: 0.2490
# Val RMSE: 0.2488, Val MAE: 0.1068
# Test RMSE: 0.3257, Test MAE: 0.1490
# ---------------------------------
# Model saved at epoch 96 with val RMSE 0.2488
# Patience grace period: 39
# ---------------------------------
# Epoch 97/500
# Train RMSE: 0.2489
# Val RMSE: 0.2488, Val MAE: 0.1071
# Test RMSE: 0.3249, Test MAE: 0.1492
# ---------------------------------
# Patience grace period: 37
# ---------------------------------
# Epoch 98/500
# Train RMSE: 0.2489
# Val RMSE: 0.2488, Val MAE: 0.1068
# Test RMSE: 0.3257, Test MAE: 0.1492
# ---------------------------------
# Model saved at epoch 98 with val RMSE 0.2488
# Patience grace period: 36
# ---------------------------------
# Epoch 99/500
# Train RMSE: 0.2489
# Val RMSE: 0.2488, Val MAE: 0.1073
# Test RMSE: 0.3249, Test MAE: 0.1496
# ---------------------------------
# Model saved at epoch 99 with val RMSE 0.2488
# Patience grace period: 35
# ---------------------------------
# Epoch 100/500
# Train RMSE: 0.2488
# Val RMSE: 0.2487, Val MAE: 0.1070
# Test RMSE: 0.3254, Test MAE: 0.1494
# ---------------------------------
# Model saved at epoch 100 with val RMSE 0.2487
# Patience grace period: 33
# ---------------------------------
# Epoch 101/500
# Train RMSE: 0.2488
# Val RMSE: 0.2487, Val MAE: 0.1071
# Test RMSE: 0.3251, Test MAE: 0.1493
# ---------------------------------
# Model saved at epoch 101 with val RMSE 0.2487
# Patience grace period: 31
# ---------------------------------
# Epoch 102/500
# Train RMSE: 0.2488
# Val RMSE: 0.2488, Val MAE: 0.1073
# Test RMSE: 0.3246, Test MAE: 0.1497
# ---------------------------------
# Patience grace period: 29
# ---------------------------------
# Epoch 103/500
# Train RMSE: 0.2488
# Val RMSE: 0.2486, Val MAE: 0.1070
# Test RMSE: 0.3248, Test MAE: 0.1493
# ---------------------------------
# Model saved at epoch 103 with val RMSE 0.2486
# Patience grace period: 40
# ---------------------------------
# Epoch 104/500
# Train RMSE: 0.2487
# Val RMSE: 0.2487, Val MAE: 0.1068
# Test RMSE: 0.3252, Test MAE: 0.1491
# ---------------------------------
# Patience grace period: 38
# ---------------------------------
# Epoch 105/500
# Train RMSE: 0.2487
# Val RMSE: 0.2486, Val MAE: 0.1069
# Test RMSE: 0.3256, Test MAE: 0.1491
# ---------------------------------
# Model saved at epoch 105 with val RMSE 0.2486
# Patience grace period: 37
# ---------------------------------
# Epoch 106/500
# Train RMSE: 0.2487
# Val RMSE: 0.2486, Val MAE: 0.1069
# Test RMSE: 0.3253, Test MAE: 0.1491
# ---------------------------------
# Patience grace period: 35
# ---------------------------------
# Epoch 107/500
# Train RMSE: 0.2487
# Val RMSE: 0.2487, Val MAE: 0.1069
# Test RMSE: 0.3256, Test MAE: 0.1492
# ---------------------------------
# Patience grace period: 33
# ---------------------------------
# Epoch 108/500
# Train RMSE: 0.2486
# Val RMSE: 0.2486, Val MAE: 0.1071
# Test RMSE: 0.3253, Test MAE: 0.1492
# ---------------------------------
# Model saved at epoch 108 with val RMSE 0.2486
# Patience grace period: 32
# ---------------------------------
# Epoch 109/500
# Train RMSE: 0.2486
# Val RMSE: 0.2486, Val MAE: 0.1067
# Test RMSE: 0.3257, Test MAE: 0.1490
# ---------------------------------
# Patience grace period: 30
# ---------------------------------
# Epoch 110/500
# Train RMSE: 0.2486
# Val RMSE: 0.2487, Val MAE: 0.1068
# Test RMSE: 0.3256, Test MAE: 0.1491
# ---------------------------------
# Patience grace period: 28
# ---------------------------------
# Epoch 111/500
# Train RMSE: 0.2485
# Val RMSE: 0.2486, Val MAE: 0.1070
# Test RMSE: 0.3253, Test MAE: 0.1494
# ---------------------------------
# Patience grace period: 27
# ---------------------------------
# Epoch 112/500
# Train RMSE: 0.2485
# Val RMSE: 0.2487, Val MAE: 0.1065
# Test RMSE: 0.3267, Test MAE: 0.1491
# ---------------------------------
# Patience grace period: 25
# ---------------------------------
# Epoch 113/500
# Train RMSE: 0.2485
# Val RMSE: 0.2486, Val MAE: 0.1066
# Test RMSE: 0.3259, Test MAE: 0.1491
# ---------------------------------
# Patience grace period: 24
# ---------------------------------
# Epoch 114/500
# Train RMSE: 0.2484
# Val RMSE: 0.2486, Val MAE: 0.1068
# Test RMSE: 0.3257, Test MAE: 0.1491
# ---------------------------------
# Patience grace period: 22
# ---------------------------------
# Epoch 115/500
# Train RMSE: 0.2485
# Val RMSE: 0.2487, Val MAE: 0.1070
# Test RMSE: 0.3251, Test MAE: 0.1495
# ---------------------------------
# Patience grace period: 20
# ---------------------------------
# Epoch 116/500
# Train RMSE: 0.2484
# Val RMSE: 0.2486, Val MAE: 0.1069
# Test RMSE: 0.3255, Test MAE: 0.1492
# ---------------------------------
# Model saved at epoch 116 with val RMSE 0.2486
# Patience grace period: 19
# ---------------------------------
# Epoch 117/500
# Train RMSE: 0.2484
# Val RMSE: 0.2486, Val MAE: 0.1073
# Test RMSE: 0.3252, Test MAE: 0.1494
# ---------------------------------
# Model saved at epoch 117 with val RMSE 0.2486
# Patience grace period: 17
# ---------------------------------
# Epoch 118/500
# Train RMSE: 0.2483
# Val RMSE: 0.2486, Val MAE: 0.1072
# Test RMSE: 0.3247, Test MAE: 0.1493
# ---------------------------------
# Patience grace period: 15
# ---------------------------------
# Epoch 119/500
# Train RMSE: 0.2483
# Val RMSE: 0.2486, Val MAE: 0.1072
# Test RMSE: 0.3244, Test MAE: 0.1495
# ---------------------------------
# Patience grace period: 14
# ---------------------------------
# Epoch 120/500
# Train RMSE: 0.2483
# Val RMSE: 0.2486, Val MAE: 0.1075
# Test RMSE: 0.3245, Test MAE: 0.1498
# ---------------------------------
# Patience grace period: 12
# ---------------------------------
# Epoch 121/500
# Train RMSE: 0.2483
# Val RMSE: 0.2487, Val MAE: 0.1078
# Test RMSE: 0.3237, Test MAE: 0.1498
# ---------------------------------
# Patience grace period: 10
# ---------------------------------
# Epoch 122/500
# Train RMSE: 0.2483
# Val RMSE: 0.2486, Val MAE: 0.1070
# Test RMSE: 0.3255, Test MAE: 0.1492
# ---------------------------------
# Patience grace period: 9
# ---------------------------------
# Epoch 123/500
# Train RMSE: 0.2482
# Val RMSE: 0.2486, Val MAE: 0.1074
# Test RMSE: 0.3245, Test MAE: 0.1498
# ---------------------------------
# Patience grace period: 7
# ---------------------------------
# Epoch 124/500
# Train RMSE: 0.2482
# Val RMSE: 0.2485, Val MAE: 0.1069
# Test RMSE: 0.3252, Test MAE: 0.1494
# ---------------------------------
# Model saved at epoch 124 with val RMSE 0.2485
# Patience grace period: 40
# ---------------------------------
# Epoch 125/500
# Train RMSE: 0.2482
# Val RMSE: 0.2486, Val MAE: 0.1072
# Test RMSE: 0.3250, Test MAE: 0.1494
# ---------------------------------
# Patience grace period: 38
# ---------------------------------
# Epoch 126/500
# Train RMSE: 0.2482
# Val RMSE: 0.2486, Val MAE: 0.1071
# Test RMSE: 0.3252, Test MAE: 0.1493
# ---------------------------------
# Patience grace period: 37
# ---------------------------------
# Epoch 127/500
# Train RMSE: 0.2481
# Val RMSE: 0.2486, Val MAE: 0.1074
# Test RMSE: 0.3246, Test MAE: 0.1495
# ---------------------------------
# Patience grace period: 35
# ---------------------------------
# Epoch 128/500
# Train RMSE: 0.2481
# Val RMSE: 0.2485, Val MAE: 0.1073
# Test RMSE: 0.3249, Test MAE: 0.1497
# ---------------------------------
# Patience grace period: 34
# ---------------------------------
# Epoch 129/500
# Train RMSE: 0.2481
# Val RMSE: 0.2486, Val MAE: 0.1076
# Test RMSE: 0.3246, Test MAE: 0.1497
# ---------------------------------
# Patience grace period: 32
# ---------------------------------
# Epoch 130/500
# Train RMSE: 0.2481
# Val RMSE: 0.2486, Val MAE: 0.1075
# Test RMSE: 0.3245, Test MAE: 0.1497
# ---------------------------------
# Patience grace period: 30
# ---------------------------------
# Epoch 131/500
# Train RMSE: 0.2480
# Val RMSE: 0.2485, Val MAE: 0.1069
# Test RMSE: 0.3253, Test MAE: 0.1493
# ---------------------------------
# Patience grace period: 29
# ---------------------------------
# Epoch 132/500
# Train RMSE: 0.2480
# Val RMSE: 0.2485, Val MAE: 0.1070
# Test RMSE: 0.3253, Test MAE: 0.1493
# ---------------------------------
# Model saved at epoch 132 with val RMSE 0.2485
# Patience grace period: 28
# ---------------------------------
# Epoch 133/500
# Train RMSE: 0.2480
# Val RMSE: 0.2486, Val MAE: 0.1075
# Test RMSE: 0.3242, Test MAE: 0.1499
# ---------------------------------
# Patience grace period: 26
# ---------------------------------
# Epoch 134/500
# Train RMSE: 0.2480
# Val RMSE: 0.2486, Val MAE: 0.1074
# Test RMSE: 0.3246, Test MAE: 0.1498
# ---------------------------------
# Patience grace period: 24
# ---------------------------------
# Epoch 135/500
# Train RMSE: 0.2480
# Val RMSE: 0.2488, Val MAE: 0.1084
# Test RMSE: 0.3235, Test MAE: 0.1504
# ---------------------------------
# Patience grace period: 22
# ---------------------------------
# Epoch 136/500
# Train RMSE: 0.2480
# Val RMSE: 0.2486, Val MAE: 0.1073
# Test RMSE: 0.3248, Test MAE: 0.1494
# ---------------------------------
# Patience grace period: 21
# ---------------------------------
# Epoch 137/500
# Train RMSE: 0.2479
# Val RMSE: 0.2486, Val MAE: 0.1076
# Test RMSE: 0.3242, Test MAE: 0.1498
# ---------------------------------
# Patience grace period: 19
# ---------------------------------
# Epoch 138/500
# Train RMSE: 0.2479
# Val RMSE: 0.2485, Val MAE: 0.1076
# Test RMSE: 0.3243, Test MAE: 0.1500
# ---------------------------------
# Patience grace period: 18
# ---------------------------------
# Epoch 139/500
# Train RMSE: 0.2479
# Val RMSE: 0.2485, Val MAE: 0.1071
# Test RMSE: 0.3249, Test MAE: 0.1494
# ---------------------------------
# Patience grace period: 17
# ---------------------------------
# Epoch 140/500
# Train RMSE: 0.2479
# Val RMSE: 0.2485, Val MAE: 0.1075
# Test RMSE: 0.3245, Test MAE: 0.1498
# ---------------------------------
# Patience grace period: 15
# ---------------------------------
# Epoch 141/500
# Train RMSE: 0.2478
# Val RMSE: 0.2485, Val MAE: 0.1073
# Test RMSE: 0.3247, Test MAE: 0.1495
# ---------------------------------
# Patience grace period: 14
# ---------------------------------
# Epoch 142/500
# Train RMSE: 0.2478
# Val RMSE: 0.2484, Val MAE: 0.1069
# Test RMSE: 0.3255, Test MAE: 0.1492
# ---------------------------------
# Model saved at epoch 142 with val RMSE 0.2484
# Patience grace period: 13
# ---------------------------------
# Epoch 143/500
# Train RMSE: 0.2478
# Val RMSE: 0.2486, Val MAE: 0.1074
# Test RMSE: 0.3246, Test MAE: 0.1497
# ---------------------------------
# Patience grace period: 11
# ---------------------------------
# Epoch 144/500
# Train RMSE: 0.2478
# Val RMSE: 0.2485, Val MAE: 0.1072
# Test RMSE: 0.3251, Test MAE: 0.1496
# ---------------------------------
# Patience grace period: 10
# ---------------------------------
# Epoch 145/500
# Train RMSE: 0.2478
# Val RMSE: 0.2485, Val MAE: 0.1069
# Test RMSE: 0.3258, Test MAE: 0.1496
# ---------------------------------
# Patience grace period: 8
# ---------------------------------
# Epoch 146/500
# Train RMSE: 0.2478
# Val RMSE: 0.2484, Val MAE: 0.1067
# Test RMSE: 0.3260, Test MAE: 0.1493
# ---------------------------------
# Model saved at epoch 146 with val RMSE 0.2484
# Patience grace period: 7
# ---------------------------------
# Epoch 147/500
# Train RMSE: 0.2478
# Val RMSE: 0.2484, Val MAE: 0.1064
# Test RMSE: 0.3262, Test MAE: 0.1489
# ---------------------------------
# Patience grace period: 5
# ---------------------------------
# Epoch 148/500
# Train RMSE: 0.2477
# Val RMSE: 0.2485, Val MAE: 0.1062
# Test RMSE: 0.3266, Test MAE: 0.1489
# ---------------------------------
# Patience grace period: 3
# ---------------------------------
# Epoch 149/500
# Train RMSE: 0.2477
# Val RMSE: 0.2485, Val MAE: 0.1062
# Test RMSE: 0.3271, Test MAE: 0.1489
# ---------------------------------
# Patience grace period: 2
# ---------------------------------
# Epoch 150/500
# Train RMSE: 0.2476
# Val RMSE: 0.2484, Val MAE: 0.1063
# Test RMSE: 0.3261, Test MAE: 0.1489
# ---------------------------------
# Patience grace period: 1
# ---------------------------------
# Epoch 151/500
# Train RMSE: 0.2476
# Val RMSE: 0.2485, Val MAE: 0.1058
# Test RMSE: 0.3277, Test MAE: 0.1486
# ---------------------------------
# Patience grace period: -1
# Early stopping triggered at epoch 151
# Final Test RMSE: 0.3260, Final Test MAE: 0.1493
# <ipython-input-3-2a228d64b832>:126: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   self.model.load_state_dict(torch.load(os.path.join(save_dir, 'best_model.pth')))
# Pearson Corr: 0.7467554729639482
# Spearman Corr: 0.42986540639516746
# p-rmse: 0.32595493617468235
#        rmse       mae  seed                             subtask       method  \
# 0  0.325955  0.149297     1  openproblems_bmmc_cite_phase2_mod2  no_residual
#
#     pearson p_value_pearson  spearman p_value_spearman
# 0  0.746755          0.0000  0.429865           0.0000
# ---------------------------------
# Epoch 1/500
# Train RMSE: 0.3798
# Val RMSE: 0.3288, Val MAE: 0.1346
# Test RMSE: 0.4091, Test MAE: 0.1791
# ---------------------------------
# Model saved at epoch 1 with val RMSE 0.3288
# Patience grace period: 40
# ---------------------------------
# Epoch 2/500
# Train RMSE: 0.3311
# Val RMSE: 0.2987, Val MAE: 0.1285
# Test RMSE: 0.3772, Test MAE: 0.1693
# ---------------------------------
# Model saved at epoch 2 with val RMSE 0.2987
# Patience grace period: 40
# ---------------------------------
# Epoch 3/500
# Train RMSE: 0.3080
# Val RMSE: 0.2823, Val MAE: 0.1216
# Test RMSE: 0.3625, Test MAE: 0.1618
# ---------------------------------
# Model saved at epoch 3 with val RMSE 0.2823
# Patience grace period: 40
# ---------------------------------
# Epoch 4/500
# Train RMSE: 0.2932
# Val RMSE: 0.2735, Val MAE: 0.1176
# Test RMSE: 0.3543, Test MAE: 0.1575
# ---------------------------------
# Model saved at epoch 4 with val RMSE 0.2735
# Patience grace period: 40
# ---------------------------------
# Epoch 5/500
# Train RMSE: 0.2840
# Val RMSE: 0.2685, Val MAE: 0.1161
# Test RMSE: 0.3482, Test MAE: 0.1559
# ---------------------------------
# Model saved at epoch 5 with val RMSE 0.2685
# Patience grace period: 40
# ---------------------------------
# Epoch 6/500
# Train RMSE: 0.2776
# Val RMSE: 0.2650, Val MAE: 0.1148
# Test RMSE: 0.3432, Test MAE: 0.1544
# ---------------------------------
# Model saved at epoch 6 with val RMSE 0.2650
# Patience grace period: 40
# ---------------------------------
# Epoch 7/500
# Train RMSE: 0.2727
# Val RMSE: 0.2628, Val MAE: 0.1131
# Test RMSE: 0.3406, Test MAE: 0.1528
# ---------------------------------
# Model saved at epoch 7 with val RMSE 0.2628
# Patience grace period: 40
# ---------------------------------
# Epoch 8/500
# Train RMSE: 0.2690
# Val RMSE: 0.2608, Val MAE: 0.1118
# Test RMSE: 0.3381, Test MAE: 0.1516
# ---------------------------------
# Model saved at epoch 8 with val RMSE 0.2608
# Patience grace period: 40
# ---------------------------------
# Epoch 9/500
# Train RMSE: 0.2661
# Val RMSE: 0.2591, Val MAE: 0.1109
# Test RMSE: 0.3356, Test MAE: 0.1512
# ---------------------------------
# Model saved at epoch 9 with val RMSE 0.2591
# Patience grace period: 40
# ---------------------------------
# Epoch 10/500
# Train RMSE: 0.2640
# ...
# ---------------------------------
# Model saved at epoch 98 with val RMSE 0.2486
# Patience grace period: 35
# ---------------------------------
# Epoch 99/500
# Train RMSE: 0.2490
# Val RMSE: 0.2486, Val MAE: 0.1065
# Test RMSE: 0.3252, Test MAE: 0.1498
# ---------------------------------
# Model saved at epoch 99 with val RMSE 0.2486
# Patience grace period: 34
# ---------------------------------
# Epoch 100/500
# Train RMSE: 0.2489
# Val RMSE: 0.2486, Val MAE: 0.1066
# Test RMSE: 0.3251, Test MAE: 0.1498
# ---------------------------------
# Model saved at epoch 100 with val RMSE 0.2486
# Patience grace period: 33
# ---------------------------------
# Epoch 101/500
# Train RMSE: 0.2489
# Val RMSE: 0.2486, Val MAE: 0.1070
# Test RMSE: 0.3248, Test MAE: 0.1503
# ---------------------------------
# Patience grace period: 31
# ---------------------------------
# Epoch 102/500
# Train RMSE: 0.2488
# Val RMSE: 0.2486, Val MAE: 0.1062
# Test RMSE: 0.3259, Test MAE: 0.1495
# ---------------------------------
# Model saved at epoch 102 with val RMSE 0.2486
# Patience grace period: 30
# ---------------------------------
# Epoch 103/500
# Train RMSE: 0.2488
# Val RMSE: 0.2486, Val MAE: 0.1070
# Test RMSE: 0.3243, Test MAE: 0.1503
# ---------------------------------
# Patience grace period: 28
# ---------------------------------
# Epoch 104/500
# Train RMSE: 0.2488
# Val RMSE: 0.2485, Val MAE: 0.1064
# Test RMSE: 0.3253, Test MAE: 0.1497
# ---------------------------------
# Model saved at epoch 104 with val RMSE 0.2485
# Patience grace period: 40
# ---------------------------------
# Epoch 105/500
# Train RMSE: 0.2488
# Val RMSE: 0.2486, Val MAE: 0.1065
# Test RMSE: 0.3257, Test MAE: 0.1498
# ---------------------------------
# Patience grace period: 38
# ---------------------------------
# Epoch 106/500
# Train RMSE: 0.2488
# Val RMSE: 0.2486, Val MAE: 0.1069
# Test RMSE: 0.3245, Test MAE: 0.1498
# ---------------------------------
# Patience grace period: 37
# ---------------------------------
# Epoch 107/500
# Train RMSE: 0.2487
# Val RMSE: 0.2485, Val MAE: 0.1067
# Test RMSE: 0.3250, Test MAE: 0.1499
# ---------------------------------
# Patience grace period: 36
# ---------------------------------
# Epoch 108/500
# Train RMSE: 0.2487
# Val RMSE: 0.2485, Val MAE: 0.1066
# Test RMSE: 0.3253, Test MAE: 0.1500
# ---------------------------------
# Model saved at epoch 108 with val RMSE 0.2485
# Patience grace period: 35
# ---------------------------------
# Epoch 109/500
# Train RMSE: 0.2487
# Val RMSE: 0.2485, Val MAE: 0.1066
# Test RMSE: 0.3255, Test MAE: 0.1498
# ---------------------------------
# Model saved at epoch 109 with val RMSE 0.2485
# Patience grace period: 34
# ---------------------------------
# Epoch 110/500
# Train RMSE: 0.2487
# Val RMSE: 0.2485, Val MAE: 0.1071
# Test RMSE: 0.3247, Test MAE: 0.1501
# ---------------------------------
# Patience grace period: 32
# ---------------------------------
# Epoch 111/500
# Train RMSE: 0.2486
# Val RMSE: 0.2485, Val MAE: 0.1068
# Test RMSE: 0.3250, Test MAE: 0.1500
# ---------------------------------
# Patience grace period: 31
# ---------------------------------
# Epoch 112/500
# Train RMSE: 0.2486
# Val RMSE: 0.2484, Val MAE: 0.1065
# Test RMSE: 0.3253, Test MAE: 0.1498
# ---------------------------------
# Model saved at epoch 112 with val RMSE 0.2484
# Patience grace period: 30
# ---------------------------------
# Epoch 113/500
# Train RMSE: 0.2486
# Val RMSE: 0.2484, Val MAE: 0.1060
# Test RMSE: 0.3260, Test MAE: 0.1495
# ---------------------------------
# Model saved at epoch 113 with val RMSE 0.2484
# Patience grace period: 29
# ---------------------------------
# Epoch 114/500
# Train RMSE: 0.2486
# Val RMSE: 0.2485, Val MAE: 0.1057
# Test RMSE: 0.3268, Test MAE: 0.1492
# ---------------------------------
# Patience grace period: 27
# ---------------------------------
# Epoch 115/500
# Train RMSE: 0.2486
# Val RMSE: 0.2486, Val MAE: 0.1051
# Test RMSE: 0.3285, Test MAE: 0.1488
# ---------------------------------
# Patience grace period: 25
# ---------------------------------
# Epoch 116/500
# Train RMSE: 0.2486
# Val RMSE: 0.2487, Val MAE: 0.1050
# Test RMSE: 0.3286, Test MAE: 0.1489
# ---------------------------------
# Patience grace period: 23
# ---------------------------------
# Epoch 117/500
# Train RMSE: 0.2485
# Val RMSE: 0.2487, Val MAE: 0.1049
# Test RMSE: 0.3289, Test MAE: 0.1488
# ---------------------------------
# Patience grace period: 22
# ---------------------------------
# Epoch 118/500
# Train RMSE: 0.2485
# Val RMSE: 0.2487, Val MAE: 0.1050
# Test RMSE: 0.3290, Test MAE: 0.1489
# ---------------------------------
# Patience grace period: 21
# ---------------------------------
# Epoch 119/500
# Train RMSE: 0.2484
# Val RMSE: 0.2485, Val MAE: 0.1052
# Test RMSE: 0.3284, Test MAE: 0.1489
# ---------------------------------
# Patience grace period: 20
# ---------------------------------
# Epoch 120/500
# Train RMSE: 0.2485
# Val RMSE: 0.2487, Val MAE: 0.1048
# Test RMSE: 0.3291, Test MAE: 0.1489
# ---------------------------------
# Patience grace period: 18
# ---------------------------------
# Epoch 121/500
# Train RMSE: 0.2484
# Val RMSE: 0.2487, Val MAE: 0.1049
# Test RMSE: 0.3293, Test MAE: 0.1488
# ---------------------------------
# Patience grace period: 17
# ---------------------------------
# Epoch 122/500
# Train RMSE: 0.2484
# Val RMSE: 0.2487, Val MAE: 0.1050
# Test RMSE: 0.3287, Test MAE: 0.1490
# ---------------------------------
# Patience grace period: 16
# ---------------------------------
# Epoch 123/500
# Train RMSE: 0.2484
# Val RMSE: 0.2486, Val MAE: 0.1050
# Test RMSE: 0.3290, Test MAE: 0.1488
# ---------------------------------
# Patience grace period: 15
# ---------------------------------
# Epoch 124/500
# Train RMSE: 0.2484
# Val RMSE: 0.2487, Val MAE: 0.1050
# Test RMSE: 0.3289, Test MAE: 0.1490
# ---------------------------------
# Patience grace period: 13
# ---------------------------------
# Epoch 125/500
# Train RMSE: 0.2483
# Val RMSE: 0.2485, Val MAE: 0.1052
# Test RMSE: 0.3285, Test MAE: 0.1491
# ---------------------------------
# Patience grace period: 12
# ---------------------------------
# Epoch 126/500
# Train RMSE: 0.2483
# Val RMSE: 0.2485, Val MAE: 0.1050
# Test RMSE: 0.3284, Test MAE: 0.1488
# ---------------------------------
# Patience grace period: 11
# ---------------------------------
# Epoch 127/500
# Train RMSE: 0.2482
# Val RMSE: 0.2485, Val MAE: 0.1051
# Test RMSE: 0.3283, Test MAE: 0.1491
# ---------------------------------
# Patience grace period: 9
# ---------------------------------
# Epoch 128/500
# Train RMSE: 0.2483
# Val RMSE: 0.2486, Val MAE: 0.1051
# Test RMSE: 0.3291, Test MAE: 0.1491
# ---------------------------------
# Patience grace period: 7
# ---------------------------------
# Epoch 129/500
# Train RMSE: 0.2482
# Val RMSE: 0.2485, Val MAE: 0.1052
# Test RMSE: 0.3282, Test MAE: 0.1491
# ---------------------------------
# Patience grace period: 6
# ---------------------------------
# Epoch 130/500
# Train RMSE: 0.2482
# Val RMSE: 0.2485, Val MAE: 0.1052
# Test RMSE: 0.3282, Test MAE: 0.1490
# ---------------------------------
# Patience grace period: 4
# ---------------------------------
# Epoch 131/500
# Train RMSE: 0.2482
# Val RMSE: 0.2484, Val MAE: 0.1054
# Test RMSE: 0.3277, Test MAE: 0.1494
# ---------------------------------
# Model saved at epoch 131 with val RMSE 0.2484
# Patience grace period: 3
# ---------------------------------
# Epoch 132/500
# Train RMSE: 0.2482
# Val RMSE: 0.2485, Val MAE: 0.1052
# Test RMSE: 0.3283, Test MAE: 0.1492
# ---------------------------------
# Patience grace period: 1
# ---------------------------------
# Epoch 133/500
# Train RMSE: 0.2481
# Val RMSE: 0.2484, Val MAE: 0.1055
# Test RMSE: 0.3277, Test MAE: 0.1493
# ---------------------------------
# Model saved at epoch 133 with val RMSE 0.2484
# Patience grace period: 40
# ---------------------------------
# Epoch 134/500
# Train RMSE: 0.2481
# Val RMSE: 0.2484, Val MAE: 0.1054
# Test RMSE: 0.3283, Test MAE: 0.1491
# ---------------------------------
# Patience grace period: 38
# ---------------------------------
# Epoch 135/500
# Train RMSE: 0.2481
# Val RMSE: 0.2485, Val MAE: 0.1050
# Test RMSE: 0.3287, Test MAE: 0.1489
# ---------------------------------
# Patience grace period: 36
# ---------------------------------
# Epoch 136/500
# Train RMSE: 0.2481
# Val RMSE: 0.2484, Val MAE: 0.1053
# Test RMSE: 0.3276, Test MAE: 0.1492
# ---------------------------------
# Model saved at epoch 136 with val RMSE 0.2484
# Patience grace period: 35
# ---------------------------------
# Epoch 137/500
# Train RMSE: 0.2481
# Val RMSE: 0.2484, Val MAE: 0.1055
# Test RMSE: 0.3279, Test MAE: 0.1492
# ---------------------------------
# Patience grace period: 33
# ---------------------------------
# Epoch 138/500
# Train RMSE: 0.2480
# Val RMSE: 0.2483, Val MAE: 0.1054
# Test RMSE: 0.3278, Test MAE: 0.1491
# ---------------------------------
# Model saved at epoch 138 with val RMSE 0.2483
# Patience grace period: 32
# ---------------------------------
# Epoch 139/500
# Train RMSE: 0.2480
# Val RMSE: 0.2483, Val MAE: 0.1057
# Test RMSE: 0.3271, Test MAE: 0.1492
# ---------------------------------
# Model saved at epoch 139 with val RMSE 0.2483
# Patience grace period: 31
# ---------------------------------
# Epoch 140/500
# Train RMSE: 0.2480
# Val RMSE: 0.2484, Val MAE: 0.1052
# Test RMSE: 0.3285, Test MAE: 0.1490
# ---------------------------------
# Patience grace period: 29
# ---------------------------------
# Epoch 141/500
# Train RMSE: 0.2480
# Val RMSE: 0.2483, Val MAE: 0.1058
# Test RMSE: 0.3274, Test MAE: 0.1494
# ---------------------------------
# Model saved at epoch 141 with val RMSE 0.2483
# Patience grace period: 40
# ---------------------------------
# Epoch 142/500
# Train RMSE: 0.2479
# Val RMSE: 0.2483, Val MAE: 0.1056
# Test RMSE: 0.3279, Test MAE: 0.1492
# ---------------------------------
# Patience grace period: 38
# ---------------------------------
# Epoch 143/500
# Train RMSE: 0.2480
# Val RMSE: 0.2484, Val MAE: 0.1052
# Test RMSE: 0.3276, Test MAE: 0.1490
# ---------------------------------
# Patience grace period: 36
# ---------------------------------
# Epoch 144/500
# Train RMSE: 0.2479
# Val RMSE: 0.2484, Val MAE: 0.1054
# Test RMSE: 0.3279, Test MAE: 0.1494
# ---------------------------------
# Patience grace period: 34
# ---------------------------------
# Epoch 145/500
# Train RMSE: 0.2479
# Val RMSE: 0.2483, Val MAE: 0.1060
# Test RMSE: 0.3269, Test MAE: 0.1496
# ---------------------------------
# Patience grace period: 33
# ---------------------------------
# Epoch 146/500
# Train RMSE: 0.2479
# Val RMSE: 0.2484, Val MAE: 0.1052
# Test RMSE: 0.3285, Test MAE: 0.1492
# ---------------------------------
# Patience grace period: 31
# ---------------------------------
# Epoch 147/500
# Train RMSE: 0.2479
# Val RMSE: 0.2484, Val MAE: 0.1054
# Test RMSE: 0.3278, Test MAE: 0.1493
# ---------------------------------
# Patience grace period: 30
# ---------------------------------
# Epoch 148/500
# Train RMSE: 0.2478
# Val RMSE: 0.2485, Val MAE: 0.1050
# Test RMSE: 0.3289, Test MAE: 0.1491
# ---------------------------------
# Patience grace period: 28
# ---------------------------------
# Epoch 149/500
# Train RMSE: 0.2478
# Val RMSE: 0.2485, Val MAE: 0.1049
# Test RMSE: 0.3295, Test MAE: 0.1487
# ---------------------------------
# Patience grace period: 26
# ---------------------------------
# Epoch 150/500
# Train RMSE: 0.2478
# Val RMSE: 0.2485, Val MAE: 0.1050
# Test RMSE: 0.3292, Test MAE: 0.1490
# ---------------------------------
# Patience grace period: 25
# ---------------------------------
# Epoch 151/500
# Train RMSE: 0.2478
# Val RMSE: 0.2484, Val MAE: 0.1052
# Test RMSE: 0.3283, Test MAE: 0.1492
# ---------------------------------
# Patience grace period: 24
# ---------------------------------
# Epoch 152/500
# Train RMSE: 0.2478
# Val RMSE: 0.2484, Val MAE: 0.1052
# Test RMSE: 0.3286, Test MAE: 0.1492
# ---------------------------------
# Patience grace period: 23
# ---------------------------------
# Epoch 153/500
# Train RMSE: 0.2477
# Val RMSE: 0.2484, Val MAE: 0.1052
# Test RMSE: 0.3288, Test MAE: 0.1491
# ---------------------------------
# Patience grace period: 22
# ---------------------------------
# Epoch 154/500
# Train RMSE: 0.2477
# Val RMSE: 0.2484, Val MAE: 0.1051
# Test RMSE: 0.3290, Test MAE: 0.1492
# ---------------------------------
# Patience grace period: 20
# ---------------------------------
# Epoch 155/500
# Train RMSE: 0.2477
# Val RMSE: 0.2486, Val MAE: 0.1048
# Test RMSE: 0.3298, Test MAE: 0.1491
# ---------------------------------
# Patience grace period: 18
# ---------------------------------
# Epoch 156/500
# Train RMSE: 0.2477
# Val RMSE: 0.2484, Val MAE: 0.1051
# Test RMSE: 0.3290, Test MAE: 0.1490
# ---------------------------------
# Patience grace period: 17
# ---------------------------------
# Epoch 157/500
# Train RMSE: 0.2477
# Val RMSE: 0.2484, Val MAE: 0.1053
# Test RMSE: 0.3288, Test MAE: 0.1493
# ---------------------------------
# Patience grace period: 16
# ---------------------------------
# Epoch 158/500
# Train RMSE: 0.2477
# Val RMSE: 0.2484, Val MAE: 0.1049
# Test RMSE: 0.3286, Test MAE: 0.1489
# ---------------------------------
# Patience grace period: 15
# ---------------------------------
# Epoch 159/500
# Train RMSE: 0.2476
# Val RMSE: 0.2484, Val MAE: 0.1051
# Test RMSE: 0.3290, Test MAE: 0.1493
# ---------------------------------
# Patience grace period: 13
# ---------------------------------
# Epoch 160/500
# Train RMSE: 0.2476
# Val RMSE: 0.2484, Val MAE: 0.1053
# Test RMSE: 0.3288, Test MAE: 0.1493
# ---------------------------------
# Patience grace period: 12
# ---------------------------------
# Epoch 161/500
# Train RMSE: 0.2476
# Val RMSE: 0.2483, Val MAE: 0.1053
# Test RMSE: 0.3280, Test MAE: 0.1491
# ---------------------------------
# Patience grace period: 11
# ---------------------------------
# Epoch 162/500
# Train RMSE: 0.2476
# Val RMSE: 0.2485, Val MAE: 0.1048
# Test RMSE: 0.3292, Test MAE: 0.1490
# ---------------------------------
# Patience grace period: 9
# ---------------------------------
# Epoch 163/500
# Train RMSE: 0.2475
# Val RMSE: 0.2484, Val MAE: 0.1052
# Test RMSE: 0.3285, Test MAE: 0.1491
# ---------------------------------
# Patience grace period: 8
# ---------------------------------
# Epoch 164/500
# Train RMSE: 0.2475
# Val RMSE: 0.2484, Val MAE: 0.1049
# Test RMSE: 0.3292, Test MAE: 0.1488
# ---------------------------------
# Patience grace period: 6
# ---------------------------------
# Epoch 165/500
# Train RMSE: 0.2475
# Val RMSE: 0.2484, Val MAE: 0.1050
# Test RMSE: 0.3291, Test MAE: 0.1491
# ---------------------------------
# Patience grace period: 4
# ---------------------------------
# Epoch 166/500
# Train RMSE: 0.2475
# Val RMSE: 0.2483, Val MAE: 0.1054
# Test RMSE: 0.3281, Test MAE: 0.1492
# ---------------------------------
# Patience grace period: 3
# ---------------------------------
# Epoch 167/500
# Train RMSE: 0.2475
# Val RMSE: 0.2484, Val MAE: 0.1050
# Test RMSE: 0.3294, Test MAE: 0.1490
# ---------------------------------
# Patience grace period: 1
# ---------------------------------
# Epoch 168/500
# Train RMSE: 0.2475
# Val RMSE: 0.2484, Val MAE: 0.1050
# Test RMSE: 0.3293, Test MAE: 0.1490
# ---------------------------------
# Patience grace period: -1
# Early stopping triggered at epoch 168
# Final Test RMSE: 0.3274, Final Test MAE: 0.1494
# <ipython-input-3-2a228d64b832>:126: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   self.model.load_state_dict(torch.load(os.path.join(save_dir, 'best_model.pth')))
# Pearson Corr: 0.7457336437337192
# Spearman Corr: 0.42843008593247
# p-rmse: 0.3273849088153147
#        rmse       mae  seed                             subtask       method  \
# 0  0.327385  0.149426     5  openproblems_bmmc_cite_phase2_mod2  no_residual
#
#     pearson p_value_pearson  spearman p_value_spearman
# 0  0.745734          0.0000   0.42843           0.0000

# %%
config_hierachical_PROTEIN = {
    "subtask": "openproblems_bmmc_cite_phase2_mod2",
    "batch_size": 520,
    "act": "relu",
    "conv_flow": ["gat"],
    "agg_flow": [None],
    "device": "cuda",
    "learning_rate": 0.000064,
    "hidden_size": 280,
    "num_heads": 6,
    "n_neigbours": 3,
    "metric": "euclidean",
    "n_components": 1200,
    "dropout_rate": 0.2,
    "num_epochs": 500,
    "seed": 1,
    "es_patience": 40,
    "es_min_delta": 0.0001,
    "es_rate_threshold": 0.00002,
    "layer_dim_ex": 3,
    "verbose": True,
    "sample": True,
    "preprocessing_type": "None",
    "variant": "no_attention",
    "num_clusters": 10
}

pipeline(**config_hierachical_PROTEIN)
# Out:
# [INFO][2025-04-15 21:06:24,136][dance][_load_raw_data] Loading /content/data/openproblems_bmmc_cite_phase2_mod2/openproblems_bmmc_cite_phase2_mod2.censor_dataset.output_train_mod1.h5ad
# Initializing pipeline...
# [INFO][2025-04-15 21:06:24,785][dance][_load_raw_data] Loading /content/data/openproblems_bmmc_cite_phase2_mod2/openproblems_bmmc_cite_phase2_mod2.censor_dataset.output_train_mod2.h5ad
# [INFO][2025-04-15 21:06:32,484][dance][_load_raw_data] Loading /content/data/openproblems_bmmc_cite_phase2_mod2/openproblems_bmmc_cite_phase2_mod2.censor_dataset.output_test_mod1.h5ad
# [INFO][2025-04-15 21:06:32,508][dance][_load_raw_data] Loading /content/data/openproblems_bmmc_cite_phase2_mod2/openproblems_bmmc_cite_phase2_mod2.censor_dataset.output_test_mod2.h5ad
# [INFO][2025-04-15 21:06:32,706][dance][_maybe_preprocess] Preprocessing done.
# /usr/local/lib/python3.11/dist-packages/mudata/_core/mudata.py:1531: FutureWarning: From 0.4 .update() will not pull obs/var columns from individual modalities by default anymore. Set mudata.set_options(pull_on_update=False) to adopt the new behaviour, which will become the default. Use new pull_obs/pull_var and push_obs/push_var methods for more flexibility.
#   self._update_attr("var", axis=0, join_common=join_common)
# /usr/local/lib/python3.11/dist-packages/mudata/_core/mudata.py:931: UserWarning: Cannot join columns with the same name because var_names are intersecting.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/mudata/_core/mudata.py:1429: FutureWarning: From 0.4 .update() will not pull obs/var columns from individual modalities by default anymore. Set mudata.set_options(pull_on_update=False) to adopt the new behaviour, which will become the default. Use new pull_obs/pull_var and push_obs/push_var methods for more flexibility.
#   self._update_attr("obs", axis=1, join_common=join_common)
# /usr/local/lib/python3.11/dist-packages/mudata/_core/mudata.py:1558: UserWarning: Modality names will be prepended to var_names since there are identical var_names in different modalities.
#   warnings.warn(
# [INFO][2025-04-15 21:06:40,002][dance][set_config_from_dict] Setting config 'feature_mod' to 'mod1'
# [INFO][2025-04-15 21:06:40,003][dance][set_config_from_dict] Setting config 'label_mod' to 'mod2'
# [INFO][2025-04-15 21:06:40,003][dance][load_data] Raw data loaded:
# Data object that wraps (.data):
# MuData object with n_obs × n_vars = 67175 × 14087
#   uns:	'dance_config'
#   2 modalities
#     mod1:	67175 x 134
#       obs:	'batch'
#       layers:	'counts'
#     mod2:	67175 x 13953
#       obs:	'batch'
#       layers:	'counts'
# [INFO][2025-04-15 21:06:40,126][dance][wrapped_func] Took 0:00:15.991210 to load and process data.
# <ipython-input-4-038168299b8a>:42: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   data.data.uns['gtrain'] = torch.load(train_graph_path)
# <ipython-input-4-038168299b8a>:43: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   data.data.uns['gval'] = torch.load(val_graph_path)
# <ipython-input-4-038168299b8a>:44: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   data.data.uns['gtest'] = torch.load(test_graph_path)
# <ipython-input-4-038168299b8a>:45: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   train_label = torch.load(train_label_path).numpy()
# Processed data found. Loading...
# <ipython-input-4-038168299b8a>:46: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   val_label = torch.load(val_label_path).numpy()
# <ipython-input-4-038168299b8a>:47: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   test_label = torch.load(test_label_path).numpy()
# <ipython-input-4-038168299b8a>:48: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   kwargs["FEATURE_SIZE"] = torch.load(feature_size_path).item()
# <ipython-input-4-038168299b8a>:49: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   kwargs["OUTPUT_SIZE"] = torch.load(output_size_path).item()
# Processed data loaded.
# ---------------------------------
# Epoch 1/500
# Train RMSE: 0.3934
# Val RMSE: 0.3574, Val MAE: 0.1451
# Test RMSE: 0.4435, Test MAE: 0.1935
# ---------------------------------
# Model saved at epoch 1 with val RMSE 0.3574
# Patience grace period: 40
# ---------------------------------
# Epoch 2/500
# Train RMSE: 0.3474
# Val RMSE: 0.3131, Val MAE: 0.1311
# Test RMSE: 0.3903, Test MAE: 0.1733
# ---------------------------------
# Model saved at epoch 2 with val RMSE 0.3131
# Patience grace period: 40
# ---------------------------------
# Epoch 3/500
# Train RMSE: 0.3211
# Val RMSE: 0.2923, Val MAE: 0.1264
# Test RMSE: 0.3679, Test MAE: 0.1664
# ---------------------------------
# Model saved at epoch 3 with val RMSE 0.2923
# Patience grace period: 40
# ---------------------------------
# Epoch 4/500
# Train RMSE: 0.3028
# Val RMSE: 0.2796, Val MAE: 0.1209
# Test RMSE: 0.3562, Test MAE: 0.1600
# ---------------------------------
# Model saved at epoch 4 with val RMSE 0.2796
# Patience grace period: 40
# ---------------------------------
# Epoch 5/500
# Train RMSE: 0.2900
# Val RMSE: 0.2721, Val MAE: 0.1176
# Test RMSE: 0.3500, Test MAE: 0.1563
# ---------------------------------
# Model saved at epoch 5 with val RMSE 0.2721
# Patience grace period: 40
# ---------------------------------
# Epoch 6/500
# Train RMSE: 0.2814
# Val RMSE: 0.2678, Val MAE: 0.1161
# Test RMSE: 0.3465, Test MAE: 0.1545
# ---------------------------------
# Model saved at epoch 6 with val RMSE 0.2678
# Patience grace period: 40
# ---------------------------------
# Epoch 7/500
# Train RMSE: 0.2756
# Val RMSE: 0.2649, Val MAE: 0.1145
# Test RMSE: 0.3444, Test MAE: 0.1525
# ---------------------------------
# Model saved at epoch 7 with val RMSE 0.2649
# Patience grace period: 40
# ---------------------------------
# Epoch 8/500
# Train RMSE: 0.2717
# Val RMSE: 0.2626, Val MAE: 0.1133
# Test RMSE: 0.3425, Test MAE: 0.1511
# ---------------------------------
# Model saved at epoch 8 with val RMSE 0.2626
# Patience grace period: 40
# ---------------------------------
# Epoch 9/500
# Train RMSE: 0.2688
# Val RMSE: 0.2610, Val MAE: 0.1119
# Test RMSE: 0.3415, Test MAE: 0.1497
# ---------------------------------
# Model saved at epoch 9 with val RMSE 0.2610
# Patience grace period: 40
# ---------------------------------
# Epoch 10/500
# Train RMSE: 0.2667
# Val RMSE: 0.2593, Val MAE: 0.1119
# Test RMSE: 0.3391, Test MAE: 0.1496
# ---------------------------------
# Model saved at epoch 10 with val RMSE 0.2593
# Patience grace period: 40
# ---------------------------------
# Epoch 11/500
# Train RMSE: 0.2652
# Val RMSE: 0.2586, Val MAE: 0.1102
# Test RMSE: 0.3400, Test MAE: 0.1482
# ---------------------------------
# Model saved at epoch 11 with val RMSE 0.2586
# Patience grace period: 40
# ---------------------------------
# Epoch 12/500
# Train RMSE: 0.2639
# Val RMSE: 0.2578, Val MAE: 0.1094
# Test RMSE: 0.3392, Test MAE: 0.1480
# ---------------------------------
# Model saved at epoch 12 with val RMSE 0.2578
# Patience grace period: 40
# ---------------------------------
# Epoch 13/500
# Train RMSE: 0.2629
# Val RMSE: 0.2573, Val MAE: 0.1090
# Test RMSE: 0.3395, Test MAE: 0.1474
# ---------------------------------
# Model saved at epoch 13 with val RMSE 0.2573
# Patience grace period: 40
# ---------------------------------
# Epoch 14/500
# Train RMSE: 0.2621
# Val RMSE: 0.2565, Val MAE: 0.1093
# Test RMSE: 0.3371, Test MAE: 0.1479
# ---------------------------------
# Model saved at epoch 14 with val RMSE 0.2565
# Patience grace period: 40
# ---------------------------------
# Epoch 15/500
# Train RMSE: 0.2614
# Val RMSE: 0.2559, Val MAE: 0.1095
# Test RMSE: 0.3361, Test MAE: 0.1481
# ---------------------------------
# Model saved at epoch 15 with val RMSE 0.2559
# Patience grace period: 40
# ---------------------------------
# Epoch 16/500
# Train RMSE: 0.2608
# Val RMSE: 0.2556, Val MAE: 0.1090
# Test RMSE: 0.3363, Test MAE: 0.1478
# ---------------------------------
# Model saved at epoch 16 with val RMSE 0.2556
# Patience grace period: 40
# ---------------------------------
# Epoch 17/500
# Train RMSE: 0.2603
# Val RMSE: 0.2549, Val MAE: 0.1100
# Test RMSE: 0.3337, Test MAE: 0.1484
# ---------------------------------
# Model saved at epoch 17 with val RMSE 0.2549
# Patience grace period: 40
# ---------------------------------
# Epoch 18/500
# Train RMSE: 0.2598
# Val RMSE: 0.2550, Val MAE: 0.1084
# Test RMSE: 0.3356, Test MAE: 0.1474
# ---------------------------------
# Patience grace period: 38
# ---------------------------------
# Epoch 19/500
# Train RMSE: 0.2592
# Val RMSE: 0.2544, Val MAE: 0.1094
# Test RMSE: 0.3330, Test MAE: 0.1481
# ---------------------------------
# Model saved at epoch 19 with val RMSE 0.2544
# Patience grace period: 40
# ---------------------------------
# Epoch 20/500
# Train RMSE: 0.2588
# Val RMSE: 0.2542, Val MAE: 0.1086
# Test RMSE: 0.3338, Test MAE: 0.1475
# ---------------------------------
# Model saved at epoch 20 with val RMSE 0.2542
# Patience grace period: 40
# ---------------------------------
# Epoch 21/500
# Train RMSE: 0.2585
# Val RMSE: 0.2541, Val MAE: 0.1083
# Test RMSE: 0.3338, Test MAE: 0.1474
# ---------------------------------
# Model saved at epoch 21 with val RMSE 0.2541
# Patience grace period: 40
# ---------------------------------
# Epoch 22/500
# Train RMSE: 0.2582
# Val RMSE: 0.2537, Val MAE: 0.1084
# Test RMSE: 0.3331, Test MAE: 0.1473
# ---------------------------------
# Model saved at epoch 22 with val RMSE 0.2537
# Patience grace period: 40
# ---------------------------------
# Epoch 23/500
# Train RMSE: 0.2578
# Val RMSE: 0.2536, Val MAE: 0.1084
# Test RMSE: 0.3327, Test MAE: 0.1475
# ---------------------------------
# Model saved at epoch 23 with val RMSE 0.2536
# Patience grace period: 40
# ---------------------------------
# Epoch 24/500
# Train RMSE: 0.2576
# Val RMSE: 0.2534, Val MAE: 0.1078
# Test RMSE: 0.3322, Test MAE: 0.1474
# ---------------------------------
# Model saved at epoch 24 with val RMSE 0.2534
# Patience grace period: 40
# ---------------------------------
# Epoch 25/500
# Train RMSE: 0.2574
# Val RMSE: 0.2532, Val MAE: 0.1081
# Test RMSE: 0.3319, Test MAE: 0.1475
# ---------------------------------
# Model saved at epoch 25 with val RMSE 0.2532
# Patience grace period: 40
# ---------------------------------
# Epoch 26/500
# Train RMSE: 0.2571
# Val RMSE: 0.2531, Val MAE: 0.1084
# Test RMSE: 0.3318, Test MAE: 0.1478
# ---------------------------------
# Model saved at epoch 26 with val RMSE 0.2531
# Patience grace period: 40
# ---------------------------------
# Epoch 27/500
# Train RMSE: 0.2569
# Val RMSE: 0.2529, Val MAE: 0.1084
# Test RMSE: 0.3313, Test MAE: 0.1478
# ---------------------------------
# Model saved at epoch 27 with val RMSE 0.2529
# Patience grace period: 40
# ---------------------------------
# Epoch 28/500
# Train RMSE: 0.2568
# Val RMSE: 0.2528, Val MAE: 0.1083
# Test RMSE: 0.3309, Test MAE: 0.1478
# ---------------------------------
# Model saved at epoch 28 with val RMSE 0.2528
# Patience grace period: 39
# ---------------------------------
# Epoch 29/500
# Train RMSE: 0.2565
# Val RMSE: 0.2526, Val MAE: 0.1081
# Test RMSE: 0.3310, Test MAE: 0.1477
# ---------------------------------
# Model saved at epoch 29 with val RMSE 0.2526
# Patience grace period: 40
# ---------------------------------
# Epoch 30/500
# Train RMSE: 0.2563
# Val RMSE: 0.2525, Val MAE: 0.1083
# Test RMSE: 0.3307, Test MAE: 0.1477
# ---------------------------------
# Model saved at epoch 30 with val RMSE 0.2525
# Patience grace period: 40
# ---------------------------------
# Epoch 31/500
# Train RMSE: 0.2562
# Val RMSE: 0.2522, Val MAE: 0.1089
# Test RMSE: 0.3295, Test MAE: 0.1482
# ---------------------------------
# Model saved at epoch 31 with val RMSE 0.2522
# Patience grace period: 40
# ---------------------------------
# Epoch 32/500
# Train RMSE: 0.2560
# Val RMSE: 0.2521, Val MAE: 0.1086
# Test RMSE: 0.3296, Test MAE: 0.1481
# ---------------------------------
# Model saved at epoch 32 with val RMSE 0.2521
# Patience grace period: 40
# ---------------------------------
# Epoch 33/500
# Train RMSE: 0.2558
# Val RMSE: 0.2521, Val MAE: 0.1082
# Test RMSE: 0.3299, Test MAE: 0.1478
# ---------------------------------
# Model saved at epoch 33 with val RMSE 0.2521
# Patience grace period: 39
# ---------------------------------
# Epoch 34/500
# Train RMSE: 0.2556
# Val RMSE: 0.2520, Val MAE: 0.1080
# Test RMSE: 0.3304, Test MAE: 0.1478
# ---------------------------------
# Model saved at epoch 34 with val RMSE 0.2520
# Patience grace period: 40
# ---------------------------------
# Epoch 35/500
# Train RMSE: 0.2555
# Val RMSE: 0.2519, Val MAE: 0.1078
# Test RMSE: 0.3305, Test MAE: 0.1476
# ---------------------------------
# Model saved at epoch 35 with val RMSE 0.2519
# Patience grace period: 39
# ---------------------------------
# Epoch 36/500
# Train RMSE: 0.2554
# Val RMSE: 0.2518, Val MAE: 0.1081
# Test RMSE: 0.3296, Test MAE: 0.1479
# ---------------------------------
# Model saved at epoch 36 with val RMSE 0.2518
# Patience grace period: 40
# ---------------------------------
# Epoch 37/500
# Train RMSE: 0.2553
# Val RMSE: 0.2518, Val MAE: 0.1078
# Test RMSE: 0.3305, Test MAE: 0.1478
# ---------------------------------
# Patience grace period: 38
# ---------------------------------
# Epoch 38/500
# Train RMSE: 0.2552
# Val RMSE: 0.2516, Val MAE: 0.1086
# Test RMSE: 0.3289, Test MAE: 0.1484
# ---------------------------------
# Model saved at epoch 38 with val RMSE 0.2516
# Patience grace period: 40
# ---------------------------------
# Epoch 39/500
# Train RMSE: 0.2550
# Val RMSE: 0.2515, Val MAE: 0.1078
# Test RMSE: 0.3298, Test MAE: 0.1479
# ---------------------------------
# Model saved at epoch 39 with val RMSE 0.2515
# Patience grace period: 39
# ---------------------------------
# Epoch 40/500
# Train RMSE: 0.2549
# Val RMSE: 0.2515, Val MAE: 0.1081
# Test RMSE: 0.3289, Test MAE: 0.1480
# ---------------------------------
# Model saved at epoch 40 with val RMSE 0.2515
# Patience grace period: 40
# ---------------------------------
# Epoch 41/500
# Train RMSE: 0.2549
# Val RMSE: 0.2514, Val MAE: 0.1083
# Test RMSE: 0.3293, Test MAE: 0.1482
# ---------------------------------
# Model saved at epoch 41 with val RMSE 0.2514
# Patience grace period: 39
# ---------------------------------
# Epoch 42/500
# Train RMSE: 0.2548
# Val RMSE: 0.2513, Val MAE: 0.1081
# Test RMSE: 0.3288, Test MAE: 0.1480
# ---------------------------------
# Model saved at epoch 42 with val RMSE 0.2513
# Patience grace period: 40
# ---------------------------------
# Epoch 43/500
# Train RMSE: 0.2547
# Val RMSE: 0.2514, Val MAE: 0.1076
# Test RMSE: 0.3296, Test MAE: 0.1482
# ---------------------------------
# Patience grace period: 38
# ---------------------------------
# Epoch 44/500
# Train RMSE: 0.2546
# Val RMSE: 0.2515, Val MAE: 0.1073
# Test RMSE: 0.3306, Test MAE: 0.1478
# ---------------------------------
# Patience grace period: 36
# ---------------------------------
# Epoch 45/500
# Train RMSE: 0.2545
# Val RMSE: 0.2512, Val MAE: 0.1072
# Test RMSE: 0.3300, Test MAE: 0.1476
# ---------------------------------
# Model saved at epoch 45 with val RMSE 0.2512
# Patience grace period: 35
# ---------------------------------
# Epoch 46/500
# Train RMSE: 0.2544
# Val RMSE: 0.2511, Val MAE: 0.1076
# Test RMSE: 0.3287, Test MAE: 0.1481
# ---------------------------------
# Model saved at epoch 46 with val RMSE 0.2511
# Patience grace period: 40
# ---------------------------------
# Epoch 47/500
# Train RMSE: 0.2543
# Val RMSE: 0.2509, Val MAE: 0.1083
# Test RMSE: 0.3278, Test MAE: 0.1481
# ---------------------------------
# Model saved at epoch 47 with val RMSE 0.2509
# Patience grace period: 40
# ---------------------------------
# Epoch 48/500
# Train RMSE: 0.2543
# Val RMSE: 0.2510, Val MAE: 0.1074
# Test RMSE: 0.3293, Test MAE: 0.1479
# ---------------------------------
# Patience grace period: 38
# ---------------------------------
# Epoch 49/500
# Train RMSE: 0.2542
# Val RMSE: 0.2509, Val MAE: 0.1080
# Test RMSE: 0.3288, Test MAE: 0.1482
# ---------------------------------
# Patience grace period: 37
# ---------------------------------
# Epoch 50/500
# Train RMSE: 0.2541
# Val RMSE: 0.2509, Val MAE: 0.1074
# Test RMSE: 0.3294, Test MAE: 0.1475
# ---------------------------------
# Patience grace period: 36
# ---------------------------------
# Epoch 51/500
# Train RMSE: 0.2540
# Val RMSE: 0.2509, Val MAE: 0.1072
# Test RMSE: 0.3295, Test MAE: 0.1478
# ---------------------------------
# Patience grace period: 34
# ---------------------------------
# Epoch 52/500
# Train RMSE: 0.2540
# Val RMSE: 0.2508, Val MAE: 0.1077
# Test RMSE: 0.3283, Test MAE: 0.1482
# ---------------------------------
# Model saved at epoch 52 with val RMSE 0.2508
# Patience grace period: 33
# ---------------------------------
# Epoch 53/500
# Train RMSE: 0.2539
# Val RMSE: 0.2508, Val MAE: 0.1078
# Test RMSE: 0.3281, Test MAE: 0.1481
# ---------------------------------
# Model saved at epoch 53 with val RMSE 0.2508
# Patience grace period: 40
# ---------------------------------
# Epoch 54/500
# Train RMSE: 0.2539
# Val RMSE: 0.2507, Val MAE: 0.1075
# Test RMSE: 0.3288, Test MAE: 0.1478
# ---------------------------------
# Model saved at epoch 54 with val RMSE 0.2507
# Patience grace period: 39
# ---------------------------------
# Epoch 55/500
# Train RMSE: 0.2538
# Val RMSE: 0.2508, Val MAE: 0.1077
# Test RMSE: 0.3284, Test MAE: 0.1482
# ---------------------------------
# Patience grace period: 37
# ---------------------------------
# Epoch 56/500
# Train RMSE: 0.2538
# Val RMSE: 0.2507, Val MAE: 0.1071
# Test RMSE: 0.3293, Test MAE: 0.1477
# ---------------------------------
# Model saved at epoch 56 with val RMSE 0.2507
# Patience grace period: 36
# ---------------------------------
# Epoch 57/500
# Train RMSE: 0.2538
# Val RMSE: 0.2505, Val MAE: 0.1084
# Test RMSE: 0.3270, Test MAE: 0.1485
# ---------------------------------
# Model saved at epoch 57 with val RMSE 0.2505
# Patience grace period: 40
# ---------------------------------
# Epoch 58/500
# Train RMSE: 0.2537
# Val RMSE: 0.2507, Val MAE: 0.1071
# Test RMSE: 0.3296, Test MAE: 0.1479
# ---------------------------------
# Patience grace period: 38
# ---------------------------------
# Epoch 59/500
# Train RMSE: 0.2536
# Val RMSE: 0.2507, Val MAE: 0.1068
# Test RMSE: 0.3300, Test MAE: 0.1476
# ---------------------------------
# Patience grace period: 37
# ---------------------------------
# Epoch 60/500
# Train RMSE: 0.2536
# Val RMSE: 0.2505, Val MAE: 0.1072
# Test RMSE: 0.3287, Test MAE: 0.1477
# ---------------------------------
# Model saved at epoch 60 with val RMSE 0.2505
# Patience grace period: 36
# ---------------------------------
# Epoch 61/500
# Train RMSE: 0.2536
# Val RMSE: 0.2505, Val MAE: 0.1075
# Test RMSE: 0.3279, Test MAE: 0.1477
# ---------------------------------
# Model saved at epoch 61 with val RMSE 0.2505
# Patience grace period: 35
# ---------------------------------
# Epoch 62/500
# Train RMSE: 0.2535
# Val RMSE: 0.2504, Val MAE: 0.1078
# Test RMSE: 0.3275, Test MAE: 0.1482
# ---------------------------------
# Model saved at epoch 62 with val RMSE 0.2504
# Patience grace period: 40
# ---------------------------------
# Epoch 63/500
# Train RMSE: 0.2534
# Val RMSE: 0.2505, Val MAE: 0.1071
# Test RMSE: 0.3293, Test MAE: 0.1477
# ---------------------------------
# Patience grace period: 38
# ---------------------------------
# Epoch 64/500
# Train RMSE: 0.2534
# Val RMSE: 0.2504, Val MAE: 0.1079
# Test RMSE: 0.3278, Test MAE: 0.1482
# ---------------------------------
# Model saved at epoch 64 with val RMSE 0.2504
# Patience grace period: 37
# ---------------------------------
# Epoch 65/500
# Train RMSE: 0.2534
# Val RMSE: 0.2504, Val MAE: 0.1074
# Test RMSE: 0.3284, Test MAE: 0.1478
# ---------------------------------
# Model saved at epoch 65 with val RMSE 0.2504
# Patience grace period: 36
# ---------------------------------
# Epoch 66/500
# Train RMSE: 0.2533
# Val RMSE: 0.2503, Val MAE: 0.1072
# Test RMSE: 0.3287, Test MAE: 0.1476
# ---------------------------------
# Model saved at epoch 66 with val RMSE 0.2503
# Patience grace period: 40
# ---------------------------------
# Epoch 67/500
# Train RMSE: 0.2532
# Val RMSE: 0.2502, Val MAE: 0.1073
# Test RMSE: 0.3283, Test MAE: 0.1477
# ---------------------------------
# Model saved at epoch 67 with val RMSE 0.2502
# Patience grace period: 39
# ---------------------------------
# Epoch 68/500
# Train RMSE: 0.2532
# Val RMSE: 0.2503, Val MAE: 0.1072
# Test RMSE: 0.3292, Test MAE: 0.1479
# ---------------------------------
# Patience grace period: 37
# ---------------------------------
# Epoch 69/500
# Train RMSE: 0.2532
# Val RMSE: 0.2502, Val MAE: 0.1077
# Test RMSE: 0.3272, Test MAE: 0.1479
# ---------------------------------
# Patience grace period: 36
# ---------------------------------
# Epoch 70/500
# Train RMSE: 0.2531
# Val RMSE: 0.2502, Val MAE: 0.1073
# Test RMSE: 0.3280, Test MAE: 0.1479
# ---------------------------------
# Model saved at epoch 70 with val RMSE 0.2502
# Patience grace period: 35
# ---------------------------------
# Epoch 71/500
# Train RMSE: 0.2531
# Val RMSE: 0.2501, Val MAE: 0.1072
# Test RMSE: 0.3281, Test MAE: 0.1478
# ---------------------------------
# Model saved at epoch 71 with val RMSE 0.2501
# Patience grace period: 40
# ---------------------------------
# Epoch 72/500
# Train RMSE: 0.2530
# Val RMSE: 0.2501, Val MAE: 0.1077
# Test RMSE: 0.3274, Test MAE: 0.1484
# ---------------------------------
# Patience grace period: 38
# ---------------------------------
# Epoch 73/500
# Train RMSE: 0.2530
# Val RMSE: 0.2501, Val MAE: 0.1072
# Test RMSE: 0.3278, Test MAE: 0.1479
# ---------------------------------
# Patience grace period: 36
# ---------------------------------
# Epoch 74/500
# Train RMSE: 0.2529
# Val RMSE: 0.2500, Val MAE: 0.1080
# Test RMSE: 0.3263, Test MAE: 0.1483
# ---------------------------------
# Model saved at epoch 74 with val RMSE 0.2500
# Patience grace period: 40
# ---------------------------------
# Epoch 75/500
# Train RMSE: 0.2529
# Val RMSE: 0.2502, Val MAE: 0.1068
# Test RMSE: 0.3291, Test MAE: 0.1476
# ---------------------------------
# Patience grace period: 38
# ---------------------------------
# Epoch 76/500
# Train RMSE: 0.2529
# Val RMSE: 0.2500, Val MAE: 0.1073
# Test RMSE: 0.3277, Test MAE: 0.1479
# ---------------------------------
# Model saved at epoch 76 with val RMSE 0.2500
# Patience grace period: 37
# ---------------------------------
# Epoch 77/500
# Train RMSE: 0.2528
# Val RMSE: 0.2499, Val MAE: 0.1075
# Test RMSE: 0.3273, Test MAE: 0.1481
# ---------------------------------
# Model saved at epoch 77 with val RMSE 0.2499
# Patience grace period: 36
# ---------------------------------
# Epoch 78/500
# Train RMSE: 0.2527
# Val RMSE: 0.2500, Val MAE: 0.1070
# Test RMSE: 0.3281, Test MAE: 0.1477
# ---------------------------------
# Patience grace period: 34
# ---------------------------------
# Epoch 79/500
# Train RMSE: 0.2528
# Val RMSE: 0.2499, Val MAE: 0.1071
# Test RMSE: 0.3283, Test MAE: 0.1477
# ---------------------------------
# Patience grace period: 33
# ---------------------------------
# Epoch 80/500
# Train RMSE: 0.2527
# Val RMSE: 0.2499, Val MAE: 0.1073
# Test RMSE: 0.3267, Test MAE: 0.1480
# ---------------------------------
# Model saved at epoch 80 with val RMSE 0.2499
# Patience grace period: 32
# ---------------------------------
# Epoch 81/500
# Train RMSE: 0.2527
# Val RMSE: 0.2499, Val MAE: 0.1067
# Test RMSE: 0.3281, Test MAE: 0.1474
# ---------------------------------
# Patience grace period: 30
# ---------------------------------
# Epoch 82/500
# Train RMSE: 0.2526
# Val RMSE: 0.2498, Val MAE: 0.1076
# Test RMSE: 0.3270, Test MAE: 0.1485
# ---------------------------------
# Model saved at epoch 82 with val RMSE 0.2498
# Patience grace period: 40
# ---------------------------------
# Epoch 83/500
# Train RMSE: 0.2526
# Val RMSE: 0.2499, Val MAE: 0.1070
# Test RMSE: 0.3274, Test MAE: 0.1478
# ---------------------------------
# Patience grace period: 38
# ---------------------------------
# Epoch 84/500
# Train RMSE: 0.2525
# Val RMSE: 0.2498, Val MAE: 0.1068
# Test RMSE: 0.3278, Test MAE: 0.1477
# ---------------------------------
# Patience grace period: 37
# ---------------------------------
# Epoch 85/500
# Train RMSE: 0.2526
# Val RMSE: 0.2497, Val MAE: 0.1075
# Test RMSE: 0.3269, Test MAE: 0.1482
# ---------------------------------
# Model saved at epoch 85 with val RMSE 0.2497
# Patience grace period: 36
# ---------------------------------
# Epoch 86/500
# Train RMSE: 0.2525
# Val RMSE: 0.2498, Val MAE: 0.1072
# Test RMSE: 0.3273, Test MAE: 0.1479
# ---------------------------------
# Patience grace period: 34
# ---------------------------------
# Epoch 87/500
# Train RMSE: 0.2525
# Val RMSE: 0.2497, Val MAE: 0.1074
# Test RMSE: 0.3270, Test MAE: 0.1481
# ---------------------------------
# Model saved at epoch 87 with val RMSE 0.2497
# Patience grace period: 33
# ---------------------------------
# Epoch 88/500
# Train RMSE: 0.2524
# Val RMSE: 0.2497, Val MAE: 0.1075
# Test RMSE: 0.3262, Test MAE: 0.1483
# ---------------------------------
# Model saved at epoch 88 with val RMSE 0.2497
# Patience grace period: 40
# ---------------------------------
# Epoch 89/500
# Train RMSE: 0.2524
# Val RMSE: 0.2498, Val MAE: 0.1070
# Test RMSE: 0.3279, Test MAE: 0.1478
# ---------------------------------
# Patience grace period: 38
# ---------------------------------
# Epoch 90/500
# Train RMSE: 0.2523
# Val RMSE: 0.2496, Val MAE: 0.1071
# Test RMSE: 0.3271, Test MAE: 0.1478
# ---------------------------------
# Model saved at epoch 90 with val RMSE 0.2496
# Patience grace period: 37
# ---------------------------------
# Epoch 91/500
# Train RMSE: 0.2523
# Val RMSE: 0.2498, Val MAE: 0.1066
# Test RMSE: 0.3283, Test MAE: 0.1476
# ---------------------------------
# Patience grace period: 35
# ---------------------------------
# Epoch 92/500
# Train RMSE: 0.2522
# Val RMSE: 0.2497, Val MAE: 0.1077
# Test RMSE: 0.3262, Test MAE: 0.1484
# ---------------------------------
# Patience grace period: 34
# ---------------------------------
# Epoch 93/500
# Train RMSE: 0.2522
# Val RMSE: 0.2496, Val MAE: 0.1077
# Test RMSE: 0.3264, Test MAE: 0.1483
# ---------------------------------
# Model saved at epoch 93 with val RMSE 0.2496
# Patience grace period: 40
# ---------------------------------
# Epoch 94/500
# Train RMSE: 0.2522
# Val RMSE: 0.2497, Val MAE: 0.1064
# Test RMSE: 0.3282, Test MAE: 0.1476
# ---------------------------------
# Patience grace period: 38
# ---------------------------------
# Epoch 95/500
# Train RMSE: 0.2521
# Val RMSE: 0.2496, Val MAE: 0.1069
# Test RMSE: 0.3279, Test MAE: 0.1480
# ---------------------------------
# Patience grace period: 37
# ---------------------------------
# Epoch 96/500
# Train RMSE: 0.2521
# Val RMSE: 0.2496, Val MAE: 0.1073
# Test RMSE: 0.3272, Test MAE: 0.1481
# ---------------------------------
# Model saved at epoch 96 with val RMSE 0.2496
# Patience grace period: 36
# ---------------------------------
# Epoch 97/500
# Train RMSE: 0.2520
# Val RMSE: 0.2496, Val MAE: 0.1063
# Test RMSE: 0.3288, Test MAE: 0.1476
# ---------------------------------
# Patience grace period: 34
# ---------------------------------
# Epoch 98/500
# Train RMSE: 0.2520
# Val RMSE: 0.2496, Val MAE: 0.1069
# Test RMSE: 0.3278, Test MAE: 0.1479
# ---------------------------------
# Model saved at epoch 98 with val RMSE 0.2496
# Patience grace period: 33
# ---------------------------------
# Epoch 99/500
# Train RMSE: 0.2519
# Val RMSE: 0.2494, Val MAE: 0.1070
# Test RMSE: 0.3265, Test MAE: 0.1478
# ---------------------------------
# Model saved at epoch 99 with val RMSE 0.2494
# Patience grace period: 40
# ---------------------------------
# Epoch 100/500
# Train RMSE: 0.2519
# Val RMSE: 0.2495, Val MAE: 0.1071
# Test RMSE: 0.3268, Test MAE: 0.1480
# ---------------------------------
# Patience grace period: 38
# ---------------------------------
# Epoch 101/500
# Train RMSE: 0.2518
# Val RMSE: 0.2495, Val MAE: 0.1068
# Test RMSE: 0.3276, Test MAE: 0.1476
# ---------------------------------
# Patience grace period: 36
# ---------------------------------
# Epoch 102/500
# Train RMSE: 0.2518
# Val RMSE: 0.2494, Val MAE: 0.1077
# Test RMSE: 0.3261, Test MAE: 0.1485
# ---------------------------------
# Model saved at epoch 102 with val RMSE 0.2494
# Patience grace period: 35
# ---------------------------------
# Epoch 103/500
# Train RMSE: 0.2518
# Val RMSE: 0.2494, Val MAE: 0.1072
# Test RMSE: 0.3263, Test MAE: 0.1480
# ---------------------------------
# Model saved at epoch 103 with val RMSE 0.2494
# Patience grace period: 33
# ---------------------------------
# Epoch 104/500
# Train RMSE: 0.2517
# Val RMSE: 0.2493, Val MAE: 0.1070
# Test RMSE: 0.3263, Test MAE: 0.1481
# ---------------------------------
# Model saved at epoch 104 with val RMSE 0.2493
# Patience grace period: 32
# ---------------------------------
# Epoch 105/500
# Train RMSE: 0.2517
# Val RMSE: 0.2495, Val MAE: 0.1065
# Test RMSE: 0.3281, Test MAE: 0.1477
# ---------------------------------
# Patience grace period: 30
# ---------------------------------
# Epoch 106/500
# Train RMSE: 0.2517
# Val RMSE: 0.2496, Val MAE: 0.1062
# Test RMSE: 0.3291, Test MAE: 0.1473
# ---------------------------------
# Patience grace period: 28
# ---------------------------------
# Epoch 107/500
# Train RMSE: 0.2516
# Val RMSE: 0.2494, Val MAE: 0.1071
# Test RMSE: 0.3277, Test MAE: 0.1482
# ---------------------------------
# Patience grace period: 27
# ---------------------------------
# Epoch 108/500
# Train RMSE: 0.2515
# Val RMSE: 0.2494, Val MAE: 0.1068
# Test RMSE: 0.3277, Test MAE: 0.1481
# ---------------------------------
# Patience grace period: 25
# ---------------------------------
# Epoch 109/500
# Train RMSE: 0.2515
# Val RMSE: 0.2494, Val MAE: 0.1069
# Test RMSE: 0.3277, Test MAE: 0.1480
# ---------------------------------
# Patience grace period: 24
# ---------------------------------
# Epoch 110/500
# Train RMSE: 0.2514
# Val RMSE: 0.2495, Val MAE: 0.1063
# Test RMSE: 0.3282, Test MAE: 0.1478
# ---------------------------------
# Patience grace period: 22
# ---------------------------------
# Epoch 111/500
# Train RMSE: 0.2515
# Val RMSE: 0.2493, Val MAE: 0.1072
# Test RMSE: 0.3269, Test MAE: 0.1479
# ---------------------------------
# Model saved at epoch 111 with val RMSE 0.2493
# Patience grace period: 21
# ---------------------------------
# Epoch 112/500
# Train RMSE: 0.2514
# Val RMSE: 0.2493, Val MAE: 0.1076
# Test RMSE: 0.3259, Test MAE: 0.1485
# ---------------------------------
# Model saved at epoch 112 with val RMSE 0.2493
# Patience grace period: 20
# ---------------------------------
# Epoch 113/500
# Train RMSE: 0.2514
# Val RMSE: 0.2494, Val MAE: 0.1082
# Test RMSE: 0.3240, Test MAE: 0.1490
# ---------------------------------
# Patience grace period: 18
# ---------------------------------
# Epoch 114/500
# Train RMSE: 0.2513
# Val RMSE: 0.2493, Val MAE: 0.1072
# Test RMSE: 0.3262, Test MAE: 0.1484
# ---------------------------------
# Patience grace period: 17
# ---------------------------------
# Epoch 115/500
# Train RMSE: 0.2513
# Val RMSE: 0.2492, Val MAE: 0.1077
# Test RMSE: 0.3255, Test MAE: 0.1484
# ---------------------------------
# Model saved at epoch 115 with val RMSE 0.2492
# Patience grace period: 40
# ---------------------------------
# Epoch 116/500
# Train RMSE: 0.2512
# Val RMSE: 0.2492, Val MAE: 0.1072
# Test RMSE: 0.3266, Test MAE: 0.1482
# ---------------------------------
# Patience grace period: 38
# ---------------------------------
# Epoch 117/500
# Train RMSE: 0.2512
# Val RMSE: 0.2492, Val MAE: 0.1072
# Test RMSE: 0.3275, Test MAE: 0.1485
# ---------------------------------
# Patience grace period: 37
# ---------------------------------
# Epoch 118/500
# Train RMSE: 0.2512
# Val RMSE: 0.2491, Val MAE: 0.1070
# Test RMSE: 0.3266, Test MAE: 0.1481
# ---------------------------------
# Model saved at epoch 118 with val RMSE 0.2491
# Patience grace period: 36
# ---------------------------------
# Epoch 119/500
# Train RMSE: 0.2511
# Val RMSE: 0.2492, Val MAE: 0.1076
# Test RMSE: 0.3259, Test MAE: 0.1489
# ---------------------------------
# Patience grace period: 34
# ---------------------------------
# Epoch 120/500
# Train RMSE: 0.2511
# Val RMSE: 0.2492, Val MAE: 0.1078
# Test RMSE: 0.3252, Test MAE: 0.1486
# ---------------------------------
# Patience grace period: 32
# ---------------------------------
# Epoch 121/500
# Train RMSE: 0.2510
# Val RMSE: 0.2494, Val MAE: 0.1062
# Test RMSE: 0.3287, Test MAE: 0.1479
# ---------------------------------
# Patience grace period: 30
# ---------------------------------
# Epoch 122/500
# Train RMSE: 0.2510
# Val RMSE: 0.2492, Val MAE: 0.1074
# Test RMSE: 0.3252, Test MAE: 0.1486
# ---------------------------------
# Patience grace period: 29
# ---------------------------------
# Epoch 123/500
# Train RMSE: 0.2510
# Val RMSE: 0.2491, Val MAE: 0.1072
# Test RMSE: 0.3262, Test MAE: 0.1487
# ---------------------------------
# Patience grace period: 28
# ---------------------------------
# Epoch 124/500
# Train RMSE: 0.2509
# Val RMSE: 0.2492, Val MAE: 0.1071
# Test RMSE: 0.3266, Test MAE: 0.1482
# ---------------------------------
# Patience grace period: 26
# ---------------------------------
# Epoch 125/500
# Train RMSE: 0.2509
# Val RMSE: 0.2491, Val MAE: 0.1073
# Test RMSE: 0.3258, Test MAE: 0.1485
# ---------------------------------
# Model saved at epoch 125 with val RMSE 0.2491
# Patience grace period: 40
# ---------------------------------
# Epoch 126/500
# Train RMSE: 0.2508
# Val RMSE: 0.2491, Val MAE: 0.1070
# Test RMSE: 0.3271, Test MAE: 0.1483
# ---------------------------------
# Patience grace period: 38
# ---------------------------------
# Epoch 127/500
# Train RMSE: 0.2508
# Val RMSE: 0.2491, Val MAE: 0.1068
# Test RMSE: 0.3268, Test MAE: 0.1481
# ---------------------------------
# Model saved at epoch 127 with val RMSE 0.2491
# Patience grace period: 37
# ---------------------------------
# Epoch 128/500
# Train RMSE: 0.2507
# Val RMSE: 0.2491, Val MAE: 0.1069
# Test RMSE: 0.3269, Test MAE: 0.1484
# ---------------------------------
# Patience grace period: 35
# ---------------------------------
# Epoch 129/500
# Train RMSE: 0.2507
# Val RMSE: 0.2490, Val MAE: 0.1068
# Test RMSE: 0.3273, Test MAE: 0.1481
# ---------------------------------
# Model saved at epoch 129 with val RMSE 0.2490
# Patience grace period: 34
# ---------------------------------
# Epoch 130/500
# Train RMSE: 0.2506
# Val RMSE: 0.2491, Val MAE: 0.1072
# Test RMSE: 0.3263, Test MAE: 0.1487
# ---------------------------------
# Patience grace period: 32
# ---------------------------------
# Epoch 131/500
# Train RMSE: 0.2506
# Val RMSE: 0.2491, Val MAE: 0.1065
# Test RMSE: 0.3269, Test MAE: 0.1482
# ---------------------------------
# Patience grace period: 31
# ---------------------------------
# Epoch 132/500
# Train RMSE: 0.2506
# Val RMSE: 0.2490, Val MAE: 0.1069
# Test RMSE: 0.3264, Test MAE: 0.1483
# ---------------------------------
# Model saved at epoch 132 with val RMSE 0.2490
# Patience grace period: 30
# ---------------------------------
# Epoch 133/500
# Train RMSE: 0.2506
# Val RMSE: 0.2490, Val MAE: 0.1070
# Test RMSE: 0.3262, Test MAE: 0.1485
# ---------------------------------
# Model saved at epoch 133 with val RMSE 0.2490
# Patience grace period: 40
# ---------------------------------
# Epoch 134/500
# Train RMSE: 0.2505
# Val RMSE: 0.2490, Val MAE: 0.1066
# Test RMSE: 0.3275, Test MAE: 0.1480
# ---------------------------------
# Patience grace period: 38
# ---------------------------------
# Epoch 135/500
# Train RMSE: 0.2505
# Val RMSE: 0.2490, Val MAE: 0.1069
# Test RMSE: 0.3264, Test MAE: 0.1483
# ---------------------------------
# Patience grace period: 37
# ---------------------------------
# Epoch 136/500
# Train RMSE: 0.2505
# Val RMSE: 0.2490, Val MAE: 0.1066
# Test RMSE: 0.3265, Test MAE: 0.1483
# ---------------------------------
# Patience grace period: 35
# ---------------------------------
# Epoch 137/500
# Train RMSE: 0.2504
# Val RMSE: 0.2491, Val MAE: 0.1073
# Test RMSE: 0.3254, Test MAE: 0.1486
# ---------------------------------
# Patience grace period: 33
# ---------------------------------
# Epoch 138/500
# Train RMSE: 0.2504
# Val RMSE: 0.2489, Val MAE: 0.1072
# Test RMSE: 0.3256, Test MAE: 0.1484
# ---------------------------------
# Model saved at epoch 138 with val RMSE 0.2489
# Patience grace period: 32
# ---------------------------------
# Epoch 139/500
# Train RMSE: 0.2503
# Val RMSE: 0.2491, Val MAE: 0.1066
# Test RMSE: 0.3271, Test MAE: 0.1482
# ---------------------------------
# Patience grace period: 30
# ---------------------------------
# Epoch 140/500
# Train RMSE: 0.2503
# Val RMSE: 0.2489, Val MAE: 0.1071
# Test RMSE: 0.3261, Test MAE: 0.1486
# ---------------------------------
# Model saved at epoch 140 with val RMSE 0.2489
# Patience grace period: 29
# ---------------------------------
# Epoch 141/500
# Train RMSE: 0.2503
# Val RMSE: 0.2489, Val MAE: 0.1067
# Test RMSE: 0.3267, Test MAE: 0.1482
# ---------------------------------
# Patience grace period: 27
# ---------------------------------
# Epoch 142/500
# Train RMSE: 0.2502
# Val RMSE: 0.2489, Val MAE: 0.1070
# Test RMSE: 0.3260, Test MAE: 0.1484
# ---------------------------------
# Patience grace period: 25
# ---------------------------------
# Epoch 143/500
# Train RMSE: 0.2502
# Val RMSE: 0.2490, Val MAE: 0.1080
# Test RMSE: 0.3243, Test MAE: 0.1491
# ---------------------------------
# Patience grace period: 23
# ---------------------------------
# Epoch 144/500
# Train RMSE: 0.2502
# Val RMSE: 0.2489, Val MAE: 0.1070
# Test RMSE: 0.3261, Test MAE: 0.1485
# ---------------------------------
# Model saved at epoch 144 with val RMSE 0.2489
# Patience grace period: 22
# ---------------------------------
# Epoch 145/500
# Train RMSE: 0.2501
# Val RMSE: 0.2489, Val MAE: 0.1068
# Test RMSE: 0.3264, Test MAE: 0.1486
# ---------------------------------
# Patience grace period: 20
# ---------------------------------
# Epoch 146/500
# Train RMSE: 0.2501
# Val RMSE: 0.2489, Val MAE: 0.1067
# Test RMSE: 0.3265, Test MAE: 0.1485
# ---------------------------------
# Model saved at epoch 146 with val RMSE 0.2489
# Patience grace period: 19
# ---------------------------------
# Epoch 147/500
# Train RMSE: 0.2501
# Val RMSE: 0.2488, Val MAE: 0.1068
# Test RMSE: 0.3264, Test MAE: 0.1485
# ---------------------------------
# Model saved at epoch 147 with val RMSE 0.2488
# Patience grace period: 40
# ---------------------------------
# Epoch 148/500
# Train RMSE: 0.2500
# Val RMSE: 0.2490, Val MAE: 0.1063
# Test RMSE: 0.3273, Test MAE: 0.1483
# ---------------------------------
# Patience grace period: 38
# ---------------------------------
# Epoch 149/500
# Train RMSE: 0.2500
# Val RMSE: 0.2489, Val MAE: 0.1074
# Test RMSE: 0.3253, Test MAE: 0.1491
# ---------------------------------
# Patience grace period: 37
# ---------------------------------
# Epoch 150/500
# Train RMSE: 0.2500
# Val RMSE: 0.2489, Val MAE: 0.1065
# Test RMSE: 0.3271, Test MAE: 0.1486
# ---------------------------------
# Patience grace period: 35
# ---------------------------------
# Epoch 151/500
# Train RMSE: 0.2500
# Val RMSE: 0.2489, Val MAE: 0.1072
# Test RMSE: 0.3254, Test MAE: 0.1491
# ---------------------------------
# Patience grace period: 34
# ---------------------------------
# Epoch 152/500
# Train RMSE: 0.2499
# Val RMSE: 0.2489, Val MAE: 0.1073
# Test RMSE: 0.3251, Test MAE: 0.1492
# ---------------------------------
# Patience grace period: 33
# ---------------------------------
# Epoch 153/500
# Train RMSE: 0.2498
# Val RMSE: 0.2489, Val MAE: 0.1067
# Test RMSE: 0.3271, Test MAE: 0.1486
# ---------------------------------
# Patience grace period: 32
# ---------------------------------
# Epoch 154/500
# Train RMSE: 0.2498
# Val RMSE: 0.2488, Val MAE: 0.1067
# Test RMSE: 0.3266, Test MAE: 0.1487
# ---------------------------------
# Patience grace period: 31
# ---------------------------------
# Epoch 155/500
# Train RMSE: 0.2499
# Val RMSE: 0.2490, Val MAE: 0.1069
# Test RMSE: 0.3258, Test MAE: 0.1487
# ---------------------------------
# Patience grace period: 29
# ---------------------------------
# Epoch 156/500
# Train RMSE: 0.2498
# Val RMSE: 0.2489, Val MAE: 0.1073
# Test RMSE: 0.3255, Test MAE: 0.1492
# ---------------------------------
# Patience grace period: 28
# ---------------------------------
# Epoch 157/500
# Train RMSE: 0.2498
# Val RMSE: 0.2488, Val MAE: 0.1073
# Test RMSE: 0.3248, Test MAE: 0.1492
# ---------------------------------
# Model saved at epoch 157 with val RMSE 0.2488
# Patience grace period: 27
# ---------------------------------
# Epoch 158/500
# Train RMSE: 0.2497
# Val RMSE: 0.2488, Val MAE: 0.1071
# Test RMSE: 0.3254, Test MAE: 0.1490
# ---------------------------------
# Patience grace period: 25
# ---------------------------------
# Epoch 159/500
# Train RMSE: 0.2497
# Val RMSE: 0.2488, Val MAE: 0.1066
# Test RMSE: 0.3270, Test MAE: 0.1485
# ---------------------------------
# Patience grace period: 23
# ---------------------------------
# Epoch 160/500
# Train RMSE: 0.2497
# Val RMSE: 0.2489, Val MAE: 0.1070
# Test RMSE: 0.3260, Test MAE: 0.1490
# ---------------------------------
# Patience grace period: 21
# ---------------------------------
# Epoch 161/500
# Train RMSE: 0.2497
# Val RMSE: 0.2490, Val MAE: 0.1068
# Test RMSE: 0.3263, Test MAE: 0.1488
# ---------------------------------
# Patience grace period: 19
# ---------------------------------
# Epoch 162/500
# Train RMSE: 0.2496
# Val RMSE: 0.2488, Val MAE: 0.1075
# Test RMSE: 0.3244, Test MAE: 0.1492
# ---------------------------------
# Patience grace period: 18
# ---------------------------------
# Epoch 163/500
# Train RMSE: 0.2496
# Val RMSE: 0.2487, Val MAE: 0.1070
# Test RMSE: 0.3252, Test MAE: 0.1491
# ---------------------------------
# Model saved at epoch 163 with val RMSE 0.2487
# Patience grace period: 17
# ---------------------------------
# Epoch 164/500
# Train RMSE: 0.2495
# Val RMSE: 0.2488, Val MAE: 0.1071
# Test RMSE: 0.3255, Test MAE: 0.1493
# ---------------------------------
# Patience grace period: 15
# ---------------------------------
# Epoch 165/500
# Train RMSE: 0.2495
# Val RMSE: 0.2487, Val MAE: 0.1073
# Test RMSE: 0.3249, Test MAE: 0.1492
# ---------------------------------
# Model saved at epoch 165 with val RMSE 0.2487
# Patience grace period: 40
# ---------------------------------
# Epoch 166/500
# Train RMSE: 0.2495
# Val RMSE: 0.2488, Val MAE: 0.1068
# Test RMSE: 0.3257, Test MAE: 0.1489
# ---------------------------------
# Patience grace period: 38
# ---------------------------------
# Epoch 167/500
# Train RMSE: 0.2495
# Val RMSE: 0.2489, Val MAE: 0.1069
# Test RMSE: 0.3254, Test MAE: 0.1490
# ---------------------------------
# Patience grace period: 36
# ---------------------------------
# Epoch 168/500
# Train RMSE: 0.2495
# Val RMSE: 0.2489, Val MAE: 0.1080
# Test RMSE: 0.3237, Test MAE: 0.1498
# ---------------------------------
# Patience grace period: 34
# ---------------------------------
# Epoch 169/500
# Train RMSE: 0.2494
# Val RMSE: 0.2488, Val MAE: 0.1073
# Test RMSE: 0.3251, Test MAE: 0.1494
# ---------------------------------
# Patience grace period: 33
# ---------------------------------
# Epoch 170/500
# Train RMSE: 0.2494
# Val RMSE: 0.2488, Val MAE: 0.1076
# Test RMSE: 0.3241, Test MAE: 0.1494
# ---------------------------------
# Patience grace period: 32
# ---------------------------------
# Epoch 171/500
# Train RMSE: 0.2494
# Val RMSE: 0.2487, Val MAE: 0.1071
# ...
# Model saved at epoch 129 with val RMSE 0.2487
# Patience grace period: 40
# ---------------------------------
# Epoch 130/500
# Train RMSE: 0.2506
# Val RMSE: 0.2487, Val MAE: 0.1065
# Test RMSE: 0.3262, Test MAE: 0.1488
# ---------------------------------
# Patience grace period: 38
# ---------------------------------
# Epoch 131/500
# Train RMSE: 0.2506
# Val RMSE: 0.2488, Val MAE: 0.1079
# Test RMSE: 0.3242, Test MAE: 0.1496
# ---------------------------------
# Patience grace period: 36
# ---------------------------------
# Epoch 132/500
# Train RMSE: 0.2505
# Val RMSE: 0.2487, Val MAE: 0.1065
# Test RMSE: 0.3264, Test MAE: 0.1487
# ---------------------------------
# Patience grace period: 35
# ---------------------------------
# Epoch 133/500
# Train RMSE: 0.2505
# Val RMSE: 0.2487, Val MAE: 0.1077
# Test RMSE: 0.3241, Test MAE: 0.1494
# ---------------------------------
# Patience grace period: 33
# ---------------------------------
# Epoch 134/500
# Train RMSE: 0.2504
# Val RMSE: 0.2487, Val MAE: 0.1068
# Test RMSE: 0.3253, Test MAE: 0.1489
# ---------------------------------
# Model saved at epoch 134 with val RMSE 0.2487
# Patience grace period: 32
# ---------------------------------
# Epoch 135/500
# Train RMSE: 0.2504
# Val RMSE: 0.2486, Val MAE: 0.1068
# Test RMSE: 0.3258, Test MAE: 0.1491
# ---------------------------------
# Model saved at epoch 135 with val RMSE 0.2486
# Patience grace period: 31
# ---------------------------------
# Epoch 136/500
# Train RMSE: 0.2505
# Val RMSE: 0.2486, Val MAE: 0.1070
# Test RMSE: 0.3256, Test MAE: 0.1490
# ---------------------------------
# Model saved at epoch 136 with val RMSE 0.2486
# Patience grace period: 30
# ---------------------------------
# Epoch 137/500
# Train RMSE: 0.2504
# Val RMSE: 0.2486, Val MAE: 0.1068
# Test RMSE: 0.3255, Test MAE: 0.1488
# ---------------------------------
# Patience grace period: 28
# ---------------------------------
# Epoch 138/500
# Train RMSE: 0.2504
# Val RMSE: 0.2486, Val MAE: 0.1068
# Test RMSE: 0.3262, Test MAE: 0.1490
# ---------------------------------
# Patience grace period: 26
# ---------------------------------
# Epoch 139/500
# Train RMSE: 0.2503
# Val RMSE: 0.2487, Val MAE: 0.1074
# Test RMSE: 0.3254, Test MAE: 0.1495
# ---------------------------------
# Patience grace period: 24
# ---------------------------------
# Epoch 140/500
# Train RMSE: 0.2503
# Val RMSE: 0.2486, Val MAE: 0.1070
# Test RMSE: 0.3250, Test MAE: 0.1493
# ---------------------------------
# Model saved at epoch 140 with val RMSE 0.2486
# Patience grace period: 23
# ---------------------------------
# Epoch 141/500
# Train RMSE: 0.2503
# Val RMSE: 0.2486, Val MAE: 0.1064
# Test RMSE: 0.3261, Test MAE: 0.1488
# ---------------------------------
# Model saved at epoch 141 with val RMSE 0.2486
# Patience grace period: 22
# ---------------------------------
# Epoch 142/500
# Train RMSE: 0.2502
# Val RMSE: 0.2486, Val MAE: 0.1069
# Test RMSE: 0.3252, Test MAE: 0.1495
# ---------------------------------
# Patience grace period: 20
# ---------------------------------
# Epoch 143/500
# Train RMSE: 0.2502
# Val RMSE: 0.2485, Val MAE: 0.1067
# Test RMSE: 0.3253, Test MAE: 0.1491
# ---------------------------------
# Model saved at epoch 143 with val RMSE 0.2485
# Patience grace period: 40
# ---------------------------------
# Epoch 144/500
# Train RMSE: 0.2502
# Val RMSE: 0.2485, Val MAE: 0.1065
# Test RMSE: 0.3255, Test MAE: 0.1484
# ---------------------------------
# Patience grace period: 38
# ---------------------------------
# Epoch 145/500
# Train RMSE: 0.2502
# Val RMSE: 0.2485, Val MAE: 0.1065
# Test RMSE: 0.3255, Test MAE: 0.1488
# ---------------------------------
# Model saved at epoch 145 with val RMSE 0.2485
# Patience grace period: 37
# ---------------------------------
# Epoch 146/500
# Train RMSE: 0.2501
# Val RMSE: 0.2485, Val MAE: 0.1066
# Test RMSE: 0.3256, Test MAE: 0.1489
# ---------------------------------
# Model saved at epoch 146 with val RMSE 0.2485
# Patience grace period: 36
# ---------------------------------
# Epoch 147/500
# Train RMSE: 0.2501
# Val RMSE: 0.2487, Val MAE: 0.1078
# Test RMSE: 0.3239, Test MAE: 0.1499
# ---------------------------------
# Patience grace period: 34
# ---------------------------------
# Epoch 148/500
# Train RMSE: 0.2500
# Val RMSE: 0.2485, Val MAE: 0.1070
# Test RMSE: 0.3253, Test MAE: 0.1490
# ---------------------------------
# Patience grace period: 33
# ---------------------------------
# Epoch 149/500
# Train RMSE: 0.2500
# Val RMSE: 0.2485, Val MAE: 0.1063
# Test RMSE: 0.3263, Test MAE: 0.1487
# ---------------------------------
# Patience grace period: 32
# ---------------------------------
# Epoch 150/500
# Train RMSE: 0.2499
# Val RMSE: 0.2485, Val MAE: 0.1067
# Test RMSE: 0.3255, Test MAE: 0.1490
# ---------------------------------
# Model saved at epoch 150 with val RMSE 0.2485
# Patience grace period: 31
# ---------------------------------
# Epoch 151/500
# Train RMSE: 0.2499
# Val RMSE: 0.2486, Val MAE: 0.1073
# Test RMSE: 0.3243, Test MAE: 0.1496
# ---------------------------------
# Patience grace period: 29
# ---------------------------------
# Epoch 152/500
# Train RMSE: 0.2499
# Val RMSE: 0.2485, Val MAE: 0.1069
# Test RMSE: 0.3256, Test MAE: 0.1492
# ---------------------------------
# Patience grace period: 28
# ---------------------------------
# Epoch 153/500
# Train RMSE: 0.2499
# Val RMSE: 0.2485, Val MAE: 0.1064
# Test RMSE: 0.3263, Test MAE: 0.1490
# ---------------------------------
# Patience grace period: 26
# ---------------------------------
# Epoch 154/500
# Train RMSE: 0.2499
# Val RMSE: 0.2485, Val MAE: 0.1063
# Test RMSE: 0.3259, Test MAE: 0.1489
# ---------------------------------
# Model saved at epoch 154 with val RMSE 0.2485
# Patience grace period: 25
# ---------------------------------
# Epoch 155/500
# Train RMSE: 0.2498
# Val RMSE: 0.2485, Val MAE: 0.1069
# Test RMSE: 0.3251, Test MAE: 0.1492
# ---------------------------------
# Patience grace period: 23
# ---------------------------------
# Epoch 156/500
# Train RMSE: 0.2498
# Val RMSE: 0.2485, Val MAE: 0.1060
# Test RMSE: 0.3263, Test MAE: 0.1486
# ---------------------------------
# Patience grace period: 21
# ---------------------------------
# Epoch 157/500
# Train RMSE: 0.2498
# Val RMSE: 0.2485, Val MAE: 0.1070
# Test RMSE: 0.3251, Test MAE: 0.1495
# ---------------------------------
# Patience grace period: 19
# ---------------------------------
# Epoch 158/500
# Train RMSE: 0.2498
# Val RMSE: 0.2486, Val MAE: 0.1070
# Test RMSE: 0.3247, Test MAE: 0.1492
# ---------------------------------
# Patience grace period: 17
# ---------------------------------
# Epoch 159/500
# Train RMSE: 0.2498
# Val RMSE: 0.2486, Val MAE: 0.1072
# Test RMSE: 0.3243, Test MAE: 0.1499
# ---------------------------------
# Patience grace period: 16
# ---------------------------------
# Epoch 160/500
# Train RMSE: 0.2497
# Val RMSE: 0.2485, Val MAE: 0.1059
# Test RMSE: 0.3273, Test MAE: 0.1487
# ---------------------------------
# Patience grace period: 15
# ---------------------------------
# Epoch 161/500
# Train RMSE: 0.2497
# Val RMSE: 0.2485, Val MAE: 0.1071
# Test RMSE: 0.3242, Test MAE: 0.1497
# ---------------------------------
# Patience grace period: 14
# ---------------------------------
# Epoch 162/500
# Train RMSE: 0.2496
# Val RMSE: 0.2485, Val MAE: 0.1058
# Test RMSE: 0.3271, Test MAE: 0.1488
# ---------------------------------
# Patience grace period: 12
# ---------------------------------
# Epoch 163/500
# Train RMSE: 0.2496
# Val RMSE: 0.2484, Val MAE: 0.1068
# Test RMSE: 0.3248, Test MAE: 0.1495
# ---------------------------------
# Model saved at epoch 163 with val RMSE 0.2484
# Patience grace period: 40
# ---------------------------------
# Epoch 164/500
# Train RMSE: 0.2496
# Val RMSE: 0.2484, Val MAE: 0.1063
# Test RMSE: 0.3265, Test MAE: 0.1492
# ---------------------------------
# Model saved at epoch 164 with val RMSE 0.2484
# Patience grace period: 39
# ---------------------------------
# Epoch 165/500
# Train RMSE: 0.2495
# Val RMSE: 0.2484, Val MAE: 0.1064
# Test RMSE: 0.3255, Test MAE: 0.1492
# ---------------------------------
# Model saved at epoch 165 with val RMSE 0.2484
# Patience grace period: 38
# ---------------------------------
# Epoch 166/500
# Train RMSE: 0.2495
# Val RMSE: 0.2484, Val MAE: 0.1067
# Test RMSE: 0.3254, Test MAE: 0.1495
# ---------------------------------
# Patience grace period: 36
# ---------------------------------
# Epoch 167/500
# Train RMSE: 0.2494
# Val RMSE: 0.2484, Val MAE: 0.1063
# Test RMSE: 0.3264, Test MAE: 0.1491
# ---------------------------------
# Patience grace period: 35
# ---------------------------------
# Epoch 168/500
# Train RMSE: 0.2495
# Val RMSE: 0.2484, Val MAE: 0.1070
# Test RMSE: 0.3250, Test MAE: 0.1496
# ---------------------------------
# Patience grace period: 33
# ---------------------------------
# Epoch 169/500
# Train RMSE: 0.2495
# Val RMSE: 0.2484, Val MAE: 0.1062
# Test RMSE: 0.3267, Test MAE: 0.1493
# ---------------------------------
# Patience grace period: 32
# ---------------------------------
# Epoch 170/500
# Train RMSE: 0.2495
# Val RMSE: 0.2484, Val MAE: 0.1062
# Test RMSE: 0.3265, Test MAE: 0.1490
# ---------------------------------
# Patience grace period: 30
# ---------------------------------
# Epoch 171/500
# Train RMSE: 0.2494
# Val RMSE: 0.2484, Val MAE: 0.1064
# Test RMSE: 0.3256, Test MAE: 0.1494
# ---------------------------------
# Model saved at epoch 171 with val RMSE 0.2484
# Patience grace period: 29
# ---------------------------------
# Epoch 172/500
# Train RMSE: 0.2494
# Val RMSE: 0.2484, Val MAE: 0.1064
# Test RMSE: 0.3260, Test MAE: 0.1491
# ---------------------------------
# Patience grace period: 27
# ---------------------------------
# Epoch 173/500
# Train RMSE: 0.2493
# Val RMSE: 0.2483, Val MAE: 0.1063
# Test RMSE: 0.3259, Test MAE: 0.1491
# ---------------------------------
# Model saved at epoch 173 with val RMSE 0.2483
# Patience grace period: 40
# ---------------------------------
# Epoch 174/500
# Train RMSE: 0.2493
# Val RMSE: 0.2484, Val MAE: 0.1064
# Test RMSE: 0.3260, Test MAE: 0.1494
# ---------------------------------
# Patience grace period: 38
# ---------------------------------
# Epoch 175/500
# Train RMSE: 0.2493
# Val RMSE: 0.2484, Val MAE: 0.1058
# Test RMSE: 0.3264, Test MAE: 0.1486
# ---------------------------------
# Patience grace period: 36
# ---------------------------------
# Epoch 176/500
# Train RMSE: 0.2492
# Val RMSE: 0.2483, Val MAE: 0.1060
# Test RMSE: 0.3263, Test MAE: 0.1489
# ---------------------------------
# Patience grace period: 35
# ---------------------------------
# Epoch 177/500
# Train RMSE: 0.2492
# Val RMSE: 0.2484, Val MAE: 0.1068
# Test RMSE: 0.3252, Test MAE: 0.1494
# ---------------------------------
# Patience grace period: 33
# ---------------------------------
# Epoch 178/500
# Train RMSE: 0.2493
# Val RMSE: 0.2484, Val MAE: 0.1054
# Test RMSE: 0.3279, Test MAE: 0.1486
# ---------------------------------
# Patience grace period: 31
# ---------------------------------
# Epoch 179/500
# Train RMSE: 0.2491
# Val RMSE: 0.2483, Val MAE: 0.1064
# Test RMSE: 0.3253, Test MAE: 0.1491
# ---------------------------------
# Patience grace period: 30
# ---------------------------------
# Epoch 180/500
# Train RMSE: 0.2492
# Val RMSE: 0.2484, Val MAE: 0.1065
# Test RMSE: 0.3263, Test MAE: 0.1493
# ---------------------------------
# Patience grace period: 28
# ---------------------------------
# Epoch 181/500
# Train RMSE: 0.2491
# Val RMSE: 0.2483, Val MAE: 0.1060
# Test RMSE: 0.3266, Test MAE: 0.1489
# ---------------------------------
# Model saved at epoch 181 with val RMSE 0.2483
# Patience grace period: 27
# ---------------------------------
# Epoch 182/500
# Train RMSE: 0.2491
# Val RMSE: 0.2483, Val MAE: 0.1064
# Test RMSE: 0.3258, Test MAE: 0.1493
# ---------------------------------
# Patience grace period: 25
# ---------------------------------
# Epoch 183/500
# Train RMSE: 0.2491
# Val RMSE: 0.2484, Val MAE: 0.1057
# Test RMSE: 0.3266, Test MAE: 0.1485
# ---------------------------------
# Patience grace period: 23
# ---------------------------------
# Epoch 184/500
# Train RMSE: 0.2491
# Val RMSE: 0.2483, Val MAE: 0.1063
# Test RMSE: 0.3255, Test MAE: 0.1492
# ---------------------------------
# Patience grace period: 22
# ---------------------------------
# Epoch 185/500
# Train RMSE: 0.2490
# Val RMSE: 0.2483, Val MAE: 0.1064
# Test RMSE: 0.3255, Test MAE: 0.1491
# ---------------------------------
# Patience grace period: 20
# ---------------------------------
# Epoch 186/500
# Train RMSE: 0.2490
# Val RMSE: 0.2483, Val MAE: 0.1056
# Test RMSE: 0.3273, Test MAE: 0.1484
# ---------------------------------
# Patience grace period: 19
# ---------------------------------
# Epoch 187/500
# Train RMSE: 0.2490
# Val RMSE: 0.2483, Val MAE: 0.1062
# Test RMSE: 0.3259, Test MAE: 0.1492
# ---------------------------------
# Model saved at epoch 187 with val RMSE 0.2483
# Patience grace period: 18
# ---------------------------------
# Epoch 188/500
# Train RMSE: 0.2490
# Val RMSE: 0.2483, Val MAE: 0.1060
# Test RMSE: 0.3263, Test MAE: 0.1486
# ---------------------------------
# Patience grace period: 16
# ---------------------------------
# Epoch 189/500
# Train RMSE: 0.2490
# Val RMSE: 0.2483, Val MAE: 0.1057
# Test RMSE: 0.3266, Test MAE: 0.1486
# ---------------------------------
# Patience grace period: 14
# ---------------------------------
# Epoch 190/500
# Train RMSE: 0.2489
# Val RMSE: 0.2484, Val MAE: 0.1060
# Test RMSE: 0.3269, Test MAE: 0.1490
# ---------------------------------
# Patience grace period: 12
# ---------------------------------
# Epoch 191/500
# Train RMSE: 0.2489
# Val RMSE: 0.2484, Val MAE: 0.1064
# Test RMSE: 0.3260, Test MAE: 0.1492
# ---------------------------------
# Patience grace period: 10
# ---------------------------------
# Epoch 192/500
# Train RMSE: 0.2489
# Val RMSE: 0.2483, Val MAE: 0.1064
# Test RMSE: 0.3250, Test MAE: 0.1493
# ---------------------------------
# Patience grace period: 9
# ---------------------------------
# Epoch 193/500
# Train RMSE: 0.2489
# Val RMSE: 0.2483, Val MAE: 0.1059
# Test RMSE: 0.3263, Test MAE: 0.1489
# ---------------------------------
# Model saved at epoch 193 with val RMSE 0.2483
# Patience grace period: 8
# ---------------------------------
# Epoch 194/500
# Train RMSE: 0.2488
# Val RMSE: 0.2483, Val MAE: 0.1060
# Test RMSE: 0.3273, Test MAE: 0.1489
# ---------------------------------
# Patience grace period: 6
# ---------------------------------
# Epoch 195/500
# Train RMSE: 0.2488
# Val RMSE: 0.2483, Val MAE: 0.1057
# Test RMSE: 0.3265, Test MAE: 0.1488
# ---------------------------------
# Patience grace period: 5
# ---------------------------------
# Epoch 196/500
# Train RMSE: 0.2488
# Val RMSE: 0.2484, Val MAE: 0.1054
# Test RMSE: 0.3280, Test MAE: 0.1486
# ---------------------------------
# Patience grace period: 3
# ---------------------------------
# Epoch 197/500
# Train RMSE: 0.2488
# Val RMSE: 0.2483, Val MAE: 0.1067
# Test RMSE: 0.3251, Test MAE: 0.1493
# ---------------------------------
# Model saved at epoch 197 with val RMSE 0.2483
# Patience grace period: 2
# ---------------------------------
# Epoch 198/500
# Train RMSE: 0.2488
# Val RMSE: 0.2483, Val MAE: 0.1055
# Test RMSE: 0.3274, Test MAE: 0.1486
# ---------------------------------
# Patience grace period: 0
# Early stopping triggered at epoch 198
# Final Test RMSE: 0.3251, Final Test MAE: 0.1493
# <ipython-input-3-2a228d64b832>:126: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   self.model.load_state_dict(torch.load(os.path.join(save_dir, 'best_model.pth')))
# Pearson Corr: 0.7481356794886787
# Spearman Corr: 0.4301712924120494
# p-rmse: 0.3251005384020071
#        rmse       mae  seed                             subtask        method  \
# 0  0.325101  0.149299     5  openproblems_bmmc_cite_phase2_mod2  no_attention
#
#     pearson p_value_pearson  spearman p_value_spearman
# 0  0.748136          0.0000  0.430171           0.0000

# %%
config_hierachical_PROTEIN = {
    "subtask": "openproblems_bmmc_cite_phase2_mod2",
    "batch_size": 520,
    "act": "relu",
    "conv_flow": ["gat", 'sage'],
    "agg_flow": [None, 'lstm'],
    "device": "cuda",
    "learning_rate": 0.000064,
    "hidden_size": 280,
    "num_heads": 6,
    "n_neigbours": 3,
    "metric": "euclidean",
    "n_components": 1200,
    "dropout_rate": 0.2,
    "num_epochs": 500,
    "seed": 1,
    "es_patience": 40,
    "es_min_delta": 0.0001,
    "es_rate_threshold": 0.00002,
    "layer_dim_ex": 3,
    "verbose": True,
    "sample": True,
    "preprocessing_type": "None",
    "variant": "original",
    "num_clusters": 10
}

pipeline(**config_hierachical_PROTEIN)
# Out:
# [INFO][2025-04-15 22:00:01,181][dance][_load_raw_data] Loading /content/data/openproblems_bmmc_cite_phase2_mod2/openproblems_bmmc_cite_phase2_mod2.censor_dataset.output_train_mod1.h5ad
# Initializing pipeline...
# [INFO][2025-04-15 22:00:01,832][dance][_load_raw_data] Loading /content/data/openproblems_bmmc_cite_phase2_mod2/openproblems_bmmc_cite_phase2_mod2.censor_dataset.output_train_mod2.h5ad
# [INFO][2025-04-15 22:00:09,539][dance][_load_raw_data] Loading /content/data/openproblems_bmmc_cite_phase2_mod2/openproblems_bmmc_cite_phase2_mod2.censor_dataset.output_test_mod1.h5ad
# [INFO][2025-04-15 22:00:09,563][dance][_load_raw_data] Loading /content/data/openproblems_bmmc_cite_phase2_mod2/openproblems_bmmc_cite_phase2_mod2.censor_dataset.output_test_mod2.h5ad
# [INFO][2025-04-15 22:00:09,764][dance][_maybe_preprocess] Preprocessing done.
# /usr/local/lib/python3.11/dist-packages/mudata/_core/mudata.py:1531: FutureWarning: From 0.4 .update() will not pull obs/var columns from individual modalities by default anymore. Set mudata.set_options(pull_on_update=False) to adopt the new behaviour, which will become the default. Use new pull_obs/pull_var and push_obs/push_var methods for more flexibility.
#   self._update_attr("var", axis=0, join_common=join_common)
# /usr/local/lib/python3.11/dist-packages/mudata/_core/mudata.py:931: UserWarning: Cannot join columns with the same name because var_names are intersecting.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/mudata/_core/mudata.py:1429: FutureWarning: From 0.4 .update() will not pull obs/var columns from individual modalities by default anymore. Set mudata.set_options(pull_on_update=False) to adopt the new behaviour, which will become the default. Use new pull_obs/pull_var and push_obs/push_var methods for more flexibility.
#   self._update_attr("obs", axis=1, join_common=join_common)
# /usr/local/lib/python3.11/dist-packages/mudata/_core/mudata.py:1558: UserWarning: Modality names will be prepended to var_names since there are identical var_names in different modalities.
#   warnings.warn(
# [INFO][2025-04-15 22:00:16,916][dance][set_config_from_dict] Setting config 'feature_mod' to 'mod1'
# [INFO][2025-04-15 22:00:16,916][dance][set_config_from_dict] Setting config 'label_mod' to 'mod2'
# [INFO][2025-04-15 22:00:16,917][dance][load_data] Raw data loaded:
# Data object that wraps (.data):
# MuData object with n_obs × n_vars = 67175 × 14087
#   uns:	'dance_config'
#   2 modalities
#     mod1:	67175 x 134
#       obs:	'batch'
#       layers:	'counts'
#     mod2:	67175 x 13953
#       obs:	'batch'
#       layers:	'counts'
# [INFO][2025-04-15 22:00:17,041][dance][wrapped_func] Took 0:00:15.861008 to load and process data.
# <ipython-input-4-038168299b8a>:42: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   data.data.uns['gtrain'] = torch.load(train_graph_path)
# <ipython-input-4-038168299b8a>:43: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   data.data.uns['gval'] = torch.load(val_graph_path)
# <ipython-input-4-038168299b8a>:44: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   data.data.uns['gtest'] = torch.load(test_graph_path)
# <ipython-input-4-038168299b8a>:45: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   train_label = torch.load(train_label_path).numpy()
# Processed data found. Loading...
# <ipython-input-4-038168299b8a>:46: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   val_label = torch.load(val_label_path).numpy()
# <ipython-input-4-038168299b8a>:47: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   test_label = torch.load(test_label_path).numpy()
# <ipython-input-4-038168299b8a>:48: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   kwargs["FEATURE_SIZE"] = torch.load(feature_size_path).item()
# <ipython-input-4-038168299b8a>:49: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   kwargs["OUTPUT_SIZE"] = torch.load(output_size_path).item()
# Processed data loaded.
# ---------------------------------
# Epoch 1/500
# Train RMSE: 0.3714
# Val RMSE: 0.3103, Val MAE: 0.1357
# Test RMSE: 0.3828, Test MAE: 0.1790
# ---------------------------------
# Model saved at epoch 1 with val RMSE 0.3103
# Patience grace period: 40
# ---------------------------------
# Epoch 2/500
# Train RMSE: 0.3150
# Val RMSE: 0.2857, Val MAE: 0.1273
# Test RMSE: 0.3570, Test MAE: 0.1680
# ---------------------------------
# Model saved at epoch 2 with val RMSE 0.2857
# Patience grace period: 40
# ---------------------------------
# Epoch 3/500
# Train RMSE: 0.2947
# Val RMSE: 0.2743, Val MAE: 0.1211
# Test RMSE: 0.3495, Test MAE: 0.1611
# ---------------------------------
# Model saved at epoch 3 with val RMSE 0.2743
# Patience grace period: 40
# ---------------------------------
# Epoch 4/500
# Train RMSE: 0.2843
# Val RMSE: 0.2694, Val MAE: 0.1187
# Test RMSE: 0.3473, Test MAE: 0.1585
# ---------------------------------
# Model saved at epoch 4 with val RMSE 0.2694
# Patience grace period: 40
# ---------------------------------
# Epoch 5/500
# Train RMSE: 0.2781
# Val RMSE: 0.2658, Val MAE: 0.1175
# Test RMSE: 0.3444, Test MAE: 0.1567
# ---------------------------------
# Model saved at epoch 5 with val RMSE 0.2658
# Patience grace period: 40
# ---------------------------------
# Epoch 6/500
# Train RMSE: 0.2736
# Val RMSE: 0.2629, Val MAE: 0.1167
# Test RMSE: 0.3412, Test MAE: 0.1548
# ---------------------------------
# Model saved at epoch 6 with val RMSE 0.2629
# Patience grace period: 40
# ---------------------------------
# Epoch 7/500
# Train RMSE: 0.2699
# Val RMSE: 0.2605, Val MAE: 0.1156
# Test RMSE: 0.3393, Test MAE: 0.1531
# ---------------------------------
# Model saved at epoch 7 with val RMSE 0.2605
# Patience grace period: 40
# ---------------------------------
# Epoch 8/500
# Train RMSE: 0.2669
# Val RMSE: 0.2587, Val MAE: 0.1141
# Test RMSE: 0.3388, Test MAE: 0.1516
# ---------------------------------
# Model saved at epoch 8 with val RMSE 0.2587
# Patience grace period: 40
# ---------------------------------
# Epoch 9/500
# Train RMSE: 0.2645
# Val RMSE: 0.2574, Val MAE: 0.1133
# Test RMSE: 0.3381, Test MAE: 0.1509
# ---------------------------------
# Model saved at epoch 9 with val RMSE 0.2574
# Patience grace period: 40
# ---------------------------------
# Epoch 10/500
# Train RMSE: 0.2627
# Val RMSE: 0.2565, Val MAE: 0.1127
# Test RMSE: 0.3374, Test MAE: 0.1505
# ---------------------------------
# Model saved at epoch 10 with val RMSE 0.2565
# Patience grace period: 40
# ---------------------------------
# Epoch 11/500
# Train RMSE: 0.2613
# Val RMSE: 0.2558, Val MAE: 0.1122
# Test RMSE: 0.3366, Test MAE: 0.1502
# ---------------------------------
# Model saved at epoch 11 with val RMSE 0.2558
# Patience grace period: 40
# ---------------------------------
# Epoch 12/500
# Train RMSE: 0.2601
# Val RMSE: 0.2552, Val MAE: 0.1118
# Test RMSE: 0.3360, Test MAE: 0.1497
# ---------------------------------
# Model saved at epoch 12 with val RMSE 0.2552
# Patience grace period: 40
# ---------------------------------
# Epoch 13/500
# Train RMSE: 0.2591
# Val RMSE: 0.2548, Val MAE: 0.1114
# Test RMSE: 0.3357, Test MAE: 0.1495
# ---------------------------------
# Model saved at epoch 13 with val RMSE 0.2548
# Patience grace period: 40
# ---------------------------------
# Epoch 14/500
# Train RMSE: 0.2583
# Val RMSE: 0.2544, Val MAE: 0.1114
# Test RMSE: 0.3345, Test MAE: 0.1495
# ---------------------------------
# Model saved at epoch 14 with val RMSE 0.2544
# Patience grace period: 40
# ---------------------------------
# Epoch 15/500
# Train RMSE: 0.2577
# Val RMSE: 0.2540, Val MAE: 0.1111
# Test RMSE: 0.3340, Test MAE: 0.1493
# ---------------------------------
# Model saved at epoch 15 with val RMSE 0.2540
# Patience grace period: 40
# ---------------------------------
# Epoch 16/500
# Train RMSE: 0.2571
# Val RMSE: 0.2537, Val MAE: 0.1109
# Test RMSE: 0.3331, Test MAE: 0.1490
# ---------------------------------
# Model saved at epoch 16 with val RMSE 0.2537
# Patience grace period: 40
# ---------------------------------
# Epoch 17/500
# Train RMSE: 0.2565
# Val RMSE: 0.2534, Val MAE: 0.1103
# Test RMSE: 0.3336, Test MAE: 0.1487
# ---------------------------------
# Model saved at epoch 17 with val RMSE 0.2534
# Patience grace period: 40
# ---------------------------------
# Epoch 18/500
# Train RMSE: 0.2561
# Val RMSE: 0.2532, Val MAE: 0.1107
# Test RMSE: 0.3319, Test MAE: 0.1489
# ---------------------------------
# Model saved at epoch 18 with val RMSE 0.2532
# Patience grace period: 40
# ---------------------------------
# Epoch 19/500
# Train RMSE: 0.2556
# Val RMSE: 0.2530, Val MAE: 0.1107
# Test RMSE: 0.3312, Test MAE: 0.1489
# ---------------------------------
# Model saved at epoch 19 with val RMSE 0.2530
# Patience grace period: 40
# ---------------------------------
# Epoch 20/500
# Train RMSE: 0.2553
# Val RMSE: 0.2527, Val MAE: 0.1100
# Test RMSE: 0.3315, Test MAE: 0.1486
# ---------------------------------
# Model saved at epoch 20 with val RMSE 0.2527
# Patience grace period: 40
# ---------------------------------
# Epoch 21/500
# Train RMSE: 0.2549
# Val RMSE: 0.2525, Val MAE: 0.1095
# Test RMSE: 0.3322, Test MAE: 0.1483
# ---------------------------------
# Model saved at epoch 21 with val RMSE 0.2525
# Patience grace period: 40
# ---------------------------------
# Epoch 22/500
# Train RMSE: 0.2546
# Val RMSE: 0.2523, Val MAE: 0.1093
# Test RMSE: 0.3318, Test MAE: 0.1481
# ---------------------------------
# Model saved at epoch 22 with val RMSE 0.2523
# Patience grace period: 40
# ---------------------------------
# Epoch 23/500
# Train RMSE: 0.2543
# Val RMSE: 0.2523, Val MAE: 0.1095
# Test RMSE: 0.3310, Test MAE: 0.1483
# ---------------------------------
# Model saved at epoch 23 with val RMSE 0.2523
# Patience grace period: 39
# ---------------------------------
# Epoch 24/500
# Train RMSE: 0.2541
# Val RMSE: 0.2520, Val MAE: 0.1088
# Test RMSE: 0.3318, Test MAE: 0.1482
# ---------------------------------
# Model saved at epoch 24 with val RMSE 0.2520
# Patience grace period: 40
# ---------------------------------
# Epoch 25/500
# Train RMSE: 0.2539
# Val RMSE: 0.2519, Val MAE: 0.1084
# Test RMSE: 0.3319, Test MAE: 0.1480
# ---------------------------------
# Model saved at epoch 25 with val RMSE 0.2519
# Patience grace period: 40
# ---------------------------------
# Epoch 26/500
# Train RMSE: 0.2536
# Val RMSE: 0.2518, Val MAE: 0.1090
# Test RMSE: 0.3304, Test MAE: 0.1481
# ---------------------------------
# Model saved at epoch 26 with val RMSE 0.2518
# Patience grace period: 39
# ---------------------------------
# Epoch 27/500
# Train RMSE: 0.2535
# Val RMSE: 0.2516, Val MAE: 0.1086
# Test RMSE: 0.3309, Test MAE: 0.1481
# ---------------------------------
# Model saved at epoch 27 with val RMSE 0.2516
# Patience grace period: 40
# ---------------------------------
# Epoch 28/500
# Train RMSE: 0.2532
# Val RMSE: 0.2515, Val MAE: 0.1087
# Test RMSE: 0.3303, Test MAE: 0.1483
# ---------------------------------
# Model saved at epoch 28 with val RMSE 0.2515
# Patience grace period: 39
# ---------------------------------
# Epoch 29/500
# Train RMSE: 0.2531
# Val RMSE: 0.2515, Val MAE: 0.1087
# Test RMSE: 0.3300, Test MAE: 0.1481
# ---------------------------------
# Model saved at epoch 29 with val RMSE 0.2515
# Patience grace period: 40
# ---------------------------------
# Epoch 30/500
# Train RMSE: 0.2529
# Val RMSE: 0.2514, Val MAE: 0.1086
# Test RMSE: 0.3302, Test MAE: 0.1482
# ---------------------------------
# Model saved at epoch 30 with val RMSE 0.2514
# Patience grace period: 39
# ---------------------------------
# Epoch 31/500
# Train RMSE: 0.2527
# Val RMSE: 0.2512, Val MAE: 0.1081
# Test RMSE: 0.3304, Test MAE: 0.1482
# ---------------------------------
# Model saved at epoch 31 with val RMSE 0.2512
# Patience grace period: 40
# ---------------------------------
# Epoch 32/500
# Train RMSE: 0.2526
# Val RMSE: 0.2513, Val MAE: 0.1086
# Test RMSE: 0.3295, Test MAE: 0.1483
# ---------------------------------
# Patience grace period: 38
# ---------------------------------
# Epoch 33/500
# Train RMSE: 0.2524
# Val RMSE: 0.2511, Val MAE: 0.1078
# Test RMSE: 0.3304, Test MAE: 0.1481
# ---------------------------------
# Model saved at epoch 33 with val RMSE 0.2511
# Patience grace period: 40
# ---------------------------------
# Epoch 34/500
# Train RMSE: 0.2523
# Val RMSE: 0.2511, Val MAE: 0.1084
# Test RMSE: 0.3295, Test MAE: 0.1484
# ---------------------------------
# Patience grace period: 38
# ---------------------------------
# Epoch 35/500
# Train RMSE: 0.2522
# Val RMSE: 0.2509, Val MAE: 0.1080
# Test RMSE: 0.3300, Test MAE: 0.1482
# ---------------------------------
# Model saved at epoch 35 with val RMSE 0.2509
# Patience grace period: 40
# ---------------------------------
# Epoch 36/500
# Train RMSE: 0.2521
# Val RMSE: 0.2509, Val MAE: 0.1078
# Test RMSE: 0.3300, Test MAE: 0.1484
# ---------------------------------
# Model saved at epoch 36 with val RMSE 0.2509
# Patience grace period: 39
# ---------------------------------
# Epoch 37/500
# Train RMSE: 0.2519
# Val RMSE: 0.2508, Val MAE: 0.1083
# Test RMSE: 0.3287, Test MAE: 0.1486
# ---------------------------------
# Model saved at epoch 37 with val RMSE 0.2508
# Patience grace period: 40
# ---------------------------------
# Epoch 38/500
# Train RMSE: 0.2518
# Val RMSE: 0.2507, Val MAE: 0.1078
# Test RMSE: 0.3293, Test MAE: 0.1484
# ---------------------------------
# Model saved at epoch 38 with val RMSE 0.2507
# Patience grace period: 40
# ---------------------------------
# Epoch 39/500
# Train RMSE: 0.2517
# Val RMSE: 0.2506, Val MAE: 0.1076
# Test RMSE: 0.3296, Test MAE: 0.1483
# ---------------------------------
# Model saved at epoch 39 with val RMSE 0.2506
# Patience grace period: 39
# ---------------------------------
# Epoch 40/500
# Train RMSE: 0.2515
# Val RMSE: 0.2506, Val MAE: 0.1078
# Test RMSE: 0.3288, Test MAE: 0.1486
# ---------------------------------
# Model saved at epoch 40 with val RMSE 0.2506
# Patience grace period: 40
# ---------------------------------
# Epoch 41/500
# Train RMSE: 0.2514
# Val RMSE: 0.2505, Val MAE: 0.1080
# Test RMSE: 0.3285, Test MAE: 0.1487
# ---------------------------------
# Model saved at epoch 41 with val RMSE 0.2505
# Patience grace period: 39
# ---------------------------------
# Epoch 42/500
# Train RMSE: 0.2513
# Val RMSE: 0.2504, Val MAE: 0.1076
# Test RMSE: 0.3289, Test MAE: 0.1488
# ---------------------------------
# Model saved at epoch 42 with val RMSE 0.2504
# Patience grace period: 40
# ---------------------------------
# Epoch 43/500
# Train RMSE: 0.2513
# Val RMSE: 0.2504, Val MAE: 0.1072
# Test RMSE: 0.3294, Test MAE: 0.1483
# ---------------------------------
# Model saved at epoch 43 with val RMSE 0.2504
# Patience grace period: 39
# ---------------------------------
# Epoch 44/500
# Train RMSE: 0.2511
# Val RMSE: 0.2504, Val MAE: 0.1075
# Test RMSE: 0.3289, Test MAE: 0.1487
# ---------------------------------
# Model saved at epoch 44 with val RMSE 0.2504
# Patience grace period: 38
# ---------------------------------
# Epoch 45/500
# Train RMSE: 0.2510
# Val RMSE: 0.2503, Val MAE: 0.1079
# Test RMSE: 0.3283, Test MAE: 0.1489
# ---------------------------------
# Model saved at epoch 45 with val RMSE 0.2503
# Patience grace period: 37
# ---------------------------------
# Epoch 46/500
# Train RMSE: 0.2509
# Val RMSE: 0.2503, Val MAE: 0.1079
# Test RMSE: 0.3281, Test MAE: 0.1490
# ---------------------------------
# Model saved at epoch 46 with val RMSE 0.2503
# Patience grace period: 40
# ---------------------------------
# Epoch 47/500
# Train RMSE: 0.2509
# Val RMSE: 0.2503, Val MAE: 0.1082
# Test RMSE: 0.3271, Test MAE: 0.1492
# ---------------------------------
# Model saved at epoch 47 with val RMSE 0.2503
# Patience grace period: 39
# ---------------------------------
# Epoch 48/500
# Train RMSE: 0.2508
# Val RMSE: 0.2502, Val MAE: 0.1072
# Test RMSE: 0.3296, Test MAE: 0.1487
# ---------------------------------
# Model saved at epoch 48 with val RMSE 0.2502
# Patience grace period: 40
# ---------------------------------
# Epoch 49/500
# Train RMSE: 0.2507
# Val RMSE: 0.2501, Val MAE: 0.1076
# Test RMSE: 0.3283, Test MAE: 0.1489
# ---------------------------------
# Model saved at epoch 49 with val RMSE 0.2501
# Patience grace period: 39
# ---------------------------------
# Epoch 50/500
# Train RMSE: 0.2506
# Val RMSE: 0.2501, Val MAE: 0.1078
# Test RMSE: 0.3278, Test MAE: 0.1493
# ---------------------------------
# Model saved at epoch 50 with val RMSE 0.2501
# Patience grace period: 38
# ---------------------------------
# Epoch 51/500
# Train RMSE: 0.2505
# Val RMSE: 0.2501, Val MAE: 0.1078
# Test RMSE: 0.3279, Test MAE: 0.1493
# ---------------------------------
# Model saved at epoch 51 with val RMSE 0.2501
# Patience grace period: 37
# ---------------------------------
# Epoch 52/500
# Train RMSE: 0.2505
# Val RMSE: 0.2501, Val MAE: 0.1075
# Test RMSE: 0.3280, Test MAE: 0.1491
# ---------------------------------
# Model saved at epoch 52 with val RMSE 0.2501
# Patience grace period: 40
# ---------------------------------
# Epoch 53/500
# Train RMSE: 0.2504
# Val RMSE: 0.2500, Val MAE: 0.1075
# Test RMSE: 0.3282, Test MAE: 0.1493
# ---------------------------------
# Model saved at epoch 53 with val RMSE 0.2500
# Patience grace period: 39
# ---------------------------------
# Epoch 54/500
# Train RMSE: 0.2503
# Val RMSE: 0.2499, Val MAE: 0.1070
# Test RMSE: 0.3289, Test MAE: 0.1489
# ---------------------------------
# Model saved at epoch 54 with val RMSE 0.2499
# Patience grace period: 40
# ---------------------------------
# Epoch 55/500
# Train RMSE: 0.2502
# Val RMSE: 0.2500, Val MAE: 0.1080
# Test RMSE: 0.3271, Test MAE: 0.1497
# ---------------------------------
# Patience grace period: 38
# ---------------------------------
# Epoch 56/500
# Train RMSE: 0.2502
# Val RMSE: 0.2499, Val MAE: 0.1076
# Test RMSE: 0.3272, Test MAE: 0.1494
# ---------------------------------
# Model saved at epoch 56 with val RMSE 0.2499
# Patience grace period: 37
# ---------------------------------
# Epoch 57/500
# Train RMSE: 0.2501
# Val RMSE: 0.2498, Val MAE: 0.1071
# Test RMSE: 0.3286, Test MAE: 0.1493
# ---------------------------------
# Model saved at epoch 57 with val RMSE 0.2498
# Patience grace period: 40
# ---------------------------------
# Epoch 58/500
# Train RMSE: 0.2501
# Val RMSE: 0.2499, Val MAE: 0.1076
# Test RMSE: 0.3277, Test MAE: 0.1495
# ---------------------------------
# Patience grace period: 38
# ---------------------------------
# Epoch 59/500
# Train RMSE: 0.2500
# Val RMSE: 0.2498, Val MAE: 0.1073
# Test RMSE: 0.3276, Test MAE: 0.1493
# ---------------------------------
# Patience grace period: 37
# ---------------------------------
# Epoch 60/500
# Train RMSE: 0.2499
# Val RMSE: 0.2498, Val MAE: 0.1076
# Test RMSE: 0.3268, Test MAE: 0.1496
# ---------------------------------
# Patience grace period: 35
# ---------------------------------
# Epoch 61/500
# Train RMSE: 0.2499
# Val RMSE: 0.2498, Val MAE: 0.1072
# Test RMSE: 0.3278, Test MAE: 0.1495
# ---------------------------------
# Model saved at epoch 61 with val RMSE 0.2498
# Patience grace period: 34
# ---------------------------------
# Epoch 62/500
# Train RMSE: 0.2498
# Val RMSE: 0.2498, Val MAE: 0.1074
# Test RMSE: 0.3274, Test MAE: 0.1498
# ---------------------------------
# Patience grace period: 32
# ---------------------------------
# Epoch 63/500
# Train RMSE: 0.2498
# Val RMSE: 0.2498, Val MAE: 0.1076
# Test RMSE: 0.3266, Test MAE: 0.1497
# ---------------------------------
# Patience grace period: 30
# ---------------------------------
# Epoch 64/500
# Train RMSE: 0.2497
# Val RMSE: 0.2496, Val MAE: 0.1071
# Test RMSE: 0.3280, Test MAE: 0.1497
# ---------------------------------
# Model saved at epoch 64 with val RMSE 0.2496
# Patience grace period: 40
# ---------------------------------
# Epoch 65/500
# Train RMSE: 0.2497
# Val RMSE: 0.2497, Val MAE: 0.1069
# Test RMSE: 0.3286, Test MAE: 0.1493
# ---------------------------------
# Patience grace period: 38
# ---------------------------------
# Epoch 66/500
# Train RMSE: 0.2496
# Val RMSE: 0.2496, Val MAE: 0.1071
# Test RMSE: 0.3283, Test MAE: 0.1498
# ---------------------------------
# Patience grace period: 37
# ---------------------------------
# Epoch 67/500
# Train RMSE: 0.2496
# Val RMSE: 0.2497, Val MAE: 0.1075
# Test RMSE: 0.3274, Test MAE: 0.1501
# ---------------------------------
# Patience grace period: 35
# ---------------------------------
# Epoch 68/500
# Train RMSE: 0.2495
# Val RMSE: 0.2497, Val MAE: 0.1074
# Test RMSE: 0.3272, Test MAE: 0.1499
# ---------------------------------
# Patience grace period: 33
# ---------------------------------
# Epoch 69/500
# Train RMSE: 0.2495
# Val RMSE: 0.2496, Val MAE: 0.1070
# Test RMSE: 0.3280, Test MAE: 0.1496
# ---------------------------------
# Model saved at epoch 69 with val RMSE 0.2496
# Patience grace period: 32
# ---------------------------------
# Epoch 70/500
# Train RMSE: 0.2494
# Val RMSE: 0.2495, Val MAE: 0.1073
# Test RMSE: 0.3271, Test MAE: 0.1500
# ---------------------------------
# Model saved at epoch 70 with val RMSE 0.2495
# Patience grace period: 40
# ---------------------------------
# Epoch 71/500
# Train RMSE: 0.2494
# Val RMSE: 0.2496, Val MAE: 0.1076
# Test RMSE: 0.3266, Test MAE: 0.1502
# ---------------------------------
# Patience grace period: 38
# ---------------------------------
# Epoch 72/500
# Train RMSE: 0.2493
# Val RMSE: 0.2495, Val MAE: 0.1073
# Test RMSE: 0.3271, Test MAE: 0.1501
# ---------------------------------
# Patience grace period: 37
# ---------------------------------
# Epoch 73/500
# Train RMSE: 0.2493
# Val RMSE: 0.2495, Val MAE: 0.1069
# Test RMSE: 0.3275, Test MAE: 0.1496
# ---------------------------------
# Patience grace period: 36
# ---------------------------------
# Epoch 74/500
# Train RMSE: 0.2493
# Val RMSE: 0.2495, Val MAE: 0.1072
# Test RMSE: 0.3272, Test MAE: 0.1500
# ---------------------------------
# Patience grace period: 34
# ---------------------------------
# Epoch 75/500
# Train RMSE: 0.2492
# Val RMSE: 0.2496, Val MAE: 0.1072
# Test RMSE: 0.3277, Test MAE: 0.1503
# ---------------------------------
# Patience grace period: 32
# ---------------------------------
# Epoch 76/500
# Train RMSE: 0.2492
# Val RMSE: 0.2495, Val MAE: 0.1073
# Test RMSE: 0.3272, Test MAE: 0.1501
# ---------------------------------
# Model saved at epoch 76 with val RMSE 0.2495
# Patience grace period: 31
# ---------------------------------
# Epoch 77/500
# Train RMSE: 0.2491
# Val RMSE: 0.2496, Val MAE: 0.1076
# Test RMSE: 0.3263, Test MAE: 0.1505
# ---------------------------------
# Patience grace period: 29
# ---------------------------------
# Epoch 78/500
# Train RMSE: 0.2491
# Val RMSE: 0.2496, Val MAE: 0.1075
# Test RMSE: 0.3266, Test MAE: 0.1505
# ---------------------------------
# Patience grace period: 28
# ---------------------------------
# Epoch 79/500
# Train RMSE: 0.2490
# Val RMSE: 0.2495, Val MAE: 0.1072
# Test RMSE: 0.3271, Test MAE: 0.1501
# ---------------------------------
# Patience grace period: 27
# ---------------------------------
# Epoch 80/500
# Train RMSE: 0.2490
# Val RMSE: 0.2495, Val MAE: 0.1068
# Test RMSE: 0.3282, Test MAE: 0.1500
# ---------------------------------
# Model saved at epoch 80 with val RMSE 0.2495
# Patience grace period: 26
# ---------------------------------
# Epoch 81/500
# Train RMSE: 0.2490
# Val RMSE: 0.2495, Val MAE: 0.1074
# Test RMSE: 0.3267, Test MAE: 0.1504
# ---------------------------------
# Model saved at epoch 81 with val RMSE 0.2495
# Patience grace period: 25
# ---------------------------------
# Epoch 82/500
# Train RMSE: 0.2489
# Val RMSE: 0.2494, Val MAE: 0.1072
# Test RMSE: 0.3271, Test MAE: 0.1505
# ---------------------------------
# Model saved at epoch 82 with val RMSE 0.2494
# Patience grace period: 24
# ---------------------------------
# Epoch 83/500
# Train RMSE: 0.2489
# Val RMSE: 0.2494, Val MAE: 0.1068
# Test RMSE: 0.3280, Test MAE: 0.1501
# ---------------------------------
# Model saved at epoch 83 with val RMSE 0.2494
# Patience grace period: 40
# ---------------------------------
# Epoch 84/500
# Train RMSE: 0.2489
# Val RMSE: 0.2494, Val MAE: 0.1073
# Test RMSE: 0.3269, Test MAE: 0.1504
# ---------------------------------
# Patience grace period: 38
# ---------------------------------
# Epoch 85/500
# Train RMSE: 0.2488
# Val RMSE: 0.2494, Val MAE: 0.1069
# Test RMSE: 0.3278, Test MAE: 0.1503
# ---------------------------------
# Patience grace period: 37
# ---------------------------------
# Epoch 86/500
# Train RMSE: 0.2488
# Val RMSE: 0.2494, Val MAE: 0.1069
# Test RMSE: 0.3274, Test MAE: 0.1502
# ---------------------------------
# Model saved at epoch 86 with val RMSE 0.2494
# Patience grace period: 36
# ---------------------------------
# Epoch 87/500
# Train RMSE: 0.2488
# Val RMSE: 0.2494, Val MAE: 0.1072
# Test RMSE: 0.3272, Test MAE: 0.1503
# ---------------------------------
# Patience grace period: 34
# ---------------------------------
# Epoch 88/500
# Train RMSE: 0.2487
# Val RMSE: 0.2494, Val MAE: 0.1071
# Test RMSE: 0.3266, Test MAE: 0.1504
# ---------------------------------
# Model saved at epoch 88 with val RMSE 0.2494
# Patience grace period: 33
# ---------------------------------
# Epoch 89/500
# Train RMSE: 0.2487
# Val RMSE: 0.2494, Val MAE: 0.1070
# Test RMSE: 0.3273, Test MAE: 0.1505
# ---------------------------------
# Patience grace period: 31
# ---------------------------------
# Epoch 90/500
# Train RMSE: 0.2487
# Val RMSE: 0.2493, Val MAE: 0.1068
# Test RMSE: 0.3272, Test MAE: 0.1503
# ---------------------------------
# Model saved at epoch 90 with val RMSE 0.2493
# Patience grace period: 30
# ---------------------------------
# Epoch 91/500
# Train RMSE: 0.2487
# Val RMSE: 0.2493, Val MAE: 0.1069
# Test RMSE: 0.3270, Test MAE: 0.1503
# ---------------------------------
# Model saved at epoch 91 with val RMSE 0.2493
# Patience grace period: 29
# ---------------------------------
# Epoch 92/500
# Train RMSE: 0.2486
# Val RMSE: 0.2494, Val MAE: 0.1069
# Test RMSE: 0.3276, Test MAE: 0.1503
# ---------------------------------
# Patience grace period: 27
# ---------------------------------
# Epoch 93/500
# Train RMSE: 0.2486
# Val RMSE: 0.2493, Val MAE: 0.1067
# Test RMSE: 0.3278, Test MAE: 0.1503
# ---------------------------------
# Patience grace period: 26
# ---------------------------------
# Epoch 94/500
# Train RMSE: 0.2486
# Val RMSE: 0.2494, Val MAE: 0.1068
# Test RMSE: 0.3275, Test MAE: 0.1504
# ---------------------------------
# Patience grace period: 24
# ---------------------------------
# Epoch 95/500
# Train RMSE: 0.2485
# Val RMSE: 0.2493, Val MAE: 0.1066
# Test RMSE: 0.3272, Test MAE: 0.1503
# ---------------------------------
# Patience grace period: 23
# ---------------------------------
# Epoch 96/500
# Train RMSE: 0.2485
# Val RMSE: 0.2493, Val MAE: 0.1072
# Test RMSE: 0.3264, Test MAE: 0.1507
# ---------------------------------
# Model saved at epoch 96 with val RMSE 0.2493
# Patience grace period: 22
# ---------------------------------
# Epoch 97/500
# Train RMSE: 0.2485
# Val RMSE: 0.2492, Val MAE: 0.1073
# Test RMSE: 0.3262, Test MAE: 0.1510
# ---------------------------------
# Model saved at epoch 97 with val RMSE 0.2492
# Patience grace period: 40
# ---------------------------------
# Epoch 98/500
# Train RMSE: 0.2485
# Val RMSE: 0.2493, Val MAE: 0.1070
# Test RMSE: 0.3271, Test MAE: 0.1505
# ---------------------------------
# Patience grace period: 38
# ---------------------------------
# Epoch 99/500
# Train RMSE: 0.2484
# Val RMSE: 0.2493, Val MAE: 0.1063
# Test RMSE: 0.3283, Test MAE: 0.1501
# ---------------------------------
# Patience grace period: 37
# ---------------------------------
# Epoch 100/500
# Train RMSE: 0.2484
# Val RMSE: 0.2493, Val MAE: 0.1064
# Test RMSE: 0.3278, Test MAE: 0.1503
# ---------------------------------
# Patience grace period: 36
# ---------------------------------
# Epoch 101/500
# Train RMSE: 0.2484
# Val RMSE: 0.2492, Val MAE: 0.1067
# Test RMSE: 0.3270, Test MAE: 0.1504
# ---------------------------------
# Model saved at epoch 101 with val RMSE 0.2492
# Patience grace period: 35
# ---------------------------------
# Epoch 102/500
# Train RMSE: 0.2483
# Val RMSE: 0.2493, Val MAE: 0.1069
# Test RMSE: 0.3265, Test MAE: 0.1504
# ---------------------------------
# Patience grace period: 33
# ---------------------------------
# Epoch 103/500
# Train RMSE: 0.2483
# Val RMSE: 0.2493, Val MAE: 0.1071
# Test RMSE: 0.3268, Test MAE: 0.1507
# ---------------------------------
# Patience grace period: 31
# ---------------------------------
# Epoch 104/500
# Train RMSE: 0.2483
# Val RMSE: 0.2493, Val MAE: 0.1073
# Test RMSE: 0.3264, Test MAE: 0.1508
# ---------------------------------
# Patience grace period: 29
# ---------------------------------
# Epoch 105/500
# Train RMSE: 0.2483
# Val RMSE: 0.2493, Val MAE: 0.1071
# Test RMSE: 0.3267, Test MAE: 0.1507
# ---------------------------------
# Patience grace period: 27
# ---------------------------------
# Epoch 106/500
# Train RMSE: 0.2483
# Val RMSE: 0.2494, Val MAE: 0.1073
# Test RMSE: 0.3258, Test MAE: 0.1507
# ---------------------------------
# Patience grace period: 25
# ---------------------------------
# Epoch 107/500
# Train RMSE: 0.2482
# Val RMSE: 0.2494, Val MAE: 0.1073
# Test RMSE: 0.3263, Test MAE: 0.1508
# ---------------------------------
# Patience grace period: 24
# ---------------------------------
# Epoch 108/500
# Train RMSE: 0.2482
# Val RMSE: 0.2494, Val MAE: 0.1075
# Test RMSE: 0.3253, Test MAE: 0.1511
# ---------------------------------
# Patience grace period: 22
# ---------------------------------
# Epoch 109/500
# Train RMSE: 0.2482
# Val RMSE: 0.2493, Val MAE: 0.1070
# Test RMSE: 0.3266, Test MAE: 0.1506
# ---------------------------------
# Patience grace period: 21
# ---------------------------------
# Epoch 110/500
# Train RMSE: 0.2481
# Val RMSE: 0.2495, Val MAE: 0.1077
# Test RMSE: 0.3254, Test MAE: 0.1511
# ---------------------------------
# Patience grace period: 19
# ---------------------------------
# Epoch 111/500
# Train RMSE: 0.2481
# Val RMSE: 0.2493, Val MAE: 0.1073
# Test RMSE: 0.3261, Test MAE: 0.1510
# ---------------------------------
# Patience grace period: 18
# ---------------------------------
# Epoch 112/500
# Train RMSE: 0.2481
# Val RMSE: 0.2493, Val MAE: 0.1075
# Test RMSE: 0.3255, Test MAE: 0.1510
# ---------------------------------
# Patience grace period: 16
# ---------------------------------
# Epoch 113/500
# Train RMSE: 0.2481
# Val RMSE: 0.2492, Val MAE: 0.1071
# Test RMSE: 0.3266, Test MAE: 0.1510
# ---------------------------------
# Patience grace period: 15
# ---------------------------------
# Epoch 114/500
# Train RMSE: 0.2480
# Val RMSE: 0.2493, Val MAE: 0.1070
# Test RMSE: 0.3268, Test MAE: 0.1504
# ---------------------------------
# Patience grace period: 13
# ---------------------------------
# Epoch 115/500
# Train RMSE: 0.2480
# Val RMSE: 0.2493, Val MAE: 0.1072
# Test RMSE: 0.3266, Test MAE: 0.1508
# ---------------------------------
# Patience grace period: 11
# ---------------------------------
# Epoch 116/500
# Train RMSE: 0.2480
# Val RMSE: 0.2492, Val MAE: 0.1070
# Test RMSE: 0.3262, Test MAE: 0.1507
# ---------------------------------
# Patience grace period: 10
# ---------------------------------
# Epoch 117/500
# Train RMSE: 0.2480
# Val RMSE: 0.2492, Val MAE: 0.1068
# Test RMSE: 0.3271, Test MAE: 0.1507
# ---------------------------------
# Patience grace period: 8
# ---------------------------------
# Epoch 118/500
# Train RMSE: 0.2480
# Val RMSE: 0.2493, Val MAE: 0.1069
# Test RMSE: 0.3270, Test MAE: 0.1505
# ---------------------------------
# Patience grace period: 6
# ---------------------------------
# Epoch 119/500
# Train RMSE: 0.2479
# Val RMSE: 0.2493, Val MAE: 0.1075
# Test RMSE: 0.3260, Test MAE: 0.1509
# ---------------------------------
# Patience grace period: 5
# ---------------------------------
# Epoch 120/500
# Train RMSE: 0.2479
# Val RMSE: 0.2493, Val MAE: 0.1072
# Test RMSE: 0.3264, Test MAE: 0.1508
# ---------------------------------
# Patience grace period: 3
# ---------------------------------
# Epoch 121/500
# Train RMSE: 0.2479
# Val RMSE: 0.2494, Val MAE: 0.1073
# Test RMSE: 0.3261, Test MAE: 0.1509
# ---------------------------------
# Patience grace period: 1
# ---------------------------------
# Epoch 122/500
# Train RMSE: 0.2479
# Val RMSE: 0.2493, Val MAE: 0.1069
# Test RMSE: 0.3272, Test MAE: 0.1506
# ---------------------------------
# Patience grace period: 0
# Early stopping triggered at epoch 122
# Final Test RMSE: 0.3270, Final Test MAE: 0.1504
# <ipython-input-3-2a228d64b832>:126: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   self.model.load_state_dict(torch.load(os.path.join(save_dir, 'best_model.pth')))
# Pearson Corr: 0.7478783751881832
# Spearman Corr: 0.4291214531792981
# p-rmse: 0.32699777350703063
#        rmse       mae  seed                             subtask    method  \
# 0  0.326998  0.150408     1  openproblems_bmmc_cite_phase2_mod2  original
#
#     pearson p_value_pearson  spearman p_value_spearman
# 0  0.747878          0.0000  0.429121           0.0000
# ---------------------------------
# Epoch 1/500
# Train RMSE: 0.3728
# Val RMSE: 0.3124, Val MAE: 0.1355
# Test RMSE: 0.3847, Test MAE: 0.1788
# ---------------------------------
# Model saved at epoch 1 with val RMSE 0.3124
# Patience grace period: 40
# ---------------------------------
# Epoch 2/500
# Train RMSE: 0.3159
# Val RMSE: 0.2856, Val MAE: 0.1269
# Test RMSE: 0.3570, Test MAE: 0.1675
# ---------------------------------
# Model saved at epoch 2 with val RMSE 0.2856
# Patience grace period: 40
# ---------------------------------
# Epoch 3/500
# Train RMSE: 0.2949
# Val RMSE: 0.2735, Val MAE: 0.1212
# Test RMSE: 0.3479, Test MAE: 0.1608
# ---------------------------------
# Model saved at epoch 3 with val RMSE 0.2735
# Patience grace period: 40
# ---------------------------------
# Epoch 4/500
# Train RMSE: 0.2841
# Val RMSE: 0.2687, Val MAE: 0.1187
# Test RMSE: 0.3454, Test MAE: 0.1581
# ---------------------------------
# Model saved at epoch 4 with val RMSE 0.2687
# Patience grace period: 40
# ---------------------------------
# Epoch 5/500
# Train RMSE: 0.2778
# Val RMSE: 0.2656, Val MAE: 0.1171
# Test RMSE: 0.3437, Test MAE: 0.1559
# ---------------------------------
# Model saved at epoch 5 with val RMSE 0.2656
# Patience grace period: 40
# ---------------------------------
# Epoch 6/500
# Train RMSE: 0.2732
# Val RMSE: 0.2629, Val MAE: 0.1157
# Test RMSE: 0.3422, Test MAE: 0.1541
# ---------------------------------
# Model saved at epoch 6 with val RMSE 0.2629
# Patience grace period: 40
# ---------------------------------
# Epoch 7/500
# Train RMSE: 0.2696
# Val RMSE: 0.2606, Val MAE: 0.1147
# Test RMSE: 0.3403, Test MAE: 0.1527
# ---------------------------------
# Model saved at epoch 7 with val RMSE 0.2606
# Patience grace period: 40
# ---------------------------------
# Epoch 8/500
# Train RMSE: 0.2667
# Val RMSE: 0.2588, Val MAE: 0.1142
# Test RMSE: 0.3387, Test MAE: 0.1518
# ---------------------------------
# Model saved at epoch 8 with val RMSE 0.2588
# Patience grace period: 40
# ---------------------------------
# Epoch 9/500
# Train RMSE: 0.2644
# Val RMSE: 0.2575, Val MAE: 0.1133
# Test RMSE: 0.3379, Test MAE: 0.1511
# ---------------------------------
# Model saved at epoch 9 with val RMSE 0.2575
# Patience grace period: 40
# ---------------------------------
# Epoch 10/500
# Train RMSE: 0.2626
# Val RMSE: 0.2565, Val MAE: 0.1129
# Test RMSE: 0.3369, Test MAE: 0.1508
# ---------------------------------
# Model saved at epoch 10 with val RMSE 0.2565
# Patience grace period: 40
# ---------------------------------
# Epoch 11/500
# Train RMSE: 0.2611
# Val RMSE: 0.2557, Val MAE: 0.1123
# Test RMSE: 0.3359, Test MAE: 0.1503
# ---------------------------------
# Model saved at epoch 11 with val RMSE 0.2557
# Patience grace period: 40
# ---------------------------------
# Epoch 12/500
# Train RMSE: 0.2599
# Val RMSE: 0.2551, Val MAE: 0.1119
# Test RMSE: 0.3356, Test MAE: 0.1500
# ---------------------------------
# Model saved at epoch 12 with val RMSE 0.2551
# Patience grace period: 40
# ---------------------------------
# Epoch 13/500
# Train RMSE: 0.2590
# Val RMSE: 0.2547, Val MAE: 0.1112
# Test RMSE: 0.3354, Test MAE: 0.1497
# ---------------------------------
# Model saved at epoch 13 with val RMSE 0.2547
# Patience grace period: 40
# ---------------------------------
# Epoch 14/500
# Train RMSE: 0.2581
# Val RMSE: 0.2542, Val MAE: 0.1112
# Test RMSE: 0.3343, Test MAE: 0.1495
# ---------------------------------
# Model saved at epoch 14 with val RMSE 0.2542
# Patience grace period: 40
# ---------------------------------
# Epoch 15/500
# Train RMSE: 0.2574
# Val RMSE: 0.2539, Val MAE: 0.1111
# Test RMSE: 0.3333, Test MAE: 0.1492
# ---------------------------------
# Model saved at epoch 15 with val RMSE 0.2539
# Patience grace period: 40
# ---------------------------------
# Epoch 16/500
# Train RMSE: 0.2569
# Val RMSE: 0.2536, Val MAE: 0.1103
# Test RMSE: 0.3342, Test MAE: 0.1489
# ---------------------------------
# Model saved at epoch 16 with val RMSE 0.2536
# Patience grace period: 40
# ---------------------------------
# Epoch 17/500
# Train RMSE: 0.2564
# Val RMSE: 0.2533, Val MAE: 0.1102
# Test RMSE: 0.3335, Test MAE: 0.1488
# ---------------------------------
# Model saved at epoch 17 with val RMSE 0.2533
# Patience grace period: 40
# ---------------------------------
# Epoch 18/500
# Train RMSE: 0.2559
# Val RMSE: 0.2531, Val MAE: 0.1101
# Test RMSE: 0.3327, Test MAE: 0.1487
# ---------------------------------
# Model saved at epoch 18 with val RMSE 0.2531
# Patience grace period: 40
# ---------------------------------
# Epoch 19/500
# Train RMSE: 0.2555
# Val RMSE: 0.2528, Val MAE: 0.1099
# Test RMSE: 0.3321, Test MAE: 0.1486
# ---------------------------------
# Model saved at epoch 19 with val RMSE 0.2528
# Patience grace period: 40
# ---------------------------------
# Epoch 20/500
# Train RMSE: 0.2552
# Val RMSE: 0.2526, Val MAE: 0.1096
# Test RMSE: 0.3321, Test MAE: 0.1484
# ---------------------------------
# Model saved at epoch 20 with val RMSE 0.2526
# Patience grace period: 40
# ---------------------------------
# Epoch 21/500
# Train RMSE: 0.2548
# Val RMSE: 0.2525, Val MAE: 0.1093
# Test RMSE: 0.3322, Test MAE: 0.1486
# ---------------------------------
# Model saved at epoch 21 with val RMSE 0.2525
# Patience grace period: 40
# ---------------------------------
# Epoch 22/500
# Train RMSE: 0.2545
# Val RMSE: 0.2523, Val MAE: 0.1091
# Test RMSE: 0.3318, Test MAE: 0.1483
# ---------------------------------
# Model saved at epoch 22 with val RMSE 0.2523
# Patience grace period: 40
# ---------------------------------
# Epoch 23/500
# Train RMSE: 0.2543
# Val RMSE: 0.2521, Val MAE: 0.1090
# Test RMSE: 0.3317, Test MAE: 0.1485
# ---------------------------------
# Model saved at epoch 23 with val RMSE 0.2521
# Patience grace period: 40
# ---------------------------------
# Epoch 24/500
# Train RMSE: 0.2540
# Val RMSE: 0.2520, Val MAE: 0.1088
# Test RMSE: 0.3316, Test MAE: 0.1484
# ---------------------------------
# Model saved at epoch 24 with val RMSE 0.2520
# Patience grace period: 40
# ---------------------------------
# Epoch 25/500
# Train RMSE: 0.2538
# Val RMSE: 0.2518, Val MAE: 0.1085
# Test RMSE: 0.3317, Test MAE: 0.1484
# ---------------------------------
# Model saved at epoch 25 with val RMSE 0.2518
# Patience grace period: 40
# ---------------------------------
# Epoch 26/500
# Train RMSE: 0.2535
# Val RMSE: 0.2518, Val MAE: 0.1080
# Test RMSE: 0.3325, Test MAE: 0.1482
# ---------------------------------
# Model saved at epoch 26 with val RMSE 0.2518
# Patience grace period: 39
# ---------------------------------
# Epoch 27/500
# Train RMSE: 0.2533
# Val RMSE: 0.2516, Val MAE: 0.1086
# Test RMSE: 0.3313, Test MAE: 0.1486
# ---------------------------------
# Model saved at epoch 27 with val RMSE 0.2516
# Patience grace period: 40
# ---------------------------------
# Epoch 28/500
# Train RMSE: 0.2532
# Val RMSE: 0.2515, Val MAE: 0.1083
# Test RMSE: 0.3309, Test MAE: 0.1484
# ---------------------------------
# Model saved at epoch 28 with val RMSE 0.2515
# Patience grace period: 40
# ---------------------------------
# Epoch 29/500
# Train RMSE: 0.2530
# Val RMSE: 0.2514, Val MAE: 0.1078
# Test RMSE: 0.3315, Test MAE: 0.1483
# ---------------------------------
# Model saved at epoch 29 with val RMSE 0.2514
# Patience grace period: 39
# ---------------------------------
# Epoch 30/500
# Train RMSE: 0.2528
# Val RMSE: 0.2513, Val MAE: 0.1081
# Test RMSE: 0.3309, Test MAE: 0.1484
# ---------------------------------
# Model saved at epoch 30 with val RMSE 0.2513
# Patience grace period: 40
# ---------------------------------
# Epoch 31/500
# Train RMSE: 0.2526
# Val RMSE: 0.2512, Val MAE: 0.1079
# Test RMSE: 0.3312, Test MAE: 0.1485
# ---------------------------------
# Model saved at epoch 31 with val RMSE 0.2512
# Patience grace period: 40
# ---------------------------------
# Epoch 32/500
# Train RMSE: 0.2525
# Val RMSE: 0.2511, Val MAE: 0.1080
# Test RMSE: 0.3300, Test MAE: 0.1485
# ---------------------------------
# Model saved at epoch 32 with val RMSE 0.2511
# Patience grace period: 40
# ---------------------------------
# Epoch 33/500
# Train RMSE: 0.2524
# Val RMSE: 0.2510, Val MAE: 0.1079
# Test RMSE: 0.3305, Test MAE: 0.1488
# ---------------------------------
# Model saved at epoch 33 with val RMSE 0.2510
# Patience grace period: 39
# ---------------------------------
# Epoch 34/500
# Train RMSE: 0.2522
# Val RMSE: 0.2510, Val MAE: 0.1076
# Test RMSE: 0.3308, Test MAE: 0.1487
# ---------------------------------
# Model saved at epoch 34 with val RMSE 0.2510
# Patience grace period: 38
# ---------------------------------
# Epoch 35/500
# Train RMSE: 0.2521
# Val RMSE: 0.2509, Val MAE: 0.1077
# Test RMSE: 0.3308, Test MAE: 0.1487
# ---------------------------------
# Model saved at epoch 35 with val RMSE 0.2509
# Patience grace period: 40
# ---------------------------------
# Epoch 36/500
# Train RMSE: 0.2520
# Val RMSE: 0.2509, Val MAE: 0.1071
# Test RMSE: 0.3318, Test MAE: 0.1485
# ---------------------------------
# Patience grace period: 38
# ---------------------------------
# Epoch 37/500
# Train RMSE: 0.2518
# Val RMSE: 0.2507, Val MAE: 0.1074
# Test RMSE: 0.3300, Test MAE: 0.1487
# ---------------------------------
# Model saved at epoch 37 with val RMSE 0.2507
# Patience grace period: 40
# ---------------------------------
# Epoch 38/500
# Train RMSE: 0.2517
# Val RMSE: 0.2507, Val MAE: 0.1072
# Test RMSE: 0.3305, Test MAE: 0.1485
# ---------------------------------
# Model saved at epoch 38 with val RMSE 0.2507
# ...
# Patience grace period: 36
# ---------------------------------
# Epoch 39/500
# Train RMSE: 0.2515
# Val RMSE: 0.2507, Val MAE: 0.1088
# Test RMSE: 0.3272, Test MAE: 0.1497
# ---------------------------------
# Model saved at epoch 39 with val RMSE 0.2507
# Patience grace period: 40
# ---------------------------------
# Epoch 40/500
# Train RMSE: 0.2514
# Val RMSE: 0.2506, Val MAE: 0.1084
# Test RMSE: 0.3278, Test MAE: 0.1495
# ---------------------------------
# Model saved at epoch 40 with val RMSE 0.2506
# Patience grace period: 40
# ---------------------------------
# Epoch 41/500
# Train RMSE: 0.2514
# Val RMSE: 0.2505, Val MAE: 0.1084
# Test RMSE: 0.3275, Test MAE: 0.1496
# ---------------------------------
# Model saved at epoch 41 with val RMSE 0.2505
# Patience grace period: 39
# ---------------------------------
# Epoch 42/500
# Train RMSE: 0.2512
# Val RMSE: 0.2506, Val MAE: 0.1086
# Test RMSE: 0.3270, Test MAE: 0.1498
# ---------------------------------
# Patience grace period: 37
# ---------------------------------
# Epoch 43/500
# Train RMSE: 0.2512
# Val RMSE: 0.2504, Val MAE: 0.1083
# Test RMSE: 0.3277, Test MAE: 0.1495
# ---------------------------------
# Model saved at epoch 43 with val RMSE 0.2504
# Patience grace period: 40
# ---------------------------------
# Epoch 44/500
# Train RMSE: 0.2510
# Val RMSE: 0.2504, Val MAE: 0.1082
# Test RMSE: 0.3272, Test MAE: 0.1496
# ---------------------------------
# Patience grace period: 38
# ---------------------------------
# Epoch 45/500
# Train RMSE: 0.2509
# Val RMSE: 0.2503, Val MAE: 0.1082
# Test RMSE: 0.3271, Test MAE: 0.1497
# ---------------------------------
# Model saved at epoch 45 with val RMSE 0.2503
# Patience grace period: 37
# ---------------------------------
# Epoch 46/500
# Train RMSE: 0.2509
# Val RMSE: 0.2503, Val MAE: 0.1083
# Test RMSE: 0.3267, Test MAE: 0.1498
# ---------------------------------
# Model saved at epoch 46 with val RMSE 0.2503
# Patience grace period: 36
# ---------------------------------
# Epoch 47/500
# Train RMSE: 0.2508
# Val RMSE: 0.2502, Val MAE: 0.1078
# Test RMSE: 0.3280, Test MAE: 0.1495
# ---------------------------------
# Model saved at epoch 47 with val RMSE 0.2502
# Patience grace period: 40
# ---------------------------------
# Epoch 48/500
# Train RMSE: 0.2507
# Val RMSE: 0.2503, Val MAE: 0.1084
# Test RMSE: 0.3265, Test MAE: 0.1501
# ---------------------------------
# Patience grace period: 38
# ---------------------------------
# Epoch 49/500
# Train RMSE: 0.2506
# Val RMSE: 0.2503, Val MAE: 0.1085
# Test RMSE: 0.3266, Test MAE: 0.1501
# ---------------------------------
# Patience grace period: 36
# ---------------------------------
# Epoch 50/500
# Train RMSE: 0.2506
# Val RMSE: 0.2501, Val MAE: 0.1077
# Test RMSE: 0.3271, Test MAE: 0.1498
# ---------------------------------
# Model saved at epoch 50 with val RMSE 0.2501
# Patience grace period: 35
# ---------------------------------
# Epoch 51/500
# Train RMSE: 0.2505
# Val RMSE: 0.2501, Val MAE: 0.1080
# Test RMSE: 0.3267, Test MAE: 0.1500
# ---------------------------------
# Patience grace period: 33
# ---------------------------------
# Epoch 52/500
# Train RMSE: 0.2504
# Val RMSE: 0.2501, Val MAE: 0.1081
# Test RMSE: 0.3268, Test MAE: 0.1500
# ---------------------------------
# Patience grace period: 31
# ---------------------------------
# Epoch 53/500
# Train RMSE: 0.2503
# Val RMSE: 0.2501, Val MAE: 0.1083
# Test RMSE: 0.3261, Test MAE: 0.1501
# ---------------------------------
# Patience grace period: 29
# ---------------------------------
# Epoch 54/500
# Train RMSE: 0.2502
# Val RMSE: 0.2501, Val MAE: 0.1083
# Test RMSE: 0.3265, Test MAE: 0.1504
# ---------------------------------
# Model saved at epoch 54 with val RMSE 0.2501
# Patience grace period: 28
# ---------------------------------
# Epoch 55/500
# Train RMSE: 0.2502
# Val RMSE: 0.2500, Val MAE: 0.1080
# Test RMSE: 0.3264, Test MAE: 0.1503
# ---------------------------------
# Model saved at epoch 55 with val RMSE 0.2500
# Patience grace period: 40
# ---------------------------------
# Epoch 56/500
# Train RMSE: 0.2501
# Val RMSE: 0.2499, Val MAE: 0.1074
# Test RMSE: 0.3270, Test MAE: 0.1497
# ---------------------------------
# Model saved at epoch 56 with val RMSE 0.2499
# Patience grace period: 40
# ---------------------------------
# Epoch 57/500
# Train RMSE: 0.2500
# Val RMSE: 0.2500, Val MAE: 0.1081
# Test RMSE: 0.3261, Test MAE: 0.1500
# ---------------------------------
# Patience grace period: 38
# ---------------------------------
# Epoch 58/500
# Train RMSE: 0.2500
# Val RMSE: 0.2498, Val MAE: 0.1073
# Test RMSE: 0.3271, Test MAE: 0.1498
# ---------------------------------
# Model saved at epoch 58 with val RMSE 0.2498
# Patience grace period: 37
# ---------------------------------
# Epoch 59/500
# Train RMSE: 0.2499
# Val RMSE: 0.2500, Val MAE: 0.1081
# Test RMSE: 0.3259, Test MAE: 0.1501
# ---------------------------------
# Patience grace period: 35
# ---------------------------------
# Epoch 60/500
# Train RMSE: 0.2499
# Val RMSE: 0.2499, Val MAE: 0.1077
# Test RMSE: 0.3262, Test MAE: 0.1501
# ---------------------------------
# Patience grace period: 34
# ---------------------------------
# Epoch 61/500
# Train RMSE: 0.2498
# Val RMSE: 0.2498, Val MAE: 0.1074
# Test RMSE: 0.3267, Test MAE: 0.1499
# ---------------------------------
# Patience grace period: 33
# ---------------------------------
# Epoch 62/500
# Train RMSE: 0.2497
# Val RMSE: 0.2497, Val MAE: 0.1073
# Test RMSE: 0.3274, Test MAE: 0.1500
# ---------------------------------
# Model saved at epoch 62 with val RMSE 0.2497
# Patience grace period: 40
# ---------------------------------
# Epoch 63/500
# Train RMSE: 0.2497
# Val RMSE: 0.2497, Val MAE: 0.1074
# Test RMSE: 0.3267, Test MAE: 0.1500
# ---------------------------------
# Model saved at epoch 63 with val RMSE 0.2497
# Patience grace period: 39
# ---------------------------------
# Epoch 64/500
# Train RMSE: 0.2496
# Val RMSE: 0.2498, Val MAE: 0.1075
# Test RMSE: 0.3268, Test MAE: 0.1499
# ---------------------------------
# Patience grace period: 37
# ---------------------------------
# Epoch 65/500
# Train RMSE: 0.2496
# Val RMSE: 0.2498, Val MAE: 0.1078
# Test RMSE: 0.3261, Test MAE: 0.1503
# ---------------------------------
# Patience grace period: 35
# ---------------------------------
# Epoch 66/500
# Train RMSE: 0.2495
# Val RMSE: 0.2496, Val MAE: 0.1069
# Test RMSE: 0.3271, Test MAE: 0.1498
# ---------------------------------
# Model saved at epoch 66 with val RMSE 0.2496
# Patience grace period: 40
# ---------------------------------
# Epoch 67/500
# Train RMSE: 0.2495
# Val RMSE: 0.2497, Val MAE: 0.1073
# Test RMSE: 0.3266, Test MAE: 0.1499
# ---------------------------------
# Patience grace period: 38
# ---------------------------------
# Epoch 68/500
# Train RMSE: 0.2494
# Val RMSE: 0.2497, Val MAE: 0.1075
# Test RMSE: 0.3261, Test MAE: 0.1501
# ---------------------------------
# Patience grace period: 36
# ---------------------------------
# Epoch 69/500
# Train RMSE: 0.2494
# Val RMSE: 0.2496, Val MAE: 0.1075
# Test RMSE: 0.3264, Test MAE: 0.1502
# ---------------------------------
# Patience grace period: 35
# ---------------------------------
# Epoch 70/500
# Train RMSE: 0.2493
# Val RMSE: 0.2497, Val MAE: 0.1082
# Test RMSE: 0.3254, Test MAE: 0.1508
# ---------------------------------
# Patience grace period: 33
# ---------------------------------
# Epoch 71/500
# Train RMSE: 0.2493
# Val RMSE: 0.2496, Val MAE: 0.1070
# Test RMSE: 0.3264, Test MAE: 0.1499
# ---------------------------------
# Model saved at epoch 71 with val RMSE 0.2496
# Patience grace period: 32
# ---------------------------------
# Epoch 72/500
# Train RMSE: 0.2492
# Val RMSE: 0.2496, Val MAE: 0.1073
# Test RMSE: 0.3261, Test MAE: 0.1500
# ---------------------------------
# Patience grace period: 30
# ---------------------------------
# Epoch 73/500
# Train RMSE: 0.2492
# Val RMSE: 0.2496, Val MAE: 0.1071
# Test RMSE: 0.3265, Test MAE: 0.1502
# ---------------------------------
# Model saved at epoch 73 with val RMSE 0.2496
# Patience grace period: 29
# ---------------------------------
# Epoch 74/500
# Train RMSE: 0.2491
# Val RMSE: 0.2495, Val MAE: 0.1071
# Test RMSE: 0.3267, Test MAE: 0.1500
# ---------------------------------
# Model saved at epoch 74 with val RMSE 0.2495
# Patience grace period: 28
# ---------------------------------
# Epoch 75/500
# Train RMSE: 0.2491
# Val RMSE: 0.2496, Val MAE: 0.1073
# Test RMSE: 0.3260, Test MAE: 0.1504
# ---------------------------------
# Patience grace period: 26
# ---------------------------------
# Epoch 76/500
# Train RMSE: 0.2490
# Val RMSE: 0.2496, Val MAE: 0.1076
# Test RMSE: 0.3260, Test MAE: 0.1504
# ---------------------------------
# Patience grace period: 24
# ---------------------------------
# Epoch 77/500
# Train RMSE: 0.2490
# Val RMSE: 0.2495, Val MAE: 0.1072
# Test RMSE: 0.3263, Test MAE: 0.1502
# ---------------------------------
# Model saved at epoch 77 with val RMSE 0.2495
# Patience grace period: 23
# ---------------------------------
# Epoch 78/500
# Train RMSE: 0.2490
# Val RMSE: 0.2496, Val MAE: 0.1075
# Test RMSE: 0.3259, Test MAE: 0.1503
# ---------------------------------
# Patience grace period: 21
# ---------------------------------
# Epoch 79/500
# Train RMSE: 0.2489
# Val RMSE: 0.2497, Val MAE: 0.1074
# Test RMSE: 0.3260, Test MAE: 0.1503
# ---------------------------------
# Patience grace period: 19
# ---------------------------------
# Epoch 80/500
# Train RMSE: 0.2489
# Val RMSE: 0.2494, Val MAE: 0.1072
# Test RMSE: 0.3263, Test MAE: 0.1504
# ---------------------------------
# Model saved at epoch 80 with val RMSE 0.2494
# Patience grace period: 40
# ---------------------------------
# Epoch 81/500
# Train RMSE: 0.2489
# Val RMSE: 0.2495, Val MAE: 0.1071
# Test RMSE: 0.3262, Test MAE: 0.1500
# ---------------------------------
# Patience grace period: 38
# ---------------------------------
# Epoch 82/500
# Train RMSE: 0.2488
# Val RMSE: 0.2495, Val MAE: 0.1068
# Test RMSE: 0.3269, Test MAE: 0.1499
# ---------------------------------
# Patience grace period: 37
# ---------------------------------
# Epoch 83/500
# Train RMSE: 0.2488
# Val RMSE: 0.2495, Val MAE: 0.1072
# Test RMSE: 0.3265, Test MAE: 0.1501
# ---------------------------------
# Patience grace period: 35
# ---------------------------------
# Epoch 84/500
# Train RMSE: 0.2488
# Val RMSE: 0.2495, Val MAE: 0.1069
# Test RMSE: 0.3264, Test MAE: 0.1501
# ---------------------------------
# Patience grace period: 34
# ---------------------------------
# Epoch 85/500
# Train RMSE: 0.2487
# Val RMSE: 0.2497, Val MAE: 0.1076
# Test RMSE: 0.3253, Test MAE: 0.1505
# ---------------------------------
# Patience grace period: 32
# ---------------------------------
# Epoch 86/500
# Train RMSE: 0.2487
# Val RMSE: 0.2495, Val MAE: 0.1070
# Test RMSE: 0.3265, Test MAE: 0.1500
# ---------------------------------
# Patience grace period: 31
# ---------------------------------
# Epoch 87/500
# Train RMSE: 0.2487
# Val RMSE: 0.2494, Val MAE: 0.1069
# Test RMSE: 0.3265, Test MAE: 0.1504
# ---------------------------------
# Model saved at epoch 87 with val RMSE 0.2494
# Patience grace period: 30
# ---------------------------------
# Epoch 88/500
# Train RMSE: 0.2486
# Val RMSE: 0.2496, Val MAE: 0.1071
# Test RMSE: 0.3263, Test MAE: 0.1502
# ---------------------------------
# Patience grace period: 28
# ---------------------------------
# Epoch 89/500
# Train RMSE: 0.2486
# Val RMSE: 0.2495, Val MAE: 0.1070
# Test RMSE: 0.3262, Test MAE: 0.1502
# ---------------------------------
# Patience grace period: 27
# ---------------------------------
# Epoch 90/500
# Train RMSE: 0.2486
# Val RMSE: 0.2494, Val MAE: 0.1068
# Test RMSE: 0.3267, Test MAE: 0.1501
# ---------------------------------
# Patience grace period: 26
# ---------------------------------
# Epoch 91/500
# Train RMSE: 0.2485
# Val RMSE: 0.2495, Val MAE: 0.1071
# Test RMSE: 0.3261, Test MAE: 0.1503
# ---------------------------------
# Patience grace period: 24
# ---------------------------------
# Epoch 92/500
# Train RMSE: 0.2485
# Val RMSE: 0.2494, Val MAE: 0.1069
# Test RMSE: 0.3267, Test MAE: 0.1502
# ---------------------------------
# Model saved at epoch 92 with val RMSE 0.2494
# Patience grace period: 23
# ---------------------------------
# Epoch 93/500
# Train RMSE: 0.2485
# Val RMSE: 0.2495, Val MAE: 0.1072
# Test RMSE: 0.3258, Test MAE: 0.1506
# ---------------------------------
# Patience grace period: 21
# ---------------------------------
# Epoch 94/500
# Train RMSE: 0.2484
# Val RMSE: 0.2495, Val MAE: 0.1069
# Test RMSE: 0.3263, Test MAE: 0.1500
# ---------------------------------
# Patience grace period: 19
# ---------------------------------
# Epoch 95/500
# Train RMSE: 0.2484
# Val RMSE: 0.2497, Val MAE: 0.1078
# Test RMSE: 0.3249, Test MAE: 0.1511
# ---------------------------------
# Patience grace period: 17
# ---------------------------------
# Epoch 96/500
# Train RMSE: 0.2484
# Val RMSE: 0.2495, Val MAE: 0.1074
# Test RMSE: 0.3255, Test MAE: 0.1507
# ---------------------------------
# Patience grace period: 16
# ---------------------------------
# Epoch 97/500
# Train RMSE: 0.2484
# Val RMSE: 0.2495, Val MAE: 0.1074
# Test RMSE: 0.3255, Test MAE: 0.1505
# ---------------------------------
# Patience grace period: 15
# ---------------------------------
# Epoch 98/500
# Train RMSE: 0.2483
# Val RMSE: 0.2494, Val MAE: 0.1071
# Test RMSE: 0.3260, Test MAE: 0.1503
# ---------------------------------
# Patience grace period: 14
# ---------------------------------
# Epoch 99/500
# Train RMSE: 0.2483
# Val RMSE: 0.2495, Val MAE: 0.1072
# Test RMSE: 0.3259, Test MAE: 0.1502
# ---------------------------------
# Patience grace period: 12
# ---------------------------------
# Epoch 100/500
# Train RMSE: 0.2483
# Val RMSE: 0.2494, Val MAE: 0.1071
# Test RMSE: 0.3259, Test MAE: 0.1505
# ---------------------------------
# Patience grace period: 11
# ---------------------------------
# Epoch 101/500
# Train RMSE: 0.2483
# Val RMSE: 0.2497, Val MAE: 0.1078
# Test RMSE: 0.3248, Test MAE: 0.1510
# ---------------------------------
# Patience grace period: 9
# ---------------------------------
# Epoch 102/500
# Train RMSE: 0.2482
# Val RMSE: 0.2495, Val MAE: 0.1070
# Test RMSE: 0.3259, Test MAE: 0.1505
# ---------------------------------
# Patience grace period: 8
# ---------------------------------
# Epoch 103/500
# Train RMSE: 0.2482
# Val RMSE: 0.2495, Val MAE: 0.1072
# Test RMSE: 0.3255, Test MAE: 0.1504
# ---------------------------------
# Patience grace period: 6
# ---------------------------------
# Epoch 104/500
# Train RMSE: 0.2482
# Val RMSE: 0.2496, Val MAE: 0.1075
# Test RMSE: 0.3254, Test MAE: 0.1506
# ---------------------------------
# Patience grace period: 4
# ---------------------------------
# Epoch 105/500
# Train RMSE: 0.2482
# Val RMSE: 0.2494, Val MAE: 0.1069
# Test RMSE: 0.3265, Test MAE: 0.1501
# ---------------------------------
# Patience grace period: 3
# ---------------------------------
# Epoch 106/500
# Train RMSE: 0.2481
# Val RMSE: 0.2495, Val MAE: 0.1069
# Test RMSE: 0.3261, Test MAE: 0.1502
# ---------------------------------
# Patience grace period: 1
# ---------------------------------
# Epoch 107/500
# Train RMSE: 0.2481
# Val RMSE: 0.2495, Val MAE: 0.1072
# Test RMSE: 0.3253, Test MAE: 0.1505
# ---------------------------------
# Patience grace period: -1
# Early stopping triggered at epoch 107
# Final Test RMSE: 0.3267, Final Test MAE: 0.1502
# <ipython-input-3-2a228d64b832>:126: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   self.model.load_state_dict(torch.load(os.path.join(save_dir, 'best_model.pth')))
# Pearson Corr: 0.747480466905199
# Spearman Corr: 0.4276169986802547
# p-rmse: 0.32674794521357
#        rmse       mae  seed                             subtask    method  \
# 0  0.326748  0.150229     5  openproblems_bmmc_cite_phase2_mod2  original
#
#    pearson p_value_pearson  spearman p_value_spearman
# 0  0.74748          0.0000  0.427617           0.0000

# %%
config_hierachical_PROTEIN = {
    "subtask": "openproblems_bmmc_cite_phase2_mod2",
    "batch_size": 520,
    "act": "relu",
    "conv_flow": ["gat", 'sage', 'gat'],
    "agg_flow": [None, 'lstm', None],
    "device": "cuda",
    "learning_rate": 0.000064,
    "hidden_size": 280,
    "num_heads": 6,
    "n_neigbours": 3,
    "metric": "euclidean",
    "n_components": 1200,
    "dropout_rate": 0.2,
    "num_epochs": 500,
    "seed": 1,
    "es_patience": 40,
    "es_min_delta": 0.0001,
    "es_rate_threshold": 0.00002,
    "layer_dim_ex": 3,
    "verbose": True,
    "sample": True,
    "preprocessing_type": "None",
    "variant": "original",
    "num_clusters": 10
}

pipeline(**config_hierachical_PROTEIN)
# Out:
# [INFO][2025-04-15 22:43:03,046][dance][_load_raw_data] Loading /content/data/openproblems_bmmc_cite_phase2_mod2/openproblems_bmmc_cite_phase2_mod2.censor_dataset.output_train_mod1.h5ad
# Initializing pipeline...
# [INFO][2025-04-15 22:43:03,704][dance][_load_raw_data] Loading /content/data/openproblems_bmmc_cite_phase2_mod2/openproblems_bmmc_cite_phase2_mod2.censor_dataset.output_train_mod2.h5ad
# [INFO][2025-04-15 22:43:11,436][dance][_load_raw_data] Loading /content/data/openproblems_bmmc_cite_phase2_mod2/openproblems_bmmc_cite_phase2_mod2.censor_dataset.output_test_mod1.h5ad
# [INFO][2025-04-15 22:43:11,461][dance][_load_raw_data] Loading /content/data/openproblems_bmmc_cite_phase2_mod2/openproblems_bmmc_cite_phase2_mod2.censor_dataset.output_test_mod2.h5ad
# [INFO][2025-04-15 22:43:11,663][dance][_maybe_preprocess] Preprocessing done.
# /usr/local/lib/python3.11/dist-packages/mudata/_core/mudata.py:1531: FutureWarning: From 0.4 .update() will not pull obs/var columns from individual modalities by default anymore. Set mudata.set_options(pull_on_update=False) to adopt the new behaviour, which will become the default. Use new pull_obs/pull_var and push_obs/push_var methods for more flexibility.
#   self._update_attr("var", axis=0, join_common=join_common)
# /usr/local/lib/python3.11/dist-packages/mudata/_core/mudata.py:931: UserWarning: Cannot join columns with the same name because var_names are intersecting.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/mudata/_core/mudata.py:1429: FutureWarning: From 0.4 .update() will not pull obs/var columns from individual modalities by default anymore. Set mudata.set_options(pull_on_update=False) to adopt the new behaviour, which will become the default. Use new pull_obs/pull_var and push_obs/push_var methods for more flexibility.
#   self._update_attr("obs", axis=1, join_common=join_common)
# /usr/local/lib/python3.11/dist-packages/mudata/_core/mudata.py:1558: UserWarning: Modality names will be prepended to var_names since there are identical var_names in different modalities.
#   warnings.warn(
# [INFO][2025-04-15 22:43:19,054][dance][set_config_from_dict] Setting config 'feature_mod' to 'mod1'
# [INFO][2025-04-15 22:43:19,055][dance][set_config_from_dict] Setting config 'label_mod' to 'mod2'
# [INFO][2025-04-15 22:43:19,055][dance][load_data] Raw data loaded:
# Data object that wraps (.data):
# MuData object with n_obs × n_vars = 67175 × 14087
#   uns:	'dance_config'
#   2 modalities
#     mod1:	67175 x 134
#       obs:	'batch'
#       layers:	'counts'
#     mod2:	67175 x 13953
#       obs:	'batch'
#       layers:	'counts'
# [INFO][2025-04-15 22:43:19,179][dance][wrapped_func] Took 0:00:16.134155 to load and process data.
# <ipython-input-4-038168299b8a>:42: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   data.data.uns['gtrain'] = torch.load(train_graph_path)
# <ipython-input-4-038168299b8a>:43: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   data.data.uns['gval'] = torch.load(val_graph_path)
# <ipython-input-4-038168299b8a>:44: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   data.data.uns['gtest'] = torch.load(test_graph_path)
# <ipython-input-4-038168299b8a>:45: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   train_label = torch.load(train_label_path).numpy()
# Processed data found. Loading...
# <ipython-input-4-038168299b8a>:46: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   val_label = torch.load(val_label_path).numpy()
# <ipython-input-4-038168299b8a>:47: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   test_label = torch.load(test_label_path).numpy()
# <ipython-input-4-038168299b8a>:48: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   kwargs["FEATURE_SIZE"] = torch.load(feature_size_path).item()
# <ipython-input-4-038168299b8a>:49: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   kwargs["OUTPUT_SIZE"] = torch.load(output_size_path).item()
# Processed data loaded.
# ---------------------------------
# Epoch 1/500
# Train RMSE: 0.3662
# Val RMSE: 0.3049, Val MAE: 0.1334
# Test RMSE: 0.3757, Test MAE: 0.1761
# ---------------------------------
# Model saved at epoch 1 with val RMSE 0.3049
# Patience grace period: 40
# ---------------------------------
# Epoch 2/500
# Train RMSE: 0.3102
# Val RMSE: 0.2836, Val MAE: 0.1265
# Test RMSE: 0.3549, Test MAE: 0.1665
# ---------------------------------
# Model saved at epoch 2 with val RMSE 0.2836
# Patience grace period: 40
# ---------------------------------
# Epoch 3/500
# Train RMSE: 0.2911
# Val RMSE: 0.2723, Val MAE: 0.1201
# Test RMSE: 0.3473, Test MAE: 0.1598
# ---------------------------------
# Model saved at epoch 3 with val RMSE 0.2723
# Patience grace period: 40
# ---------------------------------
# Epoch 4/500
# Train RMSE: 0.2814
# Val RMSE: 0.2678, Val MAE: 0.1186
# Test RMSE: 0.3447, Test MAE: 0.1581
# ---------------------------------
# Model saved at epoch 4 with val RMSE 0.2678
# Patience grace period: 40
# ---------------------------------
# Epoch 5/500
# Train RMSE: 0.2760
# Val RMSE: 0.2649, Val MAE: 0.1176
# Test RMSE: 0.3423, Test MAE: 0.1568
# ---------------------------------
# Model saved at epoch 5 with val RMSE 0.2649
# Patience grace period: 40
# ---------------------------------
# Epoch 6/500
# Train RMSE: 0.2719
# Val RMSE: 0.2622, Val MAE: 0.1163
# Test RMSE: 0.3398, Test MAE: 0.1546
# ---------------------------------
# Model saved at epoch 6 with val RMSE 0.2622
# Patience grace period: 40
# ---------------------------------
# Epoch 7/500
# Train RMSE: 0.2684
# Val RMSE: 0.2600, Val MAE: 0.1149
# Test RMSE: 0.3381, Test MAE: 0.1527
# ---------------------------------
# Model saved at epoch 7 with val RMSE 0.2600
# Patience grace period: 40
# ---------------------------------
# Epoch 8/500
# Train RMSE: 0.2657
# Val RMSE: 0.2583, Val MAE: 0.1139
# Test RMSE: 0.3372, Test MAE: 0.1517
# ---------------------------------
# Model saved at epoch 8 with val RMSE 0.2583
# Patience grace period: 40
# ---------------------------------
# Epoch 9/500
# Train RMSE: 0.2636
# Val RMSE: 0.2572, Val MAE: 0.1128
# Test RMSE: 0.3375, Test MAE: 0.1510
# ---------------------------------
# Model saved at epoch 9 with val RMSE 0.2572
# Patience grace period: 40
# ---------------------------------
# Epoch 10/500
# Train RMSE: 0.2620
# Val RMSE: 0.2563, Val MAE: 0.1122
# Test RMSE: 0.3369, Test MAE: 0.1507
# ---------------------------------
# Model saved at epoch 10 with val RMSE 0.2563
# Patience grace period: 40
# ---------------------------------
# Epoch 11/500
# Train RMSE: 0.2607
# Val RMSE: 0.2557, Val MAE: 0.1114
# Test RMSE: 0.3368, Test MAE: 0.1503
# ---------------------------------
# Model saved at epoch 11 with val RMSE 0.2557
# Patience grace period: 40
# ---------------------------------
# Epoch 12/500
# Train RMSE: 0.2596
# Val RMSE: 0.2551, Val MAE: 0.1111
# Test RMSE: 0.3364, Test MAE: 0.1501
# ---------------------------------
# Model saved at epoch 12 with val RMSE 0.2551
# Patience grace period: 40
# ---------------------------------
# Epoch 13/500
# Train RMSE: 0.2587
# Val RMSE: 0.2546, Val MAE: 0.1107
# Test RMSE: 0.3358, Test MAE: 0.1498
# ---------------------------------
# Model saved at epoch 13 with val RMSE 0.2546
# Patience grace period: 40
# ---------------------------------
# Epoch 14/500
# Train RMSE: 0.2579
# Val RMSE: 0.2542, Val MAE: 0.1106
# Test RMSE: 0.3353, Test MAE: 0.1497
# ---------------------------------
# Model saved at epoch 14 with val RMSE 0.2542
# Patience grace period: 40
# ---------------------------------
# Epoch 15/500
# Train RMSE: 0.2573
# Val RMSE: 0.2539, Val MAE: 0.1099
# Test RMSE: 0.3353, Test MAE: 0.1493
# ---------------------------------
# Model saved at epoch 15 with val RMSE 0.2539
# Patience grace period: 40
# ---------------------------------
# Epoch 16/500
# Train RMSE: 0.2567
# Val RMSE: 0.2535, Val MAE: 0.1097
# Test RMSE: 0.3346, Test MAE: 0.1491
# ---------------------------------
# Model saved at epoch 16 with val RMSE 0.2535
# Patience grace period: 40
# ---------------------------------
# Epoch 17/500
# Train RMSE: 0.2561
# Val RMSE: 0.2532, Val MAE: 0.1092
# Test RMSE: 0.3346, Test MAE: 0.1487
# ---------------------------------
# Model saved at epoch 17 with val RMSE 0.2532
# Patience grace period: 40
# ---------------------------------
# Epoch 18/500
# Train RMSE: 0.2557
# Val RMSE: 0.2529, Val MAE: 0.1094
# Test RMSE: 0.3332, Test MAE: 0.1486
# ---------------------------------
# Model saved at epoch 18 with val RMSE 0.2529
# Patience grace period: 40
# ---------------------------------
# Epoch 19/500
# Train RMSE: 0.2552
# Val RMSE: 0.2526, Val MAE: 0.1092
# Test RMSE: 0.3331, Test MAE: 0.1486
# ---------------------------------
# Model saved at epoch 19 with val RMSE 0.2526
# Patience grace period: 40
# ---------------------------------
# Epoch 20/500
# Train RMSE: 0.2548
# Val RMSE: 0.2524, Val MAE: 0.1094
# Test RMSE: 0.3319, Test MAE: 0.1486
# ---------------------------------
# Model saved at epoch 20 with val RMSE 0.2524
# Patience grace period: 40
# ---------------------------------
# Epoch 21/500
# Train RMSE: 0.2545
# Val RMSE: 0.2522, Val MAE: 0.1086
# Test RMSE: 0.3325, Test MAE: 0.1482
# ---------------------------------
# Model saved at epoch 21 with val RMSE 0.2522
# Patience grace period: 40
# ---------------------------------
# Epoch 22/500
# Train RMSE: 0.2542
# Val RMSE: 0.2520, Val MAE: 0.1089
# Test RMSE: 0.3314, Test MAE: 0.1486
# ---------------------------------
# Model saved at epoch 22 with val RMSE 0.2520
# Patience grace period: 40
# ---------------------------------
# Epoch 23/500
# Train RMSE: 0.2539
# Val RMSE: 0.2518, Val MAE: 0.1086
# Test RMSE: 0.3314, Test MAE: 0.1483
# ---------------------------------
# Model saved at epoch 23 with val RMSE 0.2518
# Patience grace period: 40
# ---------------------------------
# Epoch 24/500
# Train RMSE: 0.2536
# Val RMSE: 0.2517, Val MAE: 0.1085
# Test RMSE: 0.3313, Test MAE: 0.1484
# ---------------------------------
# Model saved at epoch 24 with val RMSE 0.2517
# Patience grace period: 40
# ---------------------------------
# Epoch 25/500
# Train RMSE: 0.2534
# Val RMSE: 0.2516, Val MAE: 0.1082
# Test RMSE: 0.3316, Test MAE: 0.1485
# ---------------------------------
# Model saved at epoch 25 with val RMSE 0.2516
# Patience grace period: 40
# ---------------------------------
# Epoch 26/500
# Train RMSE: 0.2532
# Val RMSE: 0.2515, Val MAE: 0.1082
# Test RMSE: 0.3313, Test MAE: 0.1484
# ---------------------------------
# Model saved at epoch 26 with val RMSE 0.2515
# Patience grace period: 40
# ---------------------------------
# Epoch 27/500
# Train RMSE: 0.2530
# Val RMSE: 0.2513, Val MAE: 0.1083
# Test RMSE: 0.3306, Test MAE: 0.1486
# ---------------------------------
# Model saved at epoch 27 with val RMSE 0.2513
# Patience grace period: 40
# ---------------------------------
# Epoch 28/500
# Train RMSE: 0.2528
# Val RMSE: 0.2512, Val MAE: 0.1078
# Test RMSE: 0.3310, Test MAE: 0.1485
# ---------------------------------
# Model saved at epoch 28 with val RMSE 0.2512
# Patience grace period: 40
# ---------------------------------
# Epoch 29/500
# Train RMSE: 0.2526
# Val RMSE: 0.2512, Val MAE: 0.1073
# Test RMSE: 0.3319, Test MAE: 0.1482
# ---------------------------------
# Model saved at epoch 29 with val RMSE 0.2512
# Patience grace period: 39
# ---------------------------------
# Epoch 30/500
# Train RMSE: 0.2524
# Val RMSE: 0.2510, Val MAE: 0.1074
# Test RMSE: 0.3310, Test MAE: 0.1484
# ---------------------------------
# Model saved at epoch 30 with val RMSE 0.2510
# Patience grace period: 40
# ---------------------------------
# Epoch 31/500
# Train RMSE: 0.2522
# Val RMSE: 0.2509, Val MAE: 0.1077
# Test RMSE: 0.3304, Test MAE: 0.1486
# ---------------------------------
# Model saved at epoch 31 with val RMSE 0.2509
# Patience grace period: 40
# ---------------------------------
# Epoch 32/500
# Train RMSE: 0.2521
# Val RMSE: 0.2508, Val MAE: 0.1081
# Test RMSE: 0.3295, Test MAE: 0.1489
# ---------------------------------
# Model saved at epoch 32 with val RMSE 0.2508
# Patience grace period: 39
# ---------------------------------
# Epoch 33/500
# Train RMSE: 0.2519
# Val RMSE: 0.2507, Val MAE: 0.1075
# Test RMSE: 0.3304, Test MAE: 0.1487
# ---------------------------------
# Model saved at epoch 33 with val RMSE 0.2507
# Patience grace period: 40
# ---------------------------------
# Epoch 34/500
# Train RMSE: 0.2518
# Val RMSE: 0.2506, Val MAE: 0.1079
# Test RMSE: 0.3295, Test MAE: 0.1490
# ---------------------------------
# Model saved at epoch 34 with val RMSE 0.2506
# Patience grace period: 39
# ---------------------------------
# Epoch 35/500
# Train RMSE: 0.2517
# Val RMSE: 0.2505, Val MAE: 0.1076
# Test RMSE: 0.3297, Test MAE: 0.1489
# ---------------------------------
# Model saved at epoch 35 with val RMSE 0.2505
# Patience grace period: 40
# ---------------------------------
# Epoch 36/500
# Train RMSE: 0.2515
# Val RMSE: 0.2505, Val MAE: 0.1073
# Test RMSE: 0.3298, Test MAE: 0.1487
# ---------------------------------
# Model saved at epoch 36 with val RMSE 0.2505
# Patience grace period: 39
# ---------------------------------
# Epoch 37/500
# Train RMSE: 0.2514
# Val RMSE: 0.2504, Val MAE: 0.1073
# Test RMSE: 0.3298, Test MAE: 0.1489
# ---------------------------------
# Model saved at epoch 37 with val RMSE 0.2504
# Patience grace period: 38
# ---------------------------------
# Epoch 38/500
# Train RMSE: 0.2513
# Val RMSE: 0.2504, Val MAE: 0.1072
# Test RMSE: 0.3297, Test MAE: 0.1489
# ---------------------------------
# Model saved at epoch 38 with val RMSE 0.2504
# Patience grace period: 40
# ---------------------------------
# Epoch 39/500
# Train RMSE: 0.2512
# Val RMSE: 0.2503, Val MAE: 0.1070
# Test RMSE: 0.3301, Test MAE: 0.1489
# ---------------------------------
# Model saved at epoch 39 with val RMSE 0.2503
# Patience grace period: 39
# ---------------------------------
# Epoch 40/500
# Train RMSE: 0.2510
# Val RMSE: 0.2502, Val MAE: 0.1070
# Test RMSE: 0.3300, Test MAE: 0.1489
# ---------------------------------
# Model saved at epoch 40 with val RMSE 0.2502
# Patience grace period: 40
# ---------------------------------
# Epoch 41/500
# Train RMSE: 0.2509
# Val RMSE: 0.2501, Val MAE: 0.1072
# Test RMSE: 0.3292, Test MAE: 0.1491
# ---------------------------------
# Model saved at epoch 41 with val RMSE 0.2501
# Patience grace period: 39
# ---------------------------------
# Epoch 42/500
# Train RMSE: 0.2508
# Val RMSE: 0.2501, Val MAE: 0.1066
# Test RMSE: 0.3303, Test MAE: 0.1486
# ---------------------------------
# Patience grace period: 37
# ---------------------------------
# Epoch 43/500
# Train RMSE: 0.2507
# Val RMSE: 0.2500, Val MAE: 0.1071
# Test RMSE: 0.3290, Test MAE: 0.1493
# ---------------------------------
# Model saved at epoch 43 with val RMSE 0.2500
# Patience grace period: 40
# ---------------------------------
# Epoch 44/500
# Train RMSE: 0.2506
# Val RMSE: 0.2500, Val MAE: 0.1071
# Test RMSE: 0.3285, Test MAE: 0.1492
# ---------------------------------
# Model saved at epoch 44 with val RMSE 0.2500
# Patience grace period: 39
# ---------------------------------
# Epoch 45/500
# Train RMSE: 0.2505
# Val RMSE: 0.2499, Val MAE: 0.1070
# Test RMSE: 0.3287, Test MAE: 0.1492
# ---------------------------------
# Model saved at epoch 45 with val RMSE 0.2499
# Patience grace period: 40
# ---------------------------------
# Epoch 46/500
# Train RMSE: 0.2504
# Val RMSE: 0.2499, Val MAE: 0.1069
# Test RMSE: 0.3286, Test MAE: 0.1494
# ---------------------------------
# Model saved at epoch 46 with val RMSE 0.2499
# Patience grace period: 39
# ---------------------------------
# Epoch 47/500
# Train RMSE: 0.2504
# Val RMSE: 0.2499, Val MAE: 0.1072
# Test RMSE: 0.3283, Test MAE: 0.1496
# ---------------------------------
# Model saved at epoch 47 with val RMSE 0.2499
# Patience grace period: 38
# ---------------------------------
# Epoch 48/500
# Train RMSE: 0.2503
# Val RMSE: 0.2498, Val MAE: 0.1068
# Test RMSE: 0.3288, Test MAE: 0.1491
# ---------------------------------
# Model saved at epoch 48 with val RMSE 0.2498
# Patience grace period: 40
# ---------------------------------
# Epoch 49/500
# Train RMSE: 0.2502
# Val RMSE: 0.2498, Val MAE: 0.1071
# Test RMSE: 0.3279, Test MAE: 0.1497
# ---------------------------------
# Model saved at epoch 49 with val RMSE 0.2498
# Patience grace period: 39
# ---------------------------------
# Epoch 50/500
# Train RMSE: 0.2501
# Val RMSE: 0.2498, Val MAE: 0.1071
# Test RMSE: 0.3280, Test MAE: 0.1498
# ---------------------------------
# Model saved at epoch 50 with val RMSE 0.2498
# Patience grace period: 38
# ---------------------------------
# Epoch 51/500
# Train RMSE: 0.2501
# Val RMSE: 0.2497, Val MAE: 0.1068
# Test RMSE: 0.3282, Test MAE: 0.1496
# ---------------------------------
# Model saved at epoch 51 with val RMSE 0.2497
# Patience grace period: 40
# ---------------------------------
# Epoch 52/500
# Train RMSE: 0.2500
# Val RMSE: 0.2497, Val MAE: 0.1066
# Test RMSE: 0.3290, Test MAE: 0.1495
# ---------------------------------
# Model saved at epoch 52 with val RMSE 0.2497
# Patience grace period: 39
# ---------------------------------
# Epoch 53/500
# Train RMSE: 0.2499
# Val RMSE: 0.2496, Val MAE: 0.1067
# Test RMSE: 0.3281, Test MAE: 0.1496
# ---------------------------------
# Model saved at epoch 53 with val RMSE 0.2496
# Patience grace period: 38
# ---------------------------------
# Epoch 54/500
# Train RMSE: 0.2499
# Val RMSE: 0.2496, Val MAE: 0.1067
# Test RMSE: 0.3280, Test MAE: 0.1496
# ---------------------------------
# Model saved at epoch 54 with val RMSE 0.2496
# Patience grace period: 40
# ---------------------------------
# Epoch 55/500
# Train RMSE: 0.2498
# Val RMSE: 0.2495, Val MAE: 0.1070
# Test RMSE: 0.3273, Test MAE: 0.1500
# ---------------------------------
# Model saved at epoch 55 with val RMSE 0.2495
# Patience grace period: 39
# ---------------------------------
# Epoch 56/500
# Train RMSE: 0.2497
# Val RMSE: 0.2495, Val MAE: 0.1069
# Test RMSE: 0.3272, Test MAE: 0.1500
# ---------------------------------
# Model saved at epoch 56 with val RMSE 0.2495
# Patience grace period: 38
# ---------------------------------
# Epoch 57/500
# Train RMSE: 0.2496
# Val RMSE: 0.2495, Val MAE: 0.1069
# Test RMSE: 0.3274, Test MAE: 0.1499
# ---------------------------------
# Model saved at epoch 57 with val RMSE 0.2495
# Patience grace period: 40
# ---------------------------------
# Epoch 58/500
# Train RMSE: 0.2496
# Val RMSE: 0.2495, Val MAE: 0.1066
# Test RMSE: 0.3278, Test MAE: 0.1496
# ---------------------------------
# Patience grace period: 38
# ---------------------------------
# Epoch 59/500
# Train RMSE: 0.2495
# Val RMSE: 0.2494, Val MAE: 0.1066
# Test RMSE: 0.3275, Test MAE: 0.1498
# ---------------------------------
# Model saved at epoch 59 with val RMSE 0.2494
# Patience grace period: 37
# ---------------------------------
# Epoch 60/500
# Train RMSE: 0.2495
# Val RMSE: 0.2494, Val MAE: 0.1064
# Test RMSE: 0.3280, Test MAE: 0.1497
# ---------------------------------
# Patience grace period: 35
# ---------------------------------
# Epoch 61/500
# Train RMSE: 0.2494
# Val RMSE: 0.2494, Val MAE: 0.1064
# Test RMSE: 0.3282, Test MAE: 0.1498
# ---------------------------------
# Patience grace period: 34
# ---------------------------------
# Epoch 62/500
# Train RMSE: 0.2494
# Val RMSE: 0.2494, Val MAE: 0.1063
# Test RMSE: 0.3279, Test MAE: 0.1496
# ---------------------------------
# Model saved at epoch 62 with val RMSE 0.2494
# Patience grace period: 40
# ---------------------------------
# Epoch 63/500
# Train RMSE: 0.2493
# Val RMSE: 0.2493, Val MAE: 0.1066
# Test RMSE: 0.3272, Test MAE: 0.1500
# ---------------------------------
# Model saved at epoch 63 with val RMSE 0.2493
# Patience grace period: 39
# ---------------------------------
# Epoch 64/500
# Train RMSE: 0.2492
# Val RMSE: 0.2493, Val MAE: 0.1064
# Test RMSE: 0.3276, Test MAE: 0.1497
# ---------------------------------
# Model saved at epoch 64 with val RMSE 0.2493
# Patience grace period: 38
# ---------------------------------
# Epoch 65/500
# Train RMSE: 0.2492
# Val RMSE: 0.2493, Val MAE: 0.1065
# Test RMSE: 0.3271, Test MAE: 0.1500
# ---------------------------------
# Model saved at epoch 65 with val RMSE 0.2493
# Patience grace period: 37
# ---------------------------------
# Epoch 66/500
# Train RMSE: 0.2491
# Val RMSE: 0.2493, Val MAE: 0.1062
# Test RMSE: 0.3278, Test MAE: 0.1496
# ---------------------------------
# Patience grace period: 35
# ---------------------------------
# Epoch 67/500
# Train RMSE: 0.2491
# Val RMSE: 0.2492, Val MAE: 0.1064
# Test RMSE: 0.3272, Test MAE: 0.1498
# ---------------------------------
# Model saved at epoch 67 with val RMSE 0.2492
# Patience grace period: 40
# ---------------------------------
# Epoch 68/500
# Train RMSE: 0.2490
# Val RMSE: 0.2492, Val MAE: 0.1063
# Test RMSE: 0.3272, Test MAE: 0.1499
# ---------------------------------
# Model saved at epoch 68 with val RMSE 0.2492
# Patience grace period: 39
# ---------------------------------
# Epoch 69/500
# Train RMSE: 0.2490
# Val RMSE: 0.2492, Val MAE: 0.1062
# Test RMSE: 0.3273, Test MAE: 0.1501
# ---------------------------------
# Patience grace period: 37
# ---------------------------------
# Epoch 70/500
# Train RMSE: 0.2490
# Val RMSE: 0.2492, Val MAE: 0.1058
# Test RMSE: 0.3282, Test MAE: 0.1495
# ---------------------------------
# Patience grace period: 35
# ---------------------------------
# Epoch 71/500
# Train RMSE: 0.2489
# Val RMSE: 0.2491, Val MAE: 0.1065
# Test RMSE: 0.3266, Test MAE: 0.1502
# ---------------------------------
# Model saved at epoch 71 with val RMSE 0.2491
# Patience grace period: 34
# ---------------------------------
# Epoch 72/500
# Train RMSE: 0.2488
# Val RMSE: 0.2491, Val MAE: 0.1066
# Test RMSE: 0.3265, Test MAE: 0.1503
# ---------------------------------
# Patience grace period: 32
# ---------------------------------
# Epoch 73/500
# Train RMSE: 0.2488
# Val RMSE: 0.2492, Val MAE: 0.1059
# Test RMSE: 0.3279, Test MAE: 0.1498
# ---------------------------------
# Patience grace period: 30
# ---------------------------------
# Epoch 74/500
# Train RMSE: 0.2488
# Val RMSE: 0.2491, Val MAE: 0.1063
# Test RMSE: 0.3266, Test MAE: 0.1501
# ---------------------------------
# Model saved at epoch 74 with val RMSE 0.2491
# Patience grace period: 29
# ---------------------------------
# Epoch 75/500
# Train RMSE: 0.2487
# Val RMSE: 0.2492, Val MAE: 0.1060
# Test RMSE: 0.3275, Test MAE: 0.1500
# ---------------------------------
# Patience grace period: 27
# ---------------------------------
# Epoch 76/500
# Train RMSE: 0.2487
# Val RMSE: 0.2491, Val MAE: 0.1065
# Test RMSE: 0.3264, Test MAE: 0.1503
# ---------------------------------
# Model saved at epoch 76 with val RMSE 0.2491
# Patience grace period: 40
# ---------------------------------
# Epoch 77/500
# Train RMSE: 0.2486
# Val RMSE: 0.2491, Val MAE: 0.1059
# Test RMSE: 0.3273, Test MAE: 0.1498
# ---------------------------------
# Patience grace period: 38
# ---------------------------------
# Epoch 78/500
# Train RMSE: 0.2486
# Val RMSE: 0.2491, Val MAE: 0.1063
# Test RMSE: 0.3267, Test MAE: 0.1503
# ---------------------------------
# Model saved at epoch 78 with val RMSE 0.2491
# Patience grace period: 37
# ---------------------------------
# Epoch 79/500
# Train RMSE: 0.2485
# Val RMSE: 0.2490, Val MAE: 0.1062
# Test RMSE: 0.3266, Test MAE: 0.1501
# ---------------------------------
# Model saved at epoch 79 with val RMSE 0.2490
# Patience grace period: 36
# ---------------------------------
# Epoch 80/500
# Train RMSE: 0.2485
# Val RMSE: 0.2491, Val MAE: 0.1060
# Test RMSE: 0.3270, Test MAE: 0.1501
# ---------------------------------
# Patience grace period: 34
# ---------------------------------
# Epoch 81/500
# Train RMSE: 0.2485
# Val RMSE: 0.2491, Val MAE: 0.1061
# Test RMSE: 0.3269, Test MAE: 0.1501
# ---------------------------------
# Patience grace period: 32
# ---------------------------------
# Epoch 82/500
# Train RMSE: 0.2484
# Val RMSE: 0.2490, Val MAE: 0.1061
# Test RMSE: 0.3270, Test MAE: 0.1499
# ---------------------------------
# Model saved at epoch 82 with val RMSE 0.2490
# Patience grace period: 31
# ---------------------------------
# Epoch 83/500
# Train RMSE: 0.2484
# Val RMSE: 0.2490, Val MAE: 0.1058
# Test RMSE: 0.3270, Test MAE: 0.1499
# ---------------------------------
# Model saved at epoch 83 with val RMSE 0.2490
# Patience grace period: 30
# ---------------------------------
# Epoch 84/500
# Train RMSE: 0.2484
# Val RMSE: 0.2489, Val MAE: 0.1064
# Test RMSE: 0.3262, Test MAE: 0.1502
# ---------------------------------
# Model saved at epoch 84 with val RMSE 0.2489
# Patience grace period: 40
# ---------------------------------
# Epoch 85/500
# Train RMSE: 0.2483
# Val RMSE: 0.2491, Val MAE: 0.1058
# Test RMSE: 0.3274, Test MAE: 0.1498
# ---------------------------------
# Patience grace period: 38
# ---------------------------------
# Epoch 86/500
# Train RMSE: 0.2483
# Val RMSE: 0.2490, Val MAE: 0.1057
# Test RMSE: 0.3273, Test MAE: 0.1497
# ---------------------------------
# Patience grace period: 37
# ---------------------------------
# Epoch 87/500
# Train RMSE: 0.2483
# Val RMSE: 0.2490, Val MAE: 0.1061
# Test RMSE: 0.3265, Test MAE: 0.1501
# ---------------------------------
# Patience grace period: 36
# ---------------------------------
# Epoch 88/500
# Train RMSE: 0.2482
# Val RMSE: 0.2490, Val MAE: 0.1061
# Test RMSE: 0.3268, Test MAE: 0.1503
# ---------------------------------
# Patience grace period: 34
# ---------------------------------
# Epoch 89/500
# Train RMSE: 0.2482
# Val RMSE: 0.2490, Val MAE: 0.1059
# Test RMSE: 0.3269, Test MAE: 0.1499
# ---------------------------------
# Patience grace period: 32
# ---------------------------------
# Epoch 90/500
# Train RMSE: 0.2482
# Val RMSE: 0.2490, Val MAE: 0.1059
# Test RMSE: 0.3269, Test MAE: 0.1501
# ---------------------------------
# Patience grace period: 30
# ---------------------------------
# Epoch 91/500
# Train RMSE: 0.2481
# Val RMSE: 0.2489, Val MAE: 0.1061
# Test RMSE: 0.3263, Test MAE: 0.1501
# ---------------------------------
# Model saved at epoch 91 with val RMSE 0.2489
# Patience grace period: 29
# ---------------------------------
# Epoch 92/500
# Train RMSE: 0.2481
# Val RMSE: 0.2490, Val MAE: 0.1055
# Test RMSE: 0.3273, Test MAE: 0.1499
# ---------------------------------
# Patience grace period: 27
# ---------------------------------
# Epoch 93/500
# Train RMSE: 0.2481
# Val RMSE: 0.2489, Val MAE: 0.1061
# Test RMSE: 0.3266, Test MAE: 0.1503
# ---------------------------------
# Patience grace period: 26
# ---------------------------------
# Epoch 94/500
# Train RMSE: 0.2480
# Val RMSE: 0.2489, Val MAE: 0.1062
# Test RMSE: 0.3265, Test MAE: 0.1504
# ---------------------------------
# Patience grace period: 25
# ---------------------------------
# Epoch 95/500
# Train RMSE: 0.2480
# Val RMSE: 0.2489, Val MAE: 0.1062
# Test RMSE: 0.3263, Test MAE: 0.1505
# ---------------------------------
# Patience grace period: 23
# ---------------------------------
# Epoch 96/500
# Train RMSE: 0.2480
# Val RMSE: 0.2489, Val MAE: 0.1058
# Test RMSE: 0.3269, Test MAE: 0.1501
# ---------------------------------
# Patience grace period: 21
# ---------------------------------
# Epoch 97/500
# Train RMSE: 0.2479
# Val RMSE: 0.2489, Val MAE: 0.1062
# Test RMSE: 0.3260, Test MAE: 0.1503
# ---------------------------------
# Model saved at epoch 97 with val RMSE 0.2489
# Patience grace period: 20
# ---------------------------------
# Epoch 98/500
# Train RMSE: 0.2479
# Val RMSE: 0.2489, Val MAE: 0.1059
# Test RMSE: 0.3265, Test MAE: 0.1499
# ---------------------------------
# Patience grace period: 18
# ---------------------------------
# Epoch 99/500
# Train RMSE: 0.2479
# Val RMSE: 0.2489, Val MAE: 0.1060
# Test RMSE: 0.3263, Test MAE: 0.1502
# ---------------------------------
# Patience grace period: 17
# ---------------------------------
# Epoch 100/500
# Train RMSE: 0.2479
# Val RMSE: 0.2489, Val MAE: 0.1057
# Test RMSE: 0.3271, Test MAE: 0.1500
# ---------------------------------
# Patience grace period: 15
# ---------------------------------
# Epoch 101/500
# Train RMSE: 0.2478
# Val RMSE: 0.2489, Val MAE: 0.1060
# Test RMSE: 0.3265, Test MAE: 0.1503
# ---------------------------------
# Model saved at epoch 101 with val RMSE 0.2489
# Patience grace period: 14
# ---------------------------------
# Epoch 102/500
# Train RMSE: 0.2478
# Val RMSE: 0.2489, Val MAE: 0.1059
# Test RMSE: 0.3262, Test MAE: 0.1500
# ---------------------------------
# Model saved at epoch 102 with val RMSE 0.2489
# Patience grace period: 13
# ---------------------------------
# Epoch 103/500
# Train RMSE: 0.2478
# Val RMSE: 0.2488, Val MAE: 0.1062
# Test RMSE: 0.3256, Test MAE: 0.1505
# ---------------------------------
# Model saved at epoch 103 with val RMSE 0.2488
# Patience grace period: 40
# ---------------------------------
# Epoch 104/500
# Train RMSE: 0.2477
# Val RMSE: 0.2488, Val MAE: 0.1061
# Test RMSE: 0.3259, Test MAE: 0.1504
# ---------------------------------
# Patience grace period: 38
# ---------------------------------
# Epoch 105/500
# Train RMSE: 0.2477
# Val RMSE: 0.2488, Val MAE: 0.1061
# Test RMSE: 0.3260, Test MAE: 0.1504
# ---------------------------------
# Patience grace period: 37
# ---------------------------------
# Epoch 106/500
# Train RMSE: 0.2477
# Val RMSE: 0.2489, Val MAE: 0.1060
# Test RMSE: 0.3263, Test MAE: 0.1503
# ---------------------------------
# Patience grace period: 35
# ---------------------------------
# Epoch 107/500
# Train RMSE: 0.2477
# Val RMSE: 0.2489, Val MAE: 0.1056
# Test RMSE: 0.3269, Test MAE: 0.1501
# ---------------------------------
# Patience grace period: 33
# ---------------------------------
# Epoch 108/500
# Train RMSE: 0.2476
# Val RMSE: 0.2488, Val MAE: 0.1059
# Test RMSE: 0.3262, Test MAE: 0.1503
# ---------------------------------
# Patience grace period: 32
# ---------------------------------
# Epoch 109/500
# Train RMSE: 0.2476
# Val RMSE: 0.2488, Val MAE: 0.1061
# Test RMSE: 0.3257, Test MAE: 0.1502
# ---------------------------------
# Model saved at epoch 109 with val RMSE 0.2488
# Patience grace period: 31
# ---------------------------------
# Epoch 110/500
# Train RMSE: 0.2476
# Val RMSE: 0.2488, Val MAE: 0.1061
# Test RMSE: 0.3257, Test MAE: 0.1504
# ---------------------------------
# Patience grace period: 29
# ---------------------------------
# Epoch 111/500
# Train RMSE: 0.2476
# Val RMSE: 0.2488, Val MAE: 0.1065
# Test RMSE: 0.3247, Test MAE: 0.1507
# ---------------------------------
# Model saved at epoch 111 with val RMSE 0.2488
# Patience grace period: 28
# ---------------------------------
# Epoch 112/500
# Train RMSE: 0.2476
# Val RMSE: 0.2488, Val MAE: 0.1059
# Test RMSE: 0.3261, Test MAE: 0.1504
# ---------------------------------
# Patience grace period: 26
# ---------------------------------
# Epoch 113/500
# Train RMSE: 0.2475
# Val RMSE: 0.2488, Val MAE: 0.1061
# Test RMSE: 0.3260, Test MAE: 0.1504
# ---------------------------------
# Patience grace period: 24
# ---------------------------------
# Epoch 114/500
# Train RMSE: 0.2475
# Val RMSE: 0.2488, Val MAE: 0.1061
# Test RMSE: 0.3261, Test MAE: 0.1504
# ---------------------------------
# Patience grace period: 23
# ---------------------------------
# Epoch 115/500
# Train RMSE: 0.2475
# Val RMSE: 0.2488, Val MAE: 0.1060
# Test RMSE: 0.3260, Test MAE: 0.1502
# ---------------------------------
# Patience grace period: 21
# ---------------------------------
# Epoch 116/500
# Train RMSE: 0.2475
# Val RMSE: 0.2488, Val MAE: 0.1064
# Test RMSE: 0.3254, Test MAE: 0.1507
# ---------------------------------
# Patience grace period: 20
# ---------------------------------
# Epoch 117/500
# Train RMSE: 0.2474
# Val RMSE: 0.2488, Val MAE: 0.1063
# Test RMSE: 0.3252, Test MAE: 0.1507
# ---------------------------------
# Patience grace period: 18
# ---------------------------------
# Epoch 118/500
# Train RMSE: 0.2474
# Val RMSE: 0.2489, Val MAE: 0.1060
# Test RMSE: 0.3262, Test MAE: 0.1505
# ---------------------------------
# Patience grace period: 16
# ---------------------------------
# Epoch 119/500
# Train RMSE: 0.2474
# Val RMSE: 0.2488, Val MAE: 0.1058
# Test RMSE: 0.3261, Test MAE: 0.1505
# ---------------------------------
# Patience grace period: 15
# ---------------------------------
# Epoch 120/500
# Train RMSE: 0.2474
# Val RMSE: 0.2488, Val MAE: 0.1060
# Test RMSE: 0.3259, Test MAE: 0.1506
# ---------------------------------
# Patience grace period: 13
# ---------------------------------
# Epoch 121/500
# Train RMSE: 0.2473
# Val RMSE: 0.2488, Val MAE: 0.1059
# Test RMSE: 0.3263, Test MAE: 0.1505
# ---------------------------------
# Patience grace period: 12
# ---------------------------------
# Epoch 122/500
# Train RMSE: 0.2473
# Val RMSE: 0.2488, Val MAE: 0.1058
# Test RMSE: 0.3263, Test MAE: 0.1506
# ---------------------------------
# Patience grace period: 10
# ---------------------------------
# Epoch 123/500
# Train RMSE: 0.2473
# Val RMSE: 0.2488, Val MAE: 0.1060
# Test RMSE: 0.3259, Test MAE: 0.1506
# ---------------------------------
# Patience grace period: 8
# ---------------------------------
# Epoch 124/500
# Train RMSE: 0.2473
# Val RMSE: 0.2488, Val MAE: 0.1061
# Test RMSE: 0.3256, Test MAE: 0.1508
# ---------------------------------
# Patience grace period: 7
# ---------------------------------
# Epoch 125/500
# Train RMSE: 0.2473
# Val RMSE: 0.2488, Val MAE: 0.1059
# Test RMSE: 0.3261, Test MAE: 0.1504
# ---------------------------------
# Patience grace period: 6
# ---------------------------------
# Epoch 126/500
# Train RMSE: 0.2472
# Val RMSE: 0.2488, Val MAE: 0.1058
# Test RMSE: 0.3261, Test MAE: 0.1503
# ---------------------------------
# Patience grace period: 4
# ---------------------------------
# Epoch 127/500
# Train RMSE: 0.2472
# Val RMSE: 0.2488, Val MAE: 0.1056
# Test RMSE: 0.3264, Test MAE: 0.1503
# ---------------------------------
# Patience grace period: 2
# ---------------------------------
# Epoch 128/500
# Train RMSE: 0.2472
# Val RMSE: 0.2488, Val MAE: 0.1058
# Test RMSE: 0.3260, Test MAE: 0.1506
# ---------------------------------
# Patience grace period: 1
# ---------------------------------
# Epoch 129/500
# Train RMSE: 0.2472
# Val RMSE: 0.2488, Val MAE: 0.1057
# Test RMSE: 0.3264, Test MAE: 0.1505
# ---------------------------------
# Patience grace period: -1
# Early stopping triggered at epoch 129
# Final Test RMSE: 0.3247, Final Test MAE: 0.1507
# <ipython-input-3-2a228d64b832>:126: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   self.model.load_state_dict(torch.load(os.path.join(save_dir, 'best_model.pth')))
# Pearson Corr: 0.7480508999887405
# Spearman Corr: 0.42979537549994584
# p-rmse: 0.3247229091806345
#        rmse       mae  seed                             subtask    method  \
# 0  0.324723  0.150661     1  openproblems_bmmc_cite_phase2_mod2  original
#
#     pearson p_value_pearson  spearman p_value_spearman
# 0  0.748051          0.0000  0.429795           0.0000
# ---------------------------------
# Epoch 1/500
# Train RMSE: 0.3681
# Val RMSE: 0.3060, Val MAE: 0.1334
# Test RMSE: 0.3766, Test MAE: 0.1765
# ---------------------------------
# Model saved at epoch 1 with val RMSE 0.3060
# Patience grace period: 40
# ---------------------------------
# Epoch 2/500
# Train RMSE: 0.3110
# Val RMSE: 0.2834, Val MAE: 0.1265
# Test RMSE: 0.3544, Test MAE: 0.1668
# ---------------------------------
# Model saved at epoch 2 with val RMSE 0.2834
# Patience grace period: 40
# ---------------------------------
# Epoch 3/500
# Train RMSE: 0.2910
# Val RMSE: 0.2718, Val MAE: 0.1204
# Test RMSE: 0.3461, Test MAE: 0.1603
# ---------------------------------
# Model saved at epoch 3 with val RMSE 0.2718
# Patience grace period: 40
# ---------------------------------
# Epoch 4/500
# Train RMSE: 0.2813
# Val RMSE: 0.2677, Val MAE: 0.1185
# Test RMSE: 0.3442, Test MAE: 0.1582
# ---------------------------------
# Model saved at epoch 4 with val RMSE 0.2677
# Patience grace period: 40
# ---------------------------------
# Epoch 5/500
# Train RMSE: 0.2758
# Val RMSE: 0.2649, Val MAE: 0.1171
# Test RMSE: 0.3427, Test MAE: 0.1564
# ---------------------------------
# Model saved at epoch 5 with val RMSE 0.2649
# Patience grace period: 40
# ---------------------------------
# Epoch 6/500
# Train RMSE: 0.2717
# Val RMSE: 0.2624, Val MAE: 0.1159
# Test RMSE: 0.3404, Test MAE: 0.1547
# ---------------------------------
# Model saved at epoch 6 with val RMSE 0.2624
# Patience grace period: 40
# ---------------------------------
# Epoch 7/500
# Train RMSE: 0.2686
# Val RMSE: 0.2603, Val MAE: 0.1153
# Test RMSE: 0.3382, Test MAE: 0.1537
# ---------------------------------
# Model saved at epoch 7 with val RMSE 0.2603
# Patience grace period: 40
# ---------------------------------
# Epoch 8/500
# Train RMSE: 0.2659
# Val RMSE: 0.2586, Val MAE: 0.1145
# Test RMSE: 0.3362, Test MAE: 0.1529
# ---------------------------------
# Model saved at epoch 8 with val RMSE 0.2586
# Patience grace period: 40
# ---------------------------------
# Epoch 9/500
# Train RMSE: 0.2638
# Val RMSE: 0.2574, Val MAE: 0.1135
# Test RMSE: 0.3361, Test MAE: 0.1521
# ---------------------------------
# Model saved at epoch 9 with val RMSE 0.2574
# Patience grace period: 40
# ---------------------------------
# Epoch 10/500
# Train RMSE: 0.2620
# Val RMSE: 0.2564, Val MAE: 0.1126
# Test RMSE: 0.3359, Test MAE: 0.1515
# ---------------------------------
# Model saved at epoch 10 with val RMSE 0.2564
# Patience grace period: 40
# ---------------------------------
# Epoch 11/500
# Train RMSE: 0.2607
# Val RMSE: 0.2557, Val MAE: 0.1118
# Test RMSE: 0.3359, Test MAE: 0.1510
# ---------------------------------
# Model saved at epoch 11 with val RMSE 0.2557
# Patience grace period: 40
# ---------------------------------
# Epoch 12/500
# Train RMSE: 0.2596
# Val RMSE: 0.2551, Val MAE: 0.1116
# Test RMSE: 0.3347, Test MAE: 0.1506
# ---------------------------------
# Model saved at epoch 12 with val RMSE 0.2551
# Patience grace period: 40
# ---------------------------------
# Epoch 13/500
# Train RMSE: 0.2587
# Val RMSE: 0.2546, Val MAE: 0.1109
# Test RMSE: 0.3348, Test MAE: 0.1501
# ---------------------------------
# Model saved at epoch 13 with val RMSE 0.2546
# Patience grace period: 40
# ---------------------------------
# Epoch 14/500
# Train RMSE: 0.2579
# Val RMSE: 0.2541, Val MAE: 0.1108
# Test RMSE: 0.3338, Test MAE: 0.1499
# ---------------------------------
# Model saved at epoch 14 with val RMSE 0.2541
# Patience grace period: 40
# ---------------------------------
# Epoch 15/500
# Train RMSE: 0.2572
# Val RMSE: 0.2537, Val MAE: 0.1106
# Test RMSE: 0.3332, Test MAE: 0.1497
# ---------------------------------
# Model saved at epoch 15 with val RMSE 0.2537
# Patience grace period: 40
# ---------------------------------
# Epoch 16/500
# Train RMSE: 0.2566
# Val RMSE: 0.2534, Val MAE: 0.1105
# Test RMSE: 0.3322, Test MAE: 0.1496
# ---------------------------------
# Model saved at epoch 16 with val RMSE 0.2534
# Patience grace period: 40
# ---------------------------------
# Epoch 17/500
# Train RMSE: 0.2561
# Val RMSE: 0.2531, Val MAE: 0.1101
# Test RMSE: 0.3319, Test MAE: 0.1493
# ---------------------------------
# Model saved at epoch 17 with val RMSE 0.2531
# Patience grace period: 40
# ---------------------------------
# Epoch 18/500
# Train RMSE: 0.2556
# Val RMSE: 0.2528, Val MAE: 0.1100
# Test RMSE: 0.3315, Test MAE: 0.1491
# ---------------------------------
# Model saved at epoch 18 with val RMSE 0.2528
# Patience grace period: 40
# ---------------------------------
# Epoch 19/500
# Train RMSE: 0.2552
# Val RMSE: 0.2526, Val MAE: 0.1102
# Test RMSE: 0.3303, Test MAE: 0.1492
# ---------------------------------
# Model saved at epoch 19 with val RMSE 0.2526
# Patience grace period: 40
# ---------------------------------
# Epoch 20/500
# Train RMSE: 0.2548
# Val RMSE: 0.2523, Val MAE: 0.1099
# Test RMSE: 0.3303, Test MAE: 0.1490
# ---------------------------------
# Model saved at epoch 20 with val RMSE 0.2523
# Patience grace period: 40
# ---------------------------------
# Epoch 21/500
# Train RMSE: 0.2544
# Val RMSE: 0.2521, Val MAE: 0.1096
# Test RMSE: 0.3299, Test MAE: 0.1491
# ---------------------------------
# Model saved at epoch 21 with val RMSE 0.2521
# Patience grace period: 40
# ---------------------------------
# Epoch 22/500
# Train RMSE: 0.2541
# Val RMSE: 0.2519, Val MAE: 0.1097
# Test RMSE: 0.3292, Test MAE: 0.1491
# ---------------------------------
# Model saved at epoch 22 with val RMSE 0.2519
# Patience grace period: 40
# ---------------------------------
# Epoch 23/500
# Train RMSE: 0.2538
# Val RMSE: 0.2517, Val MAE: 0.1091
# Test RMSE: 0.3297, Test MAE: 0.1487
# ---------------------------------
# Model saved at epoch 23 with val RMSE 0.2517
# Patience grace period: 40
# ---------------------------------
# Epoch 24/500
# Train RMSE: 0.2535
# Val RMSE: 0.2515, Val MAE: 0.1091
# Test RMSE: 0.3296, Test MAE: 0.1488
# ---------------------------------
# Model saved at epoch 24 with val RMSE 0.2515
# Patience grace period: 40
# ---------------------------------
# Epoch 25/500
# Train RMSE: 0.2533
# Val RMSE: 0.2514, Val MAE: 0.1095
# Test RMSE: 0.3282, Test MAE: 0.1490
# ---------------------------------
# Model saved at epoch 25 with val RMSE 0.2514
# Patience grace period: 40
# ---------------------------------
# Epoch 26/500
# Train RMSE: 0.2531
# Val RMSE: 0.2513, Val MAE: 0.1090
# Test RMSE: 0.3288, Test MAE: 0.1487
# ---------------------------------
# Model saved at epoch 26 with val RMSE 0.2513
# Patience grace period: 40
# ---------------------------------
# Epoch 27/500
# Train RMSE: 0.2528
# Val RMSE: 0.2511, Val MAE: 0.1090
# Test RMSE: 0.3285, Test MAE: 0.1488
# ---------------------------------
# Model saved at epoch 27 with val RMSE 0.2511
# Patience grace period: 40
# ---------------------------------
# Epoch 28/500
# Train RMSE: 0.2526
# Val RMSE: 0.2510, Val MAE: 0.1087
# Test RMSE: 0.3288, Test MAE: 0.1488
# ---------------------------------
# Model saved at epoch 28 with val RMSE 0.2510
# Patience grace period: 40
# ---------------------------------
# Epoch 29/500
# Train RMSE: 0.2524
# Val RMSE: 0.2509, Val MAE: 0.1085
# Test RMSE: 0.3286, Test MAE: 0.1489
# ---------------------------------
# Model saved at epoch 29 with val RMSE 0.2509
# Patience grace period: 40
# ---------------------------------
# Epoch 30/500
# Train RMSE: 0.2523
# Val RMSE: 0.2508, Val MAE: 0.1087
# Test RMSE: 0.3280, Test MAE: 0.1489
# ---------------------------------
# Model saved at epoch 30 with val RMSE 0.2508
# Patience grace period: 39
# ---------------------------------
# Epoch 31/500
# Train RMSE: 0.2521
# Val RMSE: 0.2507, Val MAE: 0.1084
# ...
# Test RMSE: 0.3264, Test MAE: 0.1497
# ---------------------------------
# Model saved at epoch 71 with val RMSE 0.2494
# Patience grace period: 40
# ---------------------------------
# Epoch 72/500
# Train RMSE: 0.2489
# Val RMSE: 0.2494, Val MAE: 0.1076
# Test RMSE: 0.3254, Test MAE: 0.1502
# ---------------------------------
# Patience grace period: 38
# ---------------------------------
# Epoch 73/500
# Train RMSE: 0.2488
# Val RMSE: 0.2495, Val MAE: 0.1078
# Test RMSE: 0.3252, Test MAE: 0.1501
# ---------------------------------
# Patience grace period: 36
# ---------------------------------
# Epoch 74/500
# Train RMSE: 0.2488
# Val RMSE: 0.2494, Val MAE: 0.1075
# Test RMSE: 0.3256, Test MAE: 0.1500
# ---------------------------------
# Patience grace period: 35
# ---------------------------------
# Epoch 75/500
# Train RMSE: 0.2487
# Val RMSE: 0.2494, Val MAE: 0.1072
# Test RMSE: 0.3261, Test MAE: 0.1495
# ---------------------------------
# Model saved at epoch 75 with val RMSE 0.2494
# Patience grace period: 34
# ---------------------------------
# Epoch 76/500
# Train RMSE: 0.2487
# Val RMSE: 0.2494, Val MAE: 0.1075
# Test RMSE: 0.3255, Test MAE: 0.1497
# ---------------------------------
# Patience grace period: 32
# ---------------------------------
# Epoch 77/500
# Train RMSE: 0.2487
# Val RMSE: 0.2493, Val MAE: 0.1070
# Test RMSE: 0.3260, Test MAE: 0.1496
# ---------------------------------
# Model saved at epoch 77 with val RMSE 0.2493
# Patience grace period: 31
# ---------------------------------
# Epoch 78/500
# Train RMSE: 0.2486
# Val RMSE: 0.2492, Val MAE: 0.1068
# Test RMSE: 0.3265, Test MAE: 0.1495
# ---------------------------------
# Model saved at epoch 78 with val RMSE 0.2492
# Patience grace period: 40
# ---------------------------------
# Epoch 79/500
# Train RMSE: 0.2486
# Val RMSE: 0.2494, Val MAE: 0.1074
# Test RMSE: 0.3253, Test MAE: 0.1499
# ---------------------------------
# Patience grace period: 38
# ---------------------------------
# Epoch 80/500
# Train RMSE: 0.2485
# Val RMSE: 0.2492, Val MAE: 0.1072
# Test RMSE: 0.3254, Test MAE: 0.1498
# ---------------------------------
# Model saved at epoch 80 with val RMSE 0.2492
# Patience grace period: 37
# ---------------------------------
# Epoch 81/500
# Train RMSE: 0.2485
# Val RMSE: 0.2492, Val MAE: 0.1072
# Test RMSE: 0.3255, Test MAE: 0.1497
# ---------------------------------
# Patience grace period: 35
# ---------------------------------
# Epoch 82/500
# Train RMSE: 0.2485
# Val RMSE: 0.2491, Val MAE: 0.1067
# Test RMSE: 0.3262, Test MAE: 0.1496
# ---------------------------------
# Model saved at epoch 82 with val RMSE 0.2491
# Patience grace period: 40
# ---------------------------------
# Epoch 83/500
# Train RMSE: 0.2484
# Val RMSE: 0.2492, Val MAE: 0.1069
# Test RMSE: 0.3257, Test MAE: 0.1495
# ---------------------------------
# Patience grace period: 38
# ---------------------------------
# Epoch 84/500
# Train RMSE: 0.2484
# Val RMSE: 0.2492, Val MAE: 0.1070
# Test RMSE: 0.3257, Test MAE: 0.1496
# ---------------------------------
# Patience grace period: 37
# ---------------------------------
# Epoch 85/500
# Train RMSE: 0.2483
# Val RMSE: 0.2492, Val MAE: 0.1072
# Test RMSE: 0.3253, Test MAE: 0.1495
# ---------------------------------
# Patience grace period: 35
# ---------------------------------
# Epoch 86/500
# Train RMSE: 0.2483
# Val RMSE: 0.2491, Val MAE: 0.1065
# Test RMSE: 0.3264, Test MAE: 0.1493
# ---------------------------------
# Model saved at epoch 86 with val RMSE 0.2491
# Patience grace period: 34
# ---------------------------------
# Epoch 87/500
# Train RMSE: 0.2483
# Val RMSE: 0.2491, Val MAE: 0.1068
# Test RMSE: 0.3261, Test MAE: 0.1493
# ---------------------------------
# Patience grace period: 32
# ---------------------------------
# Epoch 88/500
# Train RMSE: 0.2482
# Val RMSE: 0.2490, Val MAE: 0.1066
# Test RMSE: 0.3263, Test MAE: 0.1494
# ---------------------------------
# Model saved at epoch 88 with val RMSE 0.2490
# Patience grace period: 31
# ---------------------------------
# Epoch 89/500
# Train RMSE: 0.2482
# Val RMSE: 0.2490, Val MAE: 0.1062
# Test RMSE: 0.3265, Test MAE: 0.1491
# ---------------------------------
# Model saved at epoch 89 with val RMSE 0.2490
# Patience grace period: 29
# ---------------------------------
# Epoch 90/500
# Train RMSE: 0.2482
# Val RMSE: 0.2491, Val MAE: 0.1066
# Test RMSE: 0.3257, Test MAE: 0.1493
# ---------------------------------
# Patience grace period: 27
# ---------------------------------
# Epoch 91/500
# Train RMSE: 0.2481
# Val RMSE: 0.2491, Val MAE: 0.1071
# Test RMSE: 0.3253, Test MAE: 0.1496
# ---------------------------------
# Patience grace period: 25
# ---------------------------------
# Epoch 92/500
# Train RMSE: 0.2481
# Val RMSE: 0.2491, Val MAE: 0.1066
# Test RMSE: 0.3262, Test MAE: 0.1493
# ---------------------------------
# Patience grace period: 24
# ---------------------------------
# Epoch 93/500
# Train RMSE: 0.2481
# Val RMSE: 0.2491, Val MAE: 0.1070
# Test RMSE: 0.3249, Test MAE: 0.1498
# ---------------------------------
# Patience grace period: 22
# ---------------------------------
# Epoch 94/500
# Train RMSE: 0.2480
# Val RMSE: 0.2490, Val MAE: 0.1063
# Test RMSE: 0.3268, Test MAE: 0.1488
# ---------------------------------
# Patience grace period: 21
# ---------------------------------
# Epoch 95/500
# Train RMSE: 0.2480
# Val RMSE: 0.2490, Val MAE: 0.1065
# Test RMSE: 0.3262, Test MAE: 0.1492
# ---------------------------------
# Model saved at epoch 95 with val RMSE 0.2490
# Patience grace period: 40
# ---------------------------------
# Epoch 96/500
# Train RMSE: 0.2480
# Val RMSE: 0.2490, Val MAE: 0.1067
# Test RMSE: 0.3257, Test MAE: 0.1496
# ---------------------------------
# Model saved at epoch 96 with val RMSE 0.2490
# Patience grace period: 39
# ---------------------------------
# Epoch 97/500
# Train RMSE: 0.2480
# Val RMSE: 0.2489, Val MAE: 0.1063
# Test RMSE: 0.3263, Test MAE: 0.1495
# ---------------------------------
# Model saved at epoch 97 with val RMSE 0.2489
# Patience grace period: 38
# ---------------------------------
# Epoch 98/500
# Train RMSE: 0.2479
# Val RMSE: 0.2489, Val MAE: 0.1061
# Test RMSE: 0.3273, Test MAE: 0.1491
# ---------------------------------
# Model saved at epoch 98 with val RMSE 0.2489
# Patience grace period: 37
# ---------------------------------
# Epoch 99/500
# Train RMSE: 0.2479
# Val RMSE: 0.2489, Val MAE: 0.1059
# Test RMSE: 0.3270, Test MAE: 0.1487
# ---------------------------------
# Patience grace period: 35
# ---------------------------------
# Epoch 100/500
# Train RMSE: 0.2479
# Val RMSE: 0.2489, Val MAE: 0.1063
# Test RMSE: 0.3265, Test MAE: 0.1493
# ---------------------------------
# Model saved at epoch 100 with val RMSE 0.2489
# Patience grace period: 40
# ---------------------------------
# Epoch 101/500
# Train RMSE: 0.2478
# Val RMSE: 0.2489, Val MAE: 0.1062
# Test RMSE: 0.3267, Test MAE: 0.1491
# ---------------------------------
# Patience grace period: 38
# ---------------------------------
# Epoch 102/500
# Train RMSE: 0.2478
# Val RMSE: 0.2488, Val MAE: 0.1059
# Test RMSE: 0.3267, Test MAE: 0.1490
# ---------------------------------
# Model saved at epoch 102 with val RMSE 0.2488
# Patience grace period: 37
# ---------------------------------
# Epoch 103/500
# Train RMSE: 0.2478
# Val RMSE: 0.2489, Val MAE: 0.1058
# Test RMSE: 0.3272, Test MAE: 0.1488
# ---------------------------------
# Patience grace period: 35
# ---------------------------------
# Epoch 104/500
# Train RMSE: 0.2478
# Val RMSE: 0.2491, Val MAE: 0.1069
# Test RMSE: 0.3253, Test MAE: 0.1496
# ---------------------------------
# Patience grace period: 33
# ---------------------------------
# Epoch 105/500
# Train RMSE: 0.2477
# Val RMSE: 0.2490, Val MAE: 0.1065
# Test RMSE: 0.3257, Test MAE: 0.1493
# ---------------------------------
# Patience grace period: 32
# ---------------------------------
# Epoch 106/500
# Train RMSE: 0.2477
# Val RMSE: 0.2489, Val MAE: 0.1065
# Test RMSE: 0.3257, Test MAE: 0.1494
# ---------------------------------
# Patience grace period: 31
# ---------------------------------
# Epoch 107/500
# Train RMSE: 0.2477
# Val RMSE: 0.2489, Val MAE: 0.1066
# Test RMSE: 0.3257, Test MAE: 0.1494
# ---------------------------------
# Patience grace period: 29
# ---------------------------------
# Epoch 108/500
# Train RMSE: 0.2476
# Val RMSE: 0.2488, Val MAE: 0.1061
# Test RMSE: 0.3261, Test MAE: 0.1493
# ---------------------------------
# Model saved at epoch 108 with val RMSE 0.2488
# Patience grace period: 28
# ---------------------------------
# Epoch 109/500
# Train RMSE: 0.2476
# Val RMSE: 0.2488, Val MAE: 0.1065
# Test RMSE: 0.3254, Test MAE: 0.1495
# ---------------------------------
# Patience grace period: 26
# ---------------------------------
# Epoch 110/500
# Train RMSE: 0.2476
# Val RMSE: 0.2489, Val MAE: 0.1067
# Test RMSE: 0.3259, Test MAE: 0.1493
# ---------------------------------
# Patience grace period: 24
# ---------------------------------
# Epoch 111/500
# Train RMSE: 0.2476
# Val RMSE: 0.2489, Val MAE: 0.1068
# Test RMSE: 0.3251, Test MAE: 0.1497
# ---------------------------------
# Patience grace period: 23
# ---------------------------------
# Epoch 112/500
# Train RMSE: 0.2475
# Val RMSE: 0.2489, Val MAE: 0.1068
# Test RMSE: 0.3252, Test MAE: 0.1496
# ---------------------------------
# Patience grace period: 22
# ---------------------------------
# Epoch 113/500
# Train RMSE: 0.2475
# Val RMSE: 0.2488, Val MAE: 0.1064
# Test RMSE: 0.3258, Test MAE: 0.1493
# ---------------------------------
# Patience grace period: 21
# ---------------------------------
# Epoch 114/500
# Train RMSE: 0.2475
# Val RMSE: 0.2488, Val MAE: 0.1060
# Test RMSE: 0.3265, Test MAE: 0.1491
# ---------------------------------
# Model saved at epoch 114 with val RMSE 0.2488
# Patience grace period: 40
# ---------------------------------
# Epoch 115/500
# Train RMSE: 0.2475
# Val RMSE: 0.2489, Val MAE: 0.1067
# Test RMSE: 0.3255, Test MAE: 0.1496
# ---------------------------------
# Patience grace period: 38
# ---------------------------------
# Epoch 116/500
# Train RMSE: 0.2474
# Val RMSE: 0.2489, Val MAE: 0.1068
# Test RMSE: 0.3250, Test MAE: 0.1494
# ---------------------------------
# Patience grace period: 36
# ---------------------------------
# Epoch 117/500
# Train RMSE: 0.2474
# Val RMSE: 0.2488, Val MAE: 0.1063
# Test RMSE: 0.3260, Test MAE: 0.1492
# ---------------------------------
# Patience grace period: 35
# ---------------------------------
# Epoch 118/500
# Train RMSE: 0.2474
# Val RMSE: 0.2488, Val MAE: 0.1057
# Test RMSE: 0.3273, Test MAE: 0.1488
# ---------------------------------
# Patience grace period: 34
# ---------------------------------
# Epoch 119/500
# Train RMSE: 0.2474
# Val RMSE: 0.2489, Val MAE: 0.1063
# Test RMSE: 0.3260, Test MAE: 0.1493
# ---------------------------------
# Patience grace period: 32
# ---------------------------------
# Epoch 120/500
# Train RMSE: 0.2474
# Val RMSE: 0.2488, Val MAE: 0.1062
# Test RMSE: 0.3262, Test MAE: 0.1491
# ---------------------------------
# Patience grace period: 31
# ---------------------------------
# Epoch 121/500
# Train RMSE: 0.2473
# Val RMSE: 0.2488, Val MAE: 0.1057
# Test RMSE: 0.3273, Test MAE: 0.1487
# ---------------------------------
# Model saved at epoch 121 with val RMSE 0.2488
# Patience grace period: 30
# ---------------------------------
# Epoch 122/500
# Train RMSE: 0.2473
# Val RMSE: 0.2489, Val MAE: 0.1062
# Test RMSE: 0.3265, Test MAE: 0.1492
# ---------------------------------
# Patience grace period: 28
# ---------------------------------
# Epoch 123/500
# Train RMSE: 0.2473
# Val RMSE: 0.2487, Val MAE: 0.1054
# Test RMSE: 0.3279, Test MAE: 0.1485
# ---------------------------------
# Model saved at epoch 123 with val RMSE 0.2487
# Patience grace period: 27
# ---------------------------------
# Epoch 124/500
# Train RMSE: 0.2473
# Val RMSE: 0.2488, Val MAE: 0.1062
# Test RMSE: 0.3260, Test MAE: 0.1493
# ---------------------------------
# Patience grace period: 25
# ---------------------------------
# Epoch 125/500
# Train RMSE: 0.2472
# Val RMSE: 0.2489, Val MAE: 0.1064
# Test RMSE: 0.3255, Test MAE: 0.1493
# ---------------------------------
# Patience grace period: 23
# ---------------------------------
# Epoch 126/500
# Train RMSE: 0.2472
# Val RMSE: 0.2488, Val MAE: 0.1064
# Test RMSE: 0.3259, Test MAE: 0.1495
# ---------------------------------
# Patience grace period: 22
# ---------------------------------
# Epoch 127/500
# Train RMSE: 0.2472
# Val RMSE: 0.2489, Val MAE: 0.1064
# Test RMSE: 0.3258, Test MAE: 0.1494
# ---------------------------------
# Patience grace period: 20
# ---------------------------------
# Epoch 128/500
# Train RMSE: 0.2472
# Val RMSE: 0.2488, Val MAE: 0.1059
# Test RMSE: 0.3273, Test MAE: 0.1491
# ---------------------------------
# Patience grace period: 19
# ---------------------------------
# Epoch 129/500
# Train RMSE: 0.2472
# Val RMSE: 0.2488, Val MAE: 0.1057
# Test RMSE: 0.3269, Test MAE: 0.1489
# ---------------------------------
# Patience grace period: 18
# ---------------------------------
# Epoch 130/500
# Train RMSE: 0.2472
# Val RMSE: 0.2488, Val MAE: 0.1062
# Test RMSE: 0.3262, Test MAE: 0.1492
# ---------------------------------
# Patience grace period: 16
# ---------------------------------
# Epoch 131/500
# Train RMSE: 0.2471
# Val RMSE: 0.2488, Val MAE: 0.1061
# Test RMSE: 0.3262, Test MAE: 0.1490
# ---------------------------------
# Patience grace period: 15
# ---------------------------------
# Epoch 132/500
# Train RMSE: 0.2471
# Val RMSE: 0.2488, Val MAE: 0.1065
# Test RMSE: 0.3257, Test MAE: 0.1495
# ---------------------------------
# Patience grace period: 13
# ---------------------------------
# Epoch 133/500
# Train RMSE: 0.2471
# Val RMSE: 0.2491, Val MAE: 0.1067
# Test RMSE: 0.3256, Test MAE: 0.1493
# ---------------------------------
# Patience grace period: 11
# ---------------------------------
# Epoch 134/500
# Train RMSE: 0.2471
# Val RMSE: 0.2488, Val MAE: 0.1063
# Test RMSE: 0.3261, Test MAE: 0.1493
# ---------------------------------
# Patience grace period: 10
# ---------------------------------
# Epoch 135/500
# Train RMSE: 0.2471
# Val RMSE: 0.2487, Val MAE: 0.1061
# Test RMSE: 0.3262, Test MAE: 0.1493
# ---------------------------------
# Patience grace period: 9
# ---------------------------------
# Epoch 136/500
# Train RMSE: 0.2470
# Val RMSE: 0.2487, Val MAE: 0.1060
# Test RMSE: 0.3267, Test MAE: 0.1492
# ---------------------------------
# Patience grace period: 7
# ---------------------------------
# Epoch 137/500
# Train RMSE: 0.2470
# Val RMSE: 0.2488, Val MAE: 0.1062
# Test RMSE: 0.3263, Test MAE: 0.1492
# ---------------------------------
# Patience grace period: 5
# ---------------------------------
# Epoch 138/500
# Train RMSE: 0.2470
# Val RMSE: 0.2487, Val MAE: 0.1057
# Test RMSE: 0.3272, Test MAE: 0.1489
# ---------------------------------
# Model saved at epoch 138 with val RMSE 0.2487
# Patience grace period: 4
# ---------------------------------
# Epoch 139/500
# Train RMSE: 0.2470
# Val RMSE: 0.2488, Val MAE: 0.1063
# Test RMSE: 0.3260, Test MAE: 0.1493
# ---------------------------------
# Patience grace period: 2
# ---------------------------------
# Epoch 140/500
# Train RMSE: 0.2470
# Val RMSE: 0.2490, Val MAE: 0.1069
# Test RMSE: 0.3253, Test MAE: 0.1496
# ---------------------------------
# Patience grace period: 0
# Early stopping triggered at epoch 140
# Final Test RMSE: 0.3272, Final Test MAE: 0.1489
# <ipython-input-3-2a228d64b832>:126: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   self.model.load_state_dict(torch.load(os.path.join(save_dir, 'best_model.pth')))
# Pearson Corr: 0.7473230658878236
# Spearman Corr: 0.42895829723676604
# p-rmse: 0.3272310067355786
#        rmse       mae  seed                             subtask    method  \
# 0  0.327231  0.148864     5  openproblems_bmmc_cite_phase2_mod2  original
#
#     pearson p_value_pearson  spearman p_value_spearman
# 0  0.747323          0.0000  0.428958           0.0000

# %%
config_hierachical_PROTEIN = {
    "subtask": "openproblems_bmmc_cite_phase2_mod2",
    "batch_size": 520,
    "act": "relu",
    "conv_flow": ["gat"],
    "agg_flow": [None],
    "device": "cuda",
    "learning_rate": 0.000064,
    "hidden_size": 280,
    "num_heads": 6,
    "n_neigbours": 10,
    "metric": "euclidean",
    "n_components": 1200,
    "dropout_rate": 0.2,
    "num_epochs": 500,
    "seed": 1,
    "es_patience": 40,
    "es_min_delta": 0.0001,
    "es_rate_threshold": 0.00002,
    "layer_dim_ex": 3,
    "verbose": True,
    "sample": True,
    "preprocessing_type": "None",
    "variant": "original",
    "num_clusters": 10
}

pipeline(**config_hierachical_PROTEIN)
# Out:
# Initializing pipeline...
# [INFO][2025-04-16 05:06:03,728][dance][download_file] Downloading: /content/data/openproblems_bmmc_cite_phase2_mod2.zip Bytes: 625,243,451
# 100%|██████████| 596M/596M [00:29<00:00, 21.0MB/s]
# [INFO][2025-04-16 05:06:33,507][dance][unzip_file] Unzipping /content/data/openproblems_bmmc_cite_phase2_mod2.zip
# [INFO][2025-04-16 05:06:36,849][dance][delete_file] Deleting /content/data/openproblems_bmmc_cite_phase2_mod2.zip
# [INFO][2025-04-16 05:06:36,950][dance][_load_raw_data] Loading /content/data/openproblems_bmmc_cite_phase2_mod2/openproblems_bmmc_cite_phase2_mod2.censor_dataset.output_train_mod1.h5ad
# [INFO][2025-04-16 05:06:37,665][dance][_load_raw_data] Loading /content/data/openproblems_bmmc_cite_phase2_mod2/openproblems_bmmc_cite_phase2_mod2.censor_dataset.output_train_mod2.h5ad
# [INFO][2025-04-16 05:06:45,366][dance][_load_raw_data] Loading /content/data/openproblems_bmmc_cite_phase2_mod2/openproblems_bmmc_cite_phase2_mod2.censor_dataset.output_test_mod1.h5ad
# [INFO][2025-04-16 05:06:45,392][dance][_load_raw_data] Loading /content/data/openproblems_bmmc_cite_phase2_mod2/openproblems_bmmc_cite_phase2_mod2.censor_dataset.output_test_mod2.h5ad
# [INFO][2025-04-16 05:06:45,611][dance][_maybe_preprocess] Preprocessing done.
# /usr/local/lib/python3.11/dist-packages/mudata/_core/mudata.py:1531: FutureWarning: From 0.4 .update() will not pull obs/var columns from individual modalities by default anymore. Set mudata.set_options(pull_on_update=False) to adopt the new behaviour, which will become the default. Use new pull_obs/pull_var and push_obs/push_var methods for more flexibility.
#   self._update_attr("var", axis=0, join_common=join_common)
# /usr/local/lib/python3.11/dist-packages/mudata/_core/mudata.py:931: UserWarning: Cannot join columns with the same name because var_names are intersecting.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/mudata/_core/mudata.py:1429: FutureWarning: From 0.4 .update() will not pull obs/var columns from individual modalities by default anymore. Set mudata.set_options(pull_on_update=False) to adopt the new behaviour, which will become the default. Use new pull_obs/pull_var and push_obs/push_var methods for more flexibility.
#   self._update_attr("obs", axis=1, join_common=join_common)
# /usr/local/lib/python3.11/dist-packages/mudata/_core/mudata.py:1558: UserWarning: Modality names will be prepended to var_names since there are identical var_names in different modalities.
#   warnings.warn(
# [INFO][2025-04-16 05:06:54,908][dance][set_config_from_dict] Setting config 'feature_mod' to 'mod1'
# [INFO][2025-04-16 05:06:54,909][dance][set_config_from_dict] Setting config 'label_mod' to 'mod2'
# [INFO][2025-04-16 05:06:54,910][dance][load_data] Raw data loaded:
# Data object that wraps (.data):
# MuData object with n_obs × n_vars = 67175 × 14087
#   uns:	'dance_config'
#   2 modalities
#     mod1:	67175 x 134
#       obs:	'batch'
#       layers:	'counts'
#     mod2:	67175 x 13953
#       obs:	'batch'
#       layers:	'counts'
# [INFO][2025-04-16 05:06:55,041][dance][wrapped_func] Took 0:00:53.090013 to load and process data.
# Performing data processing using GraphCreator...
# Data processing using GraphCreator complete and saved.
# ---------------------------------
# Epoch 1/500
# Train RMSE: 0.3758
# Val RMSE: 0.3258, Val MAE: 0.1334
# Test RMSE: 0.4033, Test MAE: 0.1778
# ---------------------------------
# Model saved at epoch 1 with val RMSE 0.3258
# Patience grace period: 40
# ---------------------------------
# Epoch 2/500
# Train RMSE: 0.3288
# Val RMSE: 0.2959, Val MAE: 0.1266
# Test RMSE: 0.3712, Test MAE: 0.1674
# ---------------------------------
# Model saved at epoch 2 with val RMSE 0.2959
# Patience grace period: 40
# ---------------------------------
# Epoch 3/500
# Train RMSE: 0.3057
# Val RMSE: 0.2800, Val MAE: 0.1201
# Test RMSE: 0.3562, Test MAE: 0.1601
# ---------------------------------
# Model saved at epoch 3 with val RMSE 0.2800
# Patience grace period: 40
# ---------------------------------
# Epoch 4/500
# Train RMSE: 0.2923
# Val RMSE: 0.2727, Val MAE: 0.1177
# Test RMSE: 0.3494, Test MAE: 0.1575
# ---------------------------------
# Model saved at epoch 4 with val RMSE 0.2727
# Patience grace period: 40
# ---------------------------------
# Epoch 5/500
# Train RMSE: 0.2841
# Val RMSE: 0.2685, Val MAE: 0.1165
# Test RMSE: 0.3453, Test MAE: 0.1559
# ---------------------------------
# Model saved at epoch 5 with val RMSE 0.2685
# Patience grace period: 40
# ---------------------------------
# Epoch 6/500
# Train RMSE: 0.2781
# Val RMSE: 0.2654, Val MAE: 0.1149
# Test RMSE: 0.3423, Test MAE: 0.1538
# ---------------------------------
# Model saved at epoch 6 with val RMSE 0.2654
# Patience grace period: 40
# ---------------------------------
# Epoch 7/500
# Train RMSE: 0.2734
# Val RMSE: 0.2629, Val MAE: 0.1136
# Test RMSE: 0.3402, Test MAE: 0.1521
# ---------------------------------
# Model saved at epoch 7 with val RMSE 0.2629
# Patience grace period: 40
# ---------------------------------
# Epoch 8/500
# Train RMSE: 0.2696
# Val RMSE: 0.2609, Val MAE: 0.1120
# Test RMSE: 0.3387, Test MAE: 0.1505
# ---------------------------------
# Model saved at epoch 8 with val RMSE 0.2609
# Patience grace period: 40
# ---------------------------------
# Epoch 9/500
# Train RMSE: 0.2666
# Val RMSE: 0.2594, Val MAE: 0.1108
# Test RMSE: 0.3380, Test MAE: 0.1497
# ---------------------------------
# Model saved at epoch 9 with val RMSE 0.2594
# Patience grace period: 40
# ---------------------------------
# Epoch 10/500
# Train RMSE: 0.2645
# Val RMSE: 0.2581, Val MAE: 0.1101
# Test RMSE: 0.3369, Test MAE: 0.1491
# ---------------------------------
# Model saved at epoch 10 with val RMSE 0.2581
# Patience grace period: 40
# ---------------------------------
# Epoch 11/500
# Train RMSE: 0.2628
# Val RMSE: 0.2571, Val MAE: 0.1098
# Test RMSE: 0.3359, Test MAE: 0.1488
# ---------------------------------
# Model saved at epoch 11 with val RMSE 0.2571
# Patience grace period: 40
# ---------------------------------
# Epoch 12/500
# Train RMSE: 0.2615
# Val RMSE: 0.2563, Val MAE: 0.1096
# Test RMSE: 0.3352, Test MAE: 0.1487
# ---------------------------------
# Model saved at epoch 12 with val RMSE 0.2563
# Patience grace period: 40
# ---------------------------------
# Epoch 13/500
# Train RMSE: 0.2605
# Val RMSE: 0.2559, Val MAE: 0.1086
# Test RMSE: 0.3359, Test MAE: 0.1480
# ---------------------------------
# Model saved at epoch 13 with val RMSE 0.2559
# Patience grace period: 40
# ---------------------------------
# Epoch 14/500
# Train RMSE: 0.2597
# Val RMSE: 0.2553, Val MAE: 0.1087
# Test RMSE: 0.3345, Test MAE: 0.1481
# ---------------------------------
# Model saved at epoch 14 with val RMSE 0.2553
# Patience grace period: 40
# ---------------------------------
# Epoch 15/500
# Train RMSE: 0.2589
# Val RMSE: 0.2550, Val MAE: 0.1079
# Test RMSE: 0.3352, Test MAE: 0.1474
# ---------------------------------
# Model saved at epoch 15 with val RMSE 0.2550
# Patience grace period: 40
# ---------------------------------
# Epoch 16/500
# Train RMSE: 0.2584
# Val RMSE: 0.2547, Val MAE: 0.1076
# Test RMSE: 0.3349, Test MAE: 0.1474
# ---------------------------------
# Model saved at epoch 16 with val RMSE 0.2547
# Patience grace period: 40
# ---------------------------------
# Epoch 17/500
# Train RMSE: 0.2579
# Val RMSE: 0.2541, Val MAE: 0.1085
# Test RMSE: 0.3331, Test MAE: 0.1479
# ---------------------------------
# Model saved at epoch 17 with val RMSE 0.2541
# Patience grace period: 40
# ---------------------------------
# Epoch 18/500
# Train RMSE: 0.2575
# Val RMSE: 0.2539, Val MAE: 0.1080
# Test RMSE: 0.3329, Test MAE: 0.1478
# ---------------------------------
# Model saved at epoch 18 with val RMSE 0.2539
# Patience grace period: 40
# ---------------------------------
# Epoch 19/500
# Train RMSE: 0.2570
# Val RMSE: 0.2535, Val MAE: 0.1083
# Test RMSE: 0.3319, Test MAE: 0.1478
# ---------------------------------
# Model saved at epoch 19 with val RMSE 0.2535
# Patience grace period: 40
# ---------------------------------
# Epoch 20/500
# Train RMSE: 0.2567
# Val RMSE: 0.2533, Val MAE: 0.1080
# Test RMSE: 0.3320, Test MAE: 0.1476
# ---------------------------------
# Model saved at epoch 20 with val RMSE 0.2533
# Patience grace period: 40
# ---------------------------------
# Epoch 21/500
# Train RMSE: 0.2563
# Val RMSE: 0.2531, Val MAE: 0.1077
# Test RMSE: 0.3320, Test MAE: 0.1474
# ---------------------------------
# Model saved at epoch 21 with val RMSE 0.2531
# Patience grace period: 40
# ---------------------------------
# Epoch 22/500
# Train RMSE: 0.2560
# Val RMSE: 0.2530, Val MAE: 0.1073
# Test RMSE: 0.3324, Test MAE: 0.1472
# ---------------------------------
# Model saved at epoch 22 with val RMSE 0.2530
# Patience grace period: 39
# ---------------------------------
# Epoch 23/500
# Train RMSE: 0.2557
# Val RMSE: 0.2527, Val MAE: 0.1077
# Test RMSE: 0.3316, Test MAE: 0.1476
# ---------------------------------
# Model saved at epoch 23 with val RMSE 0.2527
# Patience grace period: 40
# ---------------------------------
# Epoch 24/500
# Train RMSE: 0.2555
# Val RMSE: 0.2525, Val MAE: 0.1075
# Test RMSE: 0.3312, Test MAE: 0.1475
# ---------------------------------
# Model saved at epoch 24 with val RMSE 0.2525
# Patience grace period: 40
# ---------------------------------
# Epoch 25/500
# Train RMSE: 0.2552
# Val RMSE: 0.2525, Val MAE: 0.1069
# Test RMSE: 0.3318, Test MAE: 0.1473
# ---------------------------------
# Patience grace period: 38
# ---------------------------------
# Epoch 26/500
# Train RMSE: 0.2550
# Val RMSE: 0.2522, Val MAE: 0.1077
# Test RMSE: 0.3306, Test MAE: 0.1479
# ---------------------------------
# Model saved at epoch 26 with val RMSE 0.2522
# Patience grace period: 40
# ---------------------------------
# Epoch 27/500
# Train RMSE: 0.2548
# Val RMSE: 0.2521, Val MAE: 0.1074
# Test RMSE: 0.3308, Test MAE: 0.1477
# ---------------------------------
# Model saved at epoch 27 with val RMSE 0.2521
# Patience grace period: 40
# ---------------------------------
# Epoch 28/500
# Train RMSE: 0.2545
# Val RMSE: 0.2521, Val MAE: 0.1070
# Test RMSE: 0.3311, Test MAE: 0.1476
# ---------------------------------
# Model saved at epoch 28 with val RMSE 0.2521
# Patience grace period: 39
# ---------------------------------
# Epoch 29/500
# Train RMSE: 0.2544
# Val RMSE: 0.2518, Val MAE: 0.1074
# Test RMSE: 0.3300, Test MAE: 0.1478
# ---------------------------------
# Model saved at epoch 29 with val RMSE 0.2518
# Patience grace period: 40
# ---------------------------------
# Epoch 30/500
# Train RMSE: 0.2542
# Val RMSE: 0.2517, Val MAE: 0.1074
# Test RMSE: 0.3298, Test MAE: 0.1480
# ---------------------------------
# Model saved at epoch 30 with val RMSE 0.2517
# Patience grace period: 39
# ---------------------------------
# Epoch 31/500
# Train RMSE: 0.2540
# Val RMSE: 0.2517, Val MAE: 0.1070
# Test RMSE: 0.3305, Test MAE: 0.1476
# ---------------------------------
# Model saved at epoch 31 with val RMSE 0.2517
# Patience grace period: 40
# ---------------------------------
# Epoch 32/500
# Train RMSE: 0.2538
# Val RMSE: 0.2515, Val MAE: 0.1072
# Test RMSE: 0.3299, Test MAE: 0.1479
# ---------------------------------
# Model saved at epoch 32 with val RMSE 0.2515
# Patience grace period: 40
# ---------------------------------
# Epoch 33/500
# Train RMSE: 0.2537
# Val RMSE: 0.2513, Val MAE: 0.1081
# Test RMSE: 0.3280, Test MAE: 0.1486
# ---------------------------------
# Model saved at epoch 33 with val RMSE 0.2513
# Patience grace period: 40
# ---------------------------------
# Epoch 34/500
# Train RMSE: 0.2535
# Val RMSE: 0.2514, Val MAE: 0.1073
# Test RMSE: 0.3291, Test MAE: 0.1482
# ---------------------------------
# Patience grace period: 38
# ---------------------------------
# Epoch 35/500
# Train RMSE: 0.2534
# Val RMSE: 0.2512, Val MAE: 0.1075
# Test RMSE: 0.3291, Test MAE: 0.1484
# ---------------------------------
# Model saved at epoch 35 with val RMSE 0.2512
# Patience grace period: 40
# ---------------------------------
# Epoch 36/500
# Train RMSE: 0.2533
# Val RMSE: 0.2511, Val MAE: 0.1074
# Test RMSE: 0.3287, Test MAE: 0.1481
# ---------------------------------
# Model saved at epoch 36 with val RMSE 0.2511
# Patience grace period: 39
# ---------------------------------
# Epoch 37/500
# Train RMSE: 0.2531
# Val RMSE: 0.2511, Val MAE: 0.1078
# Test RMSE: 0.3280, Test MAE: 0.1486
# ---------------------------------
# Model saved at epoch 37 with val RMSE 0.2511
# Patience grace period: 40
# ---------------------------------
# Epoch 38/500
# Train RMSE: 0.2530
# Val RMSE: 0.2511, Val MAE: 0.1070
# Test RMSE: 0.3289, Test MAE: 0.1482
# ---------------------------------
# Patience grace period: 38
# ---------------------------------
# Epoch 39/500
# Train RMSE: 0.2529
# Val RMSE: 0.2509, Val MAE: 0.1074
# Test RMSE: 0.3283, Test MAE: 0.1486
# ---------------------------------
# Model saved at epoch 39 with val RMSE 0.2509
# Patience grace period: 40
# ---------------------------------
# Epoch 40/500
# Train RMSE: 0.2527
# Val RMSE: 0.2509, Val MAE: 0.1076
# Test RMSE: 0.3280, Test MAE: 0.1485
# ---------------------------------
# Model saved at epoch 40 with val RMSE 0.2509
# Patience grace period: 39
# ---------------------------------
# Epoch 41/500
# Train RMSE: 0.2526
# Val RMSE: 0.2508, Val MAE: 0.1075
# Test RMSE: 0.3282, Test MAE: 0.1485
# ---------------------------------
# Model saved at epoch 41 with val RMSE 0.2508
# Patience grace period: 40
# ---------------------------------
# Epoch 42/500
# Train RMSE: 0.2526
# Val RMSE: 0.2508, Val MAE: 0.1076
# Test RMSE: 0.3275, Test MAE: 0.1486
# ---------------------------------
# Model saved at epoch 42 with val RMSE 0.2508
# Patience grace period: 39
# ---------------------------------
# Epoch 43/500
# Train RMSE: 0.2524
# Val RMSE: 0.2507, Val MAE: 0.1072
# Test RMSE: 0.3281, Test MAE: 0.1485
# ---------------------------------
# Model saved at epoch 43 with val RMSE 0.2507
# Patience grace period: 38
# ---------------------------------
# Epoch 44/500
# Train RMSE: 0.2523
# Val RMSE: 0.2507, Val MAE: 0.1072
# Test RMSE: 0.3279, Test MAE: 0.1485
# ---------------------------------
# Model saved at epoch 44 with val RMSE 0.2507
# Patience grace period: 40
# ---------------------------------
# Epoch 45/500
# Train RMSE: 0.2522
# Val RMSE: 0.2506, Val MAE: 0.1078
# Test RMSE: 0.3268, Test MAE: 0.1489
# ---------------------------------
# Model saved at epoch 45 with val RMSE 0.2506
# Patience grace period: 40
# ---------------------------------
# Epoch 46/500
# Train RMSE: 0.2522
# Val RMSE: 0.2506, Val MAE: 0.1072
# Test RMSE: 0.3276, Test MAE: 0.1489
# ---------------------------------
# Model saved at epoch 46 with val RMSE 0.2506
# Patience grace period: 39
# ---------------------------------
# Epoch 47/500
# Train RMSE: 0.2520
# Val RMSE: 0.2505, Val MAE: 0.1079
# Test RMSE: 0.3264, Test MAE: 0.1491
# ---------------------------------
# Model saved at epoch 47 with val RMSE 0.2505
# Patience grace period: 40
# ---------------------------------
# Epoch 48/500
# Train RMSE: 0.2520
# Val RMSE: 0.2505, Val MAE: 0.1081
# Test RMSE: 0.3260, Test MAE: 0.1493
# ---------------------------------
# Patience grace period: 38
# ---------------------------------
# Epoch 49/500
# Train RMSE: 0.2519
# Val RMSE: 0.2504, Val MAE: 0.1070
# Test RMSE: 0.3280, Test MAE: 0.1484
# ---------------------------------
# Model saved at epoch 49 with val RMSE 0.2504
# Patience grace period: 37
# ---------------------------------
# Epoch 50/500
# Train RMSE: 0.2518
# Val RMSE: 0.2504, Val MAE: 0.1073
# Test RMSE: 0.3274, Test MAE: 0.1490
# ---------------------------------
# Model saved at epoch 50 with val RMSE 0.2504
# Patience grace period: 36
# ---------------------------------
# Epoch 51/500
# Train RMSE: 0.2517
# Val RMSE: 0.2504, Val MAE: 0.1075
# Test RMSE: 0.3268, Test MAE: 0.1490
# ---------------------------------
# Model saved at epoch 51 with val RMSE 0.2504
# Patience grace period: 40
# ---------------------------------
# Epoch 52/500
# Train RMSE: 0.2516
# Val RMSE: 0.2503, Val MAE: 0.1074
# Test RMSE: 0.3268, Test MAE: 0.1491
# ---------------------------------
# Model saved at epoch 52 with val RMSE 0.2503
# Patience grace period: 39
# ---------------------------------
# Epoch 53/500
# Train RMSE: 0.2516
# Val RMSE: 0.2503, Val MAE: 0.1075
# Test RMSE: 0.3262, Test MAE: 0.1490
# ---------------------------------
# Model saved at epoch 53 with val RMSE 0.2503
# Patience grace period: 38
# ---------------------------------
# Epoch 54/500
# Train RMSE: 0.2515
# Val RMSE: 0.2502, Val MAE: 0.1076
# Test RMSE: 0.3262, Test MAE: 0.1491
# ---------------------------------
# Model saved at epoch 54 with val RMSE 0.2502
# Patience grace period: 40
# ---------------------------------
# Epoch 55/500
# Train RMSE: 0.2514
# Val RMSE: 0.2502, Val MAE: 0.1075
# Test RMSE: 0.3264, Test MAE: 0.1490
# ---------------------------------
# Model saved at epoch 55 with val RMSE 0.2502
# Patience grace period: 39
# ---------------------------------
# Epoch 56/500
# Train RMSE: 0.2513
# Val RMSE: 0.2501, Val MAE: 0.1076
# Test RMSE: 0.3259, Test MAE: 0.1492
# ---------------------------------
# Model saved at epoch 56 with val RMSE 0.2501
# Patience grace period: 38
# ---------------------------------
# Epoch 57/500
# Train RMSE: 0.2513
# Val RMSE: 0.2502, Val MAE: 0.1072
# Test RMSE: 0.3269, Test MAE: 0.1489
# ---------------------------------
# Patience grace period: 36
# ---------------------------------
# Epoch 58/500
# Train RMSE: 0.2512
# Val RMSE: 0.2501, Val MAE: 0.1074
# Test RMSE: 0.3262, Test MAE: 0.1492
# ---------------------------------
# Model saved at epoch 58 with val RMSE 0.2501
# Patience grace period: 40
# ---------------------------------
# Epoch 59/500
# Train RMSE: 0.2511
# Val RMSE: 0.2500, Val MAE: 0.1072
# Test RMSE: 0.3267, Test MAE: 0.1489
# ---------------------------------
# Model saved at epoch 59 with val RMSE 0.2500
# Patience grace period: 39
# ---------------------------------
# Epoch 60/500
# Train RMSE: 0.2511
# Val RMSE: 0.2500, Val MAE: 0.1081
# Test RMSE: 0.3250, Test MAE: 0.1497
# ---------------------------------
# Model saved at epoch 60 with val RMSE 0.2500
# Patience grace period: 38
# ---------------------------------
# Epoch 61/500
# Train RMSE: 0.2510
# Val RMSE: 0.2499, Val MAE: 0.1077
# Test RMSE: 0.3256, Test MAE: 0.1493
# ---------------------------------
# Model saved at epoch 61 with val RMSE 0.2499
# Patience grace period: 40
# ---------------------------------
# Epoch 62/500
# Train RMSE: 0.2509
# Val RMSE: 0.2499, Val MAE: 0.1074
# Test RMSE: 0.3258, Test MAE: 0.1491
# ---------------------------------
# Model saved at epoch 62 with val RMSE 0.2499
# Patience grace period: 39
# ---------------------------------
# Epoch 63/500
# Train RMSE: 0.2509
# Val RMSE: 0.2499, Val MAE: 0.1072
# Test RMSE: 0.3261, Test MAE: 0.1490
# ---------------------------------
# Model saved at epoch 63 with val RMSE 0.2499
# Patience grace period: 38
# ---------------------------------
# Epoch 64/500
# Train RMSE: 0.2508
# Val RMSE: 0.2498, Val MAE: 0.1072
# Test RMSE: 0.3265, Test MAE: 0.1492
# ---------------------------------
# Model saved at epoch 64 with val RMSE 0.2498
# Patience grace period: 37
# ---------------------------------
# Epoch 65/500
# Train RMSE: 0.2508
# Val RMSE: 0.2498, Val MAE: 0.1073
# Test RMSE: 0.3262, Test MAE: 0.1492
# ---------------------------------
# Model saved at epoch 65 with val RMSE 0.2498
# Patience grace period: 40
# ---------------------------------
# Epoch 66/500
# Train RMSE: 0.2507
# Val RMSE: 0.2498, Val MAE: 0.1074
# Test RMSE: 0.3260, Test MAE: 0.1493
# ---------------------------------
# Model saved at epoch 66 with val RMSE 0.2498
# Patience grace period: 39
# ---------------------------------
# Epoch 67/500
# Train RMSE: 0.2506
# Val RMSE: 0.2497, Val MAE: 0.1073
# Test RMSE: 0.3256, Test MAE: 0.1493
# ---------------------------------
# Model saved at epoch 67 with val RMSE 0.2497
# Patience grace period: 38
# ---------------------------------
# Epoch 68/500
# Train RMSE: 0.2506
# Val RMSE: 0.2497, Val MAE: 0.1079
# Test RMSE: 0.3250, Test MAE: 0.1498
# ---------------------------------
# Model saved at epoch 68 with val RMSE 0.2497
# Patience grace period: 36
# ---------------------------------
# Epoch 69/500
# Train RMSE: 0.2505
# Val RMSE: 0.2497, Val MAE: 0.1076
# Test RMSE: 0.3248, Test MAE: 0.1495
# ---------------------------------
# Model saved at epoch 69 with val RMSE 0.2497
# Patience grace period: 40
# ---------------------------------
# Epoch 70/500
# Train RMSE: 0.2504
# Val RMSE: 0.2497, Val MAE: 0.1077
# Test RMSE: 0.3248, Test MAE: 0.1497
# ---------------------------------
# Patience grace period: 38
# ---------------------------------
# Epoch 71/500
# Train RMSE: 0.2504
# Val RMSE: 0.2497, Val MAE: 0.1074
# Test RMSE: 0.3252, Test MAE: 0.1494
# ---------------------------------
# Model saved at epoch 71 with val RMSE 0.2497
# Patience grace period: 37
# ---------------------------------
# Epoch 72/500
# Train RMSE: 0.2503
# Val RMSE: 0.2496, Val MAE: 0.1072
# Test RMSE: 0.3256, Test MAE: 0.1493
# ---------------------------------
# Model saved at epoch 72 with val RMSE 0.2496
# Patience grace period: 36
# ---------------------------------
# Epoch 73/500
# Train RMSE: 0.2503
# Val RMSE: 0.2496, Val MAE: 0.1077
# Test RMSE: 0.3248, Test MAE: 0.1498
# ---------------------------------
# Patience grace period: 34
# ---------------------------------
# Epoch 74/500
# Train RMSE: 0.2502
# Val RMSE: 0.2496, Val MAE: 0.1077
# Test RMSE: 0.3245, Test MAE: 0.1496
# ---------------------------------
# Model saved at epoch 74 with val RMSE 0.2496
# Patience grace period: 33
# ---------------------------------
# Epoch 75/500
# Train RMSE: 0.2502
# Val RMSE: 0.2496, Val MAE: 0.1072
# Test RMSE: 0.3249, Test MAE: 0.1495
# ---------------------------------
# Model saved at epoch 75 with val RMSE 0.2496
# Patience grace period: 40
# ---------------------------------
# Epoch 76/500
# Train RMSE: 0.2502
# Val RMSE: 0.2495, Val MAE: 0.1074
# Test RMSE: 0.3249, Test MAE: 0.1495
# ---------------------------------
# Model saved at epoch 76 with val RMSE 0.2495
# Patience grace period: 39
# ---------------------------------
# Epoch 77/500
# Train RMSE: 0.2501
# Val RMSE: 0.2496, Val MAE: 0.1070
# Test RMSE: 0.3252, Test MAE: 0.1493
# ---------------------------------
# Patience grace period: 37
# ---------------------------------
# Epoch 78/500
# Train RMSE: 0.2501
# Val RMSE: 0.2495, Val MAE: 0.1074
# Test RMSE: 0.3247, Test MAE: 0.1494
# ---------------------------------
# Model saved at epoch 78 with val RMSE 0.2495
# Patience grace period: 40
# ---------------------------------
# Epoch 79/500
# Train RMSE: 0.2501
# Val RMSE: 0.2495, Val MAE: 0.1075
# Test RMSE: 0.3245, Test MAE: 0.1495
# ---------------------------------
# Patience grace period: 38
# ---------------------------------
# Epoch 80/500
# Train RMSE: 0.2500
# Val RMSE: 0.2494, Val MAE: 0.1075
# Test RMSE: 0.3245, Test MAE: 0.1495
# ---------------------------------
# Model saved at epoch 80 with val RMSE 0.2494
# Patience grace period: 37
# ---------------------------------
# Epoch 81/500
# Train RMSE: 0.2500
# Val RMSE: 0.2495, Val MAE: 0.1080
# Test RMSE: 0.3239, Test MAE: 0.1501
# ---------------------------------
# Patience grace period: 35
# ---------------------------------
# Epoch 82/500
# Train RMSE: 0.2499
# Val RMSE: 0.2494, Val MAE: 0.1068
# Test RMSE: 0.3252, Test MAE: 0.1492
# ---------------------------------
# Model saved at epoch 82 with val RMSE 0.2494
# Patience grace period: 34
# ---------------------------------
# Epoch 83/500
# Train RMSE: 0.2499
# Val RMSE: 0.2494, Val MAE: 0.1078
# Test RMSE: 0.3237, Test MAE: 0.1498
# ---------------------------------
# Patience grace period: 32
# ---------------------------------
# Epoch 84/500
# Train RMSE: 0.2498
# Val RMSE: 0.2494, Val MAE: 0.1074
# Test RMSE: 0.3248, Test MAE: 0.1496
# ---------------------------------
# Patience grace period: 30
# ---------------------------------
# Epoch 85/500
# Train RMSE: 0.2498
# Val RMSE: 0.2494, Val MAE: 0.1070
# Test RMSE: 0.3245, Test MAE: 0.1493
# ---------------------------------
# Model saved at epoch 85 with val RMSE 0.2494
# Patience grace period: 29
# ---------------------------------
# Epoch 86/500
# Train RMSE: 0.2497
# Val RMSE: 0.2493, Val MAE: 0.1071
# Test RMSE: 0.3244, Test MAE: 0.1495
# ---------------------------------
# Model saved at epoch 86 with val RMSE 0.2493
# Patience grace period: 40
# ---------------------------------
# Epoch 87/500
# Train RMSE: 0.2497
# Val RMSE: 0.2494, Val MAE: 0.1077
# Test RMSE: 0.3238, Test MAE: 0.1499
# ---------------------------------
# Patience grace period: 38
# ---------------------------------
# Epoch 88/500
# Train RMSE: 0.2497
# Val RMSE: 0.2494, Val MAE: 0.1074
# Test RMSE: 0.3243, Test MAE: 0.1496
# ---------------------------------
# Patience grace period: 37
# ---------------------------------
# Epoch 89/500
# Train RMSE: 0.2497
# Val RMSE: 0.2493, Val MAE: 0.1074
# Test RMSE: 0.3242, Test MAE: 0.1497
# ---------------------------------
# Model saved at epoch 89 with val RMSE 0.2493
# Patience grace period: 36
# ---------------------------------
# Epoch 90/500
# Train RMSE: 0.2496
# Val RMSE: 0.2494, Val MAE: 0.1081
# Test RMSE: 0.3233, Test MAE: 0.1501
# ---------------------------------
# Patience grace period: 34
# ---------------------------------
# Epoch 91/500
# Train RMSE: 0.2496
# Val RMSE: 0.2493, Val MAE: 0.1074
# Test RMSE: 0.3240, Test MAE: 0.1496
# ---------------------------------
# Model saved at epoch 91 with val RMSE 0.2493
# Patience grace period: 33
# ---------------------------------
# Epoch 92/500
# Train RMSE: 0.2496
# Val RMSE: 0.2493, Val MAE: 0.1076
# Test RMSE: 0.3239, Test MAE: 0.1500
# ---------------------------------
# Patience grace period: 31
# ---------------------------------
# Epoch 93/500
# Train RMSE: 0.2495
# Val RMSE: 0.2493, Val MAE: 0.1074
# Test RMSE: 0.3241, Test MAE: 0.1499
# ---------------------------------
# Model saved at epoch 93 with val RMSE 0.2493
# Patience grace period: 30
# ---------------------------------
# Epoch 94/500
# Train RMSE: 0.2495
# Val RMSE: 0.2493, Val MAE: 0.1075
# Test RMSE: 0.3239, Test MAE: 0.1499
# ---------------------------------
# Patience grace period: 28
# ---------------------------------
# Epoch 95/500
# Train RMSE: 0.2495
# Val RMSE: 0.2493, Val MAE: 0.1071
# Test RMSE: 0.3243, Test MAE: 0.1499
# ---------------------------------
# Model saved at epoch 95 with val RMSE 0.2493
# Patience grace period: 27
# ---------------------------------
# Epoch 96/500
# Train RMSE: 0.2495
# Val RMSE: 0.2493, Val MAE: 0.1077
# Test RMSE: 0.3235, Test MAE: 0.1501
# ---------------------------------
# Patience grace period: 25
# ---------------------------------
# Epoch 97/500
# Train RMSE: 0.2494
# Val RMSE: 0.2493, Val MAE: 0.1078
# Test RMSE: 0.3235, Test MAE: 0.1498
# ---------------------------------
# Patience grace period: 24
# ---------------------------------
# Epoch 98/500
# Train RMSE: 0.2494
# Val RMSE: 0.2492, Val MAE: 0.1069
# Test RMSE: 0.3251, Test MAE: 0.1494
# ---------------------------------
# Model saved at epoch 98 with val RMSE 0.2492
# Patience grace period: 40
# ---------------------------------
# Epoch 99/500
# Train RMSE: 0.2494
# Val RMSE: 0.2493, Val MAE: 0.1077
# Test RMSE: 0.3236, Test MAE: 0.1501
# ---------------------------------
# Patience grace period: 38
# ---------------------------------
# Epoch 100/500
# Train RMSE: 0.2493
# Val RMSE: 0.2492, Val MAE: 0.1072
# Test RMSE: 0.3245, Test MAE: 0.1500
# ---------------------------------
# Patience grace period: 37
# ---------------------------------
# Epoch 101/500
# Train RMSE: 0.2493
# Val RMSE: 0.2492, Val MAE: 0.1072
# Test RMSE: 0.3242, Test MAE: 0.1497
# ---------------------------------
# Patience grace period: 36
# ---------------------------------
# Epoch 102/500
# Train RMSE: 0.2493
# Val RMSE: 0.2492, Val MAE: 0.1073
# Test RMSE: 0.3240, Test MAE: 0.1500
# ---------------------------------
# Patience grace period: 35
# ---------------------------------
# Epoch 103/500
# Train RMSE: 0.2492
# Val RMSE: 0.2492, Val MAE: 0.1070
# Test RMSE: 0.3244, Test MAE: 0.1498
# ---------------------------------
# Model saved at epoch 103 with val RMSE 0.2492
# Patience grace period: 34
# ---------------------------------
# Epoch 104/500
# Train RMSE: 0.2492
# Val RMSE: 0.2492, Val MAE: 0.1076
# Test RMSE: 0.3235, Test MAE: 0.1502
# ---------------------------------
# Patience grace period: 32
# ---------------------------------
# Epoch 105/500
# Train RMSE: 0.2492
# Val RMSE: 0.2492, Val MAE: 0.1069
# Test RMSE: 0.3246, Test MAE: 0.1496
# ---------------------------------
# Model saved at epoch 105 with val RMSE 0.2492
# Patience grace period: 31
# ---------------------------------
# Epoch 106/500
# Train RMSE: 0.2492
# Val RMSE: 0.2492, Val MAE: 0.1076
# Test RMSE: 0.3235, Test MAE: 0.1502
# ---------------------------------
# Patience grace period: 29
# ---------------------------------
# Epoch 107/500
# Train RMSE: 0.2492
# Val RMSE: 0.2491, Val MAE: 0.1072
# Test RMSE: 0.3242, Test MAE: 0.1500
# ---------------------------------
# Model saved at epoch 107 with val RMSE 0.2491
# Patience grace period: 28
# ---------------------------------
# Epoch 108/500
# Train RMSE: 0.2491
# Val RMSE: 0.2491, Val MAE: 0.1068
# Test RMSE: 0.3248, Test MAE: 0.1498
# ---------------------------------
# Model saved at epoch 108 with val RMSE 0.2491
# Patience grace period: 27
# ---------------------------------
# Epoch 109/500
# Train RMSE: 0.2491
# Val RMSE: 0.2491, Val MAE: 0.1071
# Test RMSE: 0.3243, Test MAE: 0.1499
# ---------------------------------
# Patience grace period: 25
# ---------------------------------
# Epoch 110/500
# Train RMSE: 0.2491
# Val RMSE: 0.2491, Val MAE: 0.1073
# Test RMSE: 0.3235, Test MAE: 0.1499
# ---------------------------------
# Patience grace period: 23
# ---------------------------------
# Epoch 111/500
# Train RMSE: 0.2490
# Val RMSE: 0.2491, Val MAE: 0.1071
# Test RMSE: 0.3241, Test MAE: 0.1500
# ---------------------------------
# Patience grace period: 22
# ---------------------------------
# Epoch 112/500
# Train RMSE: 0.2490
# Val RMSE: 0.2491, Val MAE: 0.1073
# Test RMSE: 0.3238, Test MAE: 0.1502
# ---------------------------------
# Model saved at epoch 112 with val RMSE 0.2491
# Patience grace period: 21
# ---------------------------------
# Epoch 113/500
# Train RMSE: 0.2490
# Val RMSE: 0.2491, Val MAE: 0.1068
# Test RMSE: 0.3245, Test MAE: 0.1497
# ---------------------------------
# Patience grace period: 19
# ---------------------------------
# Epoch 114/500
# Train RMSE: 0.2490
# Val RMSE: 0.2491, Val MAE: 0.1071
# Test RMSE: 0.3238, Test MAE: 0.1501
# ---------------------------------
# Patience grace period: 17
# ---------------------------------
# Epoch 115/500
# Train RMSE: 0.2490
# Val RMSE: 0.2491, Val MAE: 0.1071
# Test RMSE: 0.3242, Test MAE: 0.1501
# ---------------------------------
# Patience grace period: 16
# ---------------------------------
# Epoch 116/500
# Train RMSE: 0.2489
# Val RMSE: 0.2491, Val MAE: 0.1072
# Test RMSE: 0.3242, Test MAE: 0.1503
# ---------------------------------
# Model saved at epoch 116 with val RMSE 0.2491
# Patience grace period: 40
# ---------------------------------
# Epoch 117/500
# Train RMSE: 0.2489
# Val RMSE: 0.2491, Val MAE: 0.1069
# Test RMSE: 0.3244, Test MAE: 0.1499
# ---------------------------------
# Patience grace period: 38
# ---------------------------------
# Epoch 118/500
# Train RMSE: 0.2489
# Val RMSE: 0.2493, Val MAE: 0.1082
# Test RMSE: 0.3223, Test MAE: 0.1510
# ---------------------------------
# Patience grace period: 36
# ---------------------------------
# Epoch 119/500
# Train RMSE: 0.2489
# Val RMSE: 0.2490, Val MAE: 0.1068
# Test RMSE: 0.3242, Test MAE: 0.1499
# ---------------------------------
# Model saved at epoch 119 with val RMSE 0.2490
# Patience grace period: 35
# ---------------------------------
# Epoch 120/500
# Train RMSE: 0.2489
# Val RMSE: 0.2491, Val MAE: 0.1069
# Test RMSE: 0.3241, Test MAE: 0.1500
# ---------------------------------
# Patience grace period: 33
# ---------------------------------
# Epoch 121/500
# Train RMSE: 0.2489
# Val RMSE: 0.2490, Val MAE: 0.1070
# Test RMSE: 0.3243, Test MAE: 0.1498
# ---------------------------------
# Model saved at epoch 121 with val RMSE 0.2490
# Patience grace period: 32
# ---------------------------------
# Epoch 122/500
# Train RMSE: 0.2488
# Val RMSE: 0.2491, Val MAE: 0.1075
# Test RMSE: 0.3235, Test MAE: 0.1502
# ---------------------------------
# Patience grace period: 30
# ---------------------------------
# Epoch 123/500
# Train RMSE: 0.2488
# Val RMSE: 0.2490, Val MAE: 0.1070
# Test RMSE: 0.3241, Test MAE: 0.1499
# ---------------------------------
# Patience grace period: 29
# ---------------------------------
# Epoch 124/500
# Train RMSE: 0.2488
# Val RMSE: 0.2491, Val MAE: 0.1074
# Test RMSE: 0.3233, Test MAE: 0.1501
# ---------------------------------
# Patience grace period: 27
# ---------------------------------
# Epoch 125/500
# Train RMSE: 0.2488
# Val RMSE: 0.2491, Val MAE: 0.1074
# Test RMSE: 0.3237, Test MAE: 0.1502
# ---------------------------------
# Patience grace period: 26
# ---------------------------------
# Epoch 126/500
# Train RMSE: 0.2487
# Val RMSE: 0.2490, Val MAE: 0.1068
# Test RMSE: 0.3245, Test MAE: 0.1499
# ---------------------------------
# Model saved at epoch 126 with val RMSE 0.2490
# Patience grace period: 25
# ---------------------------------
# Epoch 127/500
# Train RMSE: 0.2487
# Val RMSE: 0.2490, Val MAE: 0.1071
# Test RMSE: 0.3239, Test MAE: 0.1501
# ---------------------------------
# Patience grace period: 23
# ---------------------------------
# Epoch 128/500
# Train RMSE: 0.2487
# Val RMSE: 0.2490, Val MAE: 0.1068
# Test RMSE: 0.3242, Test MAE: 0.1500
# ---------------------------------
# Patience grace period: 22
# ---------------------------------
# Epoch 129/500
# Train RMSE: 0.2487
# Val RMSE: 0.2491, Val MAE: 0.1076
# Test RMSE: 0.3230, Test MAE: 0.1503
# ---------------------------------
# Patience grace period: 20
# ---------------------------------
# Epoch 130/500
# Train RMSE: 0.2487
# Val RMSE: 0.2491, Val MAE: 0.1077
# Test RMSE: 0.3230, Test MAE: 0.1508
# ---------------------------------
# Patience grace period: 18
# ---------------------------------
# Epoch 131/500
# Train RMSE: 0.2486
# Val RMSE: 0.2491, Val MAE: 0.1074
# Test RMSE: 0.3233, Test MAE: 0.1507
# ---------------------------------
# Patience grace period: 16
# ---------------------------------
# Epoch 132/500
# Train RMSE: 0.2486
# Val RMSE: 0.2490, Val MAE: 0.1071
# Test RMSE: 0.3239, Test MAE: 0.1501
# ---------------------------------
# Patience grace period: 15
# ---------------------------------
# Epoch 133/500
# Train RMSE: 0.2486
# Val RMSE: 0.2491, Val MAE: 0.1077
# Test RMSE: 0.3227, Test MAE: 0.1508
# ---------------------------------
# Patience grace period: 13
# ---------------------------------
# Epoch 134/500
# Train RMSE: 0.2486
# Val RMSE: 0.2490, Val MAE: 0.1071
# Test RMSE: 0.3239, Test MAE: 0.1504
# ---------------------------------
# Patience grace period: 12
# ---------------------------------
# Epoch 135/500
# Train RMSE: 0.2486
# Val RMSE: 0.2491, Val MAE: 0.1075
# Test RMSE: 0.3235, Test MAE: 0.1505
# ---------------------------------
# Patience grace period: 10
# ---------------------------------
# Epoch 136/500
# Train RMSE: 0.2486
# Val RMSE: 0.2490, Val MAE: 0.1069
# Test RMSE: 0.3241, Test MAE: 0.1500
# ---------------------------------
# Patience grace period: 9
# ---------------------------------
# Epoch 137/500
# Train RMSE: 0.2486
# Val RMSE: 0.2490, Val MAE: 0.1073
# Test RMSE: 0.3238, Test MAE: 0.1503
# ---------------------------------
# Model saved at epoch 137 with val RMSE 0.2490
# Patience grace period: 8
# ---------------------------------
# Epoch 138/500
# Train RMSE: 0.2485
# Val RMSE: 0.2489, Val MAE: 0.1068
# Test RMSE: 0.3243, Test MAE: 0.1500
# ---------------------------------
# Model saved at epoch 138 with val RMSE 0.2489
# Patience grace period: 40
# ---------------------------------
# Epoch 139/500
# Train RMSE: 0.2485
# Val RMSE: 0.2490, Val MAE: 0.1072
# Test RMSE: 0.3241, Test MAE: 0.1503
# ---------------------------------
# Patience grace period: 38
# ---------------------------------
# Epoch 140/500
# Train RMSE: 0.2485
# Val RMSE: 0.2490, Val MAE: 0.1064
# Test RMSE: 0.3252, Test MAE: 0.1497
# ---------------------------------
# Patience grace period: 37
# ---------------------------------
# Epoch 141/500
# Train RMSE: 0.2484
# Val RMSE: 0.2490, Val MAE: 0.1073
# Test RMSE: 0.3234, Test MAE: 0.1504
# ---------------------------------
# Patience grace period: 35
# ---------------------------------
# Epoch 142/500
# Train RMSE: 0.2485
# Val RMSE: 0.2490, Val MAE: 0.1069
# Test RMSE: 0.3241, Test MAE: 0.1500
# ---------------------------------
# Patience grace period: 34
# ---------------------------------
# Epoch 143/500
# Train RMSE: 0.2484
# Val RMSE: 0.2491, Val MAE: 0.1073
# Test RMSE: 0.3235, Test MAE: 0.1504
# ---------------------------------
# Patience grace period: 32
# ---------------------------------
# Epoch 144/500
# Train RMSE: 0.2484
# Val RMSE: 0.2490, Val MAE: 0.1072
# Test RMSE: 0.3240, Test MAE: 0.1501
# ---------------------------------
# Patience grace period: 31
# ---------------------------------
# Epoch 145/500
# Train RMSE: 0.2484
# Val RMSE: 0.2490, Val MAE: 0.1072
# Test RMSE: 0.3237, Test MAE: 0.1505
# ---------------------------------
# Patience grace period: 29
# ---------------------------------
# Epoch 146/500
# Train RMSE: 0.2484
# Val RMSE: 0.2490, Val MAE: 0.1072
# Test RMSE: 0.3237, Test MAE: 0.1505
# ---------------------------------
# Patience grace period: 28
# ---------------------------------
# Epoch 147/500
# Train RMSE: 0.2484
# Val RMSE: 0.2491, Val MAE: 0.1077
# Test RMSE: 0.3229, Test MAE: 0.1506
# ---------------------------------
# Patience grace period: 26
# ---------------------------------
# Epoch 148/500
# Train RMSE: 0.2483
# Val RMSE: 0.2490, Val MAE: 0.1071
# Test RMSE: 0.3237, Test MAE: 0.1502
# ---------------------------------
# Patience grace period: 25
# ---------------------------------
# Epoch 149/500
# Train RMSE: 0.2483
# Val RMSE: 0.2490, Val MAE: 0.1071
# Test RMSE: 0.3241, Test MAE: 0.1503
# ---------------------------------
# Patience grace period: 23
# ---------------------------------
# Epoch 150/500
# Train RMSE: 0.2483
# Val RMSE: 0.2489, Val MAE: 0.1069
# Test RMSE: 0.3245, Test MAE: 0.1502
# ---------------------------------
# Patience grace period: 22
# ---------------------------------
# Epoch 151/500
# Train RMSE: 0.2483
# Val RMSE: 0.2490, Val MAE: 0.1071
# Test RMSE: 0.3243, Test MAE: 0.1505
# ---------------------------------
# Patience grace period: 20
# ---------------------------------
# Epoch 152/500
# Train RMSE: 0.2483
# Val RMSE: 0.2489, Val MAE: 0.1066
# Test RMSE: 0.3247, Test MAE: 0.1500
# ---------------------------------
# Model saved at epoch 152 with val RMSE 0.2489
# Patience grace period: 19
# ---------------------------------
# Epoch 153/500
# Train RMSE: 0.2483
# Val RMSE: 0.2490, Val MAE: 0.1075
# Test RMSE: 0.3231, Test MAE: 0.1505
# ---------------------------------
# Patience grace period: 17
# ---------------------------------
# Epoch 154/500
# Train RMSE: 0.2483
# Val RMSE: 0.2489, Val MAE: 0.1069
# Test RMSE: 0.3243, Test MAE: 0.1502
# ---------------------------------
# Patience grace period: 16
# ---------------------------------
# Epoch 155/500
# Train RMSE: 0.2482
# Val RMSE: 0.2490, Val MAE: 0.1070
# Test RMSE: 0.3241, Test MAE: 0.1504
# ---------------------------------
# Patience grace period: 14
# ---------------------------------
# Epoch 156/500
# Train RMSE: 0.2482
# Val RMSE: 0.2490, Val MAE: 0.1071
# Test RMSE: 0.3239, Test MAE: 0.1507
# ---------------------------------
# Patience grace period: 12
# ---------------------------------
# Epoch 157/500
# Train RMSE: 0.2482
# Val RMSE: 0.2490, Val MAE: 0.1071
# Test RMSE: 0.3238, Test MAE: 0.1503
# ---------------------------------
# Patience grace period: 11
# ---------------------------------
# Epoch 158/500
# Train RMSE: 0.2482
# Val RMSE: 0.2491, Val MAE: 0.1077
# Test RMSE: 0.3229, Test MAE: 0.1509
# ---------------------------------
# Patience grace period: 9
# ---------------------------------
# Epoch 159/500
# Train RMSE: 0.2482
# Val RMSE: 0.2490, Val MAE: 0.1073
# Test RMSE: 0.3239, Test MAE: 0.1505
# ---------------------------------
# Patience grace period: 8
# ---------------------------------
# Epoch 160/500
# Train RMSE: 0.2482
# Val RMSE: 0.2489, Val MAE: 0.1066
# Test RMSE: 0.3247, Test MAE: 0.1502
# ---------------------------------
# Patience grace period: 7
# ---------------------------------
# Epoch 161/500
# Train RMSE: 0.2481
# Val RMSE: 0.2491, Val MAE: 0.1074
# Test RMSE: 0.3233, Test MAE: 0.1507
# ---------------------------------
# Patience grace period: 5
# ---------------------------------
# Epoch 162/500
# Train RMSE: 0.2481
# Val RMSE: 0.2489, Val MAE: 0.1068
# Test RMSE: 0.3244, Test MAE: 0.1503
# ---------------------------------
# Patience grace period: 4
# ---------------------------------
# Epoch 163/500
# Train RMSE: 0.2481
# Val RMSE: 0.2490, Val MAE: 0.1064
# Test RMSE: 0.3249, Test MAE: 0.1499
# ---------------------------------
# Patience grace period: 2
# ---------------------------------
# Epoch 164/500
# Train RMSE: 0.2481
# Val RMSE: 0.2489, Val MAE: 0.1066
# Test RMSE: 0.3249, Test MAE: 0.1500
# ---------------------------------
# Patience grace period: 1
# ---------------------------------
# Epoch 165/500
# Train RMSE: 0.2481
# Val RMSE: 0.2489, Val MAE: 0.1064
# Test RMSE: 0.3250, Test MAE: 0.1500
# ---------------------------------
# Model saved at epoch 165 with val RMSE 0.2489
# Patience grace period: 0
# Early stopping triggered at epoch 165
# Final Test RMSE: 0.3250, Final Test MAE: 0.1500
# <ipython-input-3-2a228d64b832>:126: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   self.model.load_state_dict(torch.load(os.path.join(save_dir, 'best_model.pth')))
# Pearson Corr: 0.7488482768420702
# Spearman Corr: 0.4304667272894109
# p-rmse: 0.32500796033207086
#        rmse       mae  seed                             subtask    method  \
# 0  0.325008  0.150027     1  openproblems_bmmc_cite_phase2_mod2  original
#
#     pearson p_value_pearson  spearman p_value_spearman
# 0  0.748848          0.0000  0.430467           0.0000
# ---------------------------------
# Epoch 1/500
# Train RMSE: 0.3746
# Val RMSE: 0.3228, Val MAE: 0.1328
# Test RMSE: 0.3994, Test MAE: 0.1770
# ---------------------------------
# Model saved at epoch 1 with val RMSE 0.3228
# Patience grace period: 40
# ---------------------------------
# Epoch 2/500
# Train RMSE: 0.3273
# Val RMSE: 0.2947, Val MAE: 0.1275
# Test RMSE: 0.3688, Test MAE: 0.1683
# ---------------------------------
# Model saved at epoch 2 with val RMSE 0.2947
# Patience grace period: 40
# ---------------------------------
# Epoch 3/500
# Train RMSE: 0.3055
# Val RMSE: 0.2802, Val MAE: 0.1206
# Test RMSE: 0.3560, Test MAE: 0.1607
# ---------------------------------
# Model saved at epoch 3 with val RMSE 0.2802
# Patience grace period: 40
# ---------------------------------
# Epoch 4/500
# Train RMSE: 0.2925
# Val RMSE: 0.2732, Val MAE: 0.1177
# Test RMSE: 0.3503, Test MAE: 0.1575
# ---------------------------------
# Model saved at epoch 4 with val RMSE 0.2732
# Patience grace period: 40
# ---------------------------------
# Epoch 5/500
# Train RMSE: 0.2843
# Val RMSE: 0.2689, Val MAE: 0.1162
# Test RMSE: 0.3463, Test MAE: 0.1558
# ---------------------------------
# Model saved at epoch 5 with val RMSE 0.2689
# Patience grace period: 40
# ---------------------------------
# Epoch 6/500
# Train RMSE: 0.2783
# Val RMSE: 0.2655, Val MAE: 0.1148
# Test RMSE: 0.3426, Test MAE: 0.1536
# ---------------------------------
# Model saved at epoch 6 with val RMSE 0.2655
# Patience grace period: 40
# ---------------------------------
# Epoch 7/500
# Train RMSE: 0.2735
# Val RMSE: 0.2628, Val MAE: 0.1135
# Test RMSE: 0.3396, Test MAE: 0.1519
# ---------------------------------
# Model saved at epoch 7 with val RMSE 0.2628
# Patience grace period: 40
# ---------------------------------
# Epoch 8/500
# Train RMSE: 0.2697
# Val RMSE: 0.2606, Val MAE: 0.1125
# Test RMSE: 0.3376, Test MAE: 0.1506
# ---------------------------------
# Model saved at epoch 8 with val RMSE 0.2606
# Patience grace period: 40
# ---------------------------------
# Epoch 9/500
# Train RMSE: 0.2666
# Val RMSE: 0.2591, Val MAE: 0.1108
# Test RMSE: 0.3373, Test MAE: 0.1493
# ---------------------------------
# Model saved at epoch 9 with val RMSE 0.2591
# Patience grace period: 40
# ---------------------------------
# Epoch 10/500
# Train RMSE: 0.2643
# Val RMSE: 0.2579, Val MAE: 0.1099
# Test RMSE: 0.3371, Test MAE: 0.1486
# ---------------------------------
# Model saved at epoch 10 with val RMSE 0.2579
# Patience grace period: 40
# ---------------------------------
# Epoch 11/500
# Train RMSE: 0.2625
# Val RMSE: 0.2567, Val MAE: 0.1099
# Test RMSE: 0.3352, Test MAE: 0.1485
# ---------------------------------
# Model saved at epoch 11 with val RMSE 0.2567
# Patience grace period: 40
# ---------------------------------
# Epoch 12/500
# Train RMSE: 0.2612
# Val RMSE: 0.2559, Val MAE: 0.1094
# Test RMSE: 0.3346, Test MAE: 0.1483
# ---------------------------------
# Model saved at epoch 12 with val RMSE 0.2559
# Patience grace period: 40
# ---------------------------------
# Epoch 13/500
# Train RMSE: 0.2602
# Val RMSE: 0.2553, Val MAE: 0.1085
# Test RMSE: 0.3347, Test MAE: 0.1474
# ---------------------------------
# Model saved at epoch 13 with val RMSE 0.2553
# Patience grace period: 40
# ---------------------------------
# Epoch 14/500
# Train RMSE: 0.2593
# Val RMSE: 0.2549, Val MAE: 0.1081
# Test RMSE: 0.3347, Test MAE: 0.1471
# ---------------------------------
# Model saved at epoch 14 with val RMSE 0.2549
# Patience grace period: 40
# ---------------------------------
# Epoch 15/500
# Train RMSE: 0.2586
# Val RMSE: 0.2543, Val MAE: 0.1084
# Test RMSE: 0.3332, Test MAE: 0.1473
# ---------------------------------
# Model saved at epoch 15 with val RMSE 0.2543
# Patience grace period: 40
# ---------------------------------
# Epoch 16/500
# Train RMSE: 0.2580
# Val RMSE: 0.2540, Val MAE: 0.1079
# Test RMSE: 0.3333, Test MAE: 0.1469
# ---------------------------------
# Model saved at epoch 16 with val RMSE 0.2540
# Patience grace period: 40
# ---------------------------------
# Epoch 17/500
# Train RMSE: 0.2575
# Val RMSE: 0.2538, Val MAE: 0.1074
# Test RMSE: 0.3332, Test MAE: 0.1468
# ---------------------------------
# Model saved at epoch 17 with val RMSE 0.2538
# Patience grace period: 40
# ---------------------------------
# Epoch 18/500
# Train RMSE: 0.2570
# Val RMSE: 0.2534, Val MAE: 0.1078
# Test RMSE: 0.3321, Test MAE: 0.1471
# ---------------------------------
# Model saved at epoch 18 with val RMSE 0.2534
# Patience grace period: 40
# ---------------------------------
# Epoch 19/500
# Train RMSE: 0.2566
# Val RMSE: 0.2530, Val MAE: 0.1083
# Test RMSE: 0.3309, Test MAE: 0.1473
# ---------------------------------
# Model saved at epoch 19 with val RMSE 0.2530
# Patience grace period: 40
# ---------------------------------
# Epoch 20/500
# Train RMSE: 0.2563
# Val RMSE: 0.2529, Val MAE: 0.1077
# Test RMSE: 0.3318, Test MAE: 0.1471
# ---------------------------------
# Model saved at epoch 20 with val RMSE 0.2529
# Patience grace period: 39
# ---------------------------------
# Epoch 21/500
# Train RMSE: 0.2560
# Val RMSE: 0.2528, Val MAE: 0.1074
# Test RMSE: 0.3318, Test MAE: 0.1470
# ---------------------------------
# Model saved at epoch 21 with val RMSE 0.2528
# Patience grace period: 40
# ---------------------------------
# Epoch 22/500
# Train RMSE: 0.2557
# Val RMSE: 0.2525, Val MAE: 0.1077
# Test RMSE: 0.3306, Test MAE: 0.1474
# ---------------------------------
# Model saved at epoch 22 with val RMSE 0.2525
# Patience grace period: 40
# ---------------------------------
# Epoch 23/500
# Train RMSE: 0.2554
# Val RMSE: 0.2524, Val MAE: 0.1075
# Test RMSE: 0.3309, Test MAE: 0.1473
# ---------------------------------
# Model saved at epoch 23 with val RMSE 0.2524
# Patience grace period: 40
# ---------------------------------
# Epoch 24/500
# Train RMSE: 0.2552
# Val RMSE: 0.2521, Val MAE: 0.1077
# Test RMSE: 0.3302, Test MAE: 0.1475
# ---------------------------------
# Model saved at epoch 24 with val RMSE 0.2521
# Patience grace period: 40
# ---------------------------------
# Epoch 25/500
# Train RMSE: 0.2549
# Val RMSE: 0.2521, Val MAE: 0.1071
# Test RMSE: 0.3306, Test MAE: 0.1473
# ---------------------------------
# Model saved at epoch 25 with val RMSE 0.2521
# Patience grace period: 39
# ---------------------------------
# Epoch 26/500
# Train RMSE: 0.2547
# Val RMSE: 0.2518, Val MAE: 0.1076
# Test RMSE: 0.3296, Test MAE: 0.1476
# ---------------------------------
# Model saved at epoch 26 with val RMSE 0.2518
# Patience grace period: 40
# ---------------------------------
# Epoch 27/500
# Train RMSE: 0.2545
# Val RMSE: 0.2518, Val MAE: 0.1073
# Test RMSE: 0.3303, Test MAE: 0.1474
# ---------------------------------
# Model saved at epoch 27 with val RMSE 0.2518
# Patience grace period: 39
# ---------------------------------
# Epoch 28/500
# Train RMSE: 0.2543
# Val RMSE: 0.2518, Val MAE: 0.1068
# Test RMSE: 0.3306, Test MAE: 0.1473
# ---------------------------------
# Model saved at epoch 28 with val RMSE 0.2518
# Patience grace period: 38
# ---------------------------------
# Epoch 29/500
# Train RMSE: 0.2541
# Val RMSE: 0.2517, Val MAE: 0.1069
# ...
# Val RMSE: 0.2493, Val MAE: 0.1071
# Test RMSE: 0.3254, Test MAE: 0.1500
# ---------------------------------
# Model saved at epoch 91 with val RMSE 0.2493
# Patience grace period: 34
# ---------------------------------
# Epoch 92/500
# Train RMSE: 0.2494
# Val RMSE: 0.2493, Val MAE: 0.1072
# Test RMSE: 0.3252, Test MAE: 0.1501
# ---------------------------------
# Model saved at epoch 92 with val RMSE 0.2493
# Patience grace period: 32
# ---------------------------------
# Epoch 93/500
# Train RMSE: 0.2494
# Val RMSE: 0.2493, Val MAE: 0.1073
# Test RMSE: 0.3252, Test MAE: 0.1503
# ---------------------------------
# Model saved at epoch 93 with val RMSE 0.2493
# Patience grace period: 31
# ---------------------------------
# Epoch 94/500
# Train RMSE: 0.2494
# Val RMSE: 0.2493, Val MAE: 0.1074
# Test RMSE: 0.3250, Test MAE: 0.1504
# ---------------------------------
# Patience grace period: 29
# ---------------------------------
# Epoch 95/500
# Train RMSE: 0.2494
# Val RMSE: 0.2492, Val MAE: 0.1073
# Test RMSE: 0.3252, Test MAE: 0.1501
# ---------------------------------
# Model saved at epoch 95 with val RMSE 0.2492
# Patience grace period: 28
# ---------------------------------
# Epoch 96/500
# Train RMSE: 0.2493
# Val RMSE: 0.2493, Val MAE: 0.1079
# Test RMSE: 0.3243, Test MAE: 0.1505
# ---------------------------------
# Patience grace period: 26
# ---------------------------------
# Epoch 97/500
# Train RMSE: 0.2493
# Val RMSE: 0.2493, Val MAE: 0.1071
# Test RMSE: 0.3254, Test MAE: 0.1502
# ---------------------------------
# Patience grace period: 25
# ---------------------------------
# Epoch 98/500
# Train RMSE: 0.2493
# Val RMSE: 0.2493, Val MAE: 0.1064
# Test RMSE: 0.3263, Test MAE: 0.1498
# ---------------------------------
# Patience grace period: 23
# ---------------------------------
# Epoch 99/500
# Train RMSE: 0.2492
# Val RMSE: 0.2492, Val MAE: 0.1068
# Test RMSE: 0.3260, Test MAE: 0.1501
# ---------------------------------
# Model saved at epoch 99 with val RMSE 0.2492
# Patience grace period: 40
# ---------------------------------
# Epoch 100/500
# Train RMSE: 0.2492
# Val RMSE: 0.2492, Val MAE: 0.1071
# Test RMSE: 0.3253, Test MAE: 0.1505
# ---------------------------------
# Model saved at epoch 100 with val RMSE 0.2492
# Patience grace period: 39
# ---------------------------------
# Epoch 101/500
# Train RMSE: 0.2492
# Val RMSE: 0.2492, Val MAE: 0.1066
# Test RMSE: 0.3263, Test MAE: 0.1501
# ---------------------------------
# Patience grace period: 37
# ---------------------------------
# Epoch 102/500
# Train RMSE: 0.2492
# Val RMSE: 0.2492, Val MAE: 0.1072
# Test RMSE: 0.3255, Test MAE: 0.1504
# ---------------------------------
# Model saved at epoch 102 with val RMSE 0.2492
# Patience grace period: 36
# ---------------------------------
# Epoch 103/500
# Train RMSE: 0.2491
# Val RMSE: 0.2492, Val MAE: 0.1064
# Test RMSE: 0.3262, Test MAE: 0.1499
# ---------------------------------
# Model saved at epoch 103 with val RMSE 0.2492
# Patience grace period: 35
# ---------------------------------
# Epoch 104/500
# Train RMSE: 0.2491
# Val RMSE: 0.2492, Val MAE: 0.1065
# Test RMSE: 0.3258, Test MAE: 0.1500
# ---------------------------------
# Model saved at epoch 104 with val RMSE 0.2492
# Patience grace period: 34
# ---------------------------------
# Epoch 105/500
# Train RMSE: 0.2491
# Val RMSE: 0.2492, Val MAE: 0.1074
# Test RMSE: 0.3247, Test MAE: 0.1506
# ---------------------------------
# Patience grace period: 32
# ---------------------------------
# Epoch 106/500
# Train RMSE: 0.2491
# Val RMSE: 0.2492, Val MAE: 0.1071
# Test RMSE: 0.3255, Test MAE: 0.1505
# ---------------------------------
# Patience grace period: 31
# ---------------------------------
# Epoch 107/500
# Train RMSE: 0.2490
# Val RMSE: 0.2492, Val MAE: 0.1074
# Test RMSE: 0.3245, Test MAE: 0.1508
# ---------------------------------
# Patience grace period: 29
# ---------------------------------
# Epoch 108/500
# Train RMSE: 0.2490
# Val RMSE: 0.2492, Val MAE: 0.1068
# Test RMSE: 0.3259, Test MAE: 0.1502
# ---------------------------------
# Patience grace period: 28
# ---------------------------------
# Epoch 109/500
# Train RMSE: 0.2490
# Val RMSE: 0.2492, Val MAE: 0.1072
# Test RMSE: 0.3250, Test MAE: 0.1505
# ---------------------------------
# Patience grace period: 27
# ---------------------------------
# Epoch 110/500
# Train RMSE: 0.2490
# Val RMSE: 0.2491, Val MAE: 0.1069
# Test RMSE: 0.3251, Test MAE: 0.1503
# ---------------------------------
# Model saved at epoch 110 with val RMSE 0.2491
# Patience grace period: 40
# ---------------------------------
# Epoch 111/500
# Train RMSE: 0.2489
# Val RMSE: 0.2492, Val MAE: 0.1069
# Test RMSE: 0.3251, Test MAE: 0.1505
# ---------------------------------
# Patience grace period: 38
# ---------------------------------
# Epoch 112/500
# Train RMSE: 0.2489
# Val RMSE: 0.2491, Val MAE: 0.1068
# Test RMSE: 0.3255, Test MAE: 0.1504
# ---------------------------------
# Patience grace period: 37
# ---------------------------------
# Epoch 113/500
# Train RMSE: 0.2489
# Val RMSE: 0.2491, Val MAE: 0.1071
# Test RMSE: 0.3250, Test MAE: 0.1504
# ---------------------------------
# Patience grace period: 36
# ---------------------------------
# Epoch 114/500
# Train RMSE: 0.2489
# Val RMSE: 0.2491, Val MAE: 0.1073
# Test RMSE: 0.3252, Test MAE: 0.1506
# ---------------------------------
# Patience grace period: 34
# ---------------------------------
# Epoch 115/500
# Train RMSE: 0.2489
# Val RMSE: 0.2491, Val MAE: 0.1069
# Test RMSE: 0.3253, Test MAE: 0.1504
# ---------------------------------
# Patience grace period: 32
# ---------------------------------
# Epoch 116/500
# Train RMSE: 0.2488
# Val RMSE: 0.2491, Val MAE: 0.1071
# Test RMSE: 0.3249, Test MAE: 0.1505
# ---------------------------------
# Model saved at epoch 116 with val RMSE 0.2491
# Patience grace period: 31
# ---------------------------------
# Epoch 117/500
# Train RMSE: 0.2488
# Val RMSE: 0.2491, Val MAE: 0.1071
# Test RMSE: 0.3251, Test MAE: 0.1505
# ---------------------------------
# Patience grace period: 29
# ---------------------------------
# Epoch 118/500
# Train RMSE: 0.2488
# Val RMSE: 0.2491, Val MAE: 0.1067
# Test RMSE: 0.3256, Test MAE: 0.1501
# ---------------------------------
# Model saved at epoch 118 with val RMSE 0.2491
# Patience grace period: 28
# ---------------------------------
# Epoch 119/500
# Train RMSE: 0.2488
# Val RMSE: 0.2491, Val MAE: 0.1069
# Test RMSE: 0.3256, Test MAE: 0.1505
# ---------------------------------
# Patience grace period: 26
# ---------------------------------
# Epoch 120/500
# Train RMSE: 0.2488
# Val RMSE: 0.2490, Val MAE: 0.1067
# Test RMSE: 0.3257, Test MAE: 0.1502
# ---------------------------------
# Model saved at epoch 120 with val RMSE 0.2490
# Patience grace period: 25
# ---------------------------------
# Epoch 121/500
# Train RMSE: 0.2487
# Val RMSE: 0.2490, Val MAE: 0.1068
# Test RMSE: 0.3252, Test MAE: 0.1502
# ---------------------------------
# Model saved at epoch 121 with val RMSE 0.2490
# Patience grace period: 23
# ---------------------------------
# Epoch 122/500
# Train RMSE: 0.2487
# Val RMSE: 0.2491, Val MAE: 0.1067
# Test RMSE: 0.3259, Test MAE: 0.1504
# ---------------------------------
# Patience grace period: 21
# ---------------------------------
# Epoch 123/500
# Train RMSE: 0.2487
# Val RMSE: 0.2491, Val MAE: 0.1072
# Test RMSE: 0.3251, Test MAE: 0.1508
# ---------------------------------
# Patience grace period: 19
# ---------------------------------
# Epoch 124/500
# Train RMSE: 0.2487
# Val RMSE: 0.2490, Val MAE: 0.1068
# Test RMSE: 0.3257, Test MAE: 0.1504
# ---------------------------------
# Model saved at epoch 124 with val RMSE 0.2490
# Patience grace period: 18
# ---------------------------------
# Epoch 125/500
# Train RMSE: 0.2486
# Val RMSE: 0.2490, Val MAE: 0.1068
# Test RMSE: 0.3256, Test MAE: 0.1504
# ---------------------------------
# Patience grace period: 16
# ---------------------------------
# Epoch 126/500
# Train RMSE: 0.2486
# Val RMSE: 0.2490, Val MAE: 0.1071
# Test RMSE: 0.3247, Test MAE: 0.1506
# ---------------------------------
# Model saved at epoch 126 with val RMSE 0.2490
# Patience grace period: 15
# ---------------------------------
# Epoch 127/500
# Train RMSE: 0.2486
# Val RMSE: 0.2491, Val MAE: 0.1071
# Test RMSE: 0.3245, Test MAE: 0.1507
# ---------------------------------
# Patience grace period: 13
# ---------------------------------
# Epoch 128/500
# Train RMSE: 0.2486
# Val RMSE: 0.2490, Val MAE: 0.1070
# Test RMSE: 0.3247, Test MAE: 0.1506
# ---------------------------------
# Patience grace period: 12
# ---------------------------------
# Epoch 129/500
# Train RMSE: 0.2486
# Val RMSE: 0.2491, Val MAE: 0.1074
# Test RMSE: 0.3246, Test MAE: 0.1507
# ---------------------------------
# Patience grace period: 10
# ---------------------------------
# Epoch 130/500
# Train RMSE: 0.2485
# Val RMSE: 0.2490, Val MAE: 0.1071
# Test RMSE: 0.3248, Test MAE: 0.1506
# ---------------------------------
# Patience grace period: 9
# ---------------------------------
# Epoch 131/500
# Train RMSE: 0.2485
# Val RMSE: 0.2491, Val MAE: 0.1069
# Test RMSE: 0.3251, Test MAE: 0.1504
# ---------------------------------
# Patience grace period: 7
# ---------------------------------
# Epoch 132/500
# Train RMSE: 0.2485
# Val RMSE: 0.2490, Val MAE: 0.1068
# Test RMSE: 0.3258, Test MAE: 0.1502
# ---------------------------------
# Model saved at epoch 132 with val RMSE 0.2490
# Patience grace period: 40
# ---------------------------------
# Epoch 133/500
# Train RMSE: 0.2485
# Val RMSE: 0.2490, Val MAE: 0.1068
# Test RMSE: 0.3254, Test MAE: 0.1504
# ---------------------------------
# Patience grace period: 38
# ---------------------------------
# Epoch 134/500
# Train RMSE: 0.2485
# Val RMSE: 0.2490, Val MAE: 0.1063
# Test RMSE: 0.3257, Test MAE: 0.1499
# ---------------------------------
# Model saved at epoch 134 with val RMSE 0.2490
# Patience grace period: 37
# ---------------------------------
# Epoch 135/500
# Train RMSE: 0.2485
# Val RMSE: 0.2490, Val MAE: 0.1068
# Test RMSE: 0.3252, Test MAE: 0.1504
# ---------------------------------
# Patience grace period: 35
# ---------------------------------
# Epoch 136/500
# Train RMSE: 0.2484
# Val RMSE: 0.2490, Val MAE: 0.1068
# Test RMSE: 0.3251, Test MAE: 0.1506
# ---------------------------------
# Model saved at epoch 136 with val RMSE 0.2490
# Patience grace period: 34
# ---------------------------------
# Epoch 137/500
# Train RMSE: 0.2485
# Val RMSE: 0.2490, Val MAE: 0.1061
# Test RMSE: 0.3263, Test MAE: 0.1500
# ---------------------------------
# Patience grace period: 32
# ---------------------------------
# Epoch 138/500
# Train RMSE: 0.2484
# Val RMSE: 0.2490, Val MAE: 0.1062
# Test RMSE: 0.3262, Test MAE: 0.1503
# ---------------------------------
# Model saved at epoch 138 with val RMSE 0.2490
# Patience grace period: 31
# ---------------------------------
# Epoch 139/500
# Train RMSE: 0.2484
# Val RMSE: 0.2490, Val MAE: 0.1069
# Test RMSE: 0.3252, Test MAE: 0.1502
# ---------------------------------
# Patience grace period: 29
# ---------------------------------
# Epoch 140/500
# Train RMSE: 0.2484
# Val RMSE: 0.2490, Val MAE: 0.1070
# Test RMSE: 0.3252, Test MAE: 0.1508
# ---------------------------------
# Patience grace period: 28
# ---------------------------------
# Epoch 141/500
# Train RMSE: 0.2484
# Val RMSE: 0.2490, Val MAE: 0.1068
# Test RMSE: 0.3250, Test MAE: 0.1505
# ---------------------------------
# Model saved at epoch 141 with val RMSE 0.2490
# Patience grace period: 27
# ---------------------------------
# Epoch 142/500
# Train RMSE: 0.2483
# Val RMSE: 0.2490, Val MAE: 0.1066
# Test RMSE: 0.3254, Test MAE: 0.1503
# ---------------------------------
# Patience grace period: 25
# ---------------------------------
# Epoch 143/500
# Train RMSE: 0.2483
# Val RMSE: 0.2491, Val MAE: 0.1074
# Test RMSE: 0.3240, Test MAE: 0.1508
# ---------------------------------
# Patience grace period: 23
# ---------------------------------
# Epoch 144/500
# Train RMSE: 0.2483
# Val RMSE: 0.2490, Val MAE: 0.1061
# Test RMSE: 0.3260, Test MAE: 0.1501
# ---------------------------------
# Model saved at epoch 144 with val RMSE 0.2490
# Patience grace period: 22
# ---------------------------------
# Epoch 145/500
# Train RMSE: 0.2483
# Val RMSE: 0.2490, Val MAE: 0.1063
# Test RMSE: 0.3261, Test MAE: 0.1502
# ---------------------------------
# Patience grace period: 20
# ---------------------------------
# Epoch 146/500
# Train RMSE: 0.2483
# Val RMSE: 0.2490, Val MAE: 0.1064
# Test RMSE: 0.3259, Test MAE: 0.1502
# ---------------------------------
# Patience grace period: 19
# ---------------------------------
# Epoch 147/500
# Train RMSE: 0.2482
# Val RMSE: 0.2490, Val MAE: 0.1070
# Test RMSE: 0.3250, Test MAE: 0.1505
# ---------------------------------
# Patience grace period: 17
# ---------------------------------
# Epoch 148/500
# Train RMSE: 0.2482
# Val RMSE: 0.2490, Val MAE: 0.1071
# Test RMSE: 0.3246, Test MAE: 0.1506
# ---------------------------------
# Patience grace period: 15
# ---------------------------------
# Epoch 149/500
# Train RMSE: 0.2482
# Val RMSE: 0.2490, Val MAE: 0.1060
# Test RMSE: 0.3265, Test MAE: 0.1497
# ---------------------------------
# Patience grace period: 14
# ---------------------------------
# Epoch 150/500
# Train RMSE: 0.2482
# Val RMSE: 0.2490, Val MAE: 0.1068
# Test RMSE: 0.3252, Test MAE: 0.1502
# ---------------------------------
# Patience grace period: 12
# ---------------------------------
# Epoch 151/500
# Train RMSE: 0.2482
# Val RMSE: 0.2490, Val MAE: 0.1070
# Test RMSE: 0.3250, Test MAE: 0.1508
# ---------------------------------
# Patience grace period: 11
# ---------------------------------
# Epoch 152/500
# Train RMSE: 0.2482
# Val RMSE: 0.2491, Val MAE: 0.1074
# Test RMSE: 0.3240, Test MAE: 0.1510
# ---------------------------------
# Patience grace period: 9
# ---------------------------------
# Epoch 153/500
# Train RMSE: 0.2482
# Val RMSE: 0.2490, Val MAE: 0.1067
# Test RMSE: 0.3252, Test MAE: 0.1505
# ---------------------------------
# Patience grace period: 8
# ---------------------------------
# Epoch 154/500
# Train RMSE: 0.2481
# Val RMSE: 0.2490, Val MAE: 0.1067
# Test RMSE: 0.3252, Test MAE: 0.1503
# ---------------------------------
# Patience grace period: 7
# ---------------------------------
# Epoch 155/500
# Train RMSE: 0.2481
# Val RMSE: 0.2490, Val MAE: 0.1067
# Test RMSE: 0.3254, Test MAE: 0.1505
# ---------------------------------
# Patience grace period: 5
# ---------------------------------
# Epoch 156/500
# Train RMSE: 0.2481
# Val RMSE: 0.2490, Val MAE: 0.1070
# Test RMSE: 0.3246, Test MAE: 0.1508
# ---------------------------------
# Patience grace period: 4
# ---------------------------------
# Epoch 157/500
# Train RMSE: 0.2481
# Val RMSE: 0.2490, Val MAE: 0.1072
# Test RMSE: 0.3245, Test MAE: 0.1507
# ---------------------------------
# Patience grace period: 2
# ---------------------------------
# Epoch 158/500
# Train RMSE: 0.2481
# Val RMSE: 0.2489, Val MAE: 0.1066
# Test RMSE: 0.3253, Test MAE: 0.1503
# ---------------------------------
# Model saved at epoch 158 with val RMSE 0.2489
# Patience grace period: 1
# ---------------------------------
# Epoch 159/500
# Train RMSE: 0.2481
# Val RMSE: 0.2490, Val MAE: 0.1071
# Test RMSE: 0.3249, Test MAE: 0.1507
# ---------------------------------
# Patience grace period: -1
# Early stopping triggered at epoch 159
# Final Test RMSE: 0.3253, Final Test MAE: 0.1503
# <ipython-input-3-2a228d64b832>:126: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   self.model.load_state_dict(torch.load(os.path.join(save_dir, 'best_model.pth')))
# Pearson Corr: 0.7480124375392466
# Spearman Corr: 0.429039042858738
# p-rmse: 0.3253197303100398
#       rmse       mae  seed                             subtask    method  \
# 0  0.32532  0.150291     5  openproblems_bmmc_cite_phase2_mod2  original
#
#     pearson p_value_pearson  spearman p_value_spearman
# 0  0.748012          0.0000  0.429039           0.0000

# %%
config_hierachical_PROTEIN = {
    "subtask": "openproblems_bmmc_cite_phase2_mod2",
    "batch_size": 520,
    "act": "relu",
    "conv_flow": ["gat"],
    "agg_flow": [None],
    "device": "cuda",
    "learning_rate": 0.000064,
    "hidden_size": 280,
    "num_heads": 6,
    "n_neigbours": 20,
    "metric": "euclidean",
    "n_components": 1200,
    "dropout_rate": 0.2,
    "num_epochs": 500,
    "seed": 1,
    "es_patience": 40,
    "es_min_delta": 0.0001,
    "es_rate_threshold": 0.00002,
    "layer_dim_ex": 3,
    "verbose": True,
    "sample": True,
    "preprocessing_type": "None",
    "variant": "original",
    "num_clusters": 10
}

pipeline(**config_hierachical_PROTEIN)
# Out:
# [INFO][2025-04-16 05:51:12,239][dance][_load_raw_data] Loading /content/data/openproblems_bmmc_cite_phase2_mod2/openproblems_bmmc_cite_phase2_mod2.censor_dataset.output_train_mod1.h5ad
# Initializing pipeline...
# [INFO][2025-04-16 05:51:12,923][dance][_load_raw_data] Loading /content/data/openproblems_bmmc_cite_phase2_mod2/openproblems_bmmc_cite_phase2_mod2.censor_dataset.output_train_mod2.h5ad
# [INFO][2025-04-16 05:51:20,647][dance][_load_raw_data] Loading /content/data/openproblems_bmmc_cite_phase2_mod2/openproblems_bmmc_cite_phase2_mod2.censor_dataset.output_test_mod1.h5ad
# [INFO][2025-04-16 05:51:20,671][dance][_load_raw_data] Loading /content/data/openproblems_bmmc_cite_phase2_mod2/openproblems_bmmc_cite_phase2_mod2.censor_dataset.output_test_mod2.h5ad
# [INFO][2025-04-16 05:51:20,885][dance][_maybe_preprocess] Preprocessing done.
# /usr/local/lib/python3.11/dist-packages/mudata/_core/mudata.py:1531: FutureWarning: From 0.4 .update() will not pull obs/var columns from individual modalities by default anymore. Set mudata.set_options(pull_on_update=False) to adopt the new behaviour, which will become the default. Use new pull_obs/pull_var and push_obs/push_var methods for more flexibility.
#   self._update_attr("var", axis=0, join_common=join_common)
# /usr/local/lib/python3.11/dist-packages/mudata/_core/mudata.py:931: UserWarning: Cannot join columns with the same name because var_names are intersecting.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/mudata/_core/mudata.py:1429: FutureWarning: From 0.4 .update() will not pull obs/var columns from individual modalities by default anymore. Set mudata.set_options(pull_on_update=False) to adopt the new behaviour, which will become the default. Use new pull_obs/pull_var and push_obs/push_var methods for more flexibility.
#   self._update_attr("obs", axis=1, join_common=join_common)
# /usr/local/lib/python3.11/dist-packages/mudata/_core/mudata.py:1558: UserWarning: Modality names will be prepended to var_names since there are identical var_names in different modalities.
#   warnings.warn(
# [INFO][2025-04-16 05:51:27,886][dance][set_config_from_dict] Setting config 'feature_mod' to 'mod1'
# [INFO][2025-04-16 05:51:27,886][dance][set_config_from_dict] Setting config 'label_mod' to 'mod2'
# [INFO][2025-04-16 05:51:27,887][dance][load_data] Raw data loaded:
# Data object that wraps (.data):
# MuData object with n_obs × n_vars = 67175 × 14087
#   uns:	'dance_config'
#   2 modalities
#     mod1:	67175 x 134
#       obs:	'batch'
#       layers:	'counts'
#     mod2:	67175 x 13953
#       obs:	'batch'
#       layers:	'counts'
# [INFO][2025-04-16 05:51:28,017][dance][wrapped_func] Took 0:00:15.778875 to load and process data.
# Performing data processing using GraphCreator...
# Data processing using GraphCreator complete and saved.
# ---------------------------------
# Epoch 1/500
# Train RMSE: 0.3738
# Val RMSE: 0.3213, Val MAE: 0.1326
# Test RMSE: 0.3978, Test MAE: 0.1766
# ---------------------------------
# Model saved at epoch 1 with val RMSE 0.3213
# Patience grace period: 40
# ---------------------------------
# Epoch 2/500
# Train RMSE: 0.3260
# Val RMSE: 0.2942, Val MAE: 0.1259
# Test RMSE: 0.3696, Test MAE: 0.1669
# ---------------------------------
# Model saved at epoch 2 with val RMSE 0.2942
# Patience grace period: 40
# ---------------------------------
# Epoch 3/500
# Train RMSE: 0.3044
# Val RMSE: 0.2795, Val MAE: 0.1201
# Test RMSE: 0.3558, Test MAE: 0.1599
# ---------------------------------
# Model saved at epoch 3 with val RMSE 0.2795
# Patience grace period: 40
# ---------------------------------
# Epoch 4/500
# Train RMSE: 0.2914
# Val RMSE: 0.2725, Val MAE: 0.1174
# Test RMSE: 0.3495, Test MAE: 0.1571
# ---------------------------------
# Model saved at epoch 4 with val RMSE 0.2725
# Patience grace period: 40
# ---------------------------------
# Epoch 5/500
# Train RMSE: 0.2836
# Val RMSE: 0.2687, Val MAE: 0.1161
# Test RMSE: 0.3464, Test MAE: 0.1558
# ---------------------------------
# Model saved at epoch 5 with val RMSE 0.2687
# Patience grace period: 40
# ---------------------------------
# Epoch 6/500
# Train RMSE: 0.2779
# Val RMSE: 0.2658, Val MAE: 0.1145
# Test RMSE: 0.3438, Test MAE: 0.1541
# ---------------------------------
# Model saved at epoch 6 with val RMSE 0.2658
# Patience grace period: 40
# ---------------------------------
# Epoch 7/500
# Train RMSE: 0.2733
# Val RMSE: 0.2631, Val MAE: 0.1130
# Test RMSE: 0.3412, Test MAE: 0.1524
# ---------------------------------
# Model saved at epoch 7 with val RMSE 0.2631
# Patience grace period: 40
# ---------------------------------
# Epoch 8/500
# Train RMSE: 0.2695
# Val RMSE: 0.2610, Val MAE: 0.1115
# Test RMSE: 0.3395, Test MAE: 0.1509
# ---------------------------------
# Model saved at epoch 8 with val RMSE 0.2610
# Patience grace period: 40
# ---------------------------------
# Epoch 9/500
# Train RMSE: 0.2665
# Val RMSE: 0.2595, Val MAE: 0.1103
# Test RMSE: 0.3388, Test MAE: 0.1497
# ---------------------------------
# Model saved at epoch 9 with val RMSE 0.2595
# Patience grace period: 40
# ---------------------------------
# Epoch 10/500
# Train RMSE: 0.2642
# Val RMSE: 0.2583, Val MAE: 0.1093
# Test RMSE: 0.3380, Test MAE: 0.1490
# ---------------------------------
# Model saved at epoch 10 with val RMSE 0.2583
# Patience grace period: 40
# ---------------------------------
# Epoch 11/500
# Train RMSE: 0.2625
# Val RMSE: 0.2573, Val MAE: 0.1090
# Test RMSE: 0.3368, Test MAE: 0.1487
# ---------------------------------
# Model saved at epoch 11 with val RMSE 0.2573
# Patience grace period: 40
# ---------------------------------
# Epoch 12/500
# Train RMSE: 0.2613
# Val RMSE: 0.2562, Val MAE: 0.1094
# Test RMSE: 0.3346, Test MAE: 0.1489
# ---------------------------------
# Model saved at epoch 12 with val RMSE 0.2562
# Patience grace period: 40
# ---------------------------------
# Epoch 13/500
# Train RMSE: 0.2602
# Val RMSE: 0.2559, Val MAE: 0.1084
# Test RMSE: 0.3356, Test MAE: 0.1479
# ---------------------------------
# Model saved at epoch 13 with val RMSE 0.2559
# Patience grace period: 40
# ---------------------------------
# Epoch 14/500
# Train RMSE: 0.2594
# Val RMSE: 0.2555, Val MAE: 0.1077
# Test RMSE: 0.3353, Test MAE: 0.1474
# ---------------------------------
# Model saved at epoch 14 with val RMSE 0.2555
# Patience grace period: 40
# ---------------------------------
# Epoch 15/500
# Train RMSE: 0.2586
# Val RMSE: 0.2548, Val MAE: 0.1081
# Test RMSE: 0.3337, Test MAE: 0.1476
# ---------------------------------
# Model saved at epoch 15 with val RMSE 0.2548
# Patience grace period: 40
# ---------------------------------
# Epoch 16/500
# Train RMSE: 0.2581
# Val RMSE: 0.2544, Val MAE: 0.1080
# Test RMSE: 0.3331, Test MAE: 0.1476
# ---------------------------------
# Model saved at epoch 16 with val RMSE 0.2544
# Patience grace period: 40
# ---------------------------------
# Epoch 17/500
# Train RMSE: 0.2575
# Val RMSE: 0.2539, Val MAE: 0.1086
# Test RMSE: 0.3314, Test MAE: 0.1479
# ---------------------------------
# Model saved at epoch 17 with val RMSE 0.2539
# Patience grace period: 40
# ---------------------------------
# Epoch 18/500
# Train RMSE: 0.2571
# Val RMSE: 0.2537, Val MAE: 0.1080
# Test RMSE: 0.3316, Test MAE: 0.1477
# ---------------------------------
# Model saved at epoch 18 with val RMSE 0.2537
# Patience grace period: 40
# ---------------------------------
# Epoch 19/500
# Train RMSE: 0.2566
# Val RMSE: 0.2535, Val MAE: 0.1078
# Test RMSE: 0.3320, Test MAE: 0.1476
# ---------------------------------
# Model saved at epoch 19 with val RMSE 0.2535
# Patience grace period: 40
# ---------------------------------
# Epoch 20/500
# Train RMSE: 0.2563
# Val RMSE: 0.2533, Val MAE: 0.1076
# Test RMSE: 0.3316, Test MAE: 0.1475
# ---------------------------------
# Model saved at epoch 20 with val RMSE 0.2533
# Patience grace period: 40
# ---------------------------------
# Epoch 21/500
# Train RMSE: 0.2559
# Val RMSE: 0.2531, Val MAE: 0.1072
# Test RMSE: 0.3321, Test MAE: 0.1471
# ---------------------------------
# Model saved at epoch 21 with val RMSE 0.2531
# Patience grace period: 40
# ---------------------------------
# Epoch 22/500
# Train RMSE: 0.2556
# Val RMSE: 0.2528, Val MAE: 0.1076
# Test RMSE: 0.3308, Test MAE: 0.1475
# ---------------------------------
# Model saved at epoch 22 with val RMSE 0.2528
# Patience grace period: 40
# ---------------------------------
# Epoch 23/500
# Train RMSE: 0.2553
# Val RMSE: 0.2527, Val MAE: 0.1072
# Test RMSE: 0.3313, Test MAE: 0.1473
# ---------------------------------
# Model saved at epoch 23 with val RMSE 0.2527
# Patience grace period: 39
# ---------------------------------
# Epoch 24/500
# Train RMSE: 0.2550
# Val RMSE: 0.2524, Val MAE: 0.1074
# Test RMSE: 0.3304, Test MAE: 0.1473
# ---------------------------------
# Model saved at epoch 24 with val RMSE 0.2524
# Patience grace period: 40
# ---------------------------------
# Epoch 25/500
# Train RMSE: 0.2548
# Val RMSE: 0.2524, Val MAE: 0.1073
# Test RMSE: 0.3299, Test MAE: 0.1477
# ---------------------------------
# Model saved at epoch 25 with val RMSE 0.2524
# Patience grace period: 39
# ---------------------------------
# Epoch 26/500
# Train RMSE: 0.2546
# Val RMSE: 0.2522, Val MAE: 0.1077
# Test RMSE: 0.3297, Test MAE: 0.1479
# ---------------------------------
# Model saved at epoch 26 with val RMSE 0.2522
# Patience grace period: 40
# ---------------------------------
# Epoch 27/500
# Train RMSE: 0.2544
# Val RMSE: 0.2521, Val MAE: 0.1072
# Test RMSE: 0.3298, Test MAE: 0.1476
# ---------------------------------
# Model saved at epoch 27 with val RMSE 0.2521
# Patience grace period: 39
# ---------------------------------
# Epoch 28/500
# Train RMSE: 0.2542
# Val RMSE: 0.2521, Val MAE: 0.1068
# Test RMSE: 0.3303, Test MAE: 0.1475
# ---------------------------------
# Patience grace period: 37
# ---------------------------------
# Epoch 29/500
# Train RMSE: 0.2540
# Val RMSE: 0.2519, Val MAE: 0.1071
# Test RMSE: 0.3297, Test MAE: 0.1476
# ---------------------------------
# Model saved at epoch 29 with val RMSE 0.2519
# Patience grace period: 40
# ---------------------------------
# Epoch 30/500
# Train RMSE: 0.2538
# Val RMSE: 0.2518, Val MAE: 0.1075
# Test RMSE: 0.3291, Test MAE: 0.1480
# ---------------------------------
# Model saved at epoch 30 with val RMSE 0.2518
# Patience grace period: 40
# ---------------------------------
# Epoch 31/500
# Train RMSE: 0.2536
# Val RMSE: 0.2518, Val MAE: 0.1069
# Test RMSE: 0.3299, Test MAE: 0.1475
# ---------------------------------
# Patience grace period: 38
# ---------------------------------
# Epoch 32/500
# Train RMSE: 0.2535
# Val RMSE: 0.2516, Val MAE: 0.1074
# Test RMSE: 0.3287, Test MAE: 0.1481
# ---------------------------------
# Model saved at epoch 32 with val RMSE 0.2516
# Patience grace period: 40
# ---------------------------------
# Epoch 33/500
# Train RMSE: 0.2533
# Val RMSE: 0.2515, Val MAE: 0.1074
# Test RMSE: 0.3288, Test MAE: 0.1482
# ---------------------------------
# Model saved at epoch 33 with val RMSE 0.2515
# Patience grace period: 39
# ---------------------------------
# Epoch 34/500
# Train RMSE: 0.2532
# Val RMSE: 0.2515, Val MAE: 0.1074
# Test RMSE: 0.3289, Test MAE: 0.1482
# ---------------------------------
# Model saved at epoch 34 with val RMSE 0.2515
# Patience grace period: 40
# ---------------------------------
# Epoch 35/500
# Train RMSE: 0.2531
# Val RMSE: 0.2513, Val MAE: 0.1078
# Test RMSE: 0.3277, Test MAE: 0.1485
# ---------------------------------
# Model saved at epoch 35 with val RMSE 0.2513
# Patience grace period: 40
# ---------------------------------
# Epoch 36/500
# Train RMSE: 0.2529
# Val RMSE: 0.2513, Val MAE: 0.1075
# Test RMSE: 0.3280, Test MAE: 0.1484
# ---------------------------------
# Model saved at epoch 36 with val RMSE 0.2513
# Patience grace period: 38
# ---------------------------------
# Epoch 37/500
# Train RMSE: 0.2528
# Val RMSE: 0.2513, Val MAE: 0.1072
# Test RMSE: 0.3287, Test MAE: 0.1482
# ---------------------------------
# Patience grace period: 36
# ---------------------------------
# Epoch 38/500
# Train RMSE: 0.2527
# Val RMSE: 0.2512, Val MAE: 0.1073
# Test RMSE: 0.3285, Test MAE: 0.1483
# ---------------------------------
# Model saved at epoch 38 with val RMSE 0.2512
# Patience grace period: 35
# ---------------------------------
# Epoch 39/500
# Train RMSE: 0.2526
# Val RMSE: 0.2513, Val MAE: 0.1067
# Test RMSE: 0.3293, Test MAE: 0.1479
# ---------------------------------
# Patience grace period: 33
# ---------------------------------
# Epoch 40/500
# Train RMSE: 0.2524
# Val RMSE: 0.2511, Val MAE: 0.1075
# Test RMSE: 0.3277, Test MAE: 0.1485
# ---------------------------------
# Model saved at epoch 40 with val RMSE 0.2511
# Patience grace period: 40
# ---------------------------------
# Epoch 41/500
# Train RMSE: 0.2523
# Val RMSE: 0.2511, Val MAE: 0.1080
# Test RMSE: 0.3269, Test MAE: 0.1489
# ---------------------------------
# Model saved at epoch 41 with val RMSE 0.2511
# Patience grace period: 39
# ---------------------------------
# Epoch 42/500
# Train RMSE: 0.2522
# Val RMSE: 0.2511, Val MAE: 0.1073
# Test RMSE: 0.3281, Test MAE: 0.1485
# ---------------------------------
# Model saved at epoch 42 with val RMSE 0.2511
# Patience grace period: 37
# ---------------------------------
# Epoch 43/500
# Train RMSE: 0.2521
# Val RMSE: 0.2509, Val MAE: 0.1073
# Test RMSE: 0.3276, Test MAE: 0.1487
# ---------------------------------
# Model saved at epoch 43 with val RMSE 0.2509
# Patience grace period: 40
# ---------------------------------
# Epoch 44/500
# Train RMSE: 0.2520
# Val RMSE: 0.2509, Val MAE: 0.1075
# Test RMSE: 0.3273, Test MAE: 0.1487
# ---------------------------------
# Model saved at epoch 44 with val RMSE 0.2509
# Patience grace period: 39
# ---------------------------------
# Epoch 45/500
# Train RMSE: 0.2520
# Val RMSE: 0.2509, Val MAE: 0.1077
# Test RMSE: 0.3270, Test MAE: 0.1490
# ---------------------------------
# Model saved at epoch 45 with val RMSE 0.2509
# Patience grace period: 37
# ---------------------------------
# Epoch 46/500
# Train RMSE: 0.2518
# Val RMSE: 0.2508, Val MAE: 0.1077
# Test RMSE: 0.3269, Test MAE: 0.1490
# ---------------------------------
# Model saved at epoch 46 with val RMSE 0.2508
# Patience grace period: 40
# ---------------------------------
# Epoch 47/500
# Train RMSE: 0.2518
# Val RMSE: 0.2508, Val MAE: 0.1071
# Test RMSE: 0.3278, Test MAE: 0.1485
# ---------------------------------
# Patience grace period: 38
# ---------------------------------
# Epoch 48/500
# Train RMSE: 0.2517
# Val RMSE: 0.2507, Val MAE: 0.1078
# Test RMSE: 0.3265, Test MAE: 0.1491
# ---------------------------------
# Model saved at epoch 48 with val RMSE 0.2507
# Patience grace period: 37
# ---------------------------------
# Epoch 49/500
# Train RMSE: 0.2516
# Val RMSE: 0.2508, Val MAE: 0.1070
# Test RMSE: 0.3280, Test MAE: 0.1486
# ---------------------------------
# Patience grace period: 35
# ---------------------------------
# Epoch 50/500
# Train RMSE: 0.2515
# Val RMSE: 0.2507, Val MAE: 0.1072
# Test RMSE: 0.3274, Test MAE: 0.1488
# ---------------------------------
# Model saved at epoch 50 with val RMSE 0.2507
# Patience grace period: 40
# ---------------------------------
# Epoch 51/500
# Train RMSE: 0.2514
# Val RMSE: 0.2507, Val MAE: 0.1079
# Test RMSE: 0.3262, Test MAE: 0.1492
# ---------------------------------
# Model saved at epoch 51 with val RMSE 0.2507
# Patience grace period: 39
# ---------------------------------
# Epoch 52/500
# Train RMSE: 0.2514
# Val RMSE: 0.2507, Val MAE: 0.1071
# Test RMSE: 0.3274, Test MAE: 0.1488
# ---------------------------------
# Patience grace period: 37
# ---------------------------------
# Epoch 53/500
# Train RMSE: 0.2513
# Val RMSE: 0.2507, Val MAE: 0.1075
# Test RMSE: 0.3265, Test MAE: 0.1491
# ---------------------------------
# Patience grace period: 35
# ---------------------------------
# Epoch 54/500
# Train RMSE: 0.2512
# Val RMSE: 0.2506, Val MAE: 0.1077
# Test RMSE: 0.3260, Test MAE: 0.1492
# ---------------------------------
# Model saved at epoch 54 with val RMSE 0.2506
# Patience grace period: 40
# ---------------------------------
# Epoch 55/500
# Train RMSE: 0.2511
# Val RMSE: 0.2506, Val MAE: 0.1075
# Test RMSE: 0.3265, Test MAE: 0.1493
# ---------------------------------
# Patience grace period: 38
# ---------------------------------
# Epoch 56/500
# Train RMSE: 0.2511
# Val RMSE: 0.2506, Val MAE: 0.1078
# Test RMSE: 0.3259, Test MAE: 0.1495
# ---------------------------------
# Patience grace period: 36
# ---------------------------------
# Epoch 57/500
# Train RMSE: 0.2510
# Val RMSE: 0.2505, Val MAE: 0.1072
# Test RMSE: 0.3267, Test MAE: 0.1488
# ---------------------------------
# Model saved at epoch 57 with val RMSE 0.2505
# Patience grace period: 35
# ---------------------------------
# Epoch 58/500
# Train RMSE: 0.2510
# Val RMSE: 0.2505, Val MAE: 0.1080
# Test RMSE: 0.3252, Test MAE: 0.1496
# ---------------------------------
# Model saved at epoch 58 with val RMSE 0.2505
# Patience grace period: 40
# ---------------------------------
# Epoch 59/500
# Train RMSE: 0.2509
# Val RMSE: 0.2505, Val MAE: 0.1075
# Test RMSE: 0.3261, Test MAE: 0.1494
# ---------------------------------
# Patience grace period: 38
# ---------------------------------
# Epoch 60/500
# Train RMSE: 0.2508
# Val RMSE: 0.2505, Val MAE: 0.1081
# Test RMSE: 0.3248, Test MAE: 0.1498
# ---------------------------------
# Patience grace period: 36
# ---------------------------------
# Epoch 61/500
# Train RMSE: 0.2508
# Val RMSE: 0.2505, Val MAE: 0.1078
# Test RMSE: 0.3256, Test MAE: 0.1496
# ---------------------------------
# Model saved at epoch 61 with val RMSE 0.2505
# Patience grace period: 35
# ---------------------------------
# Epoch 62/500
# Train RMSE: 0.2508
# Val RMSE: 0.2505, Val MAE: 0.1075
# Test RMSE: 0.3262, Test MAE: 0.1492
# ---------------------------------
# Model saved at epoch 62 with val RMSE 0.2505
# Patience grace period: 34
# ---------------------------------
# Epoch 63/500
# Train RMSE: 0.2507
# Val RMSE: 0.2504, Val MAE: 0.1076
# Test RMSE: 0.3258, Test MAE: 0.1494
# ---------------------------------
# Model saved at epoch 63 with val RMSE 0.2504
# Patience grace period: 33
# ---------------------------------
# Epoch 64/500
# Train RMSE: 0.2506
# Val RMSE: 0.2504, Val MAE: 0.1069
# Test RMSE: 0.3270, Test MAE: 0.1489
# ---------------------------------
# Model saved at epoch 64 with val RMSE 0.2504
# Patience grace period: 32
# ---------------------------------
# Epoch 65/500
# Train RMSE: 0.2506
# Val RMSE: 0.2505, Val MAE: 0.1066
# Test RMSE: 0.3273, Test MAE: 0.1488
# ---------------------------------
# Patience grace period: 30
# ---------------------------------
# Epoch 66/500
# Train RMSE: 0.2505
# Val RMSE: 0.2503, Val MAE: 0.1075
# Test RMSE: 0.3261, Test MAE: 0.1494
# ---------------------------------
# Model saved at epoch 66 with val RMSE 0.2503
# Patience grace period: 40
# ---------------------------------
# Epoch 67/500
# Train RMSE: 0.2505
# Val RMSE: 0.2503, Val MAE: 0.1073
# Test RMSE: 0.3259, Test MAE: 0.1494
# ---------------------------------
# Model saved at epoch 67 with val RMSE 0.2503
# Patience grace period: 39
# ---------------------------------
# Epoch 68/500
# Train RMSE: 0.2504
# Val RMSE: 0.2503, Val MAE: 0.1071
# Test RMSE: 0.3267, Test MAE: 0.1494
# ---------------------------------
# Patience grace period: 37
# ---------------------------------
# Epoch 69/500
# Train RMSE: 0.2503
# Val RMSE: 0.2503, Val MAE: 0.1078
# Test RMSE: 0.3253, Test MAE: 0.1497
# ---------------------------------
# Patience grace period: 36
# ---------------------------------
# Epoch 70/500
# Train RMSE: 0.2503
# Val RMSE: 0.2503, Val MAE: 0.1079
# Test RMSE: 0.3250, Test MAE: 0.1499
# ---------------------------------
# Patience grace period: 34
# ---------------------------------
# Epoch 71/500
# Train RMSE: 0.2503
# Val RMSE: 0.2503, Val MAE: 0.1073
# Test RMSE: 0.3259, Test MAE: 0.1494
# ---------------------------------
# Model saved at epoch 71 with val RMSE 0.2503
# Patience grace period: 33
# ---------------------------------
# Epoch 72/500
# Train RMSE: 0.2502
# Val RMSE: 0.2502, Val MAE: 0.1076
# Test RMSE: 0.3256, Test MAE: 0.1496
# ---------------------------------
# Model saved at epoch 72 with val RMSE 0.2502
# Patience grace period: 40
# ---------------------------------
# Epoch 73/500
# Train RMSE: 0.2502
# Val RMSE: 0.2502, Val MAE: 0.1069
# Test RMSE: 0.3265, Test MAE: 0.1492
# ---------------------------------
# Model saved at epoch 73 with val RMSE 0.2502
# Patience grace period: 38
# ---------------------------------
# Epoch 74/500
# Train RMSE: 0.2501
# Val RMSE: 0.2503, Val MAE: 0.1078
# Test RMSE: 0.3250, Test MAE: 0.1497
# ---------------------------------
# Patience grace period: 36
# ---------------------------------
# Epoch 75/500
# Train RMSE: 0.2501
# Val RMSE: 0.2502, Val MAE: 0.1072
# Test RMSE: 0.3258, Test MAE: 0.1494
# ---------------------------------
# Model saved at epoch 75 with val RMSE 0.2502
# Patience grace period: 35
# ---------------------------------
# Epoch 76/500
# Train RMSE: 0.2500
# Val RMSE: 0.2502, Val MAE: 0.1075
# Test RMSE: 0.3254, Test MAE: 0.1496
# ---------------------------------
# Patience grace period: 33
# ---------------------------------
# Epoch 77/500
# Train RMSE: 0.2500
# Val RMSE: 0.2502, Val MAE: 0.1079
# Test RMSE: 0.3246, Test MAE: 0.1499
# ---------------------------------
# Patience grace period: 32
# ---------------------------------
# Epoch 78/500
# Train RMSE: 0.2500
# Val RMSE: 0.2502, Val MAE: 0.1070
# Test RMSE: 0.3265, Test MAE: 0.1493
# ---------------------------------
# Patience grace period: 30
# ---------------------------------
# Epoch 79/500
# Train RMSE: 0.2499
# Val RMSE: 0.2502, Val MAE: 0.1078
# Test RMSE: 0.3251, Test MAE: 0.1498
# ---------------------------------
# Patience grace period: 29
# ---------------------------------
# Epoch 80/500
# Train RMSE: 0.2499
# Val RMSE: 0.2502, Val MAE: 0.1072
# Test RMSE: 0.3258, Test MAE: 0.1495
# ---------------------------------
# Model saved at epoch 80 with val RMSE 0.2502
# Patience grace period: 28
# ---------------------------------
# Epoch 81/500
# Train RMSE: 0.2498
# Val RMSE: 0.2502, Val MAE: 0.1072
# Test RMSE: 0.3253, Test MAE: 0.1495
# ---------------------------------
# Patience grace period: 26
# ---------------------------------
# Epoch 82/500
# Train RMSE: 0.2498
# Val RMSE: 0.2501, Val MAE: 0.1071
# Test RMSE: 0.3256, Test MAE: 0.1494
# ---------------------------------
# Model saved at epoch 82 with val RMSE 0.2501
# Patience grace period: 40
# ---------------------------------
# Epoch 83/500
# Train RMSE: 0.2498
# Val RMSE: 0.2501, Val MAE: 0.1075
# Test RMSE: 0.3250, Test MAE: 0.1498
# ---------------------------------
# Patience grace period: 38
# ---------------------------------
# Epoch 84/500
# Train RMSE: 0.2498
# Val RMSE: 0.2501, Val MAE: 0.1075
# Test RMSE: 0.3250, Test MAE: 0.1499
# ---------------------------------
# Patience grace period: 36
# ---------------------------------
# Epoch 85/500
# Train RMSE: 0.2497
# Val RMSE: 0.2501, Val MAE: 0.1071
# Test RMSE: 0.3254, Test MAE: 0.1495
# ---------------------------------
# Patience grace period: 35
# ---------------------------------
# Epoch 86/500
# Train RMSE: 0.2497
# Val RMSE: 0.2501, Val MAE: 0.1071
# Test RMSE: 0.3256, Test MAE: 0.1494
# ---------------------------------
# Patience grace period: 33
# ---------------------------------
# Epoch 87/500
# Train RMSE: 0.2496
# Val RMSE: 0.2500, Val MAE: 0.1074
# Test RMSE: 0.3252, Test MAE: 0.1497
# ---------------------------------
# Model saved at epoch 87 with val RMSE 0.2500
# Patience grace period: 32
# ---------------------------------
# Epoch 88/500
# Train RMSE: 0.2496
# Val RMSE: 0.2502, Val MAE: 0.1073
# Test RMSE: 0.3254, Test MAE: 0.1498
# ---------------------------------
# Patience grace period: 30
# ---------------------------------
# Epoch 89/500
# Train RMSE: 0.2496
# Val RMSE: 0.2500, Val MAE: 0.1069
# Test RMSE: 0.3255, Test MAE: 0.1495
# ---------------------------------
# Patience grace period: 29
# ---------------------------------
# Epoch 90/500
# Train RMSE: 0.2495
# Val RMSE: 0.2500, Val MAE: 0.1071
# Test RMSE: 0.3257, Test MAE: 0.1497
# ---------------------------------
# Patience grace period: 28
# ---------------------------------
# Epoch 91/500
# Train RMSE: 0.2495
# Val RMSE: 0.2500, Val MAE: 0.1069
# Test RMSE: 0.3254, Test MAE: 0.1495
# ---------------------------------
# Model saved at epoch 91 with val RMSE 0.2500
# Patience grace period: 40
# ---------------------------------
# Epoch 92/500
# Train RMSE: 0.2495
# Val RMSE: 0.2500, Val MAE: 0.1076
# Test RMSE: 0.3245, Test MAE: 0.1501
# ---------------------------------
# Patience grace period: 38
# ---------------------------------
# Epoch 93/500
# Train RMSE: 0.2494
# Val RMSE: 0.2499, Val MAE: 0.1072
# Test RMSE: 0.3250, Test MAE: 0.1498
# ---------------------------------
# Model saved at epoch 93 with val RMSE 0.2499
# Patience grace period: 37
# ---------------------------------
# Epoch 94/500
# Train RMSE: 0.2495
# Val RMSE: 0.2500, Val MAE: 0.1072
# Test RMSE: 0.3254, Test MAE: 0.1499
# ---------------------------------
# Patience grace period: 35
# ---------------------------------
# Epoch 95/500
# Train RMSE: 0.2494
# Val RMSE: 0.2501, Val MAE: 0.1076
# Test RMSE: 0.3248, Test MAE: 0.1501
# ---------------------------------
# Patience grace period: 33
# ---------------------------------
# Epoch 96/500
# Train RMSE: 0.2494
# Val RMSE: 0.2500, Val MAE: 0.1074
# Test RMSE: 0.3248, Test MAE: 0.1500
# ---------------------------------
# Patience grace period: 32
# ---------------------------------
# Epoch 97/500
# Train RMSE: 0.2493
# Val RMSE: 0.2500, Val MAE: 0.1076
# Test RMSE: 0.3247, Test MAE: 0.1500
# ---------------------------------
# Patience grace period: 31
# ---------------------------------
# Epoch 98/500
# Train RMSE: 0.2493
# Val RMSE: 0.2500, Val MAE: 0.1070
# Test RMSE: 0.3257, Test MAE: 0.1495
# ---------------------------------
# Patience grace period: 30
# ---------------------------------
# Epoch 99/500
# Train RMSE: 0.2493
# Val RMSE: 0.2500, Val MAE: 0.1074
# Test RMSE: 0.3245, Test MAE: 0.1500
# ---------------------------------
# Patience grace period: 28
# ---------------------------------
# Epoch 100/500
# Train RMSE: 0.2492
# Val RMSE: 0.2499, Val MAE: 0.1067
# Test RMSE: 0.3261, Test MAE: 0.1494
# ---------------------------------
# Model saved at epoch 100 with val RMSE 0.2499
# Patience grace period: 27
# ---------------------------------
# Epoch 101/500
# Train RMSE: 0.2492
# Val RMSE: 0.2499, Val MAE: 0.1071
# Test RMSE: 0.3254, Test MAE: 0.1498
# ---------------------------------
# Patience grace period: 25
# ---------------------------------
# Epoch 102/500
# Train RMSE: 0.2492
# Val RMSE: 0.2499, Val MAE: 0.1071
# Test RMSE: 0.3252, Test MAE: 0.1497
# ---------------------------------
# Model saved at epoch 102 with val RMSE 0.2499
# Patience grace period: 24
# ---------------------------------
# Epoch 103/500
# Train RMSE: 0.2492
# Val RMSE: 0.2500, Val MAE: 0.1068
# Test RMSE: 0.3254, Test MAE: 0.1497
# ---------------------------------
# Patience grace period: 22
# ---------------------------------
# Epoch 104/500
# Train RMSE: 0.2491
# Val RMSE: 0.2500, Val MAE: 0.1072
# Test RMSE: 0.3249, Test MAE: 0.1499
# ---------------------------------
# Patience grace period: 20
# ---------------------------------
# Epoch 105/500
# Train RMSE: 0.2491
# Val RMSE: 0.2499, Val MAE: 0.1063
# Test RMSE: 0.3265, Test MAE: 0.1490
# ---------------------------------
# Model saved at epoch 105 with val RMSE 0.2499
# Patience grace period: 19
# ---------------------------------
# Epoch 106/500
# Train RMSE: 0.2491
# Val RMSE: 0.2499, Val MAE: 0.1072
# Test RMSE: 0.3248, Test MAE: 0.1500
# ---------------------------------
# Patience grace period: 17
# ---------------------------------
# Epoch 107/500
# Train RMSE: 0.2491
# Val RMSE: 0.2499, Val MAE: 0.1069
# Test RMSE: 0.3255, Test MAE: 0.1498
# ---------------------------------
# Patience grace period: 16
# ---------------------------------
# Epoch 108/500
# Train RMSE: 0.2490
# Val RMSE: 0.2499, Val MAE: 0.1071
# Test RMSE: 0.3252, Test MAE: 0.1499
# ---------------------------------
# Model saved at epoch 108 with val RMSE 0.2499
# Patience grace period: 40
# ---------------------------------
# Epoch 109/500
# Train RMSE: 0.2490
# Val RMSE: 0.2499, Val MAE: 0.1067
# Test RMSE: 0.3256, Test MAE: 0.1495
# ---------------------------------
# Patience grace period: 38
# ---------------------------------
# Epoch 110/500
# Train RMSE: 0.2490
# Val RMSE: 0.2500, Val MAE: 0.1064
# Test RMSE: 0.3265, Test MAE: 0.1494
# ---------------------------------
# Patience grace period: 36
# ---------------------------------
# Epoch 111/500
# Train RMSE: 0.2490
# Val RMSE: 0.2499, Val MAE: 0.1070
# Test RMSE: 0.3257, Test MAE: 0.1497
# ---------------------------------
# Patience grace period: 35
# ---------------------------------
# Epoch 112/500
# Train RMSE: 0.2489
# Val RMSE: 0.2500, Val MAE: 0.1076
# Test RMSE: 0.3247, Test MAE: 0.1504
# ---------------------------------
# Patience grace period: 33
# ---------------------------------
# Epoch 113/500
# Train RMSE: 0.2489
# Val RMSE: 0.2500, Val MAE: 0.1067
# Test RMSE: 0.3258, Test MAE: 0.1498
# ---------------------------------
# Patience grace period: 32
# ---------------------------------
# Epoch 114/500
# Train RMSE: 0.2489
# Val RMSE: 0.2499, Val MAE: 0.1069
# Test RMSE: 0.3251, Test MAE: 0.1498
# ---------------------------------
# Patience grace period: 31
# ---------------------------------
# Epoch 115/500
# Train RMSE: 0.2489
# Val RMSE: 0.2499, Val MAE: 0.1069
# Test RMSE: 0.3252, Test MAE: 0.1498
# ---------------------------------
# Model saved at epoch 115 with val RMSE 0.2499
# Patience grace period: 30
# ---------------------------------
# Epoch 116/500
# Train RMSE: 0.2488
# Val RMSE: 0.2499, Val MAE: 0.1064
# Test RMSE: 0.3265, Test MAE: 0.1493
# ---------------------------------
# Patience grace period: 28
# ---------------------------------
# Epoch 117/500
# Train RMSE: 0.2488
# Val RMSE: 0.2499, Val MAE: 0.1069
# Test RMSE: 0.3258, Test MAE: 0.1498
# ---------------------------------
# Patience grace period: 26
# ---------------------------------
# Epoch 118/500
# Train RMSE: 0.2488
# Val RMSE: 0.2499, Val MAE: 0.1075
# Test RMSE: 0.3244, Test MAE: 0.1504
# ---------------------------------
# Patience grace period: 25
# ---------------------------------
# Epoch 119/500
# Train RMSE: 0.2488
# Val RMSE: 0.2499, Val MAE: 0.1073
# Test RMSE: 0.3248, Test MAE: 0.1503
# ---------------------------------
# Patience grace period: 23
# ---------------------------------
# Epoch 120/500
# Train RMSE: 0.2488
# Val RMSE: 0.2499, Val MAE: 0.1072
# Test RMSE: 0.3246, Test MAE: 0.1502
# ---------------------------------
# Patience grace period: 22
# ---------------------------------
# Epoch 121/500
# Train RMSE: 0.2487
# Val RMSE: 0.2499, Val MAE: 0.1066
# Test RMSE: 0.3258, Test MAE: 0.1496
# ---------------------------------
# Patience grace period: 21
# ---------------------------------
# Epoch 122/500
# Train RMSE: 0.2487
# Val RMSE: 0.2500, Val MAE: 0.1075
# Test RMSE: 0.3242, Test MAE: 0.1504
# ---------------------------------
# Patience grace period: 19
# ---------------------------------
# Epoch 123/500
# Train RMSE: 0.2487
# Val RMSE: 0.2499, Val MAE: 0.1070
# Test RMSE: 0.3251, Test MAE: 0.1499
# ---------------------------------
# Patience grace period: 18
# ---------------------------------
# Epoch 124/500
# Train RMSE: 0.2487
# Val RMSE: 0.2499, Val MAE: 0.1074
# Test RMSE: 0.3243, Test MAE: 0.1502
# ---------------------------------
# Patience grace period: 16
# ---------------------------------
# Epoch 125/500
# Train RMSE: 0.2487
# Val RMSE: 0.2499, Val MAE: 0.1071
# Test RMSE: 0.3248, Test MAE: 0.1499
# ---------------------------------
# Patience grace period: 15
# ---------------------------------
# Epoch 126/500
# Train RMSE: 0.2486
# Val RMSE: 0.2499, Val MAE: 0.1075
# Test RMSE: 0.3245, Test MAE: 0.1504
# ---------------------------------
# Patience grace period: 13
# ---------------------------------
# Epoch 127/500
# Train RMSE: 0.2486
# Val RMSE: 0.2499, Val MAE: 0.1074
# Test RMSE: 0.3244, Test MAE: 0.1501
# ---------------------------------
# Patience grace period: 11
# ---------------------------------
# Epoch 128/500
# Train RMSE: 0.2486
# Val RMSE: 0.2498, Val MAE: 0.1066
# Test RMSE: 0.3260, Test MAE: 0.1497
# ---------------------------------
# Model saved at epoch 128 with val RMSE 0.2498
# Patience grace period: 10
# ---------------------------------
# Epoch 129/500
# Train RMSE: 0.2486
# Val RMSE: 0.2498, Val MAE: 0.1072
# Test RMSE: 0.3251, Test MAE: 0.1499
# ---------------------------------
# Model saved at epoch 129 with val RMSE 0.2498
# Patience grace period: 9
# ---------------------------------
# Epoch 130/500
# Train RMSE: 0.2486
# Val RMSE: 0.2499, Val MAE: 0.1065
# Test RMSE: 0.3263, Test MAE: 0.1496
# ---------------------------------
# Patience grace period: 7
# ---------------------------------
# Epoch 131/500
# Train RMSE: 0.2485
# Val RMSE: 0.2499, Val MAE: 0.1065
# Test RMSE: 0.3264, Test MAE: 0.1499
# ---------------------------------
# Patience grace period: 6
# ---------------------------------
# Epoch 132/500
# Train RMSE: 0.2485
# Val RMSE: 0.2499, Val MAE: 0.1062
# Test RMSE: 0.3270, Test MAE: 0.1493
# ---------------------------------
# Patience grace period: 4
# ---------------------------------
# Epoch 133/500
# Train RMSE: 0.2485
# Val RMSE: 0.2498, Val MAE: 0.1068
# Test RMSE: 0.3255, Test MAE: 0.1497
# ---------------------------------
# Patience grace period: 3
# ---------------------------------
# Epoch 134/500
# Train RMSE: 0.2485
# Val RMSE: 0.2499, Val MAE: 0.1063
# Test RMSE: 0.3268, Test MAE: 0.1496
# ---------------------------------
# Patience grace period: 1
# ---------------------------------
# Epoch 135/500
# Train RMSE: 0.2485
# Val RMSE: 0.2499, Val MAE: 0.1070
# Test RMSE: 0.3253, Test MAE: 0.1500
# ---------------------------------
# Patience grace period: -1
# Early stopping triggered at epoch 135
# Final Test RMSE: 0.3251, Final Test MAE: 0.1499
# <ipython-input-3-2a228d64b832>:126: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   self.model.load_state_dict(torch.load(os.path.join(save_dir, 'best_model.pth')))
# Pearson Corr: 0.7476671583637816
# Spearman Corr: 0.42951605709159774
# p-rmse: 0.32510150094708123
#        rmse       mae  seed                             subtask    method  \
# 0  0.325102  0.149909     1  openproblems_bmmc_cite_phase2_mod2  original
#
#     pearson p_value_pearson  spearman p_value_spearman
# 0  0.747667          0.0000  0.429516           0.0000
# ---------------------------------
# Epoch 1/500
# Train RMSE: 0.3746
# Val RMSE: 0.3228, Val MAE: 0.1327
# Test RMSE: 0.3994, Test MAE: 0.1769
# ---------------------------------
# Model saved at epoch 1 with val RMSE 0.3228
# Patience grace period: 40
# ---------------------------------
# Epoch 2/500
# Train RMSE: 0.3274
# Val RMSE: 0.2950, Val MAE: 0.1275
# Test RMSE: 0.3692, Test MAE: 0.1685
# ---------------------------------
# Model saved at epoch 2 with val RMSE 0.2950
# Patience grace period: 40
# ---------------------------------
# Epoch 3/500
# Train RMSE: 0.3057
# Val RMSE: 0.2805, Val MAE: 0.1207
# Test RMSE: 0.3563, Test MAE: 0.1609
# ---------------------------------
# Model saved at epoch 3 with val RMSE 0.2805
# Patience grace period: 40
# ---------------------------------
# Epoch 4/500
# Train RMSE: 0.2926
# Val RMSE: 0.2735, Val MAE: 0.1175
# Test RMSE: 0.3506, Test MAE: 0.1575
# ---------------------------------
# Model saved at epoch 4 with val RMSE 0.2735
# Patience grace period: 40
# ---------------------------------
# Epoch 5/500
# Train RMSE: 0.2844
# Val RMSE: 0.2693, Val MAE: 0.1159
# Test RMSE: 0.3468, Test MAE: 0.1556
# ---------------------------------
# Model saved at epoch 5 with val RMSE 0.2693
# Patience grace period: 40
# ---------------------------------
# Epoch 6/500
# Train RMSE: 0.2784
# Val RMSE: 0.2659, Val MAE: 0.1145
# Test RMSE: 0.3433, Test MAE: 0.1535
# ---------------------------------
# Model saved at epoch 6 with val RMSE 0.2659
# Patience grace period: 40
# ---------------------------------
# Epoch 7/500
# Train RMSE: 0.2736
# Val RMSE: 0.2632, Val MAE: 0.1131
# Test RMSE: 0.3403, Test MAE: 0.1518
# ---------------------------------
# Model saved at epoch 7 with val RMSE 0.2632
# Patience grace period: 40
# ---------------------------------
# Epoch 8/500
# Train RMSE: 0.2698
# Val RMSE: 0.2609, Val MAE: 0.1121
# Test RMSE: 0.3380, Test MAE: 0.1505
# ---------------------------------
# Model saved at epoch 8 with val RMSE 0.2609
# Patience grace period: 40
# ---------------------------------
# Epoch 9/500
# Train RMSE: 0.2667
# Val RMSE: 0.2595, Val MAE: 0.1103
# Test RMSE: 0.3379, Test MAE: 0.1489
# ---------------------------------
# Model saved at epoch 9 with val RMSE 0.2595
# Patience grace period: 40
# ---------------------------------
# Epoch 10/500
# Train RMSE: 0.2644
# Val RMSE: 0.2583, Val MAE: 0.1094
# Test RMSE: 0.3377, Test MAE: 0.1484
# ---------------------------------
# Model saved at epoch 10 with val RMSE 0.2583
# Patience grace period: 40
# ---------------------------------
# Epoch 11/500
# Train RMSE: 0.2626
# Val RMSE: 0.2569, Val MAE: 0.1096
# Test RMSE: 0.3355, Test MAE: 0.1484
# ---------------------------------
# Model saved at epoch 11 with val RMSE 0.2569
# Patience grace period: 40
# ---------------------------------
# Epoch 12/500
# Train RMSE: 0.2613
# Val RMSE: 0.2562, Val MAE: 0.1090
# Test RMSE: 0.3351, Test MAE: 0.1482
# ---------------------------------
# Model saved at epoch 12 with val RMSE 0.2562
# Patience grace period: 40
# ---------------------------------
# Epoch 13/500
# Train RMSE: 0.2602
# Val RMSE: 0.2557, Val MAE: 0.1080
# Test RMSE: 0.3355, Test MAE: 0.1473
# ---------------------------------
# Model saved at epoch 13 with val RMSE 0.2557
# Patience grace period: 40
# ---------------------------------
# Epoch 14/500
# Train RMSE: 0.2594
# Val RMSE: 0.2553, Val MAE: 0.1076
# Test RMSE: 0.3355, Test MAE: 0.1470
# ---------------------------------
# Model saved at epoch 14 with val RMSE 0.2553
# Patience grace period: 40
# ---------------------------------
# Epoch 15/500
# Train RMSE: 0.2587
# Val RMSE: 0.2546, Val MAE: 0.1083
# Test RMSE: 0.3332, Test MAE: 0.1475
# ---------------------------------
# Model saved at epoch 15 with val RMSE 0.2546
# Patience grace period: 40
# ---------------------------------
# Epoch 16/500
# Train RMSE: 0.2581
# Val RMSE: 0.2544, Val MAE: 0.1074
# Test RMSE: 0.3337, Test MAE: 0.1468
# ---------------------------------
# Model saved at epoch 16 with val RMSE 0.2544
# Patience grace period: 40
# ---------------------------------
# Epoch 17/500
# Train RMSE: 0.2575
# Val RMSE: 0.2541, Val MAE: 0.1072
# Test RMSE: 0.3333, Test MAE: 0.1468
# ---------------------------------
# Model saved at epoch 17 with val RMSE 0.2541
# Patience grace period: 40
# ---------------------------------
# Epoch 18/500
# Train RMSE: 0.2571
# Val RMSE: 0.2537, Val MAE: 0.1075
# Test RMSE: 0.3324, Test MAE: 0.1471
# ---------------------------------
# Model saved at epoch 18 with val RMSE 0.2537
# Patience grace period: 40
# ---------------------------------
# Epoch 19/500
# Train RMSE: 0.2567
# Val RMSE: 0.2533, Val MAE: 0.1079
# Test RMSE: 0.3312, Test MAE: 0.1472
# ---------------------------------
# Model saved at epoch 19 with val RMSE 0.2533
# Patience grace period: 40
# ---------------------------------
# Epoch 20/500
# Train RMSE: 0.2563
# Val RMSE: 0.2532, Val MAE: 0.1075
# Test RMSE: 0.3320, Test MAE: 0.1470
# ---------------------------------
# Model saved at epoch 20 with val RMSE 0.2532
# Patience grace period: 39
# ---------------------------------
# Epoch 21/500
# Train RMSE: 0.2560
# Val RMSE: 0.2530, Val MAE: 0.1072
# Test RMSE: 0.3319, Test MAE: 0.1469
# ---------------------------------
# Model saved at epoch 21 with val RMSE 0.2530
# Patience grace period: 40
# ---------------------------------
# Epoch 22/500
# Train RMSE: 0.2557
# Val RMSE: 0.2527, Val MAE: 0.1077
# Test RMSE: 0.3307, Test MAE: 0.1475
# ---------------------------------
# Model saved at epoch 22 with val RMSE 0.2527
# Patience grace period: 40
# ---------------------------------
# Epoch 23/500
# Train RMSE: 0.2554
# Val RMSE: 0.2526, Val MAE: 0.1074
# Test RMSE: 0.3311, Test MAE: 0.1473
# ---------------------------------
# Model saved at epoch 23 with val RMSE 0.2526
# Patience grace period: 40
# ---------------------------------
# Epoch 24/500
# Train RMSE: 0.2552
# Val RMSE: 0.2524, Val MAE: 0.1075
# Test RMSE: 0.3304, Test MAE: 0.1474
# ---------------------------------
# Model saved at epoch 24 with val RMSE 0.2524
# Patience grace period: 40
# ---------------------------------
# Epoch 25/500
# Train RMSE: 0.2549
# Val RMSE: 0.2523, Val MAE: 0.1071
# Test RMSE: 0.3304, Test MAE: 0.1473
# ---------------------------------
# Model saved at epoch 25 with val RMSE 0.2523
# Patience grace period: 39
# ---------------------------------
# Epoch 26/500
# Train RMSE: 0.2547
# Val RMSE: 0.2521, Val MAE: 0.1073
# Test RMSE: 0.3298, Test MAE: 0.1475
# ---------------------------------
# Model saved at epoch 26 with val RMSE 0.2521
# Patience grace period: 40
# ---------------------------------
# Epoch 27/500
# Train RMSE: 0.2544
# Val RMSE: 0.2521, Val MAE: 0.1069
# Test RMSE: 0.3308, Test MAE: 0.1473
# ---------------------------------
# Patience grace period: 38
# ---------------------------------
# Epoch 28/500
# Train RMSE: 0.2542
# Val RMSE: 0.2520, Val MAE: 0.1067
# Test RMSE: 0.3306, Test MAE: 0.1473
# ---------------------------------
# Model saved at epoch 28 with val RMSE 0.2520
# Patience grace period: 37
# ---------------------------------
# Epoch 29/500
# Train RMSE: 0.2540
# Val RMSE: 0.2519, Val MAE: 0.1067
# Test RMSE: 0.3302, Test MAE: 0.1474
# ---------------------------------
# Model saved at epoch 29 with val RMSE 0.2519
# Patience grace period: 40
# ---------------------------------
# Epoch 30/500
# Train RMSE: 0.2539
# Val RMSE: 0.2517, Val MAE: 0.1068
# Test RMSE: 0.3302, Test MAE: 0.1475
# ---------------------------------
# Model saved at epoch 30 with val RMSE 0.2517
# Patience grace period: 40
# ---------------------------------
# Epoch 31/500
# Train RMSE: 0.2537
# Val RMSE: 0.2517, Val MAE: 0.1065
# Test RMSE: 0.3301, Test MAE: 0.1474
# ---------------------------------
# Model saved at epoch 31 with val RMSE 0.2517
# Patience grace period: 39
# ---------------------------------
# Epoch 32/500
# Train RMSE: 0.2535
# Val RMSE: 0.2515, Val MAE: 0.1070
# Test RMSE: 0.3293, Test MAE: 0.1479
# ---------------------------------
# Model saved at epoch 32 with val RMSE 0.2515
# Patience grace period: 40
# ---------------------------------
# Epoch 33/500
# Train RMSE: 0.2534
# Val RMSE: 0.2514, Val MAE: 0.1071
# Test RMSE: 0.3288, Test MAE: 0.1481
# ---------------------------------
# Model saved at epoch 33 with val RMSE 0.2514
# Patience grace period: 39
# ---------------------------------
# Epoch 34/500
# Train RMSE: 0.2533
# Val RMSE: 0.2514, Val MAE: 0.1065
# Test RMSE: 0.3295, Test MAE: 0.1476
# ---------------------------------
# Patience grace period: 37
# ---------------------------------
# Epoch 35/500
# Train RMSE: 0.2531
# Val RMSE: 0.2513, Val MAE: 0.1069
# Test RMSE: 0.3287, Test MAE: 0.1481
# ---------------------------------
# Model saved at epoch 35 with val RMSE 0.2513
# Patience grace period: 40
# ---------------------------------
# Epoch 36/500
# Train RMSE: 0.2530
# Val RMSE: 0.2512, Val MAE: 0.1069
# Test RMSE: 0.3287, Test MAE: 0.1480
# ---------------------------------
# Model saved at epoch 36 with val RMSE 0.2512
# Patience grace period: 39
# ---------------------------------
# Epoch 37/500
# Train RMSE: 0.2528
# Val RMSE: 0.2512, Val MAE: 0.1066
# Test RMSE: 0.3291, Test MAE: 0.1479
# ---------------------------------
# Patience grace period: 37
# ---------------------------------
# Epoch 38/500
# Train RMSE: 0.2527
# Val RMSE: 0.2512, Val MAE: 0.1068
# Test RMSE: 0.3287, Test MAE: 0.1481
# ---------------------------------
# Model saved at epoch 38 with val RMSE 0.2512
# Patience grace period: 40
# ---------------------------------
# Epoch 39/500
# Train RMSE: 0.2526
# Val RMSE: 0.2511, Val MAE: 0.1064
# Test RMSE: 0.3291, Test MAE: 0.1479
# ---------------------------------
# Model saved at epoch 39 with val RMSE 0.2511
# Patience grace period: 39
# ---------------------------------
# Epoch 40/500
# Train RMSE: 0.2525
# Val RMSE: 0.2512, Val MAE: 0.1062
# Test RMSE: 0.3295, Test MAE: 0.1478
# ---------------------------------
# Patience grace period: 37
# ---------------------------------
# Epoch 41/500
# Train RMSE: 0.2524
# Val RMSE: 0.2510, Val MAE: 0.1069
# Test RMSE: 0.3281, Test MAE: 0.1483
# ---------------------------------
# Model saved at epoch 41 with val RMSE 0.2510
# Patience grace period: 40
# ---------------------------------
# Epoch 42/500
# Train RMSE: 0.2523
# Val RMSE: 0.2509, Val MAE: 0.1071
# Test RMSE: 0.3276, Test MAE: 0.1485
# ---------------------------------
# Model saved at epoch 42 with val RMSE 0.2509
# Patience grace period: 39
# ---------------------------------
# Epoch 43/500
# Train RMSE: 0.2522
# Val RMSE: 0.2510, Val MAE: 0.1064
# Test RMSE: 0.3289, Test MAE: 0.1481
# ---------------------------------
# Patience grace period: 37
# ---------------------------------
# Epoch 44/500
# Train RMSE: 0.2521
# Val RMSE: 0.2508, Val MAE: 0.1067
# Test RMSE: 0.3280, Test MAE: 0.1483
# ---------------------------------
# Model saved at epoch 44 with val RMSE 0.2508
# Patience grace period: 40
# ---------------------------------
# Epoch 45/500
# Train RMSE: 0.2520
# Val RMSE: 0.2508, Val MAE: 0.1066
# Test RMSE: 0.3284, Test MAE: 0.1482
# ---------------------------------
# Patience grace period: 38
# ---------------------------------
# Epoch 46/500
# Train RMSE: 0.2519
# Val RMSE: 0.2508, Val MAE: 0.1067
# Test RMSE: 0.3277, Test MAE: 0.1486
# ---------------------------------
# Model saved at epoch 46 with val RMSE 0.2508
# Patience grace period: 37
# ---------------------------------
# Epoch 47/500
# Train RMSE: 0.2518
# Val RMSE: 0.2508, Val MAE: 0.1063
# Test RMSE: 0.3283, Test MAE: 0.1482
# ---------------------------------
# Patience grace period: 35
# ---------------------------------
# Epoch 48/500
# Train RMSE: 0.2517
# Val RMSE: 0.2507, Val MAE: 0.1067
# Test RMSE: 0.3278, Test MAE: 0.1485
# ---------------------------------
# Model saved at epoch 48 with val RMSE 0.2507
# Patience grace period: 34
# ---------------------------------
# Epoch 49/500
# Train RMSE: 0.2516
# Val RMSE: 0.2506, Val MAE: 0.1066
# Test RMSE: 0.3274, Test MAE: 0.1484
# ---------------------------------
# Model saved at epoch 49 with val RMSE 0.2506
# Patience grace period: 40
# ---------------------------------
# Epoch 50/500
# Train RMSE: 0.2516
# Val RMSE: 0.2506, Val MAE: 0.1074
# Test RMSE: 0.3267, Test MAE: 0.1490
# ---------------------------------
# Model saved at epoch 50 with val RMSE 0.2506
# Patience grace period: 39
# ---------------------------------
# Epoch 51/500
# Train RMSE: 0.2515
# Val RMSE: 0.2506, Val MAE: 0.1069
# Test RMSE: 0.3268, Test MAE: 0.1487
# ---------------------------------
# Model saved at epoch 51 with val RMSE 0.2506
# Patience grace period: 38
# ---------------------------------
# Epoch 52/500
# Train RMSE: 0.2514
# Val RMSE: 0.2507, Val MAE: 0.1062
# Test RMSE: 0.3282, Test MAE: 0.1483
# ---------------------------------
# Patience grace period: 36
# ---------------------------------
# Epoch 53/500
# Train RMSE: 0.2513
# Val RMSE: 0.2504, Val MAE: 0.1068
# Test RMSE: 0.3267, Test MAE: 0.1486
# ---------------------------------
# Model saved at epoch 53 with val RMSE 0.2504
# Patience grace period: 40
# ---------------------------------
# Epoch 54/500
# Train RMSE: 0.2512
# Val RMSE: 0.2505, Val MAE: 0.1066
# Test RMSE: 0.3274, Test MAE: 0.1486
# ---------------------------------
# Patience grace period: 38
# ---------------------------------
# Epoch 55/500
# Train RMSE: 0.2512
# Val RMSE: 0.2505, Val MAE: 0.1068
# Test RMSE: 0.3268, Test MAE: 0.1488
# ---------------------------------
# Patience grace period: 37
# ---------------------------------
# Epoch 56/500
# Train RMSE: 0.2511
# Val RMSE: 0.2504, Val MAE: 0.1064
# Test RMSE: 0.3273, Test MAE: 0.1485
# ---------------------------------
# Model saved at epoch 56 with val RMSE 0.2504
# Patience grace period: 36
# ---------------------------------
# Epoch 57/500
# Train RMSE: 0.2510
# Val RMSE: 0.2504, Val MAE: 0.1069
# Test RMSE: 0.3264, Test MAE: 0.1488
# ---------------------------------
# Model saved at epoch 57 with val RMSE 0.2504
# Patience grace period: 35
# ---------------------------------
# Epoch 58/500
# Train RMSE: 0.2510
# Val RMSE: 0.2504, Val MAE: 0.1064
# Test RMSE: 0.3274, Test MAE: 0.1487
# ---------------------------------
# Patience grace period: 33
# ---------------------------------
# Epoch 59/500
# Train RMSE: 0.2509
# Val RMSE: 0.2504, Val MAE: 0.1066
# Test RMSE: 0.3275, Test MAE: 0.1486
# ---------------------------------
# Patience grace period: 31
# ---------------------------------
# Epoch 60/500
# Train RMSE: 0.2509
# Val RMSE: 0.2503, Val MAE: 0.1068
# Test RMSE: 0.3270, Test MAE: 0.1488
# ---------------------------------
# Model saved at epoch 60 with val RMSE 0.2503
# Patience grace period: 40
# ---------------------------------
# Epoch 61/500
# Train RMSE: 0.2508
# Val RMSE: 0.2503, Val MAE: 0.1068
# Test RMSE: 0.3266, Test MAE: 0.1489
# ---------------------------------
# Model saved at epoch 61 with val RMSE 0.2503
# Patience grace period: 39
# ...
# Model saved at epoch 52 with val RMSE 0.2506
# Patience grace period: 34
# ---------------------------------
# Epoch 53/500
# Train RMSE: 0.2514
# Val RMSE: 0.2506, Val MAE: 0.1080
# Test RMSE: 0.3268, Test MAE: 0.1498
# ---------------------------------
# Model saved at epoch 53 with val RMSE 0.2506
# Patience grace period: 32
# ---------------------------------
# Epoch 54/500
# Train RMSE: 0.2513
# Val RMSE: 0.2505, Val MAE: 0.1080
# Test RMSE: 0.3266, Test MAE: 0.1497
# ---------------------------------
# Model saved at epoch 54 with val RMSE 0.2505
# Patience grace period: 40
# ---------------------------------
# Epoch 55/500
# Train RMSE: 0.2513
# Val RMSE: 0.2506, Val MAE: 0.1086
# Test RMSE: 0.3259, Test MAE: 0.1501
# ---------------------------------
# Patience grace period: 38
# ---------------------------------
# Epoch 56/500
# Train RMSE: 0.2512
# Val RMSE: 0.2505, Val MAE: 0.1082
# Test RMSE: 0.3265, Test MAE: 0.1500
# ---------------------------------
# Model saved at epoch 56 with val RMSE 0.2505
# Patience grace period: 37
# ---------------------------------
# Epoch 57/500
# Train RMSE: 0.2511
# Val RMSE: 0.2505, Val MAE: 0.1076
# Test RMSE: 0.3271, Test MAE: 0.1496
# ---------------------------------
# Model saved at epoch 57 with val RMSE 0.2505
# Patience grace period: 36
# ---------------------------------
# Epoch 58/500
# Train RMSE: 0.2510
# Val RMSE: 0.2504, Val MAE: 0.1077
# Test RMSE: 0.3269, Test MAE: 0.1496
# ---------------------------------
# Model saved at epoch 58 with val RMSE 0.2504
# Patience grace period: 40
# ---------------------------------
# Epoch 59/500
# Train RMSE: 0.2510
# Val RMSE: 0.2504, Val MAE: 0.1082
# Test RMSE: 0.3260, Test MAE: 0.1500
# ---------------------------------
# Patience grace period: 38
# ---------------------------------
# Epoch 60/500
# Train RMSE: 0.2509
# Val RMSE: 0.2504, Val MAE: 0.1078
# Test RMSE: 0.3264, Test MAE: 0.1499
# ---------------------------------
# Patience grace period: 36
# ---------------------------------
# Epoch 61/500
# Train RMSE: 0.2508
# Val RMSE: 0.2504, Val MAE: 0.1081
# Test RMSE: 0.3264, Test MAE: 0.1499
# ---------------------------------
# Model saved at epoch 61 with val RMSE 0.2504
# Patience grace period: 35
# ---------------------------------
# Epoch 62/500
# Train RMSE: 0.2508
# Val RMSE: 0.2503, Val MAE: 0.1077
# Test RMSE: 0.3265, Test MAE: 0.1497
# ---------------------------------
# Model saved at epoch 62 with val RMSE 0.2503
# Patience grace period: 40
# ---------------------------------
# Epoch 63/500
# Train RMSE: 0.2507
# Val RMSE: 0.2503, Val MAE: 0.1074
# Test RMSE: 0.3267, Test MAE: 0.1496
# ---------------------------------
# Patience grace period: 38
# ---------------------------------
# Epoch 64/500
# Train RMSE: 0.2507
# Val RMSE: 0.2503, Val MAE: 0.1079
# Test RMSE: 0.3259, Test MAE: 0.1499
# ---------------------------------
# Patience grace period: 37
# ---------------------------------
# Epoch 65/500
# Train RMSE: 0.2506
# Val RMSE: 0.2503, Val MAE: 0.1075
# Test RMSE: 0.3265, Test MAE: 0.1497
# ---------------------------------
# Model saved at epoch 65 with val RMSE 0.2503
# Patience grace period: 36
# ---------------------------------
# Epoch 66/500
# Train RMSE: 0.2505
# Val RMSE: 0.2502, Val MAE: 0.1077
# Test RMSE: 0.3260, Test MAE: 0.1498
# ---------------------------------
# Model saved at epoch 66 with val RMSE 0.2502
# Patience grace period: 35
# ---------------------------------
# Epoch 67/500
# Train RMSE: 0.2505
# Val RMSE: 0.2502, Val MAE: 0.1078
# Test RMSE: 0.3262, Test MAE: 0.1498
# ---------------------------------
# Model saved at epoch 67 with val RMSE 0.2502
# Patience grace period: 40
# ---------------------------------
# Epoch 68/500
# Train RMSE: 0.2505
# Val RMSE: 0.2502, Val MAE: 0.1071
# Test RMSE: 0.3270, Test MAE: 0.1495
# ---------------------------------
# Patience grace period: 38
# ---------------------------------
# Epoch 69/500
# Train RMSE: 0.2504
# Val RMSE: 0.2502, Val MAE: 0.1078
# Test RMSE: 0.3259, Test MAE: 0.1499
# ---------------------------------
# Model saved at epoch 69 with val RMSE 0.2502
# Patience grace period: 37
# ---------------------------------
# Epoch 70/500
# Train RMSE: 0.2504
# Val RMSE: 0.2502, Val MAE: 0.1078
# Test RMSE: 0.3260, Test MAE: 0.1501
# ---------------------------------
# Model saved at epoch 70 with val RMSE 0.2502
# Patience grace period: 35
# ---------------------------------
# Epoch 71/500
# Train RMSE: 0.2503
# Val RMSE: 0.2502, Val MAE: 0.1073
# Test RMSE: 0.3268, Test MAE: 0.1497
# ---------------------------------
# Model saved at epoch 71 with val RMSE 0.2502
# Patience grace period: 34
# ---------------------------------
# Epoch 72/500
# Train RMSE: 0.2503
# Val RMSE: 0.2502, Val MAE: 0.1073
# Test RMSE: 0.3266, Test MAE: 0.1496
# ---------------------------------
# Patience grace period: 32
# ---------------------------------
# Epoch 73/500
# Train RMSE: 0.2502
# Val RMSE: 0.2501, Val MAE: 0.1074
# Test RMSE: 0.3264, Test MAE: 0.1499
# ---------------------------------
# Model saved at epoch 73 with val RMSE 0.2501
# Patience grace period: 31
# ---------------------------------
# Epoch 74/500
# Train RMSE: 0.2502
# Val RMSE: 0.2502, Val MAE: 0.1075
# Test RMSE: 0.3260, Test MAE: 0.1498
# ---------------------------------
# Patience grace period: 29
# ---------------------------------
# Epoch 75/500
# Train RMSE: 0.2501
# Val RMSE: 0.2501, Val MAE: 0.1071
# Test RMSE: 0.3267, Test MAE: 0.1495
# ---------------------------------
# Patience grace period: 28
# ---------------------------------
# Epoch 76/500
# Train RMSE: 0.2501
# Val RMSE: 0.2502, Val MAE: 0.1070
# Test RMSE: 0.3273, Test MAE: 0.1498
# ---------------------------------
# Patience grace period: 26
# ---------------------------------
# Epoch 77/500
# Train RMSE: 0.2501
# Val RMSE: 0.2501, Val MAE: 0.1074
# Test RMSE: 0.3264, Test MAE: 0.1499
# ---------------------------------
# Model saved at epoch 77 with val RMSE 0.2501
# Patience grace period: 40
# ---------------------------------
# Epoch 78/500
# Train RMSE: 0.2500
# Val RMSE: 0.2501, Val MAE: 0.1078
# Test RMSE: 0.3256, Test MAE: 0.1502
# ---------------------------------
# Patience grace period: 38
# ---------------------------------
# Epoch 79/500
# Train RMSE: 0.2500
# Val RMSE: 0.2502, Val MAE: 0.1065
# Test RMSE: 0.3281, Test MAE: 0.1493
# ---------------------------------
# Patience grace period: 36
# ---------------------------------
# Epoch 80/500
# Train RMSE: 0.2499
# Val RMSE: 0.2501, Val MAE: 0.1077
# Test RMSE: 0.3258, Test MAE: 0.1501
# ---------------------------------
# Patience grace period: 35
# ---------------------------------
# Epoch 81/500
# Train RMSE: 0.2499
# Val RMSE: 0.2501, Val MAE: 0.1070
# Test RMSE: 0.3271, Test MAE: 0.1498
# ---------------------------------
# Patience grace period: 33
# ---------------------------------
# Epoch 82/500
# Train RMSE: 0.2499
# Val RMSE: 0.2500, Val MAE: 0.1072
# Test RMSE: 0.3267, Test MAE: 0.1497
# ---------------------------------
# Model saved at epoch 82 with val RMSE 0.2500
# Patience grace period: 32
# ---------------------------------
# Epoch 83/500
# Train RMSE: 0.2498
# Val RMSE: 0.2501, Val MAE: 0.1073
# Test RMSE: 0.3263, Test MAE: 0.1499
# ---------------------------------
# Patience grace period: 30
# ---------------------------------
# Epoch 84/500
# Train RMSE: 0.2498
# Val RMSE: 0.2500, Val MAE: 0.1079
# Test RMSE: 0.3249, Test MAE: 0.1504
# ---------------------------------
# Patience grace period: 29
# ---------------------------------
# Epoch 85/500
# Train RMSE: 0.2498
# Val RMSE: 0.2500, Val MAE: 0.1077
# Test RMSE: 0.3258, Test MAE: 0.1502
# ---------------------------------
# Model saved at epoch 85 with val RMSE 0.2500
# Patience grace period: 28
# ---------------------------------
# Epoch 86/500
# Train RMSE: 0.2497
# Val RMSE: 0.2500, Val MAE: 0.1076
# Test RMSE: 0.3256, Test MAE: 0.1503
# ---------------------------------
# Model saved at epoch 86 with val RMSE 0.2500
# Patience grace period: 27
# ---------------------------------
# Epoch 87/500
# Train RMSE: 0.2497
# Val RMSE: 0.2500, Val MAE: 0.1071
# Test RMSE: 0.3264, Test MAE: 0.1498
# ---------------------------------
# Patience grace period: 25
# ---------------------------------
# Epoch 88/500
# Train RMSE: 0.2497
# Val RMSE: 0.2500, Val MAE: 0.1071
# Test RMSE: 0.3264, Test MAE: 0.1500
# ---------------------------------
# Patience grace period: 23
# ---------------------------------
# Epoch 89/500
# Train RMSE: 0.2497
# Val RMSE: 0.2500, Val MAE: 0.1075
# Test RMSE: 0.3255, Test MAE: 0.1503
# ---------------------------------
# Patience grace period: 22
# ---------------------------------
# Epoch 90/500
# Train RMSE: 0.2496
# Val RMSE: 0.2500, Val MAE: 0.1078
# Test RMSE: 0.3252, Test MAE: 0.1504
# ---------------------------------
# Patience grace period: 21
# ---------------------------------
# Epoch 91/500
# Train RMSE: 0.2496
# Val RMSE: 0.2500, Val MAE: 0.1070
# Test RMSE: 0.3264, Test MAE: 0.1499
# ---------------------------------
# Model saved at epoch 91 with val RMSE 0.2500
# Patience grace period: 20
# ---------------------------------
# Epoch 92/500
# Train RMSE: 0.2496
# Val RMSE: 0.2500, Val MAE: 0.1072
# Test RMSE: 0.3263, Test MAE: 0.1500
# ---------------------------------
# Model saved at epoch 92 with val RMSE 0.2500
# Patience grace period: 19
# ---------------------------------
# Epoch 93/500
# Train RMSE: 0.2495
# Val RMSE: 0.2499, Val MAE: 0.1073
# Test RMSE: 0.3261, Test MAE: 0.1502
# ---------------------------------
# Model saved at epoch 93 with val RMSE 0.2499
# Patience grace period: 40
# ---------------------------------
# Epoch 94/500
# Train RMSE: 0.2495
# Val RMSE: 0.2499, Val MAE: 0.1073
# Test RMSE: 0.3262, Test MAE: 0.1502
# ---------------------------------
# Patience grace period: 38
# ---------------------------------
# Epoch 95/500
# Train RMSE: 0.2495
# Val RMSE: 0.2499, Val MAE: 0.1072
# Test RMSE: 0.3265, Test MAE: 0.1499
# ---------------------------------
# Model saved at epoch 95 with val RMSE 0.2499
# Patience grace period: 37
# ---------------------------------
# Epoch 96/500
# Train RMSE: 0.2494
# Val RMSE: 0.2499, Val MAE: 0.1079
# Test RMSE: 0.3253, Test MAE: 0.1504
# ---------------------------------
# Patience grace period: 35
# ---------------------------------
# Epoch 97/500
# Train RMSE: 0.2494
# Val RMSE: 0.2500, Val MAE: 0.1071
# Test RMSE: 0.3265, Test MAE: 0.1501
# ---------------------------------
# Patience grace period: 33
# ---------------------------------
# Epoch 98/500
# Train RMSE: 0.2494
# Val RMSE: 0.2500, Val MAE: 0.1064
# Test RMSE: 0.3275, Test MAE: 0.1497
# ---------------------------------
# Patience grace period: 31
# ---------------------------------
# Epoch 99/500
# Train RMSE: 0.2494
# Val RMSE: 0.2500, Val MAE: 0.1067
# Test RMSE: 0.3271, Test MAE: 0.1499
# ---------------------------------
# Patience grace period: 30
# ---------------------------------
# Epoch 100/500
# Train RMSE: 0.2493
# Val RMSE: 0.2499, Val MAE: 0.1070
# Test RMSE: 0.3265, Test MAE: 0.1502
# ---------------------------------
# Patience grace period: 29
# ---------------------------------
# Epoch 101/500
# Train RMSE: 0.2493
# Val RMSE: 0.2500, Val MAE: 0.1066
# Test RMSE: 0.3274, Test MAE: 0.1499
# ---------------------------------
# Patience grace period: 27
# ---------------------------------
# Epoch 102/500
# Train RMSE: 0.2493
# Val RMSE: 0.2499, Val MAE: 0.1072
# Test RMSE: 0.3263, Test MAE: 0.1503
# ---------------------------------
# Patience grace period: 26
# ---------------------------------
# Epoch 103/500
# Train RMSE: 0.2492
# Val RMSE: 0.2499, Val MAE: 0.1063
# Test RMSE: 0.3272, Test MAE: 0.1498
# ---------------------------------
# Patience grace period: 25
# ---------------------------------
# Epoch 104/500
# Train RMSE: 0.2492
# Val RMSE: 0.2499, Val MAE: 0.1065
# Test RMSE: 0.3270, Test MAE: 0.1499
# ---------------------------------
# Patience grace period: 24
# ---------------------------------
# Epoch 105/500
# Train RMSE: 0.2492
# Val RMSE: 0.2499, Val MAE: 0.1073
# Test RMSE: 0.3257, Test MAE: 0.1503
# ---------------------------------
# Patience grace period: 22
# ---------------------------------
# Epoch 106/500
# Train RMSE: 0.2492
# Val RMSE: 0.2499, Val MAE: 0.1070
# Test RMSE: 0.3266, Test MAE: 0.1502
# ---------------------------------
# Patience grace period: 20
# ---------------------------------
# Epoch 107/500
# Train RMSE: 0.2492
# Val RMSE: 0.2499, Val MAE: 0.1072
# Test RMSE: 0.3259, Test MAE: 0.1504
# ---------------------------------
# Patience grace period: 19
# ---------------------------------
# Epoch 108/500
# Train RMSE: 0.2491
# Val RMSE: 0.2500, Val MAE: 0.1065
# Test RMSE: 0.3275, Test MAE: 0.1498
# ---------------------------------
# Patience grace period: 17
# ---------------------------------
# Epoch 109/500
# Train RMSE: 0.2491
# Val RMSE: 0.2499, Val MAE: 0.1069
# Test RMSE: 0.3265, Test MAE: 0.1501
# ---------------------------------
# Model saved at epoch 109 with val RMSE 0.2499
# Patience grace period: 16
# ---------------------------------
# Epoch 110/500
# Train RMSE: 0.2491
# Val RMSE: 0.2498, Val MAE: 0.1067
# Test RMSE: 0.3266, Test MAE: 0.1500
# ---------------------------------
# Model saved at epoch 110 with val RMSE 0.2498
# Patience grace period: 15
# ---------------------------------
# Epoch 111/500
# Train RMSE: 0.2491
# Val RMSE: 0.2500, Val MAE: 0.1067
# Test RMSE: 0.3265, Test MAE: 0.1503
# ---------------------------------
# Patience grace period: 13
# ---------------------------------
# Epoch 112/500
# Train RMSE: 0.2491
# Val RMSE: 0.2499, Val MAE: 0.1067
# Test RMSE: 0.3268, Test MAE: 0.1501
# ---------------------------------
# Patience grace period: 12
# ---------------------------------
# Epoch 113/500
# Train RMSE: 0.2490
# Val RMSE: 0.2499, Val MAE: 0.1067
# Test RMSE: 0.3267, Test MAE: 0.1499
# ---------------------------------
# Patience grace period: 11
# ---------------------------------
# Epoch 114/500
# Train RMSE: 0.2490
# Val RMSE: 0.2499, Val MAE: 0.1070
# Test RMSE: 0.3266, Test MAE: 0.1502
# ---------------------------------
# Patience grace period: 10
# ---------------------------------
# Epoch 115/500
# Train RMSE: 0.2490
# Val RMSE: 0.2499, Val MAE: 0.1068
# Test RMSE: 0.3265, Test MAE: 0.1502
# ---------------------------------
# Patience grace period: 8
# ---------------------------------
# Epoch 116/500
# Train RMSE: 0.2489
# Val RMSE: 0.2499, Val MAE: 0.1072
# Test RMSE: 0.3258, Test MAE: 0.1504
# ---------------------------------
# Patience grace period: 7
# ---------------------------------
# Epoch 117/500
# Train RMSE: 0.2489
# Val RMSE: 0.2499, Val MAE: 0.1069
# Test RMSE: 0.3265, Test MAE: 0.1502
# ---------------------------------
# Patience grace period: 5
# ---------------------------------
# Epoch 118/500
# Train RMSE: 0.2489
# Val RMSE: 0.2499, Val MAE: 0.1066
# Test RMSE: 0.3269, Test MAE: 0.1498
# ---------------------------------
# Patience grace period: 3
# ---------------------------------
# Epoch 119/500
# Train RMSE: 0.2489
# Val RMSE: 0.2499, Val MAE: 0.1067
# Test RMSE: 0.3271, Test MAE: 0.1502
# ---------------------------------
# Patience grace period: 1
# ---------------------------------
# Epoch 120/500
# Train RMSE: 0.2489
# Val RMSE: 0.2498, Val MAE: 0.1067
# Test RMSE: 0.3269, Test MAE: 0.1500
# ---------------------------------
# Model saved at epoch 120 with val RMSE 0.2498
# Patience grace period: 0
# Early stopping triggered at epoch 120
# Final Test RMSE: 0.3269, Final Test MAE: 0.1500
# <ipython-input-3-2a228d64b832>:126: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   self.model.load_state_dict(torch.load(os.path.join(save_dir, 'best_model.pth')))
# Pearson Corr: 0.7487808325967826
# Spearman Corr: 0.4283850591323203
# p-rmse: 0.32693103000085283
#        rmse       mae  seed                             subtask    method  \
# 0  0.326931  0.150015     5  openproblems_bmmc_cite_phase2_mod2  original
#
#     pearson p_value_pearson  spearman p_value_spearman
# 0  0.748781          0.0000  0.428385           0.0000

# %%
config_hierachical_PROTEIN = {
    "subtask": "openproblems_bmmc_cite_phase2_mod2",
    "batch_size": 520,
    "act": "relu",
    "conv_flow": ["gat"],
    "agg_flow": [None],
    "device": "cuda",
    "learning_rate": 0.000064,
    "hidden_size": 280,
    "num_heads": 6,
    "n_neigbours": 3,
    "metric": "cosine",
    "n_components": 1200,
    "dropout_rate": 0.2,
    "num_epochs": 500,
    "seed": 1,
    "es_patience": 40,
    "es_min_delta": 0.0001,
    "es_rate_threshold": 0.00002,
    "layer_dim_ex": 3,
    "verbose": True,
    "sample": True,
    "preprocessing_type": "None",
    "variant": "original",
    "num_clusters": 10
}

pipeline(**config_hierachical_PROTEIN)
# Out:
# [INFO][2025-04-16 06:27:21,170][dance][_load_raw_data] Loading /content/data/openproblems_bmmc_cite_phase2_mod2/openproblems_bmmc_cite_phase2_mod2.censor_dataset.output_train_mod1.h5ad
# Initializing pipeline...
# [INFO][2025-04-16 06:27:21,824][dance][_load_raw_data] Loading /content/data/openproblems_bmmc_cite_phase2_mod2/openproblems_bmmc_cite_phase2_mod2.censor_dataset.output_train_mod2.h5ad
# [INFO][2025-04-16 06:27:29,538][dance][_load_raw_data] Loading /content/data/openproblems_bmmc_cite_phase2_mod2/openproblems_bmmc_cite_phase2_mod2.censor_dataset.output_test_mod1.h5ad
# [INFO][2025-04-16 06:27:29,562][dance][_load_raw_data] Loading /content/data/openproblems_bmmc_cite_phase2_mod2/openproblems_bmmc_cite_phase2_mod2.censor_dataset.output_test_mod2.h5ad
# [INFO][2025-04-16 06:27:29,763][dance][_maybe_preprocess] Preprocessing done.
# /usr/local/lib/python3.11/dist-packages/mudata/_core/mudata.py:1531: FutureWarning: From 0.4 .update() will not pull obs/var columns from individual modalities by default anymore. Set mudata.set_options(pull_on_update=False) to adopt the new behaviour, which will become the default. Use new pull_obs/pull_var and push_obs/push_var methods for more flexibility.
#   self._update_attr("var", axis=0, join_common=join_common)
# /usr/local/lib/python3.11/dist-packages/mudata/_core/mudata.py:931: UserWarning: Cannot join columns with the same name because var_names are intersecting.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/mudata/_core/mudata.py:1429: FutureWarning: From 0.4 .update() will not pull obs/var columns from individual modalities by default anymore. Set mudata.set_options(pull_on_update=False) to adopt the new behaviour, which will become the default. Use new pull_obs/pull_var and push_obs/push_var methods for more flexibility.
#   self._update_attr("obs", axis=1, join_common=join_common)
# /usr/local/lib/python3.11/dist-packages/mudata/_core/mudata.py:1558: UserWarning: Modality names will be prepended to var_names since there are identical var_names in different modalities.
#   warnings.warn(
# [INFO][2025-04-16 06:27:36,864][dance][set_config_from_dict] Setting config 'feature_mod' to 'mod1'
# [INFO][2025-04-16 06:27:36,865][dance][set_config_from_dict] Setting config 'label_mod' to 'mod2'
# [INFO][2025-04-16 06:27:36,865][dance][load_data] Raw data loaded:
# Data object that wraps (.data):
# MuData object with n_obs × n_vars = 67175 × 14087
#   uns:	'dance_config'
#   2 modalities
#     mod1:	67175 x 134
#       obs:	'batch'
#       layers:	'counts'
#     mod2:	67175 x 13953
#       obs:	'batch'
#       layers:	'counts'
# [INFO][2025-04-16 06:27:36,992][dance][wrapped_func] Took 0:00:15.823273 to load and process data.
# Performing data processing using GraphCreator...
# Data processing using GraphCreator complete and saved.
# ---------------------------------
# Epoch 1/500
# Train RMSE: 0.3737
# Val RMSE: 0.3215, Val MAE: 0.1326
# Test RMSE: 0.3979, Test MAE: 0.1766
# ---------------------------------
# Model saved at epoch 1 with val RMSE 0.3215
# Patience grace period: 40
# ---------------------------------
# Epoch 2/500
# Train RMSE: 0.3260
# Val RMSE: 0.2940, Val MAE: 0.1261
# Test RMSE: 0.3693, Test MAE: 0.1670
# ---------------------------------
# Model saved at epoch 2 with val RMSE 0.2940
# Patience grace period: 40
# ---------------------------------
# Epoch 3/500
# Train RMSE: 0.3044
# Val RMSE: 0.2793, Val MAE: 0.1205
# Test RMSE: 0.3554, Test MAE: 0.1600
# ---------------------------------
# Model saved at epoch 3 with val RMSE 0.2793
# Patience grace period: 40
# ---------------------------------
# Epoch 4/500
# Train RMSE: 0.2916
# Val RMSE: 0.2723, Val MAE: 0.1181
# Test RMSE: 0.3490, Test MAE: 0.1574
# ---------------------------------
# Model saved at epoch 4 with val RMSE 0.2723
# Patience grace period: 40
# ---------------------------------
# Epoch 5/500
# Train RMSE: 0.2837
# Val RMSE: 0.2683, Val MAE: 0.1169
# Test RMSE: 0.3456, Test MAE: 0.1561
# ---------------------------------
# Model saved at epoch 5 with val RMSE 0.2683
# Patience grace period: 40
# ---------------------------------
# Epoch 6/500
# Train RMSE: 0.2779
# Val RMSE: 0.2652, Val MAE: 0.1154
# Test RMSE: 0.3426, Test MAE: 0.1543
# ---------------------------------
# Model saved at epoch 6 with val RMSE 0.2652
# Patience grace period: 40
# ---------------------------------
# Epoch 7/500
# Train RMSE: 0.2733
# Val RMSE: 0.2625, Val MAE: 0.1141
# Test RMSE: 0.3399, Test MAE: 0.1527
# ---------------------------------
# Model saved at epoch 7 with val RMSE 0.2625
# Patience grace period: 40
# ---------------------------------
# Epoch 8/500
# Train RMSE: 0.2694
# Val RMSE: 0.2604, Val MAE: 0.1127
# Test RMSE: 0.3383, Test MAE: 0.1511
# ---------------------------------
# Model saved at epoch 8 with val RMSE 0.2604
# Patience grace period: 40
# ---------------------------------
# Epoch 9/500
# Train RMSE: 0.2665
# Val RMSE: 0.2589, Val MAE: 0.1114
# Test RMSE: 0.3378, Test MAE: 0.1499
# ---------------------------------
# Model saved at epoch 9 with val RMSE 0.2589
# Patience grace period: 40
# ---------------------------------
# Epoch 10/500
# Train RMSE: 0.2643
# Val RMSE: 0.2577, Val MAE: 0.1107
# Test RMSE: 0.3368, Test MAE: 0.1494
# ---------------------------------
# Model saved at epoch 10 with val RMSE 0.2577
# Patience grace period: 40
# ---------------------------------
# Epoch 11/500
# Train RMSE: 0.2625
# Val RMSE: 0.2567, Val MAE: 0.1103
# Test RMSE: 0.3359, Test MAE: 0.1490
# ---------------------------------
# Model saved at epoch 11 with val RMSE 0.2567
# Patience grace period: 40
# ---------------------------------
# Epoch 12/500
# Train RMSE: 0.2613
# Val RMSE: 0.2558, Val MAE: 0.1106
# Test RMSE: 0.3340, Test MAE: 0.1491
# ---------------------------------
# Model saved at epoch 12 with val RMSE 0.2558
# Patience grace period: 40
# ---------------------------------
# Epoch 13/500
# Train RMSE: 0.2602
# Val RMSE: 0.2554, Val MAE: 0.1095
# Test RMSE: 0.3352, Test MAE: 0.1481
# ---------------------------------
# Model saved at epoch 13 with val RMSE 0.2554
# Patience grace period: 40
# ---------------------------------
# Epoch 14/500
# Train RMSE: 0.2594
# Val RMSE: 0.2550, Val MAE: 0.1088
# Test RMSE: 0.3350, Test MAE: 0.1476
# ---------------------------------
# Model saved at epoch 14 with val RMSE 0.2550
# Patience grace period: 40
# ---------------------------------
# Epoch 15/500
# Train RMSE: 0.2586
# Val RMSE: 0.2545, Val MAE: 0.1092
# Test RMSE: 0.3336, Test MAE: 0.1478
# ---------------------------------
# Model saved at epoch 15 with val RMSE 0.2545
# Patience grace period: 40
# ---------------------------------
# Epoch 16/500
# Train RMSE: 0.2581
# Val RMSE: 0.2540, Val MAE: 0.1091
# Test RMSE: 0.3328, Test MAE: 0.1477
# ---------------------------------
# Model saved at epoch 16 with val RMSE 0.2540
# Patience grace period: 40
# ---------------------------------
# Epoch 17/500
# Train RMSE: 0.2575
# Val RMSE: 0.2536, Val MAE: 0.1095
# Test RMSE: 0.3313, Test MAE: 0.1479
# ---------------------------------
# Model saved at epoch 17 with val RMSE 0.2536
# Patience grace period: 40
# ---------------------------------
# Epoch 18/500
# Train RMSE: 0.2571
# Val RMSE: 0.2533, Val MAE: 0.1088
# Test RMSE: 0.3316, Test MAE: 0.1476
# ---------------------------------
# Model saved at epoch 18 with val RMSE 0.2533
# Patience grace period: 40
# ---------------------------------
# Epoch 19/500
# Train RMSE: 0.2566
# Val RMSE: 0.2530, Val MAE: 0.1087
# Test RMSE: 0.3316, Test MAE: 0.1475
# ---------------------------------
# Model saved at epoch 19 with val RMSE 0.2530
# Patience grace period: 40
# ---------------------------------
# Epoch 20/500
# Train RMSE: 0.2562
# Val RMSE: 0.2528, Val MAE: 0.1083
# Test RMSE: 0.3313, Test MAE: 0.1472
# ---------------------------------
# Model saved at epoch 20 with val RMSE 0.2528
# Patience grace period: 40
# ---------------------------------
# Epoch 21/500
# Train RMSE: 0.2559
# Val RMSE: 0.2527, Val MAE: 0.1079
# Test RMSE: 0.3319, Test MAE: 0.1468
# ---------------------------------
# Model saved at epoch 21 with val RMSE 0.2527
# Patience grace period: 40
# ---------------------------------
# Epoch 22/500
# Train RMSE: 0.2555
# Val RMSE: 0.2523, Val MAE: 0.1084
# Test RMSE: 0.3304, Test MAE: 0.1473
# ---------------------------------
# Model saved at epoch 22 with val RMSE 0.2523
# Patience grace period: 40
# ---------------------------------
# Epoch 23/500
# Train RMSE: 0.2552
# Val RMSE: 0.2522, Val MAE: 0.1078
# Test RMSE: 0.3311, Test MAE: 0.1470
# ---------------------------------
# Model saved at epoch 23 with val RMSE 0.2522
# Patience grace period: 40
# ---------------------------------
# Epoch 24/500
# Train RMSE: 0.2550
# Val RMSE: 0.2520, Val MAE: 0.1080
# Test RMSE: 0.3302, Test MAE: 0.1471
# ---------------------------------
# Model saved at epoch 24 with val RMSE 0.2520
# Patience grace period: 40
# ---------------------------------
# Epoch 25/500
# Train RMSE: 0.2547
# Val RMSE: 0.2518, Val MAE: 0.1080
# Test RMSE: 0.3295, Test MAE: 0.1475
# ---------------------------------
# Model saved at epoch 25 with val RMSE 0.2518
# Patience grace period: 40
# ---------------------------------
# Epoch 26/500
# Train RMSE: 0.2545
# Val RMSE: 0.2517, Val MAE: 0.1083
# Test RMSE: 0.3293, Test MAE: 0.1476
# ---------------------------------
# Model saved at epoch 26 with val RMSE 0.2517
# Patience grace period: 40
# ---------------------------------
# Epoch 27/500
# Train RMSE: 0.2543
# Val RMSE: 0.2515, Val MAE: 0.1076
# Test RMSE: 0.3296, Test MAE: 0.1473
# ---------------------------------
# Model saved at epoch 27 with val RMSE 0.2515
# Patience grace period: 40
# ---------------------------------
# Epoch 28/500
# Train RMSE: 0.2541
# Val RMSE: 0.2515, Val MAE: 0.1071
# Test RMSE: 0.3301, Test MAE: 0.1472
# ---------------------------------
# Model saved at epoch 28 with val RMSE 0.2515
# Patience grace period: 39
# ---------------------------------
# Epoch 29/500
# Train RMSE: 0.2540
# Val RMSE: 0.2513, Val MAE: 0.1074
# Test RMSE: 0.3295, Test MAE: 0.1473
# ---------------------------------
# Model saved at epoch 29 with val RMSE 0.2513
# Patience grace period: 40
# ---------------------------------
# Epoch 30/500
# Train RMSE: 0.2537
# Val RMSE: 0.2512, Val MAE: 0.1077
# Test RMSE: 0.3290, Test MAE: 0.1477
# ---------------------------------
# Model saved at epoch 30 with val RMSE 0.2512
# Patience grace period: 40
# ---------------------------------
# Epoch 31/500
# Train RMSE: 0.2536
# Val RMSE: 0.2511, Val MAE: 0.1072
# Test RMSE: 0.3296, Test MAE: 0.1472
# ---------------------------------
# Model saved at epoch 31 with val RMSE 0.2511
# Patience grace period: 39
# ---------------------------------
# Epoch 32/500
# Train RMSE: 0.2534
# Val RMSE: 0.2510, Val MAE: 0.1075
# Test RMSE: 0.3285, Test MAE: 0.1478
# ---------------------------------
# Model saved at epoch 32 with val RMSE 0.2510
# Patience grace period: 40
# ---------------------------------
# Epoch 33/500
# Train RMSE: 0.2532
# Val RMSE: 0.2509, Val MAE: 0.1075
# Test RMSE: 0.3284, Test MAE: 0.1478
# ---------------------------------
# Model saved at epoch 33 with val RMSE 0.2509
# Patience grace period: 39
# ---------------------------------
# Epoch 34/500
# Train RMSE: 0.2531
# Val RMSE: 0.2508, Val MAE: 0.1075
# Test RMSE: 0.3286, Test MAE: 0.1479
# ---------------------------------
# Model saved at epoch 34 with val RMSE 0.2508
# Patience grace period: 40
# ---------------------------------
# Epoch 35/500
# Train RMSE: 0.2530
# Val RMSE: 0.2507, Val MAE: 0.1079
# Test RMSE: 0.3274, Test MAE: 0.1481
# ---------------------------------
# Model saved at epoch 35 with val RMSE 0.2507
# Patience grace period: 40
# ---------------------------------
# Epoch 36/500
# Train RMSE: 0.2528
# Val RMSE: 0.2506, Val MAE: 0.1075
# Test RMSE: 0.3278, Test MAE: 0.1480
# ---------------------------------
# Model saved at epoch 36 with val RMSE 0.2506
# Patience grace period: 39
# ---------------------------------
# Epoch 37/500
# Train RMSE: 0.2527
# Val RMSE: 0.2506, Val MAE: 0.1072
# Test RMSE: 0.3282, Test MAE: 0.1479
# ---------------------------------
# Model saved at epoch 37 with val RMSE 0.2506
# Patience grace period: 38
# ---------------------------------
# Epoch 38/500
# Train RMSE: 0.2526
# Val RMSE: 0.2505, Val MAE: 0.1072
# Test RMSE: 0.3283, Test MAE: 0.1479
# ---------------------------------
# Model saved at epoch 38 with val RMSE 0.2505
# Patience grace period: 40
# ---------------------------------
# Epoch 39/500
# Train RMSE: 0.2525
# Val RMSE: 0.2505, Val MAE: 0.1065
# Test RMSE: 0.3290, Test MAE: 0.1475
# ---------------------------------
# Model saved at epoch 39 with val RMSE 0.2505
# Patience grace period: 38
# ---------------------------------
# Epoch 40/500
# Train RMSE: 0.2524
# Val RMSE: 0.2503, Val MAE: 0.1073
# Test RMSE: 0.3274, Test MAE: 0.1481
# ---------------------------------
# Model saved at epoch 40 with val RMSE 0.2503
# Patience grace period: 40
# ---------------------------------
# Epoch 41/500
# Train RMSE: 0.2522
# Val RMSE: 0.2503, Val MAE: 0.1079
# Test RMSE: 0.3266, Test MAE: 0.1486
# ---------------------------------
# Model saved at epoch 41 with val RMSE 0.2503
# Patience grace period: 39
# ---------------------------------
# Epoch 42/500
# Train RMSE: 0.2521
# Val RMSE: 0.2503, Val MAE: 0.1070
# Test RMSE: 0.3278, Test MAE: 0.1480
# ---------------------------------
# Model saved at epoch 42 with val RMSE 0.2503
# Patience grace period: 38
# ---------------------------------
# Epoch 43/500
# Train RMSE: 0.2520
# Val RMSE: 0.2502, Val MAE: 0.1069
# Test RMSE: 0.3275, Test MAE: 0.1481
# ---------------------------------
# Model saved at epoch 43 with val RMSE 0.2502
# Patience grace period: 40
# ---------------------------------
# Epoch 44/500
# Train RMSE: 0.2519
# Val RMSE: 0.2501, Val MAE: 0.1071
# Test RMSE: 0.3273, Test MAE: 0.1482
# ---------------------------------
# Model saved at epoch 44 with val RMSE 0.2501
# Patience grace period: 39
# ---------------------------------
# Epoch 45/500
# Train RMSE: 0.2519
# Val RMSE: 0.2501, Val MAE: 0.1074
# Test RMSE: 0.3268, Test MAE: 0.1485
# ---------------------------------
# Model saved at epoch 45 with val RMSE 0.2501
# Patience grace period: 40
# ---------------------------------
# Epoch 46/500
# Train RMSE: 0.2518
# Val RMSE: 0.2500, Val MAE: 0.1074
# Test RMSE: 0.3267, Test MAE: 0.1485
# ---------------------------------
# Model saved at epoch 46 with val RMSE 0.2500
# Patience grace period: 39
# ---------------------------------
# Epoch 47/500
# Train RMSE: 0.2517
# Val RMSE: 0.2500, Val MAE: 0.1068
# Test RMSE: 0.3276, Test MAE: 0.1480
# ---------------------------------
# Model saved at epoch 47 with val RMSE 0.2500
# Patience grace period: 38
# ---------------------------------
# Epoch 48/500
# Train RMSE: 0.2516
# Val RMSE: 0.2499, Val MAE: 0.1073
# Test RMSE: 0.3264, Test MAE: 0.1486
# ---------------------------------
# Model saved at epoch 48 with val RMSE 0.2499
# Patience grace period: 40
# ---------------------------------
# Epoch 49/500
# Train RMSE: 0.2515
# Val RMSE: 0.2499, Val MAE: 0.1067
# Test RMSE: 0.3278, Test MAE: 0.1482
# ---------------------------------
# Model saved at epoch 49 with val RMSE 0.2499
# Patience grace period: 38
# ---------------------------------
# Epoch 50/500
# Train RMSE: 0.2514
# Val RMSE: 0.2498, Val MAE: 0.1068
# Test RMSE: 0.3274, Test MAE: 0.1483
# ---------------------------------
# Model saved at epoch 50 with val RMSE 0.2498
# Patience grace period: 37
# ---------------------------------
# Epoch 51/500
# Train RMSE: 0.2513
# Val RMSE: 0.2498, Val MAE: 0.1074
# Test RMSE: 0.3262, Test MAE: 0.1486
# ---------------------------------
# Model saved at epoch 51 with val RMSE 0.2498
# Patience grace period: 40
# ---------------------------------
# Epoch 52/500
# Train RMSE: 0.2513
# Val RMSE: 0.2498, Val MAE: 0.1067
# Test RMSE: 0.3270, Test MAE: 0.1483
# ---------------------------------
# Model saved at epoch 52 with val RMSE 0.2498
# Patience grace period: 38
# ---------------------------------
# Epoch 53/500
# Train RMSE: 0.2512
# Val RMSE: 0.2497, Val MAE: 0.1069
# Test RMSE: 0.3267, Test MAE: 0.1485
# ---------------------------------
# Model saved at epoch 53 with val RMSE 0.2497
# Patience grace period: 37
# ---------------------------------
# Epoch 54/500
# Train RMSE: 0.2511
# Val RMSE: 0.2496, Val MAE: 0.1072
# Test RMSE: 0.3258, Test MAE: 0.1486
# ---------------------------------
# Model saved at epoch 54 with val RMSE 0.2496
# Patience grace period: 40
# ---------------------------------
# Epoch 55/500
# Train RMSE: 0.2511
# Val RMSE: 0.2496, Val MAE: 0.1070
# Test RMSE: 0.3263, Test MAE: 0.1487
# ---------------------------------
# Model saved at epoch 55 with val RMSE 0.2496
# Patience grace period: 39
# ---------------------------------
# Epoch 56/500
# Train RMSE: 0.2510
# Val RMSE: 0.2496, Val MAE: 0.1073
# Test RMSE: 0.3259, Test MAE: 0.1489
# ---------------------------------
# Model saved at epoch 56 with val RMSE 0.2496
# Patience grace period: 38
# ---------------------------------
# Epoch 57/500
# Train RMSE: 0.2509
# Val RMSE: 0.2495, Val MAE: 0.1066
# Test RMSE: 0.3267, Test MAE: 0.1482
# ---------------------------------
# Model saved at epoch 57 with val RMSE 0.2495
# Patience grace period: 40
# ---------------------------------
# Epoch 58/500
# Train RMSE: 0.2509
# Val RMSE: 0.2495, Val MAE: 0.1074
# Test RMSE: 0.3252, Test MAE: 0.1489
# ---------------------------------
# Model saved at epoch 58 with val RMSE 0.2495
# Patience grace period: 39
# ---------------------------------
# Epoch 59/500
# Train RMSE: 0.2508
# Val RMSE: 0.2495, Val MAE: 0.1069
# Test RMSE: 0.3262, Test MAE: 0.1487
# ---------------------------------
# Model saved at epoch 59 with val RMSE 0.2495
# Patience grace period: 38
# ---------------------------------
# Epoch 60/500
# Train RMSE: 0.2508
# Val RMSE: 0.2494, Val MAE: 0.1075
# Test RMSE: 0.3248, Test MAE: 0.1492
# ---------------------------------
# Model saved at epoch 60 with val RMSE 0.2494
# Patience grace period: 37
# ---------------------------------
# Epoch 61/500
# Train RMSE: 0.2507
# Val RMSE: 0.2494, Val MAE: 0.1071
# Test RMSE: 0.3258, Test MAE: 0.1489
# ---------------------------------
# Model saved at epoch 61 with val RMSE 0.2494
# Patience grace period: 40
# ---------------------------------
# Epoch 62/500
# Train RMSE: 0.2507
# Val RMSE: 0.2494, Val MAE: 0.1070
# Test RMSE: 0.3262, Test MAE: 0.1487
# ---------------------------------
# Model saved at epoch 62 with val RMSE 0.2494
# Patience grace period: 39
# ---------------------------------
# Epoch 63/500
# Train RMSE: 0.2506
# Val RMSE: 0.2493, Val MAE: 0.1070
# Test RMSE: 0.3257, Test MAE: 0.1488
# ---------------------------------
# Model saved at epoch 63 with val RMSE 0.2493
# Patience grace period: 38
# ---------------------------------
# Epoch 64/500
# Train RMSE: 0.2505
# Val RMSE: 0.2493, Val MAE: 0.1063
# Test RMSE: 0.3269, Test MAE: 0.1483
# ---------------------------------
# Model saved at epoch 64 with val RMSE 0.2493
# Patience grace period: 37
# ---------------------------------
# Epoch 65/500
# Train RMSE: 0.2505
# Val RMSE: 0.2493, Val MAE: 0.1060
# Test RMSE: 0.3272, Test MAE: 0.1482
# ---------------------------------
# Patience grace period: 35
# ---------------------------------
# Epoch 66/500
# Train RMSE: 0.2504
# Val RMSE: 0.2492, Val MAE: 0.1068
# Test RMSE: 0.3261, Test MAE: 0.1487
# ---------------------------------
# Model saved at epoch 66 with val RMSE 0.2492
# Patience grace period: 40
# ---------------------------------
# Epoch 67/500
# Train RMSE: 0.2504
# Val RMSE: 0.2492, Val MAE: 0.1067
# Test RMSE: 0.3259, Test MAE: 0.1488
# ---------------------------------
# Model saved at epoch 67 with val RMSE 0.2492
# Patience grace period: 38
# ---------------------------------
# Epoch 68/500
# Train RMSE: 0.2503
# Val RMSE: 0.2492, Val MAE: 0.1064
# Test RMSE: 0.3269, Test MAE: 0.1488
# ---------------------------------
# Patience grace period: 36
# ---------------------------------
# Epoch 69/500
# Train RMSE: 0.2503
# Val RMSE: 0.2491, Val MAE: 0.1070
# Test RMSE: 0.3254, Test MAE: 0.1490
# ---------------------------------
# Model saved at epoch 69 with val RMSE 0.2491
# Patience grace period: 35
# ---------------------------------
# Epoch 70/500
# Train RMSE: 0.2502
# Val RMSE: 0.2491, Val MAE: 0.1072
# Test RMSE: 0.3252, Test MAE: 0.1493
# ---------------------------------
# Model saved at epoch 70 with val RMSE 0.2491
# Patience grace period: 34
# ---------------------------------
# Epoch 71/500
# Train RMSE: 0.2502
# Val RMSE: 0.2491, Val MAE: 0.1067
# Test RMSE: 0.3258, Test MAE: 0.1488
# ---------------------------------
# Model saved at epoch 71 with val RMSE 0.2491
# Patience grace period: 33
# ---------------------------------
# Epoch 72/500
# Train RMSE: 0.2501
# Val RMSE: 0.2490, Val MAE: 0.1068
# Test RMSE: 0.3257, Test MAE: 0.1489
# ---------------------------------
# Model saved at epoch 72 with val RMSE 0.2490
# Patience grace period: 40
# ---------------------------------
# Epoch 73/500
# Train RMSE: 0.2501
# Val RMSE: 0.2491, Val MAE: 0.1063
# Test RMSE: 0.3264, Test MAE: 0.1486
# ---------------------------------
# Patience grace period: 38
# ---------------------------------
# Epoch 74/500
# Train RMSE: 0.2500
# Val RMSE: 0.2490, Val MAE: 0.1069
# Test RMSE: 0.3252, Test MAE: 0.1490
# ---------------------------------
# Model saved at epoch 74 with val RMSE 0.2490
# Patience grace period: 37
# ---------------------------------
# Epoch 75/500
# Train RMSE: 0.2500
# Val RMSE: 0.2490, Val MAE: 0.1066
# Test RMSE: 0.3259, Test MAE: 0.1488
# ---------------------------------
# Model saved at epoch 75 with val RMSE 0.2490
# Patience grace period: 36
# ---------------------------------
# Epoch 76/500
# Train RMSE: 0.2500
# Val RMSE: 0.2490, Val MAE: 0.1069
# Test RMSE: 0.3253, Test MAE: 0.1491
# ---------------------------------
# Model saved at epoch 76 with val RMSE 0.2490
# Patience grace period: 35
# ---------------------------------
# Epoch 77/500
# Train RMSE: 0.2499
# Val RMSE: 0.2490, Val MAE: 0.1072
# Test RMSE: 0.3248, Test MAE: 0.1492
# ---------------------------------
# Patience grace period: 33
# ---------------------------------
# Epoch 78/500
# Train RMSE: 0.2499
# Val RMSE: 0.2489, Val MAE: 0.1063
# Test RMSE: 0.3264, Test MAE: 0.1487
# ---------------------------------
# Model saved at epoch 78 with val RMSE 0.2489
# Patience grace period: 40
# ---------------------------------
# Epoch 79/500
# Train RMSE: 0.2499
# Val RMSE: 0.2489, Val MAE: 0.1070
# Test RMSE: 0.3252, Test MAE: 0.1491
# ---------------------------------
# Model saved at epoch 79 with val RMSE 0.2489
# Patience grace period: 39
# ---------------------------------
# Epoch 80/500
# Train RMSE: 0.2498
# Val RMSE: 0.2489, Val MAE: 0.1064
# Test RMSE: 0.3258, Test MAE: 0.1489
# ---------------------------------
# Patience grace period: 37
# ---------------------------------
# Epoch 81/500
# Train RMSE: 0.2498
# Val RMSE: 0.2489, Val MAE: 0.1065
# Test RMSE: 0.3254, Test MAE: 0.1489
# ---------------------------------
# Model saved at epoch 81 with val RMSE 0.2489
# Patience grace period: 36
# ---------------------------------
# Epoch 82/500
# Train RMSE: 0.2498
# Val RMSE: 0.2488, Val MAE: 0.1065
# Test RMSE: 0.3257, Test MAE: 0.1489
# ---------------------------------
# Model saved at epoch 82 with val RMSE 0.2488
# Patience grace period: 40
# ---------------------------------
# Epoch 83/500
# Train RMSE: 0.2497
# Val RMSE: 0.2488, Val MAE: 0.1068
# Test RMSE: 0.3251, Test MAE: 0.1493
# ---------------------------------
# Patience grace period: 38
# ---------------------------------
# Epoch 84/500
# Train RMSE: 0.2497
# Val RMSE: 0.2488, Val MAE: 0.1068
# Test RMSE: 0.3252, Test MAE: 0.1492
# ---------------------------------
# Model saved at epoch 84 with val RMSE 0.2488
# Patience grace period: 37
# ---------------------------------
# Epoch 85/500
# Train RMSE: 0.2497
# Val RMSE: 0.2488, Val MAE: 0.1064
# Test RMSE: 0.3257, Test MAE: 0.1489
# ---------------------------------
# Model saved at epoch 85 with val RMSE 0.2488
# Patience grace period: 36
# ---------------------------------
# Epoch 86/500
# Train RMSE: 0.2496
# Val RMSE: 0.2488, Val MAE: 0.1064
# Test RMSE: 0.3256, Test MAE: 0.1489
# ---------------------------------
# Patience grace period: 34
# ---------------------------------
# Epoch 87/500
# Train RMSE: 0.2496
# Val RMSE: 0.2487, Val MAE: 0.1068
# Test RMSE: 0.3251, Test MAE: 0.1493
# ---------------------------------
# Model saved at epoch 87 with val RMSE 0.2487
# Patience grace period: 40
# ---------------------------------
# Epoch 88/500
# Train RMSE: 0.2496
# Val RMSE: 0.2488, Val MAE: 0.1066
# Test RMSE: 0.3255, Test MAE: 0.1491
# ---------------------------------
# Patience grace period: 38
# ---------------------------------
# Epoch 89/500
# Train RMSE: 0.2495
# Val RMSE: 0.2487, Val MAE: 0.1064
# Test RMSE: 0.3254, Test MAE: 0.1490
# ---------------------------------
# Patience grace period: 37
# ---------------------------------
# Epoch 90/500
# Train RMSE: 0.2495
# Val RMSE: 0.2487, Val MAE: 0.1064
# Test RMSE: 0.3255, Test MAE: 0.1492
# ---------------------------------
# Model saved at epoch 90 with val RMSE 0.2487
# Patience grace period: 36
# ---------------------------------
# Epoch 91/500
# Train RMSE: 0.2495
# Val RMSE: 0.2487, Val MAE: 0.1062
# Test RMSE: 0.3256, Test MAE: 0.1490
# ---------------------------------
# Model saved at epoch 91 with val RMSE 0.2487
# Patience grace period: 35
# ---------------------------------
# Epoch 92/500
# Train RMSE: 0.2495
# Val RMSE: 0.2487, Val MAE: 0.1070
# Test RMSE: 0.3244, Test MAE: 0.1496
# ---------------------------------
# Patience grace period: 33
# ---------------------------------
# Epoch 93/500
# Train RMSE: 0.2494
# Val RMSE: 0.2486, Val MAE: 0.1066
# Test RMSE: 0.3250, Test MAE: 0.1493
# ---------------------------------
# Model saved at epoch 93 with val RMSE 0.2486
# Patience grace period: 32
# ---------------------------------
# Epoch 94/500
# Train RMSE: 0.2494
# Val RMSE: 0.2486, Val MAE: 0.1064
# Test RMSE: 0.3255, Test MAE: 0.1492
# ---------------------------------
# Patience grace period: 30
# ---------------------------------
# Epoch 95/500
# Train RMSE: 0.2494
# Val RMSE: 0.2487, Val MAE: 0.1068
# Test RMSE: 0.3249, Test MAE: 0.1495
# ---------------------------------
# Patience grace period: 28
# ---------------------------------
# Epoch 96/500
# Train RMSE: 0.2494
# Val RMSE: 0.2486, Val MAE: 0.1068
# Test RMSE: 0.3247, Test MAE: 0.1495
# ---------------------------------
# Patience grace period: 27
# ---------------------------------
# Epoch 97/500
# Train RMSE: 0.2493
# Val RMSE: 0.2486, Val MAE: 0.1067
# Test RMSE: 0.3250, Test MAE: 0.1494
# ---------------------------------
# Patience grace period: 26
# ---------------------------------
# Epoch 98/500
# Train RMSE: 0.2493
# Val RMSE: 0.2486, Val MAE: 0.1063
# Test RMSE: 0.3258, Test MAE: 0.1490
# ---------------------------------
# Model saved at epoch 98 with val RMSE 0.2486
# Patience grace period: 40
# ---------------------------------
# Epoch 99/500
# Train RMSE: 0.2493
# Val RMSE: 0.2486, Val MAE: 0.1067
# Test RMSE: 0.3244, Test MAE: 0.1495
# ---------------------------------
# Patience grace period: 38
# ---------------------------------
# Epoch 100/500
# Train RMSE: 0.2492
# Val RMSE: 0.2486, Val MAE: 0.1061
# Test RMSE: 0.3261, Test MAE: 0.1489
# ---------------------------------
# Patience grace period: 37
# ---------------------------------
# Epoch 101/500
# Train RMSE: 0.2492
# Val RMSE: 0.2486, Val MAE: 0.1066
# Test RMSE: 0.3252, Test MAE: 0.1494
# ---------------------------------
# Model saved at epoch 101 with val RMSE 0.2486
# Patience grace period: 36
# ---------------------------------
# Epoch 102/500
# Train RMSE: 0.2492
# Val RMSE: 0.2485, Val MAE: 0.1065
# Test RMSE: 0.3252, Test MAE: 0.1493
# ---------------------------------
# Model saved at epoch 102 with val RMSE 0.2485
# Patience grace period: 35
# ---------------------------------
# Epoch 103/500
# Train RMSE: 0.2491
# Val RMSE: 0.2485, Val MAE: 0.1062
# Test RMSE: 0.3254, Test MAE: 0.1492
# ---------------------------------
# Model saved at epoch 103 with val RMSE 0.2485
# Patience grace period: 34
# ---------------------------------
# Epoch 104/500
# Train RMSE: 0.2491
# Val RMSE: 0.2486, Val MAE: 0.1068
# Test RMSE: 0.3246, Test MAE: 0.1498
# ---------------------------------
# Patience grace period: 32
# ---------------------------------
# Epoch 105/500
# Train RMSE: 0.2491
# Val RMSE: 0.2485, Val MAE: 0.1058
# Test RMSE: 0.3263, Test MAE: 0.1488
# ---------------------------------
# Model saved at epoch 105 with val RMSE 0.2485
# Patience grace period: 31
# ---------------------------------
# Epoch 106/500
# Train RMSE: 0.2491
# Val RMSE: 0.2485, Val MAE: 0.1065
# Test RMSE: 0.3247, Test MAE: 0.1495
# ---------------------------------
# Patience grace period: 29
# ---------------------------------
# Epoch 107/500
# Train RMSE: 0.2490
# Val RMSE: 0.2485, Val MAE: 0.1063
# Test RMSE: 0.3255, Test MAE: 0.1493
# ---------------------------------
# Model saved at epoch 107 with val RMSE 0.2485
# Patience grace period: 28
# ---------------------------------
# Epoch 108/500
# Train RMSE: 0.2490
# Val RMSE: 0.2484, Val MAE: 0.1064
# Test RMSE: 0.3251, Test MAE: 0.1495
# ---------------------------------
# Model saved at epoch 108 with val RMSE 0.2484
# Patience grace period: 40
# ---------------------------------
# Epoch 109/500
# Train RMSE: 0.2490
# Val RMSE: 0.2485, Val MAE: 0.1060
# Test RMSE: 0.3256, Test MAE: 0.1491
# ---------------------------------
# Patience grace period: 38
# ---------------------------------
# Epoch 110/500
# Train RMSE: 0.2490
# Val RMSE: 0.2485, Val MAE: 0.1058
# Test RMSE: 0.3262, Test MAE: 0.1490
# ---------------------------------
# Patience grace period: 37
# ---------------------------------
# Epoch 111/500
# Train RMSE: 0.2490
# Val RMSE: 0.2485, Val MAE: 0.1061
# Test RMSE: 0.3260, Test MAE: 0.1492
# ---------------------------------
# Patience grace period: 36
# ---------------------------------
# Epoch 112/500
# Train RMSE: 0.2489
# Val RMSE: 0.2484, Val MAE: 0.1067
# Test RMSE: 0.3248, Test MAE: 0.1498
# ---------------------------------
# Patience grace period: 35
# ---------------------------------
# Epoch 113/500
# Train RMSE: 0.2489
# Val RMSE: 0.2485, Val MAE: 0.1060
# Test RMSE: 0.3258, Test MAE: 0.1494
# ---------------------------------
# Patience grace period: 33
# ---------------------------------
# Epoch 114/500
# Train RMSE: 0.2489
# Val RMSE: 0.2484, Val MAE: 0.1062
# Test RMSE: 0.3251, Test MAE: 0.1494
# ---------------------------------
# Model saved at epoch 114 with val RMSE 0.2484
# Patience grace period: 32
# ---------------------------------
# Epoch 115/500
# Train RMSE: 0.2489
# Val RMSE: 0.2484, Val MAE: 0.1061
# Test RMSE: 0.3251, Test MAE: 0.1493
# ---------------------------------
# Model saved at epoch 115 with val RMSE 0.2484
# Patience grace period: 31
# ---------------------------------
# Epoch 116/500
# Train RMSE: 0.2488
# Val RMSE: 0.2484, Val MAE: 0.1057
# Test RMSE: 0.3266, Test MAE: 0.1490
# ---------------------------------
# Patience grace period: 29
# ---------------------------------
# Epoch 117/500
# Train RMSE: 0.2488
# Val RMSE: 0.2484, Val MAE: 0.1062
# Test RMSE: 0.3257, Test MAE: 0.1494
# ---------------------------------
# Patience grace period: 28
# ---------------------------------
# Epoch 118/500
# Train RMSE: 0.2488
# Val RMSE: 0.2484, Val MAE: 0.1069
# Test RMSE: 0.3241, Test MAE: 0.1501
# ---------------------------------
# Patience grace period: 27
# ---------------------------------
# Epoch 119/500
# Train RMSE: 0.2488
# Val RMSE: 0.2484, Val MAE: 0.1065
# Test RMSE: 0.3249, Test MAE: 0.1499
# ---------------------------------
# Model saved at epoch 119 with val RMSE 0.2484
# Patience grace period: 26
# ---------------------------------
# Epoch 120/500
# Train RMSE: 0.2488
# Val RMSE: 0.2484, Val MAE: 0.1065
# Test RMSE: 0.3248, Test MAE: 0.1498
# ---------------------------------
# Model saved at epoch 120 with val RMSE 0.2484
# Patience grace period: 25
# ---------------------------------
# Epoch 121/500
# Train RMSE: 0.2487
# Val RMSE: 0.2484, Val MAE: 0.1060
# Test RMSE: 0.3257, Test MAE: 0.1494
# ---------------------------------
# Patience grace period: 23
# ---------------------------------
# Epoch 122/500
# Train RMSE: 0.2487
# Val RMSE: 0.2484, Val MAE: 0.1068
# Test RMSE: 0.3241, Test MAE: 0.1500
# ---------------------------------
# Patience grace period: 21
# ---------------------------------
# Epoch 123/500
# Train RMSE: 0.2487
# Val RMSE: 0.2483, Val MAE: 0.1063
# Test RMSE: 0.3250, Test MAE: 0.1495
# ---------------------------------
# Model saved at epoch 123 with val RMSE 0.2483
# Patience grace period: 40
# ---------------------------------
# Epoch 124/500
# Train RMSE: 0.2487
# Val RMSE: 0.2483, Val MAE: 0.1067
# Test RMSE: 0.3242, Test MAE: 0.1499
# ---------------------------------
# Patience grace period: 38
# ---------------------------------
# Epoch 125/500
# Train RMSE: 0.2487
# Val RMSE: 0.2484, Val MAE: 0.1062
# Test RMSE: 0.3250, Test MAE: 0.1496
# ---------------------------------
# Patience grace period: 36
# ---------------------------------
# Epoch 126/500
# Train RMSE: 0.2486
# Val RMSE: 0.2483, Val MAE: 0.1066
# Test RMSE: 0.3245, Test MAE: 0.1500
# ---------------------------------
# Model saved at epoch 126 with val RMSE 0.2483
# Patience grace period: 35
# ---------------------------------
# Epoch 127/500
# Train RMSE: 0.2486
# Val RMSE: 0.2484, Val MAE: 0.1068
# Test RMSE: 0.3242, Test MAE: 0.1499
# ---------------------------------
# Patience grace period: 33
# ---------------------------------
# Epoch 128/500
# Train RMSE: 0.2486
# Val RMSE: 0.2483, Val MAE: 0.1058
# Test RMSE: 0.3258, Test MAE: 0.1494
# ---------------------------------
# Patience grace period: 32
# ---------------------------------
# Epoch 129/500
# Train RMSE: 0.2485
# Val RMSE: 0.2483, Val MAE: 0.1064
# Test RMSE: 0.3249, Test MAE: 0.1495
# ---------------------------------
# Model saved at epoch 129 with val RMSE 0.2483
# Patience grace period: 31
# ---------------------------------
# Epoch 130/500
# Train RMSE: 0.2485
# Val RMSE: 0.2484, Val MAE: 0.1057
# Test RMSE: 0.3263, Test MAE: 0.1493
# ---------------------------------
# Patience grace period: 29
# ---------------------------------
# Epoch 131/500
# Train RMSE: 0.2485
# Val RMSE: 0.2483, Val MAE: 0.1056
# Test RMSE: 0.3264, Test MAE: 0.1494
# ---------------------------------
# Patience grace period: 28
# ---------------------------------
# Epoch 132/500
# Train RMSE: 0.2485
# Val RMSE: 0.2484, Val MAE: 0.1054
# Test RMSE: 0.3267, Test MAE: 0.1490
# ---------------------------------
# Patience grace period: 26
# ---------------------------------
# Epoch 133/500
# Train RMSE: 0.2485
# Val RMSE: 0.2483, Val MAE: 0.1061
# Test RMSE: 0.3252, Test MAE: 0.1495
# ---------------------------------
# Model saved at epoch 133 with val RMSE 0.2483
# Patience grace period: 25
# ---------------------------------
# Epoch 134/500
# Train RMSE: 0.2485
# Val RMSE: 0.2483, Val MAE: 0.1055
# Test RMSE: 0.3265, Test MAE: 0.1492
# ---------------------------------
# Patience grace period: 23
# ---------------------------------
# Epoch 135/500
# Train RMSE: 0.2485
# Val RMSE: 0.2483, Val MAE: 0.1061
# Test RMSE: 0.3254, Test MAE: 0.1497
# ---------------------------------
# Patience grace period: 21
# ---------------------------------
# Epoch 136/500
# Train RMSE: 0.2485
# Val RMSE: 0.2482, Val MAE: 0.1060
# Test RMSE: 0.3253, Test MAE: 0.1497
# ---------------------------------
# Model saved at epoch 136 with val RMSE 0.2482
# Patience grace period: 40
# ---------------------------------
# Epoch 137/500
# Train RMSE: 0.2484
# Val RMSE: 0.2483, Val MAE: 0.1061
# Test RMSE: 0.3254, Test MAE: 0.1499
# ---------------------------------
# Patience grace period: 38
# ---------------------------------
# Epoch 138/500
# Train RMSE: 0.2484
# Val RMSE: 0.2482, Val MAE: 0.1065
# Test RMSE: 0.3244, Test MAE: 0.1502
# ---------------------------------
# Patience grace period: 37
# ---------------------------------
# Epoch 139/500
# Train RMSE: 0.2484
# Val RMSE: 0.2482, Val MAE: 0.1064
# Test RMSE: 0.3244, Test MAE: 0.1502
# ---------------------------------
# Patience grace period: 35
# ---------------------------------
# Epoch 140/500
# Train RMSE: 0.2484
# Val RMSE: 0.2483, Val MAE: 0.1059
# Test RMSE: 0.3255, Test MAE: 0.1498
# ---------------------------------
# Patience grace period: 33
# ---------------------------------
# Epoch 141/500
# Train RMSE: 0.2484
# Val RMSE: 0.2482, Val MAE: 0.1066
# Test RMSE: 0.3244, Test MAE: 0.1503
# ---------------------------------
# Patience grace period: 32
# ---------------------------------
# Epoch 142/500
# Train RMSE: 0.2483
# Val RMSE: 0.2482, Val MAE: 0.1063
# Test RMSE: 0.3250, Test MAE: 0.1499
# ---------------------------------
# Patience grace period: 31
# ---------------------------------
# Epoch 143/500
# Train RMSE: 0.2483
# Val RMSE: 0.2483, Val MAE: 0.1062
# Test RMSE: 0.3253, Test MAE: 0.1501
# ---------------------------------
# Patience grace period: 29
# ---------------------------------
# Epoch 144/500
# Train RMSE: 0.2483
# Val RMSE: 0.2483, Val MAE: 0.1057
# Test RMSE: 0.3266, Test MAE: 0.1496
# ---------------------------------
# Patience grace period: 27
# ---------------------------------
# Epoch 145/500
# Train RMSE: 0.2483
# Val RMSE: 0.2483, Val MAE: 0.1055
# Test RMSE: 0.3266, Test MAE: 0.1496
# ---------------------------------
# Patience grace period: 25
# ---------------------------------
# Epoch 146/500
# Train RMSE: 0.2483
# Val RMSE: 0.2482, Val MAE: 0.1057
# Test RMSE: 0.3260, Test MAE: 0.1497
# ---------------------------------
# Patience grace period: 24
# ---------------------------------
# Epoch 147/500
# Train RMSE: 0.2483
# Val RMSE: 0.2482, Val MAE: 0.1064
# Test RMSE: 0.3246, Test MAE: 0.1501
# ---------------------------------
# Model saved at epoch 147 with val RMSE 0.2482
# Patience grace period: 23
# ---------------------------------
# Epoch 148/500
# Train RMSE: 0.2482
# Val RMSE: 0.2482, Val MAE: 0.1065
# Test RMSE: 0.3242, Test MAE: 0.1501
# ---------------------------------
# Patience grace period: 21
# ---------------------------------
# Epoch 149/500
# Train RMSE: 0.2482
# Val RMSE: 0.2482, Val MAE: 0.1061
# Test RMSE: 0.3253, Test MAE: 0.1501
# ---------------------------------
# Patience grace period: 19
# ---------------------------------
# Epoch 150/500
# Train RMSE: 0.2482
# Val RMSE: 0.2482, Val MAE: 0.1067
# Test RMSE: 0.3242, Test MAE: 0.1503
# ---------------------------------
# Patience grace period: 18
# ---------------------------------
# Epoch 151/500
# Train RMSE: 0.2482
# Val RMSE: 0.2482, Val MAE: 0.1061
# Test RMSE: 0.3251, Test MAE: 0.1503
# ---------------------------------
# Patience grace period: 16
# ---------------------------------
# Epoch 152/500
# Train RMSE: 0.2482
# Val RMSE: 0.2482, Val MAE: 0.1057
# Test RMSE: 0.3258, Test MAE: 0.1497
# ---------------------------------
# Patience grace period: 14
# ---------------------------------
# Epoch 153/500
# Train RMSE: 0.2482
# Val RMSE: 0.2482, Val MAE: 0.1057
# Test RMSE: 0.3261, Test MAE: 0.1496
# ---------------------------------
# Patience grace period: 13
# ---------------------------------
# Epoch 154/500
# Train RMSE: 0.2482
# Val RMSE: 0.2482, Val MAE: 0.1064
# Test RMSE: 0.3244, Test MAE: 0.1502
# ---------------------------------
# Patience grace period: 11
# ---------------------------------
# Epoch 155/500
# Train RMSE: 0.2481
# Val RMSE: 0.2482, Val MAE: 0.1058
# Test RMSE: 0.3257, Test MAE: 0.1498
# ---------------------------------
# Patience grace period: 10
# ---------------------------------
# Epoch 156/500
# Train RMSE: 0.2481
# Val RMSE: 0.2482, Val MAE: 0.1058
# Test RMSE: 0.3257, Test MAE: 0.1499
# ---------------------------------
# Patience grace period: 8
# ---------------------------------
# Epoch 157/500
# Train RMSE: 0.2481
# Val RMSE: 0.2482, Val MAE: 0.1066
# Test RMSE: 0.3244, Test MAE: 0.1503
# ---------------------------------
# Model saved at epoch 157 with val RMSE 0.2482
# Patience grace period: 7
# ---------------------------------
# Epoch 158/500
# Train RMSE: 0.2481
# Val RMSE: 0.2482, Val MAE: 0.1054
# Test RMSE: 0.3266, Test MAE: 0.1493
# ---------------------------------
# Patience grace period: 5
# ---------------------------------
# Epoch 159/500
# Train RMSE: 0.2481
# Val RMSE: 0.2482, Val MAE: 0.1063
# Test RMSE: 0.3252, Test MAE: 0.1501
# ---------------------------------
# Patience grace period: 3
# ---------------------------------
# Epoch 160/500
# Train RMSE: 0.2481
# Val RMSE: 0.2482, Val MAE: 0.1065
# Test RMSE: 0.3246, Test MAE: 0.1503
# ---------------------------------
# Patience grace period: 1
# ---------------------------------
# Epoch 161/500
# Train RMSE: 0.2481
# Val RMSE: 0.2482, Val MAE: 0.1063
# Test RMSE: 0.3247, Test MAE: 0.1502
# ---------------------------------
# Model saved at epoch 161 with val RMSE 0.2482
# Patience grace period: 0
# Early stopping triggered at epoch 161
# Final Test RMSE: 0.3247, Final Test MAE: 0.1502
# <ipython-input-3-2a228d64b832>:126: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   self.model.load_state_dict(torch.load(os.path.join(save_dir, 'best_model.pth')))
# Pearson Corr: 0.7477081530727101
# Spearman Corr: 0.43060266492978333
# p-rmse: 0.3247108172432595
#        rmse       mae  seed                             subtask    method  \
# 0  0.324711  0.150198     1  openproblems_bmmc_cite_phase2_mod2  original
#
#     pearson p_value_pearson  spearman p_value_spearman
# 0  0.747708          0.0000  0.430603           0.0000
# ---------------------------------
# Epoch 1/500
# Train RMSE: 0.3746
# Val RMSE: 0.3229, Val MAE: 0.1327
# Test RMSE: 0.3994, Test MAE: 0.1770
# ---------------------------------
# Model saved at epoch 1 with val RMSE 0.3229
# Patience grace period: 40
# ---------------------------------
# Epoch 2/500
# Train RMSE: 0.3272
# Val RMSE: 0.2943, Val MAE: 0.1275
# Test RMSE: 0.3684, Test MAE: 0.1682
# ---------------------------------
# Model saved at epoch 2 with val RMSE 0.2943
# Patience grace period: 40
# ---------------------------------
# Epoch 3/500
# Train RMSE: 0.3051
# Val RMSE: 0.2796, Val MAE: 0.1207
# Test RMSE: 0.3554, Test MAE: 0.1606
# ---------------------------------
# Model saved at epoch 3 with val RMSE 0.2796
# Patience grace period: 40
# ---------------------------------
# Epoch 4/500
# Train RMSE: 0.2921
# Val RMSE: 0.2728, Val MAE: 0.1180
# Test RMSE: 0.3498, Test MAE: 0.1576
# ---------------------------------
# Model saved at epoch 4 with val RMSE 0.2728
# Patience grace period: 40
# ---------------------------------
# Epoch 5/500
# Train RMSE: 0.2841
# Val RMSE: 0.2688, Val MAE: 0.1168
# Test RMSE: 0.3461, Test MAE: 0.1561
# ---------------------------------
# Model saved at epoch 5 with val RMSE 0.2688
# Patience grace period: 40
# ---------------------------------
# Epoch 6/500
# Train RMSE: 0.2783
# Val RMSE: 0.2655, Val MAE: 0.1157
# Test RMSE: 0.3424, Test MAE: 0.1543
# ---------------------------------
# Model saved at epoch 6 with val RMSE 0.2655
# Patience grace period: 40
# ---------------------------------
# Epoch 7/500
# Train RMSE: 0.2736
# Val RMSE: 0.2629, Val MAE: 0.1145
# Test RMSE: 0.3394, Test MAE: 0.1525
# ---------------------------------
# Model saved at epoch 7 with val RMSE 0.2629
# Patience grace period: 40
# ---------------------------------
# Epoch 8/500
# Train RMSE: 0.2698
# Val RMSE: 0.2606, Val MAE: 0.1136
# Test RMSE: 0.3371, Test MAE: 0.1511
# ---------------------------------
# Model saved at epoch 8 with val RMSE 0.2606
# Patience grace period: 40
# ---------------------------------
# Epoch 9/500
# Train RMSE: 0.2667
# Val RMSE: 0.2590, Val MAE: 0.1119
# Test RMSE: 0.3367, Test MAE: 0.1494
# ---------------------------------
# Model saved at epoch 9 with val RMSE 0.2590
# Patience grace period: 40
# ---------------------------------
# Epoch 10/500
# Train RMSE: 0.2644
# Val RMSE: 0.2577, Val MAE: 0.1109
# Test RMSE: 0.3366, Test MAE: 0.1487
# ---------------------------------
# Model saved at epoch 10 with val RMSE 0.2577
# Patience grace period: 40
# ---------------------------------
# Epoch 11/500
# Train RMSE: 0.2626
# Val RMSE: 0.2566, Val MAE: 0.1111
# Test RMSE: 0.3345, Test MAE: 0.1487
# ---------------------------------
# Model saved at epoch 11 with val RMSE 0.2566
# Patience grace period: 40
# ---------------------------------
# Epoch 12/500
# Train RMSE: 0.2613
# Val RMSE: 0.2558, Val MAE: 0.1105
# Test RMSE: 0.3340, Test MAE: 0.1484
# ---------------------------------
# Model saved at epoch 12 with val RMSE 0.2558
# Patience grace period: 40
# ---------------------------------
# Epoch 13/500
# Train RMSE: 0.2603
# Val RMSE: 0.2553, Val MAE: 0.1097
# Test RMSE: 0.3340, Test MAE: 0.1476
# ---------------------------------
# Model saved at epoch 13 with val RMSE 0.2553
# Patience grace period: 40
# ---------------------------------
# Epoch 14/500
# Train RMSE: 0.2594
# Val RMSE: 0.2548, Val MAE: 0.1092
# Test RMSE: 0.3339, Test MAE: 0.1473
# ---------------------------------
# Model saved at epoch 14 with val RMSE 0.2548
# Patience grace period: 40
# ---------------------------------
# Epoch 15/500
# Train RMSE: 0.2587
# Val RMSE: 0.2543, Val MAE: 0.1095
# Test RMSE: 0.3327, Test MAE: 0.1475
# ---------------------------------
# Model saved at epoch 15 with val RMSE 0.2543
# Patience grace period: 40
# ---------------------------------
# Epoch 16/500
# Train RMSE: 0.2581
# Val RMSE: 0.2539, Val MAE: 0.1088
# Test RMSE: 0.3327, Test MAE: 0.1471
# ---------------------------------
# Model saved at epoch 16 with val RMSE 0.2539
# Patience grace period: 40
# ---------------------------------
# Epoch 17/500
# Train RMSE: 0.2576
# Val RMSE: 0.2537, Val MAE: 0.1084
# Test RMSE: 0.3327, Test MAE: 0.1469
# ---------------------------------
# Model saved at epoch 17 with val RMSE 0.2537
# Patience grace period: 40
# ---------------------------------
# Epoch 18/500
# Train RMSE: 0.2571
# Val RMSE: 0.2533, Val MAE: 0.1087
# Test RMSE: 0.3316, Test MAE: 0.1471
# ---------------------------------
# Model saved at epoch 18 with val RMSE 0.2533
# Patience grace period: 40
# ---------------------------------
# Epoch 19/500
# Train RMSE: 0.2567
# Val RMSE: 0.2530, Val MAE: 0.1091
# Test RMSE: 0.3305, Test MAE: 0.1473
# ---------------------------------
# Model saved at epoch 19 with val RMSE 0.2530
# Patience grace period: 40
# ---------------------------------
# Epoch 20/500
# Train RMSE: 0.2563
# Val RMSE: 0.2528, Val MAE: 0.1085
# Test RMSE: 0.3313, Test MAE: 0.1470
# ---------------------------------
# Model saved at epoch 20 with val RMSE 0.2528
# Patience grace period: 40
# ---------------------------------
# Epoch 21/500
# Train RMSE: 0.2560
# Val RMSE: 0.2526, Val MAE: 0.1082
# Test RMSE: 0.3311, Test MAE: 0.1469
# ---------------------------------
# Model saved at epoch 21 with val RMSE 0.2526
# Patience grace period: 40
# ---------------------------------
# Epoch 22/500
# Train RMSE: 0.2557
# Val RMSE: 0.2524, Val MAE: 0.1084
# Test RMSE: 0.3301, Test MAE: 0.1473
# ---------------------------------
# Model saved at epoch 22 with val RMSE 0.2524
# Patience grace period: 40
# ---------------------------------
# Epoch 23/500
# Train RMSE: 0.2554
# Val RMSE: 0.2522, Val MAE: 0.1083
# Test RMSE: 0.3301, Test MAE: 0.1473
# ---------------------------------
# Model saved at epoch 23 with val RMSE 0.2522
# Patience grace period: 40
# ---------------------------------
# Epoch 24/500
# Train RMSE: 0.2552
# Val RMSE: 0.2520, Val MAE: 0.1084
# Test RMSE: 0.3294, Test MAE: 0.1473
# ---------------------------------
# Model saved at epoch 24 with val RMSE 0.2520
# Patience grace period: 40
# ---------------------------------
# Epoch 25/500
# Train RMSE: 0.2549
# Val RMSE: 0.2519, Val MAE: 0.1076
# Test RMSE: 0.3300, Test MAE: 0.1470
# ---------------------------------
# Model saved at epoch 25 with val RMSE 0.2519
# Patience grace period: 39
# ---------------------------------
# Epoch 26/500
# Train RMSE: 0.2547
# Val RMSE: 0.2517, Val MAE: 0.1081
# Test RMSE: 0.3291, Test MAE: 0.1473
# ---------------------------------
# Model saved at epoch 26 with val RMSE 0.2517
# Patience grace period: 40
# ---------------------------------
# Epoch 27/500
# Train RMSE: 0.2545
# Val RMSE: 0.2516, Val MAE: 0.1075
# Test RMSE: 0.3300, Test MAE: 0.1470
# ---------------------------------
# Model saved at epoch 27 with val RMSE 0.2516
# Patience grace period: 39
# ---------------------------------
# Epoch 28/500
# Train RMSE: 0.2543
# Val RMSE: 0.2515, Val MAE: 0.1074
# Test RMSE: 0.3298, Test MAE: 0.1471
# ---------------------------------
# Model saved at epoch 28 with val RMSE 0.2515
# Patience grace period: 40
# ---------------------------------
# Epoch 29/500
# Train RMSE: 0.2541
# Val RMSE: 0.2514, Val MAE: 0.1072
# Test RMSE: 0.3295, Test MAE: 0.1471
# ---------------------------------
# Model saved at epoch 29 with val RMSE 0.2514
# Patience grace period: 40
# ---------------------------------
# Epoch 30/500
# Train RMSE: 0.2539
# Val RMSE: 0.2513, Val MAE: 0.1073
# Test RMSE: 0.3298, Test MAE: 0.1471
# ---------------------------------
# Model saved at epoch 30 with val RMSE 0.2513
# Patience grace period: 40
# ---------------------------------
# Epoch 31/500
# Train RMSE: 0.2537
# Val RMSE: 0.2512, Val MAE: 0.1071
# Test RMSE: 0.3292, Test MAE: 0.1471
# ---------------------------------
# Model saved at epoch 31 with val RMSE 0.2512
# Patience grace period: 40
# ---------------------------------
# Epoch 32/500
# Train RMSE: 0.2536
# Val RMSE: 0.2511, Val MAE: 0.1074
# ...
# Epoch 97/500
# Train RMSE: 0.2493
# Val RMSE: 0.2486, Val MAE: 0.1063
# Test RMSE: 0.3252, Test MAE: 0.1496
# ---------------------------------
# Model saved at epoch 97 with val RMSE 0.2486
# Patience grace period: 33
# ---------------------------------
# Epoch 98/500
# Train RMSE: 0.2493
# Val RMSE: 0.2486, Val MAE: 0.1057
# Test RMSE: 0.3263, Test MAE: 0.1493
# ---------------------------------
# Patience grace period: 31
# ---------------------------------
# Epoch 99/500
# Train RMSE: 0.2492
# Val RMSE: 0.2485, Val MAE: 0.1061
# Test RMSE: 0.3257, Test MAE: 0.1496
# ---------------------------------
# Model saved at epoch 99 with val RMSE 0.2485
# Patience grace period: 30
# ---------------------------------
# Epoch 100/500
# Train RMSE: 0.2492
# Val RMSE: 0.2485, Val MAE: 0.1062
# Test RMSE: 0.3253, Test MAE: 0.1498
# ---------------------------------
# Model saved at epoch 100 with val RMSE 0.2485
# Patience grace period: 40
# ---------------------------------
# Epoch 101/500
# Train RMSE: 0.2492
# Val RMSE: 0.2486, Val MAE: 0.1059
# Test RMSE: 0.3261, Test MAE: 0.1495
# ---------------------------------
# Patience grace period: 38
# ---------------------------------
# Epoch 102/500
# Train RMSE: 0.2492
# Val RMSE: 0.2485, Val MAE: 0.1065
# Test RMSE: 0.3252, Test MAE: 0.1500
# ---------------------------------
# Model saved at epoch 102 with val RMSE 0.2485
# Patience grace period: 37
# ---------------------------------
# Epoch 103/500
# Train RMSE: 0.2491
# Val RMSE: 0.2485, Val MAE: 0.1056
# Test RMSE: 0.3260, Test MAE: 0.1494
# ---------------------------------
# Patience grace period: 35
# ---------------------------------
# Epoch 104/500
# Train RMSE: 0.2491
# Val RMSE: 0.2485, Val MAE: 0.1057
# Test RMSE: 0.3257, Test MAE: 0.1494
# ---------------------------------
# Model saved at epoch 104 with val RMSE 0.2485
# Patience grace period: 34
# ---------------------------------
# Epoch 105/500
# Train RMSE: 0.2491
# Val RMSE: 0.2485, Val MAE: 0.1067
# Test RMSE: 0.3245, Test MAE: 0.1501
# ---------------------------------
# Patience grace period: 32
# ---------------------------------
# Epoch 106/500
# Train RMSE: 0.2491
# Val RMSE: 0.2485, Val MAE: 0.1063
# Test RMSE: 0.3253, Test MAE: 0.1499
# ---------------------------------
# Model saved at epoch 106 with val RMSE 0.2485
# Patience grace period: 31
# ---------------------------------
# Epoch 107/500
# Train RMSE: 0.2491
# Val RMSE: 0.2485, Val MAE: 0.1066
# Test RMSE: 0.3244, Test MAE: 0.1502
# ---------------------------------
# Model saved at epoch 107 with val RMSE 0.2485
# Patience grace period: 30
# ---------------------------------
# Epoch 108/500
# Train RMSE: 0.2490
# Val RMSE: 0.2485, Val MAE: 0.1060
# Test RMSE: 0.3258, Test MAE: 0.1497
# ---------------------------------
# Patience grace period: 28
# ---------------------------------
# Epoch 109/500
# Train RMSE: 0.2490
# Val RMSE: 0.2484, Val MAE: 0.1064
# Test RMSE: 0.3249, Test MAE: 0.1500
# ---------------------------------
# Model saved at epoch 109 with val RMSE 0.2484
# Patience grace period: 40
# ---------------------------------
# Epoch 110/500
# Train RMSE: 0.2490
# Val RMSE: 0.2484, Val MAE: 0.1060
# Test RMSE: 0.3252, Test MAE: 0.1498
# ---------------------------------
# Model saved at epoch 110 with val RMSE 0.2484
# Patience grace period: 39
# ---------------------------------
# Epoch 111/500
# Train RMSE: 0.2489
# Val RMSE: 0.2484, Val MAE: 0.1062
# Test RMSE: 0.3249, Test MAE: 0.1501
# ---------------------------------
# Patience grace period: 37
# ---------------------------------
# Epoch 112/500
# Train RMSE: 0.2489
# Val RMSE: 0.2484, Val MAE: 0.1060
# Test RMSE: 0.3255, Test MAE: 0.1499
# ---------------------------------
# Patience grace period: 35
# ---------------------------------
# Epoch 113/500
# Train RMSE: 0.2489
# Val RMSE: 0.2484, Val MAE: 0.1061
# Test RMSE: 0.3251, Test MAE: 0.1497
# ---------------------------------
# Model saved at epoch 113 with val RMSE 0.2484
# Patience grace period: 34
# ---------------------------------
# Epoch 114/500
# Train RMSE: 0.2489
# Val RMSE: 0.2484, Val MAE: 0.1064
# Test RMSE: 0.3251, Test MAE: 0.1501
# ---------------------------------
# Model saved at epoch 114 with val RMSE 0.2484
# Patience grace period: 33
# ---------------------------------
# Epoch 115/500
# Train RMSE: 0.2489
# Val RMSE: 0.2484, Val MAE: 0.1060
# Test RMSE: 0.3253, Test MAE: 0.1499
# ---------------------------------
# Patience grace period: 31
# ---------------------------------
# Epoch 116/500
# Train RMSE: 0.2489
# Val RMSE: 0.2483, Val MAE: 0.1064
# Test RMSE: 0.3247, Test MAE: 0.1501
# ---------------------------------
# Model saved at epoch 116 with val RMSE 0.2483
# Patience grace period: 30
# ---------------------------------
# Epoch 117/500
# Train RMSE: 0.2488
# Val RMSE: 0.2484, Val MAE: 0.1063
# Test RMSE: 0.3251, Test MAE: 0.1501
# ---------------------------------
# Patience grace period: 28
# ---------------------------------
# Epoch 118/500
# Train RMSE: 0.2488
# Val RMSE: 0.2483, Val MAE: 0.1059
# Test RMSE: 0.3255, Test MAE: 0.1496
# ---------------------------------
# Model saved at epoch 118 with val RMSE 0.2483
# Patience grace period: 27
# ---------------------------------
# Epoch 119/500
# Train RMSE: 0.2488
# Val RMSE: 0.2483, Val MAE: 0.1062
# Test RMSE: 0.3254, Test MAE: 0.1501
# ---------------------------------
# Patience grace period: 25
# ---------------------------------
# Epoch 120/500
# Train RMSE: 0.2488
# Val RMSE: 0.2483, Val MAE: 0.1060
# Test RMSE: 0.3256, Test MAE: 0.1498
# ---------------------------------
# Model saved at epoch 120 with val RMSE 0.2483
# Patience grace period: 40
# ---------------------------------
# Epoch 121/500
# Train RMSE: 0.2487
# Val RMSE: 0.2483, Val MAE: 0.1059
# Test RMSE: 0.3252, Test MAE: 0.1499
# ---------------------------------
# Patience grace period: 38
# ---------------------------------
# Epoch 122/500
# Train RMSE: 0.2487
# Val RMSE: 0.2483, Val MAE: 0.1060
# Test RMSE: 0.3259, Test MAE: 0.1501
# ---------------------------------
# Patience grace period: 36
# ---------------------------------
# Epoch 123/500
# Train RMSE: 0.2487
# Val RMSE: 0.2483, Val MAE: 0.1065
# Test RMSE: 0.3249, Test MAE: 0.1504
# ---------------------------------
# Patience grace period: 35
# ---------------------------------
# Epoch 124/500
# Train RMSE: 0.2487
# Val RMSE: 0.2483, Val MAE: 0.1059
# Test RMSE: 0.3259, Test MAE: 0.1500
# ---------------------------------
# Patience grace period: 34
# ---------------------------------
# Epoch 125/500
# Train RMSE: 0.2487
# Val RMSE: 0.2483, Val MAE: 0.1061
# Test RMSE: 0.3254, Test MAE: 0.1500
# ---------------------------------
# Model saved at epoch 125 with val RMSE 0.2483
# Patience grace period: 33
# ---------------------------------
# Epoch 126/500
# Train RMSE: 0.2486
# Val RMSE: 0.2483, Val MAE: 0.1062
# Test RMSE: 0.3248, Test MAE: 0.1502
# ---------------------------------
# Model saved at epoch 126 with val RMSE 0.2483
# Patience grace period: 32
# ---------------------------------
# Epoch 127/500
# Train RMSE: 0.2486
# Val RMSE: 0.2483, Val MAE: 0.1062
# Test RMSE: 0.3247, Test MAE: 0.1503
# ---------------------------------
# Patience grace period: 30
# ---------------------------------
# Epoch 128/500
# Train RMSE: 0.2486
# Val RMSE: 0.2483, Val MAE: 0.1061
# Test RMSE: 0.3248, Test MAE: 0.1502
# ---------------------------------
# Patience grace period: 28
# ---------------------------------
# Epoch 129/500
# Train RMSE: 0.2486
# Val RMSE: 0.2483, Val MAE: 0.1066
# Test RMSE: 0.3245, Test MAE: 0.1505
# ---------------------------------
# Patience grace period: 26
# ---------------------------------
# Epoch 130/500
# Train RMSE: 0.2486
# Val RMSE: 0.2482, Val MAE: 0.1063
# Test RMSE: 0.3247, Test MAE: 0.1504
# ---------------------------------
# Model saved at epoch 130 with val RMSE 0.2482
# Patience grace period: 25
# ---------------------------------
# Epoch 131/500
# Train RMSE: 0.2486
# Val RMSE: 0.2483, Val MAE: 0.1059
# Test RMSE: 0.3255, Test MAE: 0.1500
# ---------------------------------
# Patience grace period: 23
# ---------------------------------
# Epoch 132/500
# Train RMSE: 0.2486
# Val RMSE: 0.2482, Val MAE: 0.1060
# Test RMSE: 0.3259, Test MAE: 0.1498
# ---------------------------------
# Model saved at epoch 132 with val RMSE 0.2482
# Patience grace period: 22
# ---------------------------------
# Epoch 133/500
# Train RMSE: 0.2485
# Val RMSE: 0.2482, Val MAE: 0.1060
# Test RMSE: 0.3252, Test MAE: 0.1502
# ---------------------------------
# Model saved at epoch 133 with val RMSE 0.2482
# Patience grace period: 21
# ---------------------------------
# Epoch 134/500
# Train RMSE: 0.2485
# Val RMSE: 0.2482, Val MAE: 0.1054
# Test RMSE: 0.3259, Test MAE: 0.1496
# ---------------------------------
# Model saved at epoch 134 with val RMSE 0.2482
# Patience grace period: 19
# ---------------------------------
# Epoch 135/500
# Train RMSE: 0.2485
# Val RMSE: 0.2482, Val MAE: 0.1060
# Test RMSE: 0.3252, Test MAE: 0.1501
# ---------------------------------
# Model saved at epoch 135 with val RMSE 0.2482
# Patience grace period: 17
# ---------------------------------
# Epoch 136/500
# Train RMSE: 0.2485
# Val RMSE: 0.2482, Val MAE: 0.1060
# Test RMSE: 0.3250, Test MAE: 0.1502
# ---------------------------------
# Model saved at epoch 136 with val RMSE 0.2482
# Patience grace period: 40
# ---------------------------------
# Epoch 137/500
# Train RMSE: 0.2485
# Val RMSE: 0.2482, Val MAE: 0.1054
# Test RMSE: 0.3261, Test MAE: 0.1497
# ---------------------------------
# Patience grace period: 38
# ---------------------------------
# Epoch 138/500
# Train RMSE: 0.2485
# Val RMSE: 0.2482, Val MAE: 0.1056
# Test RMSE: 0.3258, Test MAE: 0.1502
# ---------------------------------
# Patience grace period: 37
# ---------------------------------
# Epoch 139/500
# Train RMSE: 0.2484
# Val RMSE: 0.2482, Val MAE: 0.1061
# Test RMSE: 0.3251, Test MAE: 0.1500
# ---------------------------------
# Patience grace period: 36
# ---------------------------------
# Epoch 140/500
# Train RMSE: 0.2484
# Val RMSE: 0.2482, Val MAE: 0.1063
# Test RMSE: 0.3249, Test MAE: 0.1506
# ---------------------------------
# Model saved at epoch 140 with val RMSE 0.2482
# Patience grace period: 35
# ---------------------------------
# Epoch 141/500
# Train RMSE: 0.2484
# Val RMSE: 0.2482, Val MAE: 0.1059
# Test RMSE: 0.3250, Test MAE: 0.1502
# ---------------------------------
# Model saved at epoch 141 with val RMSE 0.2482
# Patience grace period: 34
# ---------------------------------
# Epoch 142/500
# Train RMSE: 0.2484
# Val RMSE: 0.2482, Val MAE: 0.1058
# Test RMSE: 0.3254, Test MAE: 0.1501
# ---------------------------------
# Patience grace period: 32
# ---------------------------------
# Epoch 143/500
# Train RMSE: 0.2484
# Val RMSE: 0.2482, Val MAE: 0.1066
# Test RMSE: 0.3239, Test MAE: 0.1507
# ---------------------------------
# Patience grace period: 30
# ---------------------------------
# Epoch 144/500
# Train RMSE: 0.2484
# Val RMSE: 0.2482, Val MAE: 0.1054
# Test RMSE: 0.3257, Test MAE: 0.1498
# ---------------------------------
# Patience grace period: 29
# ---------------------------------
# Epoch 145/500
# Train RMSE: 0.2483
# Val RMSE: 0.2482, Val MAE: 0.1054
# Test RMSE: 0.3261, Test MAE: 0.1499
# ---------------------------------
# Patience grace period: 27
# ---------------------------------
# Epoch 146/500
# Train RMSE: 0.2483
# Val RMSE: 0.2482, Val MAE: 0.1058
# Test RMSE: 0.3254, Test MAE: 0.1503
# ---------------------------------
# Patience grace period: 26
# ---------------------------------
# Epoch 147/500
# Train RMSE: 0.2483
# Val RMSE: 0.2482, Val MAE: 0.1063
# Test RMSE: 0.3247, Test MAE: 0.1505
# ---------------------------------
# Patience grace period: 24
# ---------------------------------
# Epoch 148/500
# Train RMSE: 0.2483
# Val RMSE: 0.2481, Val MAE: 0.1062
# Test RMSE: 0.3248, Test MAE: 0.1503
# ---------------------------------
# Model saved at epoch 148 with val RMSE 0.2481
# Patience grace period: 23
# ---------------------------------
# Epoch 149/500
# Train RMSE: 0.2483
# Val RMSE: 0.2482, Val MAE: 0.1054
# Test RMSE: 0.3261, Test MAE: 0.1496
# ---------------------------------
# Patience grace period: 21
# ---------------------------------
# Epoch 150/500
# Train RMSE: 0.2482
# Val RMSE: 0.2481, Val MAE: 0.1061
# Test RMSE: 0.3249, Test MAE: 0.1502
# ---------------------------------
# Model saved at epoch 150 with val RMSE 0.2481
# Patience grace period: 20
# ---------------------------------
# Epoch 151/500
# Train RMSE: 0.2483
# Val RMSE: 0.2481, Val MAE: 0.1061
# Test RMSE: 0.3250, Test MAE: 0.1505
# ---------------------------------
# Model saved at epoch 151 with val RMSE 0.2481
# Patience grace period: 19
# ---------------------------------
# Epoch 152/500
# Train RMSE: 0.2483
# Val RMSE: 0.2482, Val MAE: 0.1065
# Test RMSE: 0.3241, Test MAE: 0.1509
# ---------------------------------
# Patience grace period: 17
# ---------------------------------
# Epoch 153/500
# Train RMSE: 0.2482
# Val RMSE: 0.2481, Val MAE: 0.1059
# Test RMSE: 0.3252, Test MAE: 0.1504
# ---------------------------------
# Patience grace period: 16
# ---------------------------------
# Epoch 154/500
# Train RMSE: 0.2482
# Val RMSE: 0.2481, Val MAE: 0.1058
# Test RMSE: 0.3253, Test MAE: 0.1501
# ---------------------------------
# Model saved at epoch 154 with val RMSE 0.2481
# Patience grace period: 15
# ---------------------------------
# Epoch 155/500
# Train RMSE: 0.2482
# Val RMSE: 0.2481, Val MAE: 0.1060
# Test RMSE: 0.3252, Test MAE: 0.1504
# ---------------------------------
# Patience grace period: 13
# ---------------------------------
# Epoch 156/500
# Train RMSE: 0.2482
# Val RMSE: 0.2481, Val MAE: 0.1061
# Test RMSE: 0.3244, Test MAE: 0.1507
# ---------------------------------
# Model saved at epoch 156 with val RMSE 0.2481
# Patience grace period: 12
# ---------------------------------
# Epoch 157/500
# Train RMSE: 0.2482
# Val RMSE: 0.2481, Val MAE: 0.1061
# Test RMSE: 0.3249, Test MAE: 0.1506
# ---------------------------------
# Patience grace period: 10
# ---------------------------------
# Epoch 158/500
# Train RMSE: 0.2481
# Val RMSE: 0.2481, Val MAE: 0.1058
# Test RMSE: 0.3251, Test MAE: 0.1502
# ---------------------------------
# Model saved at epoch 158 with val RMSE 0.2481
# Patience grace period: 9
# ---------------------------------
# Epoch 159/500
# Train RMSE: 0.2481
# Val RMSE: 0.2481, Val MAE: 0.1062
# Test RMSE: 0.3249, Test MAE: 0.1507
# ---------------------------------
# Patience grace period: 7
# ---------------------------------
# Epoch 160/500
# Train RMSE: 0.2481
# Val RMSE: 0.2481, Val MAE: 0.1063
# Test RMSE: 0.3245, Test MAE: 0.1507
# ---------------------------------
# Patience grace period: 5
# ---------------------------------
# Epoch 161/500
# Train RMSE: 0.2481
# Val RMSE: 0.2481, Val MAE: 0.1063
# Test RMSE: 0.3242, Test MAE: 0.1510
# ---------------------------------
# Patience grace period: 3
# ---------------------------------
# Epoch 162/500
# Train RMSE: 0.2481
# Val RMSE: 0.2481, Val MAE: 0.1057
# Test RMSE: 0.3254, Test MAE: 0.1503
# ---------------------------------
# Patience grace period: 2
# ---------------------------------
# Epoch 163/500
# Train RMSE: 0.2481
# Val RMSE: 0.2481, Val MAE: 0.1055
# Test RMSE: 0.3255, Test MAE: 0.1501
# ---------------------------------
# Patience grace period: 0
# Early stopping triggered at epoch 163
# Final Test RMSE: 0.3251, Final Test MAE: 0.1502
# <ipython-input-3-2a228d64b832>:126: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   self.model.load_state_dict(torch.load(os.path.join(save_dir, 'best_model.pth')))
# Pearson Corr: 0.7473741230969665
# Spearman Corr: 0.42969693843498014
# p-rmse: 0.32514602700055356
#        rmse       mae  seed                             subtask    method  \
# 0  0.325146  0.150167     5  openproblems_bmmc_cite_phase2_mod2  original
#
#     pearson p_value_pearson  spearman p_value_spearman
# 0  0.747374          0.0000  0.429697           0.0000

# %%
config_hierachical_PROTEIN = {
    "subtask": "openproblems_bmmc_cite_phase2_mod2",
    "batch_size": 520,
    "act": "relu",
    "conv_flow": ["gat"],
    "agg_flow": [None],
    "device": "cuda",
    "learning_rate": 0.000064,
    "hidden_size": 280,
    "num_heads": 6,
    "n_neigbours": 3,
    "metric": "nan_euclidean",
    "n_components": 1200,
    "dropout_rate": 0.2,
    "num_epochs": 500,
    "seed": 1,
    "es_patience": 40,
    "es_min_delta": 0.0001,
    "es_rate_threshold": 0.00002,
    "layer_dim_ex": 3,
    "verbose": True,
    "sample": True,
    "preprocessing_type": "None",
    "variant": "original",
    "num_clusters": 10
}

pipeline(**config_hierachical_PROTEIN)
# Out:
# [INFO][2025-04-16 07:13:42,922][dance][_load_raw_data] Loading /content/data/openproblems_bmmc_cite_phase2_mod2/openproblems_bmmc_cite_phase2_mod2.censor_dataset.output_train_mod1.h5ad
# Initializing pipeline...
# [INFO][2025-04-16 07:13:43,576][dance][_load_raw_data] Loading /content/data/openproblems_bmmc_cite_phase2_mod2/openproblems_bmmc_cite_phase2_mod2.censor_dataset.output_train_mod2.h5ad
# [INFO][2025-04-16 07:13:51,281][dance][_load_raw_data] Loading /content/data/openproblems_bmmc_cite_phase2_mod2/openproblems_bmmc_cite_phase2_mod2.censor_dataset.output_test_mod1.h5ad
# [INFO][2025-04-16 07:13:51,307][dance][_load_raw_data] Loading /content/data/openproblems_bmmc_cite_phase2_mod2/openproblems_bmmc_cite_phase2_mod2.censor_dataset.output_test_mod2.h5ad
# [INFO][2025-04-16 07:13:51,507][dance][_maybe_preprocess] Preprocessing done.
# /usr/local/lib/python3.11/dist-packages/mudata/_core/mudata.py:1531: FutureWarning: From 0.4 .update() will not pull obs/var columns from individual modalities by default anymore. Set mudata.set_options(pull_on_update=False) to adopt the new behaviour, which will become the default. Use new pull_obs/pull_var and push_obs/push_var methods for more flexibility.
#   self._update_attr("var", axis=0, join_common=join_common)
# /usr/local/lib/python3.11/dist-packages/mudata/_core/mudata.py:931: UserWarning: Cannot join columns with the same name because var_names are intersecting.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/mudata/_core/mudata.py:1429: FutureWarning: From 0.4 .update() will not pull obs/var columns from individual modalities by default anymore. Set mudata.set_options(pull_on_update=False) to adopt the new behaviour, which will become the default. Use new pull_obs/pull_var and push_obs/push_var methods for more flexibility.
#   self._update_attr("obs", axis=1, join_common=join_common)
# /usr/local/lib/python3.11/dist-packages/mudata/_core/mudata.py:1558: UserWarning: Modality names will be prepended to var_names since there are identical var_names in different modalities.
#   warnings.warn(
# [INFO][2025-04-16 07:13:58,496][dance][set_config_from_dict] Setting config 'feature_mod' to 'mod1'
# [INFO][2025-04-16 07:13:58,497][dance][set_config_from_dict] Setting config 'label_mod' to 'mod2'
# [INFO][2025-04-16 07:13:58,498][dance][load_data] Raw data loaded:
# Data object that wraps (.data):
# MuData object with n_obs × n_vars = 67175 × 14087
#   uns:	'dance_config'
#   2 modalities
#     mod1:	67175 x 134
#       obs:	'batch'
#       layers:	'counts'
#     mod2:	67175 x 13953
#       obs:	'batch'
#       layers:	'counts'
# [INFO][2025-04-16 07:13:58,622][dance][wrapped_func] Took 0:00:15.700218 to load and process data.
# Performing data processing using GraphCreator...
# Data processing using GraphCreator complete and saved.
# ---------------------------------
# Epoch 1/500
# Train RMSE: 0.3737
# Val RMSE: 0.3212, Val MAE: 0.1327
# Test RMSE: 0.3978, Test MAE: 0.1766
# ---------------------------------
# Model saved at epoch 1 with val RMSE 0.3212
# Patience grace period: 40
# ---------------------------------
# Epoch 2/500
# Train RMSE: 0.3260
# Val RMSE: 0.2939, Val MAE: 0.1262
# Test RMSE: 0.3693, Test MAE: 0.1671
# ---------------------------------
# Model saved at epoch 2 with val RMSE 0.2939
# Patience grace period: 40
# ---------------------------------
# Epoch 3/500
# Train RMSE: 0.3044
# Val RMSE: 0.2792, Val MAE: 0.1206
# Test RMSE: 0.3554, Test MAE: 0.1602
# ---------------------------------
# Model saved at epoch 3 with val RMSE 0.2792
# Patience grace period: 40
# ---------------------------------
# Epoch 4/500
# Train RMSE: 0.2916
# Val RMSE: 0.2720, Val MAE: 0.1181
# Test RMSE: 0.3489, Test MAE: 0.1575
# ---------------------------------
# Model saved at epoch 4 with val RMSE 0.2720
# Patience grace period: 40
# ---------------------------------
# Epoch 5/500
# Train RMSE: 0.2836
# Val RMSE: 0.2681, Val MAE: 0.1168
# Test RMSE: 0.3454, Test MAE: 0.1561
# ---------------------------------
# Model saved at epoch 5 with val RMSE 0.2681
# Patience grace period: 40
# ---------------------------------
# Epoch 6/500
# Train RMSE: 0.2779
# Val RMSE: 0.2650, Val MAE: 0.1154
# Test RMSE: 0.3426, Test MAE: 0.1543
# ---------------------------------
# Model saved at epoch 6 with val RMSE 0.2650
# Patience grace period: 40
# ---------------------------------
# Epoch 7/500
# Train RMSE: 0.2732
# Val RMSE: 0.2624, Val MAE: 0.1141
# Test RMSE: 0.3399, Test MAE: 0.1527
# ---------------------------------
# Model saved at epoch 7 with val RMSE 0.2624
# Patience grace period: 40
# ---------------------------------
# Epoch 8/500
# Train RMSE: 0.2694
# Val RMSE: 0.2603, Val MAE: 0.1127
# Test RMSE: 0.3382, Test MAE: 0.1512
# ---------------------------------
# Model saved at epoch 8 with val RMSE 0.2603
# Patience grace period: 40
# ---------------------------------
# Epoch 9/500
# Train RMSE: 0.2665
# Val RMSE: 0.2588, Val MAE: 0.1115
# Test RMSE: 0.3376, Test MAE: 0.1499
# ---------------------------------
# Model saved at epoch 9 with val RMSE 0.2588
# Patience grace period: 40
# ---------------------------------
# Epoch 10/500
# Train RMSE: 0.2642
# Val RMSE: 0.2576, Val MAE: 0.1106
# Test RMSE: 0.3368, Test MAE: 0.1492
# ---------------------------------
# Model saved at epoch 10 with val RMSE 0.2576
# Patience grace period: 40
# ---------------------------------
# Epoch 11/500
# Train RMSE: 0.2625
# Val RMSE: 0.2567, Val MAE: 0.1102
# Test RMSE: 0.3358, Test MAE: 0.1488
# ---------------------------------
# Model saved at epoch 11 with val RMSE 0.2567
# Patience grace period: 40
# ---------------------------------
# Epoch 12/500
# Train RMSE: 0.2613
# Val RMSE: 0.2558, Val MAE: 0.1106
# Test RMSE: 0.3337, Test MAE: 0.1490
# ---------------------------------
# Model saved at epoch 12 with val RMSE 0.2558
# Patience grace period: 40
# ---------------------------------
# Epoch 13/500
# Train RMSE: 0.2602
# Val RMSE: 0.2554, Val MAE: 0.1095
# Test RMSE: 0.3349, Test MAE: 0.1481
# ---------------------------------
# Model saved at epoch 13 with val RMSE 0.2554
# Patience grace period: 40
# ---------------------------------
# Epoch 14/500
# Train RMSE: 0.2594
# Val RMSE: 0.2550, Val MAE: 0.1088
# Test RMSE: 0.3347, Test MAE: 0.1475
# ---------------------------------
# Model saved at epoch 14 with val RMSE 0.2550
# Patience grace period: 40
# ---------------------------------
# Epoch 15/500
# Train RMSE: 0.2586
# Val RMSE: 0.2544, Val MAE: 0.1092
# Test RMSE: 0.3330, Test MAE: 0.1477
# ---------------------------------
# Model saved at epoch 15 with val RMSE 0.2544
# Patience grace period: 40
# ---------------------------------
# Epoch 16/500
# Train RMSE: 0.2581
# Val RMSE: 0.2540, Val MAE: 0.1090
# Test RMSE: 0.3323, Test MAE: 0.1476
# ---------------------------------
# Model saved at epoch 16 with val RMSE 0.2540
# Patience grace period: 40
# ---------------------------------
# Epoch 17/500
# Train RMSE: 0.2575
# Val RMSE: 0.2535, Val MAE: 0.1096
# Test RMSE: 0.3306, Test MAE: 0.1479
# ---------------------------------
# Model saved at epoch 17 with val RMSE 0.2535
# Patience grace period: 40
# ---------------------------------
# Epoch 18/500
# Train RMSE: 0.2571
# Val RMSE: 0.2533, Val MAE: 0.1089
# Test RMSE: 0.3310, Test MAE: 0.1475
# ---------------------------------
# Model saved at epoch 18 with val RMSE 0.2533
# Patience grace period: 40
# ---------------------------------
# Epoch 19/500
# Train RMSE: 0.2566
# Val RMSE: 0.2531, Val MAE: 0.1084
# Test RMSE: 0.3316, Test MAE: 0.1473
# ---------------------------------
# Model saved at epoch 19 with val RMSE 0.2531
# Patience grace period: 40
# ---------------------------------
# Epoch 20/500
# Train RMSE: 0.2563
# Val RMSE: 0.2529, Val MAE: 0.1082
# Test RMSE: 0.3311, Test MAE: 0.1472
# ---------------------------------
# Model saved at epoch 20 with val RMSE 0.2529
# Patience grace period: 40
# ---------------------------------
# Epoch 21/500
# Train RMSE: 0.2559
# Val RMSE: 0.2527, Val MAE: 0.1077
# Test RMSE: 0.3318, Test MAE: 0.1468
# ---------------------------------
# Model saved at epoch 21 with val RMSE 0.2527
# Patience grace period: 40
# ---------------------------------
# Epoch 22/500
# Train RMSE: 0.2556
# Val RMSE: 0.2524, Val MAE: 0.1081
# Test RMSE: 0.3307, Test MAE: 0.1472
# ---------------------------------
# Model saved at epoch 22 with val RMSE 0.2524
# Patience grace period: 40
# ---------------------------------
# Epoch 23/500
# Train RMSE: 0.2553
# Val RMSE: 0.2523, Val MAE: 0.1076
# Test RMSE: 0.3311, Test MAE: 0.1470
# ---------------------------------
# Model saved at epoch 23 with val RMSE 0.2523
# Patience grace period: 40
# ---------------------------------
# Epoch 24/500
# Train RMSE: 0.2550
# Val RMSE: 0.2521, Val MAE: 0.1077
# Test RMSE: 0.3303, Test MAE: 0.1470
# ---------------------------------
# Model saved at epoch 24 with val RMSE 0.2521
# Patience grace period: 40
# ---------------------------------
# Epoch 25/500
# Train RMSE: 0.2548
# Val RMSE: 0.2520, Val MAE: 0.1076
# Test RMSE: 0.3299, Test MAE: 0.1473
# ---------------------------------
# Model saved at epoch 25 with val RMSE 0.2520
# Patience grace period: 40
# ---------------------------------
# Epoch 26/500
# Train RMSE: 0.2546
# Val RMSE: 0.2518, Val MAE: 0.1080
# Test RMSE: 0.3297, Test MAE: 0.1475
# ---------------------------------
# Model saved at epoch 26 with val RMSE 0.2518
# Patience grace period: 40
# ---------------------------------
# Epoch 27/500
# Train RMSE: 0.2544
# Val RMSE: 0.2517, Val MAE: 0.1073
# Test RMSE: 0.3298, Test MAE: 0.1471
# ---------------------------------
# Model saved at epoch 27 with val RMSE 0.2517
# Patience grace period: 40
# ---------------------------------
# Epoch 28/500
# Train RMSE: 0.2542
# Val RMSE: 0.2517, Val MAE: 0.1069
# Test RMSE: 0.3304, Test MAE: 0.1470
# ---------------------------------
# Model saved at epoch 28 with val RMSE 0.2517
# Patience grace period: 38
# ---------------------------------
# Epoch 29/500
# Train RMSE: 0.2540
# Val RMSE: 0.2515, Val MAE: 0.1072
# Test RMSE: 0.3298, Test MAE: 0.1472
# ---------------------------------
# Model saved at epoch 29 with val RMSE 0.2515
# Patience grace period: 40
# ---------------------------------
# Epoch 30/500
# Train RMSE: 0.2538
# Val RMSE: 0.2513, Val MAE: 0.1076
# Test RMSE: 0.3291, Test MAE: 0.1475
# ---------------------------------
# Model saved at epoch 30 with val RMSE 0.2513
# Patience grace period: 40
# ---------------------------------
# Epoch 31/500
# Train RMSE: 0.2537
# Val RMSE: 0.2513, Val MAE: 0.1069
# Test RMSE: 0.3299, Test MAE: 0.1470
# ---------------------------------
# Model saved at epoch 31 with val RMSE 0.2513
# Patience grace period: 39
# ---------------------------------
# Epoch 32/500
# Train RMSE: 0.2535
# Val RMSE: 0.2511, Val MAE: 0.1074
# Test RMSE: 0.3287, Test MAE: 0.1476
# ---------------------------------
# Model saved at epoch 32 with val RMSE 0.2511
# Patience grace period: 40
# ---------------------------------
# Epoch 33/500
# Train RMSE: 0.2533
# Val RMSE: 0.2510, Val MAE: 0.1073
# Test RMSE: 0.3287, Test MAE: 0.1476
# ---------------------------------
# Model saved at epoch 33 with val RMSE 0.2510
# Patience grace period: 39
# ---------------------------------
# Epoch 34/500
# Train RMSE: 0.2532
# Val RMSE: 0.2510, Val MAE: 0.1073
# Test RMSE: 0.3288, Test MAE: 0.1476
# ---------------------------------
# Model saved at epoch 34 with val RMSE 0.2510
# Patience grace period: 40
# ---------------------------------
# Epoch 35/500
# Train RMSE: 0.2531
# Val RMSE: 0.2508, Val MAE: 0.1076
# Test RMSE: 0.3276, Test MAE: 0.1479
# ---------------------------------
# Model saved at epoch 35 with val RMSE 0.2508
# Patience grace period: 40
# ---------------------------------
# Epoch 36/500
# Train RMSE: 0.2529
# Val RMSE: 0.2507, Val MAE: 0.1074
# Test RMSE: 0.3279, Test MAE: 0.1478
# ---------------------------------
# Model saved at epoch 36 with val RMSE 0.2507
# Patience grace period: 39
# ---------------------------------
# Epoch 37/500
# Train RMSE: 0.2528
# Val RMSE: 0.2507, Val MAE: 0.1070
# Test RMSE: 0.3286, Test MAE: 0.1475
# ---------------------------------
# Model saved at epoch 37 with val RMSE 0.2507
# Patience grace period: 38
# ---------------------------------
# Epoch 38/500
# Train RMSE: 0.2527
# Val RMSE: 0.2506, Val MAE: 0.1071
# Test RMSE: 0.3285, Test MAE: 0.1477
# ---------------------------------
# Model saved at epoch 38 with val RMSE 0.2506
# Patience grace period: 40
# ---------------------------------
# Epoch 39/500
# Train RMSE: 0.2526
# Val RMSE: 0.2507, Val MAE: 0.1064
# Test RMSE: 0.3293, Test MAE: 0.1473
# ---------------------------------
# Patience grace period: 38
# ---------------------------------
# Epoch 40/500
# Train RMSE: 0.2524
# Val RMSE: 0.2505, Val MAE: 0.1072
# Test RMSE: 0.3277, Test MAE: 0.1478
# ---------------------------------
# Model saved at epoch 40 with val RMSE 0.2505
# Patience grace period: 40
# ---------------------------------
# Epoch 41/500
# Train RMSE: 0.2523
# Val RMSE: 0.2504, Val MAE: 0.1077
# Test RMSE: 0.3268, Test MAE: 0.1482
# ---------------------------------
# Model saved at epoch 41 with val RMSE 0.2504
# Patience grace period: 39
# ---------------------------------
# Epoch 42/500
# Train RMSE: 0.2522
# Val RMSE: 0.2504, Val MAE: 0.1070
# Test RMSE: 0.3280, Test MAE: 0.1478
# ---------------------------------
# Model saved at epoch 42 with val RMSE 0.2504
# Patience grace period: 38
# ---------------------------------
# Epoch 43/500
# Train RMSE: 0.2521
# Val RMSE: 0.2503, Val MAE: 0.1070
# Test RMSE: 0.3275, Test MAE: 0.1479
# ---------------------------------
# Model saved at epoch 43 with val RMSE 0.2503
# Patience grace period: 40
# ---------------------------------
# Epoch 44/500
# Train RMSE: 0.2520
# Val RMSE: 0.2502, Val MAE: 0.1071
# Test RMSE: 0.3272, Test MAE: 0.1480
# ---------------------------------
# Model saved at epoch 44 with val RMSE 0.2502
# Patience grace period: 39
# ---------------------------------
# Epoch 45/500
# Train RMSE: 0.2520
# Val RMSE: 0.2502, Val MAE: 0.1073
# Test RMSE: 0.3268, Test MAE: 0.1483
# ---------------------------------
# Model saved at epoch 45 with val RMSE 0.2502
# Patience grace period: 40
# ---------------------------------
# Epoch 46/500
# Train RMSE: 0.2518
# Val RMSE: 0.2501, Val MAE: 0.1073
# Test RMSE: 0.3267, Test MAE: 0.1483
# ---------------------------------
# Model saved at epoch 46 with val RMSE 0.2501
# Patience grace period: 39
# ---------------------------------
# Epoch 47/500
# Train RMSE: 0.2518
# Val RMSE: 0.2501, Val MAE: 0.1067
# Test RMSE: 0.3277, Test MAE: 0.1477
# ---------------------------------
# Model saved at epoch 47 with val RMSE 0.2501
# Patience grace period: 37
# ---------------------------------
# Epoch 48/500
# Train RMSE: 0.2516
# Val RMSE: 0.2500, Val MAE: 0.1074
# Test RMSE: 0.3263, Test MAE: 0.1484
# ---------------------------------
# Model saved at epoch 48 with val RMSE 0.2500
# Patience grace period: 40
# ---------------------------------
# Epoch 49/500
# Train RMSE: 0.2516
# Val RMSE: 0.2500, Val MAE: 0.1066
# Test RMSE: 0.3279, Test MAE: 0.1479
# ---------------------------------
# Patience grace period: 38
# ---------------------------------
# Epoch 50/500
# Train RMSE: 0.2515
# Val RMSE: 0.2500, Val MAE: 0.1068
# Test RMSE: 0.3273, Test MAE: 0.1481
# ---------------------------------
# Model saved at epoch 50 with val RMSE 0.2500
# Patience grace period: 37
# ---------------------------------
# Epoch 51/500
# Train RMSE: 0.2514
# Val RMSE: 0.2499, Val MAE: 0.1074
# Test RMSE: 0.3260, Test MAE: 0.1484
# ---------------------------------
# Model saved at epoch 51 with val RMSE 0.2499
# Patience grace period: 40
# ---------------------------------
# Epoch 52/500
# Train RMSE: 0.2514
# Val RMSE: 0.2499, Val MAE: 0.1067
# Test RMSE: 0.3271, Test MAE: 0.1480
# ---------------------------------
# Patience grace period: 38
# ---------------------------------
# Epoch 53/500
# Train RMSE: 0.2513
# Val RMSE: 0.2499, Val MAE: 0.1070
# Test RMSE: 0.3264, Test MAE: 0.1483
# ---------------------------------
# Model saved at epoch 53 with val RMSE 0.2499
# Patience grace period: 37
# ---------------------------------
# Epoch 54/500
# Train RMSE: 0.2512
# Val RMSE: 0.2498, Val MAE: 0.1072
# Test RMSE: 0.3257, Test MAE: 0.1484
# ---------------------------------
# Model saved at epoch 54 with val RMSE 0.2498
# Patience grace period: 40
# ---------------------------------
# Epoch 55/500
# Train RMSE: 0.2511
# Val RMSE: 0.2497, Val MAE: 0.1070
# Test RMSE: 0.3263, Test MAE: 0.1485
# ---------------------------------
# Model saved at epoch 55 with val RMSE 0.2497
# Patience grace period: 39
# ---------------------------------
# Epoch 56/500
# Train RMSE: 0.2511
# Val RMSE: 0.2497, Val MAE: 0.1073
# Test RMSE: 0.3258, Test MAE: 0.1487
# ---------------------------------
# Model saved at epoch 56 with val RMSE 0.2497
# Patience grace period: 38
# ---------------------------------
# Epoch 57/500
# Train RMSE: 0.2510
# Val RMSE: 0.2497, Val MAE: 0.1067
# Test RMSE: 0.3265, Test MAE: 0.1480
# ---------------------------------
# Model saved at epoch 57 with val RMSE 0.2497
# Patience grace period: 37
# ---------------------------------
# Epoch 58/500
# Train RMSE: 0.2510
# Val RMSE: 0.2496, Val MAE: 0.1074
# Test RMSE: 0.3251, Test MAE: 0.1487
# ---------------------------------
# Model saved at epoch 58 with val RMSE 0.2496
# Patience grace period: 40
# ---------------------------------
# Epoch 59/500
# Train RMSE: 0.2509
# Val RMSE: 0.2496, Val MAE: 0.1070
# Test RMSE: 0.3260, Test MAE: 0.1486
# ---------------------------------
# Model saved at epoch 59 with val RMSE 0.2496
# Patience grace period: 39
# ---------------------------------
# Epoch 60/500
# Train RMSE: 0.2508
# Val RMSE: 0.2495, Val MAE: 0.1075
# Test RMSE: 0.3246, Test MAE: 0.1490
# ---------------------------------
# Model saved at epoch 60 with val RMSE 0.2495
# Patience grace period: 38
# ---------------------------------
# Epoch 61/500
# Train RMSE: 0.2508
# Val RMSE: 0.2495, Val MAE: 0.1072
# Test RMSE: 0.3255, Test MAE: 0.1488
# ---------------------------------
# Model saved at epoch 61 with val RMSE 0.2495
# Patience grace period: 40
# ---------------------------------
# Epoch 62/500
# Train RMSE: 0.2507
# Val RMSE: 0.2495, Val MAE: 0.1070
# Test RMSE: 0.3260, Test MAE: 0.1486
# ---------------------------------
# Patience grace period: 38
# ---------------------------------
# Epoch 63/500
# Train RMSE: 0.2506
# Val RMSE: 0.2494, Val MAE: 0.1070
# Test RMSE: 0.3257, Test MAE: 0.1486
# ---------------------------------
# Model saved at epoch 63 with val RMSE 0.2494
# Patience grace period: 37
# ---------------------------------
# Epoch 64/500
# Train RMSE: 0.2506
# Val RMSE: 0.2494, Val MAE: 0.1063
# Test RMSE: 0.3268, Test MAE: 0.1481
# ---------------------------------
# Model saved at epoch 64 with val RMSE 0.2494
# Patience grace period: 35
# ---------------------------------
# Epoch 65/500
# Train RMSE: 0.2506
# Val RMSE: 0.2495, Val MAE: 0.1061
# Test RMSE: 0.3270, Test MAE: 0.1481
# ---------------------------------
# Patience grace period: 33
# ---------------------------------
# Epoch 66/500
# Train RMSE: 0.2505
# Val RMSE: 0.2493, Val MAE: 0.1069
# Test RMSE: 0.3258, Test MAE: 0.1487
# ---------------------------------
# Model saved at epoch 66 with val RMSE 0.2493
# Patience grace period: 40
# ---------------------------------
# Epoch 67/500
# Train RMSE: 0.2505
# Val RMSE: 0.2493, Val MAE: 0.1068
# Test RMSE: 0.3257, Test MAE: 0.1487
# ---------------------------------
# Model saved at epoch 67 with val RMSE 0.2493
# Patience grace period: 39
# ---------------------------------
# Epoch 68/500
# Train RMSE: 0.2504
# Val RMSE: 0.2493, Val MAE: 0.1065
# Test RMSE: 0.3265, Test MAE: 0.1487
# ---------------------------------
# Patience grace period: 37
# ---------------------------------
# Epoch 69/500
# Train RMSE: 0.2503
# Val RMSE: 0.2493, Val MAE: 0.1072
# Test RMSE: 0.3251, Test MAE: 0.1490
# ---------------------------------
# Model saved at epoch 69 with val RMSE 0.2493
# Patience grace period: 36
# ---------------------------------
# Epoch 70/500
# Train RMSE: 0.2503
# Val RMSE: 0.2493, Val MAE: 0.1073
# Test RMSE: 0.3249, Test MAE: 0.1492
# ---------------------------------
# Model saved at epoch 70 with val RMSE 0.2493
# Patience grace period: 34
# ---------------------------------
# Epoch 71/500
# Train RMSE: 0.2503
# Val RMSE: 0.2493, Val MAE: 0.1067
# Test RMSE: 0.3257, Test MAE: 0.1487
# ---------------------------------
# Model saved at epoch 71 with val RMSE 0.2493
# Patience grace period: 32
# ---------------------------------
# Epoch 72/500
# Train RMSE: 0.2502
# Val RMSE: 0.2492, Val MAE: 0.1069
# Test RMSE: 0.3254, Test MAE: 0.1489
# ---------------------------------
# Model saved at epoch 72 with val RMSE 0.2492
# Patience grace period: 40
# ---------------------------------
# Epoch 73/500
# Train RMSE: 0.2502
# Val RMSE: 0.2492, Val MAE: 0.1064
# Test RMSE: 0.3262, Test MAE: 0.1486
# ---------------------------------
# Patience grace period: 38
# ---------------------------------
# Epoch 74/500
# Train RMSE: 0.2501
# Val RMSE: 0.2492, Val MAE: 0.1071
# Test RMSE: 0.3248, Test MAE: 0.1489
# ---------------------------------
# Model saved at epoch 74 with val RMSE 0.2492
# Patience grace period: 37
# ---------------------------------
# Epoch 75/500
# Train RMSE: 0.2501
# Val RMSE: 0.2491, Val MAE: 0.1068
# Test RMSE: 0.3255, Test MAE: 0.1488
# ---------------------------------
# Model saved at epoch 75 with val RMSE 0.2491
# Patience grace period: 36
# ---------------------------------
# Epoch 76/500
# Train RMSE: 0.2500
# Val RMSE: 0.2491, Val MAE: 0.1070
# Test RMSE: 0.3250, Test MAE: 0.1491
# ---------------------------------
# Model saved at epoch 76 with val RMSE 0.2491
# Patience grace period: 35
# ---------------------------------
# Epoch 77/500
# Train RMSE: 0.2500
# Val RMSE: 0.2491, Val MAE: 0.1073
# Test RMSE: 0.3244, Test MAE: 0.1493
# ---------------------------------
# Patience grace period: 33
# ---------------------------------
# Epoch 78/500
# Train RMSE: 0.2499
# Val RMSE: 0.2491, Val MAE: 0.1064
# Test RMSE: 0.3261, Test MAE: 0.1487
# ---------------------------------
# Model saved at epoch 78 with val RMSE 0.2491
# Patience grace period: 40
# ---------------------------------
# Epoch 79/500
# Train RMSE: 0.2499
# Val RMSE: 0.2490, Val MAE: 0.1072
# Test RMSE: 0.3246, Test MAE: 0.1491
# ---------------------------------
# Model saved at epoch 79 with val RMSE 0.2490
# Patience grace period: 39
# ---------------------------------
# Epoch 80/500
# Train RMSE: 0.2499
# Val RMSE: 0.2490, Val MAE: 0.1067
# Test RMSE: 0.3253, Test MAE: 0.1490
# ---------------------------------
# Patience grace period: 37
# ---------------------------------
# Epoch 81/500
# Train RMSE: 0.2498
# Val RMSE: 0.2490, Val MAE: 0.1067
# Test RMSE: 0.3249, Test MAE: 0.1489
# ---------------------------------
# Model saved at epoch 81 with val RMSE 0.2490
# Patience grace period: 36
# ---------------------------------
# Epoch 82/500
# Train RMSE: 0.2498
# Val RMSE: 0.2489, Val MAE: 0.1066
# Test RMSE: 0.3252, Test MAE: 0.1490
# ---------------------------------
# Model saved at epoch 82 with val RMSE 0.2489
# Patience grace period: 40
# ---------------------------------
# Epoch 83/500
# Train RMSE: 0.2497
# Val RMSE: 0.2490, Val MAE: 0.1070
# Test RMSE: 0.3245, Test MAE: 0.1494
# ---------------------------------
# Patience grace period: 38
# ---------------------------------
# Epoch 84/500
# Train RMSE: 0.2497
# Val RMSE: 0.2489, Val MAE: 0.1070
# Test RMSE: 0.3246, Test MAE: 0.1493
# ---------------------------------
# Model saved at epoch 84 with val RMSE 0.2489
# Patience grace period: 37
# ---------------------------------
# Epoch 85/500
# Train RMSE: 0.2497
# Val RMSE: 0.2489, Val MAE: 0.1067
# Test RMSE: 0.3250, Test MAE: 0.1490
# ---------------------------------
# Model saved at epoch 85 with val RMSE 0.2489
# Patience grace period: 36
# ---------------------------------
# Epoch 86/500
# Train RMSE: 0.2496
# Val RMSE: 0.2489, Val MAE: 0.1065
# Test RMSE: 0.3251, Test MAE: 0.1489
# ---------------------------------
# Patience grace period: 34
# ---------------------------------
# Epoch 87/500
# Train RMSE: 0.2496
# Val RMSE: 0.2488, Val MAE: 0.1069
# Test RMSE: 0.3247, Test MAE: 0.1492
# ---------------------------------
# Model saved at epoch 87 with val RMSE 0.2488
# Patience grace period: 40
# ---------------------------------
# Epoch 88/500
# Train RMSE: 0.2496
# Val RMSE: 0.2489, Val MAE: 0.1069
# Test RMSE: 0.3248, Test MAE: 0.1493
# ---------------------------------
# Patience grace period: 38
# ---------------------------------
# Epoch 89/500
# Train RMSE: 0.2495
# Val RMSE: 0.2488, Val MAE: 0.1065
# Test RMSE: 0.3249, Test MAE: 0.1490
# ---------------------------------
# Patience grace period: 37
# ---------------------------------
# Epoch 90/500
# Train RMSE: 0.2495
# Val RMSE: 0.2488, Val MAE: 0.1066
# Test RMSE: 0.3251, Test MAE: 0.1493
# ---------------------------------
# Patience grace period: 35
# ---------------------------------
# Epoch 91/500
# Train RMSE: 0.2495
# Val RMSE: 0.2488, Val MAE: 0.1065
# Test RMSE: 0.3248, Test MAE: 0.1491
# ---------------------------------
# Model saved at epoch 91 with val RMSE 0.2488
# Patience grace period: 34
# ---------------------------------
# Epoch 92/500
# Train RMSE: 0.2495
# Val RMSE: 0.2488, Val MAE: 0.1071
# Test RMSE: 0.3239, Test MAE: 0.1496
# ---------------------------------
# Patience grace period: 32
# ---------------------------------
# Epoch 93/500
# Train RMSE: 0.2494
# Val RMSE: 0.2487, Val MAE: 0.1066
# Test RMSE: 0.3246, Test MAE: 0.1493
# ---------------------------------
# Model saved at epoch 93 with val RMSE 0.2487
# Patience grace period: 31
# ---------------------------------
# Epoch 94/500
# Train RMSE: 0.2494
# Val RMSE: 0.2487, Val MAE: 0.1066
# Test RMSE: 0.3248, Test MAE: 0.1493
# ---------------------------------
# Patience grace period: 29
# ---------------------------------
# Epoch 95/500
# Train RMSE: 0.2493
# Val RMSE: 0.2488, Val MAE: 0.1069
# Test RMSE: 0.3244, Test MAE: 0.1495
# ---------------------------------
# Patience grace period: 27
# ---------------------------------
# Epoch 96/500
# Train RMSE: 0.2493
# Val RMSE: 0.2488, Val MAE: 0.1069
# Test RMSE: 0.3241, Test MAE: 0.1495
# ---------------------------------
# Patience grace period: 26
# ---------------------------------
# Epoch 97/500
# Train RMSE: 0.2493
# Val RMSE: 0.2487, Val MAE: 0.1070
# Test RMSE: 0.3241, Test MAE: 0.1494
# ---------------------------------
# Patience grace period: 25
# ---------------------------------
# Epoch 98/500
# Train RMSE: 0.2493
# Val RMSE: 0.2487, Val MAE: 0.1065
# Test RMSE: 0.3251, Test MAE: 0.1491
# ---------------------------------
# Model saved at epoch 98 with val RMSE 0.2487
# Patience grace period: 40
# ---------------------------------
# Epoch 99/500
# Train RMSE: 0.2492
# Val RMSE: 0.2487, Val MAE: 0.1069
# Test RMSE: 0.3237, Test MAE: 0.1496
# ---------------------------------
# Patience grace period: 38
# ---------------------------------
# Epoch 100/500
# Train RMSE: 0.2492
# Val RMSE: 0.2487, Val MAE: 0.1062
# Test RMSE: 0.3253, Test MAE: 0.1490
# ---------------------------------
# Patience grace period: 37
# ---------------------------------
# Epoch 101/500
# Train RMSE: 0.2492
# Val RMSE: 0.2487, Val MAE: 0.1067
# Test RMSE: 0.3245, Test MAE: 0.1493
# ---------------------------------
# Patience grace period: 35
# ---------------------------------
# Epoch 102/500
# Train RMSE: 0.2492
# Val RMSE: 0.2487, Val MAE: 0.1066
# Test RMSE: 0.3244, Test MAE: 0.1492
# ---------------------------------
# Model saved at epoch 102 with val RMSE 0.2487
# Patience grace period: 34
# ---------------------------------
# Epoch 103/500
# Train RMSE: 0.2491
# Val RMSE: 0.2486, Val MAE: 0.1064
# Test RMSE: 0.3245, Test MAE: 0.1493
# ---------------------------------
# Model saved at epoch 103 with val RMSE 0.2486
# Patience grace period: 33
# ---------------------------------
# Epoch 104/500
# Train RMSE: 0.2491
# Val RMSE: 0.2487, Val MAE: 0.1068
# Test RMSE: 0.3240, Test MAE: 0.1496
# ---------------------------------
# Patience grace period: 31
# ---------------------------------
# Epoch 105/500
# Train RMSE: 0.2491
# Val RMSE: 0.2486, Val MAE: 0.1060
# Test RMSE: 0.3254, Test MAE: 0.1488
# ---------------------------------
# Model saved at epoch 105 with val RMSE 0.2486
# Patience grace period: 30
# ---------------------------------
# Epoch 106/500
# Train RMSE: 0.2491
# Val RMSE: 0.2487, Val MAE: 0.1067
# Test RMSE: 0.3239, Test MAE: 0.1496
# ---------------------------------
# Patience grace period: 28
# ---------------------------------
# Epoch 107/500
# Train RMSE: 0.2490
# Val RMSE: 0.2486, Val MAE: 0.1065
# Test RMSE: 0.3247, Test MAE: 0.1494
# ---------------------------------
# Patience grace period: 27
# ---------------------------------
# Epoch 108/500
# Train RMSE: 0.2490
# Val RMSE: 0.2486, Val MAE: 0.1066
# Test RMSE: 0.3242, Test MAE: 0.1495
# ---------------------------------
# Model saved at epoch 108 with val RMSE 0.2486
# Patience grace period: 40
# ---------------------------------
# Epoch 109/500
# Train RMSE: 0.2490
# Val RMSE: 0.2486, Val MAE: 0.1063
# Test RMSE: 0.3245, Test MAE: 0.1492
# ---------------------------------
# Patience grace period: 38
# ---------------------------------
# Epoch 110/500
# Train RMSE: 0.2490
# Val RMSE: 0.2486, Val MAE: 0.1061
# Test RMSE: 0.3253, Test MAE: 0.1491
# ---------------------------------
# Patience grace period: 37
# ---------------------------------
# Epoch 111/500
# Train RMSE: 0.2489
# Val RMSE: 0.2486, Val MAE: 0.1064
# Test RMSE: 0.3251, Test MAE: 0.1493
# ---------------------------------
# Patience grace period: 36
# ---------------------------------
# Epoch 112/500
# Train RMSE: 0.2489
# Val RMSE: 0.2486, Val MAE: 0.1070
# Test RMSE: 0.3238, Test MAE: 0.1498
# ---------------------------------
# Patience grace period: 35
# ---------------------------------
# Epoch 113/500
# Train RMSE: 0.2489
# Val RMSE: 0.2486, Val MAE: 0.1063
# Test RMSE: 0.3250, Test MAE: 0.1494
# ---------------------------------
# Patience grace period: 33
# ---------------------------------
# Epoch 114/500
# Train RMSE: 0.2489
# Val RMSE: 0.2486, Val MAE: 0.1064
# Test RMSE: 0.3243, Test MAE: 0.1493
# ---------------------------------
# Patience grace period: 32
# ---------------------------------
# Epoch 115/500
# Train RMSE: 0.2489
# Val RMSE: 0.2485, Val MAE: 0.1063
# Test RMSE: 0.3242, Test MAE: 0.1493
# ---------------------------------
# Model saved at epoch 115 with val RMSE 0.2485
# Patience grace period: 31
# ---------------------------------
# Epoch 116/500
# Train RMSE: 0.2488
# Val RMSE: 0.2485, Val MAE: 0.1059
# Test RMSE: 0.3255, Test MAE: 0.1490
# ---------------------------------
# Patience grace period: 29
# ---------------------------------
# Epoch 117/500
# Train RMSE: 0.2488
# Val RMSE: 0.2486, Val MAE: 0.1064
# Test RMSE: 0.3248, Test MAE: 0.1494
# ---------------------------------
# Patience grace period: 27
# ---------------------------------
# Epoch 118/500
# Train RMSE: 0.2488
# Val RMSE: 0.2486, Val MAE: 0.1070
# Test RMSE: 0.3234, Test MAE: 0.1500
# ---------------------------------
# Patience grace period: 26
# ---------------------------------
# Epoch 119/500
# Train RMSE: 0.2488
# Val RMSE: 0.2485, Val MAE: 0.1069
# Test RMSE: 0.3237, Test MAE: 0.1499
# ---------------------------------
# Patience grace period: 25
# ---------------------------------
# Epoch 120/500
# Train RMSE: 0.2487
# Val RMSE: 0.2485, Val MAE: 0.1066
# Test RMSE: 0.3241, Test MAE: 0.1497
# ---------------------------------
# Patience grace period: 24
# ---------------------------------
# Epoch 121/500
# Train RMSE: 0.2487
# Val RMSE: 0.2485, Val MAE: 0.1061
# Test RMSE: 0.3248, Test MAE: 0.1493
# ---------------------------------
# Model saved at epoch 121 with val RMSE 0.2485
# Patience grace period: 23
# ---------------------------------
# Epoch 122/500
# Train RMSE: 0.2487
# Val RMSE: 0.2486, Val MAE: 0.1072
# Test RMSE: 0.3231, Test MAE: 0.1502
# ---------------------------------
# Patience grace period: 21
# ---------------------------------
# Epoch 123/500
# Train RMSE: 0.2487
# Val RMSE: 0.2485, Val MAE: 0.1065
# Test RMSE: 0.3241, Test MAE: 0.1496
# ---------------------------------
# Model saved at epoch 123 with val RMSE 0.2485
# Patience grace period: 20
# ---------------------------------
# Epoch 124/500
# Train RMSE: 0.2487
# Val RMSE: 0.2485, Val MAE: 0.1068
# Test RMSE: 0.3235, Test MAE: 0.1498
# ---------------------------------
# Patience grace period: 18
# ---------------------------------
# Epoch 125/500
# Train RMSE: 0.2487
# Val RMSE: 0.2485, Val MAE: 0.1064
# Test RMSE: 0.3243, Test MAE: 0.1495
# ---------------------------------
# Patience grace period: 16
# ---------------------------------
# Epoch 126/500
# Train RMSE: 0.2486
# Val RMSE: 0.2485, Val MAE: 0.1070
# Test RMSE: 0.3234, Test MAE: 0.1501
# ---------------------------------
# Patience grace period: 14
# ---------------------------------
# Epoch 127/500
# Train RMSE: 0.2486
# Val RMSE: 0.2485, Val MAE: 0.1070
# Test RMSE: 0.3233, Test MAE: 0.1499
# ---------------------------------
# Patience grace period: 12
# ---------------------------------
# Epoch 128/500
# Train RMSE: 0.2486
# Val RMSE: 0.2485, Val MAE: 0.1060
# Test RMSE: 0.3250, Test MAE: 0.1495
# ---------------------------------
# Model saved at epoch 128 with val RMSE 0.2485
# Patience grace period: 11
# ---------------------------------
# Epoch 129/500
# Train RMSE: 0.2485
# Val RMSE: 0.2485, Val MAE: 0.1067
# Test RMSE: 0.3239, Test MAE: 0.1496
# ---------------------------------
# Model saved at epoch 129 with val RMSE 0.2485
# Patience grace period: 10
# ---------------------------------
# Epoch 130/500
# Train RMSE: 0.2486
# Val RMSE: 0.2485, Val MAE: 0.1060
# Test RMSE: 0.3253, Test MAE: 0.1494
# ---------------------------------
# Patience grace period: 8
# ---------------------------------
# Epoch 131/500
# Train RMSE: 0.2485
# Val RMSE: 0.2485, Val MAE: 0.1060
# Test RMSE: 0.3253, Test MAE: 0.1496
# ---------------------------------
# Patience grace period: 7
# ---------------------------------
# Epoch 132/500
# Train RMSE: 0.2485
# Val RMSE: 0.2485, Val MAE: 0.1058
# Test RMSE: 0.3256, Test MAE: 0.1491
# ---------------------------------
# Patience grace period: 5
# ---------------------------------
# Epoch 133/500
# Train RMSE: 0.2485
# Val RMSE: 0.2485, Val MAE: 0.1064
# Test RMSE: 0.3241, Test MAE: 0.1496
# ---------------------------------
# Patience grace period: 4
# ---------------------------------
# Epoch 134/500
# Train RMSE: 0.2485
# Val RMSE: 0.2484, Val MAE: 0.1059
# Test RMSE: 0.3254, Test MAE: 0.1493
# ---------------------------------
# Model saved at epoch 134 with val RMSE 0.2484
# Patience grace period: 40
# ---------------------------------
# Epoch 135/500
# Train RMSE: 0.2485
# Val RMSE: 0.2485, Val MAE: 0.1066
# Test RMSE: 0.3240, Test MAE: 0.1498
# ---------------------------------
# Patience grace period: 38
# ---------------------------------
# Epoch 136/500
# Train RMSE: 0.2485
# Val RMSE: 0.2484, Val MAE: 0.1065
# Test RMSE: 0.3238, Test MAE: 0.1498
# ---------------------------------
# Model saved at epoch 136 with val RMSE 0.2484
# Patience grace period: 37
# ---------------------------------
# Epoch 137/500
# Train RMSE: 0.2484
# Val RMSE: 0.2484, Val MAE: 0.1066
# Test RMSE: 0.3241, Test MAE: 0.1501
# ---------------------------------
# Patience grace period: 35
# ---------------------------------
# Epoch 138/500
# Train RMSE: 0.2484
# Val RMSE: 0.2485, Val MAE: 0.1070
# Test RMSE: 0.3232, Test MAE: 0.1503
# ---------------------------------
# Patience grace period: 33
# ---------------------------------
# Epoch 139/500
# Train RMSE: 0.2484
# Val RMSE: 0.2484, Val MAE: 0.1070
# Test RMSE: 0.3231, Test MAE: 0.1504
# ---------------------------------
# Patience grace period: 32
# ---------------------------------
# Epoch 140/500
# Train RMSE: 0.2484
# Val RMSE: 0.2484, Val MAE: 0.1065
# Test RMSE: 0.3240, Test MAE: 0.1500
# ---------------------------------
# Patience grace period: 31
# ---------------------------------
# Epoch 141/500
# Train RMSE: 0.2484
# Val RMSE: 0.2485, Val MAE: 0.1075
# Test RMSE: 0.3226, Test MAE: 0.1507
# ---------------------------------
# Patience grace period: 29
# ---------------------------------
# Epoch 142/500
# Train RMSE: 0.2484
# Val RMSE: 0.2485, Val MAE: 0.1070
# Test RMSE: 0.3234, Test MAE: 0.1502
# ---------------------------------
# Patience grace period: 28
# ---------------------------------
# Epoch 143/500
# Train RMSE: 0.2483
# Val RMSE: 0.2485, Val MAE: 0.1066
# Test RMSE: 0.3240, Test MAE: 0.1503
# ---------------------------------
# Patience grace period: 26
# ---------------------------------
# Epoch 144/500
# Train RMSE: 0.2483
# Val RMSE: 0.2484, Val MAE: 0.1063
# Test RMSE: 0.3251, Test MAE: 0.1499
# ---------------------------------
# Patience grace period: 25
# ---------------------------------
# Epoch 145/500
# Train RMSE: 0.2483
# Val RMSE: 0.2485, Val MAE: 0.1060
# Test RMSE: 0.3252, Test MAE: 0.1497
# ---------------------------------
# Patience grace period: 23
# ---------------------------------
# Epoch 146/500
# Train RMSE: 0.2483
# Val RMSE: 0.2484, Val MAE: 0.1063
# Test RMSE: 0.3246, Test MAE: 0.1499
# ---------------------------------
# Model saved at epoch 146 with val RMSE 0.2484
# Patience grace period: 22
# ---------------------------------
# Epoch 147/500
# Train RMSE: 0.2483
# Val RMSE: 0.2484, Val MAE: 0.1070
# Test RMSE: 0.3233, Test MAE: 0.1503
# ---------------------------------
# Patience grace period: 20
# ---------------------------------
# Epoch 148/500
# Train RMSE: 0.2483
# Val RMSE: 0.2485, Val MAE: 0.1070
# Test RMSE: 0.3229, Test MAE: 0.1503
# ---------------------------------
# Patience grace period: 18
# ---------------------------------
# Epoch 149/500
# Train RMSE: 0.2483
# Val RMSE: 0.2484, Val MAE: 0.1065
# Test RMSE: 0.3240, Test MAE: 0.1502
# ---------------------------------
# Patience grace period: 17
# ---------------------------------
# Epoch 150/500
# Train RMSE: 0.2482
# Val RMSE: 0.2484, Val MAE: 0.1071
# Test RMSE: 0.3231, Test MAE: 0.1505
# ---------------------------------
# Patience grace period: 15
# ---------------------------------
# Epoch 151/500
# Train RMSE: 0.2482
# Val RMSE: 0.2484, Val MAE: 0.1065
# Test RMSE: 0.3240, Test MAE: 0.1504
# ---------------------------------
# Patience grace period: 13
# ---------------------------------
# Epoch 152/500
# Train RMSE: 0.2482
# Val RMSE: 0.2484, Val MAE: 0.1061
# Test RMSE: 0.3246, Test MAE: 0.1498
# ---------------------------------
# Patience grace period: 12
# ---------------------------------
# Epoch 153/500
# Train RMSE: 0.2482
# Val RMSE: 0.2484, Val MAE: 0.1062
# Test RMSE: 0.3248, Test MAE: 0.1499
# ---------------------------------
# Patience grace period: 11
# ---------------------------------
# Epoch 154/500
# Train RMSE: 0.2482
# Val RMSE: 0.2485, Val MAE: 0.1069
# Test RMSE: 0.3232, Test MAE: 0.1505
# ---------------------------------
# Patience grace period: 9
# ---------------------------------
# Epoch 155/500
# Train RMSE: 0.2482
# Val RMSE: 0.2484, Val MAE: 0.1063
# Test RMSE: 0.3244, Test MAE: 0.1501
# ---------------------------------
# Patience grace period: 8
# ---------------------------------
# Epoch 156/500
# Train RMSE: 0.2482
# Val RMSE: 0.2484, Val MAE: 0.1063
# Test RMSE: 0.3244, Test MAE: 0.1501
# ---------------------------------
# Patience grace period: 6
# ---------------------------------
# Epoch 157/500
# Train RMSE: 0.2481
# Val RMSE: 0.2484, Val MAE: 0.1070
# Test RMSE: 0.3232, Test MAE: 0.1505
# ---------------------------------
# Patience grace period: 5
# ---------------------------------
# Epoch 158/500
# Train RMSE: 0.2481
# Val RMSE: 0.2483, Val MAE: 0.1059
# Test RMSE: 0.3251, Test MAE: 0.1495
# ---------------------------------
# Model saved at epoch 158 with val RMSE 0.2483
# Patience grace period: 4
# ---------------------------------
# Epoch 159/500
# Train RMSE: 0.2481
# Val RMSE: 0.2484, Val MAE: 0.1066
# Test RMSE: 0.3242, Test MAE: 0.1501
# ---------------------------------
# Patience grace period: 2
# ---------------------------------
# Epoch 160/500
# Train RMSE: 0.2481
# Val RMSE: 0.2484, Val MAE: 0.1070
# Test RMSE: 0.3234, Test MAE: 0.1505
# ---------------------------------
# Patience grace period: 0
# Early stopping triggered at epoch 160
# Final Test RMSE: 0.3251, Final Test MAE: 0.1495
# <ipython-input-3-2a228d64b832>:126: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   self.model.load_state_dict(torch.load(os.path.join(save_dir, 'best_model.pth')))
# Pearson Corr: 0.7489006865936385
# Spearman Corr: 0.431526932105972
# p-rmse: 0.3250689790956851
#        rmse       mae  seed                             subtask    method  \
# 0  0.325069  0.149473     1  openproblems_bmmc_cite_phase2_mod2  original
#
#     pearson p_value_pearson  spearman p_value_spearman
# 0  0.748901          0.0000  0.431527           0.0000
# ---------------------------------
# Epoch 1/500
# Train RMSE: 0.3746
# Val RMSE: 0.3227, Val MAE: 0.1329
# Test RMSE: 0.3993, Test MAE: 0.1770
# ---------------------------------
# Model saved at epoch 1 with val RMSE 0.3227
# Patience grace period: 40
# ---------------------------------
# Epoch 2/500
# Train RMSE: 0.3272
# Val RMSE: 0.2941, Val MAE: 0.1276
# Test RMSE: 0.3683, Test MAE: 0.1683
# ---------------------------------
# Model saved at epoch 2 with val RMSE 0.2941
# Patience grace period: 40
# ---------------------------------
# Epoch 3/500
# Train RMSE: 0.3051
# Val RMSE: 0.2794, Val MAE: 0.1207
# Test RMSE: 0.3553, Test MAE: 0.1606
# ---------------------------------
# Model saved at epoch 3 with val RMSE 0.2794
# Patience grace period: 40
# ---------------------------------
# Epoch 4/500
# Train RMSE: 0.2921
# Val RMSE: 0.2727, Val MAE: 0.1180
# Test RMSE: 0.3496, Test MAE: 0.1577
# ---------------------------------
# Model saved at epoch 4 with val RMSE 0.2727
# Patience grace period: 40
# ---------------------------------
# Epoch 5/500
# Train RMSE: 0.2841
# Val RMSE: 0.2685, Val MAE: 0.1168
# Test RMSE: 0.3457, Test MAE: 0.1561
# ---------------------------------
# Model saved at epoch 5 with val RMSE 0.2685
# Patience grace period: 40
# ---------------------------------
# Epoch 6/500
# Train RMSE: 0.2782
# Val RMSE: 0.2653, Val MAE: 0.1156
# Test RMSE: 0.3419, Test MAE: 0.1541
# ---------------------------------
# Model saved at epoch 6 with val RMSE 0.2653
# Patience grace period: 40
# ---------------------------------
# Epoch 7/500
# Train RMSE: 0.2736
# Val RMSE: 0.2627, Val MAE: 0.1145
# Test RMSE: 0.3391, Test MAE: 0.1525
# ---------------------------------
# Model saved at epoch 7 with val RMSE 0.2627
# Patience grace period: 40
# ---------------------------------
# Epoch 8/500
# Train RMSE: 0.2698
# Val RMSE: 0.2606, Val MAE: 0.1136
# Test RMSE: 0.3369, Test MAE: 0.1512
# ---------------------------------
# Model saved at epoch 8 with val RMSE 0.2606
# Patience grace period: 40
# ---------------------------------
# Epoch 9/500
# Train RMSE: 0.2667
# Val RMSE: 0.2590, Val MAE: 0.1118
# Test RMSE: 0.3366, Test MAE: 0.1496
# ---------------------------------
# Model saved at epoch 9 with val RMSE 0.2590
# Patience grace period: 40
# ---------------------------------
# Epoch 10/500
# Train RMSE: 0.2644
# Val RMSE: 0.2577, Val MAE: 0.1108
# Test RMSE: 0.3365, Test MAE: 0.1488
# ---------------------------------
# Model saved at epoch 10 with val RMSE 0.2577
# Patience grace period: 40
# ---------------------------------
# Epoch 11/500
# Train RMSE: 0.2626
# Val RMSE: 0.2565, Val MAE: 0.1111
# Test RMSE: 0.3343, Test MAE: 0.1488
# ---------------------------------
# Model saved at epoch 11 with val RMSE 0.2565
# Patience grace period: 40
# ---------------------------------
# Epoch 12/500
# Train RMSE: 0.2612
# Val RMSE: 0.2557, Val MAE: 0.1104
# Test RMSE: 0.3338, Test MAE: 0.1484
# ---------------------------------
# Model saved at epoch 12 with val RMSE 0.2557
# Patience grace period: 40
# ---------------------------------
# Epoch 13/500
# Train RMSE: 0.2602
# Val RMSE: 0.2551, Val MAE: 0.1095
# Test RMSE: 0.3337, Test MAE: 0.1475
# ---------------------------------
# Model saved at epoch 13 with val RMSE 0.2551
# Patience grace period: 40
# ---------------------------------
# Epoch 14/500
# Train RMSE: 0.2593
# Val RMSE: 0.2547, Val MAE: 0.1090
# Test RMSE: 0.3336, Test MAE: 0.1472
# ---------------------------------
# Model saved at epoch 14 with val RMSE 0.2547
# Patience grace period: 40
# ---------------------------------
# Epoch 15/500
# Train RMSE: 0.2586
# Val RMSE: 0.2542, Val MAE: 0.1092
# Test RMSE: 0.3326, Test MAE: 0.1474
# ---------------------------------
# Model saved at epoch 15 with val RMSE 0.2542
# Patience grace period: 40
# ---------------------------------
# Epoch 16/500
# Train RMSE: 0.2580
# Val RMSE: 0.2539, Val MAE: 0.1086
# Test RMSE: 0.3327, Test MAE: 0.1469
# ---------------------------------
# Model saved at epoch 16 with val RMSE 0.2539
# Patience grace period: 40
# ---------------------------------
# Epoch 17/500
# Train RMSE: 0.2575
# Val RMSE: 0.2537, Val MAE: 0.1081
# Test RMSE: 0.3327, Test MAE: 0.1467
# ---------------------------------
# Model saved at epoch 17 with val RMSE 0.2537
# Patience grace period: 40
# ---------------------------------
# Epoch 18/500
# Train RMSE: 0.2571
# Val RMSE: 0.2533, Val MAE: 0.1085
# Test RMSE: 0.3316, Test MAE: 0.1471
# ---------------------------------
# Model saved at epoch 18 with val RMSE 0.2533
# Patience grace period: 40
# ---------------------------------
# Epoch 19/500
# Train RMSE: 0.2567
# Val RMSE: 0.2530, Val MAE: 0.1090
# Test RMSE: 0.3305, Test MAE: 0.1473
# ---------------------------------
# Model saved at epoch 19 with val RMSE 0.2530
# Patience grace period: 40
# ---------------------------------
# Epoch 20/500
# Train RMSE: 0.2563
# Val RMSE: 0.2528, Val MAE: 0.1084
# Test RMSE: 0.3312, Test MAE: 0.1470
# ---------------------------------
# Model saved at epoch 20 with val RMSE 0.2528
# Patience grace period: 40
# ---------------------------------
# Epoch 21/500
# Train RMSE: 0.2560
# Val RMSE: 0.2527, Val MAE: 0.1080
# Test RMSE: 0.3313, Test MAE: 0.1469
# ---------------------------------
# Model saved at epoch 21 with val RMSE 0.2527
# Patience grace period: 40
# ---------------------------------
# Epoch 22/500
# Train RMSE: 0.2557
# Val RMSE: 0.2524, Val MAE: 0.1082
# Test RMSE: 0.3302, Test MAE: 0.1472
# ---------------------------------
# Model saved at epoch 22 with val RMSE 0.2524
# Patience grace period: 40
# ---------------------------------
# Epoch 23/500
# Train RMSE: 0.2554
# Val RMSE: 0.2522, Val MAE: 0.1081
# Test RMSE: 0.3303, Test MAE: 0.1472
# ---------------------------------
# Model saved at epoch 23 with val RMSE 0.2522
# Patience grace period: 40
# ---------------------------------
# Epoch 24/500
# Train RMSE: 0.2551
# Val RMSE: 0.2520, Val MAE: 0.1081
# Test RMSE: 0.3297, Test MAE: 0.1471
# ---------------------------------
# Model saved at epoch 24 with val RMSE 0.2520
# Patience grace period: 40
# ---------------------------------
# Epoch 25/500
# Train RMSE: 0.2549
# Val RMSE: 0.2519, Val MAE: 0.1074
# Test RMSE: 0.3301, Test MAE: 0.1469
# ---------------------------------
# Model saved at epoch 25 with val RMSE 0.2519
# Patience grace period: 39
# ---------------------------------
# Epoch 26/500
# Train RMSE: 0.2547
# Val RMSE: 0.2517, Val MAE: 0.1079
# Test RMSE: 0.3292, Test MAE: 0.1472
# ---------------------------------
# Model saved at epoch 26 with val RMSE 0.2517
# Patience grace period: 40
# ---------------------------------
# Epoch 27/500
# Train RMSE: 0.2544
# Val RMSE: 0.2517, Val MAE: 0.1073
# Test RMSE: 0.3301, Test MAE: 0.1469
# ---------------------------------
# Model saved at epoch 27 with val RMSE 0.2517
# Patience grace period: 39
# ---------------------------------
# Epoch 28/500
# Train RMSE: 0.2542
# Val RMSE: 0.2516, Val MAE: 0.1071
# Test RMSE: 0.3300, Test MAE: 0.1469
# ---------------------------------
# Model saved at epoch 28 with val RMSE 0.2516
# Patience grace period: 40
# ---------------------------------
# Epoch 29/500
# Train RMSE: 0.2541
# Val RMSE: 0.2514, Val MAE: 0.1070
# Test RMSE: 0.3296, Test MAE: 0.1470
# ---------------------------------
# Model saved at epoch 29 with val RMSE 0.2514
# Patience grace period: 40
# ---------------------------------
# Epoch 30/500
# Train RMSE: 0.2539
# Val RMSE: 0.2513, Val MAE: 0.1071
# Test RMSE: 0.3299, Test MAE: 0.1470
# ---------------------------------
# Model saved at epoch 30 with val RMSE 0.2513
# Patience grace period: 40
# ---------------------------------
# Epoch 31/500
# Train RMSE: 0.2537
# Val RMSE: 0.2512, Val MAE: 0.1069
# Test RMSE: 0.3293, Test MAE: 0.1470
# ---------------------------------
# Model saved at epoch 31 with val RMSE 0.2512
# Patience grace period: 40
# ---------------------------------
# Epoch 32/500
# Train RMSE: 0.2535
# Val RMSE: 0.2511, Val MAE: 0.1073
# Test RMSE: 0.3288, Test MAE: 0.1474
# ---------------------------------
# Model saved at epoch 32 with val RMSE 0.2511
# Patience grace period: 40
# ---------------------------------
# Epoch 33/500
# Train RMSE: 0.2534
# Val RMSE: 0.2510, Val MAE: 0.1073
# Test RMSE: 0.3285, Test MAE: 0.1476
# ---------------------------------
# Model saved at epoch 33 with val RMSE 0.2510
# Patience grace period: 39
# ---------------------------------
# Epoch 34/500
# Train RMSE: 0.2533
# Val RMSE: 0.2510, Val MAE: 0.1066
# Test RMSE: 0.3294, Test MAE: 0.1470
# ---------------------------------
# Patience grace period: 37
# ---------------------------------
# Epoch 35/500
# Train RMSE: 0.2531
# Val RMSE: 0.2508, Val MAE: 0.1072
# ...
# Val RMSE: 0.2485, Val MAE: 0.1063
# Test RMSE: 0.3251, Test MAE: 0.1495
# ---------------------------------
# Model saved at epoch 100 with val RMSE 0.2485
# Patience grace period: 29
# ---------------------------------
# Epoch 101/500
# Train RMSE: 0.2492
# Val RMSE: 0.2486, Val MAE: 0.1060
# Test RMSE: 0.3258, Test MAE: 0.1493
# ---------------------------------
# Patience grace period: 27
# ---------------------------------
# Epoch 102/500
# Train RMSE: 0.2491
# Val RMSE: 0.2485, Val MAE: 0.1067
# Test RMSE: 0.3246, Test MAE: 0.1497
# ---------------------------------
# Model saved at epoch 102 with val RMSE 0.2485
# Patience grace period: 40
# ---------------------------------
# Epoch 103/500
# Train RMSE: 0.2491
# Val RMSE: 0.2485, Val MAE: 0.1058
# Test RMSE: 0.3256, Test MAE: 0.1491
# ---------------------------------
# Model saved at epoch 103 with val RMSE 0.2485
# Patience grace period: 39
# ---------------------------------
# Epoch 104/500
# Train RMSE: 0.2491
# Val RMSE: 0.2485, Val MAE: 0.1058
# Test RMSE: 0.3254, Test MAE: 0.1491
# ---------------------------------
# Model saved at epoch 104 with val RMSE 0.2485
# Patience grace period: 38
# ---------------------------------
# Epoch 105/500
# Train RMSE: 0.2490
# Val RMSE: 0.2485, Val MAE: 0.1069
# Test RMSE: 0.3240, Test MAE: 0.1498
# ---------------------------------
# Patience grace period: 36
# ---------------------------------
# Epoch 106/500
# Train RMSE: 0.2490
# Val RMSE: 0.2485, Val MAE: 0.1065
# Test RMSE: 0.3248, Test MAE: 0.1497
# ---------------------------------
# Model saved at epoch 106 with val RMSE 0.2485
# Patience grace period: 35
# ---------------------------------
# Epoch 107/500
# Train RMSE: 0.2490
# Val RMSE: 0.2485, Val MAE: 0.1066
# Test RMSE: 0.3242, Test MAE: 0.1498
# ---------------------------------
# Model saved at epoch 107 with val RMSE 0.2485
# Patience grace period: 34
# ---------------------------------
# Epoch 108/500
# Train RMSE: 0.2490
# Val RMSE: 0.2485, Val MAE: 0.1061
# Test RMSE: 0.3255, Test MAE: 0.1494
# ---------------------------------
# Patience grace period: 32
# ---------------------------------
# Epoch 109/500
# Train RMSE: 0.2490
# Val RMSE: 0.2484, Val MAE: 0.1064
# Test RMSE: 0.3247, Test MAE: 0.1496
# ---------------------------------
# Model saved at epoch 109 with val RMSE 0.2484
# Patience grace period: 31
# ---------------------------------
# Epoch 110/500
# Train RMSE: 0.2489
# Val RMSE: 0.2484, Val MAE: 0.1061
# Test RMSE: 0.3250, Test MAE: 0.1494
# ---------------------------------
# Model saved at epoch 110 with val RMSE 0.2484
# Patience grace period: 40
# ---------------------------------
# Epoch 111/500
# Train RMSE: 0.2489
# Val RMSE: 0.2485, Val MAE: 0.1063
# Test RMSE: 0.3246, Test MAE: 0.1497
# ---------------------------------
# Patience grace period: 38
# ---------------------------------
# Epoch 112/500
# Train RMSE: 0.2489
# Val RMSE: 0.2484, Val MAE: 0.1062
# Test RMSE: 0.3249, Test MAE: 0.1495
# ---------------------------------
# Patience grace period: 37
# ---------------------------------
# Epoch 113/500
# Train RMSE: 0.2489
# Val RMSE: 0.2484, Val MAE: 0.1061
# Test RMSE: 0.3251, Test MAE: 0.1493
# ---------------------------------
# Model saved at epoch 113 with val RMSE 0.2484
# Patience grace period: 36
# ---------------------------------
# Epoch 114/500
# Train RMSE: 0.2488
# Val RMSE: 0.2484, Val MAE: 0.1065
# Test RMSE: 0.3249, Test MAE: 0.1497
# ---------------------------------
# Model saved at epoch 114 with val RMSE 0.2484
# Patience grace period: 35
# ---------------------------------
# Epoch 115/500
# Train RMSE: 0.2488
# Val RMSE: 0.2484, Val MAE: 0.1062
# Test RMSE: 0.3249, Test MAE: 0.1495
# ---------------------------------
# Patience grace period: 33
# ---------------------------------
# Epoch 116/500
# Train RMSE: 0.2488
# Val RMSE: 0.2484, Val MAE: 0.1066
# Test RMSE: 0.3242, Test MAE: 0.1497
# ---------------------------------
# Model saved at epoch 116 with val RMSE 0.2484
# Patience grace period: 32
# ---------------------------------
# Epoch 117/500
# Train RMSE: 0.2487
# Val RMSE: 0.2484, Val MAE: 0.1063
# Test RMSE: 0.3248, Test MAE: 0.1495
# ---------------------------------
# Patience grace period: 30
# ---------------------------------
# Epoch 118/500
# Train RMSE: 0.2488
# Val RMSE: 0.2483, Val MAE: 0.1061
# Test RMSE: 0.3250, Test MAE: 0.1492
# ---------------------------------
# Model saved at epoch 118 with val RMSE 0.2483
# Patience grace period: 29
# ---------------------------------
# Epoch 119/500
# Train RMSE: 0.2487
# Val RMSE: 0.2484, Val MAE: 0.1064
# Test RMSE: 0.3250, Test MAE: 0.1497
# ---------------------------------
# Patience grace period: 27
# ---------------------------------
# Epoch 120/500
# Train RMSE: 0.2487
# Val RMSE: 0.2483, Val MAE: 0.1063
# Test RMSE: 0.3249, Test MAE: 0.1494
# ---------------------------------
# Model saved at epoch 120 with val RMSE 0.2483
# Patience grace period: 26
# ---------------------------------
# Epoch 121/500
# Train RMSE: 0.2487
# Val RMSE: 0.2483, Val MAE: 0.1062
# Test RMSE: 0.3246, Test MAE: 0.1495
# ---------------------------------
# Patience grace period: 24
# ---------------------------------
# Epoch 122/500
# Train RMSE: 0.2487
# Val RMSE: 0.2483, Val MAE: 0.1063
# Test RMSE: 0.3252, Test MAE: 0.1498
# ---------------------------------
# Patience grace period: 22
# ---------------------------------
# Epoch 123/500
# Train RMSE: 0.2486
# Val RMSE: 0.2484, Val MAE: 0.1068
# Test RMSE: 0.3243, Test MAE: 0.1501
# ---------------------------------
# Patience grace period: 20
# ---------------------------------
# Epoch 124/500
# Train RMSE: 0.2486
# Val RMSE: 0.2483, Val MAE: 0.1063
# Test RMSE: 0.3250, Test MAE: 0.1497
# ---------------------------------
# Model saved at epoch 124 with val RMSE 0.2483
# Patience grace period: 19
# ---------------------------------
# Epoch 125/500
# Train RMSE: 0.2486
# Val RMSE: 0.2483, Val MAE: 0.1063
# Test RMSE: 0.3249, Test MAE: 0.1497
# ---------------------------------
# Model saved at epoch 125 with val RMSE 0.2483
# Patience grace period: 40
# ---------------------------------
# Epoch 126/500
# Train RMSE: 0.2486
# Val RMSE: 0.2483, Val MAE: 0.1064
# Test RMSE: 0.3244, Test MAE: 0.1498
# ---------------------------------
# Model saved at epoch 126 with val RMSE 0.2483
# Patience grace period: 38
# ---------------------------------
# Epoch 127/500
# Train RMSE: 0.2486
# Val RMSE: 0.2483, Val MAE: 0.1064
# Test RMSE: 0.3242, Test MAE: 0.1499
# ---------------------------------
# Model saved at epoch 127 with val RMSE 0.2483
# Patience grace period: 36
# ---------------------------------
# Epoch 128/500
# Train RMSE: 0.2486
# Val RMSE: 0.2483, Val MAE: 0.1062
# Test RMSE: 0.3245, Test MAE: 0.1497
# ---------------------------------
# Model saved at epoch 128 with val RMSE 0.2483
# Patience grace period: 35
# ---------------------------------
# Epoch 129/500
# Train RMSE: 0.2485
# Val RMSE: 0.2483, Val MAE: 0.1067
# Test RMSE: 0.3243, Test MAE: 0.1499
# ---------------------------------
# Patience grace period: 33
# ---------------------------------
# Epoch 130/500
# Train RMSE: 0.2485
# Val RMSE: 0.2483, Val MAE: 0.1064
# Test RMSE: 0.3244, Test MAE: 0.1499
# ---------------------------------
# Model saved at epoch 130 with val RMSE 0.2483
# Patience grace period: 32
# ---------------------------------
# Epoch 131/500
# Train RMSE: 0.2485
# Val RMSE: 0.2483, Val MAE: 0.1061
# Test RMSE: 0.3249, Test MAE: 0.1496
# ---------------------------------
# Model saved at epoch 131 with val RMSE 0.2483
# Patience grace period: 30
# ---------------------------------
# Epoch 132/500
# Train RMSE: 0.2485
# Val RMSE: 0.2483, Val MAE: 0.1060
# Test RMSE: 0.3257, Test MAE: 0.1492
# ---------------------------------
# Model saved at epoch 132 with val RMSE 0.2483
# Patience grace period: 29
# ---------------------------------
# Epoch 133/500
# Train RMSE: 0.2485
# Val RMSE: 0.2483, Val MAE: 0.1061
# Test RMSE: 0.3249, Test MAE: 0.1497
# ---------------------------------
# Patience grace period: 27
# ---------------------------------
# Epoch 134/500
# Train RMSE: 0.2485
# Val RMSE: 0.2482, Val MAE: 0.1057
# Test RMSE: 0.3252, Test MAE: 0.1492
# ---------------------------------
# Model saved at epoch 134 with val RMSE 0.2482
# Patience grace period: 26
# ---------------------------------
# Epoch 135/500
# Train RMSE: 0.2484
# Val RMSE: 0.2483, Val MAE: 0.1061
# Test RMSE: 0.3250, Test MAE: 0.1497
# ---------------------------------
# Patience grace period: 24
# ---------------------------------
# Epoch 136/500
# Train RMSE: 0.2484
# Val RMSE: 0.2482, Val MAE: 0.1059
# Test RMSE: 0.3249, Test MAE: 0.1497
# ---------------------------------
# Model saved at epoch 136 with val RMSE 0.2482
# Patience grace period: 23
# ---------------------------------
# Epoch 137/500
# Train RMSE: 0.2484
# Val RMSE: 0.2483, Val MAE: 0.1055
# Test RMSE: 0.3260, Test MAE: 0.1492
# ---------------------------------
# Patience grace period: 21
# ---------------------------------
# Epoch 138/500
# Train RMSE: 0.2484
# Val RMSE: 0.2482, Val MAE: 0.1057
# Test RMSE: 0.3257, Test MAE: 0.1497
# ---------------------------------
# Patience grace period: 20
# ---------------------------------
# Epoch 139/500
# Train RMSE: 0.2484
# Val RMSE: 0.2482, Val MAE: 0.1061
# Test RMSE: 0.3250, Test MAE: 0.1495
# ---------------------------------
# Model saved at epoch 139 with val RMSE 0.2482
# Patience grace period: 19
# ---------------------------------
# Epoch 140/500
# Train RMSE: 0.2483
# Val RMSE: 0.2482, Val MAE: 0.1064
# Test RMSE: 0.3248, Test MAE: 0.1501
# ---------------------------------
# Patience grace period: 17
# ---------------------------------
# Epoch 141/500
# Train RMSE: 0.2484
# Val RMSE: 0.2482, Val MAE: 0.1062
# Test RMSE: 0.3247, Test MAE: 0.1499
# ---------------------------------
# Model saved at epoch 141 with val RMSE 0.2482
# Patience grace period: 40
# ---------------------------------
# Epoch 142/500
# Train RMSE: 0.2483
# Val RMSE: 0.2482, Val MAE: 0.1060
# Test RMSE: 0.3252, Test MAE: 0.1497
# ---------------------------------
# Patience grace period: 38
# ---------------------------------
# Epoch 143/500
# Train RMSE: 0.2483
# Val RMSE: 0.2482, Val MAE: 0.1067
# Test RMSE: 0.3238, Test MAE: 0.1502
# ---------------------------------
# Patience grace period: 36
# ---------------------------------
# Epoch 144/500
# Train RMSE: 0.2483
# Val RMSE: 0.2482, Val MAE: 0.1056
# Test RMSE: 0.3254, Test MAE: 0.1494
# ---------------------------------
# Patience grace period: 35
# ---------------------------------
# Epoch 145/500
# Train RMSE: 0.2483
# Val RMSE: 0.2482, Val MAE: 0.1056
# Test RMSE: 0.3257, Test MAE: 0.1496
# ---------------------------------
# Patience grace period: 33
# ---------------------------------
# Epoch 146/500
# Train RMSE: 0.2483
# Val RMSE: 0.2482, Val MAE: 0.1058
# Test RMSE: 0.3255, Test MAE: 0.1496
# ---------------------------------
# Patience grace period: 32
# ---------------------------------
# Epoch 147/500
# Train RMSE: 0.2482
# Val RMSE: 0.2482, Val MAE: 0.1065
# Test RMSE: 0.3244, Test MAE: 0.1501
# ---------------------------------
# Patience grace period: 30
# ---------------------------------
# Epoch 148/500
# Train RMSE: 0.2482
# Val RMSE: 0.2482, Val MAE: 0.1065
# Test RMSE: 0.3242, Test MAE: 0.1500
# ---------------------------------
# Patience grace period: 28
# ---------------------------------
# Epoch 149/500
# Train RMSE: 0.2482
# Val RMSE: 0.2482, Val MAE: 0.1055
# Test RMSE: 0.3260, Test MAE: 0.1491
# ---------------------------------
# Model saved at epoch 149 with val RMSE 0.2482
# Patience grace period: 27
# ---------------------------------
# Epoch 150/500
# Train RMSE: 0.2482
# Val RMSE: 0.2482, Val MAE: 0.1061
# Test RMSE: 0.3248, Test MAE: 0.1497
# ---------------------------------
# Model saved at epoch 150 with val RMSE 0.2482
# Patience grace period: 26
# ---------------------------------
# Epoch 151/500
# Train RMSE: 0.2482
# Val RMSE: 0.2482, Val MAE: 0.1063
# Test RMSE: 0.3246, Test MAE: 0.1501
# ---------------------------------
# Patience grace period: 24
# ---------------------------------
# Epoch 152/500
# Train RMSE: 0.2482
# Val RMSE: 0.2483, Val MAE: 0.1067
# Test RMSE: 0.3236, Test MAE: 0.1505
# ---------------------------------
# Patience grace period: 22
# ---------------------------------
# Epoch 153/500
# Train RMSE: 0.2482
# Val RMSE: 0.2482, Val MAE: 0.1062
# Test RMSE: 0.3246, Test MAE: 0.1501
# ---------------------------------
# Model saved at epoch 153 with val RMSE 0.2482
# Patience grace period: 21
# ---------------------------------
# Epoch 154/500
# Train RMSE: 0.2481
# Val RMSE: 0.2482, Val MAE: 0.1061
# Test RMSE: 0.3247, Test MAE: 0.1499
# ---------------------------------
# Model saved at epoch 154 with val RMSE 0.2482
# Patience grace period: 20
# ---------------------------------
# Epoch 155/500
# Train RMSE: 0.2481
# Val RMSE: 0.2482, Val MAE: 0.1062
# Test RMSE: 0.3248, Test MAE: 0.1501
# ---------------------------------
# Patience grace period: 18
# ---------------------------------
# Epoch 156/500
# Train RMSE: 0.2481
# Val RMSE: 0.2482, Val MAE: 0.1063
# Test RMSE: 0.3241, Test MAE: 0.1503
# ---------------------------------
# Patience grace period: 17
# ---------------------------------
# Epoch 157/500
# Train RMSE: 0.2481
# Val RMSE: 0.2482, Val MAE: 0.1063
# Test RMSE: 0.3245, Test MAE: 0.1501
# ---------------------------------
# Patience grace period: 15
# ---------------------------------
# Epoch 158/500
# Train RMSE: 0.2481
# Val RMSE: 0.2481, Val MAE: 0.1059
# Test RMSE: 0.3249, Test MAE: 0.1496
# ---------------------------------
# Model saved at epoch 158 with val RMSE 0.2481
# Patience grace period: 14
# ---------------------------------
# Epoch 159/500
# Train RMSE: 0.2481
# Val RMSE: 0.2482, Val MAE: 0.1064
# Test RMSE: 0.3245, Test MAE: 0.1502
# ---------------------------------
# Patience grace period: 12
# ---------------------------------
# Epoch 160/500
# Train RMSE: 0.2480
# Val RMSE: 0.2482, Val MAE: 0.1065
# Test RMSE: 0.3241, Test MAE: 0.1503
# ---------------------------------
# Patience grace period: 10
# ---------------------------------
# Epoch 161/500
# Train RMSE: 0.2480
# Val RMSE: 0.2482, Val MAE: 0.1065
# Test RMSE: 0.3239, Test MAE: 0.1505
# ---------------------------------
# Patience grace period: 8
# ---------------------------------
# Epoch 162/500
# Train RMSE: 0.2480
# Val RMSE: 0.2482, Val MAE: 0.1059
# Test RMSE: 0.3250, Test MAE: 0.1498
# ---------------------------------
# Patience grace period: 7
# ---------------------------------
# Epoch 163/500
# Train RMSE: 0.2480
# Val RMSE: 0.2482, Val MAE: 0.1057
# Test RMSE: 0.3250, Test MAE: 0.1497
# ---------------------------------
# Patience grace period: 5
# ---------------------------------
# Epoch 164/500
# Train RMSE: 0.2480
# Val RMSE: 0.2482, Val MAE: 0.1067
# Test RMSE: 0.3235, Test MAE: 0.1503
# ---------------------------------
# Patience grace period: 3
# ---------------------------------
# Epoch 165/500
# Train RMSE: 0.2480
# Val RMSE: 0.2481, Val MAE: 0.1058
# Test RMSE: 0.3253, Test MAE: 0.1497
# ---------------------------------
# Model saved at epoch 165 with val RMSE 0.2481
# Patience grace period: 2
# ---------------------------------
# Epoch 166/500
# Train RMSE: 0.2480
# Val RMSE: 0.2482, Val MAE: 0.1063
# Test RMSE: 0.3241, Test MAE: 0.1501
# ---------------------------------
# Patience grace period: 0
# Early stopping triggered at epoch 166
# Final Test RMSE: 0.3253, Final Test MAE: 0.1497
# <ipython-input-3-2a228d64b832>:126: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   self.model.load_state_dict(torch.load(os.path.join(save_dir, 'best_model.pth')))
# Pearson Corr: 0.7481616425289367
# Spearman Corr: 0.4305377827389911
# p-rmse: 0.3252962889282863
#        rmse       mae  seed                             subtask    method  \
# 0  0.325296  0.149724     5  openproblems_bmmc_cite_phase2_mod2  original
#
#     pearson p_value_pearson  spearman p_value_spearman
# 0  0.748162          0.0000  0.430538           0.0000
